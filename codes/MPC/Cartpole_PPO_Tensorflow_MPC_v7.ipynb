# %% [markdown]
# **References:**
#
# - https://keras.io/examples/rl/ppo_cartpole/
# - [Proximal Policy Optimization Algorithms](https://arxiv.org/abs/1707.06347)
# - [OpenAI Spinning Up docs - PPO](https://spinningup.openai.com/en/latest/algorithms/ppo.html)
# - [OpenAI Spinning Up Github - PPO](https://github.com/openai/spinningup/blob/master/spinup/algos/tf1/ppo/ppo.py)
# - https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py

# %%
import warnings

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'


import tensorflow as tf
#from tf import keras as keras
import keras
from keras import layers

import numpy as np
import gym
import scipy.signal

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle

# %%
np.seterr(all="ignore")
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
import matplotlib, cv2
import matplotlib.pyplot as plt
import base64, io, os, time
import IPython, functools
#from tqdm import tqdm
import tensorflow_probability as tfp
import math
from typing import Optional
from gym import spaces, logger
from gym.utils import seeding
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if (distutils.version.LooseVersion(tf.__version__) <
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
warnings.filterwarnings("ignore", message=".*Conversion of an array with ndim > 0 to a scalar.*")
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
from numpy.linalg import matrix_power
from scipy.linalg import block_diag

# %% [markdown]
# ## Functions and class

# %%
class CartPoleEnvCustomized(gym.Env):
    """
    ### Description
    This environment corresponds to the version of the cart-pole problem
    described by Barto, Sutton, and Anderson in ["Neuronlike Adaptive Elements That Can Solve Difficult Learning Control Problem"](https://ieeexplore.ieee.org/document/6313077).
    A pole is attached by an un-actuated joint to a cart, which moves along a
    frictionless track. The pendulum starts upright, and the goal is to prevent
    it from falling over by increasing and reducing the cart's velocity.
    ### Action Space
    The agent take a 1-element vector for actions.
    The action space is `(action)` in `[0, 1]`, where `action` is used to push
    the cart with a fixed amount of force:
    | Num | Action                 |
    |-----|------------------------|
    | 0   | Push cart to the left  |
    | 1   | Push cart to the right |
    Note: The amount the velocity is reduced or increased is not fixed as it depends on the angle the pole is pointing.
    This is because the center of gravity of the pole increases the amount of energy needed to move the cart underneath it
    ### Observation Space
    The observation is a `ndarray` with shape `(4,)` where the elements correspond to the following:
    | Num | Observation           | Min                  | Max                |
    |-----|-----------------------|----------------------|--------------------|
    | 0   | Cart Position         | -4.8*                 | 4.8*                |
    | 1   | Cart Velocity         | -Inf                 | Inf                |
    | 2   | Pole Angle            | ~ -0.418 rad (-24°)** | ~ 0.418 rad (24°)** |
    | 3   | Pole Angular Velocity | -Inf                 | Inf                |
    **Note:** above denotes the ranges of possible observations for each element, but in two cases this range exceeds the
    range of possible values in an un-terminated episode:
    - `*`: the cart x-position can be observed between `(-4.8, 4.8)`, but an episode terminates if the cart leaves the
    `(-2.4, 2.4)` range.
    - `**`: Similarly, the pole angle can be observed between  `(-.418, .418)` radians or precisely **±24°**, but an episode is
    terminated if the pole angle is outside the `(-.2095, .2095)` range or precisely **±12°**
    ### Rewards
    Reward is 1 for every step taken, including the termination step. The threshold is 475 for v1.
    ### Starting State
    All observations are assigned a uniform random value between (-0.05, 0.05)
    ### Episode Termination
    The episode terminates of one of the following occurs:
    1. Pole Angle is more than ±12°
    2. Cart Position is more than ±2.4 (center of the cart reaches the edge of the display)
    3. Episode length is greater than 500 (200 for v0)
    ### Arguments
    No additional arguments are currently supported.
    """

    metadata = {"render.modes": ["human", "rgb_array"], "video.frames_per_second": 50}

    def __init__(self):
        self.gravity = 9.8
        self.masscart = 1.0
        self.masspole = 0.1
        self.total_mass = self.masspole + self.masscart
        self.length = 0.5  # actually half the pole's length
        self.polemass_length = self.masspole * self.length
        self.force_mag = 10.0
        self.dt = 0.02  # seconds between state updates
        self.kinematics_integrator = None # "euler","semi-implicit euler"


        # Angle at which to fail the episode
        self.theta_threshold_radians = 12 * 2 * math.pi / 360
        self.x_threshold = 2.4
        #self.i_threshold = self.force_mag / self.torque_const_Kt

        # Angle limit set to 2 * theta_threshold_radians so failing observation
        # is still within bounds.
        high = np.array(
            [
                self.x_threshold * 2,
                np.finfo(np.float32).max,
                self.theta_threshold_radians * 2,
                np.finfo(np.float32).max,
            ],
            dtype=np.float32,
        )

        self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        self.viewer = None
        self.state = None

        self.steps_beyond_done = None

        ### Customization changes ######
        self.DCMotor_radius = 0.15 #0.2 #### chnge actualy diameter and arm len for rotation
        self.NumIntegrationsSteps = 1
        self.MPC = ModelPredictCtrl()
        self.MPC.N = 60
        dt_prime = self.dt/self.NumIntegrationsSteps
        self.tau = dt_prime
        self.MPC.dt = dt_prime
        self.MPC.plant.tau1 = dt_prime
        self.MPC.ref_model.tau1 = dt_prime
        self.MPC.ConfigureMPCParams()
        self.wanted_torque = 0
        ####


    def step(self, action):
        err_msg = f"{action!r} ({type(action)}) invalid"
        assert self.action_space.contains(action), err_msg

        x, x_dot, theta, theta_dot = self.state
        force = +self.force_mag if action == 1 else -self.force_mag #+/-10N
        #wanted_torque_ret = self.wanted_torque #return old action
        torque_wanted = force*self.DCMotor_radius
        self.MPC.y_spf = torque_wanted
        beta_AF = 0.5
        torque_wanted =  (beta_AF)*self.wanted_torque+(1-beta_AF)*torque_wanted
        self.wanted_torque = torque_wanted
        self.MPC.y[0] = torque_wanted #self.MPC.y_spf #torque_wanted
        wanted_torque_ret = self.wanted_torque
        ### Customization changes #####
        for n in np.arange(start=0, stop=self.NumIntegrationsSteps, step=1):
          #w = x_dot/self.DCMotor_radius
          self.MPC.plant.thetadot =  x_dot/self.DCMotor_radius
          torque_actual = self.MPC.step()
          F = torque_actual/self.DCMotor_radius
          #F = torque_wanted/self.DCMotor_radius #ideal env
          ###

          costheta = math.cos(theta)
          sintheta = math.sin(theta)

          # For the interested reader:
          # https://coneural.org/florian/papers/05_cart_pole.pdf
          temp = (
              F + self.polemass_length * theta_dot ** 2 * sintheta
          ) / self.total_mass
          thetaacc = (self.gravity * sintheta - costheta * temp) / (
              self.length * (4.0 / 3.0 - self.masspole * costheta ** 2 / self.total_mass)
          )
          xacc = temp - self.polemass_length * thetaacc * costheta / self.total_mass

          if self.kinematics_integrator == "euler":
              x = x + self.tau * x_dot
              x_dot = x_dot + self.tau * xacc
              theta = theta + self.tau * theta_dot
              theta_dot = theta_dot + self.tau * thetaacc
          elif self.kinematics_integrator == "semi-implicit euler":
              x_dot = x_dot + self.tau * xacc
              x = x + self.tau * x_dot
              theta_dot = theta_dot + self.tau * thetaacc
              theta = theta + self.tau * theta_dot
          else: # trapz on velocities
              new_x_dot = x_dot + self.tau * xacc
              new_theta_dot = theta_dot + self.tau * thetaacc
              x = x + self.tau * (x_dot+new_x_dot)/2
              theta = theta + self.tau * (theta_dot+new_theta_dot)/2
              x_dot = new_x_dot+0
              theta_dot = new_theta_dot+0


        self.state = (x, x_dot, theta, theta_dot)

        done = bool(
            x < -self.x_threshold
            or x > self.x_threshold
            or theta < -self.theta_threshold_radians
            or theta > self.theta_threshold_radians
        )

        if not done: # if we inside the valid range
            reward = 1.0

        elif self.steps_beyond_done is None:
            # Pole just fell!
            self.steps_beyond_done = 0
            reward = 1.0

        else:
            if self.steps_beyond_done == 0:
                logger.warn(
                    "You are calling 'step()' even though this "
                    "environment has already returned done = True. You "
                    "should always call 'reset()' once you receive 'done = "
                    "True' -- any further steps are undefined behavior."
                )
            self.steps_beyond_done += 1
            reward = 0.0

        return np.array(self.state, dtype=np.float32), reward, done, {} ,wanted_torque_ret, torque_actual


    def reset(self, return_info = False, options = None):
        #super().reset(seed=seed)
        self.state = np.random.uniform(low=-0.05, high=0.05, size=(4,))

        self.steps_beyond_done = None

        ### reset MPC
        self.MPC.reset()
        self.MPC.plant.reset()
        self.MPC.ref_model.reset()
        self.wanted_torque = 0
        #

        if not return_info:
            return np.array(self.state, dtype=np.float32)
        else:
            return np.array(self.state, dtype=np.float32), {}

    def render(self, mode="human"):
        screen_width = 600
        screen_height = 400

        world_width = self.x_threshold * 2
        scale = screen_width / world_width
        carty = 100  # TOP OF CART
        polewidth = 10.0
        polelen = scale * (2 * self.length)
        cartwidth = 50.0
        cartheight = 30.0

        if self.viewer is None:
            #from gym.utils import pyglet_rendering
            from gym.envs.classic_control import rendering as pyglet_rendering

            self.viewer = pyglet_rendering.Viewer(screen_width, screen_height)
            l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
            axleoffset = cartheight / 4.0
            cart = pyglet_rendering.FilledPolygon([(l, b), (l, t), (r, t), (r, b)])
            self.carttrans = pyglet_rendering.Transform()
            cart.add_attr(self.carttrans)
            self.viewer.add_geom(cart)
            l, r, t, b = (
                -polewidth / 2,
                polewidth / 2,
                polelen - polewidth / 2,
                -polewidth / 2,
            )
            pole = pyglet_rendering.FilledPolygon([(l, b), (l, t), (r, t), (r, b)])
            pole.set_color(0.8, 0.6, 0.4)
            self.poletrans = pyglet_rendering.Transform(translation=(0, axleoffset))
            pole.add_attr(self.poletrans)
            pole.add_attr(self.carttrans)
            self.viewer.add_geom(pole)
            self.axle = pyglet_rendering.make_circle(polewidth / 2)
            self.axle.add_attr(self.poletrans)
            self.axle.add_attr(self.carttrans)
            self.axle.set_color(0.5, 0.5, 0.8)
            self.viewer.add_geom(self.axle)
            self.track = pyglet_rendering.Line((0, carty), (screen_width, carty))
            self.track.set_color(0, 0, 0)
            self.viewer.add_geom(self.track)

            self._pole_geom = pole

        if self.state is None:
            return None

        # Edit the pole polygon vertex
        pole = self._pole_geom
        l, r, t, b = (
            -polewidth / 2,
            polewidth / 2,
            polelen - polewidth / 2,
            -polewidth / 2,
        )
        pole.v = [(l, b), (l, t), (r, t), (r, b)]

        x = self.state
        cartx = x[0] * scale + screen_width / 2.0  # MIDDLE OF CART
        self.carttrans.set_translation(cartx, carty)
        self.poletrans.set_rotation(-x[2])

        return self.viewer.render(return_rgb_array=mode == "rgb_array")

    def close(self):
        if self.viewer:
            self.viewer.close()
            self.viewer = None

# %%
class ElectricalDCMotorEnv():

  def __init__(self):
    self.Resistor_R = 1.0
    self.inductor_L = 0.1
    self.torque_const_Kt = 1.0
    self.bemf_const_Ke = 1.0
    self.tau1 = 0.05
    self.ZOH_mode = True
        #
    self.current = 0.0
    self.voltage_input = None
    self.thetadot = 0.0
    self.F = 0.0

  def step(self, u):
    voltage_BEMF = self.thetadot*self.bemf_const_Ke
    self.voltage_input = np.clip(u, -10, 10)

    f1 = self.torque_const_Kt*self.current
    if self.ZOH_mode:
      a = np.exp(-self.tau1*self.Resistor_R/self.inductor_L)
      self.current = a*self.current + (1-a)/self.Resistor_R*(u-voltage_BEMF)
    else:
      self.current += self.tau1*(self.voltage_input-voltage_BEMF-self.current*self.Resistor_R)/self.inductor_L
    f2 = self.torque_const_Kt*self.current
    self.F=f2 #f1 #f2 #(f1+f2)/2
    return self.F # return actual applied torque

  def reset(self):
    self.current = 0.0
    self.F = 0.0

# %%
class ReferenceModel():

  def __init__(self):
    self.tau1 = 0.05
    self.A_rm = np.array([[0]])
    self.B_rm = np.array([[0]])
    self.y_rm = np.array([[0]])

  def step(self, u):
    # TODO: complete
    #for _ in range(0,1):
    y_m_prev = self.y_rm+0
    self.y_rm = self.A_rm@self.y_rm + self.B_rm*u
    return self.y_rm #y_m_prev #self.y_rm

  def reset(self):
    self.y_rm = np.array([[0]])

# %%
class ModelPredictCtrl:

  def __init__(self,dt=0.01, N=60,
               a_sp = 1, b_sp = 0,
               R_resistor = 1, L_inductor = 0.1,
               k_t=1,k_w=1):
    self.plant = ElectricalDCMotorEnv()
    self.ref_model = ReferenceModel()
    self.dt = dt
    self.a_sp = a_sp
    self.b_sp = b_sp
    self.R_resistor = R_resistor
    self.L_inductor = L_inductor
    self.k_t = k_t
    self.k_w = k_w
    self.N=N
    self.A_pm = None
    self.B_pm = None
    self.A = None
    self.B = None
    self.Atilde = None
    self.Q1 = np.array([[1,-1]]) ####
    self.Q = None
    self.R = None
    self.y_spf = None
    self.K = None
    self.K_MPC = None
    self.y = np.array([[0],[0]])
    self.u = 0


  def ConfigureMPCParams(self):

    # Configure reference model
    A_sp = self.a_sp
    A_rm = np.array([[A_sp]])
    B_rm = np.array([[self.b_sp]])
    self.ref_model.A_rm = A_rm
    self.ref_model.B_rm = B_rm


    # Configure plant model
    dt = self.dt
    # note: self.dt and self.ref_model.tau1 aren't necessarily the same
    A_sp = self.a_sp
    A_pm = np.exp(-self.R_resistor/self.L_inductor*dt)
    B_pm = self.k_t*(1-A_pm)/self.R_resistor
    B = np.array([[self.b_sp],[B_pm]])
    self.A = np.array([[A_sp,0],[0,A_pm]])
    self.B = B


    # Confgure weight matrices Q & R and control gain K_mpc
    N = self.N
    A = self.A
    B = self.B
    B_shape_1 = B.shape[1]

    Atilde = 0
    for n in range(0,N):
      if n==0:
        Atilde = A*1
      else:
        Atilde = np.vstack((Atilde,matrix_power(A, n+1)))
    self.Atilde = Atilde

    Btilde = 0
    for i in range(0,N):
      if i==0:
        Btilde = B*1
      else:
        Btilde = np.hstack((Btilde,B*0))
    for i in range(1,N):
      for j in range(0,N):
        if j==0:
          row = matrix_power(A, i)@B
        elif i>=j:
          row = np.hstack((row,matrix_power(A, i-j)@B))
        else:
          row = np.hstack((row,i*0*B))
      Btilde = np.vstack((Btilde,row))

    Q1 = self.Q1
    Q1_N = Q1+0
    for n in range(1,N):
      Q1_N = block_diag(Q1_N,Q1)
    W_Q = 100*np.eye(N)
    W_Q[0,0] = 500
    Q = ((Q1_N.T)@(W_Q))@Q1_N#####
    self.Q = Q

    I=np.eye(B_shape_1)
    O=0*I

    R1 = 0
    for i in range(0,N):
      if i==0:
        R1 = I
      else:
        R1 = np.hstack((R1,O))
    row = 0
    for i in range(1,N):
      for j in range(0,N):
        if j==0:
          row = -I*(i==1)
          continue
        elif i==j:
          Mij = I
        elif i==j+1:
          Mij = -I
        else:
          Mij = O
        row = np.hstack((row,Mij))
      R1 = np.vstack((R1,row))

    R2 = 0
    for i in range(0,N):
      if i==0:
          R2 = I
      else:
          R2 = np.hstack((R2,O))
    row = 0
    for i in range(1,N):
      for j in range(0,N):
        if j==0:
          row = -I
          continue
        else:
          Mij = I*(i==j)
        row = np.hstack((row,Mij))
      R2 = np.vstack((R2,row))

    R3 = 0
    for i in range(0,N):
      if i==0:
        R3 = I
      else:
        R3 = np.hstack((R3,O))
    row = 0
    for i in range(1,N):
      for j in range(0,N):
        if j==0:
          row = -I*(i==1)
          continue
        elif i==j+1:
          Mij = -I
        else:
          Mij = (i<=j)*I/(N-i)
        row = np.hstack((row,Mij))
      R3 = np.vstack((R3,row))

    W_R = 0.01*np.eye(N*B_shape_1)
    W_R[0,0]=0.2 #5
    R=0.334*R1+0.333*R2+0.333*R3
    R=(R.T)@(W_R)@(R)
    self.R=R

    BTQ = Btilde.T@Q
    BTQB= BTQ@Btilde
    K = -np.linalg.pinv(BTQB+R)@BTQ
    R0 = 0
    for i in range(0,N):
      if i==0:
          R0 = I
      else:
          R0 = np.hstack((R0,O))
    self.K = R0@K
    self.K_MPC = self.K@Atilde
    #self.Atilde = Atilde

  def computeCtrlInput(self, y):#, w):
    self.u = (self.K_MPC@y).item()
    self.u = np.clip(self.u, -10, 10)
    return self.u

  def step(self):
    #self.y[0] = y_sp0
    u = self.computeCtrlInput(self.y)#, self.plant.thetadot)
    self.u = u#+1*self.plant.thetadot
    self.u = np.clip(self.u, -10, 10)
    y_rm = self.ref_model.step(self.u)#(u)
    self.u = u+self.k_w*self.plant.thetadot
    self.u = np.clip(self.u, -10, 10)
    y_pm = self.plant.step(self.u)
    self.y = np.vstack((y_rm,y_pm))
    return self.y[1].item()

  def reset(self):
    self.y = np.array([[0],[0]])
    self.u = 0

# %%
env = CartPoleEnvCustomized()

# %%
print("Sample Time: dt= ", env.dt)
print("Num Integrations Steps: N= ", env.NumIntegrationsSteps)
print("Integration Time: dt/N=", env.dt/env.NumIntegrationsSteps)
# Out:
# Sample Time: dt=  0.02
# Num Integrations Steps: N=  1
# Integration Time: dt/N= 0.02

# %%
print("K_MPC= ", env.MPC.K_MPC)
# Out:
# K_MPC=  [[ 5.4295893  -4.44155325]]

# %%
def discounted_cumulative_sums(x, discount):
    # Discounted cumulative sums of vectors for computing rewards-to-go and advantage estimates
    return scipy.signal.lfilter([1], [1, float(-discount)], x[::-1], axis=0)[::-1]


class Buffer:
    # Buffer for storing trajectories
    def __init__(self, observation_dimensions, size, gamma=0.99, lam=0.95):
        # Buffer initialization
        self.observation_buffer = np.zeros(
            (size, observation_dimensions), dtype=np.float32
        )
        self.action_buffer = np.zeros(size, dtype=np.int32)
        self.advantage_buffer = np.zeros(size, dtype=np.float32)
        self.reward_buffer = np.zeros(size, dtype=np.float32)
        self.return_buffer = np.zeros(size, dtype=np.float32)
        self.value_buffer = np.zeros(size, dtype=np.float32)
        self.logprobability_buffer = np.zeros(size, dtype=np.float32)
        self.gamma, self.lam = gamma, lam
        self.pointer, self.trajectory_start_index = 0, 0

    def store(self, observation, action, reward, value, logprobability):
        # Append one step of agent-environment interaction
        self.observation_buffer[self.pointer] = observation
        self.action_buffer[self.pointer] = action
        self.reward_buffer[self.pointer] = reward
        self.value_buffer[self.pointer] = value
        self.logprobability_buffer[self.pointer] = logprobability
        self.pointer += 1

    def finish_trajectory(self, last_value=0):
        # Finish the trajectory by computing advantage estimates and rewards-to-go
        path_slice = slice(self.trajectory_start_index, self.pointer)
        rewards = np.append(self.reward_buffer[path_slice], last_value)
        values = np.append(self.value_buffer[path_slice], last_value)

        deltas = rewards[:-1] + self.gamma * values[1:] - values[:-1]

        self.advantage_buffer[path_slice] = discounted_cumulative_sums(
            deltas, self.gamma * self.lam
        )
        self.return_buffer[path_slice] = discounted_cumulative_sums(
            rewards, self.gamma
        )[:-1]

        self.trajectory_start_index = self.pointer

    def get(self):
        # Get all data of the buffer and normalize the advantages
        self.pointer, self.trajectory_start_index = 0, 0
        advantage_mean, advantage_std = (
            np.mean(self.advantage_buffer),
            np.std(self.advantage_buffer),
        )
        self.advantage_buffer = (self.advantage_buffer - advantage_mean) / advantage_std
        return (
            self.observation_buffer,
            self.action_buffer,
            self.advantage_buffer,
            self.return_buffer,
            self.logprobability_buffer,
        )

#output_activation=None
def mlp(x, sizes, activation=keras.activations.tanh,
        output_activation=None):
    # Build a feedforward neural network
    for size in sizes[:-1]:
        x = layers.Dense(units=size, activation=activation)(x)
    return layers.Dense(units=sizes[-1], activation=output_activation)(x)



def logprobabilities(logits, a):
    # Compute the log-probabilities of taking actions a by using the logits (i.e. the output of the actor)
    logprobabilities_all = keras.ops.log_softmax(logits)
    logprobability = keras.ops.sum(
        keras.ops.one_hot(a, num_actions) * logprobabilities_all, axis=1
    )
    return logprobability


seed_generator = keras.random.SeedGenerator(1337)


# Sample action from actor
@tf.function
def sample_action(observation):
    logits = actor(observation)
    action = keras.ops.squeeze(
        keras.random.categorical(logits, 1, seed=seed_generator), axis=1
    )
    return logits, action


# Train the policy by maxizing the PPO-Clip objective
@tf.function
def train_policy(
    observation_buffer, action_buffer, logprobability_buffer, advantage_buffer
):
    with tf.GradientTape() as tape:  # Record operations for automatic differentiation.
        ratio = keras.ops.exp(
            logprobabilities(actor(observation_buffer), action_buffer)
            - logprobability_buffer
        )
        min_advantage = keras.ops.where(
            advantage_buffer > 0,
            (1 + clip_ratio) * advantage_buffer,
            (1 - clip_ratio) * advantage_buffer,
        )

        policy_loss = -keras.ops.mean(
            keras.ops.minimum(ratio * advantage_buffer, min_advantage)
        )
    policy_grads = tape.gradient(policy_loss, actor.trainable_variables)
    policy_optimizer.apply_gradients(zip(policy_grads, actor.trainable_variables))

    kl = keras.ops.mean(
        logprobability_buffer
        - logprobabilities(actor(observation_buffer), action_buffer)
    )
    kl = keras.ops.sum(kl)
    return kl


# Train the value function by regression on mean-squared error
@tf.function
def train_value_function(observation_buffer, return_buffer):
    with tf.GradientTape() as tape:  # Record operations for automatic differentiation.
        value_loss = keras.ops.mean((return_buffer - critic(observation_buffer)) ** 2)
    value_grads = tape.gradient(value_loss, critic.trainable_variables)
    value_optimizer.apply_gradients(zip(value_grads, critic.trainable_variables))

# %% [markdown]
# ## Hyperparameters

# %%
# Hyperparameters of the PPO algorithm
steps_per_epoch = 4000
epochs = 100 #60 # 40 #30
steps_per_episode_goal = 500
episodes_max = 2500 #3000
gamma = 0.99
clip_ratio = 0.2
policy_learning_rate = 3e-4
value_function_learning_rate = 1e-3
train_policy_iterations = 80
train_value_iterations = 80
lam = 0.97
target_kl = 0.01
hidden_sizes = (64, 64)

# True if you want to render the environment
render = False

# %% [markdown]
# ## Initializations

# %%
# Initialize the environment and get the dimensionality of the
# observation space and the number of possible actions
env = CartPoleEnvCustomized()
observation_dimensions = env.observation_space.shape[0]
num_actions = env.action_space.n

# Initialize the buffer
buffer = Buffer(observation_dimensions, steps_per_epoch)

# Initialize the actor and the critic as keras models
observation_input = keras.Input(shape=(observation_dimensions,), dtype="float32")
logits = mlp(observation_input, list(hidden_sizes) + [num_actions])
actor = keras.Model(inputs=observation_input, outputs=logits)
value = keras.ops.squeeze(mlp(observation_input, list(hidden_sizes) + [1]), axis=1)
critic = keras.Model(inputs=observation_input, outputs=value)

# Initialize the policy and the value function optimizers
policy_optimizer = keras.optimizers.Adam(learning_rate=policy_learning_rate)
value_optimizer = keras.optimizers.Adam(learning_rate=value_function_learning_rate)

# Initialize the observation, episode return and episode length
#observation, _ = env.reset()
observation = env.reset()
episode_return, episode_length = 0, 0

# %%
#actor.summary()

# %%
#critic.summary()

# %% [markdown]
# ## Train

# %%
avg_reward_list = []
acc_ep_reward_list = []

episode = 0
epoch = 0
# Iterate over the number of epochs/episodes
#while (epoch < epochs) and (episode < episodes_max):
while(episode < episodes_max):
    print(f"Epoch: {epoch}")
    # Initialize the sum of the returns, lengths and number of episodes for each epoch
    episode_return = 0.0
    t = 0
    # Iterate over the steps of each epoch
    #while (t < steps_per_epoch):
    while (t < steps_per_epoch) and (episode < episodes_max):
        if render:
            env.render()

        # Get the logits, action, and take one step in the environment
        observation = observation.reshape(1, -1)
        logits, action = sample_action(observation)
        #observation_new, reward, done, _, _ = env.step(action[0].numpy())
        observation_new, reward, done, _ ,torque_wanted, torque_actual= env.step(action[0].numpy().item())
        x_obs = observation_new[0]
        reward_learn= reward*(x_obs>-0.1 and x_obs<0.1)
        episode_return += reward

        # Get the value and log-probability of the action
        value_t = critic(observation)
        logprobability_t = logprobabilities(logits, action)
        # Store obs, act, rew, v_t, logp_pi_t
        buffer.store(observation, action, reward_learn, value_t, logprobability_t)
        # Update the observation
        observation = observation_new

        # Finish trajectory if reached to a terminal state
        terminal = done
        if terminal or (t == steps_per_epoch - 1) or ((t+1)%steps_per_episode_goal==0):
            #print(f"Episode: {episode}; Acc. Reward: {episode_return:.2f}")
            acc_ep_reward_list.append(episode_return)
            avg_return = round(np.mean(acc_ep_reward_list[-40:]))
            avg_reward_list.append(avg_return)
            episode_return = 0.0
            episode += 1
        #observation, _ = env.reset()
        if terminal or (t == steps_per_epoch - 1):# not necessarily (t+1)%steps_per_episode_goal==0
            last_value = 0 if done else critic(observation.reshape(1, -1))
            buffer.finish_trajectory(last_value)
            observation = env.reset()
            print(f"Episode: {episode}; Acc. Reward: {avg_return:.1f}; Pole fell: {terminal}")
            #acc_ep_reward_list.append(episode_return)
            #print(f"Episode: {episode} ;Acc. Reward: {episode_return:.1f}")
            #episode_return = 0.0
        t+=1
        #if episode >= episodes_max:
        #  break

    # Get values from the buffer
    (
        observation_buffer,
        action_buffer,
        advantage_buffer,
        return_buffer,
        logprobability_buffer,
    ) = buffer.get()

    # Update the policy and implement early stopping using KL divergence
    for _ in range(train_policy_iterations):
        kl = train_policy(
            observation_buffer, action_buffer, logprobability_buffer, advantage_buffer
        )
        if kl > 1.5 * target_kl:
            # Early Stopping
            break

    # Update the value function
    for _ in range(train_value_iterations):
        train_value_function(observation_buffer, return_buffer)
    epoch+=1
# Out:
# Epoch: 0
# Episode: 1; Acc. Reward: 29.0; Pole fell: True
# Episode: 2; Acc. Reward: 22.0; Pole fell: True
# Episode: 3; Acc. Reward: 21.0; Pole fell: True
# Episode: 4; Acc. Reward: 21.0; Pole fell: True
# Episode: 5; Acc. Reward: 20.0; Pole fell: True
# Episode: 6; Acc. Reward: 19.0; Pole fell: True
# Episode: 7; Acc. Reward: 18.0; Pole fell: True
# Episode: 8; Acc. Reward: 18.0; Pole fell: True
# Episode: 9; Acc. Reward: 18.0; Pole fell: True
# Episode: 10; Acc. Reward: 20.0; Pole fell: True
# Episode: 11; Acc. Reward: 20.0; Pole fell: True
# Episode: 12; Acc. Reward: 20.0; Pole fell: True
# Episode: 13; Acc. Reward: 21.0; Pole fell: True
# Episode: 14; Acc. Reward: 20.0; Pole fell: True
# Episode: 15; Acc. Reward: 22.0; Pole fell: True
# Episode: 16; Acc. Reward: 22.0; Pole fell: True
# Episode: 17; Acc. Reward: 21.0; Pole fell: True
# Episode: 18; Acc. Reward: 21.0; Pole fell: True
# Episode: 19; Acc. Reward: 21.0; Pole fell: True
# Episode: 20; Acc. Reward: 20.0; Pole fell: True
# Episode: 21; Acc. Reward: 20.0; Pole fell: True
# Episode: 22; Acc. Reward: 20.0; Pole fell: True
# Episode: 23; Acc. Reward: 20.0; Pole fell: True
# Episode: 24; Acc. Reward: 19.0; Pole fell: True
# Episode: 25; Acc. Reward: 19.0; Pole fell: True
# Episode: 26; Acc. Reward: 19.0; Pole fell: True
# Episode: 28; Acc. Reward: 18.0; Pole fell: True
# Episode: 29; Acc. Reward: 19.0; Pole fell: True
# Episode: 30; Acc. Reward: 18.0; Pole fell: True
# Episode: 31; Acc. Reward: 18.0; Pole fell: True
# Episode: 32; Acc. Reward: 19.0; Pole fell: True
# Episode: 33; Acc. Reward: 19.0; Pole fell: True
# Episode: 34; Acc. Reward: 19.0; Pole fell: True
# Episode: 35; Acc. Reward: 19.0; Pole fell: True
# Episode: 36; Acc. Reward: 19.0; Pole fell: True
# Episode: 37; Acc. Reward: 19.0; Pole fell: True
# Episode: 38; Acc. Reward: 19.0; Pole fell: True
# Episode: 39; Acc. Reward: 19.0; Pole fell: True
# Episode: 40; Acc. Reward: 19.0; Pole fell: True
# Episode: 41; Acc. Reward: 18.0; Pole fell: True
# Episode: 42; Acc. Reward: 19.0; Pole fell: True
# Episode: 43; Acc. Reward: 19.0; Pole fell: True
# Episode: 44; Acc. Reward: 19.0; Pole fell: True
# Episode: 45; Acc. Reward: 19.0; Pole fell: True
# Episode: 46; Acc. Reward: 19.0; Pole fell: True
# Episode: 47; Acc. Reward: 19.0; Pole fell: True
# Episode: 48; Acc. Reward: 19.0; Pole fell: True
# Episode: 49; Acc. Reward: 19.0; Pole fell: True
# Episode: 50; Acc. Reward: 19.0; Pole fell: True
# Episode: 51; Acc. Reward: 19.0; Pole fell: True
# Episode: 52; Acc. Reward: 19.0; Pole fell: True
# Episode: 54; Acc. Reward: 18.0; Pole fell: True
# Episode: 55; Acc. Reward: 18.0; Pole fell: True
# Episode: 56; Acc. Reward: 18.0; Pole fell: True
# Episode: 57; Acc. Reward: 18.0; Pole fell: True
# Episode: 58; Acc. Reward: 17.0; Pole fell: True
# Episode: 59; Acc. Reward: 18.0; Pole fell: True
# Episode: 60; Acc. Reward: 18.0; Pole fell: True
# Episode: 61; Acc. Reward: 18.0; Pole fell: True
# Episode: 62; Acc. Reward: 18.0; Pole fell: True
# Episode: 63; Acc. Reward: 18.0; Pole fell: True
# Episode: 64; Acc. Reward: 18.0; Pole fell: True
# Episode: 65; Acc. Reward: 18.0; Pole fell: True
# Episode: 66; Acc. Reward: 18.0; Pole fell: True
# Episode: 67; Acc. Reward: 19.0; Pole fell: True
# Episode: 68; Acc. Reward: 19.0; Pole fell: True
# Episode: 69; Acc. Reward: 19.0; Pole fell: True
# Episode: 70; Acc. Reward: 19.0; Pole fell: True
# Episode: 71; Acc. Reward: 19.0; Pole fell: True
# Episode: 72; Acc. Reward: 19.0; Pole fell: True
# Episode: 73; Acc. Reward: 19.0; Pole fell: True
# Episode: 74; Acc. Reward: 19.0; Pole fell: True
# Episode: 75; Acc. Reward: 19.0; Pole fell: True
# Episode: 76; Acc. Reward: 19.0; Pole fell: True
# Episode: 77; Acc. Reward: 19.0; Pole fell: True
# Episode: 79; Acc. Reward: 20.0; Pole fell: True
# Episode: 80; Acc. Reward: 19.0; Pole fell: True
# Episode: 81; Acc. Reward: 19.0; Pole fell: True
# Episode: 82; Acc. Reward: 19.0; Pole fell: True
# Episode: 83; Acc. Reward: 18.0; Pole fell: True
# Episode: 84; Acc. Reward: 19.0; Pole fell: True
# Episode: 85; Acc. Reward: 19.0; Pole fell: True
# Episode: 86; Acc. Reward: 19.0; Pole fell: True
# Episode: 87; Acc. Reward: 19.0; Pole fell: True
# Episode: 88; Acc. Reward: 19.0; Pole fell: True
# Episode: 89; Acc. Reward: 19.0; Pole fell: True
# Episode: 90; Acc. Reward: 19.0; Pole fell: True
# Episode: 91; Acc. Reward: 19.0; Pole fell: True
# Episode: 92; Acc. Reward: 19.0; Pole fell: True
# Episode: 93; Acc. Reward: 19.0; Pole fell: True
# Episode: 94; Acc. Reward: 19.0; Pole fell: True
# Episode: 95; Acc. Reward: 20.0; Pole fell: True
# Episode: 96; Acc. Reward: 20.0; Pole fell: True
# Episode: 97; Acc. Reward: 20.0; Pole fell: True
# Episode: 98; Acc. Reward: 21.0; Pole fell: True
# Episode: 99; Acc. Reward: 20.0; Pole fell: True
# Episode: 100; Acc. Reward: 20.0; Pole fell: True
# Episode: 101; Acc. Reward: 20.0; Pole fell: True
# Episode: 102; Acc. Reward: 20.0; Pole fell: True
# Episode: 103; Acc. Reward: 20.0; Pole fell: True
# Episode: 104; Acc. Reward: 20.0; Pole fell: True
# Episode: 106; Acc. Reward: 20.0; Pole fell: True
# Episode: 107; Acc. Reward: 19.0; Pole fell: True
# Episode: 108; Acc. Reward: 19.0; Pole fell: True
# Episode: 109; Acc. Reward: 19.0; Pole fell: True
# Episode: 110; Acc. Reward: 19.0; Pole fell: True
# Episode: 111; Acc. Reward: 18.0; Pole fell: True
# Episode: 112; Acc. Reward: 19.0; Pole fell: True
# Episode: 113; Acc. Reward: 18.0; Pole fell: True
# Episode: 114; Acc. Reward: 19.0; Pole fell: True
# Episode: 115; Acc. Reward: 18.0; Pole fell: True
# Episode: 116; Acc. Reward: 18.0; Pole fell: True
# Episode: 117; Acc. Reward: 18.0; Pole fell: True
# Episode: 118; Acc. Reward: 18.0; Pole fell: True
# Episode: 119; Acc. Reward: 18.0; Pole fell: True
# Episode: 120; Acc. Reward: 18.0; Pole fell: True
# Episode: 121; Acc. Reward: 19.0; Pole fell: True
# Episode: 122; Acc. Reward: 18.0; Pole fell: True
# Episode: 123; Acc. Reward: 19.0; Pole fell: True
# Episode: 124; Acc. Reward: 18.0; Pole fell: True
# Episode: 125; Acc. Reward: 18.0; Pole fell: True
# Episode: 126; Acc. Reward: 18.0; Pole fell: True
# Episode: 127; Acc. Reward: 18.0; Pole fell: True
# Episode: 128; Acc. Reward: 18.0; Pole fell: True
# Episode: 129; Acc. Reward: 19.0; Pole fell: True
# Episode: 130; Acc. Reward: 18.0; Pole fell: True
# Episode: 131; Acc. Reward: 18.0; Pole fell: True
# Episode: 132; Acc. Reward: 18.0; Pole fell: True
# Episode: 133; Acc. Reward: 18.0; Pole fell: True
# Episode: 135; Acc. Reward: 17.0; Pole fell: True
# Episode: 136; Acc. Reward: 18.0; Pole fell: True
# Episode: 137; Acc. Reward: 17.0; Pole fell: True
# Episode: 138; Acc. Reward: 17.0; Pole fell: True
# Episode: 139; Acc. Reward: 17.0; Pole fell: True
# Episode: 140; Acc. Reward: 17.0; Pole fell: True
# Episode: 141; Acc. Reward: 17.0; Pole fell: True
# Episode: 142; Acc. Reward: 17.0; Pole fell: True
# Episode: 143; Acc. Reward: 17.0; Pole fell: True
# Episode: 144; Acc. Reward: 17.0; Pole fell: True
# Episode: 145; Acc. Reward: 17.0; Pole fell: True
# Episode: 146; Acc. Reward: 18.0; Pole fell: True
# Episode: 147; Acc. Reward: 18.0; Pole fell: True
# Episode: 148; Acc. Reward: 18.0; Pole fell: True
# Episode: 149; Acc. Reward: 18.0; Pole fell: True
# Episode: 150; Acc. Reward: 18.0; Pole fell: True
# Episode: 151; Acc. Reward: 18.0; Pole fell: True
# Episode: 152; Acc. Reward: 18.0; Pole fell: True
# Episode: 153; Acc. Reward: 19.0; Pole fell: True
# Episode: 154; Acc. Reward: 19.0; Pole fell: True
# Episode: 155; Acc. Reward: 19.0; Pole fell: True
# Episode: 156; Acc. Reward: 19.0; Pole fell: True
# Episode: 157; Acc. Reward: 18.0; Pole fell: True
# Episode: 158; Acc. Reward: 18.0; Pole fell: True
# Episode: 159; Acc. Reward: 19.0; Pole fell: True
# Episode: 160; Acc. Reward: 19.0; Pole fell: True
# Episode: 161; Acc. Reward: 19.0; Pole fell: True
# Episode: 162; Acc. Reward: 19.0; Pole fell: True
# Episode: 163; Acc. Reward: 20.0; Pole fell: True
# Episode: 164; Acc. Reward: 20.0; Pole fell: True
# Episode: 165; Acc. Reward: 20.0; Pole fell: True
# Episode: 166; Acc. Reward: 20.0; Pole fell: True
# Episode: 167; Acc. Reward: 20.0; Pole fell: True
# Episode: 168; Acc. Reward: 20.0; Pole fell: True
# Episode: 169; Acc. Reward: 20.0; Pole fell: True
# Episode: 170; Acc. Reward: 20.0; Pole fell: True
# Episode: 171; Acc. Reward: 20.0; Pole fell: True
# Episode: 172; Acc. Reward: 20.0; Pole fell: True
# Episode: 173; Acc. Reward: 20.0; Pole fell: True
# Episode: 174; Acc. Reward: 22.0; Pole fell: True
# Episode: 175; Acc. Reward: 21.0; Pole fell: True
# Episode: 176; Acc. Reward: 23.0; Pole fell: True
# Episode: 177; Acc. Reward: 23.0; Pole fell: True
# Episode: 178; Acc. Reward: 23.0; Pole fell: True
# Episode: 180; Acc. Reward: 22.0; Pole fell: True
# Episode: 181; Acc. Reward: 23.0; Pole fell: True
# Episode: 182; Acc. Reward: 23.0; Pole fell: True
# Episode: 183; Acc. Reward: 22.0; Pole fell: True
# Episode: 184; Acc. Reward: 22.0; Pole fell: True
# Episode: 185; Acc. Reward: 23.0; Pole fell: True
# Episode: 186; Acc. Reward: 22.0; Pole fell: True
# Episode: 187; Acc. Reward: 22.0; Pole fell: True
# Episode: 188; Acc. Reward: 23.0; Pole fell: True
# Episode: 189; Acc. Reward: 22.0; Pole fell: True
# Episode: 190; Acc. Reward: 23.0; Pole fell: True
# Episode: 191; Acc. Reward: 23.0; Pole fell: True
# Episode: 192; Acc. Reward: 23.0; Pole fell: True
# Episode: 193; Acc. Reward: 22.0; Pole fell: True
# Episode: 194; Acc. Reward: 22.0; Pole fell: True
# Episode: 195; Acc. Reward: 22.0; Pole fell: True
# Episode: 196; Acc. Reward: 23.0; Pole fell: True
# Episode: 197; Acc. Reward: 23.0; Pole fell: True
# Episode: 198; Acc. Reward: 22.0; Pole fell: True
# Episode: 199; Acc. Reward: 22.0; Pole fell: True
# Episode: 200; Acc. Reward: 22.0; Pole fell: True
# Episode: 201; Acc. Reward: 22.0; Pole fell: True
# Episode: 202; Acc. Reward: 22.0; Pole fell: True
# Episode: 203; Acc. Reward: 22.0; Pole fell: True
# Episode: 204; Acc. Reward: 21.0; Pole fell: True
# Episode: 205; Acc. Reward: 21.0; Pole fell: True
# Episode: 206; Acc. Reward: 21.0; Pole fell: False
# Epoch: 1
# Episode: 207; Acc. Reward: 21.0; Pole fell: True
# Episode: 208; Acc. Reward: 20.0; Pole fell: True
# Episode: 209; Acc. Reward: 20.0; Pole fell: True
# Episode: 210; Acc. Reward: 20.0; Pole fell: True
# Episode: 211; Acc. Reward: 20.0; Pole fell: True
# Episode: 212; Acc. Reward: 21.0; Pole fell: True
# Episode: 213; Acc. Reward: 21.0; Pole fell: True
# Episode: 214; Acc. Reward: 20.0; Pole fell: True
# Episode: 215; Acc. Reward: 20.0; Pole fell: True
# Episode: 216; Acc. Reward: 19.0; Pole fell: True
# Episode: 217; Acc. Reward: 19.0; Pole fell: True
# Episode: 218; Acc. Reward: 19.0; Pole fell: True
# Episode: 219; Acc. Reward: 19.0; Pole fell: True
# Episode: 220; Acc. Reward: 20.0; Pole fell: True
# Episode: 221; Acc. Reward: 20.0; Pole fell: True
# Episode: 222; Acc. Reward: 20.0; Pole fell: True
# Episode: 223; Acc. Reward: 20.0; Pole fell: True
# Episode: 224; Acc. Reward: 20.0; Pole fell: True
# Episode: 225; Acc. Reward: 20.0; Pole fell: True
# Episode: 226; Acc. Reward: 20.0; Pole fell: True
# Episode: 227; Acc. Reward: 21.0; Pole fell: True
# Episode: 228; Acc. Reward: 20.0; Pole fell: True
# Episode: 229; Acc. Reward: 20.0; Pole fell: True
# Episode: 231; Acc. Reward: 20.0; Pole fell: True
# Episode: 232; Acc. Reward: 20.0; Pole fell: True
# Episode: 233; Acc. Reward: 21.0; Pole fell: True
# Episode: 234; Acc. Reward: 21.0; Pole fell: True
# Episode: 235; Acc. Reward: 21.0; Pole fell: True
# Episode: 236; Acc. Reward: 21.0; Pole fell: True
# Episode: 237; Acc. Reward: 21.0; Pole fell: True
# Episode: 238; Acc. Reward: 21.0; Pole fell: True
# Episode: 239; Acc. Reward: 21.0; Pole fell: True
# Episode: 240; Acc. Reward: 21.0; Pole fell: True
# Episode: 241; Acc. Reward: 23.0; Pole fell: True
# Episode: 242; Acc. Reward: 23.0; Pole fell: True
# Episode: 243; Acc. Reward: 23.0; Pole fell: True
# Episode: 244; Acc. Reward: 24.0; Pole fell: True
# Episode: 245; Acc. Reward: 24.0; Pole fell: True
# Episode: 246; Acc. Reward: 24.0; Pole fell: True
# Episode: 247; Acc. Reward: 24.0; Pole fell: True
# Episode: 249; Acc. Reward: 24.0; Pole fell: True
# Episode: 250; Acc. Reward: 25.0; Pole fell: True
# Episode: 251; Acc. Reward: 25.0; Pole fell: True
# Episode: 252; Acc. Reward: 24.0; Pole fell: True
# Episode: 253; Acc. Reward: 24.0; Pole fell: True
# Episode: 254; Acc. Reward: 24.0; Pole fell: True
# Episode: 255; Acc. Reward: 24.0; Pole fell: True
# Episode: 256; Acc. Reward: 24.0; Pole fell: True
# Episode: 257; Acc. Reward: 24.0; Pole fell: True
# Episode: 258; Acc. Reward: 24.0; Pole fell: True
# Episode: 259; Acc. Reward: 25.0; Pole fell: True
# Episode: 260; Acc. Reward: 24.0; Pole fell: True
# Episode: 261; Acc. Reward: 25.0; Pole fell: True
# Episode: 262; Acc. Reward: 25.0; Pole fell: True
# Episode: 263; Acc. Reward: 24.0; Pole fell: True
# Episode: 264; Acc. Reward: 25.0; Pole fell: True
# Episode: 265; Acc. Reward: 25.0; Pole fell: True
# Episode: 266; Acc. Reward: 26.0; Pole fell: True
# Episode: 267; Acc. Reward: 25.0; Pole fell: True
# Episode: 268; Acc. Reward: 25.0; Pole fell: True
# Episode: 269; Acc. Reward: 25.0; Pole fell: True
# Episode: 271; Acc. Reward: 25.0; Pole fell: True
# Episode: 272; Acc. Reward: 25.0; Pole fell: True
# Episode: 273; Acc. Reward: 24.0; Pole fell: True
# Episode: 274; Acc. Reward: 24.0; Pole fell: True
# Episode: 275; Acc. Reward: 24.0; Pole fell: True
# Episode: 276; Acc. Reward: 25.0; Pole fell: True
# Episode: 277; Acc. Reward: 25.0; Pole fell: True
# Episode: 278; Acc. Reward: 25.0; Pole fell: True
# Episode: 279; Acc. Reward: 25.0; Pole fell: True
# Episode: 280; Acc. Reward: 25.0; Pole fell: True
# Episode: 281; Acc. Reward: 24.0; Pole fell: True
# Episode: 282; Acc. Reward: 24.0; Pole fell: True
# Episode: 283; Acc. Reward: 23.0; Pole fell: True
# Episode: 284; Acc. Reward: 23.0; Pole fell: True
# Episode: 285; Acc. Reward: 23.0; Pole fell: True
# Episode: 286; Acc. Reward: 23.0; Pole fell: True
# Episode: 287; Acc. Reward: 23.0; Pole fell: True
# Episode: 288; Acc. Reward: 23.0; Pole fell: True
# Episode: 289; Acc. Reward: 23.0; Pole fell: True
# Episode: 290; Acc. Reward: 22.0; Pole fell: True
# Episode: 292; Acc. Reward: 23.0; Pole fell: True
# Episode: 293; Acc. Reward: 23.0; Pole fell: True
# Episode: 294; Acc. Reward: 24.0; Pole fell: True
# Episode: 295; Acc. Reward: 23.0; Pole fell: True
# Episode: 296; Acc. Reward: 23.0; Pole fell: True
# Episode: 297; Acc. Reward: 23.0; Pole fell: True
# Episode: 298; Acc. Reward: 23.0; Pole fell: True
# Episode: 299; Acc. Reward: 22.0; Pole fell: True
# Episode: 300; Acc. Reward: 23.0; Pole fell: True
# Episode: 301; Acc. Reward: 23.0; Pole fell: True
# Episode: 302; Acc. Reward: 23.0; Pole fell: True
# Episode: 303; Acc. Reward: 23.0; Pole fell: True
# Episode: 304; Acc. Reward: 23.0; Pole fell: True
# Episode: 305; Acc. Reward: 23.0; Pole fell: True
# Episode: 306; Acc. Reward: 23.0; Pole fell: True
# Episode: 307; Acc. Reward: 23.0; Pole fell: True
# Episode: 308; Acc. Reward: 23.0; Pole fell: True
# Episode: 309; Acc. Reward: 23.0; Pole fell: True
# Episode: 310; Acc. Reward: 23.0; Pole fell: True
# Episode: 311; Acc. Reward: 23.0; Pole fell: True
# Episode: 312; Acc. Reward: 23.0; Pole fell: True
# Episode: 313; Acc. Reward: 24.0; Pole fell: True
# Episode: 315; Acc. Reward: 23.0; Pole fell: True
# Episode: 316; Acc. Reward: 22.0; Pole fell: True
# Episode: 317; Acc. Reward: 22.0; Pole fell: True
# Episode: 318; Acc. Reward: 22.0; Pole fell: True
# Episode: 319; Acc. Reward: 21.0; Pole fell: True
# Episode: 320; Acc. Reward: 22.0; Pole fell: True
# Episode: 321; Acc. Reward: 21.0; Pole fell: True
# Episode: 322; Acc. Reward: 21.0; Pole fell: True
# Episode: 323; Acc. Reward: 22.0; Pole fell: True
# Episode: 324; Acc. Reward: 22.0; Pole fell: True
# Episode: 325; Acc. Reward: 22.0; Pole fell: True
# Episode: 326; Acc. Reward: 22.0; Pole fell: True
# Episode: 327; Acc. Reward: 22.0; Pole fell: True
# Episode: 328; Acc. Reward: 22.0; Pole fell: True
# Episode: 329; Acc. Reward: 23.0; Pole fell: True
# Episode: 330; Acc. Reward: 23.0; Pole fell: True
# Episode: 331; Acc. Reward: 22.0; Pole fell: True
# Episode: 332; Acc. Reward: 23.0; Pole fell: True
# Episode: 333; Acc. Reward: 23.0; Pole fell: True
# Episode: 334; Acc. Reward: 22.0; Pole fell: True
# Episode: 335; Acc. Reward: 22.0; Pole fell: True
# Episode: 336; Acc. Reward: 22.0; Pole fell: True
# Episode: 337; Acc. Reward: 22.0; Pole fell: True
# Episode: 339; Acc. Reward: 21.0; Pole fell: True
# Episode: 340; Acc. Reward: 21.0; Pole fell: True
# Episode: 341; Acc. Reward: 21.0; Pole fell: True
# Episode: 342; Acc. Reward: 22.0; Pole fell: True
# Episode: 343; Acc. Reward: 22.0; Pole fell: True
# Episode: 344; Acc. Reward: 21.0; Pole fell: True
# Episode: 345; Acc. Reward: 21.0; Pole fell: True
# Episode: 346; Acc. Reward: 21.0; Pole fell: True
# Episode: 347; Acc. Reward: 20.0; Pole fell: True
# Episode: 348; Acc. Reward: 20.0; Pole fell: True
# Episode: 349; Acc. Reward: 20.0; Pole fell: True
# Episode: 350; Acc. Reward: 20.0; Pole fell: True
# Episode: 351; Acc. Reward: 21.0; Pole fell: True
# Episode: 352; Acc. Reward: 21.0; Pole fell: True
# Episode: 353; Acc. Reward: 20.0; Pole fell: True
# Episode: 354; Acc. Reward: 21.0; Pole fell: True
# Episode: 355; Acc. Reward: 21.0; Pole fell: True
# Episode: 356; Acc. Reward: 20.0; Pole fell: True
# Episode: 357; Acc. Reward: 21.0; Pole fell: True
# Episode: 358; Acc. Reward: 21.0; Pole fell: True
# Episode: 359; Acc. Reward: 21.0; Pole fell: True
# Episode: 360; Acc. Reward: 20.0; Pole fell: True
# Episode: 361; Acc. Reward: 20.0; Pole fell: True
# Episode: 362; Acc. Reward: 20.0; Pole fell: True
# Episode: 363; Acc. Reward: 20.0; Pole fell: True
# Episode: 365; Acc. Reward: 20.0; Pole fell: True
# Episode: 366; Acc. Reward: 21.0; Pole fell: True
# Episode: 367; Acc. Reward: 21.0; Pole fell: True
# Episode: 368; Acc. Reward: 21.0; Pole fell: True
# Episode: 369; Acc. Reward: 20.0; Pole fell: True
# Episode: 370; Acc. Reward: 20.0; Pole fell: True
# Episode: 371; Acc. Reward: 21.0; Pole fell: True
# Episode: 372; Acc. Reward: 20.0; Pole fell: True
# Episode: 373; Acc. Reward: 21.0; Pole fell: True
# Episode: 374; Acc. Reward: 21.0; Pole fell: True
# Episode: 375; Acc. Reward: 23.0; Pole fell: True
# Episode: 376; Acc. Reward: 23.0; Pole fell: True
# Episode: 377; Acc. Reward: 23.0; Pole fell: True
# Episode: 378; Acc. Reward: 24.0; Pole fell: True
# Episode: 379; Acc. Reward: 24.0; Pole fell: True
# Episode: 380; Acc. Reward: 24.0; Pole fell: True
# Episode: 381; Acc. Reward: 23.0; Pole fell: True
# Episode: 382; Acc. Reward: 23.0; Pole fell: False
# Epoch: 2
# Episode: 383; Acc. Reward: 23.0; Pole fell: True
# Episode: 384; Acc. Reward: 23.0; Pole fell: True
# Episode: 385; Acc. Reward: 22.0; Pole fell: True
# Episode: 386; Acc. Reward: 23.0; Pole fell: True
# Episode: 387; Acc. Reward: 23.0; Pole fell: True
# Episode: 388; Acc. Reward: 24.0; Pole fell: True
# Episode: 389; Acc. Reward: 24.0; Pole fell: True
# Episode: 390; Acc. Reward: 24.0; Pole fell: True
# Episode: 391; Acc. Reward: 24.0; Pole fell: True
# Episode: 392; Acc. Reward: 24.0; Pole fell: True
# Episode: 393; Acc. Reward: 26.0; Pole fell: True
# Episode: 394; Acc. Reward: 26.0; Pole fell: True
# Episode: 395; Acc. Reward: 26.0; Pole fell: True
# Episode: 396; Acc. Reward: 27.0; Pole fell: True
# Episode: 397; Acc. Reward: 27.0; Pole fell: True
# Episode: 399; Acc. Reward: 28.0; Pole fell: True
# Episode: 400; Acc. Reward: 29.0; Pole fell: True
# Episode: 401; Acc. Reward: 29.0; Pole fell: True
# Episode: 402; Acc. Reward: 29.0; Pole fell: True
# Episode: 403; Acc. Reward: 30.0; Pole fell: True
# Episode: 404; Acc. Reward: 30.0; Pole fell: True
# Episode: 405; Acc. Reward: 30.0; Pole fell: True
# Episode: 406; Acc. Reward: 29.0; Pole fell: True
# Episode: 407; Acc. Reward: 29.0; Pole fell: True
# Episode: 408; Acc. Reward: 29.0; Pole fell: True
# Episode: 409; Acc. Reward: 29.0; Pole fell: True
# Episode: 410; Acc. Reward: 29.0; Pole fell: True
# Episode: 411; Acc. Reward: 29.0; Pole fell: True
# Episode: 412; Acc. Reward: 29.0; Pole fell: True
# Episode: 413; Acc. Reward: 29.0; Pole fell: True
# Episode: 414; Acc. Reward: 29.0; Pole fell: True
# Episode: 415; Acc. Reward: 28.0; Pole fell: True
# Episode: 417; Acc. Reward: 27.0; Pole fell: True
# Episode: 418; Acc. Reward: 28.0; Pole fell: True
# Episode: 419; Acc. Reward: 29.0; Pole fell: True
# Episode: 420; Acc. Reward: 29.0; Pole fell: True
# Episode: 421; Acc. Reward: 29.0; Pole fell: True
# Episode: 422; Acc. Reward: 31.0; Pole fell: True
# Episode: 423; Acc. Reward: 31.0; Pole fell: True
# Episode: 424; Acc. Reward: 33.0; Pole fell: True
# Episode: 425; Acc. Reward: 33.0; Pole fell: True
# Episode: 426; Acc. Reward: 33.0; Pole fell: True
# Episode: 427; Acc. Reward: 32.0; Pole fell: True
# Episode: 428; Acc. Reward: 31.0; Pole fell: True
# Episode: 429; Acc. Reward: 32.0; Pole fell: True
# Episode: 430; Acc. Reward: 32.0; Pole fell: True
# Episode: 432; Acc. Reward: 32.0; Pole fell: True
# Episode: 433; Acc. Reward: 31.0; Pole fell: True
# Episode: 434; Acc. Reward: 32.0; Pole fell: True
# Episode: 435; Acc. Reward: 31.0; Pole fell: True
# Episode: 436; Acc. Reward: 32.0; Pole fell: True
# Episode: 437; Acc. Reward: 32.0; Pole fell: True
# Episode: 438; Acc. Reward: 31.0; Pole fell: True
# Episode: 439; Acc. Reward: 30.0; Pole fell: True
# Episode: 440; Acc. Reward: 30.0; Pole fell: True
# Episode: 441; Acc. Reward: 29.0; Pole fell: True
# Episode: 442; Acc. Reward: 30.0; Pole fell: True
# Episode: 443; Acc. Reward: 31.0; Pole fell: True
# Episode: 444; Acc. Reward: 31.0; Pole fell: True
# Episode: 445; Acc. Reward: 31.0; Pole fell: True
# Episode: 446; Acc. Reward: 31.0; Pole fell: True
# Episode: 447; Acc. Reward: 31.0; Pole fell: True
# Episode: 449; Acc. Reward: 30.0; Pole fell: True
# Episode: 450; Acc. Reward: 30.0; Pole fell: True
# Episode: 451; Acc. Reward: 30.0; Pole fell: True
# Episode: 452; Acc. Reward: 30.0; Pole fell: True
# Episode: 453; Acc. Reward: 30.0; Pole fell: True
# Episode: 454; Acc. Reward: 30.0; Pole fell: True
# Episode: 455; Acc. Reward: 30.0; Pole fell: True
# Episode: 456; Acc. Reward: 31.0; Pole fell: True
# Episode: 457; Acc. Reward: 32.0; Pole fell: True
# Episode: 458; Acc. Reward: 30.0; Pole fell: True
# Episode: 459; Acc. Reward: 31.0; Pole fell: True
# Episode: 460; Acc. Reward: 30.0; Pole fell: True
# Episode: 461; Acc. Reward: 30.0; Pole fell: True
# Episode: 462; Acc. Reward: 29.0; Pole fell: True
# Episode: 463; Acc. Reward: 30.0; Pole fell: True
# Episode: 464; Acc. Reward: 28.0; Pole fell: True
# Episode: 466; Acc. Reward: 28.0; Pole fell: True
# Episode: 467; Acc. Reward: 29.0; Pole fell: True
# Episode: 468; Acc. Reward: 30.0; Pole fell: True
# Episode: 469; Acc. Reward: 30.0; Pole fell: True
# Episode: 470; Acc. Reward: 29.0; Pole fell: True
# Episode: 471; Acc. Reward: 29.0; Pole fell: True
# Episode: 472; Acc. Reward: 28.0; Pole fell: True
# Episode: 473; Acc. Reward: 29.0; Pole fell: True
# Episode: 474; Acc. Reward: 28.0; Pole fell: True
# Episode: 475; Acc. Reward: 28.0; Pole fell: True
# Episode: 476; Acc. Reward: 27.0; Pole fell: True
# Episode: 477; Acc. Reward: 27.0; Pole fell: True
# Episode: 478; Acc. Reward: 27.0; Pole fell: True
# Episode: 479; Acc. Reward: 27.0; Pole fell: True
# Episode: 480; Acc. Reward: 27.0; Pole fell: True
# Episode: 481; Acc. Reward: 27.0; Pole fell: True
# Episode: 482; Acc. Reward: 27.0; Pole fell: True
# Episode: 483; Acc. Reward: 26.0; Pole fell: True
# Episode: 484; Acc. Reward: 26.0; Pole fell: True
# Episode: 486; Acc. Reward: 27.0; Pole fell: True
# Episode: 487; Acc. Reward: 27.0; Pole fell: True
# Episode: 488; Acc. Reward: 27.0; Pole fell: True
# Episode: 489; Acc. Reward: 27.0; Pole fell: True
# Episode: 490; Acc. Reward: 28.0; Pole fell: True
# Episode: 491; Acc. Reward: 28.0; Pole fell: True
# Episode: 492; Acc. Reward: 28.0; Pole fell: True
# Episode: 493; Acc. Reward: 28.0; Pole fell: True
# Episode: 494; Acc. Reward: 28.0; Pole fell: True
# Episode: 495; Acc. Reward: 30.0; Pole fell: True
# Episode: 496; Acc. Reward: 29.0; Pole fell: True
# Episode: 497; Acc. Reward: 29.0; Pole fell: True
# Episode: 498; Acc. Reward: 29.0; Pole fell: True
# Episode: 500; Acc. Reward: 30.0; Pole fell: True
# Episode: 501; Acc. Reward: 30.0; Pole fell: True
# Episode: 502; Acc. Reward: 30.0; Pole fell: True
# Episode: 503; Acc. Reward: 29.0; Pole fell: True
# Episode: 504; Acc. Reward: 30.0; Pole fell: True
# Episode: 505; Acc. Reward: 30.0; Pole fell: True
# Episode: 506; Acc. Reward: 30.0; Pole fell: True
# Episode: 507; Acc. Reward: 32.0; Pole fell: True
# Episode: 508; Acc. Reward: 33.0; Pole fell: True
# Episode: 509; Acc. Reward: 33.0; Pole fell: True
# Episode: 510; Acc. Reward: 33.0; Pole fell: True
# Episode: 511; Acc. Reward: 33.0; Pole fell: True
# Episode: 512; Acc. Reward: 33.0; Pole fell: False
# Epoch: 3
# Episode: 513; Acc. Reward: 34.0; Pole fell: True
# Episode: 514; Acc. Reward: 34.0; Pole fell: True
# Episode: 515; Acc. Reward: 35.0; Pole fell: True
# Episode: 516; Acc. Reward: 34.0; Pole fell: True
# Episode: 517; Acc. Reward: 34.0; Pole fell: True
# Episode: 518; Acc. Reward: 38.0; Pole fell: True
# Episode: 519; Acc. Reward: 38.0; Pole fell: True
# Episode: 520; Acc. Reward: 40.0; Pole fell: True
# Episode: 522; Acc. Reward: 41.0; Pole fell: True
# Episode: 523; Acc. Reward: 41.0; Pole fell: True
# Episode: 524; Acc. Reward: 41.0; Pole fell: True
# Episode: 525; Acc. Reward: 41.0; Pole fell: True
# Episode: 526; Acc. Reward: 41.0; Pole fell: True
# Episode: 527; Acc. Reward: 41.0; Pole fell: True
# Episode: 528; Acc. Reward: 41.0; Pole fell: True
# Episode: 529; Acc. Reward: 42.0; Pole fell: True
# Episode: 530; Acc. Reward: 41.0; Pole fell: True
# Episode: 531; Acc. Reward: 41.0; Pole fell: True
# Episode: 532; Acc. Reward: 41.0; Pole fell: True
# Episode: 533; Acc. Reward: 41.0; Pole fell: True
# Episode: 534; Acc. Reward: 41.0; Pole fell: True
# Episode: 535; Acc. Reward: 39.0; Pole fell: True
# Episode: 536; Acc. Reward: 39.0; Pole fell: True
# Episode: 538; Acc. Reward: 38.0; Pole fell: True
# Episode: 539; Acc. Reward: 39.0; Pole fell: True
# Episode: 540; Acc. Reward: 40.0; Pole fell: True
# Episode: 541; Acc. Reward: 40.0; Pole fell: True
# Episode: 542; Acc. Reward: 40.0; Pole fell: True
# Episode: 543; Acc. Reward: 40.0; Pole fell: True
# Episode: 544; Acc. Reward: 41.0; Pole fell: True
# Episode: 545; Acc. Reward: 40.0; Pole fell: True
# Episode: 546; Acc. Reward: 41.0; Pole fell: True
# Episode: 547; Acc. Reward: 37.0; Pole fell: True
# Episode: 548; Acc. Reward: 36.0; Pole fell: True
# Episode: 549; Acc. Reward: 38.0; Pole fell: True
# Episode: 550; Acc. Reward: 38.0; Pole fell: True
# Episode: 551; Acc. Reward: 38.0; Pole fell: True
# Episode: 553; Acc. Reward: 36.0; Pole fell: True
# Episode: 554; Acc. Reward: 37.0; Pole fell: True
# Episode: 555; Acc. Reward: 39.0; Pole fell: True
# Episode: 556; Acc. Reward: 39.0; Pole fell: True
# Episode: 557; Acc. Reward: 40.0; Pole fell: True
# Episode: 558; Acc. Reward: 37.0; Pole fell: True
# Episode: 559; Acc. Reward: 37.0; Pole fell: True
# Episode: 560; Acc. Reward: 36.0; Pole fell: True
# Episode: 561; Acc. Reward: 36.0; Pole fell: True
# Episode: 562; Acc. Reward: 35.0; Pole fell: True
# Episode: 563; Acc. Reward: 35.0; Pole fell: True
# Episode: 565; Acc. Reward: 34.0; Pole fell: True
# Episode: 566; Acc. Reward: 34.0; Pole fell: True
# Episode: 567; Acc. Reward: 34.0; Pole fell: True
# Episode: 568; Acc. Reward: 36.0; Pole fell: True
# Episode: 569; Acc. Reward: 36.0; Pole fell: True
# Episode: 570; Acc. Reward: 36.0; Pole fell: True
# Episode: 571; Acc. Reward: 35.0; Pole fell: True
# Episode: 572; Acc. Reward: 37.0; Pole fell: True
# Episode: 573; Acc. Reward: 38.0; Pole fell: True
# Episode: 574; Acc. Reward: 38.0; Pole fell: True
# Episode: 576; Acc. Reward: 40.0; Pole fell: True
# Episode: 577; Acc. Reward: 40.0; Pole fell: True
# Episode: 578; Acc. Reward: 40.0; Pole fell: True
# Episode: 579; Acc. Reward: 40.0; Pole fell: True
# Episode: 580; Acc. Reward: 38.0; Pole fell: True
# Episode: 581; Acc. Reward: 39.0; Pole fell: True
# Episode: 582; Acc. Reward: 40.0; Pole fell: True
# Episode: 583; Acc. Reward: 42.0; Pole fell: True
# Episode: 584; Acc. Reward: 41.0; Pole fell: True
# Episode: 585; Acc. Reward: 42.0; Pole fell: True
# Episode: 587; Acc. Reward: 41.0; Pole fell: True
# Episode: 588; Acc. Reward: 42.0; Pole fell: True
# Episode: 589; Acc. Reward: 41.0; Pole fell: True
# Episode: 590; Acc. Reward: 41.0; Pole fell: True
# Episode: 591; Acc. Reward: 42.0; Pole fell: True
# Episode: 592; Acc. Reward: 42.0; Pole fell: True
# Episode: 593; Acc. Reward: 42.0; Pole fell: True
# Episode: 594; Acc. Reward: 41.0; Pole fell: True
# Episode: 595; Acc. Reward: 39.0; Pole fell: True
# Episode: 596; Acc. Reward: 39.0; Pole fell: True
# Episode: 597; Acc. Reward: 39.0; Pole fell: True
# Episode: 598; Acc. Reward: 39.0; Pole fell: True
# Episode: 599; Acc. Reward: 39.0; Pole fell: True
# Episode: 600; Acc. Reward: 39.0; Pole fell: True
# Episode: 601; Acc. Reward: 38.0; Pole fell: True
# Episode: 602; Acc. Reward: 38.0; Pole fell: True
# Episode: 604; Acc. Reward: 38.0; Pole fell: True
# Episode: 605; Acc. Reward: 38.0; Pole fell: True
# Episode: 606; Acc. Reward: 37.0; Pole fell: True
# Episode: 607; Acc. Reward: 37.0; Pole fell: True
# Episode: 608; Acc. Reward: 37.0; Pole fell: True
# Episode: 609; Acc. Reward: 36.0; Pole fell: True
# Episode: 610; Acc. Reward: 37.0; Pole fell: True
# Episode: 611; Acc. Reward: 37.0; Pole fell: True
# Episode: 612; Acc. Reward: 37.0; Pole fell: True
# Episode: 613; Acc. Reward: 35.0; Pole fell: True
# Episode: 614; Acc. Reward: 37.0; Pole fell: True
# Episode: 615; Acc. Reward: 36.0; Pole fell: True
# Episode: 616; Acc. Reward: 35.0; Pole fell: True
# Episode: 617; Acc. Reward: 36.0; Pole fell: False
# Epoch: 4
# Episode: 618; Acc. Reward: 36.0; Pole fell: True
# Episode: 619; Acc. Reward: 37.0; Pole fell: True
# Episode: 620; Acc. Reward: 38.0; Pole fell: True
# Episode: 621; Acc. Reward: 38.0; Pole fell: True
# Episode: 622; Acc. Reward: 37.0; Pole fell: True
# Episode: 623; Acc. Reward: 36.0; Pole fell: True
# Episode: 624; Acc. Reward: 36.0; Pole fell: True
# Episode: 625; Acc. Reward: 36.0; Pole fell: True
# Episode: 626; Acc. Reward: 36.0; Pole fell: True
# Episode: 628; Acc. Reward: 36.0; Pole fell: True
# Episode: 629; Acc. Reward: 36.0; Pole fell: True
# Episode: 630; Acc. Reward: 36.0; Pole fell: True
# Episode: 631; Acc. Reward: 36.0; Pole fell: True
# Episode: 632; Acc. Reward: 39.0; Pole fell: True
# Episode: 633; Acc. Reward: 39.0; Pole fell: True
# Episode: 634; Acc. Reward: 40.0; Pole fell: True
# Episode: 636; Acc. Reward: 43.0; Pole fell: True
# Episode: 637; Acc. Reward: 43.0; Pole fell: True
# Episode: 638; Acc. Reward: 43.0; Pole fell: True
# Episode: 639; Acc. Reward: 44.0; Pole fell: True
# Episode: 640; Acc. Reward: 44.0; Pole fell: True
# Episode: 641; Acc. Reward: 44.0; Pole fell: True
# Episode: 642; Acc. Reward: 45.0; Pole fell: True
# Episode: 643; Acc. Reward: 45.0; Pole fell: True
# Episode: 644; Acc. Reward: 45.0; Pole fell: True
# Episode: 645; Acc. Reward: 45.0; Pole fell: True
# Episode: 646; Acc. Reward: 45.0; Pole fell: True
# Episode: 647; Acc. Reward: 46.0; Pole fell: True
# Episode: 649; Acc. Reward: 46.0; Pole fell: True
# Episode: 650; Acc. Reward: 46.0; Pole fell: True
# Episode: 651; Acc. Reward: 46.0; Pole fell: True
# Episode: 652; Acc. Reward: 49.0; Pole fell: True
# Episode: 653; Acc. Reward: 49.0; Pole fell: True
# Episode: 654; Acc. Reward: 48.0; Pole fell: True
# Episode: 655; Acc. Reward: 49.0; Pole fell: True
# Episode: 656; Acc. Reward: 50.0; Pole fell: True
# Episode: 657; Acc. Reward: 49.0; Pole fell: True
# Episode: 659; Acc. Reward: 48.0; Pole fell: True
# Episode: 660; Acc. Reward: 48.0; Pole fell: True
# Episode: 661; Acc. Reward: 50.0; Pole fell: True
# Episode: 662; Acc. Reward: 50.0; Pole fell: True
# Episode: 663; Acc. Reward: 50.0; Pole fell: True
# Episode: 664; Acc. Reward: 52.0; Pole fell: True
# Episode: 665; Acc. Reward: 51.0; Pole fell: True
# Episode: 666; Acc. Reward: 51.0; Pole fell: True
# Episode: 668; Acc. Reward: 54.0; Pole fell: True
# Episode: 669; Acc. Reward: 54.0; Pole fell: True
# Episode: 670; Acc. Reward: 56.0; Pole fell: True
# Episode: 671; Acc. Reward: 55.0; Pole fell: True
# Episode: 672; Acc. Reward: 54.0; Pole fell: True
# Episode: 673; Acc. Reward: 54.0; Pole fell: True
# Episode: 675; Acc. Reward: 51.0; Pole fell: True
# Episode: 676; Acc. Reward: 51.0; Pole fell: True
# Episode: 677; Acc. Reward: 52.0; Pole fell: True
# Episode: 678; Acc. Reward: 54.0; Pole fell: True
# Episode: 679; Acc. Reward: 54.0; Pole fell: True
# Episode: 680; Acc. Reward: 54.0; Pole fell: True
# Episode: 681; Acc. Reward: 55.0; Pole fell: True
# Episode: 683; Acc. Reward: 56.0; Pole fell: True
# Episode: 684; Acc. Reward: 57.0; Pole fell: True
# Episode: 685; Acc. Reward: 58.0; Pole fell: True
# Episode: 686; Acc. Reward: 58.0; Pole fell: True
# Episode: 687; Acc. Reward: 58.0; Pole fell: True
# Episode: 688; Acc. Reward: 58.0; Pole fell: True
# Episode: 689; Acc. Reward: 59.0; Pole fell: True
# Episode: 690; Acc. Reward: 60.0; Pole fell: True
# Episode: 691; Acc. Reward: 60.0; Pole fell: False
# Epoch: 5
# Episode: 692; Acc. Reward: 58.0; Pole fell: True
# Episode: 693; Acc. Reward: 58.0; Pole fell: True
# Episode: 694; Acc. Reward: 59.0; Pole fell: True
# Episode: 695; Acc. Reward: 59.0; Pole fell: True
# Episode: 696; Acc. Reward: 60.0; Pole fell: True
# Episode: 697; Acc. Reward: 61.0; Pole fell: True
# Episode: 698; Acc. Reward: 61.0; Pole fell: True
# Episode: 700; Acc. Reward: 62.0; Pole fell: True
# Episode: 701; Acc. Reward: 62.0; Pole fell: True
# Episode: 702; Acc. Reward: 61.0; Pole fell: True
# Episode: 703; Acc. Reward: 61.0; Pole fell: True
# Episode: 704; Acc. Reward: 60.0; Pole fell: True
# Episode: 705; Acc. Reward: 60.0; Pole fell: True
# Episode: 706; Acc. Reward: 60.0; Pole fell: True
# Episode: 707; Acc. Reward: 62.0; Pole fell: True
# Episode: 709; Acc. Reward: 58.0; Pole fell: True
# Episode: 710; Acc. Reward: 57.0; Pole fell: True
# Episode: 711; Acc. Reward: 58.0; Pole fell: True
# Episode: 712; Acc. Reward: 57.0; Pole fell: True
# Episode: 713; Acc. Reward: 57.0; Pole fell: True
# Episode: 714; Acc. Reward: 56.0; Pole fell: True
# Episode: 715; Acc. Reward: 58.0; Pole fell: True
# Episode: 716; Acc. Reward: 58.0; Pole fell: True
# Episode: 717; Acc. Reward: 59.0; Pole fell: True
# Episode: 719; Acc. Reward: 55.0; Pole fell: True
# Episode: 720; Acc. Reward: 57.0; Pole fell: True
# Episode: 721; Acc. Reward: 55.0; Pole fell: True
# Episode: 722; Acc. Reward: 55.0; Pole fell: True
# Episode: 723; Acc. Reward: 55.0; Pole fell: True
# Episode: 724; Acc. Reward: 56.0; Pole fell: True
# Episode: 725; Acc. Reward: 56.0; Pole fell: True
# Episode: 726; Acc. Reward: 57.0; Pole fell: True
# Episode: 727; Acc. Reward: 55.0; Pole fell: True
# Episode: 729; Acc. Reward: 54.0; Pole fell: True
# Episode: 730; Acc. Reward: 54.0; Pole fell: True
# Episode: 731; Acc. Reward: 54.0; Pole fell: True
# Episode: 732; Acc. Reward: 54.0; Pole fell: True
# Episode: 733; Acc. Reward: 55.0; Pole fell: True
# Episode: 734; Acc. Reward: 56.0; Pole fell: True
# Episode: 735; Acc. Reward: 55.0; Pole fell: True
# Episode: 736; Acc. Reward: 54.0; Pole fell: True
# Episode: 737; Acc. Reward: 52.0; Pole fell: True
# Episode: 739; Acc. Reward: 52.0; Pole fell: True
# Episode: 740; Acc. Reward: 51.0; Pole fell: True
# Episode: 741; Acc. Reward: 50.0; Pole fell: True
# Episode: 742; Acc. Reward: 50.0; Pole fell: True
# Episode: 743; Acc. Reward: 50.0; Pole fell: True
# Episode: 744; Acc. Reward: 52.0; Pole fell: True
# Episode: 745; Acc. Reward: 52.0; Pole fell: True
# Episode: 746; Acc. Reward: 52.0; Pole fell: True
# Episode: 748; Acc. Reward: 50.0; Pole fell: True
# Episode: 749; Acc. Reward: 52.0; Pole fell: True
# Episode: 750; Acc. Reward: 52.0; Pole fell: True
# Episode: 751; Acc. Reward: 53.0; Pole fell: True
# Episode: 752; Acc. Reward: 54.0; Pole fell: True
# Episode: 753; Acc. Reward: 55.0; Pole fell: True
# Episode: 755; Acc. Reward: 54.0; Pole fell: True
# Episode: 756; Acc. Reward: 55.0; Pole fell: True
# Episode: 757; Acc. Reward: 56.0; Pole fell: True
# Episode: 758; Acc. Reward: 57.0; Pole fell: True
# Episode: 759; Acc. Reward: 58.0; Pole fell: True
# Episode: 760; Acc. Reward: 58.0; Pole fell: True
# Episode: 761; Acc. Reward: 58.0; Pole fell: True
# Episode: 762; Acc. Reward: 58.0; Pole fell: True
# Epoch: 6
# Episode: 763; Acc. Reward: 57.0; Pole fell: True
# Episode: 764; Acc. Reward: 56.0; Pole fell: True
# Episode: 765; Acc. Reward: 57.0; Pole fell: True
# Episode: 766; Acc. Reward: 56.0; Pole fell: True
# Episode: 767; Acc. Reward: 58.0; Pole fell: True
# Episode: 768; Acc. Reward: 59.0; Pole fell: True
# Episode: 769; Acc. Reward: 60.0; Pole fell: True
# Episode: 770; Acc. Reward: 59.0; Pole fell: True
# Episode: 772; Acc. Reward: 59.0; Pole fell: True
# Episode: 773; Acc. Reward: 58.0; Pole fell: True
# Episode: 774; Acc. Reward: 57.0; Pole fell: True
# Episode: 775; Acc. Reward: 57.0; Pole fell: True
# Episode: 776; Acc. Reward: 57.0; Pole fell: True
# Episode: 777; Acc. Reward: 59.0; Pole fell: True
# Episode: 778; Acc. Reward: 60.0; Pole fell: True
# Episode: 779; Acc. Reward: 60.0; Pole fell: True
# Episode: 781; Acc. Reward: 59.0; Pole fell: True
# Episode: 782; Acc. Reward: 59.0; Pole fell: True
# Episode: 783; Acc. Reward: 60.0; Pole fell: True
# Episode: 784; Acc. Reward: 59.0; Pole fell: True
# Episode: 785; Acc. Reward: 60.0; Pole fell: True
# Episode: 786; Acc. Reward: 62.0; Pole fell: True
# Episode: 788; Acc. Reward: 66.0; Pole fell: True
# Episode: 789; Acc. Reward: 64.0; Pole fell: True
# Episode: 790; Acc. Reward: 65.0; Pole fell: True
# Episode: 791; Acc. Reward: 63.0; Pole fell: True
# Episode: 792; Acc. Reward: 63.0; Pole fell: True
# Episode: 793; Acc. Reward: 63.0; Pole fell: True
# Episode: 794; Acc. Reward: 62.0; Pole fell: True
# Episode: 796; Acc. Reward: 61.0; Pole fell: True
# Episode: 797; Acc. Reward: 60.0; Pole fell: True
# Episode: 798; Acc. Reward: 61.0; Pole fell: True
# Episode: 799; Acc. Reward: 61.0; Pole fell: True
# Episode: 800; Acc. Reward: 61.0; Pole fell: True
# Episode: 801; Acc. Reward: 62.0; Pole fell: True
# Episode: 802; Acc. Reward: 61.0; Pole fell: True
# Episode: 804; Acc. Reward: 61.0; Pole fell: True
# Episode: 805; Acc. Reward: 60.0; Pole fell: True
# Episode: 806; Acc. Reward: 60.0; Pole fell: True
# Episode: 807; Acc. Reward: 60.0; Pole fell: True
# Episode: 808; Acc. Reward: 60.0; Pole fell: True
# Episode: 809; Acc. Reward: 60.0; Pole fell: True
# Episode: 810; Acc. Reward: 62.0; Pole fell: True
# Episode: 812; Acc. Reward: 62.0; Pole fell: True
# Episode: 813; Acc. Reward: 63.0; Pole fell: True
# Episode: 814; Acc. Reward: 62.0; Pole fell: True
# Episode: 815; Acc. Reward: 62.0; Pole fell: True
# Episode: 816; Acc. Reward: 62.0; Pole fell: True
# Episode: 817; Acc. Reward: 61.0; Pole fell: True
# Episode: 818; Acc. Reward: 62.0; Pole fell: True
# Episode: 819; Acc. Reward: 61.0; Pole fell: True
# Episode: 820; Acc. Reward: 62.0; Pole fell: True
# Episode: 822; Acc. Reward: 60.0; Pole fell: True
# Episode: 823; Acc. Reward: 60.0; Pole fell: True
# Episode: 824; Acc. Reward: 60.0; Pole fell: True
# Episode: 825; Acc. Reward: 60.0; Pole fell: True
# Episode: 826; Acc. Reward: 60.0; Pole fell: True
# Episode: 827; Acc. Reward: 59.0; Pole fell: True
# Episode: 828; Acc. Reward: 58.0; Pole fell: True
# Episode: 829; Acc. Reward: 57.0; Pole fell: False
# Epoch: 7
# Episode: 830; Acc. Reward: 58.0; Pole fell: True
# Episode: 831; Acc. Reward: 60.0; Pole fell: True
# Episode: 832; Acc. Reward: 59.0; Pole fell: True
# Episode: 833; Acc. Reward: 60.0; Pole fell: True
# Episode: 834; Acc. Reward: 61.0; Pole fell: True
# Episode: 836; Acc. Reward: 62.0; Pole fell: True
# Episode: 837; Acc. Reward: 61.0; Pole fell: True
# Episode: 838; Acc. Reward: 61.0; Pole fell: True
# Episode: 839; Acc. Reward: 61.0; Pole fell: True
# Episode: 840; Acc. Reward: 61.0; Pole fell: True
# Episode: 841; Acc. Reward: 62.0; Pole fell: True
# Episode: 842; Acc. Reward: 63.0; Pole fell: True
# Episode: 844; Acc. Reward: 66.0; Pole fell: True
# Episode: 845; Acc. Reward: 66.0; Pole fell: True
# Episode: 846; Acc. Reward: 67.0; Pole fell: True
# Episode: 847; Acc. Reward: 67.0; Pole fell: True
# Episode: 848; Acc. Reward: 68.0; Pole fell: True
# Episode: 850; Acc. Reward: 64.0; Pole fell: True
# Episode: 851; Acc. Reward: 65.0; Pole fell: True
# Episode: 852; Acc. Reward: 66.0; Pole fell: True
# Episode: 853; Acc. Reward: 67.0; Pole fell: True
# Episode: 854; Acc. Reward: 67.0; Pole fell: True
# Episode: 855; Acc. Reward: 68.0; Pole fell: True
# Episode: 857; Acc. Reward: 68.0; Pole fell: True
# Episode: 858; Acc. Reward: 68.0; Pole fell: True
# Episode: 859; Acc. Reward: 68.0; Pole fell: True
# Episode: 860; Acc. Reward: 68.0; Pole fell: True
# Episode: 861; Acc. Reward: 70.0; Pole fell: True
# Episode: 862; Acc. Reward: 72.0; Pole fell: True
# Episode: 863; Acc. Reward: 72.0; Pole fell: True
# Episode: 865; Acc. Reward: 70.0; Pole fell: True
# Episode: 866; Acc. Reward: 71.0; Pole fell: True
# Episode: 867; Acc. Reward: 72.0; Pole fell: True
# Episode: 868; Acc. Reward: 71.0; Pole fell: True
# Episode: 869; Acc. Reward: 71.0; Pole fell: True
# Episode: 871; Acc. Reward: 71.0; Pole fell: True
# Episode: 872; Acc. Reward: 73.0; Pole fell: True
# Episode: 873; Acc. Reward: 72.0; Pole fell: True
# Episode: 874; Acc. Reward: 72.0; Pole fell: True
# Episode: 875; Acc. Reward: 73.0; Pole fell: True
# Episode: 876; Acc. Reward: 73.0; Pole fell: True
# Episode: 878; Acc. Reward: 71.0; Pole fell: True
# Episode: 879; Acc. Reward: 72.0; Pole fell: True
# Episode: 880; Acc. Reward: 72.0; Pole fell: True
# Episode: 881; Acc. Reward: 71.0; Pole fell: True
# Episode: 882; Acc. Reward: 69.0; Pole fell: True
# Episode: 883; Acc. Reward: 70.0; Pole fell: True
# Episode: 884; Acc. Reward: 69.0; Pole fell: True
# Episode: 885; Acc. Reward: 69.0; Pole fell: True
# Episode: 886; Acc. Reward: 68.0; Pole fell: False
# Epoch: 8
# Episode: 887; Acc. Reward: 67.0; Pole fell: True
# Episode: 888; Acc. Reward: 68.0; Pole fell: True
# Episode: 889; Acc. Reward: 69.0; Pole fell: True
# Episode: 890; Acc. Reward: 69.0; Pole fell: True
# Episode: 891; Acc. Reward: 68.0; Pole fell: True
# Episode: 892; Acc. Reward: 68.0; Pole fell: True
# Episode: 893; Acc. Reward: 68.0; Pole fell: True
# Episode: 895; Acc. Reward: 66.0; Pole fell: True
# Episode: 896; Acc. Reward: 65.0; Pole fell: True
# Episode: 897; Acc. Reward: 67.0; Pole fell: True
# Episode: 898; Acc. Reward: 68.0; Pole fell: True
# Episode: 899; Acc. Reward: 67.0; Pole fell: True
# Episode: 900; Acc. Reward: 68.0; Pole fell: True
# Episode: 901; Acc. Reward: 67.0; Pole fell: True
# Episode: 903; Acc. Reward: 66.0; Pole fell: True
# Episode: 904; Acc. Reward: 66.0; Pole fell: True
# Episode: 905; Acc. Reward: 67.0; Pole fell: True
# Episode: 906; Acc. Reward: 66.0; Pole fell: True
# Episode: 907; Acc. Reward: 66.0; Pole fell: True
# Episode: 908; Acc. Reward: 66.0; Pole fell: True
# Episode: 910; Acc. Reward: 63.0; Pole fell: True
# Episode: 911; Acc. Reward: 63.0; Pole fell: True
# Episode: 912; Acc. Reward: 63.0; Pole fell: True
# Episode: 913; Acc. Reward: 63.0; Pole fell: True
# Episode: 914; Acc. Reward: 63.0; Pole fell: True
# Episode: 915; Acc. Reward: 64.0; Pole fell: True
# Episode: 917; Acc. Reward: 64.0; Pole fell: True
# Episode: 918; Acc. Reward: 65.0; Pole fell: True
# Episode: 919; Acc. Reward: 67.0; Pole fell: True
# Episode: 920; Acc. Reward: 69.0; Pole fell: True
# Episode: 921; Acc. Reward: 69.0; Pole fell: True
# Episode: 923; Acc. Reward: 69.0; Pole fell: True
# Episode: 924; Acc. Reward: 69.0; Pole fell: True
# Episode: 925; Acc. Reward: 68.0; Pole fell: True
# Episode: 926; Acc. Reward: 68.0; Pole fell: True
# Episode: 927; Acc. Reward: 69.0; Pole fell: True
# Episode: 928; Acc. Reward: 68.0; Pole fell: True
# Episode: 929; Acc. Reward: 68.0; Pole fell: True
# Episode: 931; Acc. Reward: 66.0; Pole fell: True
# Episode: 932; Acc. Reward: 67.0; Pole fell: True
# Episode: 933; Acc. Reward: 69.0; Pole fell: True
# Episode: 934; Acc. Reward: 70.0; Pole fell: True
# Episode: 935; Acc. Reward: 70.0; Pole fell: True
# Episode: 936; Acc. Reward: 70.0; Pole fell: True
# Episode: 937; Acc. Reward: 69.0; Pole fell: True
# Episode: 939; Acc. Reward: 68.0; Pole fell: True
# Episode: 940; Acc. Reward: 67.0; Pole fell: True
# Episode: 941; Acc. Reward: 67.0; Pole fell: True
# Episode: 942; Acc. Reward: 68.0; Pole fell: True
# Episode: 943; Acc. Reward: 67.0; Pole fell: True
# Episode: 944; Acc. Reward: 67.0; Pole fell: True
# Episode: 945; Acc. Reward: 66.0; Pole fell: True
# Episode: 946; Acc. Reward: 67.0; Pole fell: True
# Episode: 947; Acc. Reward: 66.0; Pole fell: False
# Epoch: 9
# Episode: 948; Acc. Reward: 66.0; Pole fell: True
# Episode: 949; Acc. Reward: 66.0; Pole fell: True
# Episode: 950; Acc. Reward: 68.0; Pole fell: True
# Episode: 951; Acc. Reward: 69.0; Pole fell: True
# Episode: 952; Acc. Reward: 67.0; Pole fell: True
# Episode: 953; Acc. Reward: 67.0; Pole fell: True
# Episode: 955; Acc. Reward: 63.0; Pole fell: True
# Episode: 956; Acc. Reward: 65.0; Pole fell: True
# Episode: 957; Acc. Reward: 66.0; Pole fell: True
# Episode: 958; Acc. Reward: 67.0; Pole fell: True
# Episode: 959; Acc. Reward: 64.0; Pole fell: True
# Episode: 960; Acc. Reward: 63.0; Pole fell: True
# Episode: 961; Acc. Reward: 63.0; Pole fell: True
# Episode: 963; Acc. Reward: 64.0; Pole fell: True
# Episode: 964; Acc. Reward: 65.0; Pole fell: True
# Episode: 965; Acc. Reward: 65.0; Pole fell: True
# Episode: 966; Acc. Reward: 66.0; Pole fell: True
# Episode: 967; Acc. Reward: 67.0; Pole fell: True
# Episode: 969; Acc. Reward: 66.0; Pole fell: True
# Episode: 970; Acc. Reward: 67.0; Pole fell: True
# Episode: 971; Acc. Reward: 69.0; Pole fell: True
# Episode: 972; Acc. Reward: 69.0; Pole fell: True
# Episode: 974; Acc. Reward: 67.0; Pole fell: True
# Episode: 975; Acc. Reward: 69.0; Pole fell: True
# Episode: 976; Acc. Reward: 70.0; Pole fell: True
# Episode: 977; Acc. Reward: 71.0; Pole fell: True
# Episode: 978; Acc. Reward: 71.0; Pole fell: True
# Episode: 979; Acc. Reward: 73.0; Pole fell: True
# Episode: 981; Acc. Reward: 72.0; Pole fell: True
# Episode: 982; Acc. Reward: 72.0; Pole fell: True
# Episode: 983; Acc. Reward: 73.0; Pole fell: True
# Episode: 984; Acc. Reward: 75.0; Pole fell: True
# Episode: 985; Acc. Reward: 76.0; Pole fell: True
# Episode: 986; Acc. Reward: 75.0; Pole fell: True
# Episode: 988; Acc. Reward: 74.0; Pole fell: True
# Episode: 989; Acc. Reward: 75.0; Pole fell: True
# Episode: 990; Acc. Reward: 74.0; Pole fell: True
# Episode: 991; Acc. Reward: 74.0; Pole fell: True
# Episode: 992; Acc. Reward: 75.0; Pole fell: True
# Episode: 993; Acc. Reward: 74.0; Pole fell: True
# Episode: 994; Acc. Reward: 74.0; Pole fell: True
# Episode: 996; Acc. Reward: 74.0; Pole fell: True
# Episode: 997; Acc. Reward: 74.0; Pole fell: True
# Episode: 998; Acc. Reward: 76.0; Pole fell: True
# Episode: 999; Acc. Reward: 76.0; Pole fell: True
# Episode: 1000; Acc. Reward: 76.0; Pole fell: True
# Episode: 1001; Acc. Reward: 75.0; Pole fell: False
# Epoch: 10
# Episode: 1002; Acc. Reward: 77.0; Pole fell: True
# Episode: 1003; Acc. Reward: 75.0; Pole fell: True
# Episode: 1004; Acc. Reward: 75.0; Pole fell: True
# Episode: 1005; Acc. Reward: 76.0; Pole fell: True
# Episode: 1006; Acc. Reward: 75.0; Pole fell: True
# Episode: 1007; Acc. Reward: 74.0; Pole fell: True
# Episode: 1009; Acc. Reward: 73.0; Pole fell: True
# Episode: 1010; Acc. Reward: 72.0; Pole fell: True
# Episode: 1011; Acc. Reward: 74.0; Pole fell: True
# Episode: 1012; Acc. Reward: 74.0; Pole fell: True
# Episode: 1013; Acc. Reward: 71.0; Pole fell: True
# Episode: 1014; Acc. Reward: 72.0; Pole fell: True
# Episode: 1015; Acc. Reward: 71.0; Pole fell: True
# Episode: 1017; Acc. Reward: 70.0; Pole fell: True
# Episode: 1018; Acc. Reward: 70.0; Pole fell: True
# Episode: 1019; Acc. Reward: 68.0; Pole fell: True
# Episode: 1020; Acc. Reward: 69.0; Pole fell: True
# Episode: 1021; Acc. Reward: 71.0; Pole fell: True
# Episode: 1022; Acc. Reward: 71.0; Pole fell: True
# Episode: 1024; Acc. Reward: 69.0; Pole fell: True
# Episode: 1025; Acc. Reward: 69.0; Pole fell: True
# Episode: 1026; Acc. Reward: 70.0; Pole fell: True
# Episode: 1027; Acc. Reward: 73.0; Pole fell: True
# Episode: 1029; Acc. Reward: 72.0; Pole fell: True
# Episode: 1030; Acc. Reward: 73.0; Pole fell: True
# Episode: 1031; Acc. Reward: 73.0; Pole fell: True
# Episode: 1032; Acc. Reward: 75.0; Pole fell: True
# Episode: 1033; Acc. Reward: 77.0; Pole fell: True
# Episode: 1035; Acc. Reward: 76.0; Pole fell: True
# Episode: 1036; Acc. Reward: 76.0; Pole fell: True
# Episode: 1037; Acc. Reward: 74.0; Pole fell: True
# Episode: 1038; Acc. Reward: 72.0; Pole fell: True
# Episode: 1039; Acc. Reward: 72.0; Pole fell: True
# Episode: 1040; Acc. Reward: 72.0; Pole fell: True
# Episode: 1041; Acc. Reward: 73.0; Pole fell: True
# Episode: 1042; Acc. Reward: 73.0; Pole fell: True
# Episode: 1044; Acc. Reward: 70.0; Pole fell: True
# Episode: 1045; Acc. Reward: 70.0; Pole fell: True
# Episode: 1046; Acc. Reward: 70.0; Pole fell: True
# Episode: 1047; Acc. Reward: 70.0; Pole fell: True
# Episode: 1048; Acc. Reward: 71.0; Pole fell: True
# Episode: 1049; Acc. Reward: 73.0; Pole fell: True
# Episode: 1051; Acc. Reward: 70.0; Pole fell: True
# Episode: 1052; Acc. Reward: 70.0; Pole fell: True
# Episode: 1053; Acc. Reward: 70.0; Pole fell: True
# Episode: 1054; Acc. Reward: 73.0; Pole fell: True
# ...
# Episode: 1396; Acc. Reward: 137.0; Pole fell: True
# Episode: 1398; Acc. Reward: 131.0; Pole fell: True
# Episode: 1399; Acc. Reward: 133.0; Pole fell: True
# Episode: 1400; Acc. Reward: 133.0; Pole fell: True
# Episode: 1401; Acc. Reward: 130.0; Pole fell: False
# Epoch: 20
# Episode: 1402; Acc. Reward: 130.0; Pole fell: True
# Episode: 1403; Acc. Reward: 133.0; Pole fell: True
# Episode: 1405; Acc. Reward: 131.0; Pole fell: True
# Episode: 1406; Acc. Reward: 130.0; Pole fell: True
# Episode: 1407; Acc. Reward: 134.0; Pole fell: True
# Episode: 1409; Acc. Reward: 131.0; Pole fell: True
# Episode: 1410; Acc. Reward: 132.0; Pole fell: True
# Episode: 1411; Acc. Reward: 134.0; Pole fell: True
# Episode: 1412; Acc. Reward: 132.0; Pole fell: True
# Episode: 1414; Acc. Reward: 128.0; Pole fell: True
# Episode: 1415; Acc. Reward: 131.0; Pole fell: True
# Episode: 1416; Acc. Reward: 130.0; Pole fell: True
# Episode: 1418; Acc. Reward: 127.0; Pole fell: True
# Episode: 1419; Acc. Reward: 128.0; Pole fell: True
# Episode: 1420; Acc. Reward: 128.0; Pole fell: True
# Episode: 1422; Acc. Reward: 125.0; Pole fell: True
# Episode: 1423; Acc. Reward: 124.0; Pole fell: True
# Episode: 1424; Acc. Reward: 125.0; Pole fell: True
# Episode: 1426; Acc. Reward: 123.0; Pole fell: True
# Episode: 1427; Acc. Reward: 123.0; Pole fell: True
# Episode: 1428; Acc. Reward: 124.0; Pole fell: True
# Episode: 1430; Acc. Reward: 122.0; Pole fell: True
# Episode: 1431; Acc. Reward: 122.0; Pole fell: True
# Episode: 1432; Acc. Reward: 122.0; Pole fell: True
# Episode: 1433; Acc. Reward: 125.0; Pole fell: False
# Epoch: 21
# Episode: 1434; Acc. Reward: 124.0; Pole fell: True
# Episode: 1435; Acc. Reward: 125.0; Pole fell: True
# Episode: 1437; Acc. Reward: 129.0; Pole fell: True
# Episode: 1438; Acc. Reward: 130.0; Pole fell: True
# Episode: 1440; Acc. Reward: 129.0; Pole fell: True
# Episode: 1441; Acc. Reward: 132.0; Pole fell: True
# Episode: 1442; Acc. Reward: 134.0; Pole fell: True
# Episode: 1444; Acc. Reward: 129.0; Pole fell: True
# Episode: 1445; Acc. Reward: 132.0; Pole fell: True
# Episode: 1447; Acc. Reward: 129.0; Pole fell: True
# Episode: 1448; Acc. Reward: 130.0; Pole fell: True
# Episode: 1449; Acc. Reward: 134.0; Pole fell: True
# Episode: 1451; Acc. Reward: 132.0; Pole fell: True
# Episode: 1452; Acc. Reward: 132.0; Pole fell: True
# Episode: 1454; Acc. Reward: 136.0; Pole fell: True
# Episode: 1455; Acc. Reward: 141.0; Pole fell: True
# Episode: 1457; Acc. Reward: 141.0; Pole fell: True
# Episode: 1458; Acc. Reward: 143.0; Pole fell: True
# Episode: 1459; Acc. Reward: 144.0; Pole fell: False
# Epoch: 22
# Episode: 1460; Acc. Reward: 145.0; Pole fell: True
# Episode: 1461; Acc. Reward: 148.0; Pole fell: True
# Episode: 1463; Acc. Reward: 149.0; Pole fell: True
# Episode: 1464; Acc. Reward: 150.0; Pole fell: True
# Episode: 1466; Acc. Reward: 151.0; Pole fell: True
# Episode: 1467; Acc. Reward: 152.0; Pole fell: True
# Episode: 1468; Acc. Reward: 153.0; Pole fell: True
# Episode: 1470; Acc. Reward: 153.0; Pole fell: True
# Episode: 1471; Acc. Reward: 155.0; Pole fell: True
# Episode: 1473; Acc. Reward: 154.0; Pole fell: True
# Episode: 1474; Acc. Reward: 156.0; Pole fell: True
# Episode: 1476; Acc. Reward: 152.0; Pole fell: True
# Episode: 1477; Acc. Reward: 156.0; Pole fell: True
# Episode: 1479; Acc. Reward: 153.0; Pole fell: True
# Episode: 1480; Acc. Reward: 155.0; Pole fell: True
# Episode: 1482; Acc. Reward: 157.0; Pole fell: True
# Episode: 1483; Acc. Reward: 162.0; Pole fell: False
# Epoch: 23
# Episode: 1484; Acc. Reward: 164.0; Pole fell: True
# Episode: 1485; Acc. Reward: 165.0; Pole fell: True
# Episode: 1487; Acc. Reward: 166.0; Pole fell: True
# Episode: 1488; Acc. Reward: 167.0; Pole fell: True
# Episode: 1490; Acc. Reward: 165.0; Pole fell: True
# Episode: 1491; Acc. Reward: 167.0; Pole fell: True
# Episode: 1493; Acc. Reward: 163.0; Pole fell: True
# Episode: 1494; Acc. Reward: 169.0; Pole fell: True
# Episode: 1496; Acc. Reward: 167.0; Pole fell: True
# Episode: 1497; Acc. Reward: 168.0; Pole fell: True
# Episode: 1499; Acc. Reward: 165.0; Pole fell: True
# Episode: 1500; Acc. Reward: 168.0; Pole fell: True
# Episode: 1502; Acc. Reward: 166.0; Pole fell: True
# Episode: 1503; Acc. Reward: 171.0; Pole fell: True
# Episode: 1504; Acc. Reward: 172.0; Pole fell: True
# Episode: 1505; Acc. Reward: 173.0; Pole fell: True
# Episode: 1506; Acc. Reward: 173.0; Pole fell: False
# Epoch: 24
# Episode: 1507; Acc. Reward: 178.0; Pole fell: True
# Episode: 1509; Acc. Reward: 177.0; Pole fell: True
# Episode: 1510; Acc. Reward: 179.0; Pole fell: True
# Episode: 1511; Acc. Reward: 177.0; Pole fell: True
# Episode: 1513; Acc. Reward: 176.0; Pole fell: True
# Episode: 1515; Acc. Reward: 177.0; Pole fell: True
# Episode: 1516; Acc. Reward: 181.0; Pole fell: True
# Episode: 1518; Acc. Reward: 175.0; Pole fell: True
# Episode: 1519; Acc. Reward: 180.0; Pole fell: True
# Episode: 1521; Acc. Reward: 178.0; Pole fell: True
# Episode: 1522; Acc. Reward: 179.0; Pole fell: True
# Episode: 1524; Acc. Reward: 179.0; Pole fell: True
# Episode: 1526; Acc. Reward: 180.0; Pole fell: True
# Episode: 1527; Acc. Reward: 181.0; Pole fell: True
# Episode: 1528; Acc. Reward: 178.0; Pole fell: False
# Epoch: 25
# Episode: 1529; Acc. Reward: 185.0; Pole fell: True
# Episode: 1531; Acc. Reward: 186.0; Pole fell: True
# Episode: 1533; Acc. Reward: 188.0; Pole fell: True
# Episode: 1534; Acc. Reward: 188.0; Pole fell: True
# Episode: 1536; Acc. Reward: 186.0; Pole fell: True
# Episode: 1537; Acc. Reward: 188.0; Pole fell: True
# Episode: 1539; Acc. Reward: 189.0; Pole fell: True
# Episode: 1541; Acc. Reward: 190.0; Pole fell: True
# Episode: 1543; Acc. Reward: 188.0; Pole fell: True
# Episode: 1544; Acc. Reward: 188.0; Pole fell: True
# Episode: 1546; Acc. Reward: 192.0; Pole fell: True
# Episode: 1547; Acc. Reward: 190.0; Pole fell: True
# Episode: 1548; Acc. Reward: 188.0; Pole fell: False
# Epoch: 26
# Episode: 1549; Acc. Reward: 193.0; Pole fell: True
# Episode: 1551; Acc. Reward: 192.0; Pole fell: True
# Episode: 1552; Acc. Reward: 198.0; Pole fell: True
# Episode: 1554; Acc. Reward: 196.0; Pole fell: True
# Episode: 1556; Acc. Reward: 197.0; Pole fell: True
# Episode: 1557; Acc. Reward: 198.0; Pole fell: True
# Episode: 1559; Acc. Reward: 195.0; Pole fell: True
# Episode: 1560; Acc. Reward: 198.0; Pole fell: True
# Episode: 1562; Acc. Reward: 194.0; Pole fell: True
# Episode: 1564; Acc. Reward: 193.0; Pole fell: True
# Episode: 1565; Acc. Reward: 197.0; Pole fell: True
# Episode: 1567; Acc. Reward: 193.0; Pole fell: True
# Episode: 1568; Acc. Reward: 198.0; Pole fell: True
# Episode: 1569; Acc. Reward: 190.0; Pole fell: False
# Epoch: 27
# Episode: 1570; Acc. Reward: 197.0; Pole fell: True
# Episode: 1572; Acc. Reward: 193.0; Pole fell: True
# Episode: 1574; Acc. Reward: 192.0; Pole fell: True
# Episode: 1575; Acc. Reward: 200.0; Pole fell: True
# Episode: 1577; Acc. Reward: 198.0; Pole fell: True
# Episode: 1579; Acc. Reward: 201.0; Pole fell: True
# Episode: 1581; Acc. Reward: 199.0; Pole fell: True
# Episode: 1583; Acc. Reward: 200.0; Pole fell: True
# Episode: 1584; Acc. Reward: 203.0; Pole fell: True
# Episode: 1586; Acc. Reward: 199.0; Pole fell: True
# Episode: 1587; Acc. Reward: 201.0; Pole fell: False
# Epoch: 28
# Episode: 1588; Acc. Reward: 207.0; Pole fell: True
# Episode: 1590; Acc. Reward: 204.0; Pole fell: True
# Episode: 1592; Acc. Reward: 204.0; Pole fell: True
# Episode: 1593; Acc. Reward: 212.0; Pole fell: True
# Episode: 1595; Acc. Reward: 208.0; Pole fell: True
# Episode: 1597; Acc. Reward: 208.0; Pole fell: True
# Episode: 1599; Acc. Reward: 214.0; Pole fell: True
# Episode: 1600; Acc. Reward: 214.0; Pole fell: True
# Episode: 1602; Acc. Reward: 218.0; Pole fell: True
# Episode: 1604; Acc. Reward: 217.0; Pole fell: True
# Episode: 1605; Acc. Reward: 216.0; Pole fell: False
# Epoch: 29
# Episode: 1606; Acc. Reward: 222.0; Pole fell: True
# Episode: 1608; Acc. Reward: 220.0; Pole fell: True
# Episode: 1610; Acc. Reward: 217.0; Pole fell: True
# Episode: 1612; Acc. Reward: 220.0; Pole fell: True
# Episode: 1613; Acc. Reward: 222.0; Pole fell: True
# Episode: 1615; Acc. Reward: 219.0; Pole fell: True
# Episode: 1617; Acc. Reward: 221.0; Pole fell: True
# Episode: 1619; Acc. Reward: 222.0; Pole fell: True
# Episode: 1621; Acc. Reward: 224.0; Pole fell: True
# Episode: 1622; Acc. Reward: 220.0; Pole fell: True
# Episode: 1623; Acc. Reward: 225.0; Pole fell: False
# Epoch: 30
# Episode: 1625; Acc. Reward: 229.0; Pole fell: True
# Episode: 1627; Acc. Reward: 228.0; Pole fell: True
# Episode: 1628; Acc. Reward: 229.0; Pole fell: True
# Episode: 1631; Acc. Reward: 230.0; Pole fell: True
# Episode: 1633; Acc. Reward: 229.0; Pole fell: True
# Episode: 1634; Acc. Reward: 236.0; Pole fell: True
# Episode: 1636; Acc. Reward: 236.0; Pole fell: True
# Episode: 1638; Acc. Reward: 238.0; Pole fell: False
# Epoch: 31
# Episode: 1640; Acc. Reward: 243.0; Pole fell: True
# Episode: 1642; Acc. Reward: 248.0; Pole fell: True
# Episode: 1645; Acc. Reward: 256.0; Pole fell: True
# Episode: 1647; Acc. Reward: 258.0; Pole fell: True
# Episode: 1649; Acc. Reward: 259.0; Pole fell: True
# Episode: 1651; Acc. Reward: 262.0; Pole fell: False
# Epoch: 32
# Episode: 1653; Acc. Reward: 271.0; Pole fell: True
# Episode: 1656; Acc. Reward: 279.0; Pole fell: True
# Episode: 1658; Acc. Reward: 282.0; Pole fell: True
# Episode: 1660; Acc. Reward: 285.0; Pole fell: True
# Episode: 1663; Acc. Reward: 298.0; Pole fell: True
# Episode: 1664; Acc. Reward: 288.0; Pole fell: False
# Epoch: 33
# Episode: 1666; Acc. Reward: 300.0; Pole fell: True
# Episode: 1669; Acc. Reward: 310.0; Pole fell: True
# Episode: 1672; Acc. Reward: 303.0; Pole fell: True
# Episode: 1675; Acc. Reward: 315.0; Pole fell: True
# Episode: 1676; Acc. Reward: 314.0; Pole fell: False
# Epoch: 34
# Episode: 1684; Acc. Reward: 340.0; Pole fell: True
# Episode: 1685; Acc. Reward: 344.0; Pole fell: False
# Epoch: 35
# Episode: 1693; Acc. Reward: 382.0; Pole fell: False
# Epoch: 36
# Episode: 1701; Acc. Reward: 425.0; Pole fell: False
# Epoch: 37
# Episode: 1709; Acc. Reward: 452.0; Pole fell: False
# Epoch: 38
# Episode: 1710; Acc. Reward: 459.0; Pole fell: True
# Episode: 1718; Acc. Reward: 475.0; Pole fell: False
# Epoch: 39
# Episode: 1726; Acc. Reward: 488.0; Pole fell: False
# Epoch: 40
# Episode: 1734; Acc. Reward: 488.0; Pole fell: False
# Epoch: 41
# Episode: 1742; Acc. Reward: 488.0; Pole fell: False
# Epoch: 42
# Episode: 1750; Acc. Reward: 491.0; Pole fell: False
# Epoch: 43
# Episode: 1758; Acc. Reward: 500.0; Pole fell: False
# Epoch: 44
# Episode: 1766; Acc. Reward: 500.0; Pole fell: False
# Epoch: 45
# Episode: 1774; Acc. Reward: 500.0; Pole fell: False
# Epoch: 46
# Episode: 1782; Acc. Reward: 500.0; Pole fell: False
# Epoch: 47
# Episode: 1790; Acc. Reward: 500.0; Pole fell: False
# Epoch: 48
# Episode: 1798; Acc. Reward: 500.0; Pole fell: False
# Epoch: 49
# Episode: 1806; Acc. Reward: 500.0; Pole fell: False
# Epoch: 50
# Episode: 1814; Acc. Reward: 500.0; Pole fell: False
# Epoch: 51
# Episode: 1822; Acc. Reward: 500.0; Pole fell: False
# Epoch: 52
# Episode: 1830; Acc. Reward: 500.0; Pole fell: False
# Epoch: 53
# Episode: 1838; Acc. Reward: 500.0; Pole fell: False
# Epoch: 54
# Episode: 1846; Acc. Reward: 500.0; Pole fell: False
# Epoch: 55
# Episode: 1854; Acc. Reward: 500.0; Pole fell: False
# Epoch: 56
# Episode: 1862; Acc. Reward: 500.0; Pole fell: False
# Epoch: 57
# Episode: 1870; Acc. Reward: 500.0; Pole fell: False
# Epoch: 58
# Episode: 1878; Acc. Reward: 500.0; Pole fell: False
# Epoch: 59
# Episode: 1886; Acc. Reward: 500.0; Pole fell: False
# Epoch: 60
# Episode: 1894; Acc. Reward: 500.0; Pole fell: False
# Epoch: 61
# Episode: 1902; Acc. Reward: 500.0; Pole fell: False
# Epoch: 62
# Episode: 1910; Acc. Reward: 500.0; Pole fell: False
# Epoch: 63
# Episode: 1918; Acc. Reward: 500.0; Pole fell: False
# Epoch: 64
# Episode: 1926; Acc. Reward: 500.0; Pole fell: False
# Epoch: 65
# Episode: 1934; Acc. Reward: 500.0; Pole fell: False
# Epoch: 66
# Episode: 1942; Acc. Reward: 500.0; Pole fell: False
# Epoch: 67
# Episode: 1950; Acc. Reward: 500.0; Pole fell: False
# Epoch: 68
# Episode: 1958; Acc. Reward: 500.0; Pole fell: False
# Epoch: 69
# Episode: 1966; Acc. Reward: 500.0; Pole fell: False
# Epoch: 70
# Episode: 1974; Acc. Reward: 500.0; Pole fell: False
# Epoch: 71
# Episode: 1982; Acc. Reward: 500.0; Pole fell: False
# Epoch: 72
# Episode: 1990; Acc. Reward: 500.0; Pole fell: False
# Epoch: 73
# Episode: 1998; Acc. Reward: 500.0; Pole fell: False
# Epoch: 74
# Episode: 2006; Acc. Reward: 500.0; Pole fell: False
# Epoch: 75
# Episode: 2014; Acc. Reward: 500.0; Pole fell: False
# Epoch: 76
# Episode: 2022; Acc. Reward: 500.0; Pole fell: False
# Epoch: 77
# Episode: 2030; Acc. Reward: 500.0; Pole fell: False
# Epoch: 78
# Episode: 2038; Acc. Reward: 500.0; Pole fell: False
# Epoch: 79
# Episode: 2046; Acc. Reward: 500.0; Pole fell: False
# Epoch: 80
# Episode: 2054; Acc. Reward: 500.0; Pole fell: False
# Epoch: 81
# Episode: 2062; Acc. Reward: 500.0; Pole fell: False
# Epoch: 82
# Episode: 2070; Acc. Reward: 500.0; Pole fell: False
# Epoch: 83
# Episode: 2078; Acc. Reward: 500.0; Pole fell: False
# Epoch: 84
# Episode: 2086; Acc. Reward: 500.0; Pole fell: False
# Epoch: 85
# Episode: 2094; Acc. Reward: 500.0; Pole fell: False
# Epoch: 86
# Episode: 2102; Acc. Reward: 500.0; Pole fell: False
# Epoch: 87
# Episode: 2110; Acc. Reward: 500.0; Pole fell: False
# Epoch: 88
# Episode: 2118; Acc. Reward: 500.0; Pole fell: False
# Epoch: 89
# Episode: 2126; Acc. Reward: 500.0; Pole fell: False
# Epoch: 90
# Episode: 2134; Acc. Reward: 500.0; Pole fell: False
# Epoch: 91
# Episode: 2142; Acc. Reward: 500.0; Pole fell: False
# Epoch: 92
# Episode: 2150; Acc. Reward: 500.0; Pole fell: False
# Epoch: 93
# Episode: 2158; Acc. Reward: 500.0; Pole fell: False
# Epoch: 94
# Episode: 2166; Acc. Reward: 500.0; Pole fell: False
# Epoch: 95
# Episode: 2174; Acc. Reward: 500.0; Pole fell: False
# Epoch: 96
# Episode: 2182; Acc. Reward: 500.0; Pole fell: False
# Epoch: 97
# Episode: 2190; Acc. Reward: 500.0; Pole fell: False
# Epoch: 98
# Episode: 2198; Acc. Reward: 500.0; Pole fell: False
# Epoch: 99
# Episode: 2206; Acc. Reward: 500.0; Pole fell: False
# Epoch: 100
# Episode: 2214; Acc. Reward: 500.0; Pole fell: False
# Epoch: 101
# Episode: 2222; Acc. Reward: 500.0; Pole fell: False
# Epoch: 102
# Episode: 2230; Acc. Reward: 500.0; Pole fell: False
# Epoch: 103
# Episode: 2238; Acc. Reward: 500.0; Pole fell: False
# Epoch: 104
# Episode: 2246; Acc. Reward: 500.0; Pole fell: False
# Epoch: 105
# Episode: 2254; Acc. Reward: 500.0; Pole fell: False
# Epoch: 106
# Episode: 2262; Acc. Reward: 500.0; Pole fell: False
# Epoch: 107
# Episode: 2270; Acc. Reward: 500.0; Pole fell: False
# Epoch: 108
# Episode: 2278; Acc. Reward: 500.0; Pole fell: False
# Epoch: 109
# Episode: 2286; Acc. Reward: 500.0; Pole fell: False
# Epoch: 110
# Episode: 2294; Acc. Reward: 500.0; Pole fell: False
# Epoch: 111
# Episode: 2302; Acc. Reward: 500.0; Pole fell: False
# Epoch: 112
# Episode: 2310; Acc. Reward: 500.0; Pole fell: False
# Epoch: 113
# Episode: 2318; Acc. Reward: 500.0; Pole fell: False
# Epoch: 114
# Episode: 2326; Acc. Reward: 500.0; Pole fell: False
# Epoch: 115
# Episode: 2334; Acc. Reward: 500.0; Pole fell: False
# Epoch: 116
# Episode: 2342; Acc. Reward: 500.0; Pole fell: False
# Epoch: 117
# Episode: 2350; Acc. Reward: 500.0; Pole fell: False
# Epoch: 118
# Episode: 2358; Acc. Reward: 500.0; Pole fell: False
# Epoch: 119
# Episode: 2366; Acc. Reward: 500.0; Pole fell: False
# Epoch: 120
# Episode: 2374; Acc. Reward: 500.0; Pole fell: False
# Epoch: 121
# Episode: 2382; Acc. Reward: 500.0; Pole fell: False
# Epoch: 122
# Episode: 2390; Acc. Reward: 500.0; Pole fell: False
# Epoch: 123
# Episode: 2398; Acc. Reward: 500.0; Pole fell: False
# Epoch: 124
# Episode: 2406; Acc. Reward: 500.0; Pole fell: False
# Epoch: 125
# Episode: 2414; Acc. Reward: 500.0; Pole fell: False
# Epoch: 126
# Episode: 2422; Acc. Reward: 500.0; Pole fell: False
# Epoch: 127
# Episode: 2430; Acc. Reward: 500.0; Pole fell: False
# Epoch: 128
# Episode: 2438; Acc. Reward: 500.0; Pole fell: False
# Epoch: 129
# Episode: 2446; Acc. Reward: 500.0; Pole fell: False
# Epoch: 130
# Episode: 2454; Acc. Reward: 500.0; Pole fell: False
# Epoch: 131
# Episode: 2462; Acc. Reward: 500.0; Pole fell: False
# Epoch: 132
# Episode: 2470; Acc. Reward: 500.0; Pole fell: False
# Epoch: 133
# Episode: 2478; Acc. Reward: 500.0; Pole fell: False
# Epoch: 134
# Episode: 2486; Acc. Reward: 500.0; Pole fell: False
# Epoch: 135
# Episode: 2494; Acc. Reward: 500.0; Pole fell: False
# Epoch: 136

# %%
total_episodes_test = 100
best_score = -1000
ep_reward_list_test = []

# %%
print('Test')
for ep in range(total_episodes_test):
    observation = env.reset()
    save_observation_temp = [observation]
    save_wanted_torque_temp = [0.0]
    save_actual_torque_temp = [0.0]
    save_sp_torque_temp = [0.0]
    save_ctrl_voltage_temp = [0.0]
    done=False
    t=0
    episodic_reward = 0
    while not done and t<steps_per_episode_goal:
        # using our observation, choose an action and take it in the environment
        # Get the logits, action, and take one step in the environment
        observation = observation.reshape(1, -1)
        logits, action = sample_action(observation)
        #observation_new, reward, done, _, _ = env.step(action[0].numpy())
        observation_new, reward, done, _ ,torque_wanted, torque_actual= env.step(action[0].numpy().item())
        episodic_reward += reward
        observation = observation_new
        save_observation_temp.append(observation)
        save_wanted_torque_temp.append(torque_wanted)
        save_actual_torque_temp.append(torque_actual)
        save_sp_torque_temp.append(env.MPC.y_spf)
        save_ctrl_voltage_temp[-1]=env.MPC.plant.voltage_input
        save_ctrl_voltage_temp.append(0.0)
        t+=1

    # get best score and update save data
    #save_ctrl_voltage_temp.append(env.DCMotorModel.voltage_input)
    print(f"Episode: {ep}; Acc. Reward: {episodic_reward:.1f}; Pole fell: {done}")
    if best_score<episodic_reward:
        save_observation = list(save_observation_temp)
        save_wanted_torque = list(save_wanted_torque_temp)
        save_actual_torque = list(save_actual_torque_temp)
        save_ctrl_voltage = list(save_ctrl_voltage_temp)
        save_sp_torque = list(save_sp_torque_temp)
        best_score = episodic_reward
    ep_reward_list_test.append(episodic_reward)
# Out:
# Test
# Episode: 0; Acc. Reward: 500.0; Pole fell: False
# Episode: 1; Acc. Reward: 500.0; Pole fell: False
# Episode: 2; Acc. Reward: 500.0; Pole fell: False
# Episode: 3; Acc. Reward: 500.0; Pole fell: False
# Episode: 4; Acc. Reward: 500.0; Pole fell: False
# Episode: 5; Acc. Reward: 500.0; Pole fell: False
# Episode: 6; Acc. Reward: 500.0; Pole fell: False
# Episode: 7; Acc. Reward: 500.0; Pole fell: False
# Episode: 8; Acc. Reward: 500.0; Pole fell: False
# Episode: 9; Acc. Reward: 500.0; Pole fell: False
# Episode: 10; Acc. Reward: 500.0; Pole fell: False
# Episode: 11; Acc. Reward: 500.0; Pole fell: False
# Episode: 12; Acc. Reward: 500.0; Pole fell: False
# Episode: 13; Acc. Reward: 500.0; Pole fell: False
# Episode: 14; Acc. Reward: 500.0; Pole fell: False
# Episode: 15; Acc. Reward: 500.0; Pole fell: False
# Episode: 16; Acc. Reward: 500.0; Pole fell: False
# Episode: 17; Acc. Reward: 500.0; Pole fell: False
# Episode: 18; Acc. Reward: 500.0; Pole fell: False
# Episode: 19; Acc. Reward: 500.0; Pole fell: False
# Episode: 20; Acc. Reward: 500.0; Pole fell: False
# Episode: 21; Acc. Reward: 500.0; Pole fell: False
# Episode: 22; Acc. Reward: 500.0; Pole fell: False
# Episode: 23; Acc. Reward: 500.0; Pole fell: False
# Episode: 24; Acc. Reward: 500.0; Pole fell: False
# Episode: 25; Acc. Reward: 500.0; Pole fell: False
# Episode: 26; Acc. Reward: 500.0; Pole fell: False
# Episode: 27; Acc. Reward: 500.0; Pole fell: False
# Episode: 28; Acc. Reward: 500.0; Pole fell: False
# Episode: 29; Acc. Reward: 500.0; Pole fell: False
# Episode: 30; Acc. Reward: 500.0; Pole fell: False
# Episode: 31; Acc. Reward: 500.0; Pole fell: False
# Episode: 32; Acc. Reward: 500.0; Pole fell: False
# Episode: 33; Acc. Reward: 500.0; Pole fell: False
# Episode: 34; Acc. Reward: 500.0; Pole fell: False
# Episode: 35; Acc. Reward: 500.0; Pole fell: False
# Episode: 36; Acc. Reward: 500.0; Pole fell: False
# Episode: 37; Acc. Reward: 500.0; Pole fell: False
# Episode: 38; Acc. Reward: 500.0; Pole fell: False
# Episode: 39; Acc. Reward: 500.0; Pole fell: False
# Episode: 40; Acc. Reward: 500.0; Pole fell: False
# Episode: 41; Acc. Reward: 500.0; Pole fell: False
# Episode: 42; Acc. Reward: 500.0; Pole fell: False
# Episode: 43; Acc. Reward: 500.0; Pole fell: False
# Episode: 44; Acc. Reward: 500.0; Pole fell: False
# Episode: 45; Acc. Reward: 500.0; Pole fell: False
# Episode: 46; Acc. Reward: 500.0; Pole fell: False
# Episode: 47; Acc. Reward: 500.0; Pole fell: False
# Episode: 48; Acc. Reward: 500.0; Pole fell: False
# Episode: 49; Acc. Reward: 500.0; Pole fell: False
# Episode: 50; Acc. Reward: 500.0; Pole fell: False
# Episode: 51; Acc. Reward: 500.0; Pole fell: False
# Episode: 52; Acc. Reward: 500.0; Pole fell: False
# Episode: 53; Acc. Reward: 500.0; Pole fell: False
# Episode: 54; Acc. Reward: 500.0; Pole fell: False
# Episode: 55; Acc. Reward: 500.0; Pole fell: False
# Episode: 56; Acc. Reward: 500.0; Pole fell: False
# Episode: 57; Acc. Reward: 500.0; Pole fell: False
# Episode: 58; Acc. Reward: 500.0; Pole fell: False
# Episode: 59; Acc. Reward: 500.0; Pole fell: False
# Episode: 60; Acc. Reward: 500.0; Pole fell: False
# Episode: 61; Acc. Reward: 500.0; Pole fell: False
# Episode: 62; Acc. Reward: 31.0; Pole fell: True
# Episode: 63; Acc. Reward: 500.0; Pole fell: False
# Episode: 64; Acc. Reward: 500.0; Pole fell: False
# Episode: 65; Acc. Reward: 500.0; Pole fell: False
# Episode: 66; Acc. Reward: 500.0; Pole fell: False
# Episode: 67; Acc. Reward: 500.0; Pole fell: False
# Episode: 68; Acc. Reward: 500.0; Pole fell: False
# Episode: 69; Acc. Reward: 500.0; Pole fell: False
# Episode: 70; Acc. Reward: 500.0; Pole fell: False
# Episode: 71; Acc. Reward: 500.0; Pole fell: False
# Episode: 72; Acc. Reward: 500.0; Pole fell: False
# Episode: 73; Acc. Reward: 500.0; Pole fell: False
# Episode: 74; Acc. Reward: 500.0; Pole fell: False
# Episode: 75; Acc. Reward: 500.0; Pole fell: False
# Episode: 76; Acc. Reward: 500.0; Pole fell: False
# Episode: 77; Acc. Reward: 500.0; Pole fell: False
# Episode: 78; Acc. Reward: 500.0; Pole fell: False
# Episode: 79; Acc. Reward: 500.0; Pole fell: False
# Episode: 80; Acc. Reward: 500.0; Pole fell: False
# Episode: 81; Acc. Reward: 500.0; Pole fell: False
# Episode: 82; Acc. Reward: 500.0; Pole fell: False
# Episode: 83; Acc. Reward: 500.0; Pole fell: False
# Episode: 84; Acc. Reward: 500.0; Pole fell: False
# Episode: 85; Acc. Reward: 500.0; Pole fell: False
# Episode: 86; Acc. Reward: 500.0; Pole fell: False
# Episode: 87; Acc. Reward: 500.0; Pole fell: False
# Episode: 88; Acc. Reward: 500.0; Pole fell: False
# Episode: 89; Acc. Reward: 500.0; Pole fell: False
# Episode: 90; Acc. Reward: 500.0; Pole fell: False
# Episode: 91; Acc. Reward: 500.0; Pole fell: False
# Episode: 92; Acc. Reward: 500.0; Pole fell: False
# Episode: 93; Acc. Reward: 500.0; Pole fell: False
# Episode: 94; Acc. Reward: 500.0; Pole fell: False
# Episode: 95; Acc. Reward: 500.0; Pole fell: False
# Episode: 96; Acc. Reward: 500.0; Pole fell: False
# Episode: 97; Acc. Reward: 500.0; Pole fell: False
# Episode: 98; Acc. Reward: 500.0; Pole fell: False
# Episode: 99; Acc. Reward: 500.0; Pole fell: False

# %%
save_observation_temp = None
save_observation_temp = None
save_wanted_torque_temp = None
save_actual_torque_temp = None
save_sp_torque_temp = None
save_ctrl_voltage_temp = None

# %%
path = '/content/drive/MyDrive/Colab Notebooks/codes/MPC/save_data/Cartpole/'

# %%
# Create a dictionary of variables you want to save
variables_to_save = {
    'avg_reward_list': avg_reward_list,
    'acc_ep_reward_list': acc_ep_reward_list,
    'save_observation': save_observation,
    'save_wanted_torque': save_wanted_torque,
    'save_actual_torque': save_actual_torque,
    'save_ctrl_voltage': save_ctrl_voltage,
    'ep_reward_list_test': ep_reward_list_test,
    'save_sp_torque': save_sp_torque
}

# %%
actor.save(path+"cartple_actor.keras")
critic.save(path+"cartple_critic.keras")

# %%
with open(path+'Cartpole.pkl', 'wb') as f:
    pickle.dump(variables_to_save, f)
print(f"All variables saved to {path+'Cartpole.pkl'}")
# Out:
# All variables saved to /content/drive/MyDrive/Colab Notebooks/codes/MPC/save_data/Cartpole/Cartpole.pkl

# %%
path = '/content/drive/MyDrive/Colab Notebooks/codes/MPC/save_data/Cartpole/'

# %%
# Open the file in read-binary mode and load the dictionary
with open(path+'Cartpole.pkl', 'rb') as f:
    loaded_variables = pickle.load(f)

# Access the loaded variables
avg_reward_list = loaded_variables['avg_reward_list']
acc_ep_reward_list = loaded_variables['acc_ep_reward_list']
save_observation = loaded_variables['save_observation']
save_wanted_torque = loaded_variables['save_wanted_torque']
save_actual_torque = loaded_variables['save_actual_torque']
save_ctrl_voltage = loaded_variables['save_ctrl_voltage']
ep_reward_list_test = loaded_variables['ep_reward_list_test']
save_sp_torque = loaded_variables['save_sp_torque']

# %%
actor = keras.models.load_model(path+"cartple_actor.keras")
critic = keras.models.load_model(path+"cartple_critic.keras")

# %%
plt.rc('text.latex', preamble=r'\usepackage{amsmath,amssymb,amsfonts}')
#plt.rcParams["text.usetex"]=False
#plt.rcParams["font.family"] = "sans-serif"
#plt.rcParams["font.family"] = "serif"
#plt.rcParams['mathtext.fontset'] = 'cm'
#plt.rcParams['mathtext.fontset'] = 'dejavusans'
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'

# %%
low_bound_reward_list = 0
up_bound_reward_list= 500
print("low_bound_reward_list=",low_bound_reward_list)
print("up_bound_reward_list=",up_bound_reward_list)
# Out:
# low_bound_reward_list= 0
# up_bound_reward_list= 500

# %%
def unnorm_to_norm(x):
  y = (x-low_bound_reward_list)/(up_bound_reward_list-low_bound_reward_list)
  return y

# %%
def norm_to_unnorm(y):
  x=y*(up_bound_reward_list-low_bound_reward_list)+low_bound_reward_list
  return x

# %%
norm_reward_list = np.array(avg_reward_list)
#norm_reward_list = (norm_reward_list/abs(norm_reward_list.min())+1)*100
min_norm_reward_list = 0
max_norm_reward_list=500
norm_reward_list = (norm_reward_list-min_norm_reward_list)/(max_norm_reward_list-min_norm_reward_list)

# %%
norm_reward_list = np.array(avg_reward_list)
#norm_reward_list = (norm_reward_list-min_norm_reward_list)/(max_norm_reward_list-min_norm_reward_list)
norm_reward_list = unnorm_to_norm(norm_reward_list)

# %%
# Plotting graph
# Episodes versus Acc. Rewards
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(avg_reward_list, label = "Acc. Episodic Reward",color="C0",linewidth = 1.5)
plt.axhline(y=np.array(avg_reward_list)[-20:-1].mean(), linestyle='--',
            label = "Acc. Episodic Reward's\nlast 20 mean= "+f"{np.array(avg_reward_list)[-20:-1].mean():.1f}",color="C1",linewidth = 2.5)
plt.minorticks_on()
plt.xlabel("Training episodes")
plt.ylabel("Acc. Episodic Reward")
#plt.grid()
plt.legend(fontsize=14)
plt.show()

# %%
print("Acc. Episodic Reward's last 20 mean=")
print(np.array(avg_reward_list)[-20:-1].mean())
# Out:
# Acc. Episodic Reward's last 20 mean=
# 500.0

# %%
# Episodes versus Avg. Rewards

font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.5)
f.set_figheight(2.2)
plt.plot(norm_reward_list, label = "Normalized Acc. Epi. Reward",color="C0",linewidth = 1.5)
#plt.axhline(y=norm_reward_list[-20:-1].mean(), linestyle='--',
#            label = "Normalized Acc. Episodic Reward's last 20 mean= "+f"{norm_reward_list[-20:-1].mean():.1f}",color="C1",linewidth = 2.5)
plt.xlabel("Training Episode")
plt.ylabel("Normalized Acc. Epi. Reward")
#plt.grid()
#plt.legend()
plt.xticks(np.arange(0, 2501, 500))
#plt.yticks(np.arange(0.0, 1.1, 0.1))
plt.minorticks_on()
plt.savefig(path+"Cartpole_Acc_Reward_vs_Episode.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print("Normalized Acc. Episodic Reward's last 20 mean=")
print(norm_reward_list[-20:-1].mean())
# Out:
# Normalized Acc. Episodic Reward's last 20 mean=
# 1.0

# %%
# Test Histogram
norm_ep_reward_list_test = np.array(ep_reward_list_test)
norm_ep_reward_list_test = unnorm_to_norm(norm_ep_reward_list_test)
print(norm_ep_reward_list_test.max())
print(norm_ep_reward_list_test.min())
min_bin = np.floor(norm_ep_reward_list_test.min()*100)/100
print(min_bin)
# Out:
# 1.0
# 0.062
# 0.06

# %%
font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(1.1)
f.set_figheight(2.2)
data_rewards = np.array(norm_ep_reward_list_test)
density_True = True
plt.hist(data_rewards, bins=np.arange(0,1.1,0.05), density=density_True ,color='skyblue', edgecolor='black')
plt.xlabel('Normalized Acc. \nEpi. Reward')
ylabel='Density'if density_True else 'Frequency'
plt.ylabel(ylabel)
#plt.xticks(np.arange(0.5,1.001,0.01))
plt.minorticks_on()
plt.xlim((0.8,1.1))
plt.savefig(path+"Cartpole_Acc_Reward_vs_Episode_Test_Hist.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print("Test Normalized Acc Episodic Reward's Results:")
print(f"Unnormalized: max={norm_to_unnorm(data_rewards).max():.3f} ,mean={norm_to_unnorm(data_rewards).mean():.3f}, std={norm_to_unnorm(data_rewards).std():.3f}")
print(f"Normalized:   max={data_rewards.max():.3e} ,mean={data_rewards.mean():.3e}, std={data_rewards.std():.3e}")
# Out:
# Test Normalized Acc Episodic Reward's Results:
# Unnormalized: max=500.000 ,mean=495.310, std=46.665
# Normalized:   max=1.000e+00 ,mean=9.906e-01, std=9.333e-02

# %%
dt=env.dt

# %%
dt
# Out:
# 0.02

# %%
time_= np.linspace(start = 0, stop = len(save_wanted_torque)* dt,
                   num=len(save_wanted_torque) )

# %%
sign_error = np.sign(np.array(save_wanted_torque)) - np.sign(np.array(save_actual_torque))
e_ry = np.array(save_wanted_torque) - np.array(save_actual_torque) ### add
force_error_max = np.max(np.abs(e_ry))
mean_std=f'(mean,std)=({e_ry.mean():.2e}, {e_ry.std():.2e})'

# %%
font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(4.5)
f.set_figheight(2.2)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

e_ry=np.array(save_wanted_torque)-np.array(save_actual_torque)
poly_fit = np.polynomial.polynomial.Polynomial.fit(x=time_[2:],y=e_ry[2:],deg=1,symbol='t')

plt.step(time_, save_sp_torque ,label = r"$y^{\mathrm{sp}}=a^{RL}$"+"\nfrom RL alg. pre-filter",color="cyan",linestyle='-.',linewidth = 1.8)
plt.step(time_, save_wanted_torque ,label = r"$y^{\mathrm{rm}}=a^{desired}$"+"\nfrom AF-filter",color="blue",linewidth = 1.5)
plt.step(time_, save_actual_torque , ':',label = "$y^{\mathrm{pm}}=a^{actual}$"+"\nfrom DC motor plant",color="red",linewidth = 4)
#plt.step(time_, e_ry,"--" ,label = "$y^{\mathrm{rm}}-y^{\mathrm{pm}}$"+f":\n t≥"+str(2*dt)+"⇒"+"mean="+f'{e_ry[2:].mean():.4e}'+",\n std="+f'{e_ry[2:].std():.4e}'+", rms="+f'{np.sqrt((e_ry[2:]**2).mean()):.4e}'
#,color="black",linewidth = 2)
#plt.step(time_, e_ry ,label = "$y^{\mathrm{rm}}-y^{\mathrm{pm}}$ ",color="black",linewidth = 2)
#plt.axhline(y=e_ry.mean(), color="green",linewidth = 4, linestyle='--', label='mean($y^{\mathrm{rm}}-y^{\mathrm{pm}}$) =' +f'{e_ry.mean():.4e}')
#plt.axhline(y=np.sqrt((e_ry**2).mean()), color="black",linewidth = 4, linestyle='--', label='RMS($y^{\mathrm{rm}}-y^{\mathrm{pm}}$) =' +f'{np.sqrt((e_ry**2).mean()):.4e}')
#plt.axhline(y=e_ry.std(), color="cyan",linewidth = 3, linestyle=(0, (3, 1, 1, 1)), label='STD($y^{\mathrm{rm}}-y^{\mathrm{pm}}$) =' +f'{e_ry.std():.4e}')


plt.xlabel('Time (s)')
plt.ylabel('Torque (N⋅m)')
plt.legend(fontsize=7)
#plt.legend(fontsize=10,bbox_to_anchor=(1.05, 1.0), loc='upper left')
#plt.legend(fontsize=13,loc='upper center', bbox_to_anchor=(0.5, -0.22),ncol=2)
#plt.grid()
plt.xlim((5.01,10.1))
plt.minorticks_on()
plt.savefig(path+"Cartpole_Torque_vs_Time.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\m'
# <>:13: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_466/1000434111.py:13: SyntaxWarning: invalid escape sequence '\m'
#   plt.step(time_, save_actual_torque , ':',label = "$y^{\mathrm{pm}}=a^{actual}$"+"\nfrom DC motor plant",color="red",linewidth = 4)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2010: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   p.space          = oneOf(self._space_widths)("space")
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2020: PyparsingDeprecationWarning: 'leaveWhitespace' deprecated - use 'leave_whitespace'
#   )("sym").leaveWhitespace()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:1984: PyparsingDeprecationWarning: 'setName' deprecated - use 'set_name'
#   val.setName(key)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:1987: PyparsingDeprecationWarning: 'setParseAction' deprecated - use 'set_parse_action'
#   val.setParseAction(getattr(self, key))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2088: PyparsingDeprecationWarning: 'endQuoteChar' argument is deprecated, use 'end_quote_char'
#   p.text = cmd(r"\text", QuotedString('{', '\\', endQuoteChar="}"))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2146: PyparsingDeprecationWarning: 'unquoteResults' argument is deprecated, use 'unquote_results'
#   p.math_string   = QuotedString('$', '\\', unquoteResults=False)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print("for t≥"+str(2*dt)+",n≥2:")
print('error≈',poly_fit)
print("mean=", f'{e_ry[2:].mean():.4e}')
print("std=", f'{e_ry[2:].std():.4e}')
print("rms=",f'{np.sqrt((e_ry[2:]**2).mean()):.4e}')
print("mae=",f'{np.abs(e_ry[2:]).mean():.4e}')
# Out:
# for t≥0.04,n≥2:
# error≈ -3.24212371e-05 - (9.39403848e-05)·(-1.00803213 + 0.20040241t)
# mean= -3.2421e-05
# std= 1.3670e-02
# rms= 1.3670e-02
# mae= 1.3137e-02

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

e_ry=np.array(save_wanted_torque)-np.array(save_actual_torque)


plt.step(time_[2:], e_ry[2:], '--',label = "$y^{\mathrm{rm}}-y^{\mathrm{pm}}$ ",color="black",linewidth = 1.5)
plt.axhline(y=e_ry[2:].mean(), color="green",linewidth = 3, linestyle='--', label='mean($y^{\mathrm{rm}}-y^{\mathrm{pm}}$) =' +f'{e_ry[2:].mean():.4e}')
#plt.axhline(y=np.sqrt((e_ry**2).mean()), color="black",linewidth = 4, linestyle='--', label='RMS($y^{\mathrm{rm}}-y^{\mathrm{pm}}$) =' +f'{np.sqrt((e_ry**2).mean()):.4e}')
#plt.axhline(y=e_ry.std(), color="cyan",linewidth = 3, linestyle=(0, (3, 1, 1, 1)), label='STD($y^{\mathrm{rm}}-y^{\mathrm{pm}}$) =' +f'{e_ry.std():.4e}')

plt.xlabel("time [sec]")
plt.ylabel("Torque error [Nm]")
plt.legend(fontsize=15)
#plt.legend(fontsize=10,bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.grid()
plt.show()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\m'
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# <>:11: SyntaxWarning: invalid escape sequence '\m'
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_466/3224808089.py:11: SyntaxWarning: invalid escape sequence '\m'
#   plt.step(time_[2:], e_ry[2:], '--',label = "$y^{\mathrm{rm}}-y^{\mathrm{pm}}$ ",color="black",linewidth = 1.5)
# /tmp/ipykernel_466/3224808089.py:12: SyntaxWarning: invalid escape sequence '\m'
#   plt.axhline(y=e_ry[2:].mean(), color="green",linewidth = 3, linestyle='--', label='mean($y^{\mathrm{rm}}-y^{\mathrm{pm}}$) =' +f'{e_ry[2:].mean():.4e}')

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(5)
f.set_figheight(3)

#time_u = np.linspace(start = 0, stop = len(save_ctrl_voltage)* dt,num=len(save_ctrl_voltage) )

plt.step(time_, save_ctrl_voltage)
plt.xlabel("time [sec]")
plt.ylabel("Control Voltage [volts]")
plt.grid()
plt.show()

# %%
# distribution to 4 observation parameters

position = []
velocity = []
angle = []
angular_velocity = []
for observ in save_observation:
  for index,value in enumerate(observ):
    if index == 0:
      position.append(value)
    if index == 1:
      velocity.append(value)
    if index == 2:
      angle.append(value)
    if index == 3:
      angular_velocity.append(value)

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_position = np.linspace(start = 0, stop = len(position)* dt,num=len(position))##############################################
#time_position , position
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_position[-1] , 300)

spl = make_interp_spline(time_position, position, k=3)  # type: BSpline
power_smooth = spl(xnew)
font = {'size': 10}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(3)
f.set_figheight(3)
plt.plot(xnew, power_smooth, label="pos.")
plt.axhline(y=power_smooth.mean(), color='r', linestyle='--', label=f'mean pos.= {power_smooth.mean():.3e}')
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Position [m]')
plt.legend()
plt.show()

# %%
print(len(position))
# Out:
# 501

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_velocity = np.linspace(start = 0, stop = len(velocity)* dt,num=len(velocity))
#time_velocity , velocity
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_velocity[-1] , 300)

spl = make_interp_spline(time_velocity, velocity, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Velocity [m/sec]')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_angle = np.linspace(start = 0, stop = len(angle)* dt,num=len(angle))
#time_angle , angle
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_angle[-1] , 300)

spl = make_interp_spline(time_angle,angle, k=3)  # type: BSpline
power_smooth = spl(xnew)
font = {'size': 10}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(3)
f.set_figheight(3)
plt.plot(xnew, power_smooth, label="angle")
plt.axhline(y=power_smooth.mean(), color='r', linestyle='--', label=f'mean angle= {power_smooth.mean():.3e}')
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Angle [rad]')
plt.legend()
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_angular_velocity = np.linspace(start = 0, stop = len(angular_velocity)* dt,num=len(angular_velocity))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_angular_velocity[-1] , 300)

spl = make_interp_spline(time_angular_velocity, angular_velocity, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Angular Velocity [rad/sec]')
plt.show()

# %%
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_position[-1] , 300)

spl = make_interp_spline(time_position, position, k=3)  # type: BSpline
norm_pos = spl(xnew)/0.1#2.4

spl = make_interp_spline(time_position,angle, k=3)  # type: BSpline
norm_angle = spl(xnew)/0.2095#/0.2095#*(180/np.pi)/12

#label = "Norm Pos",color="blue",linewidth = 1.5), ':', label = "Norm Angle",color="red",linewidth = 4)

# %%
font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.0)
f.set_figheight(2.2)
#plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

plt.plot(xnew, norm_pos,label = r"Norm Pos: $\frac{x(\text{m})}{0.1}$",color="blue",linewidth = 1.5)
plt.plot(xnew, norm_angle,'--', label = r"Norm Angle: $\frac{\theta(\text{rad})}{0.2095}$",color="red",linewidth = 1)

#plt.grid()
#plt.ylim((-9,5))
plt.minorticks_on()
plt.xlabel('Time (s)')
plt.ylabel('Normalized Observations')
plt.legend(fontsize=8.5)
plt.savefig(path+"Cartpole_Obs_vs_Time.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print(f"pos:   mean={(norm_pos*0.1).mean():.2e}[m]; std={(norm_pos*0.1).std():.2e}[m]")
print(f"angle: mean={(norm_angle*0.2095).mean():.2e}[rad]; std={(norm_angle*0.2095).std():.2e}[rad]")
print(f"angle: mean={(norm_angle*12).mean():.2e}[deg]; std={(norm_angle*12).std():.2e}[deg]")
# Out:
# pos:   mean=-3.92e-04[m]; std=4.88e-03[m]
# angle: mean=-2.09e-04[rad]; std=4.89e-03[rad]
# angle: mean=-1.20e-02[deg]; std=2.80e-01[deg]
