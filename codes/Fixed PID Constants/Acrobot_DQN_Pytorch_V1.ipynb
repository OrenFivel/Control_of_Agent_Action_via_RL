# %%
#dqn

# %%
#https://github.com/openai/gym/blob/master/gym/envs/classic_control/acrobot.py

# %%
#https://github.com/eugeniaring/Medium-Articles/blob/main/Pytorch/acrobot.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle

# %%
"""classic Acrobot task"""
from typing import Optional

import numpy as np
from numpy import cos, pi, sin

np.float_ = np.float64

from gym import core, logger, spaces
from gym.error import DependencyNotInstalled

__copyright__ = "Copyright 2013, RLPy http://acl.mit.edu/RLPy"
__credits__ = [
    "Alborz Geramifard",
    "Robert H. Klein",
    "Christoph Dann",
    "William Dabney",
    "Jonathan P. How",
]
__license__ = "BSD 3-Clause"
__author__ = "Christoph Dann <cdann@cdann.de>"

# SOURCE:
# https://github.com/rlpy/rlpy/blob/master/rlpy/Domains/Acrobot.py
from gym.envs.classic_control import utils


class Custom_AcrobotEnv(core.Env):
    """
    ### Description
    The Acrobot environment is based on Sutton's work in
    ["Generalization in Reinforcement Learning: Successful Examples Using Sparse Coarse Coding"](https://papers.nips.cc/paper/1995/hash/8f1d43620bc6bb580df6e80b0dc05c48-Abstract.html)
    and [Sutton and Barto's book](http://www.incompleteideas.net/book/the-book-2nd.html).
    The system consists of two links connected linearly to form a chain, with one end of
    the chain fixed. The joint between the two links is actuated. The goal is to apply
    torques on the actuated joint to swing the free end of the linear chain above a
    given height while starting from the initial state of hanging downwards.
    As seen in the **Gif**: two blue links connected by two green joints. The joint in
    between the two links is actuated. The goal is to swing the free end of the outer-link
    to reach the target height (black horizontal line above system) by applying torque on
    the actuator.
    ### Action Space
    The action is discrete, deterministic, and represents the torque applied on the actuated
    joint between the two links.
    | Num | Action                                | Unit         |
    |-----|---------------------------------------|--------------|
    | 0   | apply -1 torque to the actuated joint | torque (N m) |
    | 1   | apply 0 torque to the actuated joint  | torque (N m) |
    | 2   | apply 1 torque to the actuated joint  | torque (N m) |
    ### Observation Space
    The observation is a `ndarray` with shape `(6,)` that provides information about the
    two rotational joint angles as well as their angular velocities:
    | Num | Observation                  | Min                 | Max               |
    |-----|------------------------------|---------------------|-------------------|
    | 0   | Cosine of `theta1`           | -1                  | 1                 |
    | 1   | Sine of `theta1`             | -1                  | 1                 |
    | 2   | Cosine of `theta2`           | -1                  | 1                 |
    | 3   | Sine of `theta2`             | -1                  | 1                 |
    | 4   | Angular velocity of `theta1` | ~ -12.567 (-4 * pi) | ~ 12.567 (4 * pi) |
    | 5   | Angular velocity of `theta2` | ~ -28.274 (-9 * pi) | ~ 28.274 (9 * pi) |
    where
    - `theta1` is the angle of the first joint, where an angle of 0 indicates the first link is pointing directly
    downwards.
    - `theta2` is ***relative to the angle of the first link.***
        An angle of 0 corresponds to having the same angle between the two links.
    The angular velocities of `theta1` and `theta2` are bounded at ±4π, and ±9π rad/s respectively.
    A state of `[1, 0, 1, 0, ..., ...]` indicates that both links are pointing downwards.
    ### Rewards
    The goal is to have the free end reach a designated target height in as few steps as possible,
    and as such all steps that do not reach the goal incur a reward of -1.
    Achieving the target height results in termination with a reward of 0. The reward threshold is -100.
    ### Starting State
    Each parameter in the underlying state (`theta1`, `theta2`, and the two angular velocities) is initialized
    uniformly between -0.1 and 0.1. This means both links are pointing downwards with some initial stochasticity.
    ### Episode End
    The episode ends if one of the following occurs:
    1. Termination: The free end reaches the target height, which is constructed as:
    `-cos(theta1) - cos(theta2 + theta1) > 1.0`
    2. Truncation: Episode length is greater than 500 (200 for v0)
    ### Arguments
    No additional arguments are currently supported.
    ```
    env = gym.make('Acrobot-v1')
    ```
    By default, the dynamics of the acrobot follow those described in Sutton and Barto's book
    [Reinforcement Learning: An Introduction](http://incompleteideas.net/book/11/node4.html).
    However, a `book_or_nips` parameter can be modified to change the pendulum dynamics to those described
    in the original [NeurIPS paper](https://papers.nips.cc/paper/1995/hash/8f1d43620bc6bb580df6e80b0dc05c48-Abstract.html).
    ```
    # To change the dynamics as described above
    env.env.book_or_nips = 'nips'
    ```
    See the following note and
    the [implementation](https://github.com/openai/gym/blob/master/gym/envs/classic_control/acrobot.py) for details:
    > The dynamics equations were missing some terms in the NIPS paper which
            are present in the book. R. Sutton confirmed in personal correspondence
            that the experimental results shown in the paper and the book were
            generated with the equations shown in the book.
            However, there is the option to run the domain with the paper equations
            by setting `book_or_nips = 'nips'`
    ### Version History
    - v1: Maximum number of steps increased from 200 to 500. The observation space for v0 provided direct readings of
    `theta1` and `theta2` in radians, having a range of `[-pi, pi]`. The v1 observation space as described here provides the
    sine and cosine of each angle instead.
    - v0: Initial versions release (1.0.0) (removed from gym for v1)
    ### References
    - Sutton, R. S. (1996). Generalization in Reinforcement Learning: Successful Examples Using Sparse Coarse Coding.
        In D. Touretzky, M. C. Mozer, & M. Hasselmo (Eds.), Advances in Neural Information Processing Systems (Vol. 8).
        MIT Press. https://proceedings.neurips.cc/paper/1995/file/8f1d43620bc6bb580df6e80b0dc05c48-Paper.pdf
    - Sutton, R. S., Barto, A. G. (2018 ). Reinforcement Learning: An Introduction. The MIT Press.
    """

    metadata = {
        "render_modes": ["human", "rgb_array"],
        "render_fps": 15,
    }

    dt = 0.2

    LINK_LENGTH_1 = 1.0  # [m]
    LINK_LENGTH_2 = 1.0  # [m]
    LINK_MASS_1 = 1.0  #: [kg] mass of link 1
    LINK_MASS_2 = 1.0  #: [kg] mass of link 2
    LINK_COM_POS_1 = 0.5  #: [m] position of the center of mass of link 1
    LINK_COM_POS_2 = 0.5  #: [m] position of the center of mass of link 2
    LINK_MOI = 1.0  #: moments of inertia for both links

    MAX_VEL_1 = 4 * pi
    MAX_VEL_2 = 9 * pi

    AVAIL_TORQUE = [-1.0, 0.0, +1.0]

    torque_noise_max = 0.0

    SCREEN_DIM = 500

    #: use dynamics equations from the nips paper or the book
    book_or_nips = "book"
    action_arrow = None
    domain_fig = None
    actions_num = 3

    def __init__(self, render_mode: Optional[str] = None):
        self.render_mode = render_mode
        self.screen = None
        self.clock = None
        self.isopen = True
        high = np.array(
            [1.0, 1.0, 1.0, 1.0, self.MAX_VEL_1, self.MAX_VEL_2], dtype=np.float64
        )
        low = -high
        self.observation_space = spaces.Box(low=low, high=high, dtype=np.float64)
        self.action_space = spaces.Discrete(3)
        self.state = None

                ### Customization changes ######
        '''add ElectricalDCMotorEnv to the CartPole class
        and assign values to
        Resistor_R, inductor_L, torque_const_Kt and bemf_const_Ke'''
        self.tau1 = self.dt/10  # seconds between state updates
        self.DCMotorModel = ElectricalDCMotorEnv()
        self.DCMotorModel.tau1 = self.tau1
        self.DCMotorModel.Resistor_R = 1.0
        self.DCMotorModel.inductor_L = 0.1
        self.DCMotorModel.torque_const_Kt = 1.0
        self.DCMotorModel.bemf_const_Ke = 1.0
        ####

    def reset(self, *, seed: Optional[int] = None, options: Optional[dict] = None):
        super().reset(seed=seed)
        # Note that if you use custom reset bounds, it may lead to out-of-bound
        # state/observations.
        low, high = utils.maybe_parse_reset_bounds(
            options, -0.1, 0.1  # default low
        )  # default high
        self.state = self.np_random.uniform(low=low, high=high, size=(4,)).astype(
            np.float64
        )

        self.DCMotorModel.current = 0.0
        self.DCMotorModel.current_error = 0.0
        self.DCMotorModel.current_error_acc = 0.0
        self.DCMotorModel.current_error_prev = 0.0

        if self.render_mode == "human":
            self.render()
        return self._get_ob(), {}

    def step(self, a):
        s = self.state


        assert s is not None, "Call reset before using AcrobotEnv object."
        ns=np.asarray(s)
        wanted_torque = self.AVAIL_TORQUE[a]

        current_ref = wanted_torque/self.DCMotorModel.torque_const_Kt
        #print("current_ref", current_ref)
        for t in np.arange(start=0.0, stop=self.dt, step=self.tau1):
          actual_torque = self.DCMotorModel.step(current_ref = current_ref, theta_dot = ns[3])
          #actual_torque = wanted_torque # change for perfect applying force

          # Add noise to the force action
          '''
          if self.torque_noise_max > 0:
              actual_torque += self.np_random.uniform(
                  -self.torque_noise_max, self.torque_noise_max
              )
          '''
          # Now, augment the state with our force action so it can be passed to
          # _dsdt
          s_augmented = np.append(ns, actual_torque)
          ns = rk4(self._dsdt, s_augmented, [0, self.tau1])
          ns[0] = wrap(ns[0], -pi, pi)
          ns[1] = wrap(ns[1], -pi, pi)
          ns[2] = bound(ns[2], -self.MAX_VEL_1, self.MAX_VEL_1)
          ns[3] = bound(ns[3], -self.MAX_VEL_2, self.MAX_VEL_2)


        self.state = ns
        terminated = self._terminal()
        reward = -1.0 if not terminated else 0.0

        #if self.render_mode == "human":
        #    self.render()
        return self._get_ob(), reward, terminated, False , wanted_torque, actual_torque

    def _get_ob(self):
        s = self.state
        assert s is not None, "Call reset before using AcrobotEnv object."
        return np.array(
            [cos(s[0]), sin(s[0]), cos(s[1]), sin(s[1]), s[2], s[3]], dtype=np.float64
        )

    def _terminal(self):
        s = self.state
        assert s is not None, "Call reset before using AcrobotEnv object."
        return bool(-cos(s[0]) - cos(s[1] + s[0]) > 1.0)

    def _dsdt(self, s_augmented):
        m1 = self.LINK_MASS_1
        m2 = self.LINK_MASS_2
        l1 = self.LINK_LENGTH_1
        lc1 = self.LINK_COM_POS_1
        lc2 = self.LINK_COM_POS_2
        I1 = self.LINK_MOI
        I2 = self.LINK_MOI
        g = 9.8
        a = s_augmented[-1]
        s = s_augmented[:-1]
        theta1 = s[0]
        theta2 = s[1]
        dtheta1 = s[2]
        dtheta2 = s[3]
        d1 = (
            m1 * lc1**2
            + m2 * (l1**2 + lc2**2 + 2 * l1 * lc2 * cos(theta2))
            + I1
            + I2
        )
        d2 = m2 * (lc2**2 + l1 * lc2 * cos(theta2)) + I2
        phi2 = m2 * lc2 * g * cos(theta1 + theta2 - pi / 2.0)
        phi1 = (
            -m2 * l1 * lc2 * dtheta2**2 * sin(theta2)
            - 2 * m2 * l1 * lc2 * dtheta2 * dtheta1 * sin(theta2)
            + (m1 * lc1 + m2 * l1) * g * cos(theta1 - pi / 2)
            + phi2
        )
        if self.book_or_nips == "nips":
            # the following line is consistent with the description in the
            # paper
            ddtheta2 = (a + d2 / d1 * phi1 - phi2) / (m2 * lc2**2 + I2 - d2**2 / d1)
        else:
            # the following line is consistent with the java implementation and the
            # book
            ddtheta2 = (
                a + d2 / d1 * phi1 - m2 * l1 * lc2 * dtheta1**2 * sin(theta2) - phi2
            ) / (m2 * lc2**2 + I2 - d2**2 / d1)
        ddtheta1 = -(d2 * ddtheta2 + phi1) / d1
        return dtheta1, dtheta2, ddtheta1, ddtheta2, 0.0

    def render(self):
        if self.render_mode is None:
            logger.warn(
                "You are calling render method without specifying any render mode. "
                "You can specify the render_mode at initialization, "
                f'e.g. gym("{self.spec.id}", render_mode="rgb_array")'
            )
            return

        try:
            import pygame
            from pygame import gfxdraw
        except ImportError:
            raise DependencyNotInstalled(
                "pygame is not installed, run `pip install gym[classic_control]`"
            )

        if self.screen is None:
            pygame.init()
            if self.render_mode == "human":
                pygame.display.init()
                self.screen = pygame.display.set_mode(
                    (self.SCREEN_DIM, self.SCREEN_DIM)
                )
            else:  # mode in "rgb_array"
                self.screen = pygame.Surface((self.SCREEN_DIM, self.SCREEN_DIM))
        if self.clock is None:
            self.clock = pygame.time.Clock()

        surf = pygame.Surface((self.SCREEN_DIM, self.SCREEN_DIM))
        surf.fill((255, 255, 255))
        s = self.state

        bound = self.LINK_LENGTH_1 + self.LINK_LENGTH_2 + 0.2  # 2.2 for default
        scale = self.SCREEN_DIM / (bound * 2)
        offset = self.SCREEN_DIM / 2

        if s is None:
            return None

        p1 = [
            -self.LINK_LENGTH_1 * cos(s[0]) * scale,
            self.LINK_LENGTH_1 * sin(s[0]) * scale,
        ]

        p2 = [
            p1[0] - self.LINK_LENGTH_2 * cos(s[0] + s[1]) * scale,
            p1[1] + self.LINK_LENGTH_2 * sin(s[0] + s[1]) * scale,
        ]

        xys = np.array([[0, 0], p1, p2])[:, ::-1]
        thetas = [s[0] - pi / 2, s[0] + s[1] - pi / 2]
        link_lengths = [self.LINK_LENGTH_1 * scale, self.LINK_LENGTH_2 * scale]

        pygame.draw.line(
            surf,
            start_pos=(-2.2 * scale + offset, 1 * scale + offset),
            end_pos=(2.2 * scale + offset, 1 * scale + offset),
            color=(0, 0, 0),
        )

        for ((x, y), th, llen) in zip(xys, thetas, link_lengths):
            x = x + offset
            y = y + offset
            l, r, t, b = 0, llen, 0.1 * scale, -0.1 * scale
            coords = [(l, b), (l, t), (r, t), (r, b)]
            transformed_coords = []
            for coord in coords:
                coord = pygame.math.Vector2(coord).rotate_rad(th)
                coord = (coord[0] + x, coord[1] + y)
                transformed_coords.append(coord)
            gfxdraw.aapolygon(surf, transformed_coords, (0, 204, 204))
            gfxdraw.filled_polygon(surf, transformed_coords, (0, 204, 204))

            gfxdraw.aacircle(surf, int(x), int(y), int(0.1 * scale), (204, 204, 0))
            gfxdraw.filled_circle(surf, int(x), int(y), int(0.1 * scale), (204, 204, 0))

        surf = pygame.transform.flip(surf, False, True)
        self.screen.blit(surf, (0, 0))

        if self.render_mode == "human":
            pygame.event.pump()
            self.clock.tick(self.metadata["render_fps"])
            pygame.display.flip()

        elif self.render_mode == "rgb_array":
            return np.transpose(
                np.array(pygame.surfarray.pixels3d(self.screen)), axes=(1, 0, 2)
            )

    def close(self):
        if self.screen is not None:
            import pygame

            pygame.display.quit()
            pygame.quit()
            self.isopen = False


def wrap(x, m, M):
    """Wraps ``x`` so m <= x <= M; but unlike ``bound()`` which
    truncates, ``wrap()`` wraps x around the coordinate system defined by m,M.\n
    For example, m = -180, M = 180 (degrees), x = 360 --> returns 0.
    Args:
        x: a scalar
        m: minimum possible value in range
        M: maximum possible value in range
    Returns:
        x: a scalar, wrapped
    """
    diff = M - m
    while x > M:
        x = x - diff
    while x < m:
        x = x + diff
    return x


def bound(x, m, M=None):
    """Either have m as scalar, so bound(x,m,M) which returns m <= x <= M *OR*
    have m as length 2 vector, bound(x,m, <IGNORED>) returns m[0] <= x <= m[1].
    Args:
        x: scalar
        m: The lower bound
        M: The upper bound
    Returns:
        x: scalar, bound between min (m) and Max (M)
    """
    if M is None:
        M = m[1]
        m = m[0]
    # bound x between min (m) and Max (M)
    return min(max(x, m), M)


def rk4(derivs, y0, t):
    """
    Integrate 1-D or N-D system of ODEs using 4-th order Runge-Kutta.
    Example for 2D system:
        >>> def derivs(x):
        ...     d1 =  x[0] + 2*x[1]
        ...     d2 =  -3*x[0] + 4*x[1]
        ...     return d1, d2
        >>> dt = 0.0005
        >>> t = np.arange(0.0, 2.0, dt)
        >>> y0 = (1,2)
        >>> yout = rk4(derivs, y0, t)
    Args:
        derivs: the derivative of the system and has the signature ``dy = derivs(yi)``
        y0: initial state vector
        t: sample times
    Returns:
        yout: Runge-Kutta approximation of the ODE
    """

    try:
        Ny = len(y0)
    except TypeError:
        yout = np.zeros((len(t),), np.float_)
    else:
        yout = np.zeros((len(t), Ny), np.float_)

    yout[0] = y0

    for i in np.arange(len(t) - 1):

        this = t[i]
        dt = t[i + 1] - this
        dt2 = dt / 2.0
        y0 = yout[i]

        k1 = np.asarray(derivs(y0))
        k2 = np.asarray(derivs(y0 + dt2 * k1))
        k3 = np.asarray(derivs(y0 + dt2 * k2))
        k4 = np.asarray(derivs(y0 + dt * k3))
        yout[i + 1] = y0 + dt / 6.0 * (k1 + 2 * k2 + 2 * k3 + k4)
    # We only care about the final timestep and we cleave off action value which will be zero
    return yout[-1][:4]
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
class ElectricalDCMotorEnv():

      def __init__(self):
        self.Resistor_R = 1.0
        self.inductor_L = 0.1
        self.torque_const_Kt = 1.0
        self.bemf_const_Ke = 1.0
        self.tau1 = 0.05
        #
        self.Kp = 1.0
        self.Ki = 10.0
        self.Kd = 10**(-6)
        self.aL=10**(-3)#Low pass parameter
        self.aH = 10**2 #High pass parameter

        #
        self.current = 0.0
        self.current_error = 0.0
        self.current_error_acc = 0.0
        self.current_error_prev = 0.0
        self.voltage_input = 0.0
        self.theta_dot = 0.0
        self.PID_Discretization = "Simple" #"Backward", " "Bilinear" , "Forward" "Simple"

      def step(self, current_ref, theta_dot):
        aL = self.aL
        aH = self.aH
        self.current_error = current_ref-self.current
        delta_error = self.current_error-self.current_error_prev

        if self.PID_Discretization == "Simple":
          self.current_error_acc += self.current_error*self.tau1
          HP_delta_error = delta_error

        elif self.PID_Discretization == "Backward":
          self.current_error_acc = (self.current_error_acc+(self.current_error)*self.tau1)/(1+aL*self.tau1) #Low Pass
          HP_delta_error = (self.current_error + aH*delta_error)/(1+aL*self.tau1)#High Pass

        elif self.PID_Discretization == "Bilinear":
          error_avg = (self.current_error+self.current_error_prev)/2
          self.current_error_acc =  ((1-aL*self.tau1/2)*self.current_error_acc + error_avg*self.tau1)/(1+aL*self.tau1/2)#Low Pass
          HP_delta_error =  ((1-aL*self.tau1/2)*self.current_error + aH*delta_error)/(1+aL*self.tau1/2)#High Pass

        else:
          self.current_error_acc = (1-aL*self.tau1)*self.current_error_acc+(self.current_error_prev)*self.tau1 #Low Pass
          HP_delta_error = (1-aH*self.tau1)*self.current_error + aH*delta_error #High Pass

        P = self.Kp*self.current_error
        I = self.Ki*self.current_error_acc
        D = self.Kd*HP_delta_error/self.tau1

        voltage_BEMF = theta_dot*self.bemf_const_Ke
        voltage_input = P+I+D+voltage_BEMF
        voltage_input = np.clip(voltage_input, -10, 10)

        self.current_error_prev = 0+self.current_error
        self.current += self.tau1*(voltage_input-voltage_BEMF-self.current*self.Resistor_R)/self.inductor_L
        self.current = np.clip(self.current, -10, 10)
        self.voltage_input = voltage_input
        self.theta_dot = theta_dot
        torque = self.torque_const_Kt*self.current

        return torque # return applied torque

# %%
env =  Custom_AcrobotEnv()
env.DCMotorModel.PID_Discretization ="Simple" # "Forward" or "Backward" or" "Bilinear" or "Simple"

# %%
import random
import torch
import numpy as np
import gym
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from torch import nn
from collections import deque,namedtuple
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print(f"Initial default dtype: {torch.get_default_dtype()}")
torch.set_default_dtype(torch.float64)
print(f"New default dtype: {torch.get_default_dtype()}")
# Out:
# Initial default dtype: torch.float32
# New default dtype: torch.float64

# %%
# !apt update
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:5 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:6 https://cli.github.com/packages stable/main amd64 Packages [355 B]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,529 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:13 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [39.2 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,301 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,734 kB]
# Get:16 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 Packages [75.3 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [62.6 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [70.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,614 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,749 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,070 kB]
# Get:22 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,756 kB]
# Get:23 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,904 kB]
# Fetched 37.4 MB in 3s (11.0 MB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 79 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package python-opengl
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 79 not upgraded.
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0
# Collecting piglet
#   Downloading piglet-1.0.0-py2.py3-none-any.whl.metadata (814 bytes)
# Collecting piglet-templates (from piglet)
#   Downloading piglet_templates-1.3.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from piglet-templates->piglet) (3.3.2)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from piglet-templates->piglet) (25.4.0)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.12/dist-packages (from piglet-templates->piglet) (3.0.3)
# Downloading piglet-1.0.0-py2.py3-none-any.whl (2.2 kB)
# Downloading piglet_templates-1.3.3-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: piglet-templates, piglet
# Successfully installed piglet-1.0.0 piglet-templates-1.3.3

# %%
import glob
import io
import base64
import os
from IPython.display import HTML
from IPython import display as ipythondisplay
from pyvirtualdisplay import Display
#from gym.wrappers import Monitor

# %%
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
    # !bash ../xvfb start
    # %env DISPLAY=:1

# %%
'''
import gym
#env = gym.make('Acrobot-v1')
env =  Custom_AcrobotEnv()
env.seed(0)

print(env.action_space)
print(env.observation_space)
'''
# Out:
# "\nimport gym\n#env = gym.make('Acrobot-v1')\nenv =  Custom_AcrobotEnv()\nenv.seed(0)\n\nprint(env.action_space)\nprint(env.observation_space)\n"

# %%
class ReplayMemory(object):

    def __init__(self, capacity):
        # Define a queue with maxlen "capacity"
        self.memory = deque(maxlen=capacity)

    def push(self, state, action, next_state, reward):
        # Add the tuple (state, action, next_state, reward) to the queue
        self.memory.append((state, action, next_state, reward))

    def sample(self, batch_size):
        batch_size = min(batch_size, len(self)) # Get all the samples if the requested batch_size is higher than the number of sample currently in the memory
        # Randomly select "batch_size" samples and return the selection
        return random.sample(self.memory,batch_size)

    def __len__(self):
        return len(self.memory) # Return the number of samples currently stored in the memory

# %%
class DQN(nn.Module):

    def __init__(self, state_space_dim, action_space_dim):
        super().__init__()

        self.linear = nn.Sequential(
                  nn.Linear(state_space_dim,64),#,dtype=torch.float64),
                  nn.ReLU(),
                  nn.Linear(64,64*2),#,dtype=torch.float64),
                  nn.ReLU(),
                  nn.Linear(64*2,action_space_dim)#,dtype=torch.float64)
                )

    def forward(self, x):
        x = x.to(device)
        return self.linear(x)

# %%
def choose_action_epsilon_greedy(net, state, epsilon):

    if epsilon > 1 or epsilon < 0:
        raise Exception('The epsilon value must be between 0 and 1')

    # Evaluate the network output from the current state
    with torch.no_grad():
        net.eval()
        state = torch.tensor(state)#, dtype=torch.float64) # Convert the state to tensor
        net_out = net(state)

    # Get the best action (argmax of the network output)
    best_action = int(net_out.argmax())
    # Get the number of possible actions
    action_space_dim = net_out.shape[-1]

    # Select a non optimal action with probability epsilon, otherwise choose the best action
    if random.random() < epsilon:
        # List of non-optimal actions (this list includes all the actions but the optimal one)
        non_optimal_actions = [a for a in range(action_space_dim) if a != best_action]
        # Select randomly from non_optimal_actions
        action = random.choice(non_optimal_actions)
    else:
        # Select best action
        action = best_action

    return action, net_out.cpu().numpy()

# %%
def choose_action_softmax(net, state, temperature):

    if temperature < 0:
        raise Exception('The temperature value must be greater than or equal to 0 ')

    # If the temperature is 0, just select the best action using the eps-greedy policy with epsilon = 0
    if temperature == 0:
        return choose_action_epsilon_greedy(net, state, 0)

    # Evaluate the network output from the current state
    with torch.no_grad():
        net.eval()
        state = torch.tensor(state)#, dtype=torch.float64)
        net_out = net(state)

    # Apply softmax with temp
    temperature = max(temperature, 1e-8) # set a minimum to the temperature for numerical stability
    softmax_out = nn.functional.softmax(net_out/temperature, dim=0).cpu().numpy()

    # Sample the action using softmax output as mass pdf
    all_possible_actions = np.arange(0, softmax_out.shape[-1])
    # this samples a random element from "all_possible_actions" with the probability distribution p (softmax_out in this case)
    action = np.random.choice(all_possible_actions,p=softmax_out)

    return action, net_out.cpu().numpy()

# %%
### Define exploration profile
initial_value = 5
#num_iterations = 800
#num_iterations = 10
num_iterations = 1000
exp_decay = np.exp(-np.log(initial_value) / num_iterations * 6) # We compute the exponential decay in such a way the shape of the exploration profile does not depend on the number of iterations
exploration_profile = [initial_value * (exp_decay ** i) for i in range(num_iterations)]
score_low_bound = -499#-2000 ###change add score low bound


### Plot exploration profile
plt.figure(figsize=(12,8))
plt.plot(exploration_profile)
plt.grid()
plt.xlabel('Iteration')
plt.ylabel('Exploration profile (Softmax temperature)')
# Out:
# Text(0, 0.5, 'Exploration profile (Softmax temperature)')

# %%
### Create environment
env =  Custom_AcrobotEnv()
env.seed(0) # Set a random seed for the environment (reproducible results)

# Get the shapes of the state space (observation_space) and action space (action_space)
state_space_dim = env.observation_space.shape[0]
action_space_dim = env.action_space.n
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"STATE SPACE SIZE: {state_space_dim}")
print(f"ACTION SPACE SIZE: {action_space_dim}")
# Out:
# STATE SPACE SIZE: 6
# ACTION SPACE SIZE: 3
# /usr/local/lib/python3.12/dist-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(

# %%
# Set random seeds
torch.manual_seed(0)
np.random.seed(0)

### PARAMETERS
gamma = 0.99   # gamma parameter for the long term reward
replay_memory_capacity = 10000   # Replay memory capacity
lr = 1e-3 # Optimizer learning rate
target_net_update_steps = 10   # Number of episodes to wait before updating the target network
batch_size = 256   # Number of samples to take from the replay memory for each update
bad_state_penalty = 0   # Penalty to the reward when we are in a bad state (in this case when the pole falls down)
min_samples_for_training = 1000   # Minimum samples in the replay memory to enable the training

# %%
### Initialize the replay memory
replay_mem = ReplayMemory(replay_memory_capacity)

### Initialize the policy network
policy_net = DQN(state_space_dim, action_space_dim).to(device)

### Initialize the target network with the same weights of the policy network
target_net = DQN(state_space_dim, action_space_dim).to(device)
target_net.load_state_dict(policy_net.state_dict()) # This will copy the weights of the policy network to the target network

### Initialize the optimizer
optimizer = torch.optim.Adam(policy_net.parameters(), lr=lr) # The optimizer will update ONLY the parameters of the policy network

### Initialize the loss function (Huber loss)
loss_fn = nn.SmoothL1Loss()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
def update_step(policy_net, target_net, replay_mem, gamma, optimizer, loss_fn, batch_size):

    # Sample the data from the replay memory
    batch = replay_mem.sample(batch_size)
    batch_size = len(batch)

    # Create tensors for each element of the batch
    states      = torch.tensor([s[0] for s in batch], device=device)#, dtype=torch.float64, device=device)
    actions     = torch.tensor([s[1] for s in batch], device=device)#, dtype=torch.int64, device=device)
    rewards     = torch.tensor([s[3] for s in batch], device=device)#, dtype=torch.float64, device=device)

    # Compute a mask of non-final states (all the elements where the next state is not None)
    non_final_next_states = torch.tensor([s[2] for s in batch if s[2] is not None], device=device)#, dtype=torch.float64, device=device) # the next state can be None if the game has ended
    non_final_mask = torch.tensor([s[2] is not None for s in batch], dtype=torch.bool)

    # Compute all the Q values (forward pass)
    policy_net.train()
    q_values = policy_net(states)
    # Select the proper Q value for the corresponding action taken Q(s_t, a)
    state_action_values = q_values.gather(1, actions.unsqueeze(1).cuda())

    # Compute the value function of the next states using the target network V(s_{t+1}) = max_a( Q_target(s_{t+1}, a)) )
    with torch.no_grad():
      target_net.eval()
      q_values_target = target_net(non_final_next_states)
    next_state_max_q_values = torch.zeros(batch_size, device=device)#, dtype=torch.float64, device=device)
    next_state_max_q_values[non_final_mask] = q_values_target.max(dim=1)[0].detach()

    # Compute the expected Q values
    expected_state_action_values = rewards + (next_state_max_q_values * gamma)
    expected_state_action_values = expected_state_action_values.unsqueeze(1)# Set the required tensor shape

    # Compute the Huber loss
    loss = loss_fn(state_action_values, expected_state_action_values)

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    # Apply gradient clipping (clip all the gradients greater than 2 for training stability)
    nn.utils.clip_grad_norm_(policy_net.parameters(), 2)
    optimizer.step()

# %%
# Initialize the Gym environment
#env = gym.make('Acrobot-v1')
env =  Custom_AcrobotEnv()
env.seed(0) # Set a random seed for the environment (reproducible results)
# Out:
# /usr/local/lib/python3.12/dist-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(
# [0]

# %%
state = env.reset()[0]
dummy_input = torch.tensor(state)#, dtype=torch.float64)
input_shape = state.shape
print("input shape= ",input_shape)
# Out:
# input shape=  (6,)

# %%
# !pip install torchview
# Out:
# Collecting torchview
#   Downloading torchview-0.2.7-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from torchview) (0.21)
# Downloading torchview-0.2.7-py3-none-any.whl (26 kB)
# Installing collected packages: torchview
# Successfully installed torchview-0.2.7

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (0.21)

# %%
from torchsummary import summary
from torchview import draw_graph

# %%
print(policy_net)
# Out:
# DQN(
#   (linear): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=3, bias=True)
#   )
# )

# %%
#summary(policy_net, input_size=(input_shape))

# %%
# Generate and display the graph
dqn_model_graph = draw_graph(
    policy_net,
    input_data=dummy_input,
    graph_name='DQN',
    save_graph=False, # Set to True to save as file
    show_shapes=True,  # Displays input/output shapes
    expand_nested=True # Expand nested modules
)

# %%
dqn_model_graph.visual_graph
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# This is for creating the output video in Colab, not required outside Colab
#env = wrap_env(env, video_callable=lambda episode_id: episode_id % 100 == 0) # Save a video every 100 episodes

plotting_rewards=[]

# %%
for episode_num, tau in enumerate(tqdm(exploration_profile)):

    # Reset the environment and get the initial state
    state = env.reset()
    state = state[0]###################################################################################################################################################
    # Reset the score. The final score will be the total amount of steps before the pole falls
    score = 0
    done = False

    # Go on until the pole falls off
    while not done:

      # Choose the action following the policy
      action, q_values = choose_action_softmax(policy_net, state, temperature=tau)

      # Apply the action and get the next state, the reward and a flag "done" that is True if the game is ended
      next_state, reward, done, info, force1, F1 = env.step(action)#############################################
      #if episode_num == len(exploration_profile) - 1 :################################################################################
      #  save_observation.append(next_state)
      #  save_u1.append(force1)
      #  save_pid_u1.append(F1)
      #  save_ctrl_voltage.append(env.DCMotorModel.voltage_input)

      # Update the final score (+1 for each step)
      score += reward

      if score<score_low_bound: ##### change  to stop high negative score
        done =True

      # Apply penalty for bad state

      if done: # if the pole has fallen down
          reward += bad_state_penalty
          next_state = None

      # Update the replay memory
      replay_mem.push(state, action, next_state, reward)

      # Update the network
      if len(replay_mem) > min_samples_for_training: # we enable the training only if we have enough samples in the replay memory, otherwise the training will use the same samples too often
          update_step(policy_net, target_net, replay_mem, gamma, optimizer, loss_fn, batch_size)

      # Visually render the environment (disable to speed up the training)
      #env.render()

      # Set the current state for the next iteration
      state = next_state

    # Update the target network every target_net_update_steps episodes
    if episode_num % target_net_update_steps == 0:
        print('Updating target network...')
        target_net.load_state_dict(policy_net.state_dict()) # This will copy the weights of the policy network to the target network

    plotting_rewards.append(score)
    # Print the final score
    print(f"EPISODE: {episode_num} - FINAL SCORE: {score}; desired torque={force1}, actual torque={F1:.3f}") # Print the final score

env.close()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Updating target network...
# EPISODE: 0 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.089
# EPISODE: 1 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.817
# /tmp/ipython-input-1651696744.py:8: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   states      = torch.tensor([s[0] for s in batch], device=device)#, dtype=torch.float64, device=device)
# EPISODE: 2 - FINAL SCORE: -474.0; desired torque=-1.0, actual torque=-0.799
# EPISODE: 3 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.978
# EPISODE: 4 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.868
# EPISODE: 5 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.970
# EPISODE: 6 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.960
# EPISODE: 7 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.883
# EPISODE: 8 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.104
# EPISODE: 9 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.779
# Updating target network...
# EPISODE: 10 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.950
# EPISODE: 11 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.957
# EPISODE: 12 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.990
# EPISODE: 13 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.802
# EPISODE: 14 - FINAL SCORE: -414.0; desired torque=-1.0, actual torque=-0.871
# EPISODE: 15 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.019
# EPISODE: 16 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.102
# EPISODE: 17 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.773
# EPISODE: 18 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.070
# EPISODE: 19 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.001
# Updating target network...
# EPISODE: 20 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.071
# EPISODE: 21 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.873
# EPISODE: 22 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.102
# EPISODE: 23 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.020
# EPISODE: 24 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.974
# EPISODE: 25 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.989
# EPISODE: 26 - FINAL SCORE: -468.0; desired torque=-1.0, actual torque=-0.995
# EPISODE: 27 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.088
# EPISODE: 28 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.025
# EPISODE: 29 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.006
# Updating target network...
# EPISODE: 30 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.797
# EPISODE: 31 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.872
# EPISODE: 32 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.803
# EPISODE: 33 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.906
# EPISODE: 34 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.066
# EPISODE: 35 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.783
# EPISODE: 36 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.900
# EPISODE: 37 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.023
# EPISODE: 38 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.989
# EPISODE: 39 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.073
# Updating target network...
# EPISODE: 40 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.082
# EPISODE: 41 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.959
# EPISODE: 42 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.949
# EPISODE: 43 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.013
# EPISODE: 44 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.904
# EPISODE: 45 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.797
# EPISODE: 46 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.085
# EPISODE: 47 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.774
# EPISODE: 48 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.022
# EPISODE: 49 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.961
# Updating target network...
# EPISODE: 50 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.891
# EPISODE: 51 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.951
# EPISODE: 52 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.989
# EPISODE: 53 - FINAL SCORE: -469.0; desired torque=-1.0, actual torque=-0.871
# EPISODE: 54 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.782
# EPISODE: 55 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.882
# EPISODE: 56 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.002
# EPISODE: 57 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.020
# EPISODE: 58 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.816
# EPISODE: 59 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.014
# Updating target network...
# EPISODE: 60 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.992
# EPISODE: 61 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.092
# EPISODE: 62 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.069
# EPISODE: 63 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.864
# EPISODE: 64 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.812
# EPISODE: 65 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.890
# EPISODE: 66 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.892
# EPISODE: 67 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.795
# EPISODE: 68 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.998
# EPISODE: 69 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.023
# Updating target network...
# EPISODE: 70 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.956
# EPISODE: 71 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.866
# EPISODE: 72 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.006
# EPISODE: 73 - FINAL SCORE: -370.0; desired torque=1.0, actual torque=0.976
# EPISODE: 74 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.774
# EPISODE: 75 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.901
# EPISODE: 76 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.025
# EPISODE: 77 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.068
# EPISODE: 78 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.798
# EPISODE: 79 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.814
# Updating target network...
# EPISODE: 80 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.990
# EPISODE: 81 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.970
# EPISODE: 82 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.866
# EPISODE: 83 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.813
# EPISODE: 84 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.103
# EPISODE: 85 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.866
# EPISODE: 86 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.988
# EPISODE: 87 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.798
# EPISODE: 88 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.973
# EPISODE: 89 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.952
# Updating target network...
# EPISODE: 90 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.006
# EPISODE: 91 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.069
# EPISODE: 92 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.956
# EPISODE: 93 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.871
# EPISODE: 94 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.015
# EPISODE: 95 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.085
# EPISODE: 96 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.107
# EPISODE: 97 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.069
# EPISODE: 98 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.025
# EPISODE: 99 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.904
# Updating target network...
# EPISODE: 100 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.774
# EPISODE: 101 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.093
# EPISODE: 102 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.905
# EPISODE: 103 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.112
# EPISODE: 104 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.797
# EPISODE: 105 - FINAL SCORE: -399.0; desired torque=-1.0, actual torque=-0.990
# EPISODE: 106 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.013
# EPISODE: 107 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.892
# EPISODE: 108 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.881
# EPISODE: 109 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.957
# Updating target network...
# EPISODE: 110 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.068
# EPISODE: 111 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.005
# EPISODE: 112 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.974
# EPISODE: 113 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.017
# EPISODE: 114 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.978
# EPISODE: 115 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.890
# EPISODE: 116 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.795
# EPISODE: 117 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.899
# EPISODE: 118 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.793
# EPISODE: 119 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.003
# Updating target network...
# EPISODE: 120 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.107
# EPISODE: 121 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.085
# EPISODE: 122 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.800
# EPISODE: 123 - FINAL SCORE: -275.0; desired torque=-1.0, actual torque=-0.793
# EPISODE: 124 - FINAL SCORE: -445.0; desired torque=-1.0, actual torque=-0.887
# EPISODE: 125 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.961
# EPISODE: 126 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.863
# EPISODE: 127 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.084
# EPISODE: 128 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.019
# EPISODE: 129 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.072
# Updating target network...
# EPISODE: 130 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.907
# EPISODE: 131 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.092
# EPISODE: 132 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.993
# EPISODE: 133 - FINAL SCORE: -456.0; desired torque=0.0, actual torque=0.108
# EPISODE: 134 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.993
# EPISODE: 135 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.006
# EPISODE: 136 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.976
# EPISODE: 137 - FINAL SCORE: -299.0; desired torque=1.0, actual torque=0.961
# EPISODE: 138 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.890
# EPISODE: 139 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.006
# Updating target network...
# EPISODE: 140 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.957
# EPISODE: 141 - FINAL SCORE: -471.0; desired torque=-1.0, actual torque=-0.871
# EPISODE: 142 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.025
# EPISODE: 143 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.069
# EPISODE: 144 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.956
# EPISODE: 145 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.798
# EPISODE: 146 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.823
# EPISODE: 147 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.980
# EPISODE: 148 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.999
# EPISODE: 149 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.092
# Updating target network...
# EPISODE: 150 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.988
# EPISODE: 151 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.817
# EPISODE: 152 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=1.000
# EPISODE: 153 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.797
# EPISODE: 154 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.804
# EPISODE: 155 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.075
# EPISODE: 156 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.016
# EPISODE: 157 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.981
# EPISODE: 158 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.075
# EPISODE: 159 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.862
# Updating target network...
# EPISODE: 160 - FINAL SCORE: -421.0; desired torque=1.0, actual torque=0.810
# EPISODE: 161 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.013
# EPISODE: 162 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.988
# EPISODE: 163 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.023
# EPISODE: 164 - FINAL SCORE: -497.0; desired torque=-1.0, actual torque=-0.775
# EPISODE: 165 - FINAL SCORE: -283.0; desired torque=0.0, actual torque=-0.000
# EPISODE: 166 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.881
# EPISODE: 167 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.872
# EPISODE: 168 - FINAL SCORE: -486.0; desired torque=0.0, actual torque=-0.083
# EPISODE: 169 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.092
# Updating target network...
# EPISODE: 170 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.102
# EPISODE: 171 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.998
# EPISODE: 172 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.023
# EPISODE: 173 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.113
# EPISODE: 174 - FINAL SCORE: -328.0; desired torque=0.0, actual torque=-0.066
# EPISODE: 175 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.107
# EPISODE: 176 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.970
# EPISODE: 177 - FINAL SCORE: -473.0; desired torque=-1.0, actual torque=-0.954
# EPISODE: 178 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.773
# EPISODE: 179 - FINAL SCORE: -287.0; desired torque=-1.0, actual torque=-0.949
# Updating target network...
# EPISODE: 180 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.088
# EPISODE: 181 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.973
# EPISODE: 182 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.951
# EPISODE: 183 - FINAL SCORE: -272.0; desired torque=0.0, actual torque=0.090
# EPISODE: 184 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.817
# EPISODE: 185 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.899
# EPISODE: 186 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.069
# EPISODE: 187 - FINAL SCORE: -488.0; desired torque=1.0, actual torque=0.776
# EPISODE: 188 - FINAL SCORE: -445.0; desired torque=0.0, actual torque=-0.070
# EPISODE: 189 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.812
# Updating target network...
# EPISODE: 190 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.974
# EPISODE: 191 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.104
# EPISODE: 192 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.065
# EPISODE: 193 - FINAL SCORE: -345.0; desired torque=0.0, actual torque=0.025
# EPISODE: 194 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.886
# EPISODE: 195 - FINAL SCORE: -480.0; desired torque=1.0, actual torque=0.955
# EPISODE: 196 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=1.309
# EPISODE: 197 - FINAL SCORE: -401.0; desired torque=0.0, actual torque=-0.102
# EPISODE: 198 - FINAL SCORE: -468.0; desired torque=1.0, actual torque=0.999
# EPISODE: 199 - FINAL SCORE: -316.0; desired torque=-1.0, actual torque=-0.786
# Updating target network...
# EPISODE: 200 - FINAL SCORE: -243.0; desired torque=1.0, actual torque=0.974
# EPISODE: 201 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.785
# EPISODE: 202 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.817
# EPISODE: 203 - FINAL SCORE: -484.0; desired torque=1.0, actual torque=0.973
# EPISODE: 204 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.910
# EPISODE: 205 - FINAL SCORE: -462.0; desired torque=1.0, actual torque=0.797
# EPISODE: 206 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.075
# EPISODE: 207 - FINAL SCORE: -455.0; desired torque=1.0, actual torque=1.000
# EPISODE: 208 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.025
# EPISODE: 209 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.024
# Updating target network...
# EPISODE: 210 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.994
# EPISODE: 211 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.995
# EPISODE: 212 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.193
# EPISODE: 213 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=1.000
# EPISODE: 214 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.016
# EPISODE: 215 - FINAL SCORE: -477.0; desired torque=1.0, actual torque=0.866
# EPISODE: 216 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.778
# EPISODE: 217 - FINAL SCORE: -467.0; desired torque=0.0, actual torque=0.006
# EPISODE: 218 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.774
# EPISODE: 219 - FINAL SCORE: -414.0; desired torque=0.0, actual torque=0.091
# Updating target network...
# EPISODE: 220 - FINAL SCORE: -474.0; desired torque=1.0, actual torque=0.872
# EPISODE: 221 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.981
# EPISODE: 222 - FINAL SCORE: -295.0; desired torque=0.0, actual torque=-0.093
# EPISODE: 223 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.109
# EPISODE: 224 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.063
# EPISODE: 225 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.082
# EPISODE: 226 - FINAL SCORE: -244.0; desired torque=-1.0, actual torque=-0.971
# EPISODE: 227 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.892
# EPISODE: 228 - FINAL SCORE: -345.0; desired torque=-1.0, actual torque=-0.779
# EPISODE: 229 - FINAL SCORE: -374.0; desired torque=0.0, actual torque=-0.111
# Updating target network...
# EPISODE: 230 - FINAL SCORE: -365.0; desired torque=1.0, actual torque=0.804
# EPISODE: 231 - FINAL SCORE: -252.0; desired torque=1.0, actual torque=0.824
# EPISODE: 232 - FINAL SCORE: -397.0; desired torque=1.0, actual torque=0.824
# EPISODE: 233 - FINAL SCORE: -344.0; desired torque=-1.0, actual torque=-0.999
# EPISODE: 234 - FINAL SCORE: -255.0; desired torque=0.0, actual torque=-0.018
# EPISODE: 235 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.774
# EPISODE: 236 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=1.000
# EPISODE: 237 - FINAL SCORE: -420.0; desired torque=-1.0, actual torque=-0.952
# EPISODE: 238 - FINAL SCORE: -464.0; desired torque=1.0, actual torque=0.981
# EPISODE: 239 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.997
# Updating target network...
# EPISODE: 240 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.899
# EPISODE: 241 - FINAL SCORE: -375.0; desired torque=-1.0, actual torque=-0.970
# EPISODE: 242 - FINAL SCORE: -475.0; desired torque=1.0, actual torque=1.000
# EPISODE: 243 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.979
# EPISODE: 244 - FINAL SCORE: -465.0; desired torque=1.0, actual torque=0.950
# EPISODE: 245 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.013
# EPISODE: 246 - FINAL SCORE: -373.0; desired torque=0.0, actual torque=-0.024
# EPISODE: 247 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.995
# EPISODE: 248 - FINAL SCORE: -347.0; desired torque=-1.0, actual torque=-0.987
# EPISODE: 249 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.970
# Updating target network...
# EPISODE: 250 - FINAL SCORE: -338.0; desired torque=0.0, actual torque=-0.113
# EPISODE: 251 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.088
# EPISODE: 252 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.092
# EPISODE: 253 - FINAL SCORE: -409.0; desired torque=-1.0, actual torque=-0.968
# EPISODE: 254 - FINAL SCORE: -453.0; desired torque=0.0, actual torque=0.075
# EPISODE: 255 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.064
# EPISODE: 256 - FINAL SCORE: -445.0; desired torque=0.0, actual torque=-0.108
# EPISODE: 257 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.074
# EPISODE: 258 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-1.054
# EPISODE: 259 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.102
# Updating target network...
# EPISODE: 260 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.112
# EPISODE: 261 - FINAL SCORE: -500.0; desired torque=1.0, actual torque=0.970
# EPISODE: 262 - FINAL SCORE: -337.0; desired torque=1.0, actual torque=0.998
# EPISODE: 263 - FINAL SCORE: -314.0; desired torque=0.0, actual torque=0.006
# EPISODE: 264 - FINAL SCORE: -379.0; desired torque=1.0, actual torque=0.956
# EPISODE: 265 - FINAL SCORE: -372.0; desired torque=0.0, actual torque=-0.114
# EPISODE: 266 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.643
# EPISODE: 267 - FINAL SCORE: -422.0; desired torque=1.0, actual torque=1.000
# EPISODE: 268 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.975
# EPISODE: 269 - FINAL SCORE: -249.0; desired torque=1.0, actual torque=0.893
# Updating target network...
# EPISODE: 270 - FINAL SCORE: -268.0; desired torque=1.0, actual torque=1.015
# EPISODE: 271 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.909
# EPISODE: 272 - FINAL SCORE: -392.0; desired torque=0.0, actual torque=-0.019
# EPISODE: 273 - FINAL SCORE: -437.0; desired torque=1.0, actual torque=1.006
# EPISODE: 274 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.961
# EPISODE: 275 - FINAL SCORE: -288.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 276 - FINAL SCORE: -346.0; desired torque=-1.0, actual torque=-1.011
# EPISODE: 277 - FINAL SCORE: -317.0; desired torque=1.0, actual torque=0.805
# EPISODE: 278 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.974
# EPISODE: 279 - FINAL SCORE: -268.0; desired torque=-1.0, actual torque=-1.014
# Updating target network...
# EPISODE: 280 - FINAL SCORE: -304.0; desired torque=0.0, actual torque=-0.023
# EPISODE: 281 - FINAL SCORE: -277.0; desired torque=0.0, actual torque=-0.019
# EPISODE: 282 - FINAL SCORE: -213.0; desired torque=0.0, actual torque=-0.106
# EPISODE: 283 - FINAL SCORE: -330.0; desired torque=-1.0, actual torque=-0.973
# EPISODE: 284 - FINAL SCORE: -470.0; desired torque=0.0, actual torque=-0.000
# EPISODE: 285 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.797
# EPISODE: 286 - FINAL SCORE: -416.0; desired torque=0.0, actual torque=-0.088
# EPISODE: 287 - FINAL SCORE: -310.0; desired torque=1.0, actual torque=0.829
# EPISODE: 288 - FINAL SCORE: -449.0; desired torque=-1.0, actual torque=-0.780
# EPISODE: 289 - FINAL SCORE: -246.0; desired torque=-1.0, actual torque=-0.988
# Updating target network...
# EPISODE: 290 - FINAL SCORE: -190.0; desired torque=1.0, actual torque=0.894
# EPISODE: 291 - FINAL SCORE: -320.0; desired torque=-1.0, actual torque=-0.912
# EPISODE: 292 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.093
# EPISODE: 293 - FINAL SCORE: -199.0; desired torque=-1.0, actual torque=-1.001
# EPISODE: 294 - FINAL SCORE: -345.0; desired torque=1.0, actual torque=0.882
# EPISODE: 295 - FINAL SCORE: -255.0; desired torque=-1.0, actual torque=-0.909
# EPISODE: 296 - FINAL SCORE: -302.0; desired torque=1.0, actual torque=0.975
# EPISODE: 297 - FINAL SCORE: -283.0; desired torque=1.0, actual torque=0.894
# EPISODE: 298 - FINAL SCORE: -488.0; desired torque=-1.0, actual torque=-1.022
# EPISODE: 299 - FINAL SCORE: -401.0; desired torque=-1.0, actual torque=-1.000
# Updating target network...
# EPISODE: 300 - FINAL SCORE: -392.0; desired torque=0.0, actual torque=-0.101
# EPISODE: 301 - FINAL SCORE: -467.0; desired torque=0.0, actual torque=0.025
# EPISODE: 302 - FINAL SCORE: -346.0; desired torque=1.0, actual torque=0.893
# EPISODE: 303 - FINAL SCORE: -443.0; desired torque=0.0, actual torque=0.006
# EPISODE: 304 - FINAL SCORE: -221.0; desired torque=0.0, actual torque=-0.063
# EPISODE: 305 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.905
# EPISODE: 306 - FINAL SCORE: -361.0; desired torque=-1.0, actual torque=-0.950
# EPISODE: 307 - FINAL SCORE: -367.0; desired torque=1.0, actual torque=0.915
# EPISODE: 308 - FINAL SCORE: -232.0; desired torque=-1.0, actual torque=-1.002
# EPISODE: 309 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=0.299
# Updating target network...
# EPISODE: 310 - FINAL SCORE: -425.0; desired torque=-1.0, actual torque=-0.886
# EPISODE: 311 - FINAL SCORE: -208.0; desired torque=1.0, actual torque=0.773
# EPISODE: 312 - FINAL SCORE: -283.0; desired torque=-1.0, actual torque=-1.008
# EPISODE: 313 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.106
# EPISODE: 314 - FINAL SCORE: -279.0; desired torque=0.0, actual torque=-0.019
# EPISODE: 315 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 316 - FINAL SCORE: -335.0; desired torque=-1.0, actual torque=-0.880
# EPISODE: 317 - FINAL SCORE: -304.0; desired torque=-1.0, actual torque=-1.008
# EPISODE: 318 - FINAL SCORE: -379.0; desired torque=0.0, actual torque=-0.106
# EPISODE: 319 - FINAL SCORE: -376.0; desired torque=-1.0, actual torque=-0.899
# Updating target network...
# EPISODE: 320 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.069
# EPISODE: 321 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 322 - FINAL SCORE: -294.0; desired torque=0.0, actual torque=-0.091
# EPISODE: 323 - FINAL SCORE: -340.0; desired torque=0.0, actual torque=-0.013
# EPISODE: 324 - FINAL SCORE: -491.0; desired torque=1.0, actual torque=0.998
# EPISODE: 325 - FINAL SCORE: -394.0; desired torque=0.0, actual torque=0.002
# EPISODE: 326 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-1.390
# EPISODE: 327 - FINAL SCORE: -221.0; desired torque=0.0, actual torque=-0.087
# EPISODE: 328 - FINAL SCORE: -342.0; desired torque=1.0, actual torque=1.067
# EPISODE: 329 - FINAL SCORE: -320.0; desired torque=1.0, actual torque=0.976
# Updating target network...
# EPISODE: 330 - FINAL SCORE: -344.0; desired torque=1.0, actual torque=0.969
# EPISODE: 331 - FINAL SCORE: -383.0; desired torque=-1.0, actual torque=-0.817
# EPISODE: 332 - FINAL SCORE: -216.0; desired torque=0.0, actual torque=-0.003
# EPISODE: 333 - FINAL SCORE: -169.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 334 - FINAL SCORE: -250.0; desired torque=1.0, actual torque=0.822
# EPISODE: 335 - FINAL SCORE: -218.0; desired torque=-1.0, actual torque=-0.952
# EPISODE: 336 - FINAL SCORE: -156.0; desired torque=1.0, actual torque=0.786
# EPISODE: 337 - FINAL SCORE: -247.0; desired torque=-1.0, actual torque=-0.988
# EPISODE: 338 - FINAL SCORE: -363.0; desired torque=-1.0, actual torque=-0.774
# EPISODE: 339 - FINAL SCORE: -195.0; desired torque=1.0, actual torque=1.008
# Updating target network...
# EPISODE: 340 - FINAL SCORE: -145.0; desired torque=1.0, actual torque=1.015
# EPISODE: 341 - FINAL SCORE: -254.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 342 - FINAL SCORE: -219.0; desired torque=1.0, actual torque=1.000
# EPISODE: 343 - FINAL SCORE: -261.0; desired torque=-1.0, actual torque=-0.961
# EPISODE: 344 - FINAL SCORE: -169.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 345 - FINAL SCORE: -162.0; desired torque=1.0, actual torque=1.024
# EPISODE: 346 - FINAL SCORE: -315.0; desired torque=-1.0, actual torque=-0.994
# EPISODE: 347 - FINAL SCORE: -250.0; desired torque=1.0, actual torque=0.773
# EPISODE: 348 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=0.427
# EPISODE: 349 - FINAL SCORE: -241.0; desired torque=1.0, actual torque=0.773
# Updating target network...
# EPISODE: 350 - FINAL SCORE: -406.0; desired torque=-1.0, actual torque=-0.886
# EPISODE: 351 - FINAL SCORE: -168.0; desired torque=1.0, actual torque=0.772
# EPISODE: 352 - FINAL SCORE: -294.0; desired torque=0.0, actual torque=-0.025
# EPISODE: 353 - FINAL SCORE: -161.0; desired torque=1.0, actual torque=0.773
# EPISODE: 354 - FINAL SCORE: -244.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 355 - FINAL SCORE: -147.0; desired torque=-1.0, actual torque=-0.998
# EPISODE: 356 - FINAL SCORE: -167.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 357 - FINAL SCORE: -402.0; desired torque=-1.0, actual torque=-0.988
# EPISODE: 358 - FINAL SCORE: -407.0; desired torque=0.0, actual torque=0.427
# EPISODE: 359 - FINAL SCORE: -219.0; desired torque=1.0, actual torque=1.004
# Updating target network...
# EPISODE: 360 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=2.158
# EPISODE: 361 - FINAL SCORE: -255.0; desired torque=-1.0, actual torque=-0.886
# EPISODE: 362 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=2.158
# EPISODE: 363 - FINAL SCORE: -248.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 364 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.512
# EPISODE: 365 - FINAL SCORE: -220.0; desired torque=-1.0, actual torque=-0.989
# EPISODE: 366 - FINAL SCORE: -287.0; desired torque=-1.0, actual torque=-0.973
# EPISODE: 367 - FINAL SCORE: -215.0; desired torque=-1.0, actual torque=-0.951
# EPISODE: 368 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-2.042
# EPISODE: 369 - FINAL SCORE: -408.0; desired torque=1.0, actual torque=0.824
# Updating target network...
# EPISODE: 370 - FINAL SCORE: -178.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 371 - FINAL SCORE: -233.0; desired torque=0.0, actual torque=-0.013
# EPISODE: 372 - FINAL SCORE: -164.0; desired torque=1.0, actual torque=1.000
# EPISODE: 373 - FINAL SCORE: -271.0; desired torque=1.0, actual torque=0.831
# EPISODE: 374 - FINAL SCORE: -229.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 375 - FINAL SCORE: -180.0; desired torque=-1.0, actual torque=-0.987
# EPISODE: 376 - FINAL SCORE: -158.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 377 - FINAL SCORE: -186.0; desired torque=-1.0, actual torque=-1.061
# EPISODE: 378 - FINAL SCORE: -174.0; desired torque=0.0, actual torque=-0.003
# EPISODE: 379 - FINAL SCORE: -167.0; desired torque=1.0, actual torque=0.975
# Updating target network...
# EPISODE: 380 - FINAL SCORE: -128.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 381 - FINAL SCORE: -159.0; desired torque=1.0, actual torque=0.975
# EPISODE: 382 - FINAL SCORE: -280.0; desired torque=0.0, actual torque=-0.113
# EPISODE: 383 - FINAL SCORE: -248.0; desired torque=0.0, actual torque=0.002
# EPISODE: 384 - FINAL SCORE: -283.0; desired torque=-1.0, actual torque=-1.003
# EPISODE: 385 - FINAL SCORE: -186.0; desired torque=1.0, actual torque=0.962
# EPISODE: 386 - FINAL SCORE: -192.0; desired torque=0.0, actual torque=-0.013
# EPISODE: 387 - FINAL SCORE: -181.0; desired torque=-1.0, actual torque=-0.817
# EPISODE: 388 - FINAL SCORE: -296.0; desired torque=-1.0, actual torque=-0.997
# EPISODE: 389 - FINAL SCORE: -182.0; desired torque=0.0, actual torque=0.002
# Updating target network...
# EPISODE: 390 - FINAL SCORE: -284.0; desired torque=1.0, actual torque=0.773
# EPISODE: 391 - FINAL SCORE: -231.0; desired torque=0.0, actual torque=0.025
# EPISODE: 392 - FINAL SCORE: -214.0; desired torque=0.0, actual torque=-0.025
# EPISODE: 393 - FINAL SCORE: -188.0; desired torque=1.0, actual torque=1.063
# EPISODE: 394 - FINAL SCORE: -352.0; desired torque=0.0, actual torque=0.265
# EPISODE: 395 - FINAL SCORE: -158.0; desired torque=1.0, actual torque=1.029
# EPISODE: 396 - FINAL SCORE: -181.0; desired torque=-1.0, actual torque=-0.973
# EPISODE: 397 - FINAL SCORE: -139.0; desired torque=-1.0, actual torque=-0.997
# EPISODE: 398 - FINAL SCORE: -130.0; desired torque=1.0, actual torque=1.000
# EPISODE: 399 - FINAL SCORE: -137.0; desired torque=-1.0, actual torque=-0.775
# Updating target network...
# EPISODE: 400 - FINAL SCORE: -179.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 401 - FINAL SCORE: -212.0; desired torque=-1.0, actual torque=-0.949
# EPISODE: 402 - FINAL SCORE: -163.0; desired torque=-1.0, actual torque=-0.993
# EPISODE: 403 - FINAL SCORE: -224.0; desired torque=1.0, actual torque=1.000
# EPISODE: 404 - FINAL SCORE: -188.0; desired torque=-1.0, actual torque=-0.950
# EPISODE: 405 - FINAL SCORE: -131.0; desired torque=1.0, actual torque=0.771
# EPISODE: 406 - FINAL SCORE: -322.0; desired torque=1.0, actual torque=1.000
# EPISODE: 407 - FINAL SCORE: -183.0; desired torque=-1.0, actual torque=-1.010
# EPISODE: 408 - FINAL SCORE: -113.0; desired torque=-1.0, actual torque=-0.952
# EPISODE: 409 - FINAL SCORE: -182.0; desired torque=1.0, actual torque=0.994
# Updating target network...
# EPISODE: 410 - FINAL SCORE: -185.0; desired torque=-1.0, actual torque=-0.987
# EPISODE: 411 - FINAL SCORE: -129.0; desired torque=-1.0, actual torque=-0.773
# EPISODE: 412 - FINAL SCORE: -139.0; desired torque=-1.0, actual torque=-0.998
# EPISODE: 413 - FINAL SCORE: -182.0; desired torque=-1.0, actual torque=-0.817
# EPISODE: 414 - FINAL SCORE: -114.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 415 - FINAL SCORE: -135.0; desired torque=-1.0, actual torque=-0.951
# EPISODE: 416 - FINAL SCORE: -110.0; desired torque=-1.0, actual torque=-0.949
# EPISODE: 417 - FINAL SCORE: -113.0; desired torque=-1.0, actual torque=-0.960
# EPISODE: 418 - FINAL SCORE: -167.0; desired torque=-1.0, actual torque=-0.817
# EPISODE: 419 - FINAL SCORE: -145.0; desired torque=-1.0, actual torque=-0.998
# Updating target network...
# EPISODE: 420 - FINAL SCORE: -130.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 421 - FINAL SCORE: -143.0; desired torque=-1.0, actual torque=-0.949
# EPISODE: 422 - FINAL SCORE: -160.0; desired torque=-1.0, actual torque=-0.997
# EPISODE: 423 - FINAL SCORE: -133.0; desired torque=-1.0, actual torque=-0.997
# EPISODE: 424 - FINAL SCORE: -132.0; desired torque=-1.0, actual torque=-0.999
# EPISODE: 425 - FINAL SCORE: -140.0; desired torque=1.0, actual torque=0.773
# EPISODE: 426 - FINAL SCORE: -389.0; desired torque=0.0, actual torque=-0.113
# EPISODE: 427 - FINAL SCORE: -137.0; desired torque=-1.0, actual torque=-0.993
# EPISODE: 428 - FINAL SCORE: -184.0; desired torque=-1.0, actual torque=-0.978
# EPISODE: 429 - FINAL SCORE: -153.0; desired torque=1.0, actual torque=0.962
# Updating target network...
# EPISODE: 430 - FINAL SCORE: -193.0; desired torque=1.0, actual torque=0.989
# EPISODE: 431 - FINAL SCORE: -99.0; desired torque=-1.0, actual torque=-0.971
# EPISODE: 432 - FINAL SCORE: -113.0; desired torque=-1.0, actual torque=-0.813
# EPISODE: 433 - FINAL SCORE: -139.0; desired torque=1.0, actual torque=0.861
# EPISODE: 434 - FINAL SCORE: -181.0; desired torque=-1.0, actual torque=-0.968
# EPISODE: 435 - FINAL SCORE: -122.0; desired torque=1.0, actual torque=0.861
# EPISODE: 436 - FINAL SCORE: -133.0; desired torque=1.0, actual torque=1.000
# EPISODE: 437 - FINAL SCORE: -131.0; desired torque=-1.0, actual torque=-1.002
# EPISODE: 438 - FINAL SCORE: -105.0; desired torque=1.0, actual torque=1.000
# EPISODE: 439 - FINAL SCORE: -143.0; desired torque=1.0, actual torque=0.999
# Updating target network...
# EPISODE: 440 - FINAL SCORE: -128.0; desired torque=1.0, actual torque=0.999
# EPISODE: 441 - FINAL SCORE: -119.0; desired torque=-1.0, actual torque=-0.961
# EPISODE: 442 - FINAL SCORE: -99.0; desired torque=0.0, actual torque=-0.113
# EPISODE: 443 - FINAL SCORE: -109.0; desired torque=-1.0, actual torque=-0.773
# EPISODE: 444 - FINAL SCORE: -89.0; desired torque=-1.0, actual torque=-0.968
# EPISODE: 445 - FINAL SCORE: -132.0; desired torque=1.0, actual torque=0.955
# EPISODE: 446 - FINAL SCORE: -90.0; desired torque=1.0, actual torque=0.773
# EPISODE: 447 - FINAL SCORE: -123.0; desired torque=0.0, actual torque=0.105
# EPISODE: 448 - FINAL SCORE: -139.0; desired torque=1.0, actual torque=1.032
# EPISODE: 449 - FINAL SCORE: -127.0; desired torque=-1.0, actual torque=-1.008
# Updating target network...
# EPISODE: 450 - FINAL SCORE: -127.0; desired torque=-1.0, actual torque=-0.993
# EPISODE: 451 - FINAL SCORE: -96.0; desired torque=-1.0, actual torque=-0.949
# EPISODE: 452 - FINAL SCORE: -109.0; desired torque=1.0, actual torque=1.000
# EPISODE: 453 - FINAL SCORE: -139.0; desired torque=0.0, actual torque=-0.025
# EPISODE: 454 - FINAL SCORE: -147.0; desired torque=1.0, actual torque=1.022
# EPISODE: 455 - FINAL SCORE: -112.0; desired torque=-1.0, actual torque=-0.999
# EPISODE: 456 - FINAL SCORE: -82.0; desired torque=1.0, actual torque=1.000
# EPISODE: 457 - FINAL SCORE: -84.0; desired torque=-1.0, actual torque=-0.998
# EPISODE: 458 - FINAL SCORE: -106.0; desired torque=0.0, actual torque=-0.023
# EPISODE: 459 - FINAL SCORE: -125.0; desired torque=0.0, actual torque=0.639
# Updating target network...
# EPISODE: 460 - FINAL SCORE: -134.0; desired torque=-1.0, actual torque=-0.992
# EPISODE: 461 - FINAL SCORE: -89.0; desired torque=-1.0, actual torque=-0.817
# EPISODE: 462 - FINAL SCORE: -123.0; desired torque=-1.0, actual torque=-1.692
# EPISODE: 463 - FINAL SCORE: -108.0; desired torque=1.0, actual torque=1.003
# EPISODE: 464 - FINAL SCORE: -152.0; desired torque=-1.0, actual torque=-0.989
# EPISODE: 465 - FINAL SCORE: -100.0; desired torque=1.0, actual torque=1.000
# EPISODE: 466 - FINAL SCORE: -110.0; desired torque=-1.0, actual torque=-1.002
# EPISODE: 467 - FINAL SCORE: -129.0; desired torque=-1.0, actual torque=-1.020
# EPISODE: 468 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-0.651
# EPISODE: 469 - FINAL SCORE: -85.0; desired torque=1.0, actual torque=0.863
# Updating target network...
# EPISODE: 470 - FINAL SCORE: -121.0; desired torque=-1.0, actual torque=-0.994
# EPISODE: 471 - FINAL SCORE: -123.0; desired torque=-1.0, actual torque=-0.997
# EPISODE: 472 - FINAL SCORE: -130.0; desired torque=1.0, actual torque=0.999
# EPISODE: 473 - FINAL SCORE: -160.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 474 - FINAL SCORE: -101.0; desired torque=1.0, actual torque=0.967
# EPISODE: 475 - FINAL SCORE: -126.0; desired torque=-1.0, actual torque=-0.773
# EPISODE: 476 - FINAL SCORE: -118.0; desired torque=-1.0, actual torque=-0.987
# EPISODE: 477 - FINAL SCORE: -111.0; desired torque=-1.0, actual torque=-0.951
# EPISODE: 478 - FINAL SCORE: -142.0; desired torque=-1.0, actual torque=-1.018
# EPISODE: 479 - FINAL SCORE: -128.0; desired torque=1.0, actual torque=1.000
# Updating target network...
# EPISODE: 480 - FINAL SCORE: -184.0; desired torque=-1.0, actual torque=-0.992
# EPISODE: 481 - FINAL SCORE: -85.0; desired torque=-1.0, actual torque=-0.992
# EPISODE: 482 - FINAL SCORE: -125.0; desired torque=0.0, actual torque=-0.113
# EPISODE: 483 - FINAL SCORE: -128.0; desired torque=1.0, actual torque=0.998
# EPISODE: 484 - FINAL SCORE: -147.0; desired torque=-1.0, actual torque=-0.816
# EPISODE: 485 - FINAL SCORE: -95.0; desired torque=-1.0, actual torque=-0.784
# EPISODE: 486 - FINAL SCORE: -134.0; desired torque=-1.0, actual torque=-0.968
# EPISODE: 487 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=-2.766
# EPISODE: 488 - FINAL SCORE: -160.0; desired torque=1.0, actual torque=1.000
# EPISODE: 489 - FINAL SCORE: -139.0; desired torque=-1.0, actual torque=-1.000
# Updating target network...
# EPISODE: 490 - FINAL SCORE: -122.0; desired torque=1.0, actual torque=0.772
# EPISODE: 491 - FINAL SCORE: -188.0; desired torque=1.0, actual torque=1.000
# EPISODE: 492 - FINAL SCORE: -112.0; desired torque=-1.0, actual torque=-0.885
# EPISODE: 493 - FINAL SCORE: -107.0; desired torque=0.0, actual torque=-0.002
# EPISODE: 494 - FINAL SCORE: -137.0; desired torque=0.0, actual torque=-0.114
# EPISODE: 495 - FINAL SCORE: -119.0; desired torque=-1.0, actual torque=-0.912
# EPISODE: 496 - FINAL SCORE: -126.0; desired torque=-1.0, actual torque=-0.993
# EPISODE: 497 - FINAL SCORE: -100.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 498 - FINAL SCORE: -90.0; desired torque=-1.0, actual torque=-0.954
# EPISODE: 499 - FINAL SCORE: -102.0; desired torque=1.0, actual torque=1.000
# Updating target network...
# EPISODE: 500 - FINAL SCORE: -173.0; desired torque=0.0, actual torque=-0.113
# EPISODE: 501 - FINAL SCORE: -153.0; desired torque=1.0, actual torque=0.977
# EPISODE: 502 - FINAL SCORE: -94.0; desired torque=1.0, actual torque=0.773
# EPISODE: 503 - FINAL SCORE: -101.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 504 - FINAL SCORE: -81.0; desired torque=1.0, actual torque=0.773
# EPISODE: 505 - FINAL SCORE: -103.0; desired torque=-1.0, actual torque=-0.769
# EPISODE: 506 - FINAL SCORE: -82.0; desired torque=1.0, actual torque=1.000
# EPISODE: 507 - FINAL SCORE: -93.0; desired torque=-1.0, actual torque=-0.937
# EPISODE: 508 - FINAL SCORE: -105.0; desired torque=0.0, actual torque=-0.165
# EPISODE: 509 - FINAL SCORE: -113.0; desired torque=1.0, actual torque=0.823
# Updating target network...
# EPISODE: 510 - FINAL SCORE: -92.0; desired torque=1.0, actual torque=1.003
# EPISODE: 511 - FINAL SCORE: -97.0; desired torque=1.0, actual torque=0.809
# EPISODE: 512 - FINAL SCORE: -95.0; desired torque=-1.0, actual torque=-0.949
# EPISODE: 513 - FINAL SCORE: -99.0; desired torque=-1.0, actual torque=-1.110
# EPISODE: 514 - FINAL SCORE: -113.0; desired torque=-1.0, actual torque=-0.952
# EPISODE: 515 - FINAL SCORE: -123.0; desired torque=-1.0, actual torque=-0.813
# EPISODE: 516 - FINAL SCORE: -167.0; desired torque=1.0, actual torque=1.000
# EPISODE: 517 - FINAL SCORE: -112.0; desired torque=1.0, actual torque=1.067
# EPISODE: 518 - FINAL SCORE: -102.0; desired torque=-1.0, actual torque=-0.993
# EPISODE: 519 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.971
# Updating target network...
# EPISODE: 520 - FINAL SCORE: -97.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 521 - FINAL SCORE: -106.0; desired torque=-1.0, actual torque=-0.961
# EPISODE: 522 - FINAL SCORE: -78.0; desired torque=-1.0, actual torque=-0.946
# EPISODE: 523 - FINAL SCORE: -83.0; desired torque=-1.0, actual torque=-0.961
# EPISODE: 524 - FINAL SCORE: -109.0; desired torque=-1.0, actual torque=-1.005
# EPISODE: 525 - FINAL SCORE: -89.0; desired torque=1.0, actual torque=0.861
# EPISODE: 526 - FINAL SCORE: -84.0; desired torque=-1.0, actual torque=-0.999
# EPISODE: 527 - FINAL SCORE: -90.0; desired torque=-1.0, actual torque=-0.949
# EPISODE: 528 - FINAL SCORE: -134.0; desired torque=0.0, actual torque=0.000
# EPISODE: 529 - FINAL SCORE: -76.0; desired torque=-1.0, actual torque=-0.994
# Updating target network...
# EPISODE: 530 - FINAL SCORE: -165.0; desired torque=1.0, actual torque=1.000
# EPISODE: 531 - FINAL SCORE: -130.0; desired torque=1.0, actual torque=0.999
# EPISODE: 532 - FINAL SCORE: -103.0; desired torque=-1.0, actual torque=-1.005
# EPISODE: 533 - FINAL SCORE: -105.0; desired torque=-1.0, actual torque=-0.992
# EPISODE: 534 - FINAL SCORE: -99.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 535 - FINAL SCORE: -103.0; desired torque=1.0, actual torque=0.861
# EPISODE: 536 - FINAL SCORE: -95.0; desired torque=1.0, actual torque=1.000
# EPISODE: 537 - FINAL SCORE: -90.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 538 - FINAL SCORE: -99.0; desired torque=1.0, actual torque=1.001
# EPISODE: 539 - FINAL SCORE: -105.0; desired torque=0.0, actual torque=0.104
# Updating target network...
# EPISODE: 540 - FINAL SCORE: -128.0; desired torque=1.0, actual torque=0.994
# EPISODE: 541 - FINAL SCORE: -88.0; desired torque=-1.0, actual torque=-0.988
# EPISODE: 542 - FINAL SCORE: -87.0; desired torque=0.0, actual torque=0.071
# EPISODE: 543 - FINAL SCORE: -71.0; desired torque=-1.0, actual torque=-0.949
# EPISODE: 544 - FINAL SCORE: -77.0; desired torque=-1.0, actual torque=-0.949
# EPISODE: 545 - FINAL SCORE: -76.0; desired torque=-1.0, actual torque=-0.947
# EPISODE: 546 - FINAL SCORE: -131.0; desired torque=0.0, actual torque=-0.025
# EPISODE: 547 - FINAL SCORE: -97.0; desired torque=1.0, actual torque=0.830
# EPISODE: 548 - FINAL SCORE: -119.0; desired torque=-1.0, actual torque=-0.992
# EPISODE: 549 - FINAL SCORE: -126.0; desired torque=-1.0, actual torque=-1.361
# Updating target network...
# EPISODE: 550 - FINAL SCORE: -94.0; desired torque=-1.0, actual torque=-0.776
# EPISODE: 551 - FINAL SCORE: -107.0; desired torque=1.0, actual torque=0.999
# EPISODE: 552 - FINAL SCORE: -83.0; desired torque=-1.0, actual torque=-0.948
# EPISODE: 553 - FINAL SCORE: -89.0; desired torque=1.0, actual torque=1.000
# EPISODE: 554 - FINAL SCORE: -116.0; desired torque=1.0, actual torque=0.956
# EPISODE: 555 - FINAL SCORE: -85.0; desired torque=-1.0, actual torque=-0.992
# EPISODE: 556 - FINAL SCORE: -102.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 557 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-1.739
# EPISODE: 558 - FINAL SCORE: -85.0; desired torque=-1.0, actual torque=-0.773
# EPISODE: 559 - FINAL SCORE: -86.0; desired torque=0.0, actual torque=0.002
# Updating target network...
# EPISODE: 560 - FINAL SCORE: -109.0; desired torque=1.0, actual torque=1.000
# EPISODE: 561 - FINAL SCORE: -92.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 562 - FINAL SCORE: -91.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 563 - FINAL SCORE: -105.0; desired torque=-1.0, actual torque=-0.999
# EPISODE: 564 - FINAL SCORE: -106.0; desired torque=-1.0, actual torque=-0.949
# EPISODE: 565 - FINAL SCORE: -116.0; desired torque=1.0, actual torque=0.773
# EPISODE: 566 - FINAL SCORE: -88.0; desired torque=1.0, actual torque=0.999
# EPISODE: 567 - FINAL SCORE: -82.0; desired torque=1.0, actual torque=0.949
# EPISODE: 568 - FINAL SCORE: -74.0; desired torque=1.0, actual torque=1.006
# EPISODE: 569 - FINAL SCORE: -117.0; desired torque=-1.0, actual torque=-1.000
# Updating target network...
# EPISODE: 570 - FINAL SCORE: -108.0; desired torque=-1.0, actual torque=-0.992
# EPISODE: 571 - FINAL SCORE: -70.0; desired torque=-1.0, actual torque=-0.769
# EPISODE: 572 - FINAL SCORE: -86.0; desired torque=1.0, actual torque=1.000
# EPISODE: 573 - FINAL SCORE: -98.0; desired torque=-1.0, actual torque=-0.997
# EPISODE: 574 - FINAL SCORE: -130.0; desired torque=1.0, actual torque=0.956
# EPISODE: 575 - FINAL SCORE: -75.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 576 - FINAL SCORE: -86.0; desired torque=-1.0, actual torque=-0.774
# EPISODE: 577 - FINAL SCORE: -76.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 578 - FINAL SCORE: -108.0; desired torque=-1.0, actual torque=-0.993
# EPISODE: 579 - FINAL SCORE: -88.0; desired torque=1.0, actual torque=1.000
# Updating target network...
# EPISODE: 580 - FINAL SCORE: -76.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 581 - FINAL SCORE: -97.0; desired torque=1.0, actual torque=1.000
# EPISODE: 582 - FINAL SCORE: -137.0; desired torque=1.0, actual torque=0.975
# EPISODE: 583 - FINAL SCORE: -88.0; desired torque=0.0, actual torque=0.006
# EPISODE: 584 - FINAL SCORE: -108.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 585 - FINAL SCORE: -145.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 586 - FINAL SCORE: -88.0; desired torque=-1.0, actual torque=-1.001
# EPISODE: 587 - FINAL SCORE: -81.0; desired torque=-1.0, actual torque=-0.992
# EPISODE: 588 - FINAL SCORE: -72.0; desired torque=1.0, actual torque=1.004
# EPISODE: 589 - FINAL SCORE: -118.0; desired torque=-1.0, actual torque=-1.008
# Updating target network...
# EPISODE: 590 - FINAL SCORE: -99.0; desired torque=-1.0, actual torque=-1.001
# EPISODE: 591 - FINAL SCORE: -95.0; desired torque=-1.0, actual torque=-0.950
# EPISODE: 592 - FINAL SCORE: -84.0; desired torque=1.0, actual torque=1.000
# EPISODE: 593 - FINAL SCORE: -102.0; desired torque=-1.0, actual torque=-0.909
# EPISODE: 594 - FINAL SCORE: -82.0; desired torque=-1.0, actual torque=-0.999
# EPISODE: 595 - FINAL SCORE: -64.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 596 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=1.277
# EPISODE: 597 - FINAL SCORE: -139.0; desired torque=-1.0, actual torque=-1.000
# ...
# EPISODE: 798 - FINAL SCORE: -72.0; desired torque=1.0, actual torque=1.000
# EPISODE: 799 - FINAL SCORE: -71.0; desired torque=1.0, actual torque=1.000
# Updating target network...
# EPISODE: 800 - FINAL SCORE: -83.0; desired torque=-1.0, actual torque=-0.824
# EPISODE: 801 - FINAL SCORE: -97.0; desired torque=-1.0, actual torque=-0.997
# EPISODE: 802 - FINAL SCORE: -94.0; desired torque=-1.0, actual torque=-0.776
# EPISODE: 803 - FINAL SCORE: -86.0; desired torque=1.0, actual torque=0.999
# EPISODE: 804 - FINAL SCORE: -98.0; desired torque=0.0, actual torque=-0.025
# EPISODE: 805 - FINAL SCORE: -104.0; desired torque=1.0, actual torque=1.142
# EPISODE: 806 - FINAL SCORE: -96.0; desired torque=-1.0, actual torque=-0.773
# EPISODE: 807 - FINAL SCORE: -91.0; desired torque=-1.0, actual torque=-1.077
# EPISODE: 808 - FINAL SCORE: -127.0; desired torque=-1.0, actual torque=-0.894
# EPISODE: 809 - FINAL SCORE: -93.0; desired torque=0.0, actual torque=-0.101
# Updating target network...
# EPISODE: 810 - FINAL SCORE: -71.0; desired torque=1.0, actual torque=1.000
# EPISODE: 811 - FINAL SCORE: -100.0; desired torque=1.0, actual torque=1.092
# EPISODE: 812 - FINAL SCORE: -87.0; desired torque=1.0, actual torque=0.821
# EPISODE: 813 - FINAL SCORE: -95.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 814 - FINAL SCORE: -80.0; desired torque=-1.0, actual torque=-0.968
# EPISODE: 815 - FINAL SCORE: -93.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 816 - FINAL SCORE: -143.0; desired torque=1.0, actual torque=0.960
# EPISODE: 817 - FINAL SCORE: -98.0; desired torque=1.0, actual torque=1.000
# EPISODE: 818 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-0.536
# EPISODE: 819 - FINAL SCORE: -85.0; desired torque=1.0, actual torque=1.014
# Updating target network...
# EPISODE: 820 - FINAL SCORE: -77.0; desired torque=-1.0, actual torque=-1.003
# EPISODE: 821 - FINAL SCORE: -71.0; desired torque=1.0, actual torque=1.005
# EPISODE: 822 - FINAL SCORE: -103.0; desired torque=1.0, actual torque=0.999
# EPISODE: 823 - FINAL SCORE: -101.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 824 - FINAL SCORE: -88.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 825 - FINAL SCORE: -91.0; desired torque=1.0, actual torque=0.974
# EPISODE: 826 - FINAL SCORE: -75.0; desired torque=1.0, actual torque=1.009
# EPISODE: 827 - FINAL SCORE: -91.0; desired torque=1.0, actual torque=1.000
# EPISODE: 828 - FINAL SCORE: -86.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 829 - FINAL SCORE: -74.0; desired torque=-1.0, actual torque=-0.999
# Updating target network...
# EPISODE: 830 - FINAL SCORE: -86.0; desired torque=-1.0, actual torque=-0.949
# EPISODE: 831 - FINAL SCORE: -89.0; desired torque=-1.0, actual torque=-0.990
# EPISODE: 832 - FINAL SCORE: -76.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 833 - FINAL SCORE: -97.0; desired torque=-1.0, actual torque=-1.391
# EPISODE: 834 - FINAL SCORE: -87.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 835 - FINAL SCORE: -90.0; desired torque=1.0, actual torque=1.516
# EPISODE: 836 - FINAL SCORE: -78.0; desired torque=-1.0, actual torque=-0.773
# EPISODE: 837 - FINAL SCORE: -83.0; desired torque=1.0, actual torque=1.000
# EPISODE: 838 - FINAL SCORE: -87.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 839 - FINAL SCORE: -92.0; desired torque=1.0, actual torque=1.000
# Updating target network...
# EPISODE: 840 - FINAL SCORE: -100.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 841 - FINAL SCORE: -70.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 842 - FINAL SCORE: -97.0; desired torque=-1.0, actual torque=-0.997
# EPISODE: 843 - FINAL SCORE: -127.0; desired torque=-1.0, actual torque=-0.959
# EPISODE: 844 - FINAL SCORE: -95.0; desired torque=1.0, actual torque=1.000
# EPISODE: 845 - FINAL SCORE: -95.0; desired torque=-1.0, actual torque=-1.010
# EPISODE: 846 - FINAL SCORE: -109.0; desired torque=1.0, actual torque=1.301
# EPISODE: 847 - FINAL SCORE: -92.0; desired torque=1.0, actual torque=1.313
# EPISODE: 848 - FINAL SCORE: -87.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 849 - FINAL SCORE: -77.0; desired torque=-1.0, actual torque=-0.974
# Updating target network...
# EPISODE: 850 - FINAL SCORE: -91.0; desired torque=-1.0, actual torque=-0.824
# EPISODE: 851 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=0.388
# EPISODE: 852 - FINAL SCORE: -80.0; desired torque=1.0, actual torque=0.999
# EPISODE: 853 - FINAL SCORE: -88.0; desired torque=1.0, actual torque=0.999
# EPISODE: 854 - FINAL SCORE: -93.0; desired torque=-1.0, actual torque=-0.949
# EPISODE: 855 - FINAL SCORE: -105.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 856 - FINAL SCORE: -87.0; desired torque=-1.0, actual torque=-1.030
# EPISODE: 857 - FINAL SCORE: -115.0; desired torque=-1.0, actual torque=-0.951
# EPISODE: 858 - FINAL SCORE: -77.0; desired torque=-1.0, actual torque=-0.773
# EPISODE: 859 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=1.254
# Updating target network...
# EPISODE: 860 - FINAL SCORE: -85.0; desired torque=-1.0, actual torque=-0.973
# EPISODE: 861 - FINAL SCORE: -93.0; desired torque=1.0, actual torque=1.000
# EPISODE: 862 - FINAL SCORE: -86.0; desired torque=-1.0, actual torque=-1.004
# EPISODE: 863 - FINAL SCORE: -71.0; desired torque=-1.0, actual torque=-1.003
# EPISODE: 864 - FINAL SCORE: -88.0; desired torque=-1.0, actual torque=-0.989
# EPISODE: 865 - FINAL SCORE: -72.0; desired torque=-1.0, actual torque=-0.961
# EPISODE: 866 - FINAL SCORE: -98.0; desired torque=1.0, actual torque=0.776
# EPISODE: 867 - FINAL SCORE: -80.0; desired torque=1.0, actual torque=0.773
# EPISODE: 868 - FINAL SCORE: -500.0; desired torque=-1.0, actual torque=3.246
# EPISODE: 869 - FINAL SCORE: -74.0; desired torque=-1.0, actual torque=-1.000
# Updating target network...
# EPISODE: 870 - FINAL SCORE: -69.0; desired torque=-1.0, actual torque=-0.998
# EPISODE: 871 - FINAL SCORE: -90.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 872 - FINAL SCORE: -70.0; desired torque=-1.0, actual torque=-0.998
# EPISODE: 873 - FINAL SCORE: -78.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 874 - FINAL SCORE: -72.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 875 - FINAL SCORE: -93.0; desired torque=1.0, actual torque=1.000
# EPISODE: 876 - FINAL SCORE: -69.0; desired torque=1.0, actual torque=0.773
# EPISODE: 877 - FINAL SCORE: -95.0; desired torque=-1.0, actual torque=-1.026
# EPISODE: 878 - FINAL SCORE: -96.0; desired torque=-1.0, actual torque=-1.187
# EPISODE: 879 - FINAL SCORE: -83.0; desired torque=1.0, actual torque=1.000
# Updating target network...
# EPISODE: 880 - FINAL SCORE: -106.0; desired torque=1.0, actual torque=0.975
# EPISODE: 881 - FINAL SCORE: -70.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 882 - FINAL SCORE: -98.0; desired torque=-1.0, actual torque=-0.997
# EPISODE: 883 - FINAL SCORE: -92.0; desired torque=1.0, actual torque=0.794
# EPISODE: 884 - FINAL SCORE: -63.0; desired torque=1.0, actual torque=0.773
# EPISODE: 885 - FINAL SCORE: -113.0; desired torque=0.0, actual torque=1.300
# EPISODE: 886 - FINAL SCORE: -75.0; desired torque=-1.0, actual torque=-1.005
# EPISODE: 887 - FINAL SCORE: -77.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 888 - FINAL SCORE: -134.0; desired torque=1.0, actual torque=0.990
# EPISODE: 889 - FINAL SCORE: -93.0; desired torque=1.0, actual torque=1.000
# Updating target network...
# EPISODE: 890 - FINAL SCORE: -87.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 891 - FINAL SCORE: -75.0; desired torque=1.0, actual torque=0.773
# EPISODE: 892 - FINAL SCORE: -71.0; desired torque=-1.0, actual torque=-0.999
# EPISODE: 893 - FINAL SCORE: -87.0; desired torque=1.0, actual torque=0.998
# EPISODE: 894 - FINAL SCORE: -90.0; desired torque=1.0, actual torque=0.973
# EPISODE: 895 - FINAL SCORE: -88.0; desired torque=1.0, actual torque=0.999
# EPISODE: 896 - FINAL SCORE: -73.0; desired torque=1.0, actual torque=1.002
# EPISODE: 897 - FINAL SCORE: -70.0; desired torque=-1.0, actual torque=-0.998
# EPISODE: 898 - FINAL SCORE: -96.0; desired torque=-1.0, actual torque=-0.973
# EPISODE: 899 - FINAL SCORE: -116.0; desired torque=-1.0, actual torque=-1.284
# Updating target network...
# EPISODE: 900 - FINAL SCORE: -75.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 901 - FINAL SCORE: -80.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 902 - FINAL SCORE: -78.0; desired torque=-1.0, actual torque=-0.798
# EPISODE: 903 - FINAL SCORE: -97.0; desired torque=1.0, actual torque=0.995
# EPISODE: 904 - FINAL SCORE: -103.0; desired torque=1.0, actual torque=1.438
# EPISODE: 905 - FINAL SCORE: -143.0; desired torque=-1.0, actual torque=-1.903
# EPISODE: 906 - FINAL SCORE: -78.0; desired torque=-1.0, actual torque=-0.824
# EPISODE: 907 - FINAL SCORE: -97.0; desired torque=1.0, actual torque=1.000
# EPISODE: 908 - FINAL SCORE: -63.0; desired torque=-1.0, actual torque=-0.798
# EPISODE: 909 - FINAL SCORE: -76.0; desired torque=-1.0, actual torque=-0.975
# Updating target network...
# EPISODE: 910 - FINAL SCORE: -80.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 911 - FINAL SCORE: -84.0; desired torque=-1.0, actual torque=-0.773
# EPISODE: 912 - FINAL SCORE: -63.0; desired torque=-1.0, actual torque=-0.999
# EPISODE: 913 - FINAL SCORE: -75.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 914 - FINAL SCORE: -70.0; desired torque=-1.0, actual torque=-0.998
# EPISODE: 915 - FINAL SCORE: -83.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 916 - FINAL SCORE: -91.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 917 - FINAL SCORE: -95.0; desired torque=1.0, actual torque=1.000
# EPISODE: 918 - FINAL SCORE: -97.0; desired torque=1.0, actual torque=1.000
# EPISODE: 919 - FINAL SCORE: -90.0; desired torque=-1.0, actual torque=-0.997
# Updating target network...
# EPISODE: 920 - FINAL SCORE: -96.0; desired torque=-1.0, actual torque=-1.401
# EPISODE: 921 - FINAL SCORE: -91.0; desired torque=1.0, actual torque=1.190
# EPISODE: 922 - FINAL SCORE: -81.0; desired torque=1.0, actual torque=1.000
# EPISODE: 923 - FINAL SCORE: -82.0; desired torque=1.0, actual torque=0.773
# EPISODE: 924 - FINAL SCORE: -64.0; desired torque=-1.0, actual torque=-0.999
# EPISODE: 925 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=-1.267
# EPISODE: 926 - FINAL SCORE: -89.0; desired torque=1.0, actual torque=0.821
# EPISODE: 927 - FINAL SCORE: -88.0; desired torque=1.0, actual torque=0.773
# EPISODE: 928 - FINAL SCORE: -92.0; desired torque=-1.0, actual torque=-0.773
# EPISODE: 929 - FINAL SCORE: -74.0; desired torque=-1.0, actual torque=-1.000
# Updating target network...
# EPISODE: 930 - FINAL SCORE: -74.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 931 - FINAL SCORE: -74.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 932 - FINAL SCORE: -77.0; desired torque=-1.0, actual torque=-0.975
# EPISODE: 933 - FINAL SCORE: -76.0; desired torque=1.0, actual torque=1.000
# EPISODE: 934 - FINAL SCORE: -86.0; desired torque=1.0, actual torque=0.992
# EPISODE: 935 - FINAL SCORE: -71.0; desired torque=-1.0, actual torque=-1.003
# EPISODE: 936 - FINAL SCORE: -99.0; desired torque=-1.0, actual torque=-1.550
# EPISODE: 937 - FINAL SCORE: -96.0; desired torque=-1.0, actual torque=-0.890
# EPISODE: 938 - FINAL SCORE: -100.0; desired torque=-1.0, actual torque=-0.892
# EPISODE: 939 - FINAL SCORE: -85.0; desired torque=1.0, actual torque=1.008
# Updating target network...
# EPISODE: 940 - FINAL SCORE: -62.0; desired torque=-1.0, actual torque=-0.798
# EPISODE: 941 - FINAL SCORE: -85.0; desired torque=1.0, actual torque=1.000
# EPISODE: 942 - FINAL SCORE: -95.0; desired torque=-1.0, actual torque=-1.528
# EPISODE: 943 - FINAL SCORE: -95.0; desired torque=1.0, actual torque=0.998
# EPISODE: 944 - FINAL SCORE: -92.0; desired torque=0.0, actual torque=-0.013
# EPISODE: 945 - FINAL SCORE: -87.0; desired torque=1.0, actual torque=0.988
# EPISODE: 946 - FINAL SCORE: -63.0; desired torque=-1.0, actual torque=-0.779
# EPISODE: 947 - FINAL SCORE: -70.0; desired torque=-1.0, actual torque=-0.998
# EPISODE: 948 - FINAL SCORE: -79.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 949 - FINAL SCORE: -69.0; desired torque=-1.0, actual torque=-0.999
# Updating target network...
# EPISODE: 950 - FINAL SCORE: -63.0; desired torque=-1.0, actual torque=-0.999
# EPISODE: 951 - FINAL SCORE: -92.0; desired torque=0.0, actual torque=0.339
# EPISODE: 952 - FINAL SCORE: -87.0; desired torque=1.0, actual torque=0.867
# EPISODE: 953 - FINAL SCORE: -500.0; desired torque=0.0, actual torque=2.047
# EPISODE: 954 - FINAL SCORE: -110.0; desired torque=1.0, actual torque=0.987
# EPISODE: 955 - FINAL SCORE: -74.0; desired torque=1.0, actual torque=1.000
# EPISODE: 956 - FINAL SCORE: -106.0; desired torque=1.0, actual torque=0.987
# EPISODE: 957 - FINAL SCORE: -69.0; desired torque=-1.0, actual torque=-0.999
# EPISODE: 958 - FINAL SCORE: -76.0; desired torque=0.0, actual torque=-0.107
# EPISODE: 959 - FINAL SCORE: -77.0; desired torque=-1.0, actual torque=-0.949
# Updating target network...
# EPISODE: 960 - FINAL SCORE: -89.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 961 - FINAL SCORE: -119.0; desired torque=1.0, actual torque=0.907
# EPISODE: 962 - FINAL SCORE: -87.0; desired torque=-1.0, actual torque=-0.960
# EPISODE: 963 - FINAL SCORE: -75.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 964 - FINAL SCORE: -86.0; desired torque=1.0, actual torque=0.773
# EPISODE: 965 - FINAL SCORE: -78.0; desired torque=-1.0, actual torque=-0.792
# EPISODE: 966 - FINAL SCORE: -80.0; desired torque=-1.0, actual torque=-0.997
# EPISODE: 967 - FINAL SCORE: -109.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 968 - FINAL SCORE: -113.0; desired torque=-1.0, actual torque=-1.069
# EPISODE: 969 - FINAL SCORE: -85.0; desired torque=1.0, actual torque=0.993
# Updating target network...
# EPISODE: 970 - FINAL SCORE: -75.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 971 - FINAL SCORE: -76.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 972 - FINAL SCORE: -98.0; desired torque=1.0, actual torque=0.968
# EPISODE: 973 - FINAL SCORE: -90.0; desired torque=-1.0, actual torque=-0.997
# EPISODE: 974 - FINAL SCORE: -78.0; desired torque=-1.0, actual torque=-0.976
# EPISODE: 975 - FINAL SCORE: -100.0; desired torque=1.0, actual torque=1.000
# EPISODE: 976 - FINAL SCORE: -88.0; desired torque=1.0, actual torque=1.729
# EPISODE: 977 - FINAL SCORE: -96.0; desired torque=-1.0, actual torque=-0.998
# EPISODE: 978 - FINAL SCORE: -99.0; desired torque=1.0, actual torque=1.000
# EPISODE: 979 - FINAL SCORE: -75.0; desired torque=-1.0, actual torque=-1.000
# Updating target network...
# EPISODE: 980 - FINAL SCORE: -86.0; desired torque=1.0, actual torque=1.000
# EPISODE: 981 - FINAL SCORE: -85.0; desired torque=-1.0, actual torque=-0.998
# EPISODE: 982 - FINAL SCORE: -82.0; desired torque=-1.0, actual torque=-0.997
# EPISODE: 983 - FINAL SCORE: -87.0; desired torque=1.0, actual torque=1.000
# EPISODE: 984 - FINAL SCORE: -71.0; desired torque=-1.0, actual torque=-0.948
# EPISODE: 985 - FINAL SCORE: -87.0; desired torque=-1.0, actual torque=-0.980
# EPISODE: 986 - FINAL SCORE: -84.0; desired torque=1.0, actual torque=1.000
# EPISODE: 987 - FINAL SCORE: -75.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 988 - FINAL SCORE: -70.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 989 - FINAL SCORE: -69.0; desired torque=-1.0, actual torque=-0.999
# Updating target network...
# EPISODE: 990 - FINAL SCORE: -86.0; desired torque=1.0, actual torque=0.998
# EPISODE: 991 - FINAL SCORE: -98.0; desired torque=-1.0, actual torque=-0.949
# EPISODE: 992 - FINAL SCORE: -76.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 993 - FINAL SCORE: -90.0; desired torque=1.0, actual torque=1.005
# EPISODE: 994 - FINAL SCORE: -75.0; desired torque=1.0, actual torque=1.000
# EPISODE: 995 - FINAL SCORE: -89.0; desired torque=-1.0, actual torque=-1.589
# EPISODE: 996 - FINAL SCORE: -93.0; desired torque=-1.0, actual torque=-0.978
# EPISODE: 997 - FINAL SCORE: -94.0; desired torque=-1.0, actual torque=-1.000
# EPISODE: 998 - FINAL SCORE: -109.0; desired torque=1.0, actual torque=0.977
# EPISODE: 999 - FINAL SCORE: -63.0; desired torque=-1.0, actual torque=-0.999

# %%
plotting_rewards_test=[]
#env.seed(1) # Set a random seed for the environment (reproducible results)
total_episodes_test = 100

# %%
#save_observation = []
#save_u1 = []
#save_pid_u1 = []
#save_ctrl_voltage = []

# %%
#save_observation_temp = []
#save_u1_temp = []
#save_pid_u1_temp = []
#save_ctrl_voltage_temp = []
best_score = -501

# %%
# Test
# Initialize the Gym environment

print('Test')
for num_episode in range(total_episodes_test):
    # Reset the environment and get the initial state
    state = env.reset()
    state = state[0]##################################################################################################################################
    save_observation_temp = [state]
    save_u1_temp = [0.0]
    save_pid_u1_temp = [0.0]
    save_ctrl_voltage_temp = []

    # Reset the score. The final score will be the total amount of steps before the pole falls
    score = 0
    done = False
    # Go on until the pole falls off or the score reach 490
    while not done:
      # Choose the best action (temperature 0)
      action, q_values = choose_action_softmax(policy_net, state, temperature=0)
      # Apply the action and get the next state, the reward and a flag "done" that is True if the game is ended
      next_state, reward, done, info , wanted_torque, actual_torque = env.step(action)
      # Visually render the environment
      #env.render()
      # Update the final score (+1 for each step)
      score += reward
      # Set the current state for the next iteration
      state = next_state
      # Check if the episode ended (the pole fell down)
      if score<score_low_bound: ##### change  to stop high negative score
        done =True
      save_observation_temp.append(next_state)
      save_u1_temp.append(wanted_torque)
      save_pid_u1_temp.append(actual_torque)
      save_ctrl_voltage_temp.append(env.DCMotorModel.voltage_input)

    # get best score and update save data
    save_ctrl_voltage_temp.append(env.DCMotorModel.voltage_input)
    if best_score<score:
      save_observation = list(save_observation_temp)
      save_u1 = list(save_u1_temp)
      save_pid_u1 = list(save_pid_u1_temp)
      save_ctrl_voltage = list(save_ctrl_voltage_temp)
      best_score = score


    # Print the final score
    plotting_rewards_test.append(score)
    print(f"EPISODE {num_episode} - FINAL SCORE: {score}")
env.close()
# Out:
# Test
# EPISODE 0 - FINAL SCORE: -71.0
# EPISODE 1 - FINAL SCORE: -87.0
# EPISODE 2 - FINAL SCORE: -75.0
# EPISODE 3 - FINAL SCORE: -62.0
# EPISODE 4 - FINAL SCORE: -82.0
# EPISODE 5 - FINAL SCORE: -82.0
# EPISODE 6 - FINAL SCORE: -75.0
# EPISODE 7 - FINAL SCORE: -86.0
# EPISODE 8 - FINAL SCORE: -113.0
# EPISODE 9 - FINAL SCORE: -72.0
# EPISODE 10 - FINAL SCORE: -63.0
# EPISODE 11 - FINAL SCORE: -73.0
# EPISODE 12 - FINAL SCORE: -63.0
# EPISODE 13 - FINAL SCORE: -82.0
# EPISODE 14 - FINAL SCORE: -75.0
# EPISODE 15 - FINAL SCORE: -88.0
# EPISODE 16 - FINAL SCORE: -96.0
# EPISODE 17 - FINAL SCORE: -94.0
# EPISODE 18 - FINAL SCORE: -88.0
# EPISODE 19 - FINAL SCORE: -63.0
# EPISODE 20 - FINAL SCORE: -96.0
# EPISODE 21 - FINAL SCORE: -82.0
# EPISODE 22 - FINAL SCORE: -95.0
# EPISODE 23 - FINAL SCORE: -82.0
# EPISODE 24 - FINAL SCORE: -86.0
# EPISODE 25 - FINAL SCORE: -70.0
# EPISODE 26 - FINAL SCORE: -98.0
# EPISODE 27 - FINAL SCORE: -70.0
# EPISODE 28 - FINAL SCORE: -87.0
# EPISODE 29 - FINAL SCORE: -500.0
# EPISODE 30 - FINAL SCORE: -91.0
# EPISODE 31 - FINAL SCORE: -78.0
# EPISODE 32 - FINAL SCORE: -69.0
# EPISODE 33 - FINAL SCORE: -86.0
# EPISODE 34 - FINAL SCORE: -103.0
# EPISODE 35 - FINAL SCORE: -71.0
# EPISODE 36 - FINAL SCORE: -93.0
# EPISODE 37 - FINAL SCORE: -71.0
# EPISODE 38 - FINAL SCORE: -70.0
# EPISODE 39 - FINAL SCORE: -71.0
# EPISODE 40 - FINAL SCORE: -75.0
# EPISODE 41 - FINAL SCORE: -62.0
# EPISODE 42 - FINAL SCORE: -70.0
# EPISODE 43 - FINAL SCORE: -82.0
# EPISODE 44 - FINAL SCORE: -82.0
# EPISODE 45 - FINAL SCORE: -71.0
# EPISODE 46 - FINAL SCORE: -86.0
# EPISODE 47 - FINAL SCORE: -62.0
# EPISODE 48 - FINAL SCORE: -70.0
# EPISODE 49 - FINAL SCORE: -94.0
# EPISODE 50 - FINAL SCORE: -71.0
# EPISODE 51 - FINAL SCORE: -93.0
# EPISODE 52 - FINAL SCORE: -70.0
# EPISODE 53 - FINAL SCORE: -70.0
# EPISODE 54 - FINAL SCORE: -63.0
# EPISODE 55 - FINAL SCORE: -70.0
# EPISODE 56 - FINAL SCORE: -73.0
# EPISODE 57 - FINAL SCORE: -82.0
# EPISODE 58 - FINAL SCORE: -73.0
# EPISODE 59 - FINAL SCORE: -88.0
# EPISODE 60 - FINAL SCORE: -83.0
# EPISODE 61 - FINAL SCORE: -83.0
# EPISODE 62 - FINAL SCORE: -93.0
# EPISODE 63 - FINAL SCORE: -63.0
# EPISODE 64 - FINAL SCORE: -97.0
# EPISODE 65 - FINAL SCORE: -81.0
# EPISODE 66 - FINAL SCORE: -71.0
# EPISODE 67 - FINAL SCORE: -82.0
# EPISODE 68 - FINAL SCORE: -63.0
# EPISODE 69 - FINAL SCORE: -82.0
# EPISODE 70 - FINAL SCORE: -70.0
# EPISODE 71 - FINAL SCORE: -110.0
# EPISODE 72 - FINAL SCORE: -70.0
# EPISODE 73 - FINAL SCORE: -94.0
# EPISODE 74 - FINAL SCORE: -99.0
# EPISODE 75 - FINAL SCORE: -87.0
# EPISODE 76 - FINAL SCORE: -96.0
# EPISODE 77 - FINAL SCORE: -82.0
# EPISODE 78 - FINAL SCORE: -95.0
# EPISODE 79 - FINAL SCORE: -97.0
# EPISODE 80 - FINAL SCORE: -63.0
# EPISODE 81 - FINAL SCORE: -79.0
# EPISODE 82 - FINAL SCORE: -97.0
# EPISODE 83 - FINAL SCORE: -76.0
# EPISODE 84 - FINAL SCORE: -85.0
# EPISODE 85 - FINAL SCORE: -64.0
# EPISODE 86 - FINAL SCORE: -70.0
# EPISODE 87 - FINAL SCORE: -81.0
# EPISODE 88 - FINAL SCORE: -106.0
# EPISODE 89 - FINAL SCORE: -95.0
# EPISODE 90 - FINAL SCORE: -86.0
# EPISODE 91 - FINAL SCORE: -71.0
# EPISODE 92 - FINAL SCORE: -82.0
# EPISODE 93 - FINAL SCORE: -63.0
# EPISODE 94 - FINAL SCORE: -63.0
# EPISODE 95 - FINAL SCORE: -87.0
# EPISODE 96 - FINAL SCORE: -94.0
# EPISODE 97 - FINAL SCORE: -101.0
# EPISODE 98 - FINAL SCORE: -85.0
# EPISODE 99 - FINAL SCORE: -80.0

# %%
save_observation_temp = None
save_u1_temp = None
save_pid_u1_temp = None
save_ctrl_voltage_temp = None

# %%
# Create a dictionary of variables you want to save
variables_to_save = {
    'plotting_rewards': plotting_rewards,
    'save_observation': save_observation,
    'save_u1': save_u1,
    'save_pid_u1': save_pid_u1,
    'save_ctrl_voltage': save_ctrl_voltage,
    'plotting_rewards_test' :plotting_rewards_test
}

# %%
path = '/content/drive/MyDrive/Colab Notebooks/codes/Fixed PID Constants/save_data/Acrobot/'

# %%
with open(path+'Acrobot.pkl', 'wb') as f:
    pickle.dump(variables_to_save, f)
print(f"All variables saved to {path+'Acrobot.pkl'}")
# Out:
# All variables saved to /content/drive/MyDrive/Colab Notebooks/codes/Fixed PID Constants/save_data/Acrobot/Acrobot.pkl

# %%
torch.save(policy_net, path+"policy_net.pickle")

# %%
path = '/content/drive/MyDrive/Colab Notebooks/codes/Fixed PID Constants/save_data/Acrobot/'

# %%
# Open the file in read-binary mode and load the dictionary
with open(path+'Acrobot.pkl', 'rb') as f:
    loaded_variables = pickle.load(f)

# Access the loaded variables
plotting_rewards = loaded_variables['plotting_rewards']
save_observation = loaded_variables['save_observation']
save_u1 = loaded_variables['save_u1']
save_pid_u1 = loaded_variables['save_pid_u1']
save_ctrl_voltage = loaded_variables['save_ctrl_voltage']
plotting_rewards_test = loaded_variables['plotting_rewards_test']

# %%
#policy_net = torch.load(path+"policy_net.pickle",weights_only=False).to(device)

# %%
plt.rc('text.latex', preamble=r'\usepackage{amsmath,amssymb,amsfonts}')
#plt.rcParams["text.usetex"]=False
#plt.rcParams["font.family"] = "sans-serif"
#plt.rcParams["font.family"] = "serif"
#plt.rcParams['mathtext.fontset'] = 'cm'
#plt.rcParams['mathtext.fontset'] = 'dejavusans'
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'

# %%
def unnorm_to_norm(x):
  y = (x-low_bound_reward_list)/(up_bound_reward_list-low_bound_reward_list)
  return y

# %%
def norm_to_unnorm(y):
  x=y*(up_bound_reward_list-low_bound_reward_list)+low_bound_reward_list
  return x

# %%
low_bound_reward_list = -500 # -0.1*(1**2 force mag)*(1000*episoded)s
up_bound_reward_list = 0
print("low_bound_reward_list=",low_bound_reward_list)
print("up_bound_reward_list=",up_bound_reward_list)
norm_reward_list = np.array(plotting_rewards)
norm_reward_list = unnorm_to_norm(norm_reward_list)
# Out:
# low_bound_reward_list= -500
# up_bound_reward_list= 0

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(range(1,num_iterations+1),plotting_rewards)
plt.xlabel('Training episodes')
plt.ylabel('Acc. Episodic Reward')
plt.ylim([-550,-40])
plt.legend()
plt.title('Acrobot v1')
plt.grid()
plt.show()
# Out:
# /tmp/ipython-input-227696416.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
print("Acc. Epsiodic Reward's last 20 mean=")
print(np.array(plotting_rewards)[-20:-1].mean())
# Out:
# Acc. Epsiodic Reward's last 20 mean=
# -84.52631578947368

# %%
print(np.array(plotting_rewards).min())
# Out:
# -500.0

# %%
# Episodes versus Norm Acc. Ep. Rewards
#norm_reward_list = np.array(plotting_rewards)
#norm_reward_list = (norm_reward_list/abs(norm_reward_list.min())+1)*100
#min_norm_reward_list = np.array(plotting_rewards).min()
#max_norm_reward_list=0
#norm_reward_list = (norm_reward_list-min_norm_reward_list)/(0-min_norm_reward_list)

font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(norm_reward_list, label = "Normalized Acc. Episodic Reward",color="C0",linewidth = 1.5)
#plt.axhline(y=norm_reward_list[-20:-1].mean(), linestyle='--',
#            label = "Normalized Acc. Episodic Reward's last 20 mean= "+f"{norm_reward_list[-20:-1].mean():.1f}",color="C1",linewidth = 2.5)
plt.xlabel("Training Episode")
plt.ylabel("Normalized Acc. Epsiodic Reward")
#plt.grid()
plt.legend()
plt.show()

# %%
print("Normalized Acc. Epsiodic Reward's last 20 mean=")
print(norm_reward_list[-20:-1].mean())
# Out:
# Normalized Acc. Epsiodic Reward's last 20 mean=
# 0.8309473684210525

# %%
# Compute the moving average of the last 50 numbers
moving_average = []
for i, n in enumerate(norm_reward_list):
    if i < 50:
        # If there are not enough previous elements,
        # append the average of all available elements
        avg = sum(norm_reward_list[:i+1]) / (i+1)
    else:
        # Otherwise, compute the average of the previous 5 elements
        avg = sum(norm_reward_list[i-50:i+1]) / 50
    moving_average.append(avg)

# %%
# Plot the moving average

font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.5)
f.set_figheight(2.2)
plt.plot(moving_average)
plt.plot(moving_average, label = "Normalized Acc. Epi. Reward",color="C0",linewidth = 1.5)
#plt.axhline(y=np.array(moving_average[-20:-1]).mean(), linestyle='--',
#            label = "Acc. Episodic Reward's last 20 mean= "+f"{np.array(moving_average[-20:-1]).mean():.1f}",color="C1",linewidth = 2.5)
plt.xlabel("Training Episode")
plt.ylabel("Normalized Acc. Epi. Reward")
#plt.grid()
plt.minorticks_on()
#plt.yticks(np.arange(0.0, 1.0, 0.1))
#plt.legend()
plt.savefig(path+"Acrobot_Acc_Reward_vs_Episode.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print("Normalized Acc. Episodic Reward's last 20 mean=")
print(np.array(moving_average[-20:-1]).mean())
# Out:
# Normalized Acc. Episodic Reward's last 20 mean=
# 0.8293094736842107

# %%
# Test Histogram
norm_ep_reward_list_test = np.array(plotting_rewards_test)
norm_ep_reward_list_test = unnorm_to_norm(norm_ep_reward_list_test)
print(norm_ep_reward_list_test.max())
print(norm_ep_reward_list_test.min())
min_bin = np.floor(norm_ep_reward_list_test.min()*100)/100
print(min_bin)
# Out:
# 0.876
# 0.0
# 0.0

# %%
font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.5)
f.set_figheight(2.2)
data_rewards = np.array(norm_ep_reward_list_test)
density_True = True
plt.hist(data_rewards, bins=np.arange(0,1.01,0.05), density=density_True ,color='skyblue', edgecolor='black')
plt.xlabel('Normalized Acc. Epi. Reward')
ylabel='Density'if density_True else 'Frequency'
plt.ylabel(ylabel)
#plt.xticks(np.arange(0.0,1.01,0.1))
#plt.xticks(np.arange(0,1.00001,0.05),minor=True)
plt.minorticks_on()
plt.savefig(path+"Acrobot_Acc_Reward_vs_Episode_Test_Hist.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print("Test Normalized Acc Episodic Reward's Results:")
print(f"Unnormalized: max={norm_to_unnorm(data_rewards).max():.3f} ,mean={norm_to_unnorm(data_rewards).mean():.3f}, std={norm_to_unnorm(data_rewards).std():.3f}")
print(f"Normalized:   max={data_rewards.max():.3e} ,mean={data_rewards.mean():.3e}, std={data_rewards.std():.3e}")
# Out:
# Test Normalized Acc Episodic Reward's Results:
# Unnormalized: max=-62.000 ,mean=-91.677, std=64.557
# Normalized:   max=8.760e-01 ,mean=8.166e-01, std=1.291e-01

# %%
env.dt
# Out:
# 0.2

# %%
dt=env.dt#=0.2
time_position_u1= np.linspace(start = 0, stop = len(save_u1)* dt,num=len(save_u1) )
time_position__pid_u1= np.linspace(start = 0, stop = len(save_u1)* dt,num=len(save_u1) )

e_ry=np.array(save_u1)-np.array(save_pid_u1)

mean_std=f'(mean,std)=({e_ry.mean():.2e}, {e_ry.std():.2e})'

# %%
font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.5)
f.set_figheight(2.2)

plt.step(time_position_u1, save_u1 ,label = r"$F^\mathrm{d}$",color="blue",linewidth = 1.5) # $F^\mathrm{d}$ or $F^\mathrm{desired}$
plt.plot(time_position__pid_u1, save_pid_u1 , '--',label = r"$F$",color="red",linewidth = 2.0)
plt.plot(time_position_u1, e_ry,'-.',label = r"$F^\mathrm{d}$-$F$",color="black",linewidth = 1.1)

plt.xlabel("Time (s)")
plt.ylabel(r"Torque (N⋅m)")
#plt.grid()
plt.minorticks_on()
plt.xticks(np.arange(0,time_position_u1[-1],1)+1,minor=True)
plt.legend(fontsize=8.5)
plt.savefig(path+"Acrobot_Torque_vs_Time.pdf", format='pdf', bbox_inches='tight')
#plt.xlim(-0.1,1.1)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2010: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   p.space          = oneOf(self._space_widths)("space")
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2020: PyparsingDeprecationWarning: 'leaveWhitespace' deprecated - use 'leave_whitespace'
#   )("sym").leaveWhitespace()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:1984: PyparsingDeprecationWarning: 'setName' deprecated - use 'set_name'
#   val.setName(key)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:1987: PyparsingDeprecationWarning: 'setParseAction' deprecated - use 'set_parse_action'
#   val.setParseAction(getattr(self, key))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2088: PyparsingDeprecationWarning: 'endQuoteChar' argument is deprecated, use 'end_quote_char'
#   p.text = cmd(r"\text", QuotedString('{', '\\', endQuoteChar="}"))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2146: PyparsingDeprecationWarning: 'unquoteResults' argument is deprecated, use 'unquote_results'
#   p.math_string   = QuotedString('$', '\\', unquoteResults=False)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print(mean_std)
# Out:
# (mean,std)=(-2.30e-03, 8.23e-02)

# %%
print(f"mae={np.abs(e_ry).mean():.3e}")
# Out:
# mae=4.373e-02

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)

plt.step(time_position_u1, save_ctrl_voltage)
plt.xlabel("time [sec]")
plt.ylabel("Control Voltage [volts]")
#plt.grid()
plt.show()

# %%
import math

cos_theta_1 = []
sin_theta_1 = []
cos_theta_2 = []
sin_theta_2 = []
ang_vel_theta_1 = []
ang_vel_theta_2 = []

for observ in save_observation:
  for index,value in enumerate(observ):
    if index == 0:
      cos_theta_1.append(value)
    if index == 1:
      sin_theta_1.append(value)
    if index == 2:
      cos_theta_2.append(value)
    if index == 3:
      sin_theta_2.append(value)
    if index == 4:
      ang_vel_theta_1.append(value)
    if index == 5:
      ang_vel_theta_2.append(value)

# %%
cos_theta_1 = np.array(cos_theta_1)
cos_theta_2 = np.array(cos_theta_2)
sin_theta_1 = np.array(sin_theta_1)
sin_theta_2 = np.array(sin_theta_2)
ang_vel_theta_1 = np.array(ang_vel_theta_1)
ang_vel_theta_2 = np.array(ang_vel_theta_2)

# %%
print(len(cos_theta_1))
# Out:
# 64

# %%
dt=env.dt#=0.2
from scipy.interpolate import make_interp_spline, BSpline

time_cos_theta_1 = np.linspace(start = 0, stop = len(cos_theta_1)* dt,num=len(cos_theta_1))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_cos_theta_1[-1] , 300)

spl = make_interp_spline(time_cos_theta_1, cos_theta_1, k=3)  # type: BSpline
power_smooth = spl(xnew)

plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel("time [sec]")
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
plt.ylabel(r'$\cos({\theta_1})$')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_sin_theta_1 = np.linspace(start = 0, stop = len(sin_theta_1)* dt,num=len(sin_theta_1))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_sin_theta_1[-1] , 300)

spl = make_interp_spline(time_sin_theta_1, sin_theta_1, k=3)  # type: BSpline
power_smooth = spl(xnew)

plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel("time [sec]")
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
plt.ylabel(r'$\sin({\theta_1})$')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_cos_theta_2 = np.linspace(start = 0, stop = len(cos_theta_2)* dt,num=len(cos_theta_2))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_cos_theta_2[-1] , 300)

spl = make_interp_spline(time_cos_theta_2, cos_theta_2, k=3)  # type: BSpline
power_smooth = spl(xnew)

plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel("time [sec]")
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
plt.ylabel(r'$\cos({\theta_2})$')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_sin_theta_2 = np.linspace(start = 0, stop = len(sin_theta_2)* dt,num=len(sin_theta_2))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_sin_theta_2[-1] , 300)

spl = make_interp_spline(time_sin_theta_2, sin_theta_2, k=3)  # type: BSpline
power_smooth = spl(xnew)

plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel("time [sec]")
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
plt.ylabel(r'$\sin({\theta_2})$')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_ang_vel_theta_1 = np.linspace(start = 0, stop = len(ang_vel_theta_1)* dt,num=len(ang_vel_theta_1))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_ang_vel_theta_1[-1] , 300)

spl = make_interp_spline(time_ang_vel_theta_1, ang_vel_theta_1, k=3)  # type: BSpline
power_smooth = spl(xnew)

plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel("time [sec]")
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
plt.ylabel(r'$\dot{\theta_1}$ [rad/sec]')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_ang_vel_theta_2 = np.linspace(start = 0, stop = len(ang_vel_theta_2)* dt,num=len(ang_vel_theta_2))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_ang_vel_theta_2[-1] , 300)

spl = make_interp_spline(time_ang_vel_theta_2, ang_vel_theta_2, k=3)  # type: BSpline
power_smooth = spl(xnew)

plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel("time [sec]")
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
plt.ylabel(r'$\dot{\theta_2}$ [rad/sec]')
plt.show()

# %%
Condition = -cos_theta_1 -cos_theta_1*cos_theta_2 + sin_theta_1*sin_theta_2
spl = make_interp_spline(time_sin_theta_2, Condition, k=3)  # type: BSpline
power_smooth = spl(xnew)

font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)

plt.plot(xnew, power_smooth, label = r'Cond = $-\cos(\theta_1)-\cos({\theta_1+\theta_2})$',color="blue")
plt.plot(xnew, (power_smooth>1)-1,':', label = r'Reward = bool(Cond>1)-1',color="red", linewidth = 4)

#plt.grid()
#plt.legend()
plt.xlabel("Time [sec]")
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
plt.ylabel('Condition for Reward')
plt.legend()
plt.show()

# %%
# Initialize the Gym environment
env =  Custom_AcrobotEnv()
env.seed(1) # Set a random seed for the environment (reproducible results)

# This is for creating the output video in Colab, not required outside Colab
#env = wrap_env(env, video_callable=lambda episode_id: True) # Save a video every episode

plotting_rewards2=[]
# Let's try for a total of 10 episodes
for num_episode in range(10):
    # Reset the environment and get the initial state
    state = env.reset()
    state = state[0]##################################################################################################################################
    # Reset the score. The final score will be the total amount of steps before the pole falls
    score = 0
    done = False
    # Go on until the pole falls off or the score reach 490
    while not done:
      # Choose the best action (temperature 0)
      action, q_values = choose_action_softmax(policy_net, state, temperature=0)
      # Apply the action and get the next state, the reward and a flag "done" that is True if the game is ended
      next_state, reward, done, info , wanted_torque, actual_torque = env.step(action)
      # Visually render the environment
      #env.render()
      # Update the final score (+1 for each step)
      score += reward
      # Set the current state for the next iteration
      state = next_state
      # Check if the episode ended (the pole fell down)
      if score<score_low_bound: ##### change  to stop high negative score
        done =True
    # Print the final score
    plotting_rewards2.append(score)
    print(f"EPISODE {num_episode} - FINAL SCORE: {score}")
env.close()
# Out:
# /usr/local/lib/python3.12/dist-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(
# EPISODE 0 - FINAL SCORE: -500.0
# EPISODE 1 - FINAL SCORE: -500.0
# EPISODE 2 - FINAL SCORE: -500.0
# EPISODE 3 - FINAL SCORE: -500.0
# EPISODE 4 - FINAL SCORE: -500.0
# EPISODE 5 - FINAL SCORE: -500.0
# EPISODE 6 - FINAL SCORE: -500.0
# EPISODE 7 - FINAL SCORE: -500.0
# EPISODE 8 - FINAL SCORE: -500.0
# EPISODE 9 - FINAL SCORE: -500.0
