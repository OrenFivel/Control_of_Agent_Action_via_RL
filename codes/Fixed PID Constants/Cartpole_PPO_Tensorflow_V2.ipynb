# %% [markdown]
# **References:**
#
# - https://keras.io/examples/rl/ppo_cartpole/
# - [Proximal Policy Optimization Algorithms](https://arxiv.org/abs/1707.06347)
# - [OpenAI Spinning Up docs - PPO](https://spinningup.openai.com/en/latest/algorithms/ppo.html)
# - [OpenAI Spinning Up Github - PPO](https://github.com/openai/spinningup/blob/master/spinup/algos/tf1/ppo/ppo.py)
# - https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py

# %%
import warnings

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'


import tensorflow as tf
#from tf import keras as keras
import keras
from keras import layers

import numpy as np
import gym
import scipy.signal
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle

# %%
np.seterr(all="ignore")
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
import matplotlib, cv2
import matplotlib.pyplot as plt
import base64, io, os, time
import IPython, functools
#from tqdm import tqdm
import tensorflow_probability as tfp
import math
from typing import Optional
from gym import spaces, logger
from gym.utils import seeding
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if (distutils.version.LooseVersion(tf.__version__) <
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
warnings.filterwarnings("ignore", message=".*Conversion of an array with ndim > 0 to a scalar.*")
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## Functions and class

# %%
class CartPoleEnvCustomized_with_pid(gym.Env):
    """
    ### Description
    This environment corresponds to the version of the cart-pole problem
    described by Barto, Sutton, and Anderson in ["Neuronlike Adaptive Elements That Can Solve Difficult Learning Control Problem"](https://ieeexplore.ieee.org/document/6313077).
    A pole is attached by an un-actuated joint to a cart, which moves along a
    frictionless track. The pendulum starts upright, and the goal is to prevent
    it from falling over by increasing and reducing the cart's velocity.
    ### Action Space
    The agent take a 1-element vector for actions.
    The action space is `(action)` in `[0, 1]`, where `action` is used to push
    the cart with a fixed amount of force:
    | Num | Action                 |
    |-----|------------------------|
    | 0   | Push cart to the left  |
    | 1   | Push cart to the right |
    Note: The amount the velocity is reduced or increased is not fixed as it depends on the angle the pole is pointing.
    This is because the center of gravity of the pole increases the amount of energy needed to move the cart underneath it
    ### Observation Space
    The observation is a `ndarray` with shape `(4,)` where the elements correspond to the following:
    | Num | Observation           | Min                  | Max                |
    |-----|-----------------------|----------------------|--------------------|
    | 0   | Cart Position         | -4.8*                 | 4.8*                |
    | 1   | Cart Velocity         | -Inf                 | Inf                |
    | 2   | Pole Angle            | ~ -0.418 rad (-24°)** | ~ 0.418 rad (24°)** |
    | 3   | Pole Angular Velocity | -Inf                 | Inf                |
    **Note:** above denotes the ranges of possible observations for each element, but in two cases this range exceeds the
    range of possible values in an un-terminated episode:
    - `*`: the cart x-position can be observed between `(-4.8, 4.8)`, but an episode terminates if the cart leaves the
    `(-2.4, 2.4)` range.
    - `**`: Similarly, the pole angle can be observed between  `(-.418, .418)` radians or precisely **±24°**, but an episode is
    terminated if the pole angle is outside the `(-.2095, .2095)` range or precisely **±12°**
    ### Rewards
    Reward is 1 for every step taken, including the termination step. The threshold is 475 for v1.
    ### Starting State
    All observations are assigned a uniform random value between (-0.05, 0.05)
    ### Episode Termination
    The episode terminates of one of the following occurs:
    1. Pole Angle is more than ±12°
    2. Cart Position is more than ±2.4 (center of the cart reaches the edge of the display)
    3. Episode length is greater than 500 (200 for v0)
    ### Arguments
    No additional arguments are currently supported.
    """

    metadata = {"render.modes": ["human", "rgb_array"], "video.frames_per_second": 50}

    def __init__(self):
        self.gravity = 9.8
        self.masscart = 1.0
        self.masspole = 0.1
        self.total_mass = self.masspole + self.masscart
        self.length = 0.5  # actually half the pole's length
        self.polemass_length = self.masspole * self.length
        self.force_mag = 10.0
        self.tau = 0.02  # seconds between state updates
        self.kinematics_integrator = "euler"


        # Angle at which to fail the episode
        self.theta_threshold_radians = 12 * 2 * math.pi / 360
        self.x_threshold = 2.4

        # Angle limit set to 2 * theta_threshold_radians so failing observation
        # is still within bounds.
        high = np.array(
            [
                self.x_threshold * 2,
                np.finfo(np.float32).max,
                self.theta_threshold_radians * 2,
                np.finfo(np.float32).max,
            ],
            dtype=np.float32,
        )

        self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        self.viewer = None
        self.state = None

        self.steps_beyond_done = None

        ### Customization changes ######
        self.DCMotor_radius = 0.15 #0.2 #### chnge actualy diameter and arm len for rotation
        '''add ElectricalDCMotorEnv to the CartPole class
        and assign values to
        Resistor_R, inductor_L, torque_const_Kt and bemf_const_Ke'''
        self.DCMotorModel = ElectricalDCMotorEnv()
        self.DCMotorModel.tau = self.tau
        self.DCMotorModel.Resistor_R = 1.0
        self.DCMotorModel.inductor_L = 0.1
        self.DCMotorModel.torque_const_Kt = 1.0
        self.DCMotorModel.bemf_const_Ke = 1.0
        ####


    def step(self, action):
        err_msg = f"{action!r} ({type(action)}) invalid"
        assert self.action_space.contains(action), err_msg

        x, x_dot, theta, theta_dot = self.state
        force = self.force_mag if action == 1 else -self.force_mag #+/-10N
        torque_wanted = force*self.DCMotor_radius

        ### Customization changes #####
        ''' set current refrence value current_ref and
        caclulate actual applied force F based DC motor model and PID control at
        DCMotorModel.step function
        '''
        current_ref = torque_wanted/self.DCMotorModel.torque_const_Kt
        #F = self.DCMotorModel.step(current_ref = current_ref,x_dot = x_dot)
        torque_actual = self.DCMotorModel.step(current_ref = current_ref,
                                   x_dot = x_dot/self.DCMotor_radius)
        F = torque_actual/self.DCMotor_radius
        #F = force #ideal env
        ###

        costheta = math.cos(theta)
        sintheta = math.sin(theta)

        # For the interested reader:
        # https://coneural.org/florian/papers/05_cart_pole.pdf
        temp = (
            F + self.polemass_length * theta_dot ** 2 * sintheta
        ) / self.total_mass
        thetaacc = (self.gravity * sintheta - costheta * temp) / (
            self.length * (4.0 / 3.0 - self.masspole * costheta ** 2 / self.total_mass)
        )
        xacc = temp - self.polemass_length * thetaacc * costheta / self.total_mass

        if self.kinematics_integrator == "euler":
            x = x + self.tau * x_dot
            x_dot = x_dot + self.tau * xacc
            theta = theta + self.tau * theta_dot
            theta_dot = theta_dot + self.tau * thetaacc
        else:  # semi-implicit euler
            x_dot = x_dot + self.tau * xacc
            x = x + self.tau * x_dot
            theta_dot = theta_dot + self.tau * thetaacc
            theta = theta + self.tau * theta_dot

        self.state = (x, x_dot, theta, theta_dot)

        done = bool(
            x < -self.x_threshold
            or x > self.x_threshold
            or theta < -self.theta_threshold_radians
            or theta > self.theta_threshold_radians
        )

        if not done: # if we inside the valid range
            reward = 1.0

        elif self.steps_beyond_done is None:
            # Pole just fell!
            self.steps_beyond_done = 0
            reward = 1.0

        else:
            if self.steps_beyond_done == 0:
                logger.warn(
                    "You are calling 'step()' even though this "
                    "environment has already returned done = True. You "
                    "should always call 'reset()' once you receive 'done = "
                    "True' -- any further steps are undefined behavior."
                )
            self.steps_beyond_done += 1
            reward = 0.0

        return np.array(self.state, dtype=np.float32), reward, done, {} ,torque_wanted, torque_actual


    def reset(self, return_info = False, options = None):
        #super().reset(seed=seed)
        self.state = np.random.uniform(low=-0.05, high=0.05, size=(4,))
        self.DCMotorModel.current = 0.0
        self.DCMotorModel.current_error = 0.0
        self.DCMotorModel.current_error_acc = 0.0
        self.DCMotorModel.current_error_prev = 0.0
        self.steps_beyond_done = None

        if not return_info:
            return np.array(self.state, dtype=np.float32)
        else:
            return np.array(self.state, dtype=np.float32), {}

    def render(self, mode="human"):
        screen_width = 600
        screen_height = 400

        world_width = self.x_threshold * 2
        scale = screen_width / world_width
        carty = 100  # TOP OF CART
        polewidth = 10.0
        polelen = scale * (2 * self.length)
        cartwidth = 50.0
        cartheight = 30.0

        if self.viewer is None:
            #from gym.utils import pyglet_rendering
            from gym.envs.classic_control import rendering as pyglet_rendering

            self.viewer = pyglet_rendering.Viewer(screen_width, screen_height)
            l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
            axleoffset = cartheight / 4.0
            cart = pyglet_rendering.FilledPolygon([(l, b), (l, t), (r, t), (r, b)])
            self.carttrans = pyglet_rendering.Transform()
            cart.add_attr(self.carttrans)
            self.viewer.add_geom(cart)
            l, r, t, b = (
                -polewidth / 2,
                polewidth / 2,
                polelen - polewidth / 2,
                -polewidth / 2,
            )
            pole = pyglet_rendering.FilledPolygon([(l, b), (l, t), (r, t), (r, b)])
            pole.set_color(0.8, 0.6, 0.4)
            self.poletrans = pyglet_rendering.Transform(translation=(0, axleoffset))
            pole.add_attr(self.poletrans)
            pole.add_attr(self.carttrans)
            self.viewer.add_geom(pole)
            self.axle = pyglet_rendering.make_circle(polewidth / 2)
            self.axle.add_attr(self.poletrans)
            self.axle.add_attr(self.carttrans)
            self.axle.set_color(0.5, 0.5, 0.8)
            self.viewer.add_geom(self.axle)
            self.track = pyglet_rendering.Line((0, carty), (screen_width, carty))
            self.track.set_color(0, 0, 0)
            self.viewer.add_geom(self.track)

            self._pole_geom = pole

        if self.state is None:
            return None

        # Edit the pole polygon vertex
        pole = self._pole_geom
        l, r, t, b = (
            -polewidth / 2,
            polewidth / 2,
            polelen - polewidth / 2,
            -polewidth / 2,
        )
        pole.v = [(l, b), (l, t), (r, t), (r, b)]

        x = self.state
        cartx = x[0] * scale + screen_width / 2.0  # MIDDLE OF CART
        self.carttrans.set_translation(cartx, carty)
        self.poletrans.set_rotation(-x[2])

        return self.viewer.render(return_rgb_array=mode == "rgb_array")

    def close(self):
        if self.viewer:
            self.viewer.close()
            self.viewer = None

# %%
class ElectricalDCMotorEnv():

      def __init__(self):
        self.Resistor_R = 1.0
        self.inductor_L = 0.1
        self.torque_const_Kt = 1.0
        self.bemf_const_Ke = 1.0
        self.tau = 0.02
        #

        self.Kp = 4.3 #5.0 #50.0
        self.Ki = 1.0 #10.0 #3.0
        self.Kd = 10.0**(-6)
        self.aL=10.0**(-3) #Low pass parameter
        self.aH = 10.0**2 #High pass parameter

        #
        self.current = 0.0
        self.current_error = 0.0
        self.current_error_acc = 0.0
        self.current_error_prev = 0.0
        self.voltage_input = 0.0
        self.xdot = 0.0
        self.PID_Discretization = "Simple" #"Backward", " "Bilinear" , "Forward" "Simple"


      def step(self, current_ref, x_dot):
        aL = self.aL
        aH = self.aH
        self.current_error = current_ref-self.current
        delta_error = self.current_error-self.current_error_prev

        if self.PID_Discretization == "Simple":
          self.current_error_acc += self.current_error*self.tau
          HP_delta_error = delta_error

        elif self.PID_Discretization == "Backward":
          self.current_error_acc = (self.current_error_acc+(self.current_error)*self.tau)/(1+aL*self.tau) #Low Pass
          HP_delta_error = (self.current_error + aH*delta_error)/(1+aL*self.tau)#High Pass

        elif self.PID_Discretization == "Bilinear":
          error_avg = (self.current_error+self.current_error_prev)/2
          self.current_error_acc =  ((1-aL*self.tau/2)*self.current_error_acc + error_avg*self.tau)/(1+aL*self.tau/2)#Low Pass
          HP_delta_error =  ((1-aL*self.tau/2)*self.current_error + aH*delta_error)/(1+aL*self.tau/2)#High Pass

        else:
          self.current_error_acc = (1-aL*self.tau)*self.current_error_acc+(self.current_error_prev)*self.tau #Low Pass
          HP_delta_error = (1-aH*self.tau)*self.current_error + aH*delta_error #High Pass

        P = self.Kp*self.current_error
        I = self.Ki*self.current_error_acc
        D = self.Kd*HP_delta_error/self.tau
        voltage_BEMF = x_dot*self.bemf_const_Ke
        voltage_input = P+I+D+voltage_BEMF + 0.7*current_ref
        voltage_input = np.clip(voltage_input, -20, 20)

        self.current_error_prev = 0+self.current_error
        self.current += self.tau*(voltage_input-voltage_BEMF-self.current*self.Resistor_R)/self.inductor_L
        self.voltage_input = voltage_input
        self.xdot = x_dot
        F=self.torque_const_Kt*self.current

        return F # return applied torque

# %%
def discounted_cumulative_sums(x, discount):
    # Discounted cumulative sums of vectors for computing rewards-to-go and advantage estimates
    return scipy.signal.lfilter([1], [1, float(-discount)], x[::-1], axis=0)[::-1]


class Buffer:
    # Buffer for storing trajectories
    def __init__(self, observation_dimensions, size, gamma=0.99, lam=0.95):
        # Buffer initialization
        self.observation_buffer = np.zeros(
            (size, observation_dimensions), dtype=np.float32
        )
        self.action_buffer = np.zeros(size, dtype=np.int32)
        self.advantage_buffer = np.zeros(size, dtype=np.float32)
        self.reward_buffer = np.zeros(size, dtype=np.float32)
        self.return_buffer = np.zeros(size, dtype=np.float32)
        self.value_buffer = np.zeros(size, dtype=np.float32)
        self.logprobability_buffer = np.zeros(size, dtype=np.float32)
        self.gamma, self.lam = gamma, lam
        self.pointer, self.trajectory_start_index = 0, 0

    def store(self, observation, action, reward, value, logprobability):
        # Append one step of agent-environment interaction
        self.observation_buffer[self.pointer] = observation
        self.action_buffer[self.pointer] = action
        self.reward_buffer[self.pointer] = reward
        self.value_buffer[self.pointer] = value
        self.logprobability_buffer[self.pointer] = logprobability
        self.pointer += 1

    def finish_trajectory(self, last_value=0):
        # Finish the trajectory by computing advantage estimates and rewards-to-go
        path_slice = slice(self.trajectory_start_index, self.pointer)
        rewards = np.append(self.reward_buffer[path_slice], last_value)
        values = np.append(self.value_buffer[path_slice], last_value)

        deltas = rewards[:-1] + self.gamma * values[1:] - values[:-1]

        self.advantage_buffer[path_slice] = discounted_cumulative_sums(
            deltas, self.gamma * self.lam
        )
        self.return_buffer[path_slice] = discounted_cumulative_sums(
            rewards, self.gamma
        )[:-1]

        self.trajectory_start_index = self.pointer

    def get(self):
        # Get all data of the buffer and normalize the advantages
        self.pointer, self.trajectory_start_index = 0, 0
        advantage_mean, advantage_std = (
            np.mean(self.advantage_buffer),
            np.std(self.advantage_buffer),
        )
        self.advantage_buffer = (self.advantage_buffer - advantage_mean) / advantage_std
        return (
            self.observation_buffer,
            self.action_buffer,
            self.advantage_buffer,
            self.return_buffer,
            self.logprobability_buffer,
        )

#output_activation=None
def mlp(x, sizes, activation=keras.activations.tanh,
        output_activation=None):
    # Build a feedforward neural network
    for size in sizes[:-1]:
        x = layers.Dense(units=size, activation=activation)(x)
    return layers.Dense(units=sizes[-1], activation=output_activation)(x)



def logprobabilities(logits, a):
    # Compute the log-probabilities of taking actions a by using the logits (i.e. the output of the actor)
    logprobabilities_all = keras.ops.log_softmax(logits)
    logprobability = keras.ops.sum(
        keras.ops.one_hot(a, num_actions) * logprobabilities_all, axis=1
    )
    return logprobability


seed_generator = keras.random.SeedGenerator(1337)


# Sample action from actor
@tf.function
def sample_action(observation):
    logits = actor(observation)
    action = keras.ops.squeeze(
        keras.random.categorical(logits, 1, seed=seed_generator), axis=1
    )
    return logits, action


# Train the policy by maxizing the PPO-Clip objective
@tf.function
def train_policy(
    observation_buffer, action_buffer, logprobability_buffer, advantage_buffer
):
    with tf.GradientTape() as tape:  # Record operations for automatic differentiation.
        ratio = keras.ops.exp(
            logprobabilities(actor(observation_buffer), action_buffer)
            - logprobability_buffer
        )
        min_advantage = keras.ops.where(
            advantage_buffer > 0,
            (1 + clip_ratio) * advantage_buffer,
            (1 - clip_ratio) * advantage_buffer,
        )

        policy_loss = -keras.ops.mean(
            keras.ops.minimum(ratio * advantage_buffer, min_advantage)
        )
    policy_grads = tape.gradient(policy_loss, actor.trainable_variables)
    policy_optimizer.apply_gradients(zip(policy_grads, actor.trainable_variables))

    kl = keras.ops.mean(
        logprobability_buffer
        - logprobabilities(actor(observation_buffer), action_buffer)
    )
    kl = keras.ops.sum(kl)
    return kl


# Train the value function by regression on mean-squared error
@tf.function
def train_value_function(observation_buffer, return_buffer):
    with tf.GradientTape() as tape:  # Record operations for automatic differentiation.
        value_loss = keras.ops.mean((return_buffer - critic(observation_buffer)) ** 2)
    value_grads = tape.gradient(value_loss, critic.trainable_variables)
    value_optimizer.apply_gradients(zip(value_grads, critic.trainable_variables))

# %% [markdown]
# ## Hyperparameters

# %%
# Hyperparameters of the PPO algorithm
steps_per_epoch = 4000
epochs = 100 #60 # 40 #30
steps_per_episode_goal = 500
episodes_max = 2500 #3000
gamma = 0.99
clip_ratio = 0.2
policy_learning_rate = 3e-4
value_function_learning_rate = 1e-3
train_policy_iterations = 80
train_value_iterations = 80
lam = 0.97
target_kl = 0.01
hidden_sizes = (64, 64)

# True if you want to render the environment
render = False

# %% [markdown]
# ## Initializations

# %%
# Initialize the environment and get the dimensionality of the
# observation space and the number of possible actions
env = CartPoleEnvCustomized_with_pid()
observation_dimensions = env.observation_space.shape[0]
num_actions = env.action_space.n

# Initialize the buffer
buffer = Buffer(observation_dimensions, steps_per_epoch)

# Initialize the actor and the critic as keras models
observation_input = keras.Input(shape=(observation_dimensions,), dtype="float32")
logits = mlp(observation_input, list(hidden_sizes) + [num_actions])
actor = keras.Model(inputs=observation_input, outputs=logits)
value = keras.ops.squeeze(mlp(observation_input, list(hidden_sizes) + [1]), axis=1)
critic = keras.Model(inputs=observation_input, outputs=value)

# Initialize the policy and the value function optimizers
policy_optimizer = keras.optimizers.Adam(learning_rate=policy_learning_rate)
value_optimizer = keras.optimizers.Adam(learning_rate=value_function_learning_rate)

# Initialize the observation, episode return and episode length
#observation, _ = env.reset()
observation = env.reset()
episode_return, episode_length = 0, 0

# %%
# load
#load_path = '/content/drive/MyDrive/Colab Notebooks/codes/Fixed PID Constants/save_data/Cartpole/'

# %%
#actor = keras.models.load_model(load_path+"cartple_actor.keras")
#critic = keras.models.load_model(load_path+"cartple_critic.keras")

# %%
actor.summary(expand_nested=True, show_trainable=True)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer (InputLayer)    │ (None, 4)             │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense (Dense)               │ (None, 64)            │        320 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_1 (Dense)             │ (None, 64)            │      4,160 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_2 (Dense)             │ (None, 2)             │        130 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 4,610 (18.01 KB)
#  Trainable params: 4,610 (18.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
keras.utils.plot_model(actor,show_shapes=True,show_layer_names=True, show_layer_activations=True,expand_nested=False, dpi=100, show_trainable=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
critic.summary(expand_nested=True, show_trainable=True)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer (InputLayer)    │ (None, 4)             │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_3 (Dense)             │ (None, 64)            │        320 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_4 (Dense)             │ (None, 64)            │      4,160 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_5 (Dense)             │ (None, 1)             │         65 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ squeeze (Squeeze)           │ (None)                │          0 │   -   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 4,545 (17.75 KB)
#  Trainable params: 4,545 (17.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
keras.utils.plot_model(critic,show_shapes=True,show_layer_names=True, show_layer_activations=True,expand_nested=False, dpi=100, show_trainable=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## Train

# %%
avg_reward_list = []
acc_ep_reward_list = []

episode = 0
epoch = 0
# Iterate over the number of epochs/episodes
#while (epoch < epochs) and (episode < episodes_max):
while(episode < episodes_max):
    print(f"Epoch: {epoch}")
    # Initialize the sum of the returns, lengths and number of episodes for each epoch
    episode_return = 0.0
    t = 0
    # Iterate over the steps of each epoch
    #while (t < steps_per_epoch):
    while (t < steps_per_epoch) and (episode < episodes_max):
        if render:
            env.render()

        # Get the logits, action, and take one step in the environment
        observation = observation.reshape(1, -1)
        logits, action = sample_action(observation)
        #observation_new, reward, done, _, _ = env.step(action[0].numpy())
        observation_new, reward, done, _ ,torque_wanted, torque_actual= env.step(action[0].numpy().item())
        x_obs = observation_new[0]
        reward= reward*(x_obs>-0.1 and x_obs<0.1)
        episode_return += reward

        # Get the value and log-probability of the action
        value_t = critic(observation)
        logprobability_t = logprobabilities(logits, action)
        # Store obs, act, rew, v_t, logp_pi_t
        buffer.store(observation, action, reward, value_t, logprobability_t)
        # Update the observation
        observation = observation_new

        # Finish trajectory if reached to a terminal state
        terminal = done
        if terminal or (t == steps_per_epoch - 1) or ((t+1)%steps_per_episode_goal==0):
            #print(f"Episode: {episode}; Acc. Reward: {episode_return:.2f}")
            acc_ep_reward_list.append(episode_return)
            avg_return = round(np.mean(acc_ep_reward_list[-40:]))
            avg_reward_list.append(avg_return)
            episode_return = 0.0
            episode += 1
        #observation, _ = env.reset()
        if terminal or (t == steps_per_epoch - 1):# not necessarily (t+1)%steps_per_episode_goal==0
            last_value = 0 if done else critic(observation.reshape(1, -1))
            buffer.finish_trajectory(last_value)
            observation = env.reset()
            print(f"Episode: {episode}; Acc. Reward: {avg_return:.1f}; Pole fell: {terminal}")
            #acc_ep_reward_list.append(episode_return)
            #print(f"Episode: {episode} ;Acc. Reward: {episode_return:.1f}")
            #episode_return = 0.0
        t+=1
        #if episode >= episodes_max:
        #  break

    # Get values from the buffer
    (
        observation_buffer,
        action_buffer,
        advantage_buffer,
        return_buffer,
        logprobability_buffer,
    ) = buffer.get()

    # Update the policy and implement early stopping using KL divergence
    for _ in range(train_policy_iterations):
        kl = train_policy(
            observation_buffer, action_buffer, logprobability_buffer, advantage_buffer
        )
        if kl > 1.5 * target_kl:
            # Early Stopping
            break

    # Update the value function
    for _ in range(train_value_iterations):
        train_value_function(observation_buffer, return_buffer)
    epoch+=1
# Out:
# Epoch: 0
# Episode: 1; Acc. Reward: 10.0; Pole fell: True
# Episode: 2; Acc. Reward: 10.0; Pole fell: True
# Episode: 3; Acc. Reward: 11.0; Pole fell: True
# Episode: 4; Acc. Reward: 11.0; Pole fell: True
# Episode: 5; Acc. Reward: 13.0; Pole fell: True
# Episode: 6; Acc. Reward: 14.0; Pole fell: True
# Episode: 7; Acc. Reward: 14.0; Pole fell: True
# Episode: 8; Acc. Reward: 13.0; Pole fell: True
# Episode: 9; Acc. Reward: 12.0; Pole fell: True
# Episode: 10; Acc. Reward: 12.0; Pole fell: True
# Episode: 11; Acc. Reward: 13.0; Pole fell: True
# Episode: 12; Acc. Reward: 14.0; Pole fell: True
# Episode: 13; Acc. Reward: 14.0; Pole fell: True
# Episode: 14; Acc. Reward: 14.0; Pole fell: True
# Episode: 15; Acc. Reward: 14.0; Pole fell: True
# Episode: 16; Acc. Reward: 14.0; Pole fell: True
# Episode: 17; Acc. Reward: 14.0; Pole fell: True
# Episode: 18; Acc. Reward: 14.0; Pole fell: True
# Episode: 19; Acc. Reward: 14.0; Pole fell: True
# Episode: 20; Acc. Reward: 14.0; Pole fell: True
# Episode: 21; Acc. Reward: 14.0; Pole fell: True
# Episode: 22; Acc. Reward: 14.0; Pole fell: True
# Episode: 23; Acc. Reward: 14.0; Pole fell: True
# Episode: 24; Acc. Reward: 14.0; Pole fell: True
# Episode: 25; Acc. Reward: 14.0; Pole fell: True
# Episode: 26; Acc. Reward: 14.0; Pole fell: True
# Episode: 27; Acc. Reward: 14.0; Pole fell: True
# Episode: 28; Acc. Reward: 13.0; Pole fell: True
# Episode: 29; Acc. Reward: 13.0; Pole fell: True
# Episode: 31; Acc. Reward: 13.0; Pole fell: True
# Episode: 32; Acc. Reward: 13.0; Pole fell: True
# Episode: 33; Acc. Reward: 13.0; Pole fell: True
# Episode: 34; Acc. Reward: 13.0; Pole fell: True
# Episode: 35; Acc. Reward: 13.0; Pole fell: True
# Episode: 36; Acc. Reward: 12.0; Pole fell: True
# Episode: 37; Acc. Reward: 12.0; Pole fell: True
# Episode: 38; Acc. Reward: 12.0; Pole fell: True
# Episode: 39; Acc. Reward: 12.0; Pole fell: True
# Episode: 40; Acc. Reward: 12.0; Pole fell: True
# Episode: 41; Acc. Reward: 13.0; Pole fell: True
# Episode: 42; Acc. Reward: 13.0; Pole fell: True
# Episode: 43; Acc. Reward: 13.0; Pole fell: True
# Episode: 44; Acc. Reward: 12.0; Pole fell: True
# Episode: 45; Acc. Reward: 12.0; Pole fell: True
# Episode: 46; Acc. Reward: 12.0; Pole fell: True
# Episode: 47; Acc. Reward: 12.0; Pole fell: True
# Episode: 48; Acc. Reward: 12.0; Pole fell: True
# Episode: 49; Acc. Reward: 12.0; Pole fell: True
# Episode: 50; Acc. Reward: 12.0; Pole fell: True
# Episode: 51; Acc. Reward: 12.0; Pole fell: True
# Episode: 52; Acc. Reward: 12.0; Pole fell: True
# Episode: 53; Acc. Reward: 11.0; Pole fell: True
# Episode: 54; Acc. Reward: 11.0; Pole fell: True
# Episode: 55; Acc. Reward: 11.0; Pole fell: True
# Episode: 56; Acc. Reward: 11.0; Pole fell: True
# Episode: 57; Acc. Reward: 11.0; Pole fell: True
# Episode: 58; Acc. Reward: 11.0; Pole fell: True
# Episode: 59; Acc. Reward: 11.0; Pole fell: True
# Episode: 60; Acc. Reward: 11.0; Pole fell: True
# Episode: 61; Acc. Reward: 11.0; Pole fell: True
# Episode: 62; Acc. Reward: 11.0; Pole fell: True
# Episode: 63; Acc. Reward: 11.0; Pole fell: True
# Episode: 64; Acc. Reward: 12.0; Pole fell: True
# Episode: 65; Acc. Reward: 11.0; Pole fell: True
# Episode: 66; Acc. Reward: 11.0; Pole fell: True
# Episode: 67; Acc. Reward: 11.0; Pole fell: True
# Episode: 68; Acc. Reward: 11.0; Pole fell: True
# Episode: 69; Acc. Reward: 11.0; Pole fell: True
# Episode: 70; Acc. Reward: 11.0; Pole fell: True
# Episode: 71; Acc. Reward: 12.0; Pole fell: True
# Episode: 72; Acc. Reward: 12.0; Pole fell: True
# Episode: 73; Acc. Reward: 11.0; Pole fell: True
# Episode: 74; Acc. Reward: 12.0; Pole fell: True
# Episode: 75; Acc. Reward: 12.0; Pole fell: True
# Episode: 76; Acc. Reward: 12.0; Pole fell: True
# Episode: 77; Acc. Reward: 12.0; Pole fell: True
# Episode: 78; Acc. Reward: 12.0; Pole fell: True
# Episode: 79; Acc. Reward: 12.0; Pole fell: True
# Episode: 80; Acc. Reward: 12.0; Pole fell: True
# Episode: 81; Acc. Reward: 11.0; Pole fell: True
# Episode: 82; Acc. Reward: 11.0; Pole fell: True
# Episode: 83; Acc. Reward: 11.0; Pole fell: True
# Episode: 84; Acc. Reward: 12.0; Pole fell: True
# Episode: 85; Acc. Reward: 12.0; Pole fell: True
# Episode: 86; Acc. Reward: 12.0; Pole fell: True
# Episode: 87; Acc. Reward: 12.0; Pole fell: True
# Episode: 88; Acc. Reward: 12.0; Pole fell: True
# Episode: 89; Acc. Reward: 13.0; Pole fell: True
# Episode: 90; Acc. Reward: 13.0; Pole fell: True
# Episode: 91; Acc. Reward: 13.0; Pole fell: True
# Episode: 92; Acc. Reward: 13.0; Pole fell: True
# Episode: 93; Acc. Reward: 13.0; Pole fell: True
# Episode: 94; Acc. Reward: 12.0; Pole fell: True
# Episode: 95; Acc. Reward: 12.0; Pole fell: True
# Episode: 96; Acc. Reward: 13.0; Pole fell: True
# Episode: 97; Acc. Reward: 13.0; Pole fell: True
# Episode: 99; Acc. Reward: 13.0; Pole fell: True
# Episode: 100; Acc. Reward: 13.0; Pole fell: True
# Episode: 101; Acc. Reward: 13.0; Pole fell: True
# Episode: 102; Acc. Reward: 13.0; Pole fell: True
# Episode: 103; Acc. Reward: 13.0; Pole fell: True
# Episode: 104; Acc. Reward: 13.0; Pole fell: True
# Episode: 105; Acc. Reward: 13.0; Pole fell: True
# Episode: 106; Acc. Reward: 13.0; Pole fell: True
# Episode: 107; Acc. Reward: 13.0; Pole fell: True
# Episode: 108; Acc. Reward: 13.0; Pole fell: True
# Episode: 109; Acc. Reward: 13.0; Pole fell: True
# Episode: 110; Acc. Reward: 13.0; Pole fell: True
# Episode: 111; Acc. Reward: 13.0; Pole fell: True
# Episode: 112; Acc. Reward: 13.0; Pole fell: True
# Episode: 113; Acc. Reward: 13.0; Pole fell: True
# Episode: 114; Acc. Reward: 13.0; Pole fell: True
# Episode: 115; Acc. Reward: 13.0; Pole fell: True
# Episode: 116; Acc. Reward: 13.0; Pole fell: True
# Episode: 117; Acc. Reward: 13.0; Pole fell: True
# Episode: 118; Acc. Reward: 13.0; Pole fell: True
# Episode: 119; Acc. Reward: 14.0; Pole fell: True
# Episode: 120; Acc. Reward: 14.0; Pole fell: True
# Episode: 121; Acc. Reward: 14.0; Pole fell: True
# Episode: 122; Acc. Reward: 14.0; Pole fell: True
# Episode: 123; Acc. Reward: 14.0; Pole fell: True
# Episode: 124; Acc. Reward: 13.0; Pole fell: True
# Episode: 125; Acc. Reward: 14.0; Pole fell: True
# Episode: 126; Acc. Reward: 14.0; Pole fell: True
# Episode: 127; Acc. Reward: 14.0; Pole fell: True
# Episode: 128; Acc. Reward: 14.0; Pole fell: True
# Episode: 129; Acc. Reward: 13.0; Pole fell: True
# Episode: 131; Acc. Reward: 13.0; Pole fell: True
# Episode: 132; Acc. Reward: 13.0; Pole fell: True
# Episode: 133; Acc. Reward: 13.0; Pole fell: True
# Episode: 134; Acc. Reward: 13.0; Pole fell: True
# Episode: 135; Acc. Reward: 14.0; Pole fell: True
# Episode: 136; Acc. Reward: 14.0; Pole fell: True
# Episode: 137; Acc. Reward: 14.0; Pole fell: True
# Episode: 138; Acc. Reward: 13.0; Pole fell: True
# Episode: 139; Acc. Reward: 13.0; Pole fell: True
# Episode: 140; Acc. Reward: 13.0; Pole fell: True
# Episode: 141; Acc. Reward: 13.0; Pole fell: True
# Episode: 142; Acc. Reward: 13.0; Pole fell: True
# Episode: 143; Acc. Reward: 13.0; Pole fell: True
# Episode: 144; Acc. Reward: 13.0; Pole fell: True
# Episode: 145; Acc. Reward: 13.0; Pole fell: True
# Episode: 146; Acc. Reward: 13.0; Pole fell: True
# Episode: 147; Acc. Reward: 14.0; Pole fell: True
# Episode: 148; Acc. Reward: 13.0; Pole fell: True
# Episode: 149; Acc. Reward: 13.0; Pole fell: True
# Episode: 150; Acc. Reward: 14.0; Pole fell: True
# Episode: 151; Acc. Reward: 14.0; Pole fell: True
# Episode: 152; Acc. Reward: 14.0; Pole fell: True
# Episode: 153; Acc. Reward: 14.0; Pole fell: True
# Episode: 154; Acc. Reward: 14.0; Pole fell: True
# Episode: 155; Acc. Reward: 14.0; Pole fell: True
# Episode: 156; Acc. Reward: 14.0; Pole fell: True
# Episode: 157; Acc. Reward: 14.0; Pole fell: True
# Episode: 158; Acc. Reward: 14.0; Pole fell: True
# Episode: 159; Acc. Reward: 13.0; Pole fell: True
# Episode: 160; Acc. Reward: 13.0; Pole fell: True
# Episode: 161; Acc. Reward: 13.0; Pole fell: True
# Episode: 162; Acc. Reward: 13.0; Pole fell: True
# Episode: 163; Acc. Reward: 14.0; Pole fell: True
# Episode: 164; Acc. Reward: 14.0; Pole fell: True
# Episode: 165; Acc. Reward: 14.0; Pole fell: True
# Episode: 166; Acc. Reward: 14.0; Pole fell: True
# Episode: 167; Acc. Reward: 13.0; Pole fell: True
# Episode: 168; Acc. Reward: 14.0; Pole fell: True
# Episode: 169; Acc. Reward: 13.0; Pole fell: True
# Episode: 170; Acc. Reward: 13.0; Pole fell: True
# Episode: 171; Acc. Reward: 13.0; Pole fell: True
# Episode: 172; Acc. Reward: 13.0; Pole fell: True
# Episode: 173; Acc. Reward: 13.0; Pole fell: True
# Episode: 174; Acc. Reward: 13.0; Pole fell: True
# Episode: 175; Acc. Reward: 13.0; Pole fell: True
# Episode: 176; Acc. Reward: 13.0; Pole fell: True
# Episode: 177; Acc. Reward: 13.0; Pole fell: True
# Episode: 178; Acc. Reward: 13.0; Pole fell: True
# Episode: 179; Acc. Reward: 13.0; Pole fell: True
# Episode: 180; Acc. Reward: 13.0; Pole fell: True
# Episode: 181; Acc. Reward: 13.0; Pole fell: True
# Episode: 182; Acc. Reward: 13.0; Pole fell: True
# Episode: 183; Acc. Reward: 13.0; Pole fell: True
# Episode: 184; Acc. Reward: 13.0; Pole fell: True
# Episode: 185; Acc. Reward: 13.0; Pole fell: True
# Episode: 186; Acc. Reward: 13.0; Pole fell: True
# Episode: 187; Acc. Reward: 12.0; Pole fell: True
# Episode: 188; Acc. Reward: 12.0; Pole fell: True
# Episode: 189; Acc. Reward: 13.0; Pole fell: True
# Episode: 190; Acc. Reward: 12.0; Pole fell: True
# Episode: 191; Acc. Reward: 12.0; Pole fell: True
# Episode: 192; Acc. Reward: 12.0; Pole fell: True
# Episode: 193; Acc. Reward: 12.0; Pole fell: True
# Episode: 195; Acc. Reward: 12.0; Pole fell: True
# Episode: 196; Acc. Reward: 12.0; Pole fell: True
# Episode: 197; Acc. Reward: 12.0; Pole fell: True
# Episode: 198; Acc. Reward: 12.0; Pole fell: True
# Episode: 199; Acc. Reward: 12.0; Pole fell: True
# Episode: 200; Acc. Reward: 12.0; Pole fell: True
# Episode: 201; Acc. Reward: 12.0; Pole fell: True
# Episode: 202; Acc. Reward: 13.0; Pole fell: True
# Episode: 203; Acc. Reward: 12.0; Pole fell: True
# Episode: 204; Acc. Reward: 12.0; Pole fell: True
# Episode: 205; Acc. Reward: 12.0; Pole fell: True
# Episode: 206; Acc. Reward: 12.0; Pole fell: True
# Episode: 207; Acc. Reward: 12.0; Pole fell: True
# Episode: 208; Acc. Reward: 12.0; Pole fell: True
# Episode: 209; Acc. Reward: 12.0; Pole fell: True
# Episode: 210; Acc. Reward: 12.0; Pole fell: True
# Episode: 211; Acc. Reward: 12.0; Pole fell: True
# Episode: 212; Acc. Reward: 12.0; Pole fell: True
# Episode: 213; Acc. Reward: 12.0; Pole fell: True
# Episode: 214; Acc. Reward: 12.0; Pole fell: True
# Episode: 215; Acc. Reward: 12.0; Pole fell: True
# Episode: 216; Acc. Reward: 12.0; Pole fell: True
# Episode: 217; Acc. Reward: 13.0; Pole fell: True
# Episode: 218; Acc. Reward: 13.0; Pole fell: True
# Episode: 219; Acc. Reward: 13.0; Pole fell: True
# Episode: 220; Acc. Reward: 13.0; Pole fell: True
# Episode: 221; Acc. Reward: 13.0; Pole fell: True
# Episode: 222; Acc. Reward: 13.0; Pole fell: True
# Episode: 223; Acc. Reward: 14.0; Pole fell: True
# Episode: 225; Acc. Reward: 13.0; Pole fell: True
# Episode: 226; Acc. Reward: 13.0; Pole fell: True
# Episode: 227; Acc. Reward: 13.0; Pole fell: True
# Episode: 228; Acc. Reward: 13.0; Pole fell: True
# Episode: 229; Acc. Reward: 13.0; Pole fell: True
# Episode: 230; Acc. Reward: 13.0; Pole fell: True
# Episode: 231; Acc. Reward: 13.0; Pole fell: True
# Episode: 232; Acc. Reward: 13.0; Pole fell: True
# Episode: 233; Acc. Reward: 13.0; Pole fell: True
# Episode: 234; Acc. Reward: 12.0; Pole fell: True
# Episode: 235; Acc. Reward: 13.0; Pole fell: True
# Episode: 236; Acc. Reward: 13.0; Pole fell: True
# Episode: 237; Acc. Reward: 13.0; Pole fell: True
# Episode: 238; Acc. Reward: 13.0; Pole fell: True
# Episode: 239; Acc. Reward: 13.0; Pole fell: True
# Episode: 240; Acc. Reward: 13.0; Pole fell: True
# Episode: 241; Acc. Reward: 12.0; Pole fell: True
# Episode: 242; Acc. Reward: 12.0; Pole fell: True
# Episode: 243; Acc. Reward: 12.0; Pole fell: True
# Episode: 244; Acc. Reward: 12.0; Pole fell: True
# Episode: 245; Acc. Reward: 12.0; Pole fell: True
# Episode: 246; Acc. Reward: 12.0; Pole fell: True
# Episode: 247; Acc. Reward: 12.0; Pole fell: True
# Episode: 248; Acc. Reward: 12.0; Pole fell: True
# Episode: 249; Acc. Reward: 12.0; Pole fell: True
# Episode: 250; Acc. Reward: 12.0; Pole fell: True
# Episode: 251; Acc. Reward: 12.0; Pole fell: True
# Episode: 252; Acc. Reward: 12.0; Pole fell: True
# Episode: 253; Acc. Reward: 12.0; Pole fell: True
# Episode: 254; Acc. Reward: 12.0; Pole fell: True
# Episode: 255; Acc. Reward: 12.0; Pole fell: True
# Episode: 256; Acc. Reward: 12.0; Pole fell: True
# Episode: 257; Acc. Reward: 12.0; Pole fell: True
# Episode: 258; Acc. Reward: 12.0; Pole fell: False
# Epoch: 1
# Episode: 259; Acc. Reward: 12.0; Pole fell: True
# Episode: 260; Acc. Reward: 12.0; Pole fell: True
# Episode: 261; Acc. Reward: 11.0; Pole fell: True
# Episode: 262; Acc. Reward: 12.0; Pole fell: True
# Episode: 263; Acc. Reward: 11.0; Pole fell: True
# Episode: 264; Acc. Reward: 12.0; Pole fell: True
# Episode: 265; Acc. Reward: 12.0; Pole fell: True
# Episode: 266; Acc. Reward: 12.0; Pole fell: True
# Episode: 267; Acc. Reward: 12.0; Pole fell: True
# Episode: 268; Acc. Reward: 12.0; Pole fell: True
# Episode: 269; Acc. Reward: 12.0; Pole fell: True
# Episode: 270; Acc. Reward: 12.0; Pole fell: True
# Episode: 271; Acc. Reward: 13.0; Pole fell: True
# Episode: 272; Acc. Reward: 13.0; Pole fell: True
# Episode: 273; Acc. Reward: 13.0; Pole fell: True
# Episode: 274; Acc. Reward: 13.0; Pole fell: True
# Episode: 275; Acc. Reward: 14.0; Pole fell: True
# Episode: 276; Acc. Reward: 14.0; Pole fell: True
# Episode: 277; Acc. Reward: 14.0; Pole fell: True
# Episode: 278; Acc. Reward: 15.0; Pole fell: True
# Episode: 279; Acc. Reward: 15.0; Pole fell: True
# Episode: 280; Acc. Reward: 15.0; Pole fell: True
# Episode: 281; Acc. Reward: 15.0; Pole fell: True
# Episode: 282; Acc. Reward: 15.0; Pole fell: True
# Episode: 283; Acc. Reward: 15.0; Pole fell: True
# Episode: 284; Acc. Reward: 15.0; Pole fell: True
# Episode: 286; Acc. Reward: 15.0; Pole fell: True
# Episode: 287; Acc. Reward: 15.0; Pole fell: True
# Episode: 288; Acc. Reward: 15.0; Pole fell: True
# Episode: 289; Acc. Reward: 16.0; Pole fell: True
# Episode: 290; Acc. Reward: 16.0; Pole fell: True
# Episode: 291; Acc. Reward: 16.0; Pole fell: True
# Episode: 292; Acc. Reward: 16.0; Pole fell: True
# Episode: 293; Acc. Reward: 17.0; Pole fell: True
# Episode: 294; Acc. Reward: 16.0; Pole fell: True
# Episode: 295; Acc. Reward: 16.0; Pole fell: True
# Episode: 296; Acc. Reward: 16.0; Pole fell: True
# Episode: 297; Acc. Reward: 17.0; Pole fell: True
# Episode: 298; Acc. Reward: 17.0; Pole fell: True
# Episode: 299; Acc. Reward: 17.0; Pole fell: True
# Episode: 300; Acc. Reward: 16.0; Pole fell: True
# Episode: 301; Acc. Reward: 16.0; Pole fell: True
# Episode: 302; Acc. Reward: 16.0; Pole fell: True
# Episode: 303; Acc. Reward: 16.0; Pole fell: True
# Episode: 304; Acc. Reward: 16.0; Pole fell: True
# Episode: 305; Acc. Reward: 17.0; Pole fell: True
# Episode: 306; Acc. Reward: 17.0; Pole fell: True
# Episode: 307; Acc. Reward: 17.0; Pole fell: True
# Episode: 308; Acc. Reward: 17.0; Pole fell: True
# Episode: 309; Acc. Reward: 17.0; Pole fell: True
# Episode: 310; Acc. Reward: 17.0; Pole fell: True
# Episode: 312; Acc. Reward: 16.0; Pole fell: True
# Episode: 313; Acc. Reward: 16.0; Pole fell: True
# Episode: 314; Acc. Reward: 16.0; Pole fell: True
# Episode: 315; Acc. Reward: 15.0; Pole fell: True
# Episode: 316; Acc. Reward: 15.0; Pole fell: True
# Episode: 317; Acc. Reward: 15.0; Pole fell: True
# Episode: 318; Acc. Reward: 15.0; Pole fell: True
# Episode: 319; Acc. Reward: 15.0; Pole fell: True
# Episode: 320; Acc. Reward: 14.0; Pole fell: True
# Episode: 321; Acc. Reward: 14.0; Pole fell: True
# Episode: 322; Acc. Reward: 14.0; Pole fell: True
# Episode: 323; Acc. Reward: 14.0; Pole fell: True
# Episode: 324; Acc. Reward: 14.0; Pole fell: True
# Episode: 325; Acc. Reward: 14.0; Pole fell: True
# Episode: 326; Acc. Reward: 14.0; Pole fell: True
# Episode: 327; Acc. Reward: 14.0; Pole fell: True
# Episode: 328; Acc. Reward: 14.0; Pole fell: True
# Episode: 329; Acc. Reward: 14.0; Pole fell: True
# Episode: 330; Acc. Reward: 14.0; Pole fell: True
# Episode: 331; Acc. Reward: 14.0; Pole fell: True
# Episode: 332; Acc. Reward: 14.0; Pole fell: True
# Episode: 333; Acc. Reward: 14.0; Pole fell: True
# Episode: 334; Acc. Reward: 14.0; Pole fell: True
# Episode: 335; Acc. Reward: 14.0; Pole fell: True
# Episode: 336; Acc. Reward: 14.0; Pole fell: True
# Episode: 337; Acc. Reward: 13.0; Pole fell: True
# Episode: 338; Acc. Reward: 13.0; Pole fell: True
# Episode: 339; Acc. Reward: 13.0; Pole fell: True
# Episode: 340; Acc. Reward: 14.0; Pole fell: True
# Episode: 341; Acc. Reward: 14.0; Pole fell: True
# Episode: 342; Acc. Reward: 14.0; Pole fell: True
# Episode: 344; Acc. Reward: 13.0; Pole fell: True
# Episode: 345; Acc. Reward: 13.0; Pole fell: True
# Episode: 346; Acc. Reward: 13.0; Pole fell: True
# Episode: 347; Acc. Reward: 13.0; Pole fell: True
# Episode: 348; Acc. Reward: 12.0; Pole fell: True
# Episode: 349; Acc. Reward: 13.0; Pole fell: True
# Episode: 350; Acc. Reward: 13.0; Pole fell: True
# Episode: 351; Acc. Reward: 12.0; Pole fell: True
# Episode: 352; Acc. Reward: 13.0; Pole fell: True
# Episode: 353; Acc. Reward: 13.0; Pole fell: True
# Episode: 354; Acc. Reward: 13.0; Pole fell: True
# Episode: 355; Acc. Reward: 13.0; Pole fell: True
# Episode: 356; Acc. Reward: 14.0; Pole fell: True
# Episode: 357; Acc. Reward: 14.0; Pole fell: True
# Episode: 358; Acc. Reward: 14.0; Pole fell: True
# Episode: 359; Acc. Reward: 14.0; Pole fell: True
# Episode: 360; Acc. Reward: 14.0; Pole fell: True
# Episode: 361; Acc. Reward: 14.0; Pole fell: True
# Episode: 362; Acc. Reward: 14.0; Pole fell: True
# Episode: 363; Acc. Reward: 14.0; Pole fell: True
# Episode: 364; Acc. Reward: 14.0; Pole fell: True
# Episode: 365; Acc. Reward: 14.0; Pole fell: True
# Episode: 366; Acc. Reward: 14.0; Pole fell: True
# Episode: 367; Acc. Reward: 15.0; Pole fell: True
# Episode: 369; Acc. Reward: 15.0; Pole fell: True
# Episode: 370; Acc. Reward: 15.0; Pole fell: True
# Episode: 371; Acc. Reward: 15.0; Pole fell: True
# Episode: 372; Acc. Reward: 15.0; Pole fell: True
# Episode: 373; Acc. Reward: 15.0; Pole fell: True
# Episode: 374; Acc. Reward: 15.0; Pole fell: True
# Episode: 375; Acc. Reward: 15.0; Pole fell: True
# Episode: 376; Acc. Reward: 16.0; Pole fell: True
# Episode: 377; Acc. Reward: 16.0; Pole fell: True
# Episode: 378; Acc. Reward: 16.0; Pole fell: True
# Episode: 379; Acc. Reward: 16.0; Pole fell: True
# Episode: 380; Acc. Reward: 15.0; Pole fell: True
# Episode: 381; Acc. Reward: 16.0; Pole fell: True
# Episode: 382; Acc. Reward: 16.0; Pole fell: True
# Episode: 383; Acc. Reward: 16.0; Pole fell: True
# Episode: 384; Acc. Reward: 16.0; Pole fell: True
# Episode: 385; Acc. Reward: 16.0; Pole fell: True
# Episode: 386; Acc. Reward: 16.0; Pole fell: True
# Episode: 387; Acc. Reward: 16.0; Pole fell: True
# Episode: 388; Acc. Reward: 16.0; Pole fell: True
# Episode: 389; Acc. Reward: 16.0; Pole fell: True
# Episode: 390; Acc. Reward: 17.0; Pole fell: True
# Episode: 391; Acc. Reward: 16.0; Pole fell: True
# Episode: 392; Acc. Reward: 16.0; Pole fell: True
# Episode: 393; Acc. Reward: 16.0; Pole fell: True
# Episode: 394; Acc. Reward: 16.0; Pole fell: True
# Episode: 395; Acc. Reward: 16.0; Pole fell: True
# Episode: 396; Acc. Reward: 15.0; Pole fell: True
# Episode: 398; Acc. Reward: 15.0; Pole fell: True
# Episode: 399; Acc. Reward: 15.0; Pole fell: True
# Episode: 400; Acc. Reward: 15.0; Pole fell: True
# Episode: 401; Acc. Reward: 15.0; Pole fell: True
# Episode: 402; Acc. Reward: 15.0; Pole fell: True
# Episode: 403; Acc. Reward: 15.0; Pole fell: True
# Episode: 404; Acc. Reward: 15.0; Pole fell: True
# Episode: 405; Acc. Reward: 15.0; Pole fell: True
# Episode: 406; Acc. Reward: 15.0; Pole fell: True
# Episode: 407; Acc. Reward: 15.0; Pole fell: True
# Episode: 408; Acc. Reward: 14.0; Pole fell: True
# Episode: 409; Acc. Reward: 14.0; Pole fell: True
# Episode: 410; Acc. Reward: 14.0; Pole fell: True
# Episode: 411; Acc. Reward: 14.0; Pole fell: True
# Episode: 412; Acc. Reward: 14.0; Pole fell: True
# Episode: 413; Acc. Reward: 14.0; Pole fell: True
# Episode: 414; Acc. Reward: 14.0; Pole fell: True
# Episode: 415; Acc. Reward: 14.0; Pole fell: True
# Episode: 416; Acc. Reward: 13.0; Pole fell: True
# Episode: 417; Acc. Reward: 13.0; Pole fell: True
# Episode: 418; Acc. Reward: 13.0; Pole fell: True
# Episode: 419; Acc. Reward: 13.0; Pole fell: True
# Episode: 420; Acc. Reward: 13.0; Pole fell: True
# Episode: 421; Acc. Reward: 13.0; Pole fell: True
# Episode: 422; Acc. Reward: 13.0; Pole fell: True
# Episode: 423; Acc. Reward: 13.0; Pole fell: True
# Episode: 425; Acc. Reward: 13.0; Pole fell: True
# Episode: 426; Acc. Reward: 13.0; Pole fell: True
# Episode: 427; Acc. Reward: 13.0; Pole fell: True
# Episode: 428; Acc. Reward: 13.0; Pole fell: True
# Episode: 429; Acc. Reward: 13.0; Pole fell: True
# Episode: 430; Acc. Reward: 13.0; Pole fell: True
# Episode: 431; Acc. Reward: 13.0; Pole fell: True
# Episode: 432; Acc. Reward: 14.0; Pole fell: True
# Episode: 433; Acc. Reward: 14.0; Pole fell: True
# Episode: 434; Acc. Reward: 14.0; Pole fell: True
# Episode: 435; Acc. Reward: 15.0; Pole fell: True
# Episode: 436; Acc. Reward: 15.0; Pole fell: True
# Episode: 437; Acc. Reward: 15.0; Pole fell: True
# Episode: 438; Acc. Reward: 16.0; Pole fell: True
# Episode: 439; Acc. Reward: 15.0; Pole fell: True
# Episode: 440; Acc. Reward: 15.0; Pole fell: True
# Episode: 441; Acc. Reward: 15.0; Pole fell: True
# Episode: 442; Acc. Reward: 15.0; Pole fell: True
# Episode: 443; Acc. Reward: 15.0; Pole fell: True
# Episode: 444; Acc. Reward: 15.0; Pole fell: True
# Episode: 445; Acc. Reward: 15.0; Pole fell: True
# Episode: 446; Acc. Reward: 15.0; Pole fell: True
# Episode: 447; Acc. Reward: 14.0; Pole fell: True
# Episode: 449; Acc. Reward: 15.0; Pole fell: True
# Episode: 450; Acc. Reward: 15.0; Pole fell: True
# Episode: 451; Acc. Reward: 15.0; Pole fell: True
# Episode: 452; Acc. Reward: 15.0; Pole fell: True
# Episode: 453; Acc. Reward: 15.0; Pole fell: True
# Episode: 454; Acc. Reward: 15.0; Pole fell: True
# Episode: 455; Acc. Reward: 15.0; Pole fell: True
# Episode: 456; Acc. Reward: 16.0; Pole fell: True
# Episode: 457; Acc. Reward: 16.0; Pole fell: True
# Episode: 458; Acc. Reward: 16.0; Pole fell: True
# Episode: 459; Acc. Reward: 16.0; Pole fell: True
# Episode: 460; Acc. Reward: 16.0; Pole fell: True
# Episode: 461; Acc. Reward: 16.0; Pole fell: True
# Episode: 462; Acc. Reward: 16.0; Pole fell: True
# Episode: 463; Acc. Reward: 16.0; Pole fell: True
# Episode: 464; Acc. Reward: 17.0; Pole fell: True
# Episode: 465; Acc. Reward: 17.0; Pole fell: True
# Episode: 466; Acc. Reward: 17.0; Pole fell: True
# Episode: 467; Acc. Reward: 18.0; Pole fell: True
# Episode: 468; Acc. Reward: 18.0; Pole fell: True
# Episode: 469; Acc. Reward: 18.0; Pole fell: True
# Episode: 470; Acc. Reward: 18.0; Pole fell: True
# Episode: 471; Acc. Reward: 18.0; Pole fell: True
# Episode: 472; Acc. Reward: 17.0; Pole fell: False
# Epoch: 2
# Episode: 473; Acc. Reward: 18.0; Pole fell: True
# Episode: 474; Acc. Reward: 18.0; Pole fell: True
# Episode: 475; Acc. Reward: 17.0; Pole fell: True
# Episode: 476; Acc. Reward: 17.0; Pole fell: True
# Episode: 477; Acc. Reward: 17.0; Pole fell: True
# Episode: 478; Acc. Reward: 17.0; Pole fell: True
# Episode: 479; Acc. Reward: 17.0; Pole fell: True
# Episode: 480; Acc. Reward: 17.0; Pole fell: True
# Episode: 481; Acc. Reward: 18.0; Pole fell: True
# Episode: 482; Acc. Reward: 18.0; Pole fell: True
# Episode: 483; Acc. Reward: 19.0; Pole fell: True
# Episode: 484; Acc. Reward: 19.0; Pole fell: True
# Episode: 485; Acc. Reward: 19.0; Pole fell: True
# Episode: 486; Acc. Reward: 19.0; Pole fell: True
# Episode: 487; Acc. Reward: 20.0; Pole fell: True
# Episode: 488; Acc. Reward: 20.0; Pole fell: True
# Episode: 489; Acc. Reward: 19.0; Pole fell: True
# Episode: 491; Acc. Reward: 19.0; Pole fell: True
# Episode: 492; Acc. Reward: 19.0; Pole fell: True
# Episode: 493; Acc. Reward: 20.0; Pole fell: True
# Episode: 494; Acc. Reward: 20.0; Pole fell: True
# Episode: 495; Acc. Reward: 20.0; Pole fell: True
# Episode: 496; Acc. Reward: 20.0; Pole fell: True
# Episode: 497; Acc. Reward: 20.0; Pole fell: True
# Episode: 498; Acc. Reward: 19.0; Pole fell: True
# Episode: 499; Acc. Reward: 20.0; Pole fell: True
# Episode: 500; Acc. Reward: 19.0; Pole fell: True
# Episode: 501; Acc. Reward: 19.0; Pole fell: True
# Episode: 502; Acc. Reward: 19.0; Pole fell: True
# Episode: 503; Acc. Reward: 19.0; Pole fell: True
# Episode: 504; Acc. Reward: 19.0; Pole fell: True
# Episode: 505; Acc. Reward: 19.0; Pole fell: True
# Episode: 506; Acc. Reward: 19.0; Pole fell: True
# Episode: 507; Acc. Reward: 18.0; Pole fell: True
# Episode: 508; Acc. Reward: 19.0; Pole fell: True
# Episode: 509; Acc. Reward: 19.0; Pole fell: True
# Episode: 510; Acc. Reward: 19.0; Pole fell: True
# Episode: 511; Acc. Reward: 19.0; Pole fell: True
# Episode: 512; Acc. Reward: 19.0; Pole fell: True
# Episode: 514; Acc. Reward: 18.0; Pole fell: True
# Episode: 515; Acc. Reward: 18.0; Pole fell: True
# Episode: 516; Acc. Reward: 18.0; Pole fell: True
# Episode: 517; Acc. Reward: 18.0; Pole fell: True
# Episode: 518; Acc. Reward: 18.0; Pole fell: True
# Episode: 519; Acc. Reward: 18.0; Pole fell: True
# Episode: 520; Acc. Reward: 18.0; Pole fell: True
# Episode: 521; Acc. Reward: 18.0; Pole fell: True
# Episode: 522; Acc. Reward: 18.0; Pole fell: True
# Episode: 523; Acc. Reward: 17.0; Pole fell: True
# Episode: 524; Acc. Reward: 17.0; Pole fell: True
# Episode: 525; Acc. Reward: 17.0; Pole fell: True
# Episode: 526; Acc. Reward: 17.0; Pole fell: True
# Episode: 527; Acc. Reward: 16.0; Pole fell: True
# Episode: 528; Acc. Reward: 16.0; Pole fell: True
# Episode: 529; Acc. Reward: 17.0; Pole fell: True
# Episode: 530; Acc. Reward: 17.0; Pole fell: True
# Episode: 531; Acc. Reward: 17.0; Pole fell: True
# Episode: 532; Acc. Reward: 17.0; Pole fell: True
# Episode: 533; Acc. Reward: 17.0; Pole fell: True
# Episode: 534; Acc. Reward: 17.0; Pole fell: True
# Episode: 535; Acc. Reward: 17.0; Pole fell: True
# Episode: 536; Acc. Reward: 17.0; Pole fell: True
# Episode: 538; Acc. Reward: 18.0; Pole fell: True
# Episode: 539; Acc. Reward: 18.0; Pole fell: True
# Episode: 540; Acc. Reward: 18.0; Pole fell: True
# Episode: 541; Acc. Reward: 17.0; Pole fell: True
# Episode: 542; Acc. Reward: 18.0; Pole fell: True
# Episode: 543; Acc. Reward: 18.0; Pole fell: True
# Episode: 544; Acc. Reward: 18.0; Pole fell: True
# Episode: 545; Acc. Reward: 18.0; Pole fell: True
# Episode: 546; Acc. Reward: 18.0; Pole fell: True
# Episode: 547; Acc. Reward: 18.0; Pole fell: True
# Episode: 548; Acc. Reward: 17.0; Pole fell: True
# Episode: 549; Acc. Reward: 17.0; Pole fell: True
# Episode: 550; Acc. Reward: 17.0; Pole fell: True
# Episode: 551; Acc. Reward: 17.0; Pole fell: True
# Episode: 552; Acc. Reward: 17.0; Pole fell: True
# Episode: 553; Acc. Reward: 17.0; Pole fell: True
# Episode: 554; Acc. Reward: 17.0; Pole fell: True
# Episode: 555; Acc. Reward: 17.0; Pole fell: True
# Episode: 556; Acc. Reward: 17.0; Pole fell: True
# Episode: 557; Acc. Reward: 17.0; Pole fell: True
# Episode: 558; Acc. Reward: 17.0; Pole fell: True
# Episode: 559; Acc. Reward: 17.0; Pole fell: True
# Episode: 560; Acc. Reward: 17.0; Pole fell: True
# Episode: 561; Acc. Reward: 17.0; Pole fell: True
# Episode: 562; Acc. Reward: 17.0; Pole fell: True
# Episode: 563; Acc. Reward: 17.0; Pole fell: True
# Episode: 565; Acc. Reward: 17.0; Pole fell: True
# Episode: 566; Acc. Reward: 17.0; Pole fell: True
# Episode: 567; Acc. Reward: 17.0; Pole fell: True
# Episode: 568; Acc. Reward: 17.0; Pole fell: True
# Episode: 569; Acc. Reward: 16.0; Pole fell: True
# Episode: 570; Acc. Reward: 16.0; Pole fell: True
# Episode: 571; Acc. Reward: 16.0; Pole fell: True
# Episode: 572; Acc. Reward: 16.0; Pole fell: True
# Episode: 573; Acc. Reward: 16.0; Pole fell: True
# Episode: 574; Acc. Reward: 16.0; Pole fell: True
# Episode: 575; Acc. Reward: 15.0; Pole fell: True
# Episode: 576; Acc. Reward: 15.0; Pole fell: True
# Episode: 577; Acc. Reward: 15.0; Pole fell: True
# Episode: 578; Acc. Reward: 14.0; Pole fell: True
# Episode: 579; Acc. Reward: 15.0; Pole fell: True
# Episode: 580; Acc. Reward: 15.0; Pole fell: True
# Episode: 581; Acc. Reward: 15.0; Pole fell: True
# Episode: 582; Acc. Reward: 15.0; Pole fell: True
# Episode: 583; Acc. Reward: 15.0; Pole fell: True
# Episode: 584; Acc. Reward: 15.0; Pole fell: True
# Episode: 585; Acc. Reward: 15.0; Pole fell: True
# Episode: 587; Acc. Reward: 15.0; Pole fell: True
# Episode: 588; Acc. Reward: 15.0; Pole fell: True
# Episode: 589; Acc. Reward: 16.0; Pole fell: True
# Episode: 590; Acc. Reward: 16.0; Pole fell: True
# Episode: 591; Acc. Reward: 16.0; Pole fell: True
# Episode: 592; Acc. Reward: 17.0; Pole fell: True
# Episode: 593; Acc. Reward: 17.0; Pole fell: True
# Episode: 594; Acc. Reward: 17.0; Pole fell: True
# Episode: 595; Acc. Reward: 17.0; Pole fell: True
# Episode: 596; Acc. Reward: 18.0; Pole fell: True
# Episode: 597; Acc. Reward: 18.0; Pole fell: True
# Episode: 598; Acc. Reward: 18.0; Pole fell: True
# Episode: 599; Acc. Reward: 18.0; Pole fell: True
# Episode: 600; Acc. Reward: 18.0; Pole fell: True
# Episode: 601; Acc. Reward: 19.0; Pole fell: True
# Episode: 602; Acc. Reward: 19.0; Pole fell: True
# Episode: 603; Acc. Reward: 19.0; Pole fell: True
# Episode: 604; Acc. Reward: 19.0; Pole fell: True
# Episode: 605; Acc. Reward: 19.0; Pole fell: True
# Episode: 607; Acc. Reward: 19.0; Pole fell: True
# Episode: 608; Acc. Reward: 19.0; Pole fell: True
# Episode: 609; Acc. Reward: 19.0; Pole fell: True
# Episode: 610; Acc. Reward: 19.0; Pole fell: True
# Episode: 611; Acc. Reward: 19.0; Pole fell: True
# Episode: 612; Acc. Reward: 20.0; Pole fell: True
# Episode: 613; Acc. Reward: 20.0; Pole fell: True
# Episode: 614; Acc. Reward: 20.0; Pole fell: True
# Episode: 615; Acc. Reward: 21.0; Pole fell: True
# Episode: 616; Acc. Reward: 21.0; Pole fell: True
# Episode: 617; Acc. Reward: 22.0; Pole fell: True
# Episode: 618; Acc. Reward: 22.0; Pole fell: True
# Episode: 619; Acc. Reward: 21.0; Pole fell: True
# Episode: 620; Acc. Reward: 21.0; Pole fell: True
# Episode: 621; Acc. Reward: 21.0; Pole fell: True
# Episode: 622; Acc. Reward: 21.0; Pole fell: True
# Episode: 623; Acc. Reward: 20.0; Pole fell: True
# Episode: 624; Acc. Reward: 20.0; Pole fell: True
# Episode: 625; Acc. Reward: 20.0; Pole fell: True
# Episode: 626; Acc. Reward: 20.0; Pole fell: True
# Episode: 627; Acc. Reward: 20.0; Pole fell: True
# Episode: 629; Acc. Reward: 20.0; Pole fell: True
# Episode: 630; Acc. Reward: 19.0; Pole fell: True
# Episode: 631; Acc. Reward: 19.0; Pole fell: True
# Episode: 632; Acc. Reward: 19.0; Pole fell: True
# Episode: 633; Acc. Reward: 18.0; Pole fell: True
# Episode: 634; Acc. Reward: 19.0; Pole fell: True
# Episode: 635; Acc. Reward: 18.0; Pole fell: True
# Episode: 636; Acc. Reward: 18.0; Pole fell: True
# Episode: 637; Acc. Reward: 18.0; Pole fell: True
# Episode: 638; Acc. Reward: 18.0; Pole fell: True
# Episode: 639; Acc. Reward: 17.0; Pole fell: True
# Episode: 640; Acc. Reward: 18.0; Pole fell: True
# Episode: 641; Acc. Reward: 18.0; Pole fell: True
# Episode: 642; Acc. Reward: 18.0; Pole fell: True
# Episode: 643; Acc. Reward: 17.0; Pole fell: True
# Episode: 644; Acc. Reward: 17.0; Pole fell: True
# Episode: 645; Acc. Reward: 17.0; Pole fell: True
# Episode: 646; Acc. Reward: 17.0; Pole fell: True
# Episode: 647; Acc. Reward: 17.0; Pole fell: True
# Episode: 648; Acc. Reward: 17.0; Pole fell: True
# Episode: 649; Acc. Reward: 17.0; Pole fell: True
# Episode: 650; Acc. Reward: 17.0; Pole fell: True
# Episode: 651; Acc. Reward: 17.0; Pole fell: True
# Episode: 652; Acc. Reward: 16.0; Pole fell: True
# Episode: 653; Acc. Reward: 16.0; Pole fell: True
# Episode: 654; Acc. Reward: 16.0; Pole fell: False
# Epoch: 3
# Episode: 655; Acc. Reward: 16.0; Pole fell: True
# Episode: 656; Acc. Reward: 16.0; Pole fell: True
# Episode: 657; Acc. Reward: 15.0; Pole fell: True
# Episode: 658; Acc. Reward: 16.0; Pole fell: True
# Episode: 659; Acc. Reward: 16.0; Pole fell: True
# Episode: 660; Acc. Reward: 16.0; Pole fell: True
# Episode: 661; Acc. Reward: 16.0; Pole fell: True
# Episode: 662; Acc. Reward: 16.0; Pole fell: True
# Episode: 663; Acc. Reward: 16.0; Pole fell: True
# Episode: 664; Acc. Reward: 16.0; Pole fell: True
# Episode: 665; Acc. Reward: 17.0; Pole fell: True
# Episode: 666; Acc. Reward: 16.0; Pole fell: True
# Episode: 667; Acc. Reward: 17.0; Pole fell: True
# Episode: 668; Acc. Reward: 17.0; Pole fell: True
# Episode: 669; Acc. Reward: 17.0; Pole fell: True
# Episode: 670; Acc. Reward: 17.0; Pole fell: True
# Episode: 671; Acc. Reward: 18.0; Pole fell: True
# Episode: 672; Acc. Reward: 18.0; Pole fell: True
# Episode: 674; Acc. Reward: 18.0; Pole fell: True
# Episode: 675; Acc. Reward: 18.0; Pole fell: True
# Episode: 676; Acc. Reward: 18.0; Pole fell: True
# Episode: 677; Acc. Reward: 19.0; Pole fell: True
# Episode: 678; Acc. Reward: 19.0; Pole fell: True
# Episode: 679; Acc. Reward: 19.0; Pole fell: True
# Episode: 680; Acc. Reward: 19.0; Pole fell: True
# Episode: 681; Acc. Reward: 18.0; Pole fell: True
# Episode: 682; Acc. Reward: 19.0; Pole fell: True
# Episode: 683; Acc. Reward: 19.0; Pole fell: True
# Episode: 684; Acc. Reward: 20.0; Pole fell: True
# Episode: 685; Acc. Reward: 20.0; Pole fell: True
# Episode: 686; Acc. Reward: 20.0; Pole fell: True
# Episode: 687; Acc. Reward: 20.0; Pole fell: True
# Episode: 688; Acc. Reward: 20.0; Pole fell: True
# Episode: 690; Acc. Reward: 20.0; Pole fell: True
# Episode: 691; Acc. Reward: 20.0; Pole fell: True
# Episode: 692; Acc. Reward: 20.0; Pole fell: True
# Episode: 693; Acc. Reward: 21.0; Pole fell: True
# Episode: 694; Acc. Reward: 21.0; Pole fell: True
# Episode: 695; Acc. Reward: 21.0; Pole fell: True
# Episode: 696; Acc. Reward: 21.0; Pole fell: True
# Episode: 697; Acc. Reward: 22.0; Pole fell: True
# Episode: 698; Acc. Reward: 22.0; Pole fell: True
# Episode: 699; Acc. Reward: 23.0; Pole fell: True
# Episode: 700; Acc. Reward: 23.0; Pole fell: True
# Episode: 701; Acc. Reward: 24.0; Pole fell: True
# Episode: 703; Acc. Reward: 24.0; Pole fell: True
# Episode: 704; Acc. Reward: 23.0; Pole fell: True
# Episode: 705; Acc. Reward: 24.0; Pole fell: True
# Episode: 706; Acc. Reward: 24.0; Pole fell: True
# Episode: 707; Acc. Reward: 24.0; Pole fell: True
# Episode: 708; Acc. Reward: 24.0; Pole fell: True
# Episode: 709; Acc. Reward: 24.0; Pole fell: True
# Episode: 710; Acc. Reward: 25.0; Pole fell: True
# Episode: 711; Acc. Reward: 25.0; Pole fell: True
# Episode: 712; Acc. Reward: 24.0; Pole fell: True
# Episode: 713; Acc. Reward: 24.0; Pole fell: True
# Episode: 714; Acc. Reward: 24.0; Pole fell: True
# Episode: 715; Acc. Reward: 24.0; Pole fell: True
# Episode: 716; Acc. Reward: 24.0; Pole fell: True
# Episode: 717; Acc. Reward: 24.0; Pole fell: True
# Episode: 718; Acc. Reward: 25.0; Pole fell: True
# Episode: 720; Acc. Reward: 25.0; Pole fell: True
# Episode: 721; Acc. Reward: 25.0; Pole fell: True
# Episode: 722; Acc. Reward: 25.0; Pole fell: True
# Episode: 723; Acc. Reward: 25.0; Pole fell: True
# Episode: 724; Acc. Reward: 24.0; Pole fell: True
# Episode: 725; Acc. Reward: 24.0; Pole fell: True
# Episode: 726; Acc. Reward: 25.0; Pole fell: True
# Episode: 727; Acc. Reward: 24.0; Pole fell: True
# Episode: 728; Acc. Reward: 25.0; Pole fell: True
# Episode: 729; Acc. Reward: 25.0; Pole fell: True
# Episode: 730; Acc. Reward: 25.0; Pole fell: True
# Episode: 731; Acc. Reward: 26.0; Pole fell: True
# Episode: 732; Acc. Reward: 26.0; Pole fell: True
# Episode: 733; Acc. Reward: 26.0; Pole fell: True
# Episode: 734; Acc. Reward: 27.0; Pole fell: True
# Episode: 736; Acc. Reward: 27.0; Pole fell: True
# Episode: 737; Acc. Reward: 26.0; Pole fell: True
# Episode: 738; Acc. Reward: 25.0; Pole fell: True
# Episode: 739; Acc. Reward: 25.0; Pole fell: True
# Episode: 740; Acc. Reward: 25.0; Pole fell: True
# Episode: 741; Acc. Reward: 24.0; Pole fell: True
# Episode: 742; Acc. Reward: 25.0; Pole fell: True
# Episode: 743; Acc. Reward: 25.0; Pole fell: True
# Episode: 744; Acc. Reward: 25.0; Pole fell: True
# Episode: 745; Acc. Reward: 25.0; Pole fell: True
# Episode: 746; Acc. Reward: 26.0; Pole fell: True
# Episode: 747; Acc. Reward: 26.0; Pole fell: True
# Episode: 748; Acc. Reward: 26.0; Pole fell: True
# Episode: 749; Acc. Reward: 26.0; Pole fell: True
# Episode: 750; Acc. Reward: 26.0; Pole fell: True
# Episode: 752; Acc. Reward: 25.0; Pole fell: True
# Episode: 753; Acc. Reward: 26.0; Pole fell: True
# Episode: 754; Acc. Reward: 26.0; Pole fell: True
# Episode: 755; Acc. Reward: 26.0; Pole fell: True
# Episode: 756; Acc. Reward: 26.0; Pole fell: True
# Episode: 757; Acc. Reward: 26.0; Pole fell: True
# Episode: 758; Acc. Reward: 26.0; Pole fell: True
# Episode: 759; Acc. Reward: 26.0; Pole fell: True
# Episode: 760; Acc. Reward: 26.0; Pole fell: True
# Episode: 761; Acc. Reward: 26.0; Pole fell: True
# Episode: 762; Acc. Reward: 26.0; Pole fell: True
# Episode: 763; Acc. Reward: 26.0; Pole fell: True
# Episode: 764; Acc. Reward: 26.0; Pole fell: True
# Episode: 765; Acc. Reward: 27.0; Pole fell: True
# Episode: 766; Acc. Reward: 27.0; Pole fell: True
# Episode: 767; Acc. Reward: 27.0; Pole fell: True
# Episode: 769; Acc. Reward: 26.0; Pole fell: True
# Episode: 770; Acc. Reward: 26.0; Pole fell: True
# Episode: 771; Acc. Reward: 25.0; Pole fell: True
# Episode: 772; Acc. Reward: 25.0; Pole fell: True
# Episode: 773; Acc. Reward: 25.0; Pole fell: True
# Episode: 774; Acc. Reward: 24.0; Pole fell: True
# Episode: 775; Acc. Reward: 24.0; Pole fell: True
# Episode: 776; Acc. Reward: 24.0; Pole fell: True
# Episode: 777; Acc. Reward: 24.0; Pole fell: True
# Episode: 778; Acc. Reward: 24.0; Pole fell: True
# Episode: 779; Acc. Reward: 24.0; Pole fell: True
# Episode: 780; Acc. Reward: 25.0; Pole fell: True
# Episode: 781; Acc. Reward: 25.0; Pole fell: True
# Episode: 782; Acc. Reward: 25.0; Pole fell: True
# Episode: 783; Acc. Reward: 26.0; Pole fell: True
# Episode: 784; Acc. Reward: 25.0; Pole fell: True
# Episode: 785; Acc. Reward: 24.0; Pole fell: False
# Epoch: 4
# Episode: 786; Acc. Reward: 24.0; Pole fell: True
# Episode: 787; Acc. Reward: 24.0; Pole fell: True
# Episode: 788; Acc. Reward: 24.0; Pole fell: True
# Episode: 789; Acc. Reward: 25.0; Pole fell: True
# Episode: 790; Acc. Reward: 25.0; Pole fell: True
# Episode: 791; Acc. Reward: 25.0; Pole fell: True
# Episode: 792; Acc. Reward: 25.0; Pole fell: True
# Episode: 793; Acc. Reward: 25.0; Pole fell: True
# Episode: 794; Acc. Reward: 25.0; Pole fell: True
# Episode: 795; Acc. Reward: 25.0; Pole fell: True
# Episode: 796; Acc. Reward: 26.0; Pole fell: True
# Episode: 798; Acc. Reward: 26.0; Pole fell: True
# Episode: 799; Acc. Reward: 26.0; Pole fell: True
# Episode: 800; Acc. Reward: 26.0; Pole fell: True
# Episode: 801; Acc. Reward: 26.0; Pole fell: True
# Episode: 802; Acc. Reward: 26.0; Pole fell: True
# Episode: 803; Acc. Reward: 26.0; Pole fell: True
# Episode: 804; Acc. Reward: 27.0; Pole fell: True
# Episode: 805; Acc. Reward: 28.0; Pole fell: True
# Episode: 807; Acc. Reward: 27.0; Pole fell: True
# Episode: 808; Acc. Reward: 29.0; Pole fell: True
# Episode: 809; Acc. Reward: 30.0; Pole fell: True
# Episode: 810; Acc. Reward: 31.0; Pole fell: True
# Episode: 811; Acc. Reward: 31.0; Pole fell: True
# Episode: 812; Acc. Reward: 31.0; Pole fell: True
# Episode: 813; Acc. Reward: 30.0; Pole fell: True
# Episode: 814; Acc. Reward: 30.0; Pole fell: True
# Episode: 815; Acc. Reward: 30.0; Pole fell: True
# Episode: 816; Acc. Reward: 30.0; Pole fell: True
# Episode: 817; Acc. Reward: 30.0; Pole fell: True
# Episode: 818; Acc. Reward: 31.0; Pole fell: True
# Episode: 819; Acc. Reward: 32.0; Pole fell: True
# Episode: 821; Acc. Reward: 31.0; Pole fell: True
# Episode: 822; Acc. Reward: 31.0; Pole fell: True
# Episode: 823; Acc. Reward: 31.0; Pole fell: True
# Episode: 824; Acc. Reward: 32.0; Pole fell: True
# Episode: 825; Acc. Reward: 32.0; Pole fell: True
# Episode: 826; Acc. Reward: 33.0; Pole fell: True
# Episode: 827; Acc. Reward: 33.0; Pole fell: True
# Episode: 828; Acc. Reward: 33.0; Pole fell: True
# Episode: 829; Acc. Reward: 32.0; Pole fell: True
# Episode: 830; Acc. Reward: 32.0; Pole fell: True
# Episode: 832; Acc. Reward: 31.0; Pole fell: True
# Episode: 833; Acc. Reward: 32.0; Pole fell: True
# Episode: 834; Acc. Reward: 32.0; Pole fell: True
# Episode: 835; Acc. Reward: 32.0; Pole fell: True
# Episode: 836; Acc. Reward: 32.0; Pole fell: True
# Episode: 837; Acc. Reward: 32.0; Pole fell: True
# Episode: 838; Acc. Reward: 33.0; Pole fell: True
# Episode: 839; Acc. Reward: 33.0; Pole fell: True
# Episode: 840; Acc. Reward: 33.0; Pole fell: True
# Episode: 841; Acc. Reward: 33.0; Pole fell: True
# Episode: 843; Acc. Reward: 32.0; Pole fell: True
# Episode: 844; Acc. Reward: 31.0; Pole fell: True
# Episode: 845; Acc. Reward: 31.0; Pole fell: True
# Episode: 846; Acc. Reward: 32.0; Pole fell: True
# Episode: 847; Acc. Reward: 32.0; Pole fell: True
# Episode: 848; Acc. Reward: 31.0; Pole fell: True
# Episode: 849; Acc. Reward: 30.0; Pole fell: True
# Episode: 850; Acc. Reward: 30.0; Pole fell: True
# Episode: 851; Acc. Reward: 29.0; Pole fell: True
# Episode: 852; Acc. Reward: 29.0; Pole fell: True
# Episode: 853; Acc. Reward: 30.0; Pole fell: True
# Episode: 854; Acc. Reward: 30.0; Pole fell: True
# Episode: 855; Acc. Reward: 29.0; Pole fell: True
# Episode: 856; Acc. Reward: 29.0; Pole fell: True
# Episode: 858; Acc. Reward: 29.0; Pole fell: True
# Episode: 859; Acc. Reward: 29.0; Pole fell: True
# Episode: 860; Acc. Reward: 30.0; Pole fell: True
# Episode: 861; Acc. Reward: 29.0; Pole fell: True
# Episode: 862; Acc. Reward: 29.0; Pole fell: True
# Episode: 863; Acc. Reward: 29.0; Pole fell: True
# Episode: 864; Acc. Reward: 29.0; Pole fell: True
# Episode: 865; Acc. Reward: 28.0; Pole fell: True
# Episode: 866; Acc. Reward: 28.0; Pole fell: True
# Episode: 867; Acc. Reward: 28.0; Pole fell: True
# Episode: 868; Acc. Reward: 28.0; Pole fell: True
# Episode: 869; Acc. Reward: 28.0; Pole fell: True
# Episode: 870; Acc. Reward: 28.0; Pole fell: True
# Episode: 871; Acc. Reward: 27.0; Pole fell: True
# Episode: 872; Acc. Reward: 28.0; Pole fell: True
# Episode: 874; Acc. Reward: 27.0; Pole fell: True
# Episode: 875; Acc. Reward: 27.0; Pole fell: True
# Episode: 876; Acc. Reward: 27.0; Pole fell: True
# Episode: 877; Acc. Reward: 26.0; Pole fell: True
# Episode: 878; Acc. Reward: 27.0; Pole fell: True
# Episode: 879; Acc. Reward: 27.0; Pole fell: True
# Episode: 880; Acc. Reward: 28.0; Pole fell: True
# Episode: 881; Acc. Reward: 28.0; Pole fell: True
# Episode: 882; Acc. Reward: 28.0; Pole fell: True
# Episode: 883; Acc. Reward: 28.0; Pole fell: True
# Episode: 884; Acc. Reward: 29.0; Pole fell: True
# Episode: 885; Acc. Reward: 28.0; Pole fell: False
# Epoch: 5
# Episode: 886; Acc. Reward: 28.0; Pole fell: True
# Episode: 887; Acc. Reward: 29.0; Pole fell: True
# Episode: 888; Acc. Reward: 31.0; Pole fell: True
# Episode: 889; Acc. Reward: 31.0; Pole fell: True
# Episode: 890; Acc. Reward: 31.0; Pole fell: True
# Episode: 891; Acc. Reward: 32.0; Pole fell: True
# Episode: 892; Acc. Reward: 32.0; Pole fell: True
# Episode: 893; Acc. Reward: 32.0; Pole fell: True
# Episode: 895; Acc. Reward: 32.0; Pole fell: True
# Episode: 896; Acc. Reward: 33.0; Pole fell: True
# Episode: 897; Acc. Reward: 33.0; Pole fell: True
# Episode: 898; Acc. Reward: 34.0; Pole fell: True
# Episode: 899; Acc. Reward: 34.0; Pole fell: True
# Episode: 900; Acc. Reward: 34.0; Pole fell: True
# Episode: 901; Acc. Reward: 34.0; Pole fell: True
# Episode: 903; Acc. Reward: 36.0; Pole fell: True
# Episode: 904; Acc. Reward: 37.0; Pole fell: True
# Episode: 905; Acc. Reward: 37.0; Pole fell: True
# Episode: 906; Acc. Reward: 37.0; Pole fell: True
# Episode: 907; Acc. Reward: 38.0; Pole fell: True
# Episode: 908; Acc. Reward: 39.0; Pole fell: True
# Episode: 910; Acc. Reward: 39.0; Pole fell: True
# Episode: 911; Acc. Reward: 39.0; Pole fell: True
# Episode: 912; Acc. Reward: 39.0; Pole fell: True
# Episode: 913; Acc. Reward: 39.0; Pole fell: True
# Episode: 914; Acc. Reward: 39.0; Pole fell: True
# Episode: 915; Acc. Reward: 40.0; Pole fell: True
# Episode: 916; Acc. Reward: 41.0; Pole fell: True
# Episode: 917; Acc. Reward: 41.0; Pole fell: True
# Episode: 918; Acc. Reward: 41.0; Pole fell: True
# Episode: 919; Acc. Reward: 40.0; Pole fell: True
# Episode: 920; Acc. Reward: 40.0; Pole fell: True
# Episode: 921; Acc. Reward: 40.0; Pole fell: True
# Episode: 923; Acc. Reward: 40.0; Pole fell: True
# Episode: 924; Acc. Reward: 40.0; Pole fell: True
# Episode: 925; Acc. Reward: 41.0; Pole fell: True
# Episode: 926; Acc. Reward: 40.0; Pole fell: True
# Episode: 927; Acc. Reward: 39.0; Pole fell: True
# Episode: 928; Acc. Reward: 38.0; Pole fell: True
# Episode: 929; Acc. Reward: 39.0; Pole fell: True
# Episode: 930; Acc. Reward: 39.0; Pole fell: True
# Episode: 931; Acc. Reward: 38.0; Pole fell: True
# Episode: 933; Acc. Reward: 38.0; Pole fell: True
# Episode: 934; Acc. Reward: 39.0; Pole fell: True
# Episode: 935; Acc. Reward: 40.0; Pole fell: True
# Episode: 936; Acc. Reward: 40.0; Pole fell: True
# Episode: 937; Acc. Reward: 40.0; Pole fell: True
# Episode: 938; Acc. Reward: 40.0; Pole fell: True
# Episode: 939; Acc. Reward: 40.0; Pole fell: True
# Episode: 941; Acc. Reward: 39.0; Pole fell: True
# Episode: 942; Acc. Reward: 38.0; Pole fell: True
# Episode: 943; Acc. Reward: 37.0; Pole fell: True
# Episode: 944; Acc. Reward: 36.0; Pole fell: True
# Episode: 945; Acc. Reward: 36.0; Pole fell: True
# Episode: 946; Acc. Reward: 37.0; Pole fell: True
# Episode: 947; Acc. Reward: 35.0; Pole fell: True
# Episode: 948; Acc. Reward: 35.0; Pole fell: True
# Episode: 949; Acc. Reward: 35.0; Pole fell: True
# Episode: 950; Acc. Reward: 35.0; Pole fell: True
# Episode: 951; Acc. Reward: 36.0; Pole fell: True
# Episode: 952; Acc. Reward: 36.0; Pole fell: True
# Episode: 954; Acc. Reward: 37.0; Pole fell: True
# Episode: 955; Acc. Reward: 36.0; Pole fell: True
# Episode: 956; Acc. Reward: 36.0; Pole fell: True
# Episode: 957; Acc. Reward: 36.0; Pole fell: True
# Episode: 958; Acc. Reward: 37.0; Pole fell: True
# Episode: 959; Acc. Reward: 38.0; Pole fell: True
# Episode: 960; Acc. Reward: 39.0; Pole fell: True
# Episode: 961; Acc. Reward: 38.0; Pole fell: True
# Episode: 962; Acc. Reward: 37.0; Pole fell: True
# Episode: 963; Acc. Reward: 37.0; Pole fell: False
# Epoch: 6
# Episode: 964; Acc. Reward: 38.0; Pole fell: True
# Episode: 965; Acc. Reward: 38.0; Pole fell: True
# Episode: 966; Acc. Reward: 38.0; Pole fell: True
# Episode: 967; Acc. Reward: 38.0; Pole fell: True
# Episode: 968; Acc. Reward: 39.0; Pole fell: True
# Episode: 969; Acc. Reward: 38.0; Pole fell: True
# Episode: 970; Acc. Reward: 38.0; Pole fell: True
# Episode: 972; Acc. Reward: 38.0; Pole fell: True
# Episode: 973; Acc. Reward: 38.0; Pole fell: True
# Episode: 974; Acc. Reward: 38.0; Pole fell: True
# Episode: 975; Acc. Reward: 38.0; Pole fell: True
# Episode: 976; Acc. Reward: 38.0; Pole fell: True
# Episode: 977; Acc. Reward: 38.0; Pole fell: True
# Episode: 978; Acc. Reward: 38.0; Pole fell: True
# Episode: 979; Acc. Reward: 38.0; Pole fell: True
# Episode: 981; Acc. Reward: 38.0; Pole fell: True
# Episode: 982; Acc. Reward: 39.0; Pole fell: True
# Episode: 983; Acc. Reward: 39.0; Pole fell: True
# Episode: 984; Acc. Reward: 39.0; Pole fell: True
# Episode: 985; Acc. Reward: 39.0; Pole fell: True
# Episode: 986; Acc. Reward: 40.0; Pole fell: True
# Episode: 987; Acc. Reward: 41.0; Pole fell: True
# Episode: 989; Acc. Reward: 41.0; Pole fell: True
# Episode: 990; Acc. Reward: 43.0; Pole fell: True
# Episode: 991; Acc. Reward: 43.0; Pole fell: True
# Episode: 992; Acc. Reward: 43.0; Pole fell: True
# Episode: 993; Acc. Reward: 43.0; Pole fell: True
# Episode: 994; Acc. Reward: 44.0; Pole fell: True
# Episode: 995; Acc. Reward: 44.0; Pole fell: True
# Episode: 997; Acc. Reward: 43.0; Pole fell: True
# Episode: 998; Acc. Reward: 42.0; Pole fell: True
# Episode: 999; Acc. Reward: 41.0; Pole fell: True
# Episode: 1000; Acc. Reward: 41.0; Pole fell: True
# Episode: 1001; Acc. Reward: 42.0; Pole fell: True
# Episode: 1002; Acc. Reward: 43.0; Pole fell: True
# Episode: 1003; Acc. Reward: 45.0; Pole fell: True
# Episode: 1005; Acc. Reward: 44.0; Pole fell: True
# Episode: 1006; Acc. Reward: 44.0; Pole fell: True
# Episode: 1007; Acc. Reward: 44.0; Pole fell: True
# Episode: 1008; Acc. Reward: 43.0; Pole fell: True
# Episode: 1009; Acc. Reward: 43.0; Pole fell: True
# Episode: 1010; Acc. Reward: 44.0; Pole fell: True
# Episode: 1011; Acc. Reward: 45.0; Pole fell: True
# Episode: 1013; Acc. Reward: 45.0; Pole fell: True
# Episode: 1014; Acc. Reward: 45.0; Pole fell: True
# Episode: 1015; Acc. Reward: 46.0; Pole fell: True
# Episode: 1016; Acc. Reward: 47.0; Pole fell: True
# Episode: 1017; Acc. Reward: 47.0; Pole fell: True
# Episode: 1018; Acc. Reward: 45.0; Pole fell: True
# Episode: 1020; Acc. Reward: 46.0; Pole fell: True
# Episode: 1021; Acc. Reward: 46.0; Pole fell: True
# Episode: 1022; Acc. Reward: 46.0; Pole fell: True
# Episode: 1023; Acc. Reward: 47.0; Pole fell: True
# Episode: 1024; Acc. Reward: 47.0; Pole fell: True
# Episode: 1025; Acc. Reward: 47.0; Pole fell: True
# Episode: 1026; Acc. Reward: 47.0; Pole fell: True
# ...
# Episode: 1510; Acc. Reward: 54.0; Pole fell: True
# Episode: 1511; Acc. Reward: 55.0; Pole fell: True
# Episode: 1513; Acc. Reward: 57.0; Pole fell: True
# Episode: 1514; Acc. Reward: 57.0; Pole fell: True
# Episode: 1515; Acc. Reward: 56.0; Pole fell: True
# Episode: 1517; Acc. Reward: 58.0; Pole fell: True
# Episode: 1518; Acc. Reward: 58.0; Pole fell: True
# Episode: 1520; Acc. Reward: 57.0; Pole fell: True
# Episode: 1521; Acc. Reward: 57.0; Pole fell: True
# Episode: 1522; Acc. Reward: 57.0; Pole fell: True
# Episode: 1524; Acc. Reward: 53.0; Pole fell: True
# Episode: 1525; Acc. Reward: 54.0; Pole fell: True
# Episode: 1526; Acc. Reward: 54.0; Pole fell: True
# Episode: 1528; Acc. Reward: 54.0; Pole fell: True
# Episode: 1529; Acc. Reward: 55.0; Pole fell: True
# Episode: 1530; Acc. Reward: 56.0; Pole fell: True
# Episode: 1531; Acc. Reward: 57.0; Pole fell: False
# Epoch: 20
# Episode: 1532; Acc. Reward: 58.0; Pole fell: True
# Episode: 1533; Acc. Reward: 59.0; Pole fell: True
# Episode: 1535; Acc. Reward: 56.0; Pole fell: True
# Episode: 1536; Acc. Reward: 55.0; Pole fell: True
# Episode: 1538; Acc. Reward: 53.0; Pole fell: True
# Episode: 1539; Acc. Reward: 51.0; Pole fell: True
# Episode: 1540; Acc. Reward: 52.0; Pole fell: True
# Episode: 1542; Acc. Reward: 54.0; Pole fell: True
# Episode: 1543; Acc. Reward: 52.0; Pole fell: True
# Episode: 1545; Acc. Reward: 52.0; Pole fell: True
# Episode: 1546; Acc. Reward: 52.0; Pole fell: True
# Episode: 1547; Acc. Reward: 53.0; Pole fell: True
# Episode: 1549; Acc. Reward: 49.0; Pole fell: True
# Episode: 1551; Acc. Reward: 51.0; Pole fell: True
# Episode: 1552; Acc. Reward: 47.0; Pole fell: True
# Episode: 1553; Acc. Reward: 48.0; Pole fell: True
# Episode: 1555; Acc. Reward: 47.0; Pole fell: True
# Episode: 1556; Acc. Reward: 45.0; Pole fell: True
# Episode: 1557; Acc. Reward: 45.0; Pole fell: False
# Epoch: 21
# Episode: 1558; Acc. Reward: 47.0; Pole fell: True
# Episode: 1559; Acc. Reward: 46.0; Pole fell: True
# Episode: 1561; Acc. Reward: 46.0; Pole fell: True
# Episode: 1562; Acc. Reward: 47.0; Pole fell: True
# Episode: 1564; Acc. Reward: 50.0; Pole fell: True
# Episode: 1566; Acc. Reward: 52.0; Pole fell: True
# Episode: 1567; Acc. Reward: 52.0; Pole fell: True
# Episode: 1568; Acc. Reward: 55.0; Pole fell: True
# Episode: 1570; Acc. Reward: 53.0; Pole fell: True
# Episode: 1571; Acc. Reward: 53.0; Pole fell: True
# Episode: 1573; Acc. Reward: 50.0; Pole fell: True
# Episode: 1574; Acc. Reward: 49.0; Pole fell: True
# Episode: 1576; Acc. Reward: 50.0; Pole fell: True
# Episode: 1577; Acc. Reward: 50.0; Pole fell: True
# Episode: 1578; Acc. Reward: 50.0; Pole fell: True
# Episode: 1580; Acc. Reward: 51.0; Pole fell: True
# Episode: 1581; Acc. Reward: 48.0; Pole fell: True
# Episode: 1582; Acc. Reward: 49.0; Pole fell: False
# Epoch: 22
# Episode: 1583; Acc. Reward: 51.0; Pole fell: True
# Episode: 1585; Acc. Reward: 53.0; Pole fell: True
# Episode: 1587; Acc. Reward: 55.0; Pole fell: True
# Episode: 1588; Acc. Reward: 56.0; Pole fell: True
# Episode: 1590; Acc. Reward: 54.0; Pole fell: True
# Episode: 1591; Acc. Reward: 55.0; Pole fell: True
# Episode: 1593; Acc. Reward: 54.0; Pole fell: True
# Episode: 1594; Acc. Reward: 53.0; Pole fell: True
# Episode: 1596; Acc. Reward: 53.0; Pole fell: True
# Episode: 1597; Acc. Reward: 53.0; Pole fell: True
# Episode: 1599; Acc. Reward: 55.0; Pole fell: True
# Episode: 1600; Acc. Reward: 56.0; Pole fell: True
# Episode: 1602; Acc. Reward: 58.0; Pole fell: True
# Episode: 1603; Acc. Reward: 56.0; Pole fell: True
# Episode: 1604; Acc. Reward: 60.0; Pole fell: False
# Epoch: 23
# Episode: 1605; Acc. Reward: 61.0; Pole fell: True
# Episode: 1607; Acc. Reward: 61.0; Pole fell: True
# Episode: 1609; Acc. Reward: 60.0; Pole fell: True
# Episode: 1610; Acc. Reward: 63.0; Pole fell: True
# Episode: 1612; Acc. Reward: 64.0; Pole fell: True
# Episode: 1613; Acc. Reward: 66.0; Pole fell: True
# Episode: 1615; Acc. Reward: 66.0; Pole fell: True
# Episode: 1617; Acc. Reward: 71.0; Pole fell: True
# Episode: 1618; Acc. Reward: 71.0; Pole fell: True
# Episode: 1620; Acc. Reward: 72.0; Pole fell: True
# Episode: 1622; Acc. Reward: 72.0; Pole fell: True
# Episode: 1623; Acc. Reward: 71.0; Pole fell: True
# Episode: 1624; Acc. Reward: 70.0; Pole fell: False
# Epoch: 24
# Episode: 1625; Acc. Reward: 71.0; Pole fell: True
# Episode: 1627; Acc. Reward: 66.0; Pole fell: True
# Episode: 1628; Acc. Reward: 66.0; Pole fell: True
# Episode: 1630; Acc. Reward: 66.0; Pole fell: True
# Episode: 1631; Acc. Reward: 68.0; Pole fell: True
# Episode: 1633; Acc. Reward: 66.0; Pole fell: True
# Episode: 1634; Acc. Reward: 68.0; Pole fell: True
# Episode: 1636; Acc. Reward: 68.0; Pole fell: True
# Episode: 1637; Acc. Reward: 67.0; Pole fell: True
# Episode: 1639; Acc. Reward: 66.0; Pole fell: True
# Episode: 1641; Acc. Reward: 64.0; Pole fell: True
# Episode: 1642; Acc. Reward: 66.0; Pole fell: True
# Episode: 1644; Acc. Reward: 60.0; Pole fell: True
# Episode: 1645; Acc. Reward: 55.0; Pole fell: True
# Episode: 1646; Acc. Reward: 55.0; Pole fell: False
# Epoch: 25
# Episode: 1647; Acc. Reward: 57.0; Pole fell: True
# Episode: 1648; Acc. Reward: 54.0; Pole fell: True
# Episode: 1650; Acc. Reward: 54.0; Pole fell: True
# Episode: 1652; Acc. Reward: 52.0; Pole fell: True
# Episode: 1653; Acc. Reward: 52.0; Pole fell: True
# Episode: 1655; Acc. Reward: 52.0; Pole fell: True
# Episode: 1656; Acc. Reward: 47.0; Pole fell: True
# Episode: 1658; Acc. Reward: 50.0; Pole fell: True
# Episode: 1659; Acc. Reward: 48.0; Pole fell: True
# Episode: 1661; Acc. Reward: 45.0; Pole fell: True
# Episode: 1663; Acc. Reward: 46.0; Pole fell: True
# Episode: 1664; Acc. Reward: 44.0; Pole fell: True
# Episode: 1666; Acc. Reward: 43.0; Pole fell: True
# Episode: 1667; Acc. Reward: 45.0; Pole fell: True
# Episode: 1668; Acc. Reward: 45.0; Pole fell: False
# Epoch: 26
# Episode: 1669; Acc. Reward: 47.0; Pole fell: True
# Episode: 1671; Acc. Reward: 47.0; Pole fell: True
# Episode: 1673; Acc. Reward: 47.0; Pole fell: True
# Episode: 1674; Acc. Reward: 46.0; Pole fell: True
# Episode: 1676; Acc. Reward: 46.0; Pole fell: True
# Episode: 1677; Acc. Reward: 47.0; Pole fell: True
# Episode: 1679; Acc. Reward: 48.0; Pole fell: True
# Episode: 1681; Acc. Reward: 51.0; Pole fell: True
# Episode: 1683; Acc. Reward: 53.0; Pole fell: True
# Episode: 1685; Acc. Reward: 56.0; Pole fell: True
# Episode: 1686; Acc. Reward: 58.0; Pole fell: True
# Episode: 1687; Acc. Reward: 58.0; Pole fell: False
# Epoch: 27
# Episode: 1688; Acc. Reward: 59.0; Pole fell: True
# Episode: 1690; Acc. Reward: 57.0; Pole fell: True
# Episode: 1691; Acc. Reward: 57.0; Pole fell: True
# Episode: 1693; Acc. Reward: 59.0; Pole fell: True
# Episode: 1695; Acc. Reward: 65.0; Pole fell: True
# Episode: 1697; Acc. Reward: 64.0; Pole fell: True
# Episode: 1699; Acc. Reward: 65.0; Pole fell: True
# Episode: 1700; Acc. Reward: 67.0; Pole fell: True
# Episode: 1702; Acc. Reward: 66.0; Pole fell: True
# Episode: 1704; Acc. Reward: 65.0; Pole fell: True
# Episode: 1705; Acc. Reward: 66.0; Pole fell: True
# Episode: 1706; Acc. Reward: 71.0; Pole fell: False
# Epoch: 28
# Episode: 1707; Acc. Reward: 71.0; Pole fell: True
# Episode: 1709; Acc. Reward: 74.0; Pole fell: True
# Episode: 1711; Acc. Reward: 75.0; Pole fell: True
# Episode: 1713; Acc. Reward: 78.0; Pole fell: True
# Episode: 1715; Acc. Reward: 79.0; Pole fell: True
# Episode: 1717; Acc. Reward: 83.0; Pole fell: True
# Episode: 1719; Acc. Reward: 83.0; Pole fell: True
# Episode: 1720; Acc. Reward: 81.0; Pole fell: True
# Episode: 1722; Acc. Reward: 77.0; Pole fell: True
# Episode: 1723; Acc. Reward: 80.0; Pole fell: False
# Epoch: 29
# Episode: 1724; Acc. Reward: 77.0; Pole fell: True
# Episode: 1726; Acc. Reward: 75.0; Pole fell: True
# Episode: 1728; Acc. Reward: 81.0; Pole fell: True
# Episode: 1730; Acc. Reward: 83.0; Pole fell: True
# Episode: 1731; Acc. Reward: 82.0; Pole fell: True
# Episode: 1733; Acc. Reward: 82.0; Pole fell: True
# Episode: 1735; Acc. Reward: 77.0; Pole fell: True
# Episode: 1737; Acc. Reward: 77.0; Pole fell: True
# Episode: 1739; Acc. Reward: 78.0; Pole fell: True
# Episode: 1740; Acc. Reward: 82.0; Pole fell: False
# Epoch: 30
# Episode: 1741; Acc. Reward: 84.0; Pole fell: True
# Episode: 1743; Acc. Reward: 85.0; Pole fell: True
# Episode: 1745; Acc. Reward: 85.0; Pole fell: True
# Episode: 1747; Acc. Reward: 80.0; Pole fell: True
# Episode: 1749; Acc. Reward: 83.0; Pole fell: True
# Episode: 1751; Acc. Reward: 84.0; Pole fell: True
# Episode: 1754; Acc. Reward: 86.0; Pole fell: True
# Episode: 1755; Acc. Reward: 89.0; Pole fell: False
# Epoch: 31
# Episode: 1756; Acc. Reward: 87.0; Pole fell: True
# Episode: 1758; Acc. Reward: 85.0; Pole fell: True
# Episode: 1761; Acc. Reward: 89.0; Pole fell: True
# Episode: 1763; Acc. Reward: 94.0; Pole fell: True
# Episode: 1766; Acc. Reward: 99.0; Pole fell: True
# Episode: 1768; Acc. Reward: 92.0; Pole fell: True
# Episode: 1769; Acc. Reward: 93.0; Pole fell: False
# Epoch: 32
# Episode: 1771; Acc. Reward: 98.0; Pole fell: True
# Episode: 1772; Acc. Reward: 100.0; Pole fell: True
# Episode: 1774; Acc. Reward: 98.0; Pole fell: True
# Episode: 1776; Acc. Reward: 99.0; Pole fell: True
# Episode: 1778; Acc. Reward: 98.0; Pole fell: True
# Episode: 1780; Acc. Reward: 97.0; Pole fell: True
# Episode: 1782; Acc. Reward: 96.0; Pole fell: True
# Episode: 1784; Acc. Reward: 99.0; Pole fell: True
# Episode: 1785; Acc. Reward: 103.0; Pole fell: False
# Epoch: 33
# Episode: 1786; Acc. Reward: 103.0; Pole fell: True
# Episode: 1788; Acc. Reward: 98.0; Pole fell: True
# Episode: 1790; Acc. Reward: 96.0; Pole fell: True
# Episode: 1793; Acc. Reward: 90.0; Pole fell: True
# Episode: 1795; Acc. Reward: 91.0; Pole fell: True
# Episode: 1796; Acc. Reward: 90.0; Pole fell: True
# Episode: 1798; Acc. Reward: 89.0; Pole fell: True
# Episode: 1800; Acc. Reward: 86.0; Pole fell: True
# Episode: 1801; Acc. Reward: 87.0; Pole fell: False
# Epoch: 34
# Episode: 1803; Acc. Reward: 82.0; Pole fell: True
# Episode: 1805; Acc. Reward: 84.0; Pole fell: True
# Episode: 1808; Acc. Reward: 86.0; Pole fell: True
# Episode: 1810; Acc. Reward: 77.0; Pole fell: True
# Episode: 1812; Acc. Reward: 80.0; Pole fell: True
# Episode: 1814; Acc. Reward: 79.0; Pole fell: True
# Episode: 1815; Acc. Reward: 78.0; Pole fell: False
# Epoch: 35
# Episode: 1818; Acc. Reward: 86.0; Pole fell: True
# Episode: 1820; Acc. Reward: 89.0; Pole fell: True
# Episode: 1823; Acc. Reward: 101.0; Pole fell: True
# Episode: 1826; Acc. Reward: 113.0; Pole fell: False
# Epoch: 36
# Episode: 1828; Acc. Reward: 120.0; Pole fell: True
# Episode: 1830; Acc. Reward: 117.0; Pole fell: True
# Episode: 1832; Acc. Reward: 113.0; Pole fell: True
# Episode: 1835; Acc. Reward: 116.0; Pole fell: True
# Episode: 1837; Acc. Reward: 116.0; Pole fell: True
# Episode: 1839; Acc. Reward: 122.0; Pole fell: True
# Episode: 1840; Acc. Reward: 120.0; Pole fell: False
# Epoch: 37
# Episode: 1842; Acc. Reward: 119.0; Pole fell: True
# Episode: 1846; Acc. Reward: 128.0; Pole fell: True
# Episode: 1849; Acc. Reward: 124.0; Pole fell: True
# Episode: 1851; Acc. Reward: 125.0; Pole fell: False
# Epoch: 38
# Episode: 1853; Acc. Reward: 130.0; Pole fell: True
# Episode: 1857; Acc. Reward: 122.0; Pole fell: True
# Episode: 1861; Acc. Reward: 120.0; Pole fell: True
# Episode: 1862; Acc. Reward: 114.0; Pole fell: False
# Epoch: 39
# Episode: 1866; Acc. Reward: 100.0; Pole fell: True
# Episode: 1871; Acc. Reward: 108.0; Pole fell: False
# Epoch: 40
# Episode: 1879; Acc. Reward: 185.0; Pole fell: False
# Epoch: 41
# Episode: 1887; Acc. Reward: 258.0; Pole fell: False
# Epoch: 42
# Episode: 1895; Acc. Reward: 336.0; Pole fell: False
# Epoch: 43
# Episode: 1903; Acc. Reward: 410.0; Pole fell: False
# Epoch: 44
# Episode: 1911; Acc. Reward: 490.0; Pole fell: False
# Epoch: 45
# Episode: 1919; Acc. Reward: 495.0; Pole fell: False
# Epoch: 46
# Episode: 1927; Acc. Reward: 495.0; Pole fell: False
# Epoch: 47
# Episode: 1935; Acc. Reward: 497.0; Pole fell: False
# Epoch: 48
# Episode: 1943; Acc. Reward: 498.0; Pole fell: False
# Epoch: 49
# Episode: 1951; Acc. Reward: 499.0; Pole fell: False
# Epoch: 50
# Episode: 1959; Acc. Reward: 499.0; Pole fell: False
# Epoch: 51
# Episode: 1967; Acc. Reward: 500.0; Pole fell: False
# Epoch: 52
# Episode: 1975; Acc. Reward: 500.0; Pole fell: False
# Epoch: 53
# Episode: 1983; Acc. Reward: 500.0; Pole fell: False
# Epoch: 54
# Episode: 1991; Acc. Reward: 500.0; Pole fell: False
# Epoch: 55
# Episode: 1999; Acc. Reward: 500.0; Pole fell: False
# Epoch: 56
# Episode: 2007; Acc. Reward: 500.0; Pole fell: False
# Epoch: 57
# Episode: 2015; Acc. Reward: 500.0; Pole fell: False
# Epoch: 58
# Episode: 2023; Acc. Reward: 500.0; Pole fell: False
# Epoch: 59
# Episode: 2031; Acc. Reward: 500.0; Pole fell: False
# Epoch: 60
# Episode: 2039; Acc. Reward: 500.0; Pole fell: False
# Epoch: 61
# Episode: 2047; Acc. Reward: 500.0; Pole fell: False
# Epoch: 62
# Episode: 2055; Acc. Reward: 500.0; Pole fell: False
# Epoch: 63
# Episode: 2063; Acc. Reward: 500.0; Pole fell: False
# Epoch: 64
# Episode: 2071; Acc. Reward: 500.0; Pole fell: False
# Epoch: 65
# Episode: 2079; Acc. Reward: 500.0; Pole fell: False
# Epoch: 66
# Episode: 2087; Acc. Reward: 500.0; Pole fell: False
# Epoch: 67
# Episode: 2095; Acc. Reward: 500.0; Pole fell: False
# Epoch: 68
# Episode: 2103; Acc. Reward: 500.0; Pole fell: False
# Epoch: 69
# Episode: 2111; Acc. Reward: 500.0; Pole fell: False
# Epoch: 70
# Episode: 2119; Acc. Reward: 500.0; Pole fell: False
# Epoch: 71
# Episode: 2127; Acc. Reward: 500.0; Pole fell: False
# Epoch: 72
# Episode: 2135; Acc. Reward: 500.0; Pole fell: False
# Epoch: 73
# Episode: 2143; Acc. Reward: 500.0; Pole fell: False
# Epoch: 74
# Episode: 2151; Acc. Reward: 500.0; Pole fell: False
# Epoch: 75
# Episode: 2159; Acc. Reward: 500.0; Pole fell: False
# Epoch: 76
# Episode: 2167; Acc. Reward: 500.0; Pole fell: False
# Epoch: 77
# Episode: 2175; Acc. Reward: 500.0; Pole fell: False
# Epoch: 78
# Episode: 2183; Acc. Reward: 500.0; Pole fell: False
# Epoch: 79
# Episode: 2191; Acc. Reward: 500.0; Pole fell: False
# Epoch: 80
# Episode: 2199; Acc. Reward: 500.0; Pole fell: False
# Epoch: 81
# Episode: 2207; Acc. Reward: 500.0; Pole fell: False
# Epoch: 82
# Episode: 2215; Acc. Reward: 500.0; Pole fell: False
# Epoch: 83
# Episode: 2223; Acc. Reward: 500.0; Pole fell: False
# Epoch: 84
# Episode: 2231; Acc. Reward: 500.0; Pole fell: False
# Epoch: 85
# Episode: 2239; Acc. Reward: 500.0; Pole fell: False
# Epoch: 86
# Episode: 2247; Acc. Reward: 500.0; Pole fell: False
# Epoch: 87
# Episode: 2255; Acc. Reward: 500.0; Pole fell: False
# Epoch: 88
# Episode: 2263; Acc. Reward: 500.0; Pole fell: False
# Epoch: 89
# Episode: 2271; Acc. Reward: 500.0; Pole fell: False
# Epoch: 90
# Episode: 2279; Acc. Reward: 500.0; Pole fell: False
# Epoch: 91
# Episode: 2287; Acc. Reward: 500.0; Pole fell: False
# Epoch: 92
# Episode: 2295; Acc. Reward: 500.0; Pole fell: False
# Epoch: 93
# Episode: 2303; Acc. Reward: 500.0; Pole fell: False
# Epoch: 94
# Episode: 2311; Acc. Reward: 500.0; Pole fell: False
# Epoch: 95
# Episode: 2319; Acc. Reward: 500.0; Pole fell: False
# Epoch: 96
# Episode: 2327; Acc. Reward: 500.0; Pole fell: False
# Epoch: 97
# Episode: 2335; Acc. Reward: 500.0; Pole fell: False
# Epoch: 98
# Episode: 2343; Acc. Reward: 500.0; Pole fell: False
# Epoch: 99
# Episode: 2351; Acc. Reward: 500.0; Pole fell: False
# Epoch: 100
# Episode: 2359; Acc. Reward: 500.0; Pole fell: False
# Epoch: 101
# Episode: 2367; Acc. Reward: 500.0; Pole fell: False
# Epoch: 102
# Episode: 2375; Acc. Reward: 500.0; Pole fell: False
# Epoch: 103
# Episode: 2383; Acc. Reward: 500.0; Pole fell: False
# Epoch: 104
# Episode: 2391; Acc. Reward: 500.0; Pole fell: False
# Epoch: 105
# Episode: 2399; Acc. Reward: 500.0; Pole fell: False
# Epoch: 106
# Episode: 2407; Acc. Reward: 500.0; Pole fell: False
# Epoch: 107
# Episode: 2415; Acc. Reward: 500.0; Pole fell: False
# Epoch: 108
# Episode: 2423; Acc. Reward: 500.0; Pole fell: False
# Epoch: 109
# Episode: 2431; Acc. Reward: 500.0; Pole fell: False
# Epoch: 110
# Episode: 2439; Acc. Reward: 500.0; Pole fell: False
# Epoch: 111
# Episode: 2447; Acc. Reward: 500.0; Pole fell: False
# Epoch: 112
# Episode: 2455; Acc. Reward: 500.0; Pole fell: False
# Epoch: 113
# Episode: 2463; Acc. Reward: 500.0; Pole fell: False
# Epoch: 114
# Episode: 2471; Acc. Reward: 500.0; Pole fell: False
# Epoch: 115
# Episode: 2479; Acc. Reward: 500.0; Pole fell: False
# Epoch: 116
# Episode: 2487; Acc. Reward: 500.0; Pole fell: False
# Epoch: 117
# Episode: 2495; Acc. Reward: 500.0; Pole fell: False
# Epoch: 118

# %%
'''
observation = env.reset()
save_observation = []
save_wanted_torque = []
save_actual_torque = []
save_ctrl_voltage = []


done=False
t=0
while not done and t<steps_per_episode_goal:
    # using our observation, choose an action and take it in the environment
    # Get the logits, action, and take one step in the environment
    observation = observation.reshape(1, -1)
    logits, action = sample_action(observation)
    #observation_new, reward, done, _, _ = env.step(action[0].numpy())
    observation_new, reward, done, _ ,torque_wanted, torque_actual= env.step(action[0].numpy().item())
    observation = observation_new
    save_observation.append(observation)
    save_wanted_torque.append(torque_wanted)
    save_actual_torque.append(torque_actual)
    save_ctrl_voltage.append(env.DCMotorModel.voltage_input)
    t+=1

print(f"Pole fell down during test: {done}")
#if done:
#  print("Pole fell down during test")
#else:
#  print("Pole NOT fell down during test")
'''
# Out:
# '\nobservation = env.reset()\nsave_observation = []\nsave_wanted_torque = []\nsave_actual_torque = []\nsave_ctrl_voltage = []\n\n\ndone=False\nt=0\nwhile not done and t<steps_per_episode_goal:\n    # using our observation, choose an action and take it in the environment\n    # Get the logits, action, and take one step in the environment\n    observation = observation.reshape(1, -1)\n    logits, action = sample_action(observation)\n    #observation_new, reward, done, _, _ = env.step(action[0].numpy())\n    observation_new, reward, done, _ ,torque_wanted, torque_actual= env.step(action[0].numpy().item())\n    observation = observation_new\n    save_observation.append(observation)\n    save_wanted_torque.append(torque_wanted)\n    save_actual_torque.append(torque_actual)\n    save_ctrl_voltage.append(env.DCMotorModel.voltage_input)\n    t+=1\n\nprint(f"Pole fell down during test: {done}")\n#if done:\n#  print("Pole fell down during test")\n#else:\n#  print("Pole NOT fell down during test")\n'

# %%
total_episodes_test = 100
best_score = -1000
ep_reward_list_test = []

# %%
print('Test')
for ep in range(total_episodes_test):
    observation = env.reset()
    save_observation_temp = [observation]
    save_wanted_torque_temp = [0.0]
    save_actual_torque_temp = [0.0]
    save_ctrl_voltage_temp = []
    done=False
    t=0
    episodic_reward = 0
    while not done and t<steps_per_episode_goal:
        # using our observation, choose an action and take it in the environment
        # Get the logits, action, and take one step in the environment
        observation = observation.reshape(1, -1)
        logits, action = sample_action(observation)
        #observation_new, reward, done, _, _ = env.step(action[0].numpy())
        observation_new, reward, done, _ ,torque_wanted, torque_actual= env.step(action[0].numpy().item())
        episodic_reward += reward
        observation = observation_new
        save_observation_temp.append(observation)
        save_wanted_torque_temp.append(torque_wanted)
        save_actual_torque_temp.append(torque_actual)
        save_ctrl_voltage_temp.append(env.DCMotorModel.voltage_input)
        t+=1

    # get best score and update save data
    save_ctrl_voltage_temp.append(env.DCMotorModel.voltage_input)
    print(f"Episode: {ep}; Acc. Reward: {episodic_reward:.1f}; Pole fell: {done}")
    if best_score<episodic_reward:
        save_observation = list(save_observation_temp)
        save_wanted_torque = list(save_wanted_torque_temp)
        save_actual_torque = list(save_actual_torque_temp)
        save_ctrl_voltage = list(save_ctrl_voltage_temp)
        best_score = episodic_reward
    ep_reward_list_test.append(episodic_reward)
# Out:
# Test
# Episode: 0; Acc. Reward: 500.0; Pole fell: False
# Episode: 1; Acc. Reward: 500.0; Pole fell: False
# Episode: 2; Acc. Reward: 500.0; Pole fell: False
# Episode: 3; Acc. Reward: 500.0; Pole fell: False
# Episode: 4; Acc. Reward: 500.0; Pole fell: False
# Episode: 5; Acc. Reward: 500.0; Pole fell: False
# Episode: 6; Acc. Reward: 500.0; Pole fell: False
# Episode: 7; Acc. Reward: 500.0; Pole fell: False
# Episode: 8; Acc. Reward: 500.0; Pole fell: False
# Episode: 9; Acc. Reward: 500.0; Pole fell: False
# Episode: 10; Acc. Reward: 500.0; Pole fell: False
# Episode: 11; Acc. Reward: 500.0; Pole fell: False
# Episode: 12; Acc. Reward: 500.0; Pole fell: False
# Episode: 13; Acc. Reward: 500.0; Pole fell: False
# Episode: 14; Acc. Reward: 500.0; Pole fell: False
# Episode: 15; Acc. Reward: 500.0; Pole fell: False
# Episode: 16; Acc. Reward: 500.0; Pole fell: False
# Episode: 17; Acc. Reward: 500.0; Pole fell: False
# Episode: 18; Acc. Reward: 500.0; Pole fell: False
# Episode: 19; Acc. Reward: 500.0; Pole fell: False
# Episode: 20; Acc. Reward: 500.0; Pole fell: False
# Episode: 21; Acc. Reward: 500.0; Pole fell: False
# Episode: 22; Acc. Reward: 500.0; Pole fell: False
# Episode: 23; Acc. Reward: 500.0; Pole fell: False
# Episode: 24; Acc. Reward: 500.0; Pole fell: False
# Episode: 25; Acc. Reward: 500.0; Pole fell: False
# Episode: 26; Acc. Reward: 500.0; Pole fell: False
# Episode: 27; Acc. Reward: 500.0; Pole fell: False
# Episode: 28; Acc. Reward: 500.0; Pole fell: False
# Episode: 29; Acc. Reward: 500.0; Pole fell: False
# Episode: 30; Acc. Reward: 500.0; Pole fell: False
# Episode: 31; Acc. Reward: 500.0; Pole fell: False
# Episode: 32; Acc. Reward: 500.0; Pole fell: False
# Episode: 33; Acc. Reward: 500.0; Pole fell: False
# Episode: 34; Acc. Reward: 500.0; Pole fell: False
# Episode: 35; Acc. Reward: 500.0; Pole fell: False
# Episode: 36; Acc. Reward: 500.0; Pole fell: False
# Episode: 37; Acc. Reward: 500.0; Pole fell: False
# Episode: 38; Acc. Reward: 500.0; Pole fell: False
# Episode: 39; Acc. Reward: 500.0; Pole fell: False
# Episode: 40; Acc. Reward: 500.0; Pole fell: False
# Episode: 41; Acc. Reward: 500.0; Pole fell: False
# Episode: 42; Acc. Reward: 500.0; Pole fell: False
# Episode: 43; Acc. Reward: 500.0; Pole fell: False
# Episode: 44; Acc. Reward: 500.0; Pole fell: False
# Episode: 45; Acc. Reward: 500.0; Pole fell: False
# Episode: 46; Acc. Reward: 500.0; Pole fell: False
# Episode: 47; Acc. Reward: 500.0; Pole fell: False
# Episode: 48; Acc. Reward: 500.0; Pole fell: False
# Episode: 49; Acc. Reward: 500.0; Pole fell: False
# Episode: 50; Acc. Reward: 500.0; Pole fell: False
# Episode: 51; Acc. Reward: 500.0; Pole fell: False
# Episode: 52; Acc. Reward: 500.0; Pole fell: False
# Episode: 53; Acc. Reward: 500.0; Pole fell: False
# Episode: 54; Acc. Reward: 500.0; Pole fell: False
# Episode: 55; Acc. Reward: 500.0; Pole fell: False
# Episode: 56; Acc. Reward: 500.0; Pole fell: False
# Episode: 57; Acc. Reward: 500.0; Pole fell: False
# Episode: 58; Acc. Reward: 500.0; Pole fell: False
# Episode: 59; Acc. Reward: 500.0; Pole fell: False
# Episode: 60; Acc. Reward: 500.0; Pole fell: False
# Episode: 61; Acc. Reward: 500.0; Pole fell: False
# Episode: 62; Acc. Reward: 500.0; Pole fell: False
# Episode: 63; Acc. Reward: 500.0; Pole fell: False
# Episode: 64; Acc. Reward: 500.0; Pole fell: False
# Episode: 65; Acc. Reward: 500.0; Pole fell: False
# Episode: 66; Acc. Reward: 500.0; Pole fell: False
# Episode: 67; Acc. Reward: 500.0; Pole fell: False
# Episode: 68; Acc. Reward: 500.0; Pole fell: False
# Episode: 69; Acc. Reward: 500.0; Pole fell: False
# Episode: 70; Acc. Reward: 500.0; Pole fell: False
# Episode: 71; Acc. Reward: 500.0; Pole fell: False
# Episode: 72; Acc. Reward: 500.0; Pole fell: False
# Episode: 73; Acc. Reward: 500.0; Pole fell: False
# Episode: 74; Acc. Reward: 500.0; Pole fell: False
# Episode: 75; Acc. Reward: 500.0; Pole fell: False
# Episode: 76; Acc. Reward: 500.0; Pole fell: False
# Episode: 77; Acc. Reward: 500.0; Pole fell: False
# Episode: 78; Acc. Reward: 500.0; Pole fell: False
# Episode: 79; Acc. Reward: 500.0; Pole fell: False
# Episode: 80; Acc. Reward: 500.0; Pole fell: False
# Episode: 81; Acc. Reward: 500.0; Pole fell: False
# Episode: 82; Acc. Reward: 500.0; Pole fell: False
# Episode: 83; Acc. Reward: 500.0; Pole fell: False
# Episode: 84; Acc. Reward: 500.0; Pole fell: False
# Episode: 85; Acc. Reward: 500.0; Pole fell: False
# Episode: 86; Acc. Reward: 500.0; Pole fell: False
# Episode: 87; Acc. Reward: 500.0; Pole fell: False
# Episode: 88; Acc. Reward: 500.0; Pole fell: False
# Episode: 89; Acc. Reward: 500.0; Pole fell: False
# Episode: 90; Acc. Reward: 500.0; Pole fell: False
# Episode: 91; Acc. Reward: 500.0; Pole fell: False
# Episode: 92; Acc. Reward: 500.0; Pole fell: False
# Episode: 93; Acc. Reward: 500.0; Pole fell: False
# Episode: 94; Acc. Reward: 500.0; Pole fell: False
# Episode: 95; Acc. Reward: 500.0; Pole fell: False
# Episode: 96; Acc. Reward: 500.0; Pole fell: False
# Episode: 97; Acc. Reward: 500.0; Pole fell: False
# Episode: 98; Acc. Reward: 500.0; Pole fell: False
# Episode: 99; Acc. Reward: 500.0; Pole fell: False

# %%
save_observation_temp = None
save_u1_temp = None
save_pid_u1_temp = None
save_ctrl_voltage_temp = None

# %%
#save /content/drive/MyDrive/Colab Notebooks/codes/Fixed PID Constants/save_data/Cartpole
path = '/content/drive/MyDrive/Colab Notebooks/codes/Fixed PID Constants/save_data/Cartpole/'

# %%
# Create a dictionary of variables you want to save
variables_to_save = {
    'avg_reward_list': avg_reward_list,
    'acc_ep_reward_list': acc_ep_reward_list,
    'save_observation': save_observation,
    'save_wanted_torque': save_wanted_torque,
    'save_actual_torque': save_actual_torque,
    'save_ctrl_voltage': save_ctrl_voltage,
    'ep_reward_list_test': ep_reward_list_test
}

# %%
# Save the weights
actor.save_weights(path+"cartple_actor.weights.h5")
critic.save_weights(path+"cartple_critic.weights.h5")

# %%
actor.save(path+"cartple_actor.keras")
critic.save(path+"cartple_critic.keras")

# %%
#import os
#file_path = path+'Cartpole.pkl'
#if os.path.isfile(file_path):
#    print(f"The path is a file: {file_path}")
    # Proceed with your pickle loading code
#else:
#    print(f"The path is NOT a file, check for directory: {file_path}")

# %%
#save_path = '/content/drive/MyDrive/Colab Notebooks/codes/Fixed PID Constants/save_data/Cartpole/Cartpole.pkl'
with open(path+'Cartpole.pkl', 'wb') as f:
    pickle.dump(variables_to_save, f)
print(f"All variables saved to {path+'Cartpole.pkl'}")
# Out:
# All variables saved to /content/drive/MyDrive/Colab Notebooks/codes/Fixed PID Constants/save_data/Cartpole/Cartpole.pkl

# %%
# load
#load_path = '/content/drive/MyDrive/Colab Notebooks/codes/Fixed PID Constants/save_data/Cartpole/'

# %%
actor = keras.models.load_model(path+"cartple_actor.keras")
critic = keras.models.load_model(path+"cartple_critic.keras")

# %%
# Initialize the actor and the critic as keras models
#observation_input = keras.Input(shape=(observation_dimensions,), dtype="float32")
#logits = mlp(observation_input, list(hidden_sizes) + [num_actions])
#actor = keras.Model(inputs=observation_input, outputs=logits)
#value = keras.ops.squeeze(mlp(observation_input, list(hidden_sizes) + [1]), axis=1)
#critic = keras.Model(inputs=observation_input, outputs=value)

# %%
#actor.load_weights(load_path+"cartple_actor.weights.h5")
#critic.load_weights(load_path+"cartpole_critic.weights.h5")

# %%
path = '/content/drive/MyDrive/Colab Notebooks/codes/Fixed PID Constants/save_data/Cartpole/'

# %%
#load_path = '/content/drive/MyDrive/Colab Notebooks/codes/Fixed PID Constants/save_data/Cartpole/Cartpole.pkl'
# Open the file in read-binary mode and load the dictionary
with open(path+'Cartpole.pkl', 'rb') as f:
    loaded_variables = pickle.load(f)

# Access the loaded variables
avg_reward_list = loaded_variables['avg_reward_list']
acc_ep_reward_list = loaded_variables['acc_ep_reward_list']
save_observation = loaded_variables['save_observation']
save_wanted_torque = loaded_variables['save_wanted_torque']
save_actual_torque = loaded_variables['save_actual_torque']
save_ctrl_voltage = loaded_variables['save_ctrl_voltage']
ep_reward_list_test = loaded_variables['ep_reward_list_test']

# %%
plt.rc('text.latex', preamble=r'\usepackage{amsmath,amssymb,amsfonts}')
#plt.rcParams["text.usetex"]=False
#plt.rcParams["font.family"] = "sans-serif"
#plt.rcParams["font.family"] = "serif"
#plt.rcParams['mathtext.fontset'] = 'cm'
#plt.rcParams['mathtext.fontset'] = 'dejavusans'
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'

# %%
low_bound_reward_list = 0
up_bound_reward_list= 500
print("low_bound_reward_list=",low_bound_reward_list)
print("up_bound_reward_list=",up_bound_reward_list)
# Out:
# low_bound_reward_list= 0
# up_bound_reward_list= 500

# %%
def unnorm_to_norm(x):
  y = (x-low_bound_reward_list)/(up_bound_reward_list-low_bound_reward_list)
  return y

# %%
def norm_to_unnorm(y):
  x=y*(up_bound_reward_list-low_bound_reward_list)+low_bound_reward_list
  return x

# %%
norm_reward_list = np.array(avg_reward_list)
#norm_reward_list = (norm_reward_list/abs(norm_reward_list.min())+1)*100
min_norm_reward_list = 0
max_norm_reward_list=500
norm_reward_list = (norm_reward_list-min_norm_reward_list)/(max_norm_reward_list-min_norm_reward_list)

# %%
norm_reward_list = np.array(avg_reward_list)
#norm_reward_list = (norm_reward_list-min_norm_reward_list)/(max_norm_reward_list-min_norm_reward_list)
norm_reward_list = unnorm_to_norm(norm_reward_list)

# %%
# Episodes versus Avg. Rewards

font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.5)
f.set_figheight(2.2)
plt.plot(norm_reward_list, label = "Normalized Acc. Epi. Reward",color="C0",linewidth = 1.5)
#plt.axhline(y=norm_reward_list[-20:-1].mean(), linestyle='--',
#            label = "Normalized Acc. Episodic Reward's last 20 mean= "+f"{norm_reward_list[-20:-1].mean():.1f}",color="C1",linewidth = 2.5)
plt.xlabel("Training Episode")
plt.ylabel("Normalized Acc. Epi. Reward")
#plt.grid()
#plt.legend()
plt.xticks(np.arange(0, 2501, 500))
#plt.yticks(np.arange(0.0, 1.1, 0.1))
plt.minorticks_on()
plt.savefig(path+"Cartpole_Acc_Reward_vs_Episode.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# Plotting graph
# Episodes versus Acc. Rewards
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(avg_reward_list, label = "Acc. Episodic Reward",color="C0",linewidth = 1.5)
plt.axhline(y=np.array(avg_reward_list)[-20:-1].mean(), linestyle='--',
            label = "Acc. Epsiodic Reward's\nlast 20 mean= "+f"{np.array(avg_reward_list)[-20:-1].mean():.1f}",color="C1",linewidth = 2.5)
plt.minorticks_on()
plt.xlabel("Training episodes")
plt.ylabel("Acc. Episodic Reward")
#plt.grid()
plt.legend(fontsize=14)
plt.show()

# %%
print("Acc. Epsiodic Reward's last 20 mean=")
print(np.array(avg_reward_list)[-20:-1].mean())
# Out:
# Acc. Epsiodic Reward's last 20 mean=
# 500.0

# %%
print(np.array(avg_reward_list).min())
# Out:
# 10

# %%
print("Normalized Acc. Epsiodic Reward's last 20 mean=")
print(norm_reward_list[-20:-1].mean())
# Out:
# Normalized Acc. Epsiodic Reward's last 20 mean=
# 1.0

# %%
# Test Histogram
norm_ep_reward_list_test = np.array(ep_reward_list_test)
norm_ep_reward_list_test = unnorm_to_norm(norm_ep_reward_list_test)
print(norm_ep_reward_list_test.max())
print(norm_ep_reward_list_test.min())
min_bin = np.floor(norm_ep_reward_list_test.min()*100)/100
print(min_bin)
# Out:
# 1.0
# 1.0
# 1.0

# %%
font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(1.7)
f.set_figheight(2.2)
data_rewards = np.array(norm_ep_reward_list_test)
density_True = True
plt.hist(data_rewards, bins=np.arange(0,1.1,0.05), density=density_True ,color='skyblue', edgecolor='black')
plt.xlabel('Normalized Acc. Epi. Reward')
ylabel='Density'if density_True else 'Frequency'
plt.ylabel(ylabel)
#plt.xticks(np.arange(0.5,1.001,0.01))
plt.minorticks_on()
plt.xlim((0.8,1.1))
plt.savefig(path+"Cartpole_Acc_Reward_vs_Episode_Test_Hist.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print("Test Normalized Acc Episodic Reward's Results:")
print(f"Unnormalized: max={norm_to_unnorm(data_rewards).max():.3f} ,mean={norm_to_unnorm(data_rewards).mean():.3f}, std={norm_to_unnorm(data_rewards).std():.3f}")
print(f"Normalized:   max={data_rewards.max():.3e} ,mean={data_rewards.mean():.3e}, std={data_rewards.std():.3e}")
# Out:
# Test Normalized Acc Episodic Reward's Results:
# Unnormalized: max=500.000 ,mean=500.000, std=0.000
# Normalized:   max=1.000e+00 ,mean=1.000e+00, std=0.000e+00

# %%
dt=env.tau
time_= np.linspace(start = 0, stop = len(save_wanted_torque)* dt,
                   num=len(save_wanted_torque) )

# %%
sign_error = np.sign(np.array(save_wanted_torque)) - np.sign(np.array(save_actual_torque))
e_ry = np.array(save_wanted_torque) - np.array(save_actual_torque) ### add
force_error_max = np.max(np.abs(e_ry))
mean_std=f'(mean,std)=({e_ry.mean():.2e}, {e_ry.std():.2e})'

# %%
font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.5)
f.set_figheight(2.2)

plt.step(time_, save_wanted_torque,label = r"$F^\mathrm{d}$",color="blue",linewidth = 1.5)
plt.plot(time_, save_actual_torque, '--',label = r"$F$",color="red",linewidth = 2.0)
plt.plot(time_, e_ry,'-.',label = r"$F^\mathrm{d}$-$F$",color="black",linewidth = 1.1) ### add
plt.legend(fontsize=9)#(bbox_to_anchor=(1, 1), loc='upper left')
#plt.grid()
plt.xlabel('Time (s)')
plt.ylabel('Torque (N⋅m)')
plt.xlim((9.01,10.1))
plt.minorticks_on()
plt.savefig(path+"Cartpole_Torque_vs_Time.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2010: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   p.space          = oneOf(self._space_widths)("space")
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2020: PyparsingDeprecationWarning: 'leaveWhitespace' deprecated - use 'leave_whitespace'
#   )("sym").leaveWhitespace()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:1984: PyparsingDeprecationWarning: 'setName' deprecated - use 'set_name'
#   val.setName(key)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:1987: PyparsingDeprecationWarning: 'setParseAction' deprecated - use 'set_parse_action'
#   val.setParseAction(getattr(self, key))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2088: PyparsingDeprecationWarning: 'endQuoteChar' argument is deprecated, use 'end_quote_char'
#   p.text = cmd(r"\text", QuotedString('{', '\\', endQuoteChar="}"))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2146: PyparsingDeprecationWarning: 'unquoteResults' argument is deprecated, use 'unquote_results'
#   p.math_string   = QuotedString('$', '\\', unquoteResults=False)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print(mean_std)
# Out:
# (mean,std)=(1.81e-04, 9.63e-02)

# %%
print(f"mae={np.abs(e_ry).mean():.3e}")
# Out:
# mae=9.592e-02

# %%
# distribution to 4 observation parameters

position = []
velocity = []
angle = []
angular_velocity = []
for observ in save_observation:
  for index,value in enumerate(observ):
    if index == 0:
      position.append(value)
    if index == 1:
      velocity.append(value)
    if index == 2:
      angle.append(value)
    if index == 3:
      angular_velocity.append(value)

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_position = np.linspace(start = 0, stop = len(position)* dt,num=len(position))##############################################
#time_position , position
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_position[-1] , 300)

spl = make_interp_spline(time_position, position, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Position [m]')
plt.show()

# %%
print(len(position))
# Out:
# 501

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_velocity = np.linspace(start = 0, stop = len(velocity)* dt,num=len(velocity))
#time_velocity , velocity
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_velocity[-1] , 300)

spl = make_interp_spline(time_velocity, velocity, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Velocity [m]')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_angle = np.linspace(start = 0, stop = len(angle)* dt,num=len(angle))
#time_angle , angle
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_angle[-1] , 300)

spl = make_interp_spline(time_angle,angle, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Angle [rad]')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_angular_velocity = np.linspace(start = 0, stop = len(angular_velocity)* dt,num=len(angular_velocity))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_angular_velocity[-1] , 300)

spl = make_interp_spline(time_angular_velocity, angular_velocity, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Angular Velocity [rad/sec]')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

# %%
time_position = np.linspace(start = 0, stop = len(position)* dt,num=len(position))##############################################

# %%
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_position[-1] , 300)

spl = make_interp_spline(time_position, position, k=3)  # type: BSpline
norm_pos = spl(xnew)/0.1#2.4

spl = make_interp_spline(time_position,angle, k=3)  # type: BSpline
norm_angle = spl(xnew)/0.2095#/0.2095#*(180/np.pi)/12

#label = "Norm Pos",color="blue",linewidth = 1.5), ':', label = "Norm Angle",color="red",linewidth = 4)

# %%
font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.5)
f.set_figheight(2.2)
#plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

plt.plot(xnew, norm_pos,label = r"Norm Pos: $\frac{x(\text{m})}{0.1}$",color="blue",linewidth = 1.5)
plt.plot(xnew, norm_angle,'--', label = r"Norm Angle: $\frac{\theta(\text{rad})}{0.2095}$",color="red",linewidth = 1)

#plt.grid()
#plt.ylim((-9,5))
plt.minorticks_on()
plt.xlabel('Time (s)')
plt.ylabel('Normalized Observations')
plt.legend(fontsize=9)
plt.savefig(path+"Cartpole_Obs_vs_Time.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print(f"pos:   mean={(norm_pos*0.1).mean():.2e}[m]; std={(norm_pos*0.1).std():.2e}[m]")
print(f"angle: mean={(norm_angle*0.2095).mean():.2e}[rad]; std={(norm_angle*0.2095).std():.2e}[rad]")
print(f"angle: mean={(norm_angle*12).mean():.2e}[deg]; std={(norm_angle*12).std():.2e}[deg]")
# Out:
# pos:   mean=-6.59e-03[m]; std=1.10e-02[m]
# angle: mean=1.08e-05[rad]; std=7.88e-03[rad]
# angle: mean=6.16e-04[deg]; std=4.51e-01[deg]
