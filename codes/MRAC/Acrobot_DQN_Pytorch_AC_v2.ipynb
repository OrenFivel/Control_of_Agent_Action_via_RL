# %%
#dqn

# %%
#https://github.com/openai/gym/blob/master/gym/envs/classic_control/acrobot.py

# %%
#https://github.com/eugeniaring/Medium-Articles/blob/main/Pytorch/acrobot.ipynb

# %%
"""classic Acrobot task"""
from typing import Optional

import numpy as np
from numpy import cos, pi, sin

from gym import core, logger, spaces
from gym.error import DependencyNotInstalled

__copyright__ = "Copyright 2013, RLPy http://acl.mit.edu/RLPy"
__credits__ = [
    "Alborz Geramifard",
    "Robert H. Klein",
    "Christoph Dann",
    "William Dabney",
    "Jonathan P. How",
]
__license__ = "BSD 3-Clause"
__author__ = "Christoph Dann <cdann@cdann.de>"

# SOURCE:
# https://github.com/rlpy/rlpy/blob/master/rlpy/Domains/Acrobot.py
from gym.envs.classic_control import utils


class Custom_AcrobotEnv(core.Env):
    """
    ### Description
    The Acrobot environment is based on Sutton's work in
    ["Generalization in Reinforcement Learning: Successful Examples Using Sparse Coarse Coding"](https://papers.nips.cc/paper/1995/hash/8f1d43620bc6bb580df6e80b0dc05c48-Abstract.html)
    and [Sutton and Barto's book](http://www.incompleteideas.net/book/the-book-2nd.html).
    The system consists of two links connected linearly to form a chain, with one end of
    the chain fixed. The joint between the two links is actuated. The goal is to apply
    torques on the actuated joint to swing the free end of the linear chain above a
    given height while starting from the initial state of hanging downwards.
    As seen in the **Gif**: two blue links connected by two green joints. The joint in
    between the two links is actuated. The goal is to swing the free end of the outer-link
    to reach the target height (black horizontal line above system) by applying torque on
    the actuator.
    ### Action Space
    The action is discrete, deterministic, and represents the torque applied on the actuated
    joint between the two links.
    | Num | Action                                | Unit         |
    |-----|---------------------------------------|--------------|
    | 0   | apply -1 torque to the actuated joint | torque (N m) |
    | 1   | apply 0 torque to the actuated joint  | torque (N m) |
    | 2   | apply 1 torque to the actuated joint  | torque (N m) |
    ### Observation Space
    The observation is a `ndarray` with shape `(6,)` that provides information about the
    two rotational joint angles as well as their angular velocities:
    | Num | Observation                  | Min                 | Max               |
    |-----|------------------------------|---------------------|-------------------|
    | 0   | Cosine of `theta1`           | -1                  | 1                 |
    | 1   | Sine of `theta1`             | -1                  | 1                 |
    | 2   | Cosine of `theta2`           | -1                  | 1                 |
    | 3   | Sine of `theta2`             | -1                  | 1                 |
    | 4   | Angular velocity of `theta1` | ~ -12.567 (-4 * pi) | ~ 12.567 (4 * pi) |
    | 5   | Angular velocity of `theta2` | ~ -28.274 (-9 * pi) | ~ 28.274 (9 * pi) |
    where
    - `theta1` is the angle of the first joint, where an angle of 0 indicates the first link is pointing directly
    downwards.
    - `theta2` is ***relative to the angle of the first link.***
        An angle of 0 corresponds to having the same angle between the two links.
    The angular velocities of `theta1` and `theta2` are bounded at ±4π, and ±9π rad/s respectively.
    A state of `[1, 0, 1, 0, ..., ...]` indicates that both links are pointing downwards.
    ### Rewards
    The goal is to have the free end reach a designated target height in as few steps as possible,
    and as such all steps that do not reach the goal incur a reward of -1.
    Achieving the target height results in termination with a reward of 0. The reward threshold is -100.
    ### Starting State
    Each parameter in the underlying state (`theta1`, `theta2`, and the two angular velocities) is initialized
    uniformly between -0.1 and 0.1. This means both links are pointing downwards with some initial stochasticity.
    ### Episode End
    The episode ends if one of the following occurs:
    1. Termination: The free end reaches the target height, which is constructed as:
    `-cos(theta1) - cos(theta2 + theta1) > 1.0`
    2. Truncation: Episode length is greater than 500 (200 for v0)
    ### Arguments
    No additional arguments are currently supported.
    ```
    env = gym.make('Acrobot-v1')
    ```
    By default, the dynamics of the acrobot follow those described in Sutton and Barto's book
    [Reinforcement Learning: An Introduction](http://incompleteideas.net/book/11/node4.html).
    However, a `book_or_nips` parameter can be modified to change the pendulum dynamics to those described
    in the original [NeurIPS paper](https://papers.nips.cc/paper/1995/hash/8f1d43620bc6bb580df6e80b0dc05c48-Abstract.html).
    ```
    # To change the dynamics as described above
    env.env.book_or_nips = 'nips'
    ```
    See the following note and
    the [implementation](https://github.com/openai/gym/blob/master/gym/envs/classic_control/acrobot.py) for details:
    > The dynamics equations were missing some terms in the NIPS paper which
            are present in the book. R. Sutton confirmed in personal correspondence
            that the experimental results shown in the paper and the book were
            generated with the equations shown in the book.
            However, there is the option to run the domain with the paper equations
            by setting `book_or_nips = 'nips'`
    ### Version History
    - v1: Maximum number of steps increased from 200 to 500. The observation space for v0 provided direct readings of
    `theta1` and `theta2` in radians, having a range of `[-pi, pi]`. The v1 observation space as described here provides the
    sine and cosine of each angle instead.
    - v0: Initial versions release (1.0.0) (removed from gym for v1)
    ### References
    - Sutton, R. S. (1996). Generalization in Reinforcement Learning: Successful Examples Using Sparse Coarse Coding.
        In D. Touretzky, M. C. Mozer, & M. Hasselmo (Eds.), Advances in Neural Information Processing Systems (Vol. 8).
        MIT Press. https://proceedings.neurips.cc/paper/1995/file/8f1d43620bc6bb580df6e80b0dc05c48-Paper.pdf
    - Sutton, R. S., Barto, A. G. (2018 ). Reinforcement Learning: An Introduction. The MIT Press.
    """

    metadata = {
        "render_modes": ["human", "rgb_array"],
        "render_fps": 15,
    }

    dt = 0.2

    LINK_LENGTH_1 = 1.0  # [m]
    LINK_LENGTH_2 = 1.0  # [m]
    LINK_MASS_1 = 1.0  #: [kg] mass of link 1
    LINK_MASS_2 = 1.0  #: [kg] mass of link 2
    LINK_COM_POS_1 = 0.5  #: [m] position of the center of mass of link 1
    LINK_COM_POS_2 = 0.5  #: [m] position of the center of mass of link 2
    LINK_MOI = 1.0  #: moments of inertia for both links

    MAX_VEL_1 = 4 * pi
    MAX_VEL_2 = 9 * pi

    AVAIL_TORQUE = [-1.0, 0.0, +1]

    torque_noise_max = 0.0

    SCREEN_DIM = 500

    #: use dynamics equations from the nips paper or the book
    book_or_nips = "book"
    action_arrow = None
    domain_fig = None
    actions_num = 3

    def __init__(self, render_mode: Optional[str] = None):
        self.render_mode = render_mode
        self.screen = None
        self.clock = None
        self.isopen = True
        high = np.array(
            [1.0, 1.0, 1.0, 1.0, self.MAX_VEL_1, self.MAX_VEL_2], dtype=np.float32
        )
        low = -high
        self.observation_space = spaces.Box(low=low, high=high, dtype=np.float32)
        self.action_space = spaces.Discrete(3)
        self.state = None

                ### Customization changes ######
        self.NumIntegrationsSteps = 100#2010
        self.MRAC = ModelRefAC()
        self.tau1 = self.dt/self.NumIntegrationsSteps
        self.MRAC.timeSample = self.dt/self.NumIntegrationsSteps
        self.MRAC.plant.tau1 = self.dt/self.NumIntegrationsSteps
        self.MRAC.ref_model.tau1 = self.dt/self.NumIntegrationsSteps
        self.wanted_torque = 0
        ####

    def reset(self, *, seed: Optional[int] = None, options: Optional[dict] = None):
        super().reset(seed=seed)
        # Note that if you use custom reset bounds, it may lead to out-of-bound
        # state/observations.
        low, high = utils.maybe_parse_reset_bounds(
            options, -0.1, 0.1  # default low
        )  # default high
        self.state = self.np_random.uniform(low=low, high=high, size=(4,)).astype(
            np.float32
        )
      ####
        self.MRAC.reset()
        self.MRAC.plant.reset()
        self.MRAC.ref_model.reset()
        self.wanted_torque = 0
      ####
        if self.render_mode == "human":
            self.render()
        return self._get_ob()

    def step(self, a):
        s = self.state


        assert s is not None, "Call reset before using AcrobotEnv object."
        ns=np.asarray(s)
        wanted_torque = self.AVAIL_TORQUE[a]
        self.wanted_torque=wanted_torque
        #wanted_torque_temp = 0.135*self.wanted_torque+0.865*wanted_torque
        #wanted_torque_temp = 0.5*self.wanted_torque+0.5*wanted_torque
        #wanted_torque_temp = wanted_torque*1
        #wanted_torque= self.wanted_torque*1
        #self.wanted_torque = wanted_torque_temp*1

        self.MRAC.r = wanted_torque
        for n in np.arange(start=0, stop=self.NumIntegrationsSteps, step=1):
          self.MRAC.plant.thetadot =  ns[3]
          self.MRAC.r = wanted_torque #wanted_torque
          actual_torque = self.MRAC.step(r=wanted_torque)
          #actual_torque = wanted_torque # change for perfect applying force

          # Add noise to the force action
          '''
          if self.torque_noise_max > 0:
              actual_torque += self.np_random.uniform(
                  -self.torque_noise_max, self.torque_noise_max
              )
          '''
          # Now, augment the state with our force action so it can be passed to
          # _dsdt
          s_augmented = np.append(ns, actual_torque)
          ns = rk4(self._dsdt, s_augmented, [0, self.tau1])
          ns[0] = wrap(ns[0], -pi, pi)
          ns[1] = wrap(ns[1], -pi, pi)
          ns[2] = bound(ns[2], -self.MAX_VEL_1, self.MAX_VEL_1)
          ns[3] = bound(ns[3], -self.MAX_VEL_2, self.MAX_VEL_2)

        self.state = ns
        terminated = self._terminal()
        reward = -1.0 if not terminated else 0.0

        #if self.render_mode == "human":
        #    self.render()
        return self._get_ob(), reward, terminated, False , wanted_torque, actual_torque

    def _get_ob(self):
        s = self.state
        assert s is not None, "Call reset before using AcrobotEnv object."
        return np.array(
            [cos(s[0]), sin(s[0]), cos(s[1]), sin(s[1]), s[2], s[3]], dtype=np.float32
        )

    def _terminal(self):
        s = self.state
        assert s is not None, "Call reset before using AcrobotEnv object."
        return bool(-cos(s[0]) - cos(s[1] + s[0]) > 1.0)

    def _dsdt(self, s_augmented):
        m1 = self.LINK_MASS_1
        m2 = self.LINK_MASS_2
        l1 = self.LINK_LENGTH_1
        lc1 = self.LINK_COM_POS_1
        lc2 = self.LINK_COM_POS_2
        I1 = self.LINK_MOI
        I2 = self.LINK_MOI
        g = 9.8
        a = s_augmented[-1]
        s = s_augmented[:-1]
        theta1 = s[0]
        theta2 = s[1]
        dtheta1 = s[2]
        dtheta2 = s[3]
        d1 = (
            m1 * lc1**2
            + m2 * (l1**2 + lc2**2 + 2 * l1 * lc2 * cos(theta2))
            + I1
            + I2
        )
        d2 = m2 * (lc2**2 + l1 * lc2 * cos(theta2)) + I2
        phi2 = m2 * lc2 * g * cos(theta1 + theta2 - pi / 2.0)
        phi1 = (
            -m2 * l1 * lc2 * dtheta2**2 * sin(theta2)
            - 2 * m2 * l1 * lc2 * dtheta2 * dtheta1 * sin(theta2)
            + (m1 * lc1 + m2 * l1) * g * cos(theta1 - pi / 2)
            + phi2
        )
        if self.book_or_nips == "nips":
            # the following line is consistent with the description in the
            # paper
            ddtheta2 = (a + d2 / d1 * phi1 - phi2) / (m2 * lc2**2 + I2 - d2**2 / d1)
        else:
            # the following line is consistent with the java implementation and the
            # book
            ddtheta2 = (
                a + d2 / d1 * phi1 - m2 * l1 * lc2 * dtheta1**2 * sin(theta2) - phi2
            ) / (m2 * lc2**2 + I2 - d2**2 / d1)
        ddtheta1 = -(d2 * ddtheta2 + phi1) / d1
        return dtheta1, dtheta2, ddtheta1, ddtheta2, 0.0

    def render(self):
        if self.render_mode is None:
            logger.warn(
                "You are calling render method without specifying any render mode. "
                "You can specify the render_mode at initialization, "
                f'e.g. gym("{self.spec.id}", render_mode="rgb_array")'
            )
            return

        try:
            import pygame
            from pygame import gfxdraw
        except ImportError:
            raise DependencyNotInstalled(
                "pygame is not installed, run `pip install gym[classic_control]`"
            )

        if self.screen is None:
            pygame.init()
            if self.render_mode == "human":
                pygame.display.init()
                self.screen = pygame.display.set_mode(
                    (self.SCREEN_DIM, self.SCREEN_DIM)
                )
            else:  # mode in "rgb_array"
                self.screen = pygame.Surface((self.SCREEN_DIM, self.SCREEN_DIM))
        if self.clock is None:
            self.clock = pygame.time.Clock()

        surf = pygame.Surface((self.SCREEN_DIM, self.SCREEN_DIM))
        surf.fill((255, 255, 255))
        s = self.state

        bound = self.LINK_LENGTH_1 + self.LINK_LENGTH_2 + 0.2  # 2.2 for default
        scale = self.SCREEN_DIM / (bound * 2)
        offset = self.SCREEN_DIM / 2

        if s is None:
            return None

        p1 = [
            -self.LINK_LENGTH_1 * cos(s[0]) * scale,
            self.LINK_LENGTH_1 * sin(s[0]) * scale,
        ]

        p2 = [
            p1[0] - self.LINK_LENGTH_2 * cos(s[0] + s[1]) * scale,
            p1[1] + self.LINK_LENGTH_2 * sin(s[0] + s[1]) * scale,
        ]

        xys = np.array([[0, 0], p1, p2])[:, ::-1]
        thetas = [s[0] - pi / 2, s[0] + s[1] - pi / 2]
        link_lengths = [self.LINK_LENGTH_1 * scale, self.LINK_LENGTH_2 * scale]

        pygame.draw.line(
            surf,
            start_pos=(-2.2 * scale + offset, 1 * scale + offset),
            end_pos=(2.2 * scale + offset, 1 * scale + offset),
            color=(0, 0, 0),
        )

        for ((x, y), th, llen) in zip(xys, thetas, link_lengths):
            x = x + offset
            y = y + offset
            l, r, t, b = 0, llen, 0.1 * scale, -0.1 * scale
            coords = [(l, b), (l, t), (r, t), (r, b)]
            transformed_coords = []
            for coord in coords:
                coord = pygame.math.Vector2(coord).rotate_rad(th)
                coord = (coord[0] + x, coord[1] + y)
                transformed_coords.append(coord)
            gfxdraw.aapolygon(surf, transformed_coords, (0, 204, 204))
            gfxdraw.filled_polygon(surf, transformed_coords, (0, 204, 204))

            gfxdraw.aacircle(surf, int(x), int(y), int(0.1 * scale), (204, 204, 0))
            gfxdraw.filled_circle(surf, int(x), int(y), int(0.1 * scale), (204, 204, 0))

        surf = pygame.transform.flip(surf, False, True)
        self.screen.blit(surf, (0, 0))

        if self.render_mode == "human":
            pygame.event.pump()
            self.clock.tick(self.metadata["render_fps"])
            pygame.display.flip()

        elif self.render_mode == "rgb_array":
            return np.transpose(
                np.array(pygame.surfarray.pixels3d(self.screen)), axes=(1, 0, 2)
            )

    def close(self):
        if self.screen is not None:
            import pygame

            pygame.display.quit()
            pygame.quit()
            self.isopen = False


def wrap(x, m, M):
    """Wraps ``x`` so m <= x <= M; but unlike ``bound()`` which
    truncates, ``wrap()`` wraps x around the coordinate system defined by m,M.\n
    For example, m = -180, M = 180 (degrees), x = 360 --> returns 0.
    Args:
        x: a scalar
        m: minimum possible value in range
        M: maximum possible value in range
    Returns:
        x: a scalar, wrapped
    """
    diff = M - m
    while x > M:
        x = x - diff
    while x < m:
        x = x + diff
    return x


def bound(x, m, M=None):
    """Either have m as scalar, so bound(x,m,M) which returns m <= x <= M *OR*
    have m as length 2 vector, bound(x,m, <IGNORED>) returns m[0] <= x <= m[1].
    Args:
        x: scalar
        m: The lower bound
        M: The upper bound
    Returns:
        x: scalar, bound between min (m) and Max (M)
    """
    if M is None:
        M = m[1]
        m = m[0]
    # bound x between min (m) and Max (M)
    return min(max(x, m), M)


def rk4(derivs, y0, t):
    """
    Integrate 1-D or N-D system of ODEs using 4-th order Runge-Kutta.
    Example for 2D system:
        >>> def derivs(x):
        ...     d1 =  x[0] + 2*x[1]
        ...     d2 =  -3*x[0] + 4*x[1]
        ...     return d1, d2
        >>> dt = 0.0005
        >>> t = np.arange(0.0, 2.0, dt)
        >>> y0 = (1,2)
        >>> yout = rk4(derivs, y0, t)
    Args:
        derivs: the derivative of the system and has the signature ``dy = derivs(yi)``
        y0: initial state vector
        t: sample times
    Returns:
        yout: Runge-Kutta approximation of the ODE
    """

    try:
        Ny = len(y0)
    except TypeError:
        yout = np.zeros((len(t),), np.float_)
    else:
        yout = np.zeros((len(t), Ny), np.float_)

    yout[0] = y0

    for i in np.arange(len(t) - 1):

        this = t[i]
        dt = t[i + 1] - this
        dt2 = dt / 2.0
        y0 = yout[i]

        k1 = np.asarray(derivs(y0))
        k2 = np.asarray(derivs(y0 + dt2 * k1))
        k3 = np.asarray(derivs(y0 + dt2 * k2))
        k4 = np.asarray(derivs(y0 + dt * k3))
        yout[i + 1] = y0 + dt / 6.0 * (k1 + 2 * k2 + 2 * k3 + k4)
    # We only care about the final timestep and we cleave off action value which will be zero
    return yout[-1][:4]

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
class ElectricalDCMotorEnv():

  def __init__(self):
    self.Resistor_R = 1.0
    self.inductor_L = 0.1
    self.torque_const_Kt = 1.0
    self.bemf_const_Ke = 1.0
    self.tau1 = 0.05
        #
    self.current = 0.0
    self.voltage_input = None
    self.thetadot = 0.0

  def step(self, u):
    voltage_BEMF = self.thetadot*self.bemf_const_Ke
    self.voltage_input = np.clip(u, -10, 10)

    f1 = self.torque_const_Kt*self.current
    self.current += self.tau1*(self.voltage_input-voltage_BEMF-self.current*self.Resistor_R)/self.inductor_L
    f2 = self.torque_const_Kt*self.current
    F = f2
    return F # return actual applied torque

  def reset(self):
    self.current = 0.0

# %%
class ReferenceModel():

  def __init__(self):
    self.a_m = 50.0#30.0
    self.b_m = self.a_m
    self.tau1 = 0.05
    self.x_m = 0.0
    self.y_m = 0.0

  def step(self, r):

    #fwd integration
    #A = -self.a_m*self.tau1
    #Br = self.b_m*self.tau1*r
    #self.y_m = self.x_m+0
    #self.x_m = (1+A)*self.y_m+Br

    #bkwd integration
    #A = -self.a_m*self.tau1
    #Br = self.b_m*self.tau1*r
    #if A ==1:
    #  C=1
    #else:
    #  C = 1/(1-A)
    #self.y_m = C*(self.x_m-Br)
    #self.x_m = self.y_m+0

    #trapz integragration
    A = -0.5*self.a_m*self.tau1
    Br= +0.5*self.b_m*self.tau1*r
    if A ==1:
      C=1
    else:
      C = 1/(1-A)
    x_m = self.x_m
    y_m = C*(x_m+Br)
    x_m = (1+A)*y_m + Br
    self.x_m = x_m
    self.y_m = y_m

    return y_m

  def reset(self):
    self.x_m = 0.0
    self.y_m = 0.0

# %%
class ModelRefAC:

  def __init__(self): #  order of signals [r,y,r-y,w]
    self.plant = ElectricalDCMotorEnv()
    self.ref_model = ReferenceModel()
    self.w = 0.0
    self.u = 0.0
    self.r = 0.0
    self.y = 0.0
    self.y_m = 0.0
    self.adaptation_gain=np.array([5,5,3,5])*5 # positive scalar or np.array shape (4,)
    self.sigma_mod_adapt_gain=1e-1*0 # non-neg scalar or np.array shape (4,)
    self.emod_adapt_gain=1e-1*0
    self.dead_zone_threshold = 1e-1*0
    self.dead_zone_adapt_gain = 1e-4*0
    self.timeSample=0.05
    self.mu0 = np.array([1e-3,-1e-3,1e-3,1e-3])
    self.std = 0
    self.k_temp = self.mu0
    self.k_hat =  self.mu0
    self.keep_coeff = True # logic or bewteen 0 and 1
    self.mask = np.array([True,True,True,True])
    self.distrib = np.random.standard_normal
    self.count = 0
    self.count_upperbound = 100


  def step(self, r):
    self.r = r
    self.w = self.plant.thetadot
    y = self.y
    y_m = self.y_m
    e=y-y_m
    u = self.adaptationControlLaw(e=e, r=r, y=y, w=self.w)
    self.y_m = self.ref_model.step(r)
    self.y = self.plant.step(u)
    return self.y

  def adaptationControlLaw(self, e, r, y, w):
    v = np.array([r,y,r-y,w])#.clip(-30,30)
    e_norm = abs(e)#abs(r-y)

    #fwd integration
    #A = -(self.sigma_mod_adapt_gain+self.emod_adapt_gain*e_norm)*self.timeSample
    #Bev = -self.adaptation_gain*self.timeSample*e*v
    #if e_norm<=self.dead_zone_threshold:
    #  A = A*self.dead_zone_adapt_gain
    #  Bev = Bev*self.dead_zone_adapt_gain
    #self.k_hat = self.k_temp*self.mask
    #self.k_temp = ((1+A)*self.k_hat + Bev)*self.mask

    #backwd integration
    #A = -(self.sigma_mod_adapt_gain+self.emod_adapt_gain*e_norm)*self.timeSample
    #Bev = -self.adaptation_gain*self.timeSample*e*v
    #if e_norm<=self.dead_zone_threshold:
    #  A = A*self.dead_zone_adapt_gain
    #  Bev = Bev*self.dead_zone_adapt_gain
    #C = 1-A*(A!=np.ones_like(A))
    #C = 1/C
    #self.k_hat = C*(self.k_temp+Bev)*self.mask
    #self.k_temp = A*self.k_hat*self.mask

    #trapz integration
    A = -0.5*(self.sigma_mod_adapt_gain+self.emod_adapt_gain*e_norm)*self.timeSample
    Bev = -0.5*self.adaptation_gain*self.timeSample*e*v
    if e_norm<=self.dead_zone_threshold:
      A = A*self.dead_zone_adapt_gain
      Bev = Bev*self.dead_zone_adapt_gain
    #C = 1-A*(A!=np.ones_like(A))
    #C=1/C
    if A ==1:
      C=1
    else:
      C = 1/(1-A)
    self.k_hat = C*((self.k_temp +Bev)*self.mask)
    self.k_temp = ((1+A)*self.k_hat +Bev)*self.mask

    self.count+=1
    if self.count>self.count_upperbound:
      self.count = 0
      self.adaptation_gain=self.adaptation_gain*0.99


    #  self.k_temp = self.mu0


    u = np.dot(v,self.k_hat)
    u=np.clip(u,-10,10)
    self.u = u
    return u

  def reset(self):
    self.w = 0.0
    self.r = 0.0
    self.y = 0.0
    self.y_m = 0.0
    mu0 = self.mu0
    sigma0 = self.std
    keep_coeff = self.keep_coeff
    self.k_temp = (sigma0*self.distrib(self.k_temp.shape) + keep_coeff*self.k_temp + (1 - keep_coeff)*mu0)*self.mask
    self.k_hat = (sigma0*self.distrib(self.k_hat.shape) + keep_coeff*self.k_hat + (1 - keep_coeff)*mu0)*self.mask
    #self.count = 0

# %%
env =  Custom_AcrobotEnv()

# %%
print("dt= ", env.dt)
print("N= ", env.NumIntegrationsSteps)
print("dt/N=", env.dt/env.NumIntegrationsSteps)
print("gamma*dt/N=", env.MRAC.adaptation_gain*env.dt/env.NumIntegrationsSteps)
# Out:
# dt=  0.2
# N=  100
# dt/N= 0.002
# gamma*dt/N= [0.05 0.05 0.03 0.05]

# %%
#import os

# %%
import random
#os.environ["CUDA_VISIBLE_DEVICES"] ="GPU_ID"
import torch
import numpy as np
import gym
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from torch import nn
from collections import deque,namedtuple

# %%
# !apt update
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Fetched 257 kB in 3s (80.2 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 58 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package python-opengl
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.12).
# 0 upgraded, 0 newly installed, 0 to remove and 58 not upgraded.
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.10/dist-packages (3.0)
# Requirement already satisfied: piglet in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: piglet-templates in /usr/local/lib/python3.10/dist-packages (from piglet) (1.3.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from piglet-templates->piglet) (3.2.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from piglet-templates->piglet) (24.2.0)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.10/dist-packages (from piglet-templates->piglet) (1.6.3)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.10/dist-packages (from piglet-templates->piglet) (3.0.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse->piglet-templates->piglet) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from astunparse->piglet-templates->piglet) (1.16.0)

# %%
#!pip install nvidia-dali-cuda120
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import glob
import io
import base64
import os
from IPython.display import HTML
from IPython import display as ipythondisplay
from pyvirtualdisplay import Display
#from gym.wrappers import Monitor

# %%
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
    # !bash ../xvfb start
    # %env DISPLAY=:1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
class ReplayMemory(object):

    def __init__(self, capacity):
        # Define a queue with maxlen "capacity"
        self.memory = deque(maxlen=capacity)

    def push(self, state, action, next_state, reward):
        # Add the tuple (state, action, next_state, reward) to the queue
        self.memory.append((state, action, next_state, reward))

    def sample(self, batch_size):
        batch_size = min(batch_size, len(self)) # Get all the samples if the requested batch_size is higher than the number of sample currently in the memory
        # Randomly select "batch_size" samples and return the selection
        return random.sample(self.memory,batch_size)

    def __len__(self):
        return len(self.memory) # Return the number of samples currently stored in the memory

# %%
class DQN(nn.Module):

    def __init__(self, state_space_dim, action_space_dim):
        super().__init__()

        self.linear = nn.Sequential(
                  nn.Linear(state_space_dim,64),
                  nn.ReLU(),
                  nn.Linear(64,64*2),
                  nn.ReLU(),
                  nn.Linear(64*2,action_space_dim)
                )

    def forward(self, x):
        x = x.to(device)
        return self.linear(x)

# %%
def choose_action_epsilon_greedy(net, state, epsilon):

    if epsilon > 1 or epsilon < 0:
        raise Exception('The epsilon value must be between 0 and 1')

    # Evaluate the network output from the current state
    with torch.no_grad():
        net.eval()
        state = torch.tensor(state, dtype=torch.float32) # Convert the state to tensor
        net_out = net(state)

    # Get the best action (argmax of the network output)
    best_action = int(net_out.argmax())
    # Get the number of possible actions
    action_space_dim = net_out.shape[-1]

    # Select a non optimal action with probability epsilon, otherwise choose the best action
    if random.random() < epsilon:
        # List of non-optimal actions (this list includes all the actions but the optimal one)
        non_optimal_actions = [a for a in range(action_space_dim) if a != best_action]
        # Select randomly from non_optimal_actions
        action = random.choice(non_optimal_actions)
    else:
        # Select best action
        action = best_action

    return action, net_out.cpu().numpy()

# %%
def choose_action_softmax(net, state, temperature):

    if temperature < 0:
        raise Exception('The temperature value must be greater than or equal to 0 ')

    # If the temperature is 0, just select the best action using the eps-greedy policy with epsilon = 0
    if temperature == 0:
        return choose_action_epsilon_greedy(net, state, 0)

    # Evaluate the network output from the current state
    with torch.no_grad():
        net.eval()
        state = torch.tensor(state, dtype=torch.float32)
        net_out = net(state)

    # Apply softmax with temp
    temperature = max(temperature, 1e-8) # set a minimum to the temperature for numerical stability
    softmax_out = nn.functional.softmax(net_out/temperature, dim=0).cpu().numpy()

    # Sample the action using softmax output as mass pdf
    all_possible_actions = np.arange(0, softmax_out.shape[-1])
    # this samples a random element from "all_possible_actions" with the probability distribution p (softmax_out in this case)
    action = np.random.choice(all_possible_actions,p=softmax_out)

    return action, net_out.cpu().numpy()

# %%
### Define exploration profile
initial_value = 5
#num_iterations = 800
#num_iterations = 10
num_iterations = 600
exp_decay = np.exp(-np.log(initial_value) / num_iterations * 6) # We compute the exponential decay in such a way the shape of the exploration profile does not depend on the number of iterations
exploration_profile = [initial_value * (exp_decay ** i) for i in range(num_iterations)]
score_low_bound = -500#-2000 ###change add score low bound


### Plot exploration profile
plt.figure(figsize=(12,8))
plt.plot(exploration_profile)
plt.grid()
plt.xlabel('Iteration')
plt.ylabel('Exploration profile (Softmax temperature)')
# Out:
# Text(0, 0.5, 'Exploration profile (Softmax temperature)')

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
### Create environment
env =  Custom_AcrobotEnv()
env.seed(0) # Set a random seed for the environment (reproducible results)
env.MRAC.adaptation_gain[1]
# Get the shapes of the state space (observation_space) and action space (action_space)
state_space_dim = env.observation_space.shape[0]
action_space_dim = env.action_space.n
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"STATE SPACE SIZE: {state_space_dim}")
print(f"ACTION SPACE SIZE: {action_space_dim}")
# Out:
# STATE SPACE SIZE: 6
# ACTION SPACE SIZE: 3
# /usr/local/lib/python3.10/dist-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(

# %%
# Set random seeds
torch.manual_seed(0)
np.random.seed(0)

### PARAMETERS
gamma = 0.99   # gamma parameter for the long term reward
replay_memory_capacity = 10000   # Replay memory capacity
lr = 1e-3 # Optimizer learning rate
target_net_update_steps = 10   # Number of episodes to wait before updating the target network
batch_size = 256   # Number of samples to take from the replay memory for each update
bad_state_penalty = 0   # Penalty to the reward when we are in a bad state (in this case when the pole falls down)
min_samples_for_training = 1000   # Minimum samples in the replay memory to enable the training

# %%
### Initialize the replay memory
replay_mem = ReplayMemory(replay_memory_capacity)

### Initialize the policy network
policy_net = DQN(state_space_dim, action_space_dim).to(device)

### Initialize the target network with the same weights of the policy network
target_net = DQN(state_space_dim, action_space_dim).to(device)
target_net.load_state_dict(policy_net.state_dict()) # This will copy the weights of the policy network to the target network

### Initialize the optimizer
optimizer = torch.optim.Adam(policy_net.parameters(), lr=lr) # The optimizer will update ONLY the parameters of the policy network

### Initialize the loss function (Huber loss)
loss_fn = nn.SmoothL1Loss()

# %%
def update_step(policy_net, target_net, replay_mem, gamma, optimizer, loss_fn, batch_size):

    # Sample the data from the replay memory
    batch = replay_mem.sample(batch_size)
    batch_size = len(batch)
    #print(type(batch)) #batch = np.array(batch)

    # Create tensors for each element of the batch
    states      = torch.tensor([s[0] for s in batch], dtype=torch.float32, device=device)
    actions     = torch.tensor([s[1] for s in batch], dtype=torch.int64, device=device)
    rewards     = torch.tensor([s[3] for s in batch], dtype=torch.float32, device=device)

    # Compute a mask of non-final states (all the elements where the next state is not None)
    non_final_next_states = torch.tensor([s[2] for s in batch if s[2] is not None], dtype=torch.float32, device=device) # the next state can be None if the game has ended
    non_final_mask = torch.tensor([s[2] is not None for s in batch], dtype=torch.bool)

    # Compute all the Q values (forward pass)
    policy_net.train()
    q_values = policy_net(states)
    # Select the proper Q value for the corresponding action taken Q(s_t, a)
    #state_action_values = q_values.gather(1, actions.unsqueeze(1).cuda())
    state_action_values = q_values.gather(1, actions.unsqueeze(1).to(device))
    #er0r
    # Compute the value function of the next states using the target network V(s_{t+1}) = max_a( Q_target(s_{t+1}, a)) )
    with torch.no_grad():
      target_net.eval()
      q_values_target = target_net(non_final_next_states)
    next_state_max_q_values = torch.zeros(batch_size, device=device)
    next_state_max_q_values[non_final_mask] = q_values_target.max(dim=1)[0].detach()

    # Compute the expected Q values
    expected_state_action_values = rewards + (next_state_max_q_values * gamma)
    expected_state_action_values = expected_state_action_values.unsqueeze(1)# Set the required tensor shape

    # Compute the Huber loss
    loss = loss_fn(state_action_values, expected_state_action_values)

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    # Apply gradient clipping (clip all the gradients greater than 2 for training stability)
    nn.utils.clip_grad_norm_(policy_net.parameters(), 2)
    optimizer.step()

# %%
# Initialize the Gym environment
#env = gym.make('Acrobot-v1')
env =  Custom_AcrobotEnv()
env.seed(0) # Set a random seed for the environment (reproducible results)

# This is for creating the output video in Colab, not required outside Colab
#env = wrap_env(env, video_callable=lambda episode_id: episode_id % 100 == 0) # Save a video every 100 episodes

plotting_rewards=[]

save_observation = []
save_wanted_torque = [0]
save_actual_torque = [0]
save_model_torque = [0]
save_ctrl_voltage = []
save_MRAC_adapt_gains = []
ploting_adapt_coeff=[]
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(

# %%
initial_not_saved = True
k_hat_print = env.MRAC.mu0
print('Initial adapt. coeffs: ', k_hat_print)
#adaptation_gain = env.MRAC.adaptation_gain
#env.MRAC.adaptation_gain[1] = 0
for episode_num, tau in enumerate(tqdm(exploration_profile)):

    #if episode_num == int(len(exploration_profile)/3):
    #  env.MRAC.adaptation_gain =  adaptation_gain+0

    # Reset the environment and get the initial state
    state = env.reset()
    #state = state[0]###################################################################################################################################################
    # Reset the score. The final score will be the total amount of steps before the pole falls
    score = 0
    done = False
    # Go on until the pole falls off
    while not done:
      k_hat_print = env.MRAC.k_hat.round(2)
      if episode_num == len(exploration_profile) - 1 and initial_not_saved:
        save_MRAC_adapt_gains.append(env.MRAC.k_hat)
        save_observation.append(state)
        u0=env.MRAC.adaptationControlLaw(e=env.MRAC.y-env.MRAC.y_m,
                                              r=env.MRAC.r,y=env.MRAC.y,
                                              w=env.MRAC.w)
        save_ctrl_voltage.append(u0)
        initial_not_saved = False
      #end if

      # Choose the action following the policy
      action, q_values = choose_action_softmax(policy_net, state, temperature=tau)

      # Apply the action and get the next state, the reward and a flag "done" that is True if the game is ended
      next_state, reward, done, info, wanted_torque , actual_torque = env.step(action)#############################################
      if episode_num == len(exploration_profile) - 1 :################################################################################
        save_observation.append(next_state)
        save_wanted_torque.append(wanted_torque)
        save_actual_torque.append(actual_torque)
        save_model_torque.append(env.MRAC.y_m)
        save_ctrl_voltage.append(env.MRAC.u)
        save_MRAC_adapt_gains.append(env.MRAC.k_hat)
      #end if

      # Update the final score (+1 for each step)
      score += reward

      if score<score_low_bound: ##### change  to stop high negative score
        done =True
        #env.MRAC.k_temp = env.MRAC.mu0*1


      #if score<score_low_bound:
      #  env.MRAC.k_hat = env.MRAC.mu0*1
      #env.MRAC.k_temp = env.MRAC.mu0*1

      # Apply penalty for bad state

      if done: # if the pole has fallen down
          reward += bad_state_penalty
          next_state = None

      # Update the replay memory
      replay_mem.push(state, action, next_state, reward)

      # Update the network
      if len(replay_mem) > min_samples_for_training: # we enable the training only if we have enough samples in the replay memory, otherwise the training will use the same samples too often
          update_step(policy_net, target_net, replay_mem, gamma, optimizer, loss_fn, batch_size)

      # Visually render the environment (disable to speed up the training)
      #env.render()

      # Set the current state for the next iteration
      state = next_state

    # Update the target network every target_net_update_steps episodes
    if episode_num % target_net_update_steps == 0 : #score<score_low_bound:
        print('Updating target network...')
        target_net.load_state_dict(policy_net.state_dict()) # This will copy the weights of the policy network to the target network

    ploting_adapt_coeff.append(k_hat_print)
    plotting_rewards.append(score)
    # Print the final score
    print(f"EPISODE: {episode_num + 1} ", " adapt. coeffs at final time step: ", k_hat_print)
    if (episode_num + 1)%10==0:
      k_hat_median = np.median(np.array(ploting_adapt_coeff), axis=0)
      print("median: ", k_hat_median)
      #env.MRAC.mu0 = k_hat_median*1
      #env.MRAC.k_hat = k_hat_median*1
      #env.MRAC.k_temp = k_hat_median*1
    print(f"EPISODE: {episode_num + 1} - FINAL SCORE: {score}") # Print the final score

env.MRAC.keep_coeff = True
env.close()
# Out:
# Initial adapt. coeffs:  [ 0.001 -0.001  0.001  0.001]
#   0%|          | 0/600 [00:00<?, ?it/s]
# Updating target network...
# EPISODE: 1   adapt. coeffs at final time step:  [ 2.28 -1.25  2.12  1.  ]
# EPISODE: 1 - FINAL SCORE: -501.0
# <ipython-input-30-acfd9505cef0>:9: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   states      = torch.tensor([s[0] for s in batch], dtype=torch.float32, device=device)
# EPISODE: 2   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 2 - FINAL SCORE: -501.0
# EPISODE: 3   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 3 - FINAL SCORE: -501.0
# EPISODE: 4   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 4 - FINAL SCORE: -501.0
# EPISODE: 5   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 5 - FINAL SCORE: -501.0
# EPISODE: 6   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 6 - FINAL SCORE: -501.0
# EPISODE: 7   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 7 - FINAL SCORE: -501.0
# EPISODE: 8   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 8 - FINAL SCORE: -501.0
# EPISODE: 9   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 9 - FINAL SCORE: -501.0
# EPISODE: 10   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 10 - FINAL SCORE: -449.0
# Updating target network...
# EPISODE: 11   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 11 - FINAL SCORE: -501.0
# EPISODE: 12   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 12 - FINAL SCORE: -501.0
# EPISODE: 13   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 13 - FINAL SCORE: -501.0
# EPISODE: 14   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 14 - FINAL SCORE: -501.0
# EPISODE: 15   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 15 - FINAL SCORE: -501.0
# EPISODE: 16   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 16 - FINAL SCORE: -501.0
# EPISODE: 17   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 17 - FINAL SCORE: -501.0
# EPISODE: 18   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 18 - FINAL SCORE: -501.0
# EPISODE: 19   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 19 - FINAL SCORE: -501.0
# EPISODE: 20   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 20 - FINAL SCORE: -501.0
# Updating target network...
# EPISODE: 21   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 21 - FINAL SCORE: -501.0
# EPISODE: 22   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 22 - FINAL SCORE: -501.0
# EPISODE: 23   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 23 - FINAL SCORE: -501.0
# EPISODE: 24   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 24 - FINAL SCORE: -501.0
# EPISODE: 25   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 25 - FINAL SCORE: -501.0
# EPISODE: 26   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 26 - FINAL SCORE: -501.0
# EPISODE: 27   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 27 - FINAL SCORE: -501.0
# EPISODE: 28   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 28 - FINAL SCORE: -501.0
# EPISODE: 29   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 29 - FINAL SCORE: -501.0
# EPISODE: 30   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 30 - FINAL SCORE: -501.0
# Updating target network...
# EPISODE: 31   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 31 - FINAL SCORE: -501.0
# EPISODE: 32   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 32 - FINAL SCORE: -501.0
# EPISODE: 33   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 33 - FINAL SCORE: -501.0
# EPISODE: 34   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 34 - FINAL SCORE: -501.0
# EPISODE: 35   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 35 - FINAL SCORE: -501.0
# EPISODE: 36   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 36 - FINAL SCORE: -501.0
# EPISODE: 37   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 37 - FINAL SCORE: -501.0
# EPISODE: 38   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 38 - FINAL SCORE: -501.0
# EPISODE: 39   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 39 - FINAL SCORE: -501.0
# EPISODE: 40   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 40 - FINAL SCORE: -501.0
# Updating target network...
# EPISODE: 41   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 41 - FINAL SCORE: -501.0
# EPISODE: 42   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 42 - FINAL SCORE: -501.0
# EPISODE: 43   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 43 - FINAL SCORE: -501.0
# EPISODE: 44   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 44 - FINAL SCORE: -501.0
# EPISODE: 45   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 45 - FINAL SCORE: -376.0
# EPISODE: 46   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 46 - FINAL SCORE: -501.0
# EPISODE: 47   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 47 - FINAL SCORE: -501.0
# EPISODE: 48   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 48 - FINAL SCORE: -501.0
# EPISODE: 49   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 49 - FINAL SCORE: -501.0
# EPISODE: 50   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 50 - FINAL SCORE: -501.0
# Updating target network...
# EPISODE: 51   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 51 - FINAL SCORE: -501.0
# EPISODE: 52   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 52 - FINAL SCORE: -501.0
# EPISODE: 53   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 53 - FINAL SCORE: -501.0
# EPISODE: 54   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 54 - FINAL SCORE: -501.0
# EPISODE: 55   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 55 - FINAL SCORE: -501.0
# EPISODE: 56   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 56 - FINAL SCORE: -501.0
# EPISODE: 57   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 57 - FINAL SCORE: -501.0
# EPISODE: 58   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 58 - FINAL SCORE: -501.0
# EPISODE: 59   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 59 - FINAL SCORE: -501.0
# EPISODE: 60   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 60 - FINAL SCORE: -501.0
# Updating target network...
# EPISODE: 61   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 61 - FINAL SCORE: -501.0
# EPISODE: 62   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 62 - FINAL SCORE: -501.0
# EPISODE: 63   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 63 - FINAL SCORE: -501.0
# EPISODE: 64   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 64 - FINAL SCORE: -501.0
# EPISODE: 65   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 65 - FINAL SCORE: -501.0
# EPISODE: 66   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 66 - FINAL SCORE: -501.0
# EPISODE: 67   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 67 - FINAL SCORE: -501.0
# EPISODE: 68   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 68 - FINAL SCORE: -501.0
# EPISODE: 69   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 69 - FINAL SCORE: -501.0
# EPISODE: 70   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 70 - FINAL SCORE: -501.0
# Updating target network...
# EPISODE: 71   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 71 - FINAL SCORE: -501.0
# EPISODE: 72   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 72 - FINAL SCORE: -501.0
# EPISODE: 73   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 73 - FINAL SCORE: -501.0
# EPISODE: 74   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 74 - FINAL SCORE: -501.0
# EPISODE: 75   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 75 - FINAL SCORE: -501.0
# EPISODE: 76   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 76 - FINAL SCORE: -501.0
# EPISODE: 77   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 77 - FINAL SCORE: -501.0
# EPISODE: 78   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 78 - FINAL SCORE: -501.0
# EPISODE: 79   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 79 - FINAL SCORE: -501.0
# EPISODE: 80   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 80 - FINAL SCORE: -501.0
# Updating target network...
# EPISODE: 81   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 81 - FINAL SCORE: -501.0
# EPISODE: 82   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 82 - FINAL SCORE: -501.0
# EPISODE: 83   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 83 - FINAL SCORE: -501.0
# EPISODE: 84   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 84 - FINAL SCORE: -501.0
# EPISODE: 85   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 85 - FINAL SCORE: -501.0
# EPISODE: 86   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 86 - FINAL SCORE: -501.0
# EPISODE: 87   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 87 - FINAL SCORE: -412.0
# EPISODE: 88   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 88 - FINAL SCORE: -501.0
# EPISODE: 89   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 89 - FINAL SCORE: -501.0
# EPISODE: 90   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 90 - FINAL SCORE: -501.0
# Updating target network...
# EPISODE: 91   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 91 - FINAL SCORE: -501.0
# EPISODE: 92   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 92 - FINAL SCORE: -501.0
# EPISODE: 93   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 93 - FINAL SCORE: -501.0
# EPISODE: 94   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 94 - FINAL SCORE: -501.0
# EPISODE: 95   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 95 - FINAL SCORE: -472.0
# EPISODE: 96   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 96 - FINAL SCORE: -501.0
# EPISODE: 97   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 97 - FINAL SCORE: -501.0
# EPISODE: 98   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 98 - FINAL SCORE: -501.0
# EPISODE: 99   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 99 - FINAL SCORE: -501.0
# EPISODE: 100   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 100 - FINAL SCORE: -501.0
# Updating target network...
# EPISODE: 101   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 101 - FINAL SCORE: -501.0
# EPISODE: 102   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 102 - FINAL SCORE: -501.0
# EPISODE: 103   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 103 - FINAL SCORE: -501.0
# EPISODE: 104   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 104 - FINAL SCORE: -501.0
# EPISODE: 105   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 105 - FINAL SCORE: -317.0
# EPISODE: 106   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 106 - FINAL SCORE: -501.0
# EPISODE: 107   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 107 - FINAL SCORE: -501.0
# EPISODE: 108   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 108 - FINAL SCORE: -501.0
# EPISODE: 109   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 109 - FINAL SCORE: -501.0
# EPISODE: 110   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 110 - FINAL SCORE: -440.0
# Updating target network...
# EPISODE: 111   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 111 - FINAL SCORE: -501.0
# EPISODE: 112   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 112 - FINAL SCORE: -501.0
# EPISODE: 113   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 113 - FINAL SCORE: -501.0
# EPISODE: 114   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 114 - FINAL SCORE: -501.0
# EPISODE: 115   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 115 - FINAL SCORE: -501.0
# EPISODE: 116   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 116 - FINAL SCORE: -501.0
# EPISODE: 117   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 117 - FINAL SCORE: -501.0
# EPISODE: 118   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 118 - FINAL SCORE: -501.0
# EPISODE: 119   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 119 - FINAL SCORE: -412.0
# EPISODE: 120   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 120 - FINAL SCORE: -501.0
# Updating target network...
# EPISODE: 121   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 121 - FINAL SCORE: -501.0
# EPISODE: 122   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 122 - FINAL SCORE: -501.0
# EPISODE: 123   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 123 - FINAL SCORE: -501.0
# EPISODE: 124   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 124 - FINAL SCORE: -501.0
# EPISODE: 125   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 125 - FINAL SCORE: -369.0
# EPISODE: 126   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 126 - FINAL SCORE: -501.0
# EPISODE: 127   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 127 - FINAL SCORE: -501.0
# EPISODE: 128   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 128 - FINAL SCORE: -501.0
# EPISODE: 129   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 129 - FINAL SCORE: -379.0
# EPISODE: 130   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 130 - FINAL SCORE: -501.0
# Updating target network...
# EPISODE: 131   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 131 - FINAL SCORE: -501.0
# EPISODE: 132   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 132 - FINAL SCORE: -501.0
# EPISODE: 133   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 133 - FINAL SCORE: -501.0
# EPISODE: 134   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 134 - FINAL SCORE: -362.0
# EPISODE: 135   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 135 - FINAL SCORE: -501.0
# EPISODE: 136   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 136 - FINAL SCORE: -476.0
# EPISODE: 137   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 137 - FINAL SCORE: -501.0
# EPISODE: 138   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 138 - FINAL SCORE: -267.0
# EPISODE: 139   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 139 - FINAL SCORE: -349.0
# EPISODE: 140   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 140 - FINAL SCORE: -322.0
# Updating target network...
# EPISODE: 141   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 141 - FINAL SCORE: -199.0
# EPISODE: 142   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 142 - FINAL SCORE: -501.0
# EPISODE: 143   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 143 - FINAL SCORE: -501.0
# EPISODE: 144   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 144 - FINAL SCORE: -501.0
# EPISODE: 145   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 145 - FINAL SCORE: -501.0
# EPISODE: 146   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 146 - FINAL SCORE: -501.0
# EPISODE: 147   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 147 - FINAL SCORE: -501.0
# EPISODE: 148   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 148 - FINAL SCORE: -474.0
# EPISODE: 149   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 149 - FINAL SCORE: -501.0
# EPISODE: 150   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 150 - FINAL SCORE: -501.0
# Updating target network...
# EPISODE: 151   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 151 - FINAL SCORE: -293.0
# EPISODE: 152   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 152 - FINAL SCORE: -444.0
# EPISODE: 153   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 153 - FINAL SCORE: -501.0
# EPISODE: 154   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 154 - FINAL SCORE: -501.0
# EPISODE: 155   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 155 - FINAL SCORE: -501.0
# EPISODE: 156   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 156 - FINAL SCORE: -501.0
# EPISODE: 157   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 157 - FINAL SCORE: -501.0
# EPISODE: 158   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 158 - FINAL SCORE: -501.0
# EPISODE: 159   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 159 - FINAL SCORE: -501.0
# EPISODE: 160   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 160 - FINAL SCORE: -349.0
# Updating target network...
# EPISODE: 161   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 161 - FINAL SCORE: -468.0
# EPISODE: 162   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 162 - FINAL SCORE: -501.0
# EPISODE: 163   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 163 - FINAL SCORE: -501.0
# EPISODE: 164   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 164 - FINAL SCORE: -349.0
# EPISODE: 165   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 165 - FINAL SCORE: -328.0
# EPISODE: 166   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 166 - FINAL SCORE: -501.0
# EPISODE: 167   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 167 - FINAL SCORE: -501.0
# EPISODE: 168   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 168 - FINAL SCORE: -475.0
# EPISODE: 169   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 169 - FINAL SCORE: -471.0
# EPISODE: 170   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 170 - FINAL SCORE: -441.0
# Updating target network...
# EPISODE: 171   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 171 - FINAL SCORE: -501.0
# EPISODE: 172   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 172 - FINAL SCORE: -313.0
# EPISODE: 173   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 173 - FINAL SCORE: -501.0
# EPISODE: 174   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 174 - FINAL SCORE: -234.0
# EPISODE: 175   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 175 - FINAL SCORE: -501.0
# EPISODE: 176   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 176 - FINAL SCORE: -261.0
# EPISODE: 177   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 177 - FINAL SCORE: -501.0
# EPISODE: 178   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 178 - FINAL SCORE: -501.0
# EPISODE: 179   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 179 - FINAL SCORE: -345.0
# EPISODE: 180   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 180 - FINAL SCORE: -379.0
# Updating target network...
# EPISODE: 181   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 181 - FINAL SCORE: -260.0
# EPISODE: 182   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 182 - FINAL SCORE: -378.0
# EPISODE: 183   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 183 - FINAL SCORE: -439.0
# EPISODE: 184   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 184 - FINAL SCORE: -390.0
# EPISODE: 185   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 185 - FINAL SCORE: -187.0
# EPISODE: 186   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 186 - FINAL SCORE: -197.0
# EPISODE: 187   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 187 - FINAL SCORE: -298.0
# EPISODE: 188   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 188 - FINAL SCORE: -419.0
# EPISODE: 189   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 189 - FINAL SCORE: -217.0
# EPISODE: 190   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 190 - FINAL SCORE: -501.0
# Updating target network...
# EPISODE: 191   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 191 - FINAL SCORE: -501.0
# EPISODE: 192   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 192 - FINAL SCORE: -389.0
# EPISODE: 193   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 193 - FINAL SCORE: -342.0
# EPISODE: 194   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 194 - FINAL SCORE: -501.0
# EPISODE: 195   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 195 - FINAL SCORE: -501.0
# EPISODE: 196   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 196 - FINAL SCORE: -392.0
# EPISODE: 197   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 197 - FINAL SCORE: -252.0
# EPISODE: 198   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 198 - FINAL SCORE: -197.0
# EPISODE: 199   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 199 - FINAL SCORE: -427.0
# EPISODE: 200   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 200 - FINAL SCORE: -465.0
# Updating target network...
# EPISODE: 201   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 201 - FINAL SCORE: -389.0
# EPISODE: 202   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 202 - FINAL SCORE: -408.0
# EPISODE: 203   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 203 - FINAL SCORE: -320.0
# EPISODE: 204   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 204 - FINAL SCORE: -350.0
# EPISODE: 205   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 205 - FINAL SCORE: -297.0
# EPISODE: 206   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 206 - FINAL SCORE: -501.0
# EPISODE: 207   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 207 - FINAL SCORE: -168.0
# EPISODE: 208   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 208 - FINAL SCORE: -392.0
# EPISODE: 209   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 209 - FINAL SCORE: -222.0
# EPISODE: 210   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 210 - FINAL SCORE: -501.0
# Updating target network...
# EPISODE: 211   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 211 - FINAL SCORE: -302.0
# EPISODE: 212   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 212 - FINAL SCORE: -235.0
# EPISODE: 213   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 213 - FINAL SCORE: -334.0
# EPISODE: 214   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 214 - FINAL SCORE: -333.0
# EPISODE: 215   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 215 - FINAL SCORE: -373.0
# EPISODE: 216   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 216 - FINAL SCORE: -366.0
# EPISODE: 217   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 217 - FINAL SCORE: -188.0
# EPISODE: 218   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 218 - FINAL SCORE: -273.0
# EPISODE: 219   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 219 - FINAL SCORE: -286.0
# EPISODE: 220   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 220 - FINAL SCORE: -402.0
# Updating target network...
# EPISODE: 221   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 221 - FINAL SCORE: -169.0
# EPISODE: 222   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 222 - FINAL SCORE: -377.0
# EPISODE: 223   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 223 - FINAL SCORE: -251.0
# EPISODE: 224   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 224 - FINAL SCORE: -290.0
# EPISODE: 225   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 225 - FINAL SCORE: -227.0
# EPISODE: 226   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 226 - FINAL SCORE: -501.0
# EPISODE: 227   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 227 - FINAL SCORE: -265.0
# EPISODE: 228   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 228 - FINAL SCORE: -236.0
# EPISODE: 229   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 229 - FINAL SCORE: -222.0
# EPISODE: 230   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 230 - FINAL SCORE: -200.0
# Updating target network...
# EPISODE: 231   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 231 - FINAL SCORE: -291.0
# EPISODE: 232   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 232 - FINAL SCORE: -293.0
# EPISODE: 233   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 233 - FINAL SCORE: -222.0
# EPISODE: 234   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 234 - FINAL SCORE: -206.0
# EPISODE: 235   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 235 - FINAL SCORE: -154.0
# EPISODE: 236   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 236 - FINAL SCORE: -145.0
# EPISODE: 237   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 237 - FINAL SCORE: -232.0
# EPISODE: 238   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 238 - FINAL SCORE: -209.0
# EPISODE: 239   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 239 - FINAL SCORE: -190.0
# EPISODE: 240   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 240 - FINAL SCORE: -209.0
# Updating target network...
# EPISODE: 241   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 241 - FINAL SCORE: -190.0
# EPISODE: 242   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 242 - FINAL SCORE: -149.0
# EPISODE: 243   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 243 - FINAL SCORE: -144.0
# EPISODE: 244   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 244 - FINAL SCORE: -157.0
# EPISODE: 245   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 245 - FINAL SCORE: -235.0
# EPISODE: 246   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 246 - FINAL SCORE: -262.0
# EPISODE: 247   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 247 - FINAL SCORE: -157.0
# EPISODE: 248   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 248 - FINAL SCORE: -120.0
# EPISODE: 249   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 249 - FINAL SCORE: -269.0
# EPISODE: 250   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 250 - FINAL SCORE: -255.0
# Updating target network...
# EPISODE: 251   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 251 - FINAL SCORE: -121.0
# EPISODE: 252   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 252 - FINAL SCORE: -209.0
# EPISODE: 253   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 253 - FINAL SCORE: -202.0
# EPISODE: 254   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 254 - FINAL SCORE: -112.0
# EPISODE: 255   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 255 - FINAL SCORE: -147.0
# EPISODE: 256   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 256 - FINAL SCORE: -140.0
# EPISODE: 257   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 257 - FINAL SCORE: -168.0
# EPISODE: 258   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 258 - FINAL SCORE: -161.0
# EPISODE: 259   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 259 - FINAL SCORE: -105.0
# EPISODE: 260   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 260 - FINAL SCORE: -129.0
# Updating target network...
# EPISODE: 261   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 261 - FINAL SCORE: -161.0
# EPISODE: 262   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 262 - FINAL SCORE: -260.0
# EPISODE: 263   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 263 - FINAL SCORE: -126.0
# EPISODE: 264   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 264 - FINAL SCORE: -109.0
# EPISODE: 265   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 265 - FINAL SCORE: -124.0
# EPISODE: 266   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 266 - FINAL SCORE: -189.0
# EPISODE: 267   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 267 - FINAL SCORE: -118.0
# EPISODE: 268   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 268 - FINAL SCORE: -142.0
# EPISODE: 269   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 269 - FINAL SCORE: -176.0
# EPISODE: 270   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 270 - FINAL SCORE: -165.0
# Updating target network...
# EPISODE: 271   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 271 - FINAL SCORE: -271.0
# EPISODE: 272   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 272 - FINAL SCORE: -160.0
# EPISODE: 273   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 273 - FINAL SCORE: -180.0
# EPISODE: 274   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 274 - FINAL SCORE: -115.0
# EPISODE: 275   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 275 - FINAL SCORE: -215.0
# EPISODE: 276   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 276 - FINAL SCORE: -122.0
# EPISODE: 277   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 277 - FINAL SCORE: -175.0
# EPISODE: 278   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 278 - FINAL SCORE: -184.0
# EPISODE: 279   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 279 - FINAL SCORE: -153.0
# EPISODE: 280   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 280 - FINAL SCORE: -95.0
# Updating target network...
# EPISODE: 281   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 281 - FINAL SCORE: -121.0
# EPISODE: 282   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 282 - FINAL SCORE: -162.0
# EPISODE: 283   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 283 - FINAL SCORE: -83.0
# EPISODE: 284   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 284 - FINAL SCORE: -144.0
# EPISODE: 285   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 285 - FINAL SCORE: -141.0
# EPISODE: 286   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 286 - FINAL SCORE: -125.0
# EPISODE: 287   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 287 - FINAL SCORE: -140.0
# EPISODE: 288   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 288 - FINAL SCORE: -110.0
# EPISODE: 289   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 289 - FINAL SCORE: -195.0
# EPISODE: 290   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 290 - FINAL SCORE: -122.0
# Updating target network...
# EPISODE: 291   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 291 - FINAL SCORE: -156.0
# EPISODE: 292   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 292 - FINAL SCORE: -135.0
# EPISODE: 293   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 293 - FINAL SCORE: -137.0
# EPISODE: 294   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 294 - FINAL SCORE: -125.0
# EPISODE: 295   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 295 - FINAL SCORE: -84.0
# EPISODE: 296   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 296 - FINAL SCORE: -150.0
# EPISODE: 297   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 297 - FINAL SCORE: -106.0
# EPISODE: 298   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 298 - FINAL SCORE: -93.0
# EPISODE: 299   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 299 - FINAL SCORE: -155.0
# EPISODE: 300   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 300 - FINAL SCORE: -129.0
# Updating target network...
# EPISODE: 301   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 301 - FINAL SCORE: -209.0
# EPISODE: 302   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 302 - FINAL SCORE: -94.0
# EPISODE: 303   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 303 - FINAL SCORE: -132.0
# EPISODE: 304   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 304 - FINAL SCORE: -96.0
# EPISODE: 305   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 305 - FINAL SCORE: -173.0
# EPISODE: 306   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 306 - FINAL SCORE: -127.0
# EPISODE: 307   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 307 - FINAL SCORE: -112.0
# EPISODE: 308   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 308 - FINAL SCORE: -96.0
# EPISODE: 309   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 309 - FINAL SCORE: -112.0
# EPISODE: 310   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 310 - FINAL SCORE: -130.0
# Updating target network...
# EPISODE: 311   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 311 - FINAL SCORE: -113.0
# EPISODE: 312   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 312 - FINAL SCORE: -117.0
# EPISODE: 313   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 313 - FINAL SCORE: -150.0
# EPISODE: 314   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 314 - FINAL SCORE: -128.0
# EPISODE: 315   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 315 - FINAL SCORE: -115.0
# EPISODE: 316   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 316 - FINAL SCORE: -113.0
# EPISODE: 317   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 317 - FINAL SCORE: -93.0
# EPISODE: 318   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 318 - FINAL SCORE: -154.0
# EPISODE: 319   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 319 - FINAL SCORE: -127.0
# EPISODE: 320   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 320 - FINAL SCORE: -130.0
# Updating target network...
# EPISODE: 321   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 321 - FINAL SCORE: -165.0
# EPISODE: 322   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 322 - FINAL SCORE: -154.0
# EPISODE: 323   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 323 - FINAL SCORE: -151.0
# EPISODE: 324   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 324 - FINAL SCORE: -112.0
# EPISODE: 325   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 325 - FINAL SCORE: -94.0
# EPISODE: 326   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 326 - FINAL SCORE: -106.0
# EPISODE: 327   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 327 - FINAL SCORE: -118.0
# EPISODE: 328   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 328 - FINAL SCORE: -132.0
# EPISODE: 329   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 329 - FINAL SCORE: -119.0
# EPISODE: 330   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 330 - FINAL SCORE: -149.0
# Updating target network...
# EPISODE: 331   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 331 - FINAL SCORE: -114.0
# EPISODE: 332   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 332 - FINAL SCORE: -156.0
# EPISODE: 333   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 333 - FINAL SCORE: -130.0
# EPISODE: 334   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 334 - FINAL SCORE: -80.0
# EPISODE: 335   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 335 - FINAL SCORE: -92.0
# EPISODE: 336   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 336 - FINAL SCORE: -118.0
# EPISODE: 337   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 337 - FINAL SCORE: -92.0
# EPISODE: 338   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 338 - FINAL SCORE: -97.0
# EPISODE: 339   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 339 - FINAL SCORE: -92.0
# EPISODE: 340   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 340 - FINAL SCORE: -108.0
# Updating target network...
# EPISODE: 341   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 341 - FINAL SCORE: -152.0
# EPISODE: 342   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 342 - FINAL SCORE: -128.0
# EPISODE: 343   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 343 - FINAL SCORE: -82.0
# EPISODE: 344   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 344 - FINAL SCORE: -122.0
# EPISODE: 345   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 345 - FINAL SCORE: -102.0
# EPISODE: 346   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 346 - FINAL SCORE: -139.0
# EPISODE: 347   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 347 - FINAL SCORE: -132.0
# EPISODE: 348   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 348 - FINAL SCORE: -133.0
# EPISODE: 349   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 349 - FINAL SCORE: -90.0
# EPISODE: 350   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 350 - FINAL SCORE: -97.0
# Updating target network...
# EPISODE: 351   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 351 - FINAL SCORE: -144.0
# EPISODE: 352   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 352 - FINAL SCORE: -113.0
# EPISODE: 353   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 353 - FINAL SCORE: -116.0
# EPISODE: 354   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 354 - FINAL SCORE: -120.0
# EPISODE: 355   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 355 - FINAL SCORE: -116.0
# EPISODE: 356   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 356 - FINAL SCORE: -136.0
# EPISODE: 357   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 357 - FINAL SCORE: -144.0
# EPISODE: 358   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 358 - FINAL SCORE: -121.0
# EPISODE: 359   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 359 - FINAL SCORE: -110.0
# EPISODE: 360   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 360 - FINAL SCORE: -106.0
# Updating target network...
# EPISODE: 361   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 361 - FINAL SCORE: -501.0
# EPISODE: 362   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 362 - FINAL SCORE: -167.0
# EPISODE: 363   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 363 - FINAL SCORE: -501.0
# EPISODE: 364   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 364 - FINAL SCORE: -149.0
# EPISODE: 365   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 365 - FINAL SCORE: -501.0
# EPISODE: 366   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 366 - FINAL SCORE: -97.0
# EPISODE: 367   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 367 - FINAL SCORE: -184.0
# EPISODE: 368   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 368 - FINAL SCORE: -145.0
# EPISODE: 369   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 369 - FINAL SCORE: -108.0
# EPISODE: 370   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 370 - FINAL SCORE: -112.0
# Updating target network...
# EPISODE: 371   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 371 - FINAL SCORE: -120.0
# EPISODE: 372   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 372 - FINAL SCORE: -98.0
# EPISODE: 373   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 373 - FINAL SCORE: -103.0
# EPISODE: 374   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 374 - FINAL SCORE: -131.0
# EPISODE: 375   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 375 - FINAL SCORE: -97.0
# EPISODE: 376   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 376 - FINAL SCORE: -119.0
# EPISODE: 377   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 377 - FINAL SCORE: -95.0
# EPISODE: 378   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 378 - FINAL SCORE: -111.0
# EPISODE: 379   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 379 - FINAL SCORE: -79.0
# EPISODE: 380   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 380 - FINAL SCORE: -86.0
# Updating target network...
# EPISODE: 381   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 381 - FINAL SCORE: -125.0
# EPISODE: 382   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 382 - FINAL SCORE: -92.0
# EPISODE: 383   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 383 - FINAL SCORE: -83.0
# EPISODE: 384   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 384 - FINAL SCORE: -87.0
# EPISODE: 385   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 385 - FINAL SCORE: -80.0
# EPISODE: 386   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 386 - FINAL SCORE: -108.0
# EPISODE: 387   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 387 - FINAL SCORE: -98.0
# EPISODE: 388   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 388 - FINAL SCORE: -114.0
# EPISODE: 389   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 389 - FINAL SCORE: -87.0
# EPISODE: 390   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 390 - FINAL SCORE: -159.0
# Updating target network...
# EPISODE: 391   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 391 - FINAL SCORE: -86.0
# EPISODE: 392   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 392 - FINAL SCORE: -103.0
# EPISODE: 393   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 393 - FINAL SCORE: -78.0
# EPISODE: 394   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 394 - FINAL SCORE: -94.0
# EPISODE: 395   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 395 - FINAL SCORE: -98.0
# EPISODE: 396   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 396 - FINAL SCORE: -98.0
# EPISODE: 397   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 397 - FINAL SCORE: -96.0
# EPISODE: 398   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 398 - FINAL SCORE: -108.0
# EPISODE: 399   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 399 - FINAL SCORE: -86.0
# EPISODE: 400   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 400 - FINAL SCORE: -77.0
# Updating target network...
# EPISODE: 401   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 401 - FINAL SCORE: -83.0
# EPISODE: 402   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 402 - FINAL SCORE: -86.0
# EPISODE: 403   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 403 - FINAL SCORE: -136.0
# EPISODE: 404   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 404 - FINAL SCORE: -82.0
# EPISODE: 405   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 405 - FINAL SCORE: -83.0
# EPISODE: 406   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 406 - FINAL SCORE: -501.0
# EPISODE: 407   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 407 - FINAL SCORE: -83.0
# EPISODE: 408   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# ...
# EPISODE: 463 - FINAL SCORE: -76.0
# EPISODE: 464   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 464 - FINAL SCORE: -99.0
# EPISODE: 465   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 465 - FINAL SCORE: -89.0
# EPISODE: 466   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 466 - FINAL SCORE: -72.0
# EPISODE: 467   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 467 - FINAL SCORE: -78.0
# EPISODE: 468   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 468 - FINAL SCORE: -73.0
# EPISODE: 469   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 469 - FINAL SCORE: -501.0
# EPISODE: 470   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 470 - FINAL SCORE: -77.0
# Updating target network...
# EPISODE: 471   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 471 - FINAL SCORE: -63.0
# EPISODE: 472   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 472 - FINAL SCORE: -82.0
# EPISODE: 473   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 473 - FINAL SCORE: -71.0
# EPISODE: 474   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 474 - FINAL SCORE: -72.0
# EPISODE: 475   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 475 - FINAL SCORE: -113.0
# EPISODE: 476   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 476 - FINAL SCORE: -86.0
# EPISODE: 477   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 477 - FINAL SCORE: -69.0
# EPISODE: 478   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 478 - FINAL SCORE: -71.0
# EPISODE: 479   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 479 - FINAL SCORE: -71.0
# EPISODE: 480   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 480 - FINAL SCORE: -64.0
# Updating target network...
# EPISODE: 481   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 481 - FINAL SCORE: -142.0
# EPISODE: 482   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 482 - FINAL SCORE: -69.0
# EPISODE: 483   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 483 - FINAL SCORE: -74.0
# EPISODE: 484   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 484 - FINAL SCORE: -72.0
# EPISODE: 485   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 485 - FINAL SCORE: -69.0
# EPISODE: 486   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 486 - FINAL SCORE: -85.0
# EPISODE: 487   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 487 - FINAL SCORE: -123.0
# EPISODE: 488   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 488 - FINAL SCORE: -91.0
# EPISODE: 489   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 489 - FINAL SCORE: -89.0
# EPISODE: 490   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 490 - FINAL SCORE: -84.0
# Updating target network...
# EPISODE: 491   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 491 - FINAL SCORE: -71.0
# EPISODE: 492   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 492 - FINAL SCORE: -92.0
# EPISODE: 493   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 493 - FINAL SCORE: -71.0
# EPISODE: 494   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 494 - FINAL SCORE: -107.0
# EPISODE: 495   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 495 - FINAL SCORE: -75.0
# EPISODE: 496   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 496 - FINAL SCORE: -99.0
# EPISODE: 497   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 497 - FINAL SCORE: -94.0
# EPISODE: 498   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 498 - FINAL SCORE: -73.0
# EPISODE: 499   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 499 - FINAL SCORE: -83.0
# EPISODE: 500   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 500 - FINAL SCORE: -124.0
# Updating target network...
# EPISODE: 501   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 501 - FINAL SCORE: -98.0
# EPISODE: 502   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 502 - FINAL SCORE: -63.0
# EPISODE: 503   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 503 - FINAL SCORE: -104.0
# EPISODE: 504   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 504 - FINAL SCORE: -80.0
# EPISODE: 505   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 505 - FINAL SCORE: -71.0
# EPISODE: 506   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 506 - FINAL SCORE: -89.0
# EPISODE: 507   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 507 - FINAL SCORE: -114.0
# EPISODE: 508   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 508 - FINAL SCORE: -104.0
# EPISODE: 509   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 509 - FINAL SCORE: -70.0
# EPISODE: 510   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 510 - FINAL SCORE: -86.0
# Updating target network...
# EPISODE: 511   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 511 - FINAL SCORE: -72.0
# EPISODE: 512   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 512 - FINAL SCORE: -91.0
# EPISODE: 513   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 513 - FINAL SCORE: -64.0
# EPISODE: 514   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 514 - FINAL SCORE: -137.0
# EPISODE: 515   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 515 - FINAL SCORE: -83.0
# EPISODE: 516   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 516 - FINAL SCORE: -98.0
# EPISODE: 517   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 517 - FINAL SCORE: -77.0
# EPISODE: 518   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 518 - FINAL SCORE: -72.0
# EPISODE: 519   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 519 - FINAL SCORE: -85.0
# EPISODE: 520   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 520 - FINAL SCORE: -129.0
# Updating target network...
# EPISODE: 521   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 521 - FINAL SCORE: -91.0
# EPISODE: 522   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 522 - FINAL SCORE: -77.0
# EPISODE: 523   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 523 - FINAL SCORE: -99.0
# EPISODE: 524   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 524 - FINAL SCORE: -68.0
# EPISODE: 525   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 525 - FINAL SCORE: -93.0
# EPISODE: 526   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 526 - FINAL SCORE: -71.0
# EPISODE: 527   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 527 - FINAL SCORE: -72.0
# EPISODE: 528   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 528 - FINAL SCORE: -71.0
# EPISODE: 529   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 529 - FINAL SCORE: -78.0
# EPISODE: 530   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 530 - FINAL SCORE: -72.0
# Updating target network...
# EPISODE: 531   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 531 - FINAL SCORE: -88.0
# EPISODE: 532   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 532 - FINAL SCORE: -78.0
# EPISODE: 533   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 533 - FINAL SCORE: -71.0
# EPISODE: 534   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 534 - FINAL SCORE: -98.0
# EPISODE: 535   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 535 - FINAL SCORE: -70.0
# EPISODE: 536   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 536 - FINAL SCORE: -77.0
# EPISODE: 537   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 537 - FINAL SCORE: -90.0
# EPISODE: 538   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 538 - FINAL SCORE: -70.0
# EPISODE: 539   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 539 - FINAL SCORE: -76.0
# EPISODE: 540   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 540 - FINAL SCORE: -95.0
# Updating target network...
# EPISODE: 541   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 541 - FINAL SCORE: -111.0
# EPISODE: 542   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 542 - FINAL SCORE: -82.0
# EPISODE: 543   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 543 - FINAL SCORE: -89.0
# EPISODE: 544   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 544 - FINAL SCORE: -71.0
# EPISODE: 545   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 545 - FINAL SCORE: -86.0
# EPISODE: 546   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 546 - FINAL SCORE: -63.0
# EPISODE: 547   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 547 - FINAL SCORE: -64.0
# EPISODE: 548   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 548 - FINAL SCORE: -94.0
# EPISODE: 549   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 549 - FINAL SCORE: -75.0
# EPISODE: 550   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 550 - FINAL SCORE: -116.0
# Updating target network...
# EPISODE: 551   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 551 - FINAL SCORE: -107.0
# EPISODE: 552   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 552 - FINAL SCORE: -71.0
# EPISODE: 553   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 553 - FINAL SCORE: -81.0
# EPISODE: 554   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 554 - FINAL SCORE: -106.0
# EPISODE: 555   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 555 - FINAL SCORE: -70.0
# EPISODE: 556   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 556 - FINAL SCORE: -80.0
# EPISODE: 557   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 557 - FINAL SCORE: -101.0
# EPISODE: 558   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 558 - FINAL SCORE: -77.0
# EPISODE: 559   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 559 - FINAL SCORE: -82.0
# EPISODE: 560   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 560 - FINAL SCORE: -84.0
# Updating target network...
# EPISODE: 561   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 561 - FINAL SCORE: -62.0
# EPISODE: 562   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 562 - FINAL SCORE: -64.0
# EPISODE: 563   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 563 - FINAL SCORE: -93.0
# EPISODE: 564   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 564 - FINAL SCORE: -96.0
# EPISODE: 565   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 565 - FINAL SCORE: -71.0
# EPISODE: 566   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 566 - FINAL SCORE: -83.0
# EPISODE: 567   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 567 - FINAL SCORE: -83.0
# EPISODE: 568   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 568 - FINAL SCORE: -90.0
# EPISODE: 569   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 569 - FINAL SCORE: -73.0
# EPISODE: 570   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 570 - FINAL SCORE: -130.0
# Updating target network...
# EPISODE: 571   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 571 - FINAL SCORE: -96.0
# EPISODE: 572   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 572 - FINAL SCORE: -78.0
# EPISODE: 573   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 573 - FINAL SCORE: -83.0
# EPISODE: 574   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 574 - FINAL SCORE: -95.0
# EPISODE: 575   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 575 - FINAL SCORE: -90.0
# EPISODE: 576   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 576 - FINAL SCORE: -83.0
# EPISODE: 577   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 577 - FINAL SCORE: -82.0
# EPISODE: 578   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 578 - FINAL SCORE: -64.0
# EPISODE: 579   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 579 - FINAL SCORE: -83.0
# EPISODE: 580   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 580 - FINAL SCORE: -62.0
# Updating target network...
# EPISODE: 581   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 581 - FINAL SCORE: -75.0
# EPISODE: 582   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 582 - FINAL SCORE: -81.0
# EPISODE: 583   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 583 - FINAL SCORE: -75.0
# EPISODE: 584   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 584 - FINAL SCORE: -72.0
# EPISODE: 585   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 585 - FINAL SCORE: -81.0
# EPISODE: 586   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 586 - FINAL SCORE: -91.0
# EPISODE: 587   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 587 - FINAL SCORE: -89.0
# EPISODE: 588   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 588 - FINAL SCORE: -70.0
# EPISODE: 589   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 589 - FINAL SCORE: -72.0
# EPISODE: 590   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 590 - FINAL SCORE: -89.0
# Updating target network...
# EPISODE: 591   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 591 - FINAL SCORE: -106.0
# EPISODE: 592   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 592 - FINAL SCORE: -109.0
# EPISODE: 593   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 593 - FINAL SCORE: -87.0
# EPISODE: 594   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 594 - FINAL SCORE: -83.0
# EPISODE: 595   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 595 - FINAL SCORE: -80.0
# EPISODE: 596   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 596 - FINAL SCORE: -501.0
# EPISODE: 597   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 597 - FINAL SCORE: -94.0
# EPISODE: 598   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 598 - FINAL SCORE: -98.0
# EPISODE: 599   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 599 - FINAL SCORE: -99.0
# EPISODE: 600   adapt. coeffs at final time step:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# EPISODE: 600 - FINAL SCORE: -77.0

# %%
print("mean: ", (np.array(ploting_adapt_coeff)).mean(axis=0).round(2))
print("median: ", np.median(np.array(ploting_adapt_coeff), axis=0))
# Out:
# mean:  [ 2.27 -1.25  2.12  1.  ]
# median:  [ 2.27 -1.25  2.12  1.  ]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(range(1,num_iterations+1),plotting_rewards)
plt.xlabel('Training episodes')
plt.ylabel('Acc. Episodic Reward')
plt.ylim([-500,-40])
plt.legend()
plt.title('Acrobot v1')
plt.grid()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print(type(plotting_rewards))
# Out:
# <class 'list'>
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Compute the moving average of the last 50 numbers
moving_average = []
for i, n in enumerate(plotting_rewards):
    if i < 50:
        # If there are not enough previous elements,
        # append the average of all available elements
        avg = sum(plotting_rewards[:i+1]) / (i+1)
    else:
        # Otherwise, compute the average of the previous 5 elements
        avg = sum(plotting_rewards[i-50:i+1]) / 50
    moving_average.append(avg)

# %%
# Plot the moving average

font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(moving_average)
plt.xlabel("Episode")
plt.ylabel("Avg. Epsiodic Reward")
plt.grid()
plt.show()

# %%
font = {'size': 20}
plt.rc('font', **font)
plt.plot(ploting_adapt_coeff)
plt.xlabel("Training episodes")
plt.ylabel("Adaptation control gains\n at last time step")
#plt.rc('axes', labelsize=30)

plt.grid()
plt.legend(labels=[r"$\hat{k_r}$=coeff of $a^{wanted}$",
                   r"$\hat{k}_y$=coeff of $a^{actual}$",
                 r"$\hat{k}_{r-y}$=coeff of $(a^{wanted}-a^{actual})$",
                 r"$\hat{k}_\omega$=coeff of $\dot{\theta}$"], fontsize=10)
plt.show()

# %%
N=50
# Compute the moving average of the last 50 numbers
moving_average = []
for i, n in enumerate(ploting_adapt_coeff):
    if i < N:
        # If there are not enough previous elements,
        # append the average of all available elements
        avg = sum(ploting_adapt_coeff[:i+1]) / (i+1)
    else:
        # Otherwise, compute the average of the previous 5 elements
        avg = sum(ploting_adapt_coeff[i-N:i+1]) / N
    moving_average.append(avg)
moving_average = np.array(moving_average).T
# Plot the moving average

plt.plot(moving_average[0]
         ,label = r"$\hat{k_r}$=coeff of $a^{wanted}$"+f"→{moving_average[0,-5:-1].mean():.1e}",color="C0",linewidth = 2)
plt.plot(moving_average[1],'--',
         label = r"$\hat{k}_y$=coeff of $a^{actual}$"+f"→{moving_average[1,-5:-1].mean():.1e}",color="C1",linewidth = 3)
plt.plot(moving_average[2],':',
         label = r"$\hat{k}_{r-y}$=coeff of $(a^{wanted}-a^{actual})$"+f"→{moving_average[2,-5:-1].mean():.1e}",color="C2",linewidth = 4)
plt.plot(moving_average[3],'-.',
         label = r"$\hat{k}_\omega$=coeff of $\dot{\theta}$"+f"→{moving_average[3,-5:-1].mean():.1e}",color="C3",linewidth = 2)
#plt.plot(moving_average)
plt.xlabel("Training episodes")
plt.ylabel("Adaptation control gains\n at last time step")
plt.grid()
plt.legend(fontsize=10, bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
dt=env.dt
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
time_ = np.linspace(start = 0, stop = len(save_actual_torque)* dt,num=len(save_actual_torque) )

font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')


plt.step(time_, save_wanted_torque ,label = r"$r=a^{wanted}$ from RL alg.",color="blue",linewidth = 1.5)
plt.step(time_, save_model_torque , '--',label = "$y_m=a^{model}$ from MRAC ref. model",color="green",linewidth = 2)
plt.step(time_, save_actual_torque , ':',label = "$y=a^{actual}$ from DC motor plant",color="red",linewidth = 4)
plt.xlabel("time [sec]")
plt.ylabel("Torque [Nm]")
plt.legend(fontsize=10)
plt.grid()
plt.show()

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

e_ry=np.array(save_wanted_torque)-np.array(save_actual_torque)
e_yy_m=np.array(save_actual_torque)-np.array(save_model_torque)


plt.step(time_, e_ry ,label = "$e_{r,y}=a^{wanted}-a^{actual}$ ",color="cyan",linewidth = 1.5)
plt.step(time_, e_yy_m , ':',label = "$e_{y,y_m}=a^{actual}-a^{model}$ ",color="brown",linewidth = 4)
plt.axhline(y=e_ry.mean(), color="black",linewidth = 2, linestyle='--', label='mean($e_{r,y}$) =' +f'{e_ry.mean():.1e}')
plt.axhline(y=e_yy_m.mean(), color="magenta",linewidth = 2, linestyle='-.', label='mean($e_{y,y_m}$) =' +f'{e_yy_m.mean():.1e}')


plt.xlabel("time [sec]")
plt.ylabel("Torque error [Nm]")
plt.legend(fontsize=10)
plt.grid()
plt.show()

# %%
from scipy.integrate import cumulative_trapezoid

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

e_ry=np.array(save_wanted_torque)-np.array(save_actual_torque)
e_yy_m=np.array(save_actual_torque)-np.array(save_model_torque)

plt.step(time_, e_ry ,label = r"$e_{r,y}=a^{wanted}-a^{actual}$ ",color="cyan",linewidth = 1.5)
plt.step(time_, e_yy_m , ':',label = "$e_{y,y_m}=a^{actual}-a^{model}$ ",color="brown",linewidth = 4)

plt.xlabel("time [sec]")
plt.ylabel("Torque error [Nm]")
plt.legend(fontsize=12)
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

e_ry=np.array(save_wanted_torque)-np.array(save_actual_torque)
e_yy_m=np.array(save_actual_torque)-np.array(save_model_torque)

cum_trapz_e_ry = cumulative_trapezoid(y=np.r_[0,e_ry],x=None, dx=dt)
cum_trapz_e_yy_m = cumulative_trapezoid(y=np.r_[0,e_yy_m],x=None, dx=dt)


plt.step(time_, e_ry ,label = r"$e_{r,y}=a^{wanted}-a^{actual}$ ",color="cyan",linewidth = 1.5)
plt.step(time_, e_yy_m , ':',label = "$e_{y,y_m}=a^{actual}-a^{model}$ ",color="brown",linewidth = 4)

plt.plot(time_, cum_trapz_e_ry,'--',
         label = r"cumtrapz($e_{r,y}$)",color="black",linewidth = 2)
plt.plot(time_, cum_trapz_e_yy_m,'-.',
         label = r"cumtrapz($e_{y,y_m}$)",color="magenta",linewidth = 2)

plt.xlabel("time [sec]")
plt.ylabel("Torque error [Nm]")
plt.legend(fontsize=12)
plt.grid()
plt.show()

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)

plt.plot(time_, save_ctrl_voltage)
plt.xlabel("time [sec]")
plt.ylabel("Control Voltage [volts]")
plt.grid()
plt.show()

# %%
np_array_MRAC_adapt_gains = np.array(save_MRAC_adapt_gains).T

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

plt.plot(time_, np_array_MRAC_adapt_gains[0]
         ,label = r"$\hat{k_r}$=coeff of $a^{wanted}$"+f"→{np_array_MRAC_adapt_gains[0,-20:-1].mean():.1e}",color="C0",linewidth = 2)
plt.plot(time_, np_array_MRAC_adapt_gains[1],'--'
         ,label = r"$\hat{k_y}$=coeff of $a^{actual}$"+f"→{np_array_MRAC_adapt_gains[1,-20:-1].mean():.1e}",color="C1",linewidth = 3)
plt.plot(time_, np_array_MRAC_adapt_gains[2],':',
         label = r"$\hat{k}_{r-y}$=coeff of $(a^{wanted}-a^{actual})$"+f"→{np_array_MRAC_adapt_gains[2,-20:-1].mean():.1e}",color="C2",linewidth = 4)
plt.plot(time_, np_array_MRAC_adapt_gains[3],'-.',
         label = r"$\hat{k}_\omega$=coeff of $\dot{\theta}$"+f"→{np_array_MRAC_adapt_gains[3,-20:-1].mean():.1e}",color="C3",linewidth = 2)
plt.xlabel("time [sec]")
plt.ylabel("Adaptation control gains")
plt.grid()
plt.legend(fontsize=15, bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import math

cos_theta_1 = []
sin_theta_1 = []
cos_theta_2 = []
sin_theta_2 = []
ang_vel_theta_1 = []
ang_vel_theta_2 = []

for observ in save_observation:
  for index,value in enumerate(observ):
    if index == 0:
      cos_theta_1.append(value)
    if index == 1:
      sin_theta_1.append(value)
    if index == 2:
      cos_theta_2.append(value)
    if index == 3:
      sin_theta_2.append(value)
    if index == 4:
      ang_vel_theta_1.append(value)
    if index == 5:
      ang_vel_theta_2.append(value)

# %%
cos_theta_1 = np.array(cos_theta_1)
cos_theta_2 = np.array(cos_theta_2)
sin_theta_1 = np.array(sin_theta_1)
sin_theta_2 = np.array(sin_theta_2)
ang_vel_theta_1 = np.array(ang_vel_theta_1)
ang_vel_theta_2 = np.array(ang_vel_theta_2)

# %%
print(len(cos_theta_1))
# Out:
# 79

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_cos_theta_1 = np.linspace(start = 0, stop = len(cos_theta_1)* dt,num=len(cos_theta_1))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_cos_theta_1[-1] , 300)

spl = make_interp_spline(time_cos_theta_1, cos_theta_1, k=3)  # type: BSpline
power_smooth = spl(xnew)

plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel("time [sec]")
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
plt.ylabel(r'$\cos({\theta_1})$')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_sin_theta_1 = np.linspace(start = 0, stop = len(sin_theta_1)* dt,num=len(sin_theta_1))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_sin_theta_1[-1] , 300)

spl = make_interp_spline(time_sin_theta_1, sin_theta_1, k=3)  # type: BSpline
power_smooth = spl(xnew)

plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel("time [sec]")
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
plt.ylabel(r'$\sin({\theta_1})$')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_cos_theta_2 = np.linspace(start = 0, stop = len(cos_theta_2)* dt,num=len(cos_theta_2))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_cos_theta_2[-1] , 300)

spl = make_interp_spline(time_cos_theta_2, cos_theta_2, k=3)  # type: BSpline
power_smooth = spl(xnew)

plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel("time [sec]")
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
plt.ylabel(r'$\cos({\theta_2})$')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_sin_theta_2 = np.linspace(start = 0, stop = len(sin_theta_2)* dt,num=len(sin_theta_2))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_sin_theta_2[-1] , 300)

spl = make_interp_spline(time_sin_theta_2, sin_theta_2, k=3)  # type: BSpline
power_smooth = spl(xnew)

plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel("time [sec]")
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
plt.ylabel(r'$\sin({\theta_2})$')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_ang_vel_theta_1 = np.linspace(start = 0, stop = len(ang_vel_theta_1)* dt,num=len(ang_vel_theta_1))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_ang_vel_theta_1[-1] , 300)

spl = make_interp_spline(time_ang_vel_theta_1, ang_vel_theta_1, k=3)  # type: BSpline
power_smooth = spl(xnew)

plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel("time [sec]")
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
plt.ylabel(r'$\dot{\theta_1}$ [rad/sec]')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_ang_vel_theta_2 = np.linspace(start = 0, stop = len(ang_vel_theta_2)* dt,num=len(ang_vel_theta_2))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_ang_vel_theta_2[-1] , 300)

spl = make_interp_spline(time_ang_vel_theta_2, ang_vel_theta_2, k=3)  # type: BSpline
power_smooth = spl(xnew)

plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel("time [sec]")
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
plt.ylabel(r'$\dot{\theta_2}$ [rad/sec]')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
Condition = -cos_theta_1 -cos_theta_1*cos_theta_2 + sin_theta_1*sin_theta_2
spl = make_interp_spline(time_sin_theta_2, Condition, k=3)  # type: BSpline
power_smooth = spl(xnew)

font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)

plt.plot(xnew, power_smooth, label = r'Cond = $-\cos(\theta_1)-\cos({\theta_1+\theta_2})$',color="blue")
plt.plot(xnew, (power_smooth>1)-1,':', label = r'Reward = bool(Cond>1)-1',color="red", linewidth = 4)

plt.grid()
#plt.legend()
plt.xlabel("Time [sec]")
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
plt.ylabel('Condition for Reward')
plt.legend()
plt.show()

# %%
# Initialize the Gym environment
env =  Custom_AcrobotEnv()
env.seed(1) # Set a random seed for the environment (reproducible results)

# This is for creating the output video in Colab, not required outside Colab
#env = wrap_env(env, video_callable=lambda episode_id: True) # Save a video every episode

plotting_rewards2=[]
# Let's try for a total of 10 episodes
for num_episode in range(10):
    # Reset the environment and get the initial state
    state = env.reset()
    #state = state[0]##################################################################################################################################
    # Reset the score. The final score will be the total amount of steps before the pole falls
    score = 0
    done = False
    # Go on until the pole falls off or the score reach 490
    while not done:
      # Choose the best action (temperature 0)
      action, q_values = choose_action_softmax(policy_net, state, temperature=0)
      #action, q_values = choose_action_softmax(target_net, state, temperature=0)

      # Apply the action and get the next state, the reward and a flag "done" that is True if the game is ended
      next_state, reward, done, info , wanted_torque, actual_torque = env.step(action)
      # Visually render the environment
      #env.render()
      # Update the final score (+1 for each step)
      score += reward
      # Set the current state for the next iteration
      state = next_state
      # Check if the episode ended (the pole fell down)
      if score<=-500:#score_low_bound: ##### change  to stop high negative score
        done =True
    # Print the final score
    plotting_rewards2.append(score)
    print(f"EPISODE {num_episode + 1} - FINAL SCORE: {score}")
env.close()
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(
# EPISODE 1 - FINAL SCORE: -82.0
# EPISODE 2 - FINAL SCORE: -95.0
# EPISODE 3 - FINAL SCORE: -84.0
# EPISODE 4 - FINAL SCORE: -99.0
# EPISODE 5 - FINAL SCORE: -94.0
# EPISODE 6 - FINAL SCORE: -100.0
# EPISODE 7 - FINAL SCORE: -88.0
# EPISODE 8 - FINAL SCORE: -85.0
# EPISODE 9 - FINAL SCORE: -82.0
# EPISODE 10 - FINAL SCORE: -73.0

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(plotting_rewards2)
plt.xlabel("Episode")
plt.ylabel("Test Epsiodic Reward")
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
