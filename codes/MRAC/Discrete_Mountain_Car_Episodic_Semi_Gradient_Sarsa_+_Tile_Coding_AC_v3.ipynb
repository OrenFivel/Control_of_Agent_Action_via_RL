# %% [markdown]
# **Episodic Semi-Gradient Sarsa + Tile Coding for Discrete Mountain Car**
#
# https://marcinbogdanski.github.io/rl-sketchpad/RL_An_Introduction_2018/1001_Episodic_Semi_Gradient_Sarsa.html

# %% [markdown]
# Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from mpl_toolkits.mplot3d import axes3d
import gym
#from helpers_1001 import eval_state_action_space, plot_q_max_3d
#import tiles3           # by Richard Sutton, http://incompleteideas.net/tiles/tiles3.html
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle

# %% [markdown]
# **Custom_MountainCarEnv + ElectricalDCMotorEnv**

# %%
"""
http://incompleteideas.net/MountainCar/MountainCar1.cp
permalink: https://perma.cc/6Z2N-PFWC
"""
import math
from typing import Optional

import numpy as np

import gym
from gym import spaces
from gym.envs.classic_control import utils
from gym.error import DependencyNotInstalled


class Custom_MountainCarEnv(gym.Env):
    """
    ### Description
    The Mountain Car MDP is a deterministic MDP that consists of a car placed stochastically
    at the bottom of a sinusoidal valley, with the only possible actions being the accelerations
    that can be applied to the car in either direction. The goal of the MDP is to strategically
    accelerate the car to reach the goal state on top of the right hill. There are two versions
    of the mountain car domain in gym: one with discrete actions and one with continuous.
    This version is the one with discrete actions.
    This MDP first appeared in [Andrew Moore's PhD Thesis (1990)](https://www.cl.cam.ac.uk/techreports/UCAM-CL-TR-209.pdf)
    ```
    @TECHREPORT{Moore90efficientmemory-based,
        author = {Andrew William Moore},
        title = {Efficient Memory-based Learning for Robot Control},
        institution = {University of Cambridge},
        year = {1990}
    }
    ```
    ### Observation Space
    The observation is a `ndarray` with shape `(2,)` where the elements correspond to the following:
    | Num | Observation                          | Min  | Max | Unit         |
    |-----|--------------------------------------|------|-----|--------------|
    | 0   | position of the car along the x-axis | -Inf | Inf | position (m) |
    | 1   | velocity of the car                  | -Inf | Inf | position (m) |
    ### Action Space
    There are 3 discrete deterministic actions:
    | Num | Observation             | Value | Unit         |
    |-----|-------------------------|-------|--------------|
    | 0   | Accelerate to the left  | Inf   | position (m) |
    | 1   | Don't accelerate        | Inf   | position (m) |
    | 2   | Accelerate to the right | Inf   | position (m) |
    ### Transition Dynamics:
    Given an action, the mountain car follows the following transition dynamics:
    *velocity<sub>t+1</sub> = velocity<sub>t</sub> + (action - 1) * force - cos(3 * position<sub>t</sub>) * gravity*
    *position<sub>t+1</sub> = position<sub>t</sub> + velocity<sub>t+1</sub>*
    where force = 0.001 and gravity = 0.0025. The collisions at either end are inelastic with the velocity set to 0
    upon collision with the wall. The position is clipped to the range `[-1.2, 0.6]` and
    velocity is clipped to the range `[-0.07, 0.07]`.
    ### Reward:
    The goal is to reach the flag placed on top of the right hill as quickly as possible, as such the agent is
    penalised with a reward of -1 for each timestep.
    ### Starting State
    The position of the car is assigned a uniform random value in *[-0.6 , -0.4]*.
    The starting velocity of the car is always assigned to 0.
    ### Episode End
    The episode ends if either of the following happens:
    1. Termination: The position of the car is greater than or equal to 0.5 (the goal position on top of the right hill)
    2. Truncation: The length of the episode is 200.
    ### Arguments
    ```
    gym.make('MountainCar-v0')
    ```
    ### Version History
    * v0: Initial versions release (1.0.0)
    """

    metadata = {
        "render_modes": ["human", "rgb_array"],
        "render_fps": 30,
    }

    def __init__(self, render_mode: Optional[str] = None, goal_velocity=0):
        self.min_position = -1.2
        self.max_position = 0.6
        self.max_speed = 0.07
        self.goal_position = 0.5
        self.goal_velocity = goal_velocity

        self.one_over_mass = 0.001 # mass in kg, replaces 1/self.force
        self.gravity = 0.0025

        self.low = np.array([self.min_position, -self.max_speed], dtype=np.float32)
        self.high = np.array([self.max_position, self.max_speed], dtype=np.float32)

        self.render_mode = render_mode

        self.screen_width = 600
        self.screen_height = 400
        self.screen = None
        self.clock = None
        self.isopen = True

        self.action_space = spaces.Discrete(3)
        self.observation_space = spaces.Box(self.low, self.high, dtype=np.float32)

                ### Customization changes ######
        self.tau = 1.0 # seconds between state updates
        self.MRAC = ModelRefAC()
        self.NumIntegrationsSteps = 200
        self.tau1 =self.tau/self.NumIntegrationsSteps #.05 # integration time sample
        self.MRAC.timeSample = self.tau1
        self.MRAC.plant.tau1 = self.tau1
        self.MRAC.ref_model.tau1 = self.tau1
        ####
        self.wanted_force = 0.0


    def step(self, action: int):
        assert self.action_space.contains( action ), f"{action!r} ({type(action)}) invalid"

        position, velocity = self.state
        wanted_force = (action - 1) # wanted forces in Newton = {-1,0,+1}[N]
        self.wanted_force=wanted_force
        for n in np.arange(start=0, stop=self.NumIntegrationsSteps, step=1):
          #generates actual force
          self.MRAC.plant.thetadot = velocity
          actual_force = self.MRAC.step(r=wanted_force)
          #actual_force = wanted_force # change for perfect applying force

          velocity += (actual_force * self.one_over_mass - self.gravity * math.cos(3 * position))*self.tau1
          if velocity > self.max_speed:
              velocity = self.max_speed
          if velocity < -self.max_speed:
              velocity = -self.max_speed
          position += (velocity)*self.tau1
          if position > self.max_position:
              position = self.max_position
          if position < self.min_position:
              position = self.min_position
          if position == self.min_position and velocity < 0:
              velocity = 0

        terminated = bool(
            position >= self.goal_position #and velocity >= self.goal_velocity
        )
        reward = -1.0

        self.state = (position, velocity)
        if self.render_mode == "human":
            self.render()
        return np.array(self.state, dtype=np.float32), reward, terminated, False ,wanted_force , actual_force

    def reset(
        self,
        *,
        seed: Optional[int] = None,
        options: Optional[dict] = None,
    ):
        super().reset(seed=seed)
        # Note that if you use custom reset bounds, it may lead to out-of-bound
        # state/observations.
        low, high = utils.maybe_parse_reset_bounds(options, -0.6, -0.4)
        self.state = np.array([self.np_random.uniform(low=low, high=high), 0])

        ### reset DC motor init. conditions
        self.MRAC.reset()
        self.MRAC.plant.reset()
        self.MRAC.ref_model.reset()

        if self.render_mode == "human":
            self.render()
        return np.array(self.state, dtype=np.float32), {}

    def _height(self, xs):
        return np.sin(3 * xs) * 0.45 + 0.55

    def render(self):
        if self.render_mode is None:
            gym.logger.warn(
                "You are calling render method without specifying any render mode. "
                "You can specify the render_mode at initialization, "
                f'e.g. gym("{self.spec.id}", render_mode="rgb_array")'
            )
            return

        try:
            import pygame
            from pygame import gfxdraw
        except ImportError:
            raise DependencyNotInstalled(
                "pygame is not installed, run `pip install gym[classic_control]`"
            )

        if self.screen is None:
            pygame.init()
            if self.render_mode == "human":
                pygame.display.init()
                self.screen = pygame.display.set_mode(
                    (self.screen_width, self.screen_height)
                )
            else:  # mode in "rgb_array"
                self.screen = pygame.Surface((self.screen_width, self.screen_height))
        if self.clock is None:
            self.clock = pygame.time.Clock()

        world_width = self.max_position - self.min_position
        scale = self.screen_width / world_width
        carwidth = 40
        carheight = 20

        self.surf = pygame.Surface((self.screen_width, self.screen_height))
        self.surf.fill((255, 255, 255))

        pos = self.state[0]

        xs = np.linspace(self.min_position, self.max_position, 100)
        ys = self._height(xs)
        xys = list(zip((xs - self.min_position) * scale, ys * scale))

        pygame.draw.aalines(self.surf, points=xys, closed=False, color=(0, 0, 0))

        clearance = 10

        l, r, t, b = -carwidth / 2, carwidth / 2, carheight, 0
        coords = []
        for c in [(l, b), (l, t), (r, t), (r, b)]:
            c = pygame.math.Vector2(c).rotate_rad(math.cos(3 * pos))
            coords.append(
                (
                    c[0] + (pos - self.min_position) * scale,
                    c[1] + clearance + self._height(pos) * scale,
                )
            )

        gfxdraw.aapolygon(self.surf, coords, (0, 0, 0))
        gfxdraw.filled_polygon(self.surf, coords, (0, 0, 0))

        for c in [(carwidth / 4, 0), (-carwidth / 4, 0)]:
            c = pygame.math.Vector2(c).rotate_rad(math.cos(3 * pos))
            wheel = (
                int(c[0] + (pos - self.min_position) * scale),
                int(c[1] + clearance + self._height(pos) * scale),
            )

            gfxdraw.aacircle(
                self.surf, wheel[0], wheel[1], int(carheight / 2.5), (128, 128, 128)
            )
            gfxdraw.filled_circle(
                self.surf, wheel[0], wheel[1], int(carheight / 2.5), (128, 128, 128)
            )

        flagx = int((self.goal_position - self.min_position) * scale)
        flagy1 = int(self._height(self.goal_position) * scale)
        flagy2 = flagy1 + 50
        gfxdraw.vline(self.surf, flagx, flagy1, flagy2, (0, 0, 0))

        gfxdraw.aapolygon(
            self.surf,
            [(flagx, flagy2), (flagx, flagy2 - 10), (flagx + 25, flagy2 - 5)],
            (204, 204, 0),
        )
        gfxdraw.filled_polygon(
            self.surf,
            [(flagx, flagy2), (flagx, flagy2 - 10), (flagx + 25, flagy2 - 5)],
            (204, 204, 0),
        )

        self.surf = pygame.transform.flip(self.surf, False, True)
        self.screen.blit(self.surf, (0, 0))
        if self.render_mode == "human":
            pygame.event.pump()
            self.clock.tick(self.metadata["render_fps"])
            pygame.display.flip()

        elif self.render_mode == "rgb_array":
            return np.transpose(
                np.array(pygame.surfarray.pixels3d(self.screen)), axes=(1, 0, 2)
            )

    def get_keys_to_action(self):
        # Control with left and right arrow keys.
        return {(): 1, (276,): 0, (275,): 2, (275, 276): 1}

    def close(self):
        if self.screen is not None:
            import pygame

            pygame.display.quit()
            pygame.quit()
            self.isopen = False

# %%
class ElectricalDCMotorEnv():

  def __init__(self):
    self.Resistor_R = 1.0
    self.inductor_L = 0.1
    self.torque_const_Kt = 1.0
    self.bemf_const_Ke = 1.0
    self.tau1 = 0.05
        #
    self.current = 0.0
    self.voltage_input = None
    self.thetadot = 0.0

  def step(self, u):
    voltage_BEMF = self.thetadot*self.bemf_const_Ke
    self.voltage_input = np.clip(u, -10, 10)

    f1 = self.torque_const_Kt*self.current+0.1*np.random.standard_normal()
    self.current += self.tau1*(self.voltage_input-voltage_BEMF-self.current*self.Resistor_R)/self.inductor_L
    f2 = self.torque_const_Kt*self.current
    F = f2
    return F # return actual applied torque

  def reset(self):
    self.current = 0.0

# %%
class ReferenceModel():

  def __init__(self):
    self.a_m = 50.0#30.0
    self.b_m = self.a_m
    self.tau1 = 0.05
    self.x_m = 0.0
    self.y_m = 0.0

  def step(self, r):

    #fwd integration
    #A = -self.a_m*self.tau1
    #Br = self.b_m*self.tau1*r
    #self.y_m = self.x_m+0
    #self.x_m = (1+A)*self.y_m+Br
    #y_m = self.y_m+0

    #bkwd integration
    #A = -self.a_m*self.tau1
    #Br = self.b_m*self.tau1*r
    #if A ==1:
    #  C=1
    #else:
    #  C = 1/(1-A)
    #self.y_m = C*(self.x_m-Br)
    #self.x_m = self.y_m+0
    #y_m = self.y_m+0

    #trapz integragration
    A = -0.5*self.a_m*self.tau1
    Br= +0.5*self.b_m*self.tau1*r
    if A ==1:
      C=1
    else:
      C = 1/(1-A)
    x_m = self.x_m
    y_m = C*(x_m+Br)
    x_m = (1+A)*y_m + Br
    self.x_m = x_m
    self.y_m = y_m

    return y_m

  def reset(self):
    self.x_m = 0.0
    self.y_m = 0.0

# %%
class ModelRefAC:

  def __init__(self): #  order of signals [r,y,r-y,w]
    self.plant = ElectricalDCMotorEnv()
    self.ref_model = ReferenceModel()
    self.w = 0.0
    self.u = 0.0
    self.r = 0.0
    self.y = 0.0
    self.y_m = 0.0
    self.adaptation_gain=np.array([50,60,10,50])*14 # positive scalar or np.array shape (4,)
    self.sigma_mod_adapt_gain=0 # non-neg scalar or np.array shape (4,)
    self.emod_adapt_gain=0
    self.dead_zone_threshold = 0*1e-5
    self.dead_zone_adapt_gain = 0*1e-3
    self.timeSample=0.05
    self.mu0 = np.array([1e-3,-1e-3,1e-3,1e-3])
    self.std = 0*1e-6
    self.k_temp = self.mu0
    self.k_hat =  self.mu0
    self.keep_coeff = True
    self.mask = np.array([True,True,True,True])
    self.distrib = np.random.standard_normal


  def step(self, r):
    self.r = r
    self.w = self.plant.thetadot
    y = self.y
    y_m = self.y_m
    e=y-y_m
    u = self.adaptationControlLaw(e=e, r=r, y=y, w=self.w)
    self.y_m = self.ref_model.step(r)
    self.y = self.plant.step(u)
    return self.y

  def adaptationControlLaw(self, e, r, y, w):
    v = np.array([r,y,r-y,w])#.clip(-20,20)
    e_norm = abs(e)

    #fwd integration
    #A = -(self.sigma_mod_adapt_gain+self.emod_adapt_gain*e_norm)*self.timeSample
    #Bev = -self.adaptation_gain*self.timeSample*e*v
    #if e_norm<=self.dead_zone_threshold:
    #  A = A*self.dead_zone_adapt_gain
    #  Bev = Bev*self.dead_zone_adapt_gain
    #self.k_hat = self.k_temp*self.mask
    #self.k_temp = ((1+A)*self.k_hat + Bev)*self.mask

    #backwd integration
    #A = -(self.sigma_mod_adapt_gain+self.emod_adapt_gain*e_norm)*self.timeSample
    #Bev = -self.adaptation_gain*self.timeSample*e*v
    #if e_norm<=self.dead_zone_threshold:
    #  A = A*self.dead_zone_adapt_gain
    #  Bev = Bev*self.dead_zone_adapt_gain
    #C = 1-A*(A!=np.ones_like(A))
    #C = 1/C
    #self.k_hat = C*(self.k_temp+Bev)*self.mask
    #self.k_temp = A*self.k_hat*self.mask

    #trapz integration
    A = -0.5*(self.sigma_mod_adapt_gain+self.emod_adapt_gain*e_norm)*self.timeSample
    Bev = -0.5*self.adaptation_gain*self.timeSample*e*v
    if e_norm<=self.dead_zone_threshold:
      A = A*self.dead_zone_adapt_gain
      Bev = Bev*self.dead_zone_adapt_gain
    if A ==1:
      C=1
    else:
      C = 1/(1-A)
    self.k_hat = C*((self.k_temp +Bev)*self.mask)
    self.k_temp = ((1+A)*self.k_hat +Bev)*self.mask
    u = np.dot(v,self.k_hat)
    u=np.clip(u,-10,10)
    self.u = u
    return u

  def reset(self):
    self.w = 0.0
    self.r = 0.0
    self.y = 0.0
    self.y_m = 0.0
    mu0 = self.mu0
    sigma0 = self.std
    keep_coeff = self.keep_coeff
    self.k_temp = (sigma0*self.distrib(self.k_temp.shape) + keep_coeff*self.k_temp + (not keep_coeff)*mu0)*self.mask
    self.k_hat = (sigma0*self.distrib(self.k_hat.shape) + keep_coeff*self.k_hat + (not keep_coeff)*mu0)*self.mask

# %%
env =  Custom_MountainCarEnv()

# %%
print("dt= ", env.tau)
print("N= ", env.NumIntegrationsSteps)
print("dt/N=", env.tau/env.NumIntegrationsSteps)
print("gamma*dt/N=", env.MRAC.adaptation_gain*env.tau/env.NumIntegrationsSteps)
# Out:
# dt=  1.0
# N=  200
# dt/N= 0.005
# gamma*dt/N= [3.5 4.2 0.7 3.5]

# %% [markdown]
# Episodic Semi-Gradient Sarsa

# %%
plotting_rewards=[]
ploting_adapt_coeff=[]
avg_reward_list = []


save_observation = []
save_wanted_force = [0]
save_actual_force = [0]
save_model_force = [0]
save_ctrl_voltage = []
save_MRAC_adapt_gains = []

# %%
def policy(st, q_hat, eps):
  if np.random.rand() > eps:
    act_space = range(env.action_space.n)
    q_values = [q_hat.eval(st,a) for a in act_space]
    return argmax_rand(q_values)
  else:
    return np.random.choice(env.action_space.n)

# %%
def ep_semi_grad_sarsa(env, episodes, gamma, epsilon_start, epsilon_end, epsilon_decay,
                       q_hat, q_hat_target, callback=None, trace=None, train_mode=True):
    """Episodic Semi-Gradient Sarsa

    Params:
        env - environment
        ep - number of episodes to run
        gamma - discount factor [0..1]
        epsilon_start, epsilon_end, epsilon_decay - epsilon-greedy params:
          epsilon = epsilon_end + (epsilon_start-epsilon_end)*epsilon_decay**(episode no. n)
        q_hat      - function approximator, already initialised, with methods:
                     eval(state, action) -> float
                     train(state, target) -> None
    """

   # skip weight intialization,
    initial_not_saved = True
    print('Initial adapt. coeffs: ', env.MRAC.mu0)

    best_score = -300
    lr = None
    #for e_ in range(ep):
    episode_n = 0
    best_episode = 0
    print(f"learning rate: {q_hat._lr:E}")
    while(episode_n<episodes):
        S, infor = env.reset()
        epsilon = epsilon_end + (epsilon_start-epsilon_end)*epsilon_decay**episode_n
        if episode_n==int(episodes*0.5):
            q_hat._weights = q_hat_target._weights+0
            print(f"Reinitiate weight from Best Episode:{best_episode}; Best Score:{best_score}")
            q_hat._lr=q_hat_target._lr*1e-1
            print(f"learning rate: {q_hat._lr:E}")
        #if episode_n==int(episodes*0.9):
        #    q_hat._weights = q_hat_target._weights+0
        #    print(f"Reinitiate weight from Best Episode:{best_episode}; Best Score:{best_score}")
        #    q_hat._lr=q_hat_target._lr*1e-1
        #    print(f"learning rate: {q_hat._lr:E}")
        A = policy(S, q_hat, epsilon)
        score = 0
        #for t_ in range(200): #10**100
        t_=0
        while(t_<200) and (episode_n<episodes):
            k_hat_print = env.MRAC.k_hat.round(2)
            if episode_n == episodes-1 and initial_not_saved:
              save_MRAC_adapt_gains.append(env.MRAC.k_hat)
              save_observation.append(S)
              u0=env.MRAC.adaptationControlLaw(e=env.MRAC.y-env.MRAC.y_m,
                                              r=env.MRAC.r,y=env.MRAC.y,
                                              w=env.MRAC.w)
              save_ctrl_voltage.append(u0)
              initial_not_saved = False
            #
            infor = env.step(A)
            S_= infor[0]
            R = infor[1]
            done = infor[2]
            wanted_force=infor[4]
            actual_force=infor[5]
            ##
            if episode_n == episodes-1:
              save_observation.append(S_)
              save_wanted_force.append(wanted_force)
              save_actual_force.append(actual_force)
              save_model_force.append(env.MRAC.y_m)
              save_ctrl_voltage.append(env.MRAC.u)
              save_MRAC_adapt_gains.append(env.MRAC.k_hat)
             #end if
            score += R

            if done or ((t_+1)%200==0):
                  plotting_rewards.append(score)
                  avg_reward = np.mean(plotting_rewards[-20:])
                  print(f"EPISODE: {episode_n} - FINAL SCORE: {avg_reward} ") # Print the final score
                  avg_reward_list.append(avg_reward)
                  ploting_adapt_coeff.append(k_hat_print)
                  print(f"EPISODE: {episode_n}, ", "adapt. coeffs at final time step: ", k_hat_print)
                  if (episode_n + 1)%10==0 and episode_n>0:
                      k_hat_median = np.median(np.array(ploting_adapt_coeff), axis=0)
                      print("median: ", k_hat_median)
                  if best_score < score:
                      q_hat_target._weights = q_hat._weights+0
                      best_score = score
                      best_episode = episode_n
                      print(f"Best Episode:{best_episode}; Best Score:{best_score}")
                  #end if
                  episode_n+=1
                  score = 0
            #end if
            lr = None
            if done:
                q_hat.train(S, A, R, lr)
                break
            #end if
            A_ = policy(S_, q_hat, epsilon)
            target = R + gamma * q_hat.eval(S_, A_)

            if train_mode: #### add boolian cond. for train mode
              q_hat.train(S, A, target ,lr)
            #end if

            S, A = S_, A_

            if callback is not None:
                callback(episode_n, t_, q_hat, trace)
            #end if
            t_+=1
        #end while
    #end while
    print(f"Best Episode:{best_episode}; Best Score:{best_score}")
#end def

# %% [markdown]
# Tile Coding

# %%
class TileCodingFuncApprox():
    def __init__(self, st_low, st_high, nb_actions, learn_rate, num_tilings, init_val):
        """
        Params:
            st_low      - state space low boundry in all dim, e.g. [-1.2, -0.07] for mountain car
            st_high     - state space high boundry in all dimensions
            nb_actions  - number of possible actions
            learn_rate  - step size, will be adjusted for nb_tilings automatically
            num_tilings - tiling layers - should be power of 2 and at least 4*len(st_low)
            init_val    - initial state-action values
        """
        assert len(st_low) == len(st_high)
        self._n_dim = len(st_low)
        self._lr = learn_rate / num_tilings
        self._num_tilings = num_tilings
        self._scales = self._num_tilings / (st_high - st_low)

        # e.g. 8 tilings, 2d space, 3 actions
        # nb_total_tiles = (8+1) * (8+1) * 8 * 3
        nb_total_tiles = (num_tilings+1)**self._n_dim * num_tilings * nb_actions

        self._iht = IHT(nb_total_tiles)
        self._weights = np.zeros(nb_total_tiles) + init_val / num_tilings

    def eval(self, state, action):
        #assert len(state) == self._n_dim
        #assert np.isscalar(action)
        scaled_state = np.multiply(self._scales, state)  # scale state to map to tiles correctly
        active_tiles = tiles(                     # find active tiles
            self._iht, self._num_tilings,
            scaled_state, [action])
        return np.sum(self._weights[active_tiles])       # pick correct weights and sum up

    def train(self, state, action, target, lr=None):
        #assert len(state) == self._n_dim
        #assert np.isscalar(action)
        #assert np.isscalar(target)
        if lr is None:
            lr=self._lr
        scaled_state = np.multiply(self._scales, state)  # scale state to map to tiles correctly
        active_tiles = tiles(                     # find active tiles
            self._iht, self._num_tilings,
            scaled_state, [action])
        value = np.sum(self._weights[active_tiles])      # q-value for state-action pair
        delta = lr * (target - value)              # grad is [0,1,0,0,..]
        self._weights[active_tiles] += delta             # ..so we pick active weights instead

# %%
"""
Tile Coding Software version 3.0beta
by Rich Sutton
based on a program created by Steph Schaeffer and others
External documentation and recommendations on the use of this code is available in the
reinforcement learning textbook by Sutton and Barto, and on the web.
These need to be understood before this code is.

This software is for Python 3 or more.

This is an implementation of grid-style tile codings, based originally on
the UNH CMAC code (see http://www.ece.unh.edu/robots/cmac.htm), but by now highly changed.
Here we provide a function, "tiles", that maps floating and integer
variables to a list of tiles, and a second function "tiles-wrap" that does the same while
wrapping some floats to provided widths (the lower wrap value is always 0).

The float variables will be gridded at unit intervals, so generalization
will be by approximately 1 in each direction, and any scaling will have
to be done externally before calling tiles.

Num-tilings should be a power of 2, e.g., 16. To make the offsetting work properly, it should
also be greater than or equal to four times the number of floats.

The first argument is either an index hash table of a given size (created by (make-iht size)),
an integer "size" (range of the indices from 0), or nil (for testing, indicating that the tile
coordinates are to be returned without being converted to indices).

Documentation : http://incompleteideas.net/tiles/tiles3.html
"""

basehash = hash

class IHT:
    "Structure to handle collisions"
    def __init__(self, sizeval):
        self.size = sizeval
        self.overfullCount = 0
        self.dictionary = {}

    def __str__(self):
        "Prepares a string for printing whenever this object is printed"
        return "Collision table:" + \
               " size:" + str(self.size) + \
               " overfullCount:" + str(self.overfullCount) + \
               " dictionary:" + str(len(self.dictionary)) + " items"

    def count (self):
        return len(self.dictionary)

    def fullp (self):
        return len(self.dictionary) >= self.size

    def getindex (self, obj, readonly=False):
        d = self.dictionary
        if obj in d: return d[obj]
        elif readonly: return None
        size = self.size
        count = self.count()
        if count >= size:
            if self.overfullCount==0: print('IHT full, starting to allow collisions')
            self.overfullCount += 1
            return basehash(obj) % self.size
        else:
            d[obj] = count
            return count

def hashcoords(coordinates, m, readonly=False):
    if type(m)==IHT: return m.getindex(tuple(coordinates), readonly)
    if type(m)==int: return basehash(tuple(coordinates)) % m
    if m==None: return coordinates

from math import floor, log
from itertools import zip_longest

def tiles (ihtORsize, numtilings, floats, ints=[], readonly=False):
    """returns num-tilings tile indices corresponding to the floats and ints"""
    qfloats = [floor(f*numtilings) for f in floats]
    Tiles = []
    for tiling in range(numtilings):
        tilingX2 = tiling*2
        coords = [tiling]
        b = tiling
        for q in qfloats:
            coords.append( (q + b) // numtilings )
            b += tilingX2
        coords.extend(ints)
        Tiles.append(hashcoords(coords, ihtORsize, readonly))
    return Tiles

def tileswrap (ihtORsize, numtilings, floats, wrawidths, ints=[], readonly=False):
    """returns num-tilings tile indices corresponding to the floats and ints, wrapping some floats"""
    qfloats = [floor(f*numtilings) for f in floats]
    Tiles = []
    for tiling in range(numtilings):
        tilingX2 = tiling*2
        coords = [tiling]
        b = tiling
        #for q, width in zip_longest(qfloats, wrapwidths):
        for q, width in zip_longest(qfloats, wrawidths):
            c = (q + b%numtilings) // numtilings
            coords.append(c%width if width else c)
            b += tilingX2
        coords.extend(ints)
        Tiles.append(hashcoords(coords, ihtORsize, readonly))
    return Tiles

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

def plot_q_max_3d(q_arr, env, color='#1f77b4', alpha=1.,
                  title='', labels=['x','y','z'], axis=None):
    """Plot 3D wireframe

    Params:
        q_arr     - 2d array with dim: [state_x, state_y]
        env       - environment with members:
                      st_low - state space low boundry e.g. [-1.2, -0.07]
                      st_high - state space high boundry
        color     - plot color
        alpha     - plot transparency
        labels    - string array [label_x, label_y, label_z], len=3, empty str to omit
        axis      - axis to plot to, if None create new figure
    """
    q_max = -1 * np.max(q_arr, axis=-1)  # calc max and inverse

    x_min, x_max = env.low[0], env.high[0]
    y_min, y_max = env.low[1], env.high[1]
    x_space = np.linspace(x_min, x_max, num=q_max.shape[0])
    y_space = np.linspace(y_min, y_max, num=q_max.shape[1])
    Y, X = np.meshgrid(y_space, x_space)

    font = {'size': 10}
    plt.rc('font', **font)

    if axis is None:
        fig = plt.figure()
        axis = fig.add_subplot(111, projection='3d')

    axis.plot_wireframe(X, Y, q_max, color=color, alpha=alpha)
    axis.set_xlabel(labels[0])
    axis.set_ylabel(labels[1])
    axis.set_zlabel(labels[2])
    axis.set_xticks([x_min, x_max])
    axis.set_yticks([y_min, y_max])
    axis.set_title(title)

    axis.view_init(40, -70)



def eval_state_action_space(q_hat, env, split=[32,32]):
    """Evaluate 2d Q-function on area and return as 3d array

    Params:
        q_hat     - function approximator with method: q_hat.eval(state, action) -> float
        env       - environment with members:
                      st_low - state space low boundry e.g. [-1.2, -0.07]
                      st_high - state space high boundry
                      act_space - action space, e.g. [0, 1, 2]
        split     - number of data points in each dimensions, e.g. [20, 20]
    """
    x_min, x_max = env.low[0], env.high[0]
    y_min, y_max = env.low[1], env.high[1]
    x_split, y_split = split

    q_arr = np.zeros([x_split, y_split, env.action_space.n])
    act_space = range(env.action_space.n)
    for pi, pos in enumerate(np.linspace(x_min, x_max, x_split)):
        for vi, vel in enumerate(np.linspace(y_min, y_max, y_split)):
            for act in act_space:
                q_arr[pi, vi, act] = q_hat.eval(state=[pos, vel], action=act)

    return q_arr

# %% [markdown]
# Helper functions

# %%
def argmax_rand(arr):
    # break ties randomly, np.argmax() always picks first max
    return np.random.choice(np.flatnonzero(arr == np.max(arr)))

# %%
def callback(episode, tstep, model, trace):
    """Called from gradient_MC after every episode.

    Params:
        episode [int] - episode number
        tstep [int]   - timestep within episode
        model [obj]   - function approximator
        trace [list]  - list to write results to"""
    episodes = [1, 12, 104, 1000, 9000]
    if episode in episodes and tstep == 0:
        q_arr = eval_state_action_space(q_hat, env)
        trace.append(q_arr)

# %% [markdown]
# Solve Mountain Car

# %%
env =  Custom_MountainCarEnv()

# %%
print(env.action_space.n)
# Out:
# 3

# %%
path = '/content/drive/MyDrive/Colab Notebooks/codes/MRAC/save_data/Disc_Moun_Car/'

# %%
q_hat = TileCodingFuncApprox(env.low, env.high, env.action_space.n,
                             learn_rate=0.5, num_tilings=8, init_val=0)

q_hat_target = TileCodingFuncApprox(env.low, env.high, env.action_space.n,
                             learn_rate=0.5, num_tilings=8, init_val=1)

# %%
ep_semi_grad_sarsa(env, episodes=2000, gamma=1.00, epsilon_start=0.99, epsilon_end=1e-3, epsilon_decay=0.9,
                   q_hat=q_hat, q_hat_target=q_hat_target)
# Out:
# Initial adapt. coeffs:  [ 0.001 -0.001  0.001  0.001]
# learning rate: 6.250000E-02
# EPISODE: 0 - FINAL SCORE: -200.0
# EPISODE: 0,  adapt. coeffs at final time step:  [ 3.86 -2.85  1.25  0.09]
# Best Episode:0; Best Score:-200.0
# EPISODE: 1 - FINAL SCORE: -200.0
# EPISODE: 1,  adapt. coeffs at final time step:  [ 3.77 -1.75  1.05  0.47]
# EPISODE: 2 - FINAL SCORE: -200.0
# EPISODE: 2,  adapt. coeffs at final time step:  [ 3.26 -1.84  0.96  0.84]
# EPISODE: 3 - FINAL SCORE: -200.0
# EPISODE: 3,  adapt. coeffs at final time step:  [ 3.3  -2.19  1.03  0.95]
# EPISODE: 4 - FINAL SCORE: -200.0
# EPISODE: 4,  adapt. coeffs at final time step:  [ 3.31 -2.17  1.02  1.05]
# EPISODE: 5 - FINAL SCORE: -200.0
# EPISODE: 5,  adapt. coeffs at final time step:  [ 3.29 -1.9   0.98  0.95]
# EPISODE: 6 - FINAL SCORE: -200.0
# EPISODE: 6,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  1.04]
# EPISODE: 7 - FINAL SCORE: -200.0
# EPISODE: 7,  adapt. coeffs at final time step:  [ 3.7  -2.69  1.19  1.  ]
# EPISODE: 8 - FINAL SCORE: -200.0
# EPISODE: 8,  adapt. coeffs at final time step:  [ 3.62 -1.77  1.02  1.04]
# EPISODE: 9 - FINAL SCORE: -200.0
# EPISODE: 9,  adapt. coeffs at final time step:  [ 3.34 -1.83  0.97  0.98]
# median:  [ 3.48  -2.035  1.025  0.965]
# EPISODE: 10 - FINAL SCORE: -200.0
# EPISODE: 10,  adapt. coeffs at final time step:  [ 3.39 -2.3   1.06  0.91]
# EPISODE: 11 - FINAL SCORE: -200.0
# EPISODE: 11,  adapt. coeffs at final time step:  [ 3.69 -1.76  1.03  0.94]
# EPISODE: 12 - FINAL SCORE: -200.0
# EPISODE: 12,  adapt. coeffs at final time step:  [ 3.29 -1.9   0.98  0.96]
# EPISODE: 13 - FINAL SCORE: -200.0
# EPISODE: 13,  adapt. coeffs at final time step:  [ 3.83 -1.75  1.06  0.97]
# EPISODE: 14 - FINAL SCORE: -200.0
# EPISODE: 14,  adapt. coeffs at final time step:  [ 3.36 -2.24  1.05  0.97]
# EPISODE: 15 - FINAL SCORE: -200.0
# EPISODE: 15,  adapt. coeffs at final time step:  [ 3.3  -2.3   1.04  1.01]
# EPISODE: 16 - FINAL SCORE: -200.0
# EPISODE: 16,  adapt. coeffs at final time step:  [ 3.31 -2.31  1.05  1.  ]
# EPISODE: 17 - FINAL SCORE: -200.0
# EPISODE: 17,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  0.91]
# EPISODE: 18 - FINAL SCORE: -200.0
# EPISODE: 18,  adapt. coeffs at final time step:  [ 3.28 -1.92  0.98  0.97]
# EPISODE: 19 - FINAL SCORE: -200.0
# EPISODE: 19,  adapt. coeffs at final time step:  [ 3.67 -2.67  1.18  1.02]
# median:  [ 3.375 -2.18   1.045  0.97 ]
# EPISODE: 20 - FINAL SCORE: -200.0
# EPISODE: 20,  adapt. coeffs at final time step:  [ 3.84 -1.75  1.06  0.94]
# EPISODE: 21 - FINAL SCORE: -200.0
# EPISODE: 21,  adapt. coeffs at final time step:  [ 3.7  -1.75  1.03  0.96]
# EPISODE: 22 - FINAL SCORE: -200.0
# EPISODE: 22,  adapt. coeffs at final time step:  [ 3.84 -1.75  1.06  0.94]
# EPISODE: 23 - FINAL SCORE: -200.0
# EPISODE: 23,  adapt. coeffs at final time step:  [ 3.87 -2.86  1.25  1.02]
# EPISODE: 24 - FINAL SCORE: -200.0
# EPISODE: 24,  adapt. coeffs at final time step:  [ 3.3  -2.3   1.04  0.98]
# EPISODE: 25 - FINAL SCORE: -200.0
# EPISODE: 25,  adapt. coeffs at final time step:  [ 3.32 -1.83  0.97  0.99]
# EPISODE: 26 - FINAL SCORE: -199.1
# EPISODE: 26,  adapt. coeffs at final time step:  [ 3.66 -2.66  1.17  1.03]
# Best Episode:26; Best Score:-182.0
# EPISODE: 27 - FINAL SCORE: -197.15
# EPISODE: 27,  adapt. coeffs at final time step:  [ 3.79 -1.74  1.05  0.97]
# Best Episode:27; Best Score:-161.0
# EPISODE: 28 - FINAL SCORE: -197.15
# EPISODE: 28,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  0.99]
# EPISODE: 29 - FINAL SCORE: -197.15
# EPISODE: 29,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  1.02]
# median:  [ 3.665 -2.18   1.05   0.97 ]
# EPISODE: 30 - FINAL SCORE: -196.85
# EPISODE: 30,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.02  0.95]
# EPISODE: 31 - FINAL SCORE: -196.85
# EPISODE: 31,  adapt. coeffs at final time step:  [ 3.7  -2.71  1.19  1.06]
# EPISODE: 32 - FINAL SCORE: -196.85
# EPISODE: 32,  adapt. coeffs at final time step:  [ 3.31 -2.31  1.05  1.04]
# EPISODE: 33 - FINAL SCORE: -196.85
# EPISODE: 33,  adapt. coeffs at final time step:  [ 3.84 -2.83  1.24  0.99]
# EPISODE: 34 - FINAL SCORE: -195.0
# EPISODE: 34,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.02  0.97]
# EPISODE: 35 - FINAL SCORE: -193.4
# EPISODE: 35,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.24  1.  ]
# EPISODE: 36 - FINAL SCORE: -191.55
# EPISODE: 36,  adapt. coeffs at final time step:  [ 3.8  -2.79  1.23  0.98]
# EPISODE: 37 - FINAL SCORE: -191.15
# EPISODE: 37,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.99]
# EPISODE: 38 - FINAL SCORE: -190.9
# EPISODE: 38,  adapt. coeffs at final time step:  [ 3.78 -2.78  1.22  1.  ]
# EPISODE: 39 - FINAL SCORE: -188.85
# EPISODE: 39,  adapt. coeffs at final time step:  [ 3.4  -2.3   1.06  0.98]
# median:  [ 3.665 -2.275  1.05   0.98 ]
# Best Episode:39; Best Score:-159.0
# EPISODE: 40 - FINAL SCORE: -187.55
# EPISODE: 40,  adapt. coeffs at final time step:  [ 3.79 -2.79  1.22  0.98]
# EPISODE: 41 - FINAL SCORE: -187.55
# EPISODE: 41,  adapt. coeffs at final time step:  [ 3.24 -1.86  0.96  1.05]
# EPISODE: 42 - FINAL SCORE: -185.4
# EPISODE: 42,  adapt. coeffs at final time step:  [ 3.8  -2.79  1.23  0.93]
# Best Episode:42; Best Score:-157.0
# EPISODE: 43 - FINAL SCORE: -184.9
# EPISODE: 43,  adapt. coeffs at final time step:  [ 3.66 -2.66  1.17  1.05]
# EPISODE: 44 - FINAL SCORE: -183.0
# EPISODE: 44,  adapt. coeffs at final time step:  [ 3.84 -2.83  1.24  1.  ]
# EPISODE: 45 - FINAL SCORE: -181.55
# EPISODE: 45,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.94]
# EPISODE: 46 - FINAL SCORE: -182.45
# EPISODE: 46,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.95]
# EPISODE: 47 - FINAL SCORE: -182.45
# EPISODE: 47,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  0.93]
# EPISODE: 48 - FINAL SCORE: -182.45
# EPISODE: 48,  adapt. coeffs at final time step:  [ 3.78 -2.78  1.22  1.01]
# EPISODE: 49 - FINAL SCORE: -180.55
# EPISODE: 49,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.96]
# median:  [ 3.695 -2.305  1.06   0.98 ]
# EPISODE: 50 - FINAL SCORE: -179.05
# EPISODE: 50,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  1.03]
# EPISODE: 51 - FINAL SCORE: -178.55
# EPISODE: 51,  adapt. coeffs at final time step:  [ 3.35 -2.36  1.06  1.02]
# EPISODE: 52 - FINAL SCORE: -178.15
# EPISODE: 52,  adapt. coeffs at final time step:  [ 3.83 -2.83  1.24  1.1 ]
# EPISODE: 53 - FINAL SCORE: -178.15
# EPISODE: 53,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.02]
# EPISODE: 54 - FINAL SCORE: -177.5
# EPISODE: 54,  adapt. coeffs at final time step:  [ 3.35 -2.21  1.04  0.92]
# Best Episode:54; Best Score:-150.0
# EPISODE: 55 - FINAL SCORE: -178.7
# EPISODE: 55,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.02]
# EPISODE: 56 - FINAL SCORE: -176.4
# EPISODE: 56,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# Best Episode:56; Best Score:-117.0
# EPISODE: 57 - FINAL SCORE: -174.95
# EPISODE: 57,  adapt. coeffs at final time step:  [ 3.79 -2.79  1.22  0.95]
# EPISODE: 58 - FINAL SCORE: -175.2
# EPISODE: 58,  adapt. coeffs at final time step:  [ 3.3  -2.19  1.03  0.94]
# EPISODE: 59 - FINAL SCORE: -177.25
# EPISODE: 59,  adapt. coeffs at final time step:  [ 3.36 -2.36  1.06  1.  ]
# median:  [ 3.69 -2.31  1.06  0.98]
# EPISODE: 60 - FINAL SCORE: -178.55
# EPISODE: 60,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.  ]
# EPISODE: 61 - FINAL SCORE: -178.55
# EPISODE: 61,  adapt. coeffs at final time step:  [ 3.87 -2.87  1.25  1.  ]
# EPISODE: 62 - FINAL SCORE: -180.15
# EPISODE: 62,  adapt. coeffs at final time step:  [ 3.3  -2.3   1.04  1.03]
# EPISODE: 63 - FINAL SCORE: -178.7
# EPISODE: 63,  adapt. coeffs at final time step:  [ 3.25 -2.26  1.03  0.98]
# EPISODE: 64 - FINAL SCORE: -177.95
# EPISODE: 64,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.99]
# EPISODE: 65 - FINAL SCORE: -177.0
# EPISODE: 65,  adapt. coeffs at final time step:  [ 3.38 -2.38  1.07  1.02]
# EPISODE: 66 - FINAL SCORE: -174.85
# EPISODE: 66,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.95]
# EPISODE: 67 - FINAL SCORE: -174.6
# EPISODE: 67,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.03]
# EPISODE: 68 - FINAL SCORE: -174.6
# EPISODE: 68,  adapt. coeffs at final time step:  [ 3.81 -1.75  1.05  1.03]
# EPISODE: 69 - FINAL SCORE: -173.65
# EPISODE: 69,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.97]
# median:  [ 3.695 -2.335  1.06   0.985]
# EPISODE: 70 - FINAL SCORE: -173.1
# EPISODE: 70,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  0.96]
# EPISODE: 71 - FINAL SCORE: -171.45
# EPISODE: 71,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.01]
# EPISODE: 72 - FINAL SCORE: -171.85
# EPISODE: 72,  adapt. coeffs at final time step:  [ 3.36 -2.36  1.07  1.01]
# EPISODE: 73 - FINAL SCORE: -167.5
# EPISODE: 73,  adapt. coeffs at final time step:  [ 3.26 -2.25  1.03  0.99]
# Best Episode:73; Best Score:-113.0
# EPISODE: 74 - FINAL SCORE: -166.2
# EPISODE: 74,  adapt. coeffs at final time step:  [ 3.71 -2.7   1.19  1.  ]
# EPISODE: 75 - FINAL SCORE: -162.3
# EPISODE: 75,  adapt. coeffs at final time step:  [ 3.31 -2.31  1.05  1.  ]
# EPISODE: 76 - FINAL SCORE: -164.05
# EPISODE: 76,  adapt. coeffs at final time step:  [ 3.38 -1.81  0.98  0.98]
# EPISODE: 77 - FINAL SCORE: -165.1
# EPISODE: 77,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  0.98]
# EPISODE: 78 - FINAL SCORE: -164.85
# EPISODE: 78,  adapt. coeffs at final time step:  [ 3.84 -2.83  1.24  1.03]
# EPISODE: 79 - FINAL SCORE: -162.9
# EPISODE: 79,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.91]
# median:  [ 3.695 -2.36   1.06   0.99 ]
# EPISODE: 80 - FINAL SCORE: -158.8
# EPISODE: 80,  adapt. coeffs at final time step:  [ 3.83 -2.84  1.24  0.91]
# EPISODE: 81 - FINAL SCORE: -157.9
# EPISODE: 81,  adapt. coeffs at final time step:  [ 3.77 -2.77  1.22  0.97]
# EPISODE: 82 - FINAL SCORE: -155.55
# EPISODE: 82,  adapt. coeffs at final time step:  [ 3.8  -1.74  1.05  0.99]
# EPISODE: 83 - FINAL SCORE: -157.15
# EPISODE: 83,  adapt. coeffs at final time step:  [ 3.39 -2.29  1.06  1.06]
# EPISODE: 84 - FINAL SCORE: -159.8
# EPISODE: 84,  adapt. coeffs at final time step:  [ 3.25 -1.85  0.96  0.96]
# EPISODE: 85 - FINAL SCORE: -159.95
# EPISODE: 85,  adapt. coeffs at final time step:  [ 3.35 -2.36  1.06  1.01]
# EPISODE: 86 - FINAL SCORE: -159.45
# EPISODE: 86,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  1.  ]
# EPISODE: 87 - FINAL SCORE: -159.15
# EPISODE: 87,  adapt. coeffs at final time step:  [ 3.83 -2.83  1.24  1.02]
# EPISODE: 88 - FINAL SCORE: -155.1
# EPISODE: 88,  adapt. coeffs at final time step:  [ 3.35 -2.35  1.06  0.97]
# EPISODE: 89 - FINAL SCORE: -153.75
# EPISODE: 89,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  0.98]
# median:  [ 3.7  -2.36  1.06  0.99]
# EPISODE: 90 - FINAL SCORE: -154.2
# EPISODE: 90,  adapt. coeffs at final time step:  [ 3.35 -2.22  1.04  0.99]
# EPISODE: 91 - FINAL SCORE: -151.9
# EPISODE: 91,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  0.97]
# Best Episode:91; Best Score:-111.0
# EPISODE: 92 - FINAL SCORE: -147.9
# EPISODE: 92,  adapt. coeffs at final time step:  [ 3.84 -2.83  1.24  1.  ]
# EPISODE: 93 - FINAL SCORE: -148.1
# EPISODE: 93,  adapt. coeffs at final time step:  [ 3.87 -2.87  1.25  0.99]
# EPISODE: 94 - FINAL SCORE: -149.8
# EPISODE: 94,  adapt. coeffs at final time step:  [ 3.31 -2.16  1.02  0.99]
# EPISODE: 95 - FINAL SCORE: -149.7
# EPISODE: 95,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.96]
# EPISODE: 96 - FINAL SCORE: -149.4
# EPISODE: 96,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.96]
# EPISODE: 97 - FINAL SCORE: -146.05
# EPISODE: 97,  adapt. coeffs at final time step:  [ 3.77 -2.77  1.22  0.95]
# EPISODE: 98 - FINAL SCORE: -142.4
# EPISODE: 98,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.94]
# EPISODE: 99 - FINAL SCORE: -142.35
# EPISODE: 99,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.99]
# median:  [ 3.7  -2.36  1.06  0.99]
# EPISODE: 100 - FINAL SCORE: -142.7
# EPISODE: 100,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.06]
# EPISODE: 101 - FINAL SCORE: -141.3
# EPISODE: 101,  adapt. coeffs at final time step:  [ 3.83 -2.83  1.24  1.  ]
# EPISODE: 102 - FINAL SCORE: -142.0
# EPISODE: 102,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# EPISODE: 103 - FINAL SCORE: -139.8
# EPISODE: 103,  adapt. coeffs at final time step:  [ 3.36 -2.36  1.07  0.97]
# EPISODE: 104 - FINAL SCORE: -135.85
# EPISODE: 104,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.96]
# EPISODE: 105 - FINAL SCORE: -135.65
# EPISODE: 105,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.98]
# EPISODE: 106 - FINAL SCORE: -135.65
# EPISODE: 106,  adapt. coeffs at final time step:  [ 3.3  -2.19  1.03  0.95]
# EPISODE: 107 - FINAL SCORE: -137.65
# EPISODE: 107,  adapt. coeffs at final time step:  [ 3.31 -2.16  1.02  1.  ]
# EPISODE: 108 - FINAL SCORE: -139.25
# EPISODE: 108,  adapt. coeffs at final time step:  [ 3.36 -1.82  0.98  0.99]
# EPISODE: 109 - FINAL SCORE: -139.15
# EPISODE: 109,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.99]
# median:  [ 3.695 -2.36   1.06   0.99 ]
# EPISODE: 110 - FINAL SCORE: -138.4
# EPISODE: 110,  adapt. coeffs at final time step:  [ 3.3  -2.19  1.03  0.95]
# EPISODE: 111 - FINAL SCORE: -139.1
# EPISODE: 111,  adapt. coeffs at final time step:  [ 3.82 -1.75  1.06  1.01]
# EPISODE: 112 - FINAL SCORE: -138.65
# EPISODE: 112,  adapt. coeffs at final time step:  [ 3.37 -2.37  1.07  0.98]
# EPISODE: 113 - FINAL SCORE: -138.9
# EPISODE: 113,  adapt. coeffs at final time step:  [ 3.37 -2.25  1.05  0.99]
# EPISODE: 114 - FINAL SCORE: -138.8
# EPISODE: 114,  adapt. coeffs at final time step:  [ 3.86 -1.75  1.06  0.98]
# EPISODE: 115 - FINAL SCORE: -140.35
# EPISODE: 115,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  0.99]
# EPISODE: 116 - FINAL SCORE: -140.7
# EPISODE: 116,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  0.98]
# EPISODE: 117 - FINAL SCORE: -140.5
# EPISODE: 117,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.  ]
# EPISODE: 118 - FINAL SCORE: -142.4
# EPISODE: 118,  adapt. coeffs at final time step:  [ 3.36 -2.35  1.06  0.96]
# EPISODE: 119 - FINAL SCORE: -141.9
# EPISODE: 119,  adapt. coeffs at final time step:  [ 3.3  -2.17  1.02  0.99]
# median:  [ 3.665 -2.335  1.06   0.99 ]
# EPISODE: 120 - FINAL SCORE: -143.1
# EPISODE: 120,  adapt. coeffs at final time step:  [ 3.36 -2.36  1.07  0.99]
# EPISODE: 121 - FINAL SCORE: -142.3
# EPISODE: 121,  adapt. coeffs at final time step:  [ 3.38 -2.38  1.07  0.95]
# EPISODE: 122 - FINAL SCORE: -141.2
# EPISODE: 122,  adapt. coeffs at final time step:  [ 3.3  -2.3   1.04  1.01]
# EPISODE: 123 - FINAL SCORE: -139.8
# EPISODE: 123,  adapt. coeffs at final time step:  [ 3.3  -2.19  1.03  0.98]
# EPISODE: 124 - FINAL SCORE: -141.7
# EPISODE: 124,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.99]
# EPISODE: 125 - FINAL SCORE: -139.85
# EPISODE: 125,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.99]
# EPISODE: 126 - FINAL SCORE: -139.75
# EPISODE: 126,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.01]
# EPISODE: 127 - FINAL SCORE: -137.75
# EPISODE: 127,  adapt. coeffs at final time step:  [ 3.3  -2.17  1.02  0.99]
# EPISODE: 128 - FINAL SCORE: -137.65
# EPISODE: 128,  adapt. coeffs at final time step:  [ 3.3  -2.16  1.02  1.  ]
# EPISODE: 129 - FINAL SCORE: -139.5
# EPISODE: 129,  adapt. coeffs at final time step:  [ 3.3  -2.17  1.02  1.  ]
# median:  [ 3.395 -2.32   1.06   0.99 ]
# EPISODE: 130 - FINAL SCORE: -139.05
# EPISODE: 130,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# EPISODE: 131 - FINAL SCORE: -140.45
# EPISODE: 131,  adapt. coeffs at final time step:  [ 3.36 -1.82  0.98  1.  ]
# EPISODE: 132 - FINAL SCORE: -140.5
# EPISODE: 132,  adapt. coeffs at final time step:  [ 3.84 -2.83  1.24  0.93]
# EPISODE: 133 - FINAL SCORE: -144.0
# EPISODE: 133,  adapt. coeffs at final time step:  [ 3.4  -2.31  1.06  1.01]
# EPISODE: 134 - FINAL SCORE: -143.75
# EPISODE: 134,  adapt. coeffs at final time step:  [ 3.28 -1.92  0.98  1.01]
# EPISODE: 135 - FINAL SCORE: -144.35
# EPISODE: 135,  adapt. coeffs at final time step:  [ 3.8  -1.75  1.05  1.01]
# EPISODE: 136 - FINAL SCORE: -145.65
# EPISODE: 136,  adapt. coeffs at final time step:  [ 3.25 -1.85  0.96  0.99]
# EPISODE: 137 - FINAL SCORE: -147.45
# EPISODE: 137,  adapt. coeffs at final time step:  [ 3.38 -2.38  1.07  1.  ]
# EPISODE: 138 - FINAL SCORE: -147.8
# EPISODE: 138,  adapt. coeffs at final time step:  [ 3.3  -2.16  1.02  1.  ]
# EPISODE: 139 - FINAL SCORE: -147.55
# EPISODE: 139,  adapt. coeffs at final time step:  [ 3.38 -2.38  1.07  0.92]
# median:  [ 3.385 -2.31   1.06   0.99 ]
# EPISODE: 140 - FINAL SCORE: -147.8
# EPISODE: 140,  adapt. coeffs at final time step:  [ 3.4  -2.31  1.06  1.  ]
# EPISODE: 141 - FINAL SCORE: -148.55
# EPISODE: 141,  adapt. coeffs at final time step:  [ 3.87 -1.75  1.07  1.01]
# EPISODE: 142 - FINAL SCORE: -149.3
# EPISODE: 142,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.99]
# EPISODE: 143 - FINAL SCORE: -150.8
# EPISODE: 143,  adapt. coeffs at final time step:  [ 3.37 -2.37  1.07  1.  ]
# EPISODE: 144 - FINAL SCORE: -149.95
# EPISODE: 144,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.96]
# EPISODE: 145 - FINAL SCORE: -153.9
# EPISODE: 145,  adapt. coeffs at final time step:  [ 3.25 -1.86  0.96  0.99]
# EPISODE: 146 - FINAL SCORE: -154.1
# EPISODE: 146,  adapt. coeffs at final time step:  [ 3.8  -1.75  1.05  1.03]
# EPISODE: 147 - FINAL SCORE: -154.15
# EPISODE: 147,  adapt. coeffs at final time step:  [ 3.87 -2.87  1.25  0.97]
# EPISODE: 148 - FINAL SCORE: -152.65
# EPISODE: 148,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  0.95]
# EPISODE: 149 - FINAL SCORE: -152.75
# EPISODE: 149,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  1.01]
# median:  [ 3.39 -2.31  1.06  0.99]
# EPISODE: 150 - FINAL SCORE: -151.3
# EPISODE: 150,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  1.02]
# Best Episode:150; Best Score:-109.0
# EPISODE: 151 - FINAL SCORE: -148.2
# EPISODE: 151,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  1.03]
# Best Episode:151; Best Score:-91.0
# EPISODE: 152 - FINAL SCORE: -150.15
# EPISODE: 152,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.97]
# EPISODE: 153 - FINAL SCORE: -147.65
# EPISODE: 153,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.93]
# EPISODE: 154 - FINAL SCORE: -147.6
# EPISODE: 154,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  0.92]
# EPISODE: 155 - FINAL SCORE: -146.6
# EPISODE: 155,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  0.96]
# EPISODE: 156 - FINAL SCORE: -143.25
# EPISODE: 156,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.02  0.96]
# EPISODE: 157 - FINAL SCORE: -143.3
# EPISODE: 157,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.95]
# EPISODE: 158 - FINAL SCORE: -142.15
# EPISODE: 158,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.95]
# EPISODE: 159 - FINAL SCORE: -142.75
# EPISODE: 159,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.96]
# median:  [ 3.4   -2.315  1.06   0.99 ]
# EPISODE: 160 - FINAL SCORE: -142.55
# EPISODE: 160,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.96]
# EPISODE: 161 - FINAL SCORE: -142.4
# EPISODE: 161,  adapt. coeffs at final time step:  [ 3.36 -2.36  1.07  1.03]
# EPISODE: 162 - FINAL SCORE: -141.7
# EPISODE: 162,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.19  1.03]
# EPISODE: 163 - FINAL SCORE: -140.75
# EPISODE: 163,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.01]
# EPISODE: 164 - FINAL SCORE: -141.4
# EPISODE: 164,  adapt. coeffs at final time step:  [ 3.86 -1.75  1.06  1.06]
# EPISODE: 165 - FINAL SCORE: -139.1
# EPISODE: 165,  adapt. coeffs at final time step:  [ 3.29 -1.91  0.98  0.99]
# EPISODE: 166 - FINAL SCORE: -138.65
# EPISODE: 166,  adapt. coeffs at final time step:  [ 3.42 -2.33  1.07  1.01]
# EPISODE: 167 - FINAL SCORE: -136.5
# EPISODE: 167,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  0.97]
# EPISODE: 168 - FINAL SCORE: -137.9
# EPISODE: 168,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# EPISODE: 169 - FINAL SCORE: -137.75
# EPISODE: 169,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.97]
# median:  [ 3.4  -2.32  1.06  0.99]
# EPISODE: 170 - FINAL SCORE: -140.25
# EPISODE: 170,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  0.99]
# EPISODE: 171 - FINAL SCORE: -142.95
# EPISODE: 171,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.  ]
# EPISODE: 172 - FINAL SCORE: -142.7
# EPISODE: 172,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.99]
# EPISODE: 173 - FINAL SCORE: -143.2
# EPISODE: 173,  adapt. coeffs at final time step:  [ 3.26 -2.25  1.03  0.98]
# EPISODE: 174 - FINAL SCORE: -142.55
# EPISODE: 174,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.95]
# EPISODE: 175 - FINAL SCORE: -141.2
# EPISODE: 175,  adapt. coeffs at final time step:  [ 3.31 -2.31  1.05  0.94]
# EPISODE: 176 - FINAL SCORE: -140.0
# EPISODE: 176,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  0.95]
# Best Episode:176; Best Score:-88.0
# EPISODE: 177 - FINAL SCORE: -138.1
# EPISODE: 177,  adapt. coeffs at final time step:  [ 3.37 -2.37  1.07  0.91]
# EPISODE: 178 - FINAL SCORE: -138.25
# EPISODE: 178,  adapt. coeffs at final time step:  [ 3.87 -2.87  1.25  1.03]
# EPISODE: 179 - FINAL SCORE: -136.15
# EPISODE: 179,  adapt. coeffs at final time step:  [ 3.37 -1.82  0.98  1.01]
# median:  [ 3.4  -2.32  1.06  0.99]
# EPISODE: 180 - FINAL SCORE: -135.85
# EPISODE: 180,  adapt. coeffs at final time step:  [ 3.3  -1.84  0.97  0.98]
# EPISODE: 181 - FINAL SCORE: -135.5
# EPISODE: 181,  adapt. coeffs at final time step:  [ 3.31 -2.16  1.02  0.99]
# EPISODE: 182 - FINAL SCORE: -135.95
# EPISODE: 182,  adapt. coeffs at final time step:  [ 3.36 -2.36  1.06  1.01]
# EPISODE: 183 - FINAL SCORE: -135.4
# EPISODE: 183,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# EPISODE: 184 - FINAL SCORE: -135.1
# EPISODE: 184,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.02]
# EPISODE: 185 - FINAL SCORE: -134.95
# EPISODE: 185,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.  ]
# EPISODE: 186 - FINAL SCORE: -134.9
# EPISODE: 186,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.97]
# EPISODE: 187 - FINAL SCORE: -137.25
# EPISODE: 187,  adapt. coeffs at final time step:  [ 3.35 -2.36  1.06  1.01]
# EPISODE: 188 - FINAL SCORE: -134.45
# EPISODE: 188,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.19  1.02]
# EPISODE: 189 - FINAL SCORE: -134.4
# EPISODE: 189,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# median:  [ 3.395 -2.32   1.06   0.99 ]
# EPISODE: 190 - FINAL SCORE: -133.9
# EPISODE: 190,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# EPISODE: 191 - FINAL SCORE: -133.75
# EPISODE: 191,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.  ]
# EPISODE: 192 - FINAL SCORE: -131.95
# EPISODE: 192,  adapt. coeffs at final time step:  [ 3.83 -2.83  1.24  0.99]
# EPISODE: 193 - FINAL SCORE: -131.5
# EPISODE: 193,  adapt. coeffs at final time step:  [ 3.83 -2.83  1.24  0.98]
# EPISODE: 194 - FINAL SCORE: -131.75
# EPISODE: 194,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  0.97]
# EPISODE: 195 - FINAL SCORE: -132.15
# EPISODE: 195,  adapt. coeffs at final time step:  [ 3.81 -2.8   1.23  0.98]
# EPISODE: 196 - FINAL SCORE: -135.6
# EPISODE: 196,  adapt. coeffs at final time step:  [ 3.38 -2.38  1.07  0.98]
# EPISODE: 197 - FINAL SCORE: -135.4
# EPISODE: 197,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  0.99]
# EPISODE: 198 - FINAL SCORE: -136.65
# EPISODE: 198,  adapt. coeffs at final time step:  [ 3.26 -2.25  1.03  0.98]
# EPISODE: 199 - FINAL SCORE: -136.45
# EPISODE: 199,  adapt. coeffs at final time step:  [ 3.79 -2.79  1.22  0.97]
# median:  [ 3.4  -2.35  1.06  0.99]
# EPISODE: 200 - FINAL SCORE: -137.7
# EPISODE: 200,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.99]
# EPISODE: 201 - FINAL SCORE: -138.45
# EPISODE: 201,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.93]
# EPISODE: 202 - FINAL SCORE: -138.1
# EPISODE: 202,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# EPISODE: 203 - FINAL SCORE: -139.6
# EPISODE: 203,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# EPISODE: 204 - FINAL SCORE: -139.65
# EPISODE: 204,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# EPISODE: 205 - FINAL SCORE: -140.05
# EPISODE: 205,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# EPISODE: 206 - FINAL SCORE: -140.2
# EPISODE: 206,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# EPISODE: 207 - FINAL SCORE: -140.45
# EPISODE: 207,  adapt. coeffs at final time step:  [ 3.79 -2.79  1.22  1.02]
# EPISODE: 208 - FINAL SCORE: -141.3
# EPISODE: 208,  adapt. coeffs at final time step:  [ 3.83 -2.84  1.24  1.02]
# EPISODE: 209 - FINAL SCORE: -141.55
# EPISODE: 209,  adapt. coeffs at final time step:  [ 3.33 -2.33  1.05  1.02]
# median:  [ 3.4  -2.34  1.06  0.99]
# EPISODE: 210 - FINAL SCORE: -139.5
# EPISODE: 210,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.01]
# EPISODE: 211 - FINAL SCORE: -139.85
# EPISODE: 211,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# EPISODE: 212 - FINAL SCORE: -142.05
# EPISODE: 212,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.98]
# EPISODE: 213 - FINAL SCORE: -142.95
# EPISODE: 213,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  1.  ]
# EPISODE: 214 - FINAL SCORE: -143.7
# EPISODE: 214,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  0.98]
# EPISODE: 215 - FINAL SCORE: -144.7
# EPISODE: 215,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.97]
# EPISODE: 216 - FINAL SCORE: -144.15
# EPISODE: 216,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.96]
# EPISODE: 217 - FINAL SCORE: -144.2
# EPISODE: 217,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  0.95]
# EPISODE: 218 - FINAL SCORE: -142.85
# EPISODE: 218,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  0.99]
# EPISODE: 219 - FINAL SCORE: -142.65
# EPISODE: 219,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  1.  ]
# median:  [ 3.4  -2.34  1.06  0.99]
# EPISODE: 220 - FINAL SCORE: -141.3
# EPISODE: 220,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# EPISODE: 221 - FINAL SCORE: -140.4
# EPISODE: 221,  adapt. coeffs at final time step:  [ 3.25 -1.85  0.96  0.96]
# EPISODE: 222 - FINAL SCORE: -141.4
# EPISODE: 222,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.98]
# EPISODE: 223 - FINAL SCORE: -138.45
# EPISODE: 223,  adapt. coeffs at final time step:  [ 3.79 -2.79  1.22  0.98]
# EPISODE: 224 - FINAL SCORE: -138.95
# EPISODE: 224,  adapt. coeffs at final time step:  [ 3.3  -2.3   1.04  0.99]
# EPISODE: 225 - FINAL SCORE: -138.9
# EPISODE: 225,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.99]
# EPISODE: 226 - FINAL SCORE: -138.55
# EPISODE: 226,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.02  1.03]
# EPISODE: 227 - FINAL SCORE: -136.0
# EPISODE: 227,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  1.02]
# EPISODE: 228 - FINAL SCORE: -138.0
# EPISODE: 228,  adapt. coeffs at final time step:  [ 3.26 -2.25  1.03  0.98]
# EPISODE: 229 - FINAL SCORE: -138.0
# EPISODE: 229,  adapt. coeffs at final time step:  [ 3.83 -2.83  1.24  0.99]
# median:  [ 3.395 -2.33   1.06   0.99 ]
# EPISODE: 230 - FINAL SCORE: -140.25
# EPISODE: 230,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# EPISODE: 231 - FINAL SCORE: -140.0
# EPISODE: 231,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  1.01]
# EPISODE: 232 - FINAL SCORE: -137.9
# EPISODE: 232,  adapt. coeffs at final time step:  [ 3.25 -2.26  1.03  1.02]
# EPISODE: 233 - FINAL SCORE: -135.25
# EPISODE: 233,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  1.02]
# EPISODE: 234 - FINAL SCORE: -134.65
# EPISODE: 234,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.99]
# EPISODE: 235 - FINAL SCORE: -134.95
# EPISODE: 235,  adapt. coeffs at final time step:  [ 3.63 -2.62  1.16  0.95]
# EPISODE: 236 - FINAL SCORE: -134.7
# EPISODE: 236,  adapt. coeffs at final time step:  [ 3.78 -2.77  1.22  0.97]
# EPISODE: 237 - FINAL SCORE: -134.55
# EPISODE: 237,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  0.98]
# EPISODE: 238 - FINAL SCORE: -131.6
# EPISODE: 238,  adapt. coeffs at final time step:  [ 3.8  -2.79  1.23  0.97]
# Best Episode:238; Best Score:-86.0
# EPISODE: 239 - FINAL SCORE: -131.6
# EPISODE: 239,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  1.  ]
# median:  [ 3.41  -2.355  1.06   0.99 ]
# EPISODE: 240 - FINAL SCORE: -131.95
# EPISODE: 240,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.96]
# EPISODE: 241 - FINAL SCORE: -132.1
# EPISODE: 241,  adapt. coeffs at final time step:  [ 3.68 -2.68  1.18  0.95]
# EPISODE: 242 - FINAL SCORE: -131.8
# EPISODE: 242,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.98]
# EPISODE: 243 - FINAL SCORE: -133.7
# EPISODE: 243,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.02]
# EPISODE: 244 - FINAL SCORE: -130.0
# EPISODE: 244,  adapt. coeffs at final time step:  [ 3.79 -2.79  1.22  1.  ]
# EPISODE: 245 - FINAL SCORE: -127.85
# EPISODE: 245,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  0.99]
# EPISODE: 246 - FINAL SCORE: -128.75
# EPISODE: 246,  adapt. coeffs at final time step:  [ 3.35 -1.82  0.98  1.01]
# EPISODE: 247 - FINAL SCORE: -127.7
# EPISODE: 247,  adapt. coeffs at final time step:  [ 3.82 -2.82  1.24  1.  ]
# EPISODE: 248 - FINAL SCORE: -127.4
# EPISODE: 248,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.99]
# EPISODE: 249 - FINAL SCORE: -126.95
# EPISODE: 249,  adapt. coeffs at final time step:  [ 3.36 -2.36  1.07  1.02]
# median:  [ 3.41 -2.36  1.06  0.99]
# EPISODE: 250 - FINAL SCORE: -126.45
# EPISODE: 250,  adapt. coeffs at final time step:  [ 3.69 -1.76  1.03  1.04]
# EPISODE: 251 - FINAL SCORE: -127.5
# EPISODE: 251,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.99]
# EPISODE: 252 - FINAL SCORE: -127.15
# EPISODE: 252,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  0.98]
# EPISODE: 253 - FINAL SCORE: -129.0
# EPISODE: 253,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  0.97]
# EPISODE: 254 - FINAL SCORE: -127.1
# EPISODE: 254,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  0.94]
# EPISODE: 255 - FINAL SCORE: -125.35
# EPISODE: 255,  adapt. coeffs at final time step:  [ 3.31 -2.31  1.05  0.92]
# EPISODE: 256 - FINAL SCORE: -125.65
# EPISODE: 256,  adapt. coeffs at final time step:  [ 3.81 -2.8   1.23  0.98]
# EPISODE: 257 - FINAL SCORE: -128.0
# EPISODE: 257,  adapt. coeffs at final time step:  [ 3.81 -2.8   1.23  0.94]
# EPISODE: 258 - FINAL SCORE: -129.05
# EPISODE: 258,  adapt. coeffs at final time step:  [ 3.38 -2.37  1.07  0.95]
# EPISODE: 259 - FINAL SCORE: -129.0
# EPISODE: 259,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.92]
# median:  [ 3.52 -2.36  1.06  0.99]
# EPISODE: 260 - FINAL SCORE: -125.85
# EPISODE: 260,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  0.94]
# EPISODE: 261 - FINAL SCORE: -126.25
# EPISODE: 261,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  1.  ]
# EPISODE: 262 - FINAL SCORE: -126.95
# EPISODE: 262,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.98]
# EPISODE: 263 - FINAL SCORE: -124.75
# EPISODE: 263,  adapt. coeffs at final time step:  [ 3.8  -2.79  1.23  0.98]
# EPISODE: 264 - FINAL SCORE: -124.85
# EPISODE: 264,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  0.98]
# EPISODE: 265 - FINAL SCORE: -127.2
# EPISODE: 265,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  1.  ]
# EPISODE: 266 - FINAL SCORE: -126.75
# EPISODE: 266,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# EPISODE: 267 - FINAL SCORE: -127.25
# EPISODE: 267,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.19  0.97]
# EPISODE: 268 - FINAL SCORE: -127.2
# EPISODE: 268,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# EPISODE: 269 - FINAL SCORE: -125.35
# EPISODE: 269,  adapt. coeffs at final time step:  [ 3.31 -2.15  1.02  0.99]
# median:  [ 3.52  -2.36   1.06   0.985]
# EPISODE: 270 - FINAL SCORE: -126.4
# EPISODE: 270,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.99]
# EPISODE: 271 - FINAL SCORE: -123.6
# EPISODE: 271,  adapt. coeffs at final time step:  [ 3.69 -1.75  1.03  0.99]
# EPISODE: 272 - FINAL SCORE: -123.75
# EPISODE: 272,  adapt. coeffs at final time step:  [ 3.37 -2.25  1.05  1.02]
# EPISODE: 273 - FINAL SCORE: -124.3
# EPISODE: 273,  adapt. coeffs at final time step:  [ 3.87 -1.75  1.07  1.02]
# EPISODE: 274 - FINAL SCORE: -124.4
# EPISODE: 274,  adapt. coeffs at final time step:  [ 3.31 -2.32  1.05  0.99]
# EPISODE: 275 - FINAL SCORE: -123.3
# EPISODE: 275,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  0.98]
# Best Episode:275; Best Score:-85.0
# EPISODE: 276 - FINAL SCORE: -121.4
# EPISODE: 276,  adapt. coeffs at final time step:  [ 3.69 -1.75  1.03  1.  ]
# EPISODE: 277 - FINAL SCORE: -121.95
# EPISODE: 277,  adapt. coeffs at final time step:  [ 3.25 -1.85  0.96  0.99]
# EPISODE: 278 - FINAL SCORE: -125.35
# EPISODE: 278,  adapt. coeffs at final time step:  [ 3.4  -2.3   1.06  0.99]
# EPISODE: 279 - FINAL SCORE: -128.45
# EPISODE: 279,  adapt. coeffs at final time step:  [ 3.42 -2.34  1.07  1.  ]
# median:  [ 3.42  -2.345  1.06   0.99 ]
# EPISODE: 280 - FINAL SCORE: -130.6
# EPISODE: 280,  adapt. coeffs at final time step:  [ 3.37 -2.25  1.05  1.  ]
# EPISODE: 281 - FINAL SCORE: -128.45
# EPISODE: 281,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.  ]
# EPISODE: 282 - FINAL SCORE: -124.7
# EPISODE: 282,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  1.  ]
# EPISODE: 283 - FINAL SCORE: -124.8
# EPISODE: 283,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.  ]
# EPISODE: 284 - FINAL SCORE: -125.8
# EPISODE: 284,  adapt. coeffs at final time step:  [ 3.36 -2.36  1.06  1.03]
# EPISODE: 285 - FINAL SCORE: -125.8
# EPISODE: 285,  adapt. coeffs at final time step:  [ 3.63 -1.76  1.02  1.  ]
# EPISODE: 286 - FINAL SCORE: -122.8
# EPISODE: 286,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.19  0.99]
# Best Episode:286; Best Score:-84.0
# EPISODE: 287 - FINAL SCORE: -126.25
# EPISODE: 287,  adapt. coeffs at final time step:  [ 3.8  -1.75  1.05  1.  ]
# EPISODE: 288 - FINAL SCORE: -124.6
# EPISODE: 288,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.19  1.01]
# EPISODE: 289 - FINAL SCORE: -127.35
# EPISODE: 289,  adapt. coeffs at final time step:  [ 3.8  -1.74  1.05  1.  ]
# median:  [ 3.625 -2.345  1.06   0.99 ]
# EPISODE: 290 - FINAL SCORE: -124.45
# EPISODE: 290,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.  ]
# EPISODE: 291 - FINAL SCORE: -127.25
# EPISODE: 291,  adapt. coeffs at final time step:  [ 3.4  -2.3   1.06  1.  ]
# EPISODE: 292 - FINAL SCORE: -127.2
# EPISODE: 292,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.99]
# EPISODE: 293 - FINAL SCORE: -124.8
# EPISODE: 293,  adapt. coeffs at final time step:  [ 3.38 -2.38  1.07  1.01]
# EPISODE: 294 - FINAL SCORE: -126.15
# EPISODE: 294,  adapt. coeffs at final time step:  [ 3.3  -2.19  1.03  0.97]
# EPISODE: 295 - FINAL SCORE: -127.35
# EPISODE: 295,  adapt. coeffs at final time step:  [ 3.37 -2.37  1.07  0.99]
# EPISODE: 296 - FINAL SCORE: -129.35
# EPISODE: 296,  adapt. coeffs at final time step:  [ 3.8  -1.75  1.05  1.  ]
# EPISODE: 297 - FINAL SCORE: -127.85
# EPISODE: 297,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# EPISODE: 298 - FINAL SCORE: -125.9
# EPISODE: 298,  adapt. coeffs at final time step:  [ 3.4  -2.3   1.06  0.99]
# EPISODE: 299 - FINAL SCORE: -123.15
# EPISODE: 299,  adapt. coeffs at final time step:  [ 3.83 -2.83  1.24  0.95]
# median:  [ 3.41 -2.33  1.06  0.99]
# EPISODE: 300 - FINAL SCORE: -121.25
# EPISODE: 300,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.24  0.95]
# EPISODE: 301 - FINAL SCORE: -120.2
# EPISODE: 301,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  0.95]
# EPISODE: 302 - FINAL SCORE: -120.0
# EPISODE: 302,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  0.95]
# EPISODE: 303 - FINAL SCORE: -121.05
# EPISODE: 303,  adapt. coeffs at final time step:  [ 3.3  -2.16  1.02  0.97]
# EPISODE: 304 - FINAL SCORE: -121.05
# EPISODE: 304,  adapt. coeffs at final time step:  [ 3.31 -2.16  1.02  0.99]
# EPISODE: 305 - FINAL SCORE: -121.35
# EPISODE: 305,  adapt. coeffs at final time step:  [ 3.4  -2.31  1.06  0.99]
# EPISODE: 306 - FINAL SCORE: -124.85
# EPISODE: 306,  adapt. coeffs at final time step:  [ 3.8  -1.75  1.05  1.01]
# EPISODE: 307 - FINAL SCORE: -121.85
# EPISODE: 307,  adapt. coeffs at final time step:  [ 3.3  -2.16  1.02  0.98]
# EPISODE: 308 - FINAL SCORE: -123.7
# EPISODE: 308,  adapt. coeffs at final time step:  [ 3.3  -2.19  1.03  0.99]
# EPISODE: 309 - FINAL SCORE: -121.1
# EPISODE: 309,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  0.99]
# median:  [ 3.4  -2.32  1.06  0.99]
# EPISODE: 310 - FINAL SCORE: -122.8
# EPISODE: 310,  adapt. coeffs at final time step:  [ 3.25 -1.86  0.96  1.  ]
# EPISODE: 311 - FINAL SCORE: -121.65
# EPISODE: 311,  adapt. coeffs at final time step:  [ 3.4  -2.31  1.06  1.  ]
# EPISODE: 312 - FINAL SCORE: -123.25
# EPISODE: 312,  adapt. coeffs at final time step:  [ 3.4  -2.3   1.06  0.99]
# EPISODE: 313 - FINAL SCORE: -124.85
# EPISODE: 313,  adapt. coeffs at final time step:  [ 3.4  -2.3   1.06  0.99]
# EPISODE: 314 - FINAL SCORE: -125.4
# EPISODE: 314,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.96]
# EPISODE: 315 - FINAL SCORE: -127.3
# EPISODE: 315,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# EPISODE: 316 - FINAL SCORE: -127.8
# EPISODE: 316,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  1.  ]
# EPISODE: 317 - FINAL SCORE: -129.6
# EPISODE: 317,  adapt. coeffs at final time step:  [ 3.8  -1.75  1.05  1.01]
# EPISODE: 318 - FINAL SCORE: -132.4
# EPISODE: 318,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# EPISODE: 319 - FINAL SCORE: -134.05
# EPISODE: 319,  adapt. coeffs at final time step:  [ 3.38 -2.38  1.07  1.  ]
# median:  [ 3.4  -2.32  1.06  0.99]
# EPISODE: 320 - FINAL SCORE: -136.3
# EPISODE: 320,  adapt. coeffs at final time step:  [ 3.3  -2.17  1.02  0.99]
# EPISODE: 321 - FINAL SCORE: -139.9
# EPISODE: 321,  adapt. coeffs at final time step:  [ 3.4  -2.3   1.06  0.99]
# EPISODE: 322 - FINAL SCORE: -143.5
# EPISODE: 322,  adapt. coeffs at final time step:  [ 3.37 -2.37  1.07  1.  ]
# EPISODE: 323 - FINAL SCORE: -146.45
# EPISODE: 323,  adapt. coeffs at final time step:  [ 3.38 -2.38  1.07  1.02]
# EPISODE: 324 - FINAL SCORE: -148.0
# EPISODE: 324,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.03]
# EPISODE: 325 - FINAL SCORE: -147.3
# EPISODE: 325,  adapt. coeffs at final time step:  [ 3.32 -2.33  1.05  1.03]
# EPISODE: 326 - FINAL SCORE: -147.15
# EPISODE: 326,  adapt. coeffs at final time step:  [ 3.25 -2.26  1.03  1.02]
# EPISODE: 327 - FINAL SCORE: -146.6
# EPISODE: 327,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.  ]
# EPISODE: 328 - FINAL SCORE: -146.9
# EPISODE: 328,  adapt. coeffs at final time step:  [ 3.84 -1.75  1.06  1.04]
# EPISODE: 329 - FINAL SCORE: -146.3
# EPISODE: 329,  adapt. coeffs at final time step:  [ 3.37 -2.37  1.07  1.04]
# median:  [ 3.4  -2.32  1.06  0.99]
# EPISODE: 330 - FINAL SCORE: -146.65
# EPISODE: 330,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.99]
# EPISODE: 331 - FINAL SCORE: -145.1
# EPISODE: 331,  adapt. coeffs at final time step:  [ 3.3  -2.16  1.02  0.98]
# EPISODE: 332 - FINAL SCORE: -146.75
# EPISODE: 332,  adapt. coeffs at final time step:  [ 3.38 -1.82  0.98  1.  ]
# EPISODE: 333 - FINAL SCORE: -144.7
# EPISODE: 333,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# EPISODE: 334 - FINAL SCORE: -142.15
# EPISODE: 334,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.  ]
# EPISODE: 335 - FINAL SCORE: -140.6
# EPISODE: 335,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# EPISODE: 336 - FINAL SCORE: -137.35
# EPISODE: 336,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  0.98]
# EPISODE: 337 - FINAL SCORE: -133.5
# EPISODE: 337,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.  ]
# EPISODE: 338 - FINAL SCORE: -131.45
# EPISODE: 338,  adapt. coeffs at final time step:  [ 3.3  -2.17  1.02  0.97]
# EPISODE: 339 - FINAL SCORE: -131.0
# EPISODE: 339,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# median:  [ 3.4  -2.32  1.06  0.99]
# EPISODE: 340 - FINAL SCORE: -131.95
# EPISODE: 340,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.99]
# EPISODE: 341 - FINAL SCORE: -131.95
# EPISODE: 341,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# EPISODE: 342 - FINAL SCORE: -131.1
# EPISODE: 342,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# EPISODE: 343 - FINAL SCORE: -129.0
# EPISODE: 343,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  0.93]
# EPISODE: 344 - FINAL SCORE: -127.55
# EPISODE: 344,  adapt. coeffs at final time step:  [ 3.8  -2.79  1.23  0.94]
# EPISODE: 345 - FINAL SCORE: -128.25
# EPISODE: 345,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.96]
# EPISODE: 346 - FINAL SCORE: -125.65
# EPISODE: 346,  adapt. coeffs at final time step:  [ 3.63 -2.63  1.16  0.94]
# EPISODE: 347 - FINAL SCORE: -128.6
# EPISODE: 347,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  0.99]
# EPISODE: 348 - FINAL SCORE: -125.6
# EPISODE: 348,  adapt. coeffs at final time step:  [ 3.82 -2.82  1.24  1.  ]
# EPISODE: 349 - FINAL SCORE: -128.15
# EPISODE: 349,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.99]
# median:  [ 3.4  -2.32  1.06  0.99]
# EPISODE: 350 - FINAL SCORE: -126.3
# EPISODE: 350,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  0.99]
# EPISODE: 351 - FINAL SCORE: -127.95
# EPISODE: 351,  adapt. coeffs at final time step:  [ 3.84 -2.83  1.24  0.96]
# EPISODE: 352 - FINAL SCORE: -124.8
# EPISODE: 352,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  0.93]
# EPISODE: 353 - FINAL SCORE: -125.2
# EPISODE: 353,  adapt. coeffs at final time step:  [ 3.37 -2.24  1.05  0.97]
# EPISODE: 354 - FINAL SCORE: -128.35
# EPISODE: 354,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.99]
# EPISODE: 355 - FINAL SCORE: -130.2
# EPISODE: 355,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  1.02]
# EPISODE: 356 - FINAL SCORE: -130.45
# EPISODE: 356,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  1.02]
# EPISODE: 357 - FINAL SCORE: -134.25
# EPISODE: 357,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# EPISODE: 358 - FINAL SCORE: -134.3
# EPISODE: 358,  adapt. coeffs at final time step:  [ 3.31 -2.16  1.02  0.99]
# EPISODE: 359 - FINAL SCORE: -132.7
# EPISODE: 359,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.19  0.98]
# median:  [ 3.4  -2.32  1.06  0.99]
# EPISODE: 360 - FINAL SCORE: -130.9
# EPISODE: 360,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  0.96]
# EPISODE: 361 - FINAL SCORE: -130.0
# EPISODE: 361,  adapt. coeffs at final time step:  [ 3.31 -2.16  1.02  0.99]
# EPISODE: 362 - FINAL SCORE: -130.1
# EPISODE: 362,  adapt. coeffs at final time step:  [ 3.31 -2.16  1.02  1.01]
# EPISODE: 363 - FINAL SCORE: -131.0
# EPISODE: 363,  adapt. coeffs at final time step:  [ 3.25 -1.85  0.96  0.95]
# EPISODE: 364 - FINAL SCORE: -132.5
# EPISODE: 364,  adapt. coeffs at final time step:  [ 3.34 -2.34  1.06  0.98]
# EPISODE: 365 - FINAL SCORE: -132.0
# EPISODE: 365,  adapt. coeffs at final time step:  [ 3.24 -1.86  0.96  0.99]
# EPISODE: 366 - FINAL SCORE: -134.45
# EPISODE: 366,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.96]
# EPISODE: 367 - FINAL SCORE: -135.1
# EPISODE: 367,  adapt. coeffs at final time step:  [ 3.39 -2.39  1.08  1.01]
# EPISODE: 368 - FINAL SCORE: -138.05
# EPISODE: 368,  adapt. coeffs at final time step:  [ 3.35 -2.35  1.06  1.02]
# EPISODE: 369 - FINAL SCORE: -139.05
# EPISODE: 369,  adapt. coeffs at final time step:  [ 3.3  -2.3   1.04  0.99]
# median:  [ 3.39 -2.32  1.06  0.99]
# EPISODE: 370 - FINAL SCORE: -140.6
# EPISODE: 370,  adapt. coeffs at final time step:  [ 3.4  -2.3   1.06  0.99]
# EPISODE: 371 - FINAL SCORE: -141.2
# EPISODE: 371,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.02]
# EPISODE: 372 - FINAL SCORE: -144.7
# EPISODE: 372,  adapt. coeffs at final time step:  [ 3.38 -2.38  1.07  1.02]
# EPISODE: 373 - FINAL SCORE: -147.15
# EPISODE: 373,  adapt. coeffs at final time step:  [ 3.87 -2.87  1.25  1.01]
# EPISODE: 374 - FINAL SCORE: -146.15
# EPISODE: 374,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.97]
# EPISODE: 375 - FINAL SCORE: -146.1
# EPISODE: 375,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.01]
# EPISODE: 376 - FINAL SCORE: -148.65
# EPISODE: 376,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  0.99]
# EPISODE: 377 - FINAL SCORE: -147.7
# EPISODE: 377,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  0.98]
# EPISODE: 378 - FINAL SCORE: -147.65
# EPISODE: 378,  adapt. coeffs at final time step:  [ 3.87 -2.87  1.25  0.98]
# EPISODE: 379 - FINAL SCORE: -149.2
# EPISODE: 379,  adapt. coeffs at final time step:  [ 3.3  -2.16  1.02  0.96]
# median:  [ 3.39 -2.32  1.06  0.99]
# EPISODE: 380 - FINAL SCORE: -148.65
# EPISODE: 380,  adapt. coeffs at final time step:  [ 3.7  -2.71  1.19  0.97]
# EPISODE: 381 - FINAL SCORE: -150.55
# EPISODE: 381,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.  ]
# EPISODE: 382 - FINAL SCORE: -148.55
# EPISODE: 382,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  0.98]
# EPISODE: 383 - FINAL SCORE: -148.65
# EPISODE: 383,  adapt. coeffs at final time step:  [ 3.35 -1.82  0.98  0.99]
# EPISODE: 384 - FINAL SCORE: -149.4
# EPISODE: 384,  adapt. coeffs at final time step:  [ 3.36 -2.36  1.06  1.01]
# EPISODE: 385 - FINAL SCORE: -148.65
# EPISODE: 385,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.99]
# EPISODE: 386 - FINAL SCORE: -148.45
# EPISODE: 386,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.  ]
# EPISODE: 387 - FINAL SCORE: -147.0
# EPISODE: 387,  adapt. coeffs at final time step:  [ 3.37 -2.25  1.05  1.05]
# EPISODE: 388 - FINAL SCORE: -146.85
# EPISODE: 388,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  1.  ]
# EPISODE: 389 - FINAL SCORE: -145.35
# EPISODE: 389,  adapt. coeffs at final time step:  [ 3.3  -2.17  1.02  1.  ]
# median:  [ 3.38 -2.32  1.06  0.99]
# EPISODE: 390 - FINAL SCORE: -145.55
# EPISODE: 390,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  0.97]
# EPISODE: 391 - FINAL SCORE: -144.1
# EPISODE: 391,  adapt. coeffs at final time step:  [ 3.64 -2.64  1.17  0.98]
# EPISODE: 392 - FINAL SCORE: -141.15
# EPISODE: 392,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.24  1.  ]
# EPISODE: 393 - FINAL SCORE: -141.25
# EPISODE: 393,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  0.99]
# EPISODE: 394 - FINAL SCORE: -142.35
# EPISODE: 394,  adapt. coeffs at final time step:  [ 3.39 -2.39  1.08  1.01]
# EPISODE: 395 - FINAL SCORE: -139.4
# EPISODE: 395,  adapt. coeffs at final time step:  [ 3.25 -2.26  1.03  1.  ]
# EPISODE: 396 - FINAL SCORE: -136.55
# EPISODE: 396,  adapt. coeffs at final time step:  [ 3.87 -2.87  1.25  1.  ]
# EPISODE: 397 - FINAL SCORE: -137.05
# EPISODE: 397,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  1.02]
# EPISODE: 398 - FINAL SCORE: -134.7
# EPISODE: 398,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.19  1.02]
# EPISODE: 399 - FINAL SCORE: -132.9
# EPISODE: 399,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  1.02]
# median:  [ 3.39 -2.32  1.06  0.99]
# EPISODE: 400 - FINAL SCORE: -132.2
# EPISODE: 400,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.02]
# EPISODE: 401 - FINAL SCORE: -128.7
# EPISODE: 401,  adapt. coeffs at final time step:  [ 3.86 -2.87  1.25  1.02]
# EPISODE: 402 - FINAL SCORE: -130.85
# EPISODE: 402,  adapt. coeffs at final time step:  [ 3.39 -2.39  1.08  1.03]
# EPISODE: 403 - FINAL SCORE: -131.5
# EPISODE: 403,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  1.  ]
# EPISODE: 404 - FINAL SCORE: -130.75
# EPISODE: 404,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  0.95]
# EPISODE: 405 - FINAL SCORE: -131.3
# EPISODE: 405,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  0.95]
# EPISODE: 406 - FINAL SCORE: -129.55
# EPISODE: 406,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  0.96]
# EPISODE: 407 - FINAL SCORE: -128.0
# EPISODE: 407,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  0.93]
# EPISODE: 408 - FINAL SCORE: -127.95
# EPISODE: 408,  adapt. coeffs at final time step:  [ 3.88 -2.87  1.25  0.93]
# EPISODE: 409 - FINAL SCORE: -129.2
# EPISODE: 409,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  0.96]
# ...
# EPISODE: 1865 - FINAL SCORE: -113.1
# EPISODE: 1865,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.04]
# EPISODE: 1866 - FINAL SCORE: -110.45
# EPISODE: 1866,  adapt. coeffs at final time step:  [ 3.66 -2.66  1.18  1.01]
# EPISODE: 1867 - FINAL SCORE: -110.6
# EPISODE: 1867,  adapt. coeffs at final time step:  [ 3.38 -2.39  1.07  1.03]
# EPISODE: 1868 - FINAL SCORE: -113.3
# EPISODE: 1868,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.01]
# EPISODE: 1869 - FINAL SCORE: -115.9
# EPISODE: 1869,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.  ]
# median:  [ 3.69 -2.38  1.07  1.  ]
# EPISODE: 1870 - FINAL SCORE: -115.6
# EPISODE: 1870,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.2   1.  ]
# EPISODE: 1871 - FINAL SCORE: -112.3
# EPISODE: 1871,  adapt. coeffs at final time step:  [ 3.31 -2.18  1.03  1.  ]
# EPISODE: 1872 - FINAL SCORE: -111.4
# EPISODE: 1872,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.19  1.  ]
# EPISODE: 1873 - FINAL SCORE: -113.95
# EPISODE: 1873,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.96]
# EPISODE: 1874 - FINAL SCORE: -113.95
# EPISODE: 1874,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  0.98]
# EPISODE: 1875 - FINAL SCORE: -114.6
# EPISODE: 1875,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.19  0.97]
# EPISODE: 1876 - FINAL SCORE: -117.6
# EPISODE: 1876,  adapt. coeffs at final time step:  [ 3.39 -2.39  1.08  1.01]
# EPISODE: 1877 - FINAL SCORE: -118.15
# EPISODE: 1877,  adapt. coeffs at final time step:  [ 3.66 -2.66  1.18  1.  ]
# EPISODE: 1878 - FINAL SCORE: -121.55
# EPISODE: 1878,  adapt. coeffs at final time step:  [ 3.8  -1.75  1.05  1.01]
# EPISODE: 1879 - FINAL SCORE: -122.3
# EPISODE: 1879,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  1.04]
# median:  [ 3.69 -2.38  1.07  1.  ]
# EPISODE: 1880 - FINAL SCORE: -118.7
# EPISODE: 1880,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  1.03]
# EPISODE: 1881 - FINAL SCORE: -119.05
# EPISODE: 1881,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  1.  ]
# EPISODE: 1882 - FINAL SCORE: -118.75
# EPISODE: 1882,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.99]
# EPISODE: 1883 - FINAL SCORE: -120.65
# EPISODE: 1883,  adapt. coeffs at final time step:  [ 3.81 -1.75  1.05  1.02]
# EPISODE: 1884 - FINAL SCORE: -119.7
# EPISODE: 1884,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  0.99]
# EPISODE: 1885 - FINAL SCORE: -119.55
# EPISODE: 1885,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  0.99]
# EPISODE: 1886 - FINAL SCORE: -121.45
# EPISODE: 1886,  adapt. coeffs at final time step:  [ 3.69 -1.76  1.03  1.01]
# EPISODE: 1887 - FINAL SCORE: -118.15
# EPISODE: 1887,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  1.01]
# EPISODE: 1888 - FINAL SCORE: -114.6
# EPISODE: 1888,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.01]
# EPISODE: 1889 - FINAL SCORE: -112.15
# EPISODE: 1889,  adapt. coeffs at final time step:  [ 3.83 -2.83  1.24  1.01]
# median:  [ 3.69 -2.38  1.07  1.  ]
# EPISODE: 1890 - FINAL SCORE: -111.25
# EPISODE: 1890,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.01]
# EPISODE: 1891 - FINAL SCORE: -110.15
# EPISODE: 1891,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.01]
# EPISODE: 1892 - FINAL SCORE: -112.9
# EPISODE: 1892,  adapt. coeffs at final time step:  [ 3.33 -2.33  1.05  1.02]
# EPISODE: 1893 - FINAL SCORE: -113.1
# EPISODE: 1893,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.  ]
# EPISODE: 1894 - FINAL SCORE: -115.35
# EPISODE: 1894,  adapt. coeffs at final time step:  [ 3.85 -2.84  1.24  0.98]
# EPISODE: 1895 - FINAL SCORE: -117.9
# EPISODE: 1895,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  0.99]
# EPISODE: 1896 - FINAL SCORE: -118.45
# EPISODE: 1896,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.95]
# EPISODE: 1897 - FINAL SCORE: -118.4
# EPISODE: 1897,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.01]
# EPISODE: 1898 - FINAL SCORE: -115.95
# EPISODE: 1898,  adapt. coeffs at final time step:  [ 3.32 -2.31  1.05  1.04]
# EPISODE: 1899 - FINAL SCORE: -114.95
# EPISODE: 1899,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  1.04]
# median:  [ 3.69 -2.38  1.07  1.  ]
# EPISODE: 1900 - FINAL SCORE: -116.0
# EPISODE: 1900,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.07]
# EPISODE: 1901 - FINAL SCORE: -113.8
# EPISODE: 1901,  adapt. coeffs at final time step:  [ 3.32 -2.31  1.05  1.08]
# EPISODE: 1902 - FINAL SCORE: -114.95
# EPISODE: 1902,  adapt. coeffs at final time step:  [ 3.37 -2.37  1.07  1.1 ]
# EPISODE: 1903 - FINAL SCORE: -112.5
# EPISODE: 1903,  adapt. coeffs at final time step:  [ 3.72 -2.72  1.2   1.1 ]
# EPISODE: 1904 - FINAL SCORE: -115.5
# EPISODE: 1904,  adapt. coeffs at final time step:  [ 3.33 -2.33  1.05  1.06]
# EPISODE: 1905 - FINAL SCORE: -115.6
# EPISODE: 1905,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.08]
# EPISODE: 1906 - FINAL SCORE: -113.35
# EPISODE: 1906,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.2   1.08]
# EPISODE: 1907 - FINAL SCORE: -114.0
# EPISODE: 1907,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.08]
# EPISODE: 1908 - FINAL SCORE: -115.55
# EPISODE: 1908,  adapt. coeffs at final time step:  [ 3.83 -2.84  1.24  1.08]
# EPISODE: 1909 - FINAL SCORE: -116.1
# EPISODE: 1909,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.11]
# median:  [ 3.69 -2.38  1.07  1.  ]
# EPISODE: 1910 - FINAL SCORE: -117.25
# EPISODE: 1910,  adapt. coeffs at final time step:  [ 3.32 -2.31  1.05  1.11]
# EPISODE: 1911 - FINAL SCORE: -120.6
# EPISODE: 1911,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  1.05]
# EPISODE: 1912 - FINAL SCORE: -118.1
# EPISODE: 1912,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.19  1.05]
# EPISODE: 1913 - FINAL SCORE: -115.15
# EPISODE: 1913,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  1.06]
# EPISODE: 1914 - FINAL SCORE: -111.75
# EPISODE: 1914,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  1.05]
# EPISODE: 1915 - FINAL SCORE: -112.25
# EPISODE: 1915,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  0.98]
# EPISODE: 1916 - FINAL SCORE: -109.2
# EPISODE: 1916,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.03]
# EPISODE: 1917 - FINAL SCORE: -109.25
# EPISODE: 1917,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.02  1.01]
# EPISODE: 1918 - FINAL SCORE: -111.6
# EPISODE: 1918,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# EPISODE: 1919 - FINAL SCORE: -115.15
# EPISODE: 1919,  adapt. coeffs at final time step:  [ 3.39 -2.39  1.08  1.01]
# median:  [ 3.69 -2.38  1.07  1.  ]
# EPISODE: 1920 - FINAL SCORE: -115.15
# EPISODE: 1920,  adapt. coeffs at final time step:  [ 3.32 -2.31  1.05  1.04]
# EPISODE: 1921 - FINAL SCORE: -117.0
# EPISODE: 1921,  adapt. coeffs at final time step:  [ 3.35 -2.35  1.06  0.99]
# EPISODE: 1922 - FINAL SCORE: -116.0
# EPISODE: 1922,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.99]
# EPISODE: 1923 - FINAL SCORE: -118.75
# EPISODE: 1923,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  0.98]
# EPISODE: 1924 - FINAL SCORE: -116.65
# EPISODE: 1924,  adapt. coeffs at final time step:  [ 3.31 -2.32  1.05  1.02]
# EPISODE: 1925 - FINAL SCORE: -119.0
# EPISODE: 1925,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  0.99]
# EPISODE: 1926 - FINAL SCORE: -118.8
# EPISODE: 1926,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.2   0.99]
# EPISODE: 1927 - FINAL SCORE: -119.25
# EPISODE: 1927,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.03]
# EPISODE: 1928 - FINAL SCORE: -120.4
# EPISODE: 1928,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  1.02]
# EPISODE: 1929 - FINAL SCORE: -120.3
# EPISODE: 1929,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.02]
# median:  [ 3.69 -2.38  1.07  1.  ]
# EPISODE: 1930 - FINAL SCORE: -120.3
# EPISODE: 1930,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  1.01]
# EPISODE: 1931 - FINAL SCORE: -118.0
# EPISODE: 1931,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.19  1.01]
# EPISODE: 1932 - FINAL SCORE: -120.5
# EPISODE: 1932,  adapt. coeffs at final time step:  [ 3.33 -2.33  1.05  1.02]
# EPISODE: 1933 - FINAL SCORE: -121.6
# EPISODE: 1933,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.03]
# EPISODE: 1934 - FINAL SCORE: -124.55
# EPISODE: 1934,  adapt. coeffs at final time step:  [ 3.33 -2.33  1.05  1.  ]
# EPISODE: 1935 - FINAL SCORE: -121.95
# EPISODE: 1935,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  1.  ]
# EPISODE: 1936 - FINAL SCORE: -121.85
# EPISODE: 1936,  adapt. coeffs at final time step:  [ 3.66 -2.66  1.18  1.  ]
# EPISODE: 1937 - FINAL SCORE: -120.75
# EPISODE: 1937,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  1.  ]
# EPISODE: 1938 - FINAL SCORE: -117.35
# EPISODE: 1938,  adapt. coeffs at final time step:  [ 3.86 -2.85  1.25  1.  ]
# EPISODE: 1939 - FINAL SCORE: -113.65
# EPISODE: 1939,  adapt. coeffs at final time step:  [ 3.87 -2.86  1.25  1.  ]
# median:  [ 3.69 -2.38  1.07  1.  ]
# EPISODE: 1940 - FINAL SCORE: -112.75
# EPISODE: 1940,  adapt. coeffs at final time step:  [ 3.87 -2.86  1.25  1.  ]
# EPISODE: 1941 - FINAL SCORE: -112.85
# EPISODE: 1941,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.  ]
# EPISODE: 1942 - FINAL SCORE: -112.7
# EPISODE: 1942,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  0.99]
# EPISODE: 1943 - FINAL SCORE: -112.8
# EPISODE: 1943,  adapt. coeffs at final time step:  [ 3.33 -2.33  1.05  1.01]
# EPISODE: 1944 - FINAL SCORE: -112.85
# EPISODE: 1944,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.03]
# EPISODE: 1945 - FINAL SCORE: -110.55
# EPISODE: 1945,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.04]
# EPISODE: 1946 - FINAL SCORE: -110.1
# EPISODE: 1946,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  1.04]
# EPISODE: 1947 - FINAL SCORE: -109.05
# EPISODE: 1947,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.04]
# EPISODE: 1948 - FINAL SCORE: -109.3
# EPISODE: 1948,  adapt. coeffs at final time step:  [ 3.33 -2.33  1.05  1.03]
# EPISODE: 1949 - FINAL SCORE: -108.55
# EPISODE: 1949,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  1.01]
# median:  [ 3.69 -2.38  1.07  1.  ]
# EPISODE: 1950 - FINAL SCORE: -108.05
# EPISODE: 1950,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.01]
# EPISODE: 1951 - FINAL SCORE: -108.1
# EPISODE: 1951,  adapt. coeffs at final time step:  [ 3.25 -2.26  1.03  1.  ]
# EPISODE: 1952 - FINAL SCORE: -106.05
# EPISODE: 1952,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.19  1.  ]
# EPISODE: 1953 - FINAL SCORE: -105.85
# EPISODE: 1953,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.  ]
# EPISODE: 1954 - FINAL SCORE: -106.1
# EPISODE: 1954,  adapt. coeffs at final time step:  [ 3.33 -2.33  1.05  1.01]
# EPISODE: 1955 - FINAL SCORE: -109.7
# EPISODE: 1955,  adapt. coeffs at final time step:  [ 3.33 -2.33  1.05  1.03]
# EPISODE: 1956 - FINAL SCORE: -108.6
# EPISODE: 1956,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  1.02]
# EPISODE: 1957 - FINAL SCORE: -110.0
# EPISODE: 1957,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.02]
# EPISODE: 1958 - FINAL SCORE: -113.1
# EPISODE: 1958,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.02]
# EPISODE: 1959 - FINAL SCORE: -116.3
# EPISODE: 1959,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.01]
# median:  [ 3.69 -2.38  1.07  1.  ]
# EPISODE: 1960 - FINAL SCORE: -118.8
# EPISODE: 1960,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  0.97]
# EPISODE: 1961 - FINAL SCORE: -119.15
# EPISODE: 1961,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  0.97]
# EPISODE: 1962 - FINAL SCORE: -123.25
# EPISODE: 1962,  adapt. coeffs at final time step:  [ 3.36 -2.36  1.07  1.04]
# EPISODE: 1963 - FINAL SCORE: -122.8
# EPISODE: 1963,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.02]
# EPISODE: 1964 - FINAL SCORE: -122.2
# EPISODE: 1964,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.2   1.01]
# EPISODE: 1965 - FINAL SCORE: -125.2
# EPISODE: 1965,  adapt. coeffs at final time step:  [ 3.38 -2.38  1.07  1.02]
# EPISODE: 1966 - FINAL SCORE: -126.25
# EPISODE: 1966,  adapt. coeffs at final time step:  [ 3.37 -2.25  1.05  1.02]
# EPISODE: 1967 - FINAL SCORE: -127.3
# EPISODE: 1967,  adapt. coeffs at final time step:  [ 3.32 -2.31  1.05  1.05]
# EPISODE: 1968 - FINAL SCORE: -124.35
# EPISODE: 1968,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.2   1.04]
# EPISODE: 1969 - FINAL SCORE: -127.2
# EPISODE: 1969,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  1.01]
# median:  [ 3.69 -2.38  1.07  1.  ]
# EPISODE: 1970 - FINAL SCORE: -126.6
# EPISODE: 1970,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.01]
# EPISODE: 1971 - FINAL SCORE: -128.4
# EPISODE: 1971,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  1.02]
# EPISODE: 1972 - FINAL SCORE: -130.4
# EPISODE: 1972,  adapt. coeffs at final time step:  [ 3.4  -2.3   1.06  1.  ]
# EPISODE: 1973 - FINAL SCORE: -130.05
# EPISODE: 1973,  adapt. coeffs at final time step:  [ 3.72 -2.72  1.2   1.  ]
# EPISODE: 1974 - FINAL SCORE: -127.0
# EPISODE: 1974,  adapt. coeffs at final time step:  [ 3.86 -2.85  1.25  1.  ]
# EPISODE: 1975 - FINAL SCORE: -123.4
# EPISODE: 1975,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.04]
# EPISODE: 1976 - FINAL SCORE: -126.35
# EPISODE: 1976,  adapt. coeffs at final time step:  [ 3.35 -2.35  1.06  1.01]
# EPISODE: 1977 - FINAL SCORE: -126.1
# EPISODE: 1977,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.02]
# EPISODE: 1978 - FINAL SCORE: -124.15
# EPISODE: 1978,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.03]
# EPISODE: 1979 - FINAL SCORE: -121.1
# EPISODE: 1979,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.03]
# median:  [ 3.69 -2.38  1.07  1.  ]
# EPISODE: 1980 - FINAL SCORE: -119.6
# EPISODE: 1980,  adapt. coeffs at final time step:  [ 3.37 -2.25  1.05  1.03]
# EPISODE: 1981 - FINAL SCORE: -117.4
# EPISODE: 1981,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.03]
# EPISODE: 1982 - FINAL SCORE: -114.5
# EPISODE: 1982,  adapt. coeffs at final time step:  [ 3.37 -2.25  1.05  1.03]
# EPISODE: 1983 - FINAL SCORE: -115.4
# EPISODE: 1983,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  0.98]
# EPISODE: 1984 - FINAL SCORE: -116.05
# EPISODE: 1984,  adapt. coeffs at final time step:  [ 3.37 -2.25  1.05  1.01]
# EPISODE: 1985 - FINAL SCORE: -115.1
# EPISODE: 1985,  adapt. coeffs at final time step:  [ 3.87 -2.87  1.25  1.02]
# EPISODE: 1986 - FINAL SCORE: -115.05
# EPISODE: 1986,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.06]
# EPISODE: 1987 - FINAL SCORE: -115.0
# EPISODE: 1987,  adapt. coeffs at final time step:  [ 3.66 -2.66  1.18  1.04]
# EPISODE: 1988 - FINAL SCORE: -117.6
# EPISODE: 1988,  adapt. coeffs at final time step:  [ 3.39 -2.39  1.08  1.05]
# EPISODE: 1989 - FINAL SCORE: -114.75
# EPISODE: 1989,  adapt. coeffs at final time step:  [ 3.72 -2.72  1.2   1.05]
# median:  [ 3.69 -2.38  1.07  1.  ]
# EPISODE: 1990 - FINAL SCORE: -115.85
# EPISODE: 1990,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.08]
# EPISODE: 1991 - FINAL SCORE: -113.25
# EPISODE: 1991,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.2   1.08]
# EPISODE: 1992 - FINAL SCORE: -111.05
# EPISODE: 1992,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.08]
# EPISODE: 1993 - FINAL SCORE: -113.3
# EPISODE: 1993,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# EPISODE: 1994 - FINAL SCORE: -114.25
# EPISODE: 1994,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.02]
# EPISODE: 1995 - FINAL SCORE: -113.2
# EPISODE: 1995,  adapt. coeffs at final time step:  [ 3.69 -2.69  1.19  1.01]
# EPISODE: 1996 - FINAL SCORE: -111.35
# EPISODE: 1996,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.06]
# EPISODE: 1997 - FINAL SCORE: -110.2
# EPISODE: 1997,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.05]
# EPISODE: 1998 - FINAL SCORE: -110.15
# EPISODE: 1998,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.08]
# EPISODE: 1999 - FINAL SCORE: -111.6
# EPISODE: 1999,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.08]
# median:  [ 3.69 -2.38  1.07  1.  ]
# Best Episode:1011; Best Score:-83.0

# %%
print("=====")
print("mean: ", (np.array(ploting_adapt_coeff)).mean(axis=0).round(2))
print("median: ", np.median(np.array(ploting_adapt_coeff), axis=0))
# Out:
# =====
# mean:  [ 3.56 -2.48  1.13  1.  ]
# median:  [ 3.69 -2.38  1.07  1.  ]

# %%
# Test
# Test
#save_observation_temp = []
#save_u1_temp = []
#save_pid_u1_temp = []
#save_ctrl_voltage_temp = []
plotting_rewards_test = []
total_episodes_test = 100
best_score = -300
epsilon = 1e-3

# %%
print('Test')
#for e_ in range(ep):
episode_n = 0
best_episode = 0
while(episode_n<total_episodes_test):
  S, infor = env.reset()
  A = policy(S, q_hat, epsilon)
  save_observation_temp = [S]
  save_wanted_force_temp = [0.0]
  save_actual_force_temp = [0.0]
  save_model_force_temp = [0.0]
  save_ctrl_voltage_temp = [0.0]
  save_MRAC_adapt_gains_temp= [env.MRAC.k_hat]
  score = 0
  #for t_ in range(200): #10**100
  t_=0
  while(t_<200) and (episode_n<total_episodes_test):
    k_hat_print = env.MRAC.k_hat.round(2)
    infor = env.step(A)
    S_= infor[0]
    R = infor[1]
    done = infor[2]
    wanted_force=infor[4]
    actual_force=infor[5]
    ##
    save_observation_temp.append(S_)
    save_wanted_force_temp.append(wanted_force)
    save_actual_force_temp.append(actual_force)
    save_model_force_temp.append(env.MRAC.y_m)
    save_ctrl_voltage_temp.append(env.MRAC.u)
    save_MRAC_adapt_gains_temp.append(env.MRAC.k_hat)
    score += R
    if done or ((t_+1)%200==0):
      plotting_rewards_test.append(score)
      print(f"EPISODE: {episode_n} - FINAL SCORE: {score} ") # Print the final score
      print(f"EPISODE: {episode_n}, ", "adapt. coeffs at final time step: ", k_hat_print)
      if best_score < score:
        best_score = score
        best_episode = episode_n
        save_observation = list(save_observation_temp)
        save_wanted_force = list(save_wanted_force_temp)
        save_actual_force = list(save_actual_force_temp)
        save_model_force = list(save_model_force_temp)
        save_ctrl_voltage = list(save_ctrl_voltage_temp)
        save_MRAC_adapt_gains = list(save_MRAC_adapt_gains_temp)
        print(f"Best Episode:{best_episode}; Best Score:{best_score}")
      #end if
      episode_n+=1
      score = 0
    #end if
    if done:
      break
    #end if
    A_ = policy(S_, q_hat, epsilon)
    S, A = S_, A_
    t_+=1
  #end while
#end while
print(f"Best Episode:{best_episode}; Best Score:{best_score}")
# Out:
# Test
# EPISODE: 0 - FINAL SCORE: -106.0
# EPISODE: 0,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.08]
# Best Episode:0; Best Score:-106.0
# EPISODE: 1 - FINAL SCORE: -105.0
# EPISODE: 1,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.08]
# Best Episode:1; Best Score:-105.0
# EPISODE: 2 - FINAL SCORE: -89.0
# EPISODE: 2,  adapt. coeffs at final time step:  [ 3.86 -2.85  1.25  1.08]
# Best Episode:2; Best Score:-89.0
# EPISODE: 3 - FINAL SCORE: -107.0
# EPISODE: 3,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.11]
# EPISODE: 4 - FINAL SCORE: -107.0
# EPISODE: 4,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.09]
# EPISODE: 5 - FINAL SCORE: -107.0
# EPISODE: 5,  adapt. coeffs at final time step:  [ 3.87 -2.86  1.25  1.09]
# EPISODE: 6 - FINAL SCORE: -108.0
# EPISODE: 6,  adapt. coeffs at final time step:  [ 3.37 -2.25  1.05  1.05]
# EPISODE: 7 - FINAL SCORE: -109.0
# EPISODE: 7,  adapt. coeffs at final time step:  [ 3.37 -2.37  1.07  1.05]
# EPISODE: 8 - FINAL SCORE: -109.0
# EPISODE: 8,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.03]
# EPISODE: 9 - FINAL SCORE: -86.0
# EPISODE: 9,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.03]
# Best Episode:9; Best Score:-86.0
# EPISODE: 10 - FINAL SCORE: -106.0
# EPISODE: 10,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.03]
# EPISODE: 11 - FINAL SCORE: -109.0
# EPISODE: 11,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.03]
# EPISODE: 12 - FINAL SCORE: -106.0
# EPISODE: 12,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.02]
# EPISODE: 13 - FINAL SCORE: -106.0
# EPISODE: 13,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.03]
# EPISODE: 14 - FINAL SCORE: -108.0
# EPISODE: 14,  adapt. coeffs at final time step:  [ 3.37 -2.25  1.05  1.03]
# EPISODE: 15 - FINAL SCORE: -108.0
# EPISODE: 15,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.03]
# EPISODE: 16 - FINAL SCORE: -95.0
# EPISODE: 16,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.2   1.03]
# EPISODE: 17 - FINAL SCORE: -85.0
# EPISODE: 17,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  1.02]
# Best Episode:17; Best Score:-85.0
# EPISODE: 18 - FINAL SCORE: -106.0
# EPISODE: 18,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.03]
# EPISODE: 19 - FINAL SCORE: -85.0
# EPISODE: 19,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.03]
# EPISODE: 20 - FINAL SCORE: -99.0
# EPISODE: 20,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.03]
# EPISODE: 21 - FINAL SCORE: -87.0
# EPISODE: 21,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.03]
# EPISODE: 22 - FINAL SCORE: -106.0
# EPISODE: 22,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.08]
# EPISODE: 23 - FINAL SCORE: -106.0
# EPISODE: 23,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.06]
# EPISODE: 24 - FINAL SCORE: -106.0
# EPISODE: 24,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.1 ]
# EPISODE: 25 - FINAL SCORE: -106.0
# EPISODE: 25,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.08]
# EPISODE: 26 - FINAL SCORE: -108.0
# EPISODE: 26,  adapt. coeffs at final time step:  [ 3.37 -2.25  1.05  1.04]
# EPISODE: 27 - FINAL SCORE: -86.0
# EPISODE: 27,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.03]
# EPISODE: 28 - FINAL SCORE: -87.0
# EPISODE: 28,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.03]
# EPISODE: 29 - FINAL SCORE: -109.0
# EPISODE: 29,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.03]
# EPISODE: 30 - FINAL SCORE: -107.0
# EPISODE: 30,  adapt. coeffs at final time step:  [ 3.32 -2.31  1.05  1.06]
# EPISODE: 31 - FINAL SCORE: -108.0
# EPISODE: 31,  adapt. coeffs at final time step:  [ 3.37 -2.25  1.05  1.03]
# EPISODE: 32 - FINAL SCORE: -90.0
# EPISODE: 32,  adapt. coeffs at final time step:  [ 3.71 -1.75  1.03  1.04]
# EPISODE: 33 - FINAL SCORE: -107.0
# EPISODE: 33,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.02]
# EPISODE: 34 - FINAL SCORE: -107.0
# EPISODE: 34,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.03]
# EPISODE: 35 - FINAL SCORE: -107.0
# EPISODE: 35,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.06]
# EPISODE: 36 - FINAL SCORE: -107.0
# EPISODE: 36,  adapt. coeffs at final time step:  [ 3.32 -2.31  1.05  1.07]
# EPISODE: 37 - FINAL SCORE: -182.0
# EPISODE: 37,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  0.95]
# EPISODE: 38 - FINAL SCORE: -99.0
# EPISODE: 38,  adapt. coeffs at final time step:  [ 3.71 -2.7   1.19  0.97]
# EPISODE: 39 - FINAL SCORE: -90.0
# EPISODE: 39,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  0.97]
# EPISODE: 40 - FINAL SCORE: -108.0
# EPISODE: 40,  adapt. coeffs at final time step:  [ 3.37 -2.25  1.05  1.02]
# EPISODE: 41 - FINAL SCORE: -106.0
# EPISODE: 41,  adapt. coeffs at final time step:  [ 3.66 -2.66  1.18  1.01]
# EPISODE: 42 - FINAL SCORE: -106.0
# EPISODE: 42,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.01]
# EPISODE: 43 - FINAL SCORE: -87.0
# EPISODE: 43,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.01]
# EPISODE: 44 - FINAL SCORE: -105.0
# EPISODE: 44,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.02]
# EPISODE: 45 - FINAL SCORE: -105.0
# EPISODE: 45,  adapt. coeffs at final time step:  [ 3.83 -2.83  1.24  1.02]
# EPISODE: 46 - FINAL SCORE: -93.0
# EPISODE: 46,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.24  1.02]
# EPISODE: 47 - FINAL SCORE: -108.0
# EPISODE: 47,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.03]
# EPISODE: 48 - FINAL SCORE: -85.0
# EPISODE: 48,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.03]
# EPISODE: 49 - FINAL SCORE: -99.0
# EPISODE: 49,  adapt. coeffs at final time step:  [ 3.83 -2.83  1.24  1.03]
# EPISODE: 50 - FINAL SCORE: -86.0
# EPISODE: 50,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.03]
# EPISODE: 51 - FINAL SCORE: -106.0
# EPISODE: 51,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.04]
# EPISODE: 52 - FINAL SCORE: -85.0
# EPISODE: 52,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.04]
# EPISODE: 53 - FINAL SCORE: -108.0
# EPISODE: 53,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.04]
# EPISODE: 54 - FINAL SCORE: -108.0
# EPISODE: 54,  adapt. coeffs at final time step:  [ 3.37 -2.25  1.05  1.03]
# EPISODE: 55 - FINAL SCORE: -86.0
# EPISODE: 55,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.03]
# EPISODE: 56 - FINAL SCORE: -107.0
# EPISODE: 56,  adapt. coeffs at final time step:  [ 3.7  -2.7   1.19  1.02]
# EPISODE: 57 - FINAL SCORE: -92.0
# EPISODE: 57,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.02]
# EPISODE: 58 - FINAL SCORE: -98.0
# EPISODE: 58,  adapt. coeffs at final time step:  [ 3.83 -2.83  1.24  1.02]
# EPISODE: 59 - FINAL SCORE: -106.0
# EPISODE: 59,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.03]
# EPISODE: 60 - FINAL SCORE: -115.0
# EPISODE: 60,  adapt. coeffs at final time step:  [ 3.85 -2.86  1.25  1.03]
# EPISODE: 61 - FINAL SCORE: -106.0
# EPISODE: 61,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.03]
# EPISODE: 62 - FINAL SCORE: -88.0
# EPISODE: 62,  adapt. coeffs at final time step:  [ 3.87 -2.86  1.25  1.04]
# EPISODE: 63 - FINAL SCORE: -107.0
# EPISODE: 63,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.05]
# EPISODE: 64 - FINAL SCORE: -106.0
# EPISODE: 64,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.04]
# EPISODE: 65 - FINAL SCORE: -99.0
# EPISODE: 65,  adapt. coeffs at final time step:  [ 3.85 -2.86  1.25  1.04]
# EPISODE: 66 - FINAL SCORE: -84.0
# EPISODE: 66,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.04]
# Best Episode:66; Best Score:-84.0
# EPISODE: 67 - FINAL SCORE: -107.0
# EPISODE: 67,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.06]
# EPISODE: 68 - FINAL SCORE: -103.0
# EPISODE: 68,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.2   1.06]
# EPISODE: 69 - FINAL SCORE: -108.0
# EPISODE: 69,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.05]
# EPISODE: 70 - FINAL SCORE: -107.0
# EPISODE: 70,  adapt. coeffs at final time step:  [ 3.32 -2.31  1.05  1.07]
# EPISODE: 71 - FINAL SCORE: -106.0
# EPISODE: 71,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.05]
# EPISODE: 72 - FINAL SCORE: -107.0
# EPISODE: 72,  adapt. coeffs at final time step:  [ 3.63 -2.63  1.16  1.02]
# EPISODE: 73 - FINAL SCORE: -85.0
# EPISODE: 73,  adapt. coeffs at final time step:  [ 3.83 -2.83  1.24  1.02]
# EPISODE: 74 - FINAL SCORE: -107.0
# EPISODE: 74,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.03]
# EPISODE: 75 - FINAL SCORE: -90.0
# EPISODE: 75,  adapt. coeffs at final time step:  [ 3.83 -2.83  1.24  1.03]
# EPISODE: 76 - FINAL SCORE: -107.0
# EPISODE: 76,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.06]
# EPISODE: 77 - FINAL SCORE: -107.0
# EPISODE: 77,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.2   1.06]
# EPISODE: 78 - FINAL SCORE: -104.0
# EPISODE: 78,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.06]
# EPISODE: 79 - FINAL SCORE: -107.0
# EPISODE: 79,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  1.04]
# EPISODE: 80 - FINAL SCORE: -108.0
# EPISODE: 80,  adapt. coeffs at final time step:  [ 3.37 -2.25  1.05  1.03]
# EPISODE: 81 - FINAL SCORE: -86.0
# EPISODE: 81,  adapt. coeffs at final time step:  [ 3.84 -2.84  1.24  1.03]
# EPISODE: 82 - FINAL SCORE: -84.0
# EPISODE: 82,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.03]
# EPISODE: 83 - FINAL SCORE: -107.0
# EPISODE: 83,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.07]
# EPISODE: 84 - FINAL SCORE: -146.0
# EPISODE: 84,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.2   1.07]
# EPISODE: 85 - FINAL SCORE: -107.0
# EPISODE: 85,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.1 ]
# EPISODE: 86 - FINAL SCORE: -107.0
# EPISODE: 86,  adapt. coeffs at final time step:  [ 3.32 -2.31  1.05  1.09]
# EPISODE: 87 - FINAL SCORE: -89.0
# EPISODE: 87,  adapt. coeffs at final time step:  [ 3.8  -2.8   1.23  1.08]
# EPISODE: 88 - FINAL SCORE: -88.0
# EPISODE: 88,  adapt. coeffs at final time step:  [ 3.86 -2.86  1.25  1.08]
# EPISODE: 89 - FINAL SCORE: -106.0
# EPISODE: 89,  adapt. coeffs at final time step:  [ 3.86 -2.85  1.25  1.09]
# EPISODE: 90 - FINAL SCORE: -106.0
# EPISODE: 90,  adapt. coeffs at final time step:  [ 3.86 -2.85  1.25  1.09]
# EPISODE: 91 - FINAL SCORE: -85.0
# EPISODE: 91,  adapt. coeffs at final time step:  [ 3.87 -2.86  1.25  1.09]
# EPISODE: 92 - FINAL SCORE: -106.0
# EPISODE: 92,  adapt. coeffs at final time step:  [ 3.86 -2.85  1.25  1.09]
# EPISODE: 93 - FINAL SCORE: -108.0
# EPISODE: 93,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.06]
# EPISODE: 94 - FINAL SCORE: -107.0
# EPISODE: 94,  adapt. coeffs at final time step:  [ 3.32 -2.31  1.05  1.08]
# EPISODE: 95 - FINAL SCORE: -107.0
# EPISODE: 95,  adapt. coeffs at final time step:  [ 3.32 -2.31  1.05  1.08]
# EPISODE: 96 - FINAL SCORE: -106.0
# EPISODE: 96,  adapt. coeffs at final time step:  [ 3.85 -2.85  1.25  1.06]
# EPISODE: 97 - FINAL SCORE: -97.0
# EPISODE: 97,  adapt. coeffs at final time step:  [ 3.85 -2.86  1.25  1.06]
# EPISODE: 98 - FINAL SCORE: -106.0
# EPISODE: 98,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  1.1 ]
# EPISODE: 99 - FINAL SCORE: -96.0
# EPISODE: 99,  adapt. coeffs at final time step:  [ 3.71 -2.71  1.2   1.1 ]
# Best Episode:66; Best Score:-84.0

# %%
save_observation_temp = None
save_wanted_force_temp = None
save_actual_force_temp = None
save_model_force_temp = None
save_ctrl_voltage_temp = None
save_MRAC_adapt_gains_temp= None

# %%
# Create a dictionary of variables you want to save

variables_to_save = {
    'plotting_rewards': plotting_rewards,
    'avg_reward_list': avg_reward_list,
    'save_observation': save_observation,
    'save_wanted_force': save_wanted_force,
    'save_actual_force': save_actual_force,
    'save_model_force': save_model_force,
    'save_ctrl_voltage': save_ctrl_voltage,
    'q_hat': q_hat,
    'plotting_rewards_test':plotting_rewards_test,
    'save_MRAC_adapt_gains': save_MRAC_adapt_gains,
    'ploting_adapt_coeff': ploting_adapt_coeff

}

# %%
with open(path+'Disc_Moun_Car.pkl', 'wb') as f:
    pickle.dump(variables_to_save, f)
print(f"All variables saved to {path+'Disc_Moun_Car.pkl'}")
# Out:
# All variables saved to /content/drive/MyDrive/Colab Notebooks/codes/MRAC/save_data/Disc_Moun_Car/Disc_Moun_Car.pkl

# %%
path = '/content/drive/MyDrive/Colab Notebooks/codes/MRAC/save_data/Disc_Moun_Car/'

# %%
# Open the file in read-binary mode and load the dictionary
with open(path+'Disc_Moun_Car.pkl', 'rb') as f:
    loaded_variables = pickle.load(f)

# Access the loaded variables
plotting_rewards = loaded_variables['plotting_rewards']
avg_reward_list = loaded_variables['avg_reward_list']
save_observation = loaded_variables['save_observation']
save_wanted_force = loaded_variables['save_wanted_force']
save_actual_force = loaded_variables['save_actual_force']
save_model_force = loaded_variables['save_model_force']
save_ctrl_voltage = loaded_variables['save_ctrl_voltage']
q_hat = loaded_variables['q_hat']
plotting_rewards_test = loaded_variables['plotting_rewards_test']
ploting_adapt_coeff = loaded_variables['ploting_adapt_coeff']
save_MRAC_adapt_gains = loaded_variables['save_MRAC_adapt_gains']

# %%
plt.rc('text.latex', preamble=r'\usepackage{amsmath,amssymb,amsfonts}')
#plt.rcParams["text.usetex"]=False
#plt.rcParams["font.family"] = "sans-serif"
#plt.rcParams["font.family"] = "serif"
#plt.rcParams['mathtext.fontset'] = 'cm'
#plt.rcParams['mathtext.fontset'] = 'dejavusans'
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'

# %%
def unnorm_to_norm(x):
  y = (x-low_bound_reward_list)/(up_bound_reward_list-low_bound_reward_list)
  return y

# %%
def norm_to_unnorm(y):
  x=y*(up_bound_reward_list-low_bound_reward_list)+low_bound_reward_list
  return x

# %%
low_bound_reward_list = -200
up_bound_reward_list = 0
print("low_bound_reward_list=",low_bound_reward_list)
print("up_bound_reward_list=",up_bound_reward_list)
norm_reward_list = np.array(avg_reward_list)
norm_reward_list = unnorm_to_norm(norm_reward_list)
# Out:
# low_bound_reward_list= -200
# up_bound_reward_list= 0

# %%
import matplotlib.pyplot as plt

font = {'size': 20}
plt.rc('font', **font)
plt.plot(plotting_rewards)
plt.xlabel('Training episodes',fontsize=20)
plt.ylabel('Acc. Episodic Reward',fontsize=20)
#plt.rc('axes', labelsize=30)

plt.grid()
#plt.legend()
plt.title('Discrete_mountain_car',fontsize=20)
plt.show()

# %%
N=50

# %%
# Compute the moving average of the last 50 numbers
moving_average = []
for i, n in enumerate(plotting_rewards):
    if i < N:
        # If there are not enough previous elements,
        # append the average of all available elements
        avg = sum(plotting_rewards[:i+1]) / (i+1)
    else:
        # Otherwise, compute the average of the previous 5 elements
        avg = sum(plotting_rewards[i-N:i+1]) / N
    moving_average.append(avg)

# Plot the moving average
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(6)
f.set_figheight(4)

#plt.plot(moving_average)
plt.plot(moving_average, label = "Avg. Epsiodic Reward",color="C0",linewidth = 1.5)
plt.axhline(y=np.array(moving_average)[-N:-1].mean(), linestyle='--',
            label = "Avg. Epsiodic Reward's last " +str(N) +" mean="+f"{np.array(moving_average)[-N:-1].mean():.1f}",color="C1",linewidth = 2.5)

plt.xlabel('Training episodes',fontsize=20)
plt.ylabel('Acc. Episodic Reward',fontsize=20)

plt.grid()
plt.legend(fontsize=12)
#plt.title('Discrete mountain car Avg',fontsize=20)
plt.title('Discrete Mountain Car',fontsize=20)
plt.show()

# %%
print("Last avg of", N, "Episodes = ", f"{np.array(moving_average)[-N:-1].mean():.1f}")
# Out:
# Last avg of 50 Episodes =  -119.3

# %%
# Episodes versus Avg. Rewards
#norm_reward_list = np.array(moving_average)
#norm_reward_list = (norm_reward_list/abs(norm_reward_list.min())+1)*100
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(norm_reward_list, label = "Normalized Acc. Episodic Reward",color="C0",linewidth = 1.5)
plt.axhline(y=norm_reward_list[-20:-1].mean(), linestyle='--',
            label = "Normalized Acc. Episodic Reward's last 20 mean= "+f"{norm_reward_list[-20:-1].mean():.1f}",color="C1",linewidth = 2.5)
plt.xlabel("Training episodes")
plt.ylabel("Normalized Acc. Epsiodic Reward")
#plt.grid()
plt.legend()
plt.show()

# %%
# Episodes versus Avg. Rewards
#norm_reward_list = np.array(moving_average)
#min_norm_reward_list = np.array(plotting_rewards).min()
#max_norm_reward_list= 0
#norm_reward_list = (norm_reward_list-min_norm_reward_list)/(max_norm_reward_list-min_norm_reward_list)
font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.5)
f.set_figheight(2.2)
plt.plot(norm_reward_list, label = "Normalized Acc. Episodic Reward",color="C0",linewidth = 1.5)
#plt.axhline(y=norm_reward_list[-20:-1].mean(), linestyle='--',
#            label = "Normalized Acc. Episodic Reward's last 20 mean= "+f"{norm_reward_list[-20:-1].mean():.1f}",color="C1",linewidth = 2.5)
plt.xlabel("Training Episode")
plt.ylabel("Normalized Acc. Epi. Reward")
#plt.grid()
#plt.legend()
plt.minorticks_on()
plt.savefig(path+"Disc_Mount_Car_Acc_Reward_vs_Episode.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print("Normalized Acc. Epsiodic Reward's last 20 mean=")
print(norm_reward_list[-20:-1].mean())
# Out:
# Normalized Acc. Epsiodic Reward's last 20 mean=
# 0.4281447368421053

# %%
font = {'size': 20}
plt.rc('font', **font)
plt.plot(ploting_adapt_coeff)
plt.xlabel("Training episodes")
plt.ylabel("Adaptation control gains\n at last time step")
#plt.rc('axes', labelsize=30)

plt.grid()
plt.legend(labels=[r"$\hat{k_r}$=coeff of $a^{desired}$",
                   r"$\hat{k}_y$=coeff of $a^{actual}$",
                 r"$\hat{k}_{r-y}$=coeff of $(a^{wanted}-a^{actual})$",
                 r"$\hat{k}_\omega$=coeff of $\dot{\theta}$"], fontsize=10,
           bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2010: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   p.space          = oneOf(self._space_widths)("space")
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2020: PyparsingDeprecationWarning: 'leaveWhitespace' deprecated - use 'leave_whitespace'
#   )("sym").leaveWhitespace()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:1984: PyparsingDeprecationWarning: 'setName' deprecated - use 'set_name'
#   val.setName(key)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:1987: PyparsingDeprecationWarning: 'setParseAction' deprecated - use 'set_parse_action'
#   val.setParseAction(getattr(self, key))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2088: PyparsingDeprecationWarning: 'endQuoteChar' argument is deprecated, use 'end_quote_char'
#   p.text = cmd(r"\text", QuotedString('{', '\\', endQuoteChar="}"))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2146: PyparsingDeprecationWarning: 'unquoteResults' argument is deprecated, use 'unquote_results'
#   p.math_string   = QuotedString('$', '\\', unquoteResults=False)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()

# %%
#ploting_adapt_coeff = np.array(ploting_adapt_coeff)

# %%
N=50
# Compute the moving average of the last 50 numbers
moving_average = []
for i, n in enumerate(ploting_adapt_coeff):
    if i < N:
        # If there are not enough previous elements,
        # append the average of all available elements
        avg = sum(ploting_adapt_coeff[:i+1]) / (i+1)
    else:
        # Otherwise, compute the average of the previous 5 elements
        avg = sum(ploting_adapt_coeff[i-N:i+1]) / N
    moving_average.append(avg)
moving_average = np.array(moving_average).T
# Plot the moving average

font = {'size': 20}
plt.rc('font', **font)

plt.plot(moving_average[0]
         ,label = r"$\hat{k}_r$=coeff of $a^{desired}$"+f"→{moving_average[0,-20:-1].mean():.1e}",color="C0",linewidth = 2)
plt.plot(moving_average[1],'--',
         label = r"$\hat{k}_y$=coeff of $a^{actual}$"+f"→{moving_average[1,-20:-1].mean():.1e}",color="C1",linewidth = 3)
plt.plot(moving_average[2],':',
         label = r"$\hat{k}_{r-y}$=coeff of $(a^{desired}-a^{actual})$"+f"→{moving_average[2,-20:-1].mean():.1e}",color="C2",linewidth = 4)
plt.plot(moving_average[3],'-.',
         label = r"$\hat{k}_\omega$=coeff of $\dot{\theta}$"+f"→{moving_average[3,-20:-1].mean():.1e}",color="C3",linewidth = 2)
#plt.plot(moving_average)
plt.xlabel("Training episodes")
plt.ylabel("Adaptation control gains\n at last time step")
plt.title('Discrete Mountain Car',fontsize=20)
plt.ylim(-3.1,4.5)
plt.grid()
plt.legend(fontsize=13, bbox_to_anchor=(0.5, 0.3), loc='center')
#plt.legend(fontsize=12, bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %%
# Test Histogram
norm_ep_reward_list_test = np.array(plotting_rewards_test)
#norm_ep_reward_list_test = (norm_ep_reward_list_test-min_norm_reward_list)/(max_norm_reward_list-min_norm_reward_list)
norm_ep_reward_list_test = unnorm_to_norm(norm_ep_reward_list_test)
print(norm_ep_reward_list_test.max())
print(norm_ep_reward_list_test.min())
min_bin = np.floor(norm_ep_reward_list_test.min()*100)/100
# Out:
# 0.58
# 0.09

# %%
font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(1.9)
f.set_figheight(2.2)
data_rewards = np.array(norm_ep_reward_list_test)
density_True = True

plt.hist(data_rewards, bins=np.arange(0,1.01,0.1), density=density_True ,color='skyblue', edgecolor='black')
plt.xlabel('Normalized Acc. Epi. Reward')
ylabel='Density'if density_True else 'Frequency'
plt.ylabel(ylabel)
#plt.xticks(np.arange(0.2,1.01,0.1))
plt.minorticks_on()
plt.xlim((0.0,1.01))
plt.savefig(path+"Disc_Mount_Car_Acc_Reward_vs_Episode_Test_Hist.pdf", format='pdf', bbox_inches='tight')
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print("Test Normalized Acc Episodic Reward's Results:")
print(f"Unnormalized: max={norm_to_unnorm(data_rewards).max():.3f} ,mean={norm_to_unnorm(data_rewards).mean():.3f}, std={norm_to_unnorm(data_rewards).std():.3f}")
print(f"Normalized:   max={data_rewards.max():.3e} ,mean={data_rewards.mean():.3e}, std={data_rewards.std():.3e}")
# Out:
# Test Normalized Acc Episodic Reward's Results:
# Unnormalized: max=-84.000 ,mean=-102.370, std=12.601
# Normalized:   max=5.800e-01 ,mean=4.881e-01, std=6.301e-02

# %%
dt=env.tau

# %%
time_ = np.linspace(start = 0, stop = len(save_actual_force)* dt,num=len(save_actual_force) )

font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.5)
f.set_figheight(2.2)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')


plt.step(time_, save_wanted_force ,label = r"$r=a^{desired}$ from RL alg.",color="blue",linewidth = 1.5)
plt.step(time_, save_model_force , '--',label = "$y_m=a^{model}$ from MRAC ref. model",color="green",linewidth = 2)
plt.step(time_, save_actual_force , ':',label = "$y=a^{actual}$ from DC motor plant",color="red",linewidth = 4)
plt.xlabel("Time (s)")
plt.ylabel("Force (N)")
plt.legend(fontsize=7)#,bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.xlim(None,max(100,time_[-1]))
#plt.title('Discrete Mountain Car',fontsize=20)
plt.savefig(path+"Disc_Mount_Car_Force_vs_Time.pdf", format='pdf', bbox_inches='tight')
#plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
e_ry=np.array(save_wanted_force)-np.array(save_actual_force)
e_yy_m=np.array(save_actual_force)-np.array(save_model_force)
print(f"e_ry: (mean, std, mae) = ({e_ry.mean():.2e}, {e_ry.std():.2e}, {np.abs(e_ry).mean():.2e})")
print(f"e_yy_m: (mean, std, mae) = ({e_yy_m.mean():.2e}, {e_yy_m.std():.2e}, {np.abs(e_yy_m).mean():.2e})")
# Out:
# e_ry: (mean, std, mae) = (1.86e-06, 9.94e-05, 1.72e-05)
# e_yy_m: (mean, std, mae) = (-1.86e-06, 9.94e-05, 1.72e-05)

# %%
font = {'size': 20}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(6)
f.set_figheight(4)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

e_ry=np.array(save_wanted_force)-np.array(save_actual_force)
e_yy_m=np.array(save_actual_force)-np.array(save_model_force)


plt.step(time_, e_ry ,label = "$e_{r,y}=a^{desired}-a^{actual}$ ",color="cyan",linewidth = 1.5)
plt.step(time_, e_yy_m , ':',label = "$e_{y,y_m}=a^{actual}-a^{model}$ ",color="brown",linewidth = 4)
plt.axhline(y=e_ry.mean(), color="black",linewidth = 2, linestyle='--', label='mean($e_{r,y}$) =' +f'{e_ry.mean():.1e}')
plt.axhline(y=e_yy_m.mean(), color="magenta",linewidth = 2, linestyle='-.', label='mean($e_{y,y_m}$) =' +f'{e_yy_m.mean():.1e}')
plt.xlabel("time [sec]")
plt.xlim(None,max(100,time_[-1]))
plt.ylabel("Force error [N]")
plt.title('Discrete Mountain Car',fontsize=20)
plt.legend(fontsize=11, bbox_to_anchor=(0.5, 0.2),loc='center',ncols=2)
plt.grid()
plt.show()

# %%
from scipy.integrate import cumulative_trapezoid
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

e_ry=np.array(save_wanted_force)-np.array(save_actual_force)
e_yy_m=np.array(save_actual_force)-np.array(save_model_force)

cum_trapz_e_ry = cumulative_trapezoid(y=np.r_[0,e_ry],x=None, dx=dt)
cum_trapz_e_yy_m = cumulative_trapezoid(y=np.r_[0,e_yy_m],x=None, dx=dt)


plt.step(time_, e_ry ,label = r"$e_{r,y}=a^{wanted}-a^{actual}$ ",color="cyan",linewidth = 1.5)
plt.step(time_, e_yy_m , ':',label = "$e_{y,y_m}=a^{actual}-a^{model}$ ",color="brown",linewidth = 4)

plt.plot(time_, cum_trapz_e_ry,'--',
         label = r"cumtrapz($e_{r,y}$)",color="black",linewidth = 2)
plt.plot(time_, cum_trapz_e_yy_m,'-.',
         label = r"cumtrapz($e_{y,y_m}$)",color="magenta",linewidth = 2)

plt.xlabel("time [sec]")
plt.ylabel("Force error [N]")
plt.legend(fontsize=12)
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()

# %%
font = {'size': 20}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(6)
f.set_figheight(4)

plt.plot(time_, save_ctrl_voltage)
plt.xlabel("time [sec]")
plt.ylabel("Control Voltage [volts]")
plt.title('Discrete Mountain Car',fontsize=20)
plt.xlim(None,max(100,time_[-1]))
plt.grid()
plt.show()

# %%
np_array_MRAC_adapt_gains = np.array(save_MRAC_adapt_gains).T

# %%
font = {'size': 20}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(6)
f.set_figheight(4)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

#plt.ylabel(r'$\dot{\theta}$ [rad/sec]')

plt.plot(time_, np_array_MRAC_adapt_gains[0]
         ,label = r"$\hat{k}_r$=coeff of $a^{desired}$"+f"→{np_array_MRAC_adapt_gains[0,-20:-1].mean():.1e}",color="C0",linewidth = 2)
plt.plot(time_, np_array_MRAC_adapt_gains[1],'--'
         ,label = r"$\hat{k_y}$=coeff of $a^{actual}$"+f"→{np_array_MRAC_adapt_gains[1,-20:-1].mean():.1e}",color="C1",linewidth = 3)
plt.plot(time_, np_array_MRAC_adapt_gains[2],':',
         label = r"$\hat{k}_{r-y}$=coeff of $(a^{wanted}-a^{actual})$"+f"→{np_array_MRAC_adapt_gains[2,-20:-1].mean():.1e}",color="C2",linewidth = 4)
plt.plot(time_, np_array_MRAC_adapt_gains[3],'-.',
         label = r"$\hat{k}_\omega$=coeff of $\dot{\theta}$"+f"→{np_array_MRAC_adapt_gains[3,-20:-1].mean():.1e}",color="C3",linewidth = 2)
plt.xlabel("time [sec]")
plt.ylabel("Adaptaion control gains")
plt.title('Discrete Mountain Car',fontsize=20)
#plt.legend(fontsize=13, bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.xlim(None,max(100,time_[-1]))
plt.ylim(-3.1,4.5)
plt.grid()
plt.legend(fontsize=11, bbox_to_anchor=(0.5, 0.3), loc='center')
plt.show()

# %%
import math

position_print = []
velocity_print = []


for observ in save_observation:
  for index,value in enumerate(observ):
    if index == 0:
      position_print.append(value)

    if index == 1:
      velocity_print.append(value)

# %%
print(len(position_print))
# Out:
# 85

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_position_print = np.linspace(start = 0, stop = len(position_print)*dt,num=len(position_print))##############################################
#time_position , position
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_position_print[-1] , 300)

spl = make_interp_spline(time_position_print, position_print, k=3)  # type: BSpline
power_smooth = spl(xnew)

font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.5)
f.set_figheight(2.2)

plt.plot(xnew, power_smooth)
plt.ylabel('Position (m)')
plt.xlabel('Time (s)')
#plt.grid()
#plt.legend()
#plt.title('POSITION')
#plt.grid()
#plt.legend()
#plt.title('POSITION')
plt.savefig(path+"Disc_Mount_Position_vs_Time.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print("Car reached goal after "+str(time_position_print[-1])+ " seconds")
# Out:
# Car reached goal after 85.0 seconds

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_velocity_print = np.linspace(start = 0, stop = len(velocity_print)* dt,num=len(velocity_print))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_velocity_print[-1] , 300)

spl = make_interp_spline(time_velocity_print, velocity_print, k=3)  # type: BSpline
power_smooth = spl(xnew)

plt.plot(xnew, power_smooth)
plt.ylabel('Velocity [m/sec]')
plt.xlabel('Time[sec]')
plt.grid()
plt.title('Discrete Mountain Car',fontsize=20)
plt.show()

# %%
q_arr = eval_state_action_space(q_hat, env)
plot_q_max_3d(q_arr, env, labels=['Position', 'Velocity', ''], alpha=0.3)
