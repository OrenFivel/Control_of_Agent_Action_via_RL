# %%
#ddpg

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle

# %%
import math
from typing import Optional

import numpy as np

import gym
from gym import spaces
from gym.envs.classic_control import utils
from gym.error import DependencyNotInstalled


class Continuous_MountainCarEnv_Custom(gym.Env):
    """
    ### Description
    The Mountain Car MDP is a deterministic MDP that consists of a car placed stochastically
    at the bottom of a sinusoidal valley, with the only possible actions being the accelerations
    that can be applied to the car in either direction. The goal of the MDP is to strategically
    accelerate the car to reach the goal state on top of the right hill. There are two versions
    of the mountain car domain in gym: one with discrete actions and one with continuous.
    This version is the one with continuous actions.
    This MDP first appeared in [Andrew Moore's PhD Thesis (1990)](https://www.cl.cam.ac.uk/techreports/UCAM-CL-TR-209.pdf)
    ```
    @TECHREPORT{Moore90efficientmemory-based,
        author = {Andrew William Moore},
        title = {Efficient Memory-based Learning for Robot Control},
        institution = {University of Cambridge},
        year = {1990}
    }
    ```
    ### Observation Space
    The observation is a `ndarray` with shape `(2,)` where the elements correspond to the following:
    | Num | Observation                          | Min  | Max | Unit         |
    |-----|--------------------------------------|------|-----|--------------|
    | 0   | position of the car along the x-axis | -Inf | Inf | position (m) |
    | 1   | velocity of the car                  | -Inf | Inf | position (m) |
    ### Action Space
    The action is a `ndarray` with shape `(1,)`, representing the directional force applied on the car.
    The action is clipped in the range `[-1,1]` and multiplied by a power of 0.0015.
    ### Transition Dynamics:
    Given an action, the mountain car follows the following transition dynamics:
    *velocity<sub>t+1</sub> = velocity<sub>t+1</sub> + force * self.power - 0.0025 * cos(3 * position<sub>t</sub>)*
    *position<sub>t+1</sub> = position<sub>t</sub> + velocity<sub>t+1</sub>*
    where force is the action clipped to the range `[-1,1]` and power is a constant 0.0015.
    The collisions at either end are inelastic with the velocity set to 0 upon collision with the wall.
    The position is clipped to the range [-1.2, 0.6] and velocity is clipped to the range [-0.07, 0.07].
    ### Reward
    A negative reward of *-0.1 * action<sup>2</sup>* is received at each timestep to penalise for
    taking actions of large magnitude. If the mountain car reaches the goal then a positive reward of +100
    is added to the negative reward for that timestep.
    ### Starting State
    The position of the car is assigned a uniform random value in `[-0.6 , -0.4]`.
    The starting velocity of the car is always assigned to 0.
    ### Episode End
    The episode ends if either of the following happens:
    1. Termination: The position of the car is greater than or equal to 0.45 (the goal position on top of the right hill)
    2. Truncation: The length of the episode is 999.
    ### Arguments
    ```
    gym.make('MountainCarContinuous-v0')
    ```
    ### Version History
    * v0: Initial versions release (1.0.0)
    """

    metadata = {
        "render_modes": ["human", "rgb_array"],
        "render_fps": 30,
    }

    def __init__(self, render_mode: Optional[str] = None, goal_velocity=0):
        self.min_action = -1.0
        self.max_action = 1.0
        self.min_position = -1.2
        self.max_position = 0.6
        self.max_speed = 0.07
        self.max_step = 1000 # change from 999 for convient
        self.current_step = 0

                ### Customization changes ######
        self.tau = 1.0 # seconds between state updates
        self.MRAC = ModelRefAC()
        self.NumIntegrationsSteps = 200
        self.tau1 =self.tau/self.NumIntegrationsSteps
        self.MRAC.timeSample = self.tau1
        self.MRAC.plant.tau1 = self.tau1
        self.MRAC.ref_model.tau1 = self.tau1
        ####
        self.wanted_force = 0.0


        self.goal_position = (
            0.45  # was 0.5 in gym, 0.45 in Arnaud de Broissia's version
        )
        self.goal_velocity = goal_velocity
        self.power = 0.0015

        self.low_state = np.array(
            [self.min_position, -self.max_speed], dtype=np.float32
        )
        self.high_state = np.array(
            [self.max_position, self.max_speed], dtype=np.float32
        )

        self.render_mode = render_mode

        self.screen_width = 600
        self.screen_height = 400
        self.screen = None
        self.clock = None
        self.isopen = True

        self.action_space = spaces.Box(
            low=self.min_action, high=self.max_action, shape=(1,), dtype=np.float32
        )
        self.observation_space = spaces.Box(
            low=self.low_state, high=self.high_state, dtype=np.float32
        )

    def step(self, action: np.ndarray):

        position = self.state[0]
        velocity = self.state[1]
        #force = min(max(action[0], self.min_action), self.max_action)#The action is clipped in the range [-1,1] and multiplied by a power of 0.0015
        wanted_force = min(max(action, self.min_action), self.max_action)#The action is clipped in the range [-1,1] and multiplied by a power of 0.0015
        self.wanted_force=wanted_force
        for n in np.arange(start=0, stop=self.NumIntegrationsSteps, step=1):
          #generates actual force
          self.MRAC.plant.thetadot = velocity
          actual_force = self.MRAC.step(r=wanted_force)
          #actual_force = wanted_force # change for perfect applying force

          velocity += (actual_force * self.power - 0.0025 * math.cos(3 * position))*self.tau1
          if velocity > self.max_speed:
              velocity = self.max_speed
          if velocity < -self.max_speed:
              velocity = -self.max_speed
          position += (velocity)*self.tau1
          if position > self.max_position:
              position = self.max_position
          if position < self.min_position:
              position = self.min_position
          if position == self.min_position and velocity < 0:
              velocity = 0

        # Convert a possible numpy bool to a Python bool.

        terminated = bool(
            position >= self.goal_position #and velocity >= self.goal_velocity
        )
        '''
        terminated = bool(
            position >= self.goal_position and np.abs(
                velocity-self.goal_velocity) < 10**(-3)
        )
        '''
        reward = 0
        if terminated:
            reward = 100.0
        reward -= math.pow(actual_force, 2) * 0.1
        self.state = np.array([position, velocity], dtype=np.float32)
        # change
        #if self.current_step>100:
        #  reward -= 1e-1


        if self.render_mode == "human":
            self.render()

        self.current_step += 1
        terminated_end_of_episode = bool(self.current_step % self.max_step == 0)
        if (terminated == True) or (terminated_end_of_episode == True):
          terminated = True
          self.current_step = 0



        return self.state, reward, terminated, False ,wanted_force , actual_force

    def reset(self, *, seed: Optional[int] = None, options: Optional[dict] = None):
        super().reset(seed=seed)
        # Note that if you use custom reset bounds, it may lead to out-of-bound
        # state/observations.
        low, high = utils.maybe_parse_reset_bounds(options, -0.6, -0.4)
        self.state = np.array([self.np_random.uniform(low=low, high=high), 0])

        self.current_step = 0
        ### reset DC motor init. conditions
        self.MRAC.reset()
        self.MRAC.plant.reset()
        self.MRAC.ref_model.reset()

        if self.render_mode == "human":
            self.render()
        return np.array(self.state, dtype=np.float32)

    def _height(self, xs):
        return np.sin(3 * xs) * 0.45 + 0.55

    def render(self):
        if self.render_mode is None:
            gym.logger.warn(
                "You are calling render method without specifying any render mode. "
                "You can specify the render_mode at initialization, "
                f'e.g. gym("{self.spec.id}", render_mode="rgb_array")'
            )
            return

        try:
            import pygame
            from pygame import gfxdraw
        except ImportError:
            raise DependencyNotInstalled(
                "pygame is not installed, run `pip install gym[classic_control]`"
            )

        if self.screen is None:
            pygame.init()
            if self.render_mode == "human":
                pygame.display.init()
                self.screen = pygame.display.set_mode(
                    (self.screen_width, self.screen_height)
                )
            else:  # mode == "rgb_array":
                self.screen = pygame.Surface((self.screen_width, self.screen_height))
        if self.clock is None:
            self.clock = pygame.time.Clock()

        world_width = self.max_position - self.min_position
        scale = self.screen_width / world_width
        carwidth = 40
        carheight = 20

        self.surf = pygame.Surface((self.screen_width, self.screen_height))
        self.surf.fill((255, 255, 255))

        pos = self.state[0]

        xs = np.linspace(self.min_position, self.max_position, 100)
        ys = self._height(xs)
        xys = list(zip((xs - self.min_position) * scale, ys * scale))

        pygame.draw.aalines(self.surf, points=xys, closed=False, color=(0, 0, 0))

        clearance = 10

        l, r, t, b = -carwidth / 2, carwidth / 2, carheight, 0
        coords = []
        for c in [(l, b), (l, t), (r, t), (r, b)]:
            c = pygame.math.Vector2(c).rotate_rad(math.cos(3 * pos))
            coords.append(
                (
                    c[0] + (pos - self.min_position) * scale,
                    c[1] + clearance + self._height(pos) * scale,
                )
            )

        gfxdraw.aapolygon(self.surf, coords, (0, 0, 0))
        gfxdraw.filled_polygon(self.surf, coords, (0, 0, 0))

        for c in [(carwidth / 4, 0), (-carwidth / 4, 0)]:
            c = pygame.math.Vector2(c).rotate_rad(math.cos(3 * pos))
            wheel = (
                int(c[0] + (pos - self.min_position) * scale),
                int(c[1] + clearance + self._height(pos) * scale),
            )

            gfxdraw.aacircle(
                self.surf, wheel[0], wheel[1], int(carheight / 2.5), (128, 128, 128)
            )
            gfxdraw.filled_circle(
                self.surf, wheel[0], wheel[1], int(carheight / 2.5), (128, 128, 128)
            )

        flagx = int((self.goal_position - self.min_position) * scale)
        flagy1 = int(self._height(self.goal_position) * scale)
        flagy2 = flagy1 + 50
        gfxdraw.vline(self.surf, flagx, flagy1, flagy2, (0, 0, 0))

        gfxdraw.aapolygon(
            self.surf,
            [(flagx, flagy2), (flagx, flagy2 - 10), (flagx + 25, flagy2 - 5)],
            (204, 204, 0),
        )
        gfxdraw.filled_polygon(
            self.surf,
            [(flagx, flagy2), (flagx, flagy2 - 10), (flagx + 25, flagy2 - 5)],
            (204, 204, 0),
        )

        self.surf = pygame.transform.flip(self.surf, False, True)
        self.screen.blit(self.surf, (0, 0))
        if self.render_mode == "human":
            pygame.event.pump()
            self.clock.tick(self.metadata["render_fps"])
            pygame.display.flip()

        elif self.render_mode == "rgb_array":
            return np.transpose(
                np.array(pygame.surfarray.pixels3d(self.screen)), axes=(1, 0, 2)
            )

    def close(self):
        if self.screen is not None:
            import pygame

            pygame.display.quit()
            pygame.quit()
            self.isopen = False
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
class ElectricalDCMotorEnv():

  def __init__(self):
    self.Resistor_R = 1.0
    self.inductor_L = 0.1
    self.torque_const_Kt = 1.0
    self.bemf_const_Ke = 1.0
    self.tau1 = 0.05
        #
    self.current = 0.0
    self.voltage_input = None
    self.thetadot = 0.0

  def step(self, u):
    voltage_BEMF = self.thetadot*self.bemf_const_Ke
    self.voltage_input = np.clip(u, -10, 10)

    f1 = self.torque_const_Kt*self.current
    self.current += self.tau1*(self.voltage_input-voltage_BEMF-self.current*self.Resistor_R)/self.inductor_L
    f2 = self.torque_const_Kt*self.current
    F = f2
    return F # return actual applied torque

  def reset(self):
    self.current = 0.0

# %%
class ReferenceModel():

  def __init__(self):
    self.a_m = 50.0#30.0
    self.b_m = self.a_m
    self.tau1 = 0.05
    self.x_m = 0.0
    self.y_m = 0.0

  def step(self, r):

    #fwd integration
    #A = -self.a_m*self.tau1
    #Br = self.b_m*self.tau1*r
    #self.y_m = self.x_m+0
    #self.x_m = (1+A)*self.y_m+Br
    #y_m = self.y_m+0

    #bkwd integration
    #A = -self.a_m*self.tau1
    #Br = self.b_m*self.tau1*r
    #if A ==1:
    #  C=1
    #else:
    #  C = 1/(1-A)
    #self.y_m = C*(self.x_m-Br)
    #self.x_m = self.y_m+0
    #y_m = self.y_m+0

    #trapz integragration
    A = -0.5*self.a_m*self.tau1
    Br= +0.5*self.b_m*self.tau1*r
    if A ==1:
      C=1
    else:
      C = 1/(1-A)
    x_m = self.x_m
    y_m = C*(x_m+Br)
    x_m = (1+A)*y_m + Br
    self.x_m = x_m
    self.y_m = y_m

    return y_m

  def reset(self):
    self.x_m = 0.0
    self.y_m = 0.0

# %%
class ModelRefAC:

  def __init__(self): #  order of signals [r,y,r-y,w]
    self.plant = ElectricalDCMotorEnv()
    self.ref_model = ReferenceModel()
    self.w = 0.0
    self.u = 0.0
    self.r = 0.0
    self.y = 0.0
    self.y_m = 0.0
    self.adaptation_gain=np.array([50,60,10,50])*14 # positive scalar or np.array shape (4,)
    self.sigma_mod_adapt_gain=0 # non-neg scalar or np.array shape (4,)
    self.emod_adapt_gain=0
    self.dead_zone_threshold = 0*1e-5
    self.dead_zone_adapt_gain = 0*1e-3
    self.timeSample=0.05
    self.mu0 = np.array([1e-3,-1e-3,1e-3,1e-3])
    self.std = 0*1e-6
    self.k_temp = self.mu0
    self.k_hat =  self.mu0
    self.keep_coeff = True
    self.mask = np.array([True,True,True,True])
    self.distrib = np.random.standard_normal


  def step(self, r):
    self.r = r
    self.w = self.plant.thetadot
    y = self.y
    y_m = self.y_m
    e=y-y_m
    u = self.adaptationControlLaw(e=e, r=r, y=y, w=self.w)
    self.y_m = self.ref_model.step(r)
    self.y = self.plant.step(u)
    return self.y

  def adaptationControlLaw(self, e, r, y, w):
    v = np.array([r,y,r-y,w])#.clip(-20,20)
    e_norm = abs(e)

    #fwd integration
    #A = -(self.sigma_mod_adapt_gain+self.emod_adapt_gain*e_norm)*self.timeSample
    #Bev = -self.adaptation_gain*self.timeSample*e*v
    #if e_norm<=self.dead_zone_threshold:
    #  A = A*self.dead_zone_adapt_gain
    #  Bev = Bev*self.dead_zone_adapt_gain
    #self.k_hat = self.k_temp*self.mask
    #self.k_temp = ((1+A)*self.k_hat + Bev)*self.mask

    #backwd integration
    #A = -(self.sigma_mod_adapt_gain+self.emod_adapt_gain*e_norm)*self.timeSample
    #Bev = -self.adaptation_gain*self.timeSample*e*v
    #if e_norm<=self.dead_zone_threshold:
    #  A = A*self.dead_zone_adapt_gain
    #  Bev = Bev*self.dead_zone_adapt_gain
    #C = 1-A*(A!=np.ones_like(A))
    #C = 1/C
    #self.k_hat = C*(self.k_temp+Bev)*self.mask
    #self.k_temp = A*self.k_hat*self.mask

    #trapz integration
    A = -0.5*(self.sigma_mod_adapt_gain+self.emod_adapt_gain*e_norm)*self.timeSample
    Bev = -0.5*self.adaptation_gain*self.timeSample*e*v
    if e_norm<=self.dead_zone_threshold:
      A = A*self.dead_zone_adapt_gain
      Bev = Bev*self.dead_zone_adapt_gain
    if A ==1:
      C=1
    else:
      C = 1/(1-A)
    self.k_hat = C*((self.k_temp +Bev)*self.mask)
    self.k_temp = ((1+A)*self.k_hat +Bev)*self.mask
    u = np.dot(v,self.k_hat)
    u=np.clip(u,-10,10)
    self.u = u
    return u

  def reset(self):
    self.w = 0.0
    self.r = 0.0
    self.y = 0.0
    self.y_m = 0.0
    mu0 = self.mu0
    sigma0 = self.std
    keep_coeff = self.keep_coeff
    self.k_temp = (sigma0*self.distrib(self.k_temp.shape) + keep_coeff*self.k_temp + (not keep_coeff)*mu0)*self.mask
    self.k_hat = (sigma0*self.distrib(self.k_hat.shape) + keep_coeff*self.k_hat + (not keep_coeff)*mu0)*self.mask

# %%
env = Continuous_MountainCarEnv_Custom()

# %%
print("dt= ", env.tau)
print("N= ", env.NumIntegrationsSteps)
print("dt/N=", env.tau/env.NumIntegrationsSteps)
print("gamma*dt/N=", env.MRAC.adaptation_gain*env.tau/env.NumIntegrationsSteps)
# Out:
# dt=  1.0
# N=  200
# dt/N= 0.005
# gamma*dt/N= [3.5 4.2 0.7 3.5]

# %%
from gym import make
import random
import numpy as np
from collections import namedtuple, deque
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
Transaction = namedtuple('Transaction',
                         ('state', 'action', 'next_state', 'reward'))


class Buffer(object):

    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = deque(maxlen=capacity)

    def push(self, *args):
        self.memory.appendleft(Transaction(*args))

    def sample(self, batch_size):
        batch = random.sample(self.memory, batch_size)
        batch = Transaction(*zip(*batch))
        self.state = torch.tensor(batch.state, dtype = torch.float)
        self.action = torch.tensor(batch.action, dtype = torch.float)
        self.next_state = torch.tensor(batch.next_state, dtype = torch.float)
        self.reward = torch.tensor(batch.reward, dtype = torch.float)

    def __len__(self):
        return len(self.memory)

# %%
class Actor(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(state_dim, 256)#64
        self.fc2 = nn.Linear(256, 256)#(64, 64)
        self.fc3 = nn.Linear(256, action_dim) #64


    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return torch.tanh(x)


class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(state_dim, 64)
        self.fc2 = nn.Linear(64 + action_dim, 64)
        self.fc3 = nn.Linear(64, 256)#action_dim
        self.fc4 = nn.Linear(256, 256)
        self.fc5 = nn.Linear(256, 1)
        #self.fc2 = nn.Linear(64 + action_dim, 256)
        #self.fc3 = nn.Linear(256, 1)#action_dim


    def forward(self, x, a):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(torch.cat([x, a], dim=1)))
        x = F.hardtanh(self.fc3(x))#+F.relu(self.fc3(x))
        x = F.hardtanh(self.fc4(x))#+F.relu(self.fc4(x))
        x = self.fc5(x)
        return x

# %%
class Noise:
    def __init__(self, mu=0.0, theta=0.1, sigma=0.1):
        self.mu = mu
        self.theta = theta
        self.sigma = sigma
        self.action_dim = 1
        self.low = -1.0
        self.high = 1.0
        self.state = np.ones(self.action_dim) * self.mu

    def noise(self):
        x = self.state
        dx = self.theta * (self.mu - x) + self.sigma * np.random.randn(self.action_dim)
        self.state = x + dx
        return self.state

# %%
class AQL:
    def __init__(self, states, actions, eps, episodes, batch_size, mem_sz, alpha_actor,
                 alpha_critic, gamma, tau):
        self.gamma = gamma
        self.alpha_actor = alpha_actor
        self.alpha_critic = alpha_critic
        self.eps = eps
        self.episodes = episodes
        self.batch_size = batch_size
        self.memory = Buffer(mem_sz)
        self.tau = tau
        self.noise = Noise()
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.actor = Actor(states, actions).to(self.device).apply(self.weights)
        self.critic = Critic(states, actions).to(self.device).apply(self.weights)

        self.actor_target = Actor(states, actions).to(self.device)
        self.actor_target.load_state_dict(self.actor.state_dict())

        self.critic_target = Critic(states, actions).to(self.device)
        self.critic_target.load_state_dict(self.critic.state_dict())

        self.actor_optim = optim.Adam(self.actor.parameters(), lr=self.alpha_actor)
        self.critic_optim = optim.Adam(self.critic.parameters(), lr=self.alpha_critic)
        self.critic_criterion = nn.MSELoss()

    @staticmethod
    def weights(layer):
        if isinstance(layer, nn.Linear):
            nn.init.xavier_normal_(layer.weight)

    def update(self):
        if len(self.memory) <= self.batch_size:
            return
        self.memory.sample(self.batch_size)
        Qvals = self.critic.forward(self.memory.state, self.memory.action.unsqueeze(1))
        next_actions = self.actor_target.forward(self.memory.next_state)
        next_Q = self.critic_target.forward(self.memory.next_state, next_actions.detach())
        Qprime = self.memory.reward.unsqueeze(1) + self.gamma * next_Q
        critic_loss = self.critic_criterion(Qvals, Qprime)
        policy_loss = -self.critic.forward(self.memory.state, self.actor.forward(self.memory.state)).mean()

        self.actor_optim.zero_grad()
        policy_loss.backward()
        self.critic_optim.zero_grad()
        critic_loss.backward()

        for param_actor, param_critic in zip(self.actor.parameters(), self.critic.parameters()):
            param_actor.grad.data.clamp_(-1, 1)
            param_critic.grad.data.clamp_(-1, 1)
        self.actor_optim.step()
        self.critic_optim.step()

        for target_param, param in zip(self.actor_target.parameters(), self.actor.parameters()):
            target_param.data.copy_(param.data * self.tau + target_param.data * (1.0 - self.tau))

        for target_param, param in zip(self.critic_target.parameters(), self.critic.parameters()):
            target_param.data.copy_(param.data * self.tau + target_param.data * (1.0 - self.tau))

    def act(self, state):
        return np.clip(self.actor(state).detach() + self.eps * self.noise.noise(), -1.0, 1.0)

# %%
class Test:
    def __init__(self, path, rewards, test_episodes, mu0):
        self.rewards = rewards
        self.test_episodes = test_episodes
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = torch.load(path,weights_only=False).to(self.device)
        self.mu0=mu0
        self.run()

    def act(self, state):
        state = torch.tensor(state, dtype = torch.float).unsqueeze(0)
        with torch.no_grad():
            return self.model(state)

    def run(self):
        env = Continuous_MountainCarEnv_Custom()
        env.MRAC.mu0 = self.mu0+0
        env.MRAC.k_hat = self.mu0+0
        env.MRAC.k_temp = self.mu0+0
        rewards = []
        for i in range(self.test_episodes):
            state = env.reset()
            s = np.expand_dims(state, axis=0)
            total_reward = 0
            done = False
            while not done:
                k_hat_print = env.MRAC.k_hat.round(2)
                action = self.act(s).item()
                next_state, reward, done, _ , wanted_force , actual_force = env.step(action) #  self.state, reward, terminated, False , force , u_after_pid
                total_reward += reward
                state = next_state
                s = np.expand_dims(state, axis=0) #change
            rewards.append(total_reward)
            print(f'Test Ep.{i}: ', "adapt. coeffs at final time step: ", k_hat_print, f' total reward: {total_reward:.3f}')
        self.test_rewards = rewards
        self.m = np.mean(rewards)
        print(f'Test mean reward:{self.m:.3f}')

    def picture(self):
        font = {'size': 20}
        plt.rc('font', **font)
        plt.figure(figsize=(16, 16))
        ax1 = plt.subplot(211)#(421)
        ax2 = plt.subplot(212)#(421)
        ax1.plot(np.arange(0, len(self.rewards)), self.rewards, label=f'rewards',linewidth = 3)
        ax1.axhline(y=np.array(self.rewards[-50:-1]).mean(), color='C1', linestyle='--', label=f'last 50 mean reward: {np.array(self.rewards[-50:-1]).mean():.3f}',linewidth = 4)
        ax1.set_title(f'Continuous Mountain Car-Train')
        ax1.set_xlabel('Episode')
        ax1.set_ylabel('Reward')
        ax1.grid()
        ax1.legend()

        ax2.plot(np.arange(0, len(self.test_rewards)), self.test_rewards, label=f'rewards',linewidth = 3)
        ax2.axhline(y=self.m, color='C1', linestyle='--', label=f'mean reward: {self.m:.3f}',linewidth = 4)
        ax2.set_title(f'Continuous Mountain Car-Test')
        ax2.set_xlabel('Episode')
        ax2.set_ylabel('Reward')
        ax2.set_ylim(50,100)
        ax2.legend()
        ax2.grid()
        plt.show()

# %%
env = Continuous_MountainCarEnv_Custom()
variable = 12061997
env.seed(variable)
np.random.seed(variable)
random.seed(variable)
torch.manual_seed(variable)

#gamma=0.85
#tau=0.45
aql = AQL(states=env.observation_space.shape[0], actions=env.action_space.shape[0],
          eps=1.0, episodes=100, batch_size=64, mem_sz=60000,
          alpha_actor=1e-3, alpha_critic=5e-4, gamma=0.99, tau=0.005)

rewards = []
score = deque(maxlen=5)
best_score = -10000

# %%
path = '/content/drive/MyDrive/Colab Notebooks/codes/MRAC/save_data/Cont_Mount_Car/'

# %%
ploting_adapt_coeff=[]
k_hat_print = env.MRAC.mu0
print('Initial adapt. coeffs: ', k_hat_print)

for i in range(aql.episodes):
    state = env.reset()
    s = np.expand_dims(state, axis=0)
    total_reward = 0
    done = False
    while not done:
      k_hat_print = env.MRAC.k_hat.round(2)
      action = aql.act(torch.tensor(s, dtype = torch.float).unsqueeze(0)).item()
      next_state, reward, done, _ , wanted_force , actual_force= env.step(action) # self.state, reward, terminated, False , force , u_after_pid

      total_reward += reward
      #reward += 13 * abs(next_state[1])#*13

      aql.memory.push(state, action, next_state, reward)
      state = next_state
      s = np.expand_dims(state, axis=0) ####change
      aql.update()
    aql.eps *= 0.9
    score.appendleft(total_reward)
    ploting_adapt_coeff.append(k_hat_print)
    # save best five episodes
    print(f"Episode {i}, ", "adapt. coeffs at final time step: ", k_hat_print)
    print(f'Episode {i},'
          f'total_reward: {total_reward:.3f},'
          f' mean five: {np.mean(score):.3f},'
          f' total mean {np.mean(rewards):.3f},'
          f' EPS: {aql.eps:.2e}')
    if np.mean(score) > best_score and i >= 5:
        torch.save(aql.actor, path+"model.pickle")
        best_score = np.mean(score)
        print('updated!!!!', f"{best_score:.3f}", '---------------------')
    rewards.append(total_reward)
# Out:
# Initial adapt. coeffs:  [ 0.001 -0.001  0.001  0.001]
# Episode 0,  adapt. coeffs at final time step:  [ 3.29 -2.26  1.03  0.05]
# Episode 0,total_reward: 86.722, mean five: 86.722, total mean nan, EPS: 9.00e-01
# Episode 1,  adapt. coeffs at final time step:  [ 3.37 -2.38  1.07  0.44]
# Episode 1,total_reward: -78.317, mean five: 4.203, total mean 86.722, EPS: 8.10e-01
# Episode 2,  adapt. coeffs at final time step:  [ 3.53 -2.54  1.13  0.45]
# Episode 2,total_reward: -89.497, mean five: -27.031, total mean 4.203, EPS: 7.29e-01
# Episode 3,  adapt. coeffs at final time step:  [ 3.64 -2.64  1.17  0.45]
# Episode 3,total_reward: -90.170, mean five: -42.815, total mean -27.031, EPS: 6.56e-01
# Episode 4,  adapt. coeffs at final time step:  [ 3.38 -2.35  1.07  0.45]
# Episode 4,total_reward: 43.218, mean five: -25.609, total mean -42.815, EPS: 5.90e-01
# Episode 5,  adapt. coeffs at final time step:  [ 3.08 -2.06  0.96  0.46]
# Episode 5,total_reward: 79.535, mean five: -27.046, total mean -25.609, EPS: 5.31e-01
# updated!!!! -27.046 ---------------------
# Episode 6,  adapt. coeffs at final time step:  [ 3.   -1.99  0.93  0.48]
# Episode 6,total_reward: 69.201, mean five: 2.457, total mean -8.085, EPS: 4.78e-01
# updated!!!! 2.457 ---------------------
# Episode 7,  adapt. coeffs at final time step:  [ 2.98 -1.97  0.92  0.48]
# Episode 7,total_reward: 67.373, mean five: 33.831, total mean 2.956, EPS: 4.30e-01
# updated!!!! 33.831 ---------------------
# Episode 8,  adapt. coeffs at final time step:  [ 2.92 -1.93  0.91  0.48]
# Episode 8,total_reward: -31.068, mean five: 45.652, total mean 11.008, EPS: 3.87e-01
# updated!!!! 45.652 ---------------------
# Episode 9,  adapt. coeffs at final time step:  [ 2.95 -1.94  0.91  0.49]
# Episode 9,total_reward: 72.034, mean five: 51.415, total mean 6.333, EPS: 3.49e-01
# updated!!!! 51.415 ---------------------
# Episode 10,  adapt. coeffs at final time step:  [ 2.92 -1.92  0.9   0.49]
# Episode 10,total_reward: -26.184, mean five: 30.271, total mean 12.903, EPS: 3.14e-01
# Episode 11,  adapt. coeffs at final time step:  [ 2.92 -1.88  0.9   0.49]
# Episode 11,total_reward: -23.305, mean five: 11.770, total mean 9.350, EPS: 2.82e-01
# Episode 12,  adapt. coeffs at final time step:  [ 2.93 -1.93  0.91  0.5 ]
# Episode 12,total_reward: 71.536, mean five: 12.603, total mean 6.628, EPS: 2.54e-01
# Episode 13,  adapt. coeffs at final time step:  [ 2.92 -1.9   0.9   0.5 ]
# Episode 13,total_reward: -20.080, mean five: 14.800, total mean 11.621, EPS: 2.29e-01
# Episode 14,  adapt. coeffs at final time step:  [ 2.87 -1.91  0.89  0.5 ]
# Episode 14,total_reward: -16.474, mean five: -2.901, total mean 9.357, EPS: 2.06e-01
# Episode 15,  adapt. coeffs at final time step:  [ 2.96 -1.95  0.92  0.5 ]
# Episode 15,total_reward: 81.530, mean five: 18.642, total mean 7.635, EPS: 1.85e-01
# Episode 16,  adapt. coeffs at final time step:  [ 3.03 -2.02  0.94  0.51]
# Episode 16,total_reward: 82.683, mean five: 39.839, total mean 12.253, EPS: 1.67e-01
# Episode 17,  adapt. coeffs at final time step:  [ 3.05 -2.04  0.95  0.54]
# Episode 17,total_reward: 84.073, mean five: 42.347, total mean 16.396, EPS: 1.50e-01
# Episode 18,  adapt. coeffs at final time step:  [ 3.05 -2.04  0.95  0.54]
# Episode 18,total_reward: 87.308, mean five: 63.824, total mean 20.156, EPS: 1.35e-01
# updated!!!! 63.824 ---------------------
# Episode 19,  adapt. coeffs at final time step:  [ 3.   -2.    0.93  0.54]
# Episode 19,total_reward: -8.177, mean five: 65.484, total mean 23.690, EPS: 1.22e-01
# updated!!!! 65.484 ---------------------
# Episode 20,  adapt. coeffs at final time step:  [ 3.02 -2.    0.94  0.55]
# Episode 20,total_reward: 87.964, mean five: 66.770, total mean 22.097, EPS: 1.09e-01
# updated!!!! 66.770 ---------------------
# Episode 21,  adapt. coeffs at final time step:  [ 3.01 -2.    0.94  0.55]
# Episode 21,total_reward: 84.830, mean five: 67.200, total mean 25.234, EPS: 9.85e-02
# updated!!!! 67.200 ---------------------
# Episode 22,  adapt. coeffs at final time step:  [ 3.02 -2.    0.94  0.55]
# Episode 22,total_reward: 89.241, mean five: 68.233, total mean 27.943, EPS: 8.86e-02
# updated!!!! 68.233 ---------------------
# Episode 23,  adapt. coeffs at final time step:  [ 3.02 -2.01  0.94  0.55]
# Episode 23,total_reward: -58.505, mean five: 39.071, total mean 30.608, EPS: 7.98e-02
# Episode 24,  adapt. coeffs at final time step:  [ 3.04 -2.02  0.95  0.6 ]
# Episode 24,total_reward: 37.229, mean five: 48.152, total mean 26.895, EPS: 7.18e-02
# Episode 25,  adapt. coeffs at final time step:  [ 3.2  -2.18  1.    0.61]
# Episode 25,total_reward: 58.401, mean five: 42.239, total mean 27.308, EPS: 6.46e-02
# Episode 26,  adapt. coeffs at final time step:  [ 3.2  -2.18  1.    0.61]
# Episode 26,total_reward: 91.580, mean five: 43.589, total mean 28.504, EPS: 5.81e-02
# Episode 27,  adapt. coeffs at final time step:  [ 3.24 -2.22  1.02  0.62]
# Episode 27,total_reward: 84.535, mean five: 42.648, total mean 30.840, EPS: 5.23e-02
# Episode 28,  adapt. coeffs at final time step:  [ 3.1  -2.08  0.97  0.62]
# Episode 28,total_reward: 93.499, mean five: 73.049, total mean 32.758, EPS: 4.71e-02
# updated!!!! 73.049 ---------------------
# Episode 29,  adapt. coeffs at final time step:  [ 3.02 -2.    0.94  0.7 ]
# Episode 29,total_reward: 92.067, mean five: 84.017, total mean 34.852, EPS: 4.24e-02
# updated!!!! 84.017 ---------------------
# Episode 30,  adapt. coeffs at final time step:  [ 2.98 -1.96  0.92  0.73]
# Episode 30,total_reward: 93.020, mean five: 90.940, total mean 36.759, EPS: 3.82e-02
# updated!!!! 90.940 ---------------------
# Episode 31,  adapt. coeffs at final time step:  [ 3.14 -2.13  0.98  0.73]
# Episode 31,total_reward: 92.147, mean five: 91.054, total mean 38.574, EPS: 3.43e-02
# updated!!!! 91.054 ---------------------
# Episode 32,  adapt. coeffs at final time step:  [ 3.13 -2.12  0.98  0.73]
# Episode 32,total_reward: 93.510, mean five: 92.849, total mean 40.248, EPS: 3.09e-02
# updated!!!! 92.849 ---------------------
# Episode 33,  adapt. coeffs at final time step:  [ 3.08 -2.08  0.96  0.73]
# Episode 33,total_reward: -98.971, mean five: 54.355, total mean 41.862, EPS: 2.78e-02
# Episode 34,  adapt. coeffs at final time step:  [ 3.31 -2.31  1.05  0.73]
# Episode 34,total_reward: -99.602, mean five: 16.021, total mean 37.720, EPS: 2.50e-02
# Episode 35,  adapt. coeffs at final time step:  [ 3.41 -2.4   1.08  0.73]
# Episode 35,total_reward: -99.551, mean five: -22.494, total mean 33.797, EPS: 2.25e-02
# Episode 36,  adapt. coeffs at final time step:  [ 3.47 -2.47  1.11  0.73]
# Episode 36,total_reward: -99.635, mean five: -60.850, total mean 30.093, EPS: 2.03e-02
# Episode 37,  adapt. coeffs at final time step:  [ 3.16 -2.14  0.99  0.75]
# Episode 37,total_reward: 71.207, mean five: -65.311, total mean 26.587, EPS: 1.82e-02
# Episode 38,  adapt. coeffs at final time step:  [ 3.17 -2.15  0.99  0.75]
# Episode 38,total_reward: 90.056, mean five: -27.505, total mean 27.761, EPS: 1.64e-02
# Episode 39,  adapt. coeffs at final time step:  [ 3.67 -2.65  1.18  0.75]
# Episode 39,total_reward: 89.554, mean five: 10.326, total mean 29.358, EPS: 1.48e-02
# Episode 40,  adapt. coeffs at final time step:  [ 3.69 -2.67  1.18  0.75]
# Episode 40,total_reward: 89.898, mean five: 48.216, total mean 30.863, EPS: 1.33e-02
# Episode 41,  adapt. coeffs at final time step:  [ 3.69 -2.68  1.18  0.75]
# Episode 41,total_reward: 89.803, mean five: 86.104, total mean 32.303, EPS: 1.20e-02
# Episode 42,  adapt. coeffs at final time step:  [ 3.45 -2.44  1.1   0.76]
# Episode 42,total_reward: 93.984, mean five: 90.659, total mean 33.672, EPS: 1.08e-02
# Episode 43,  adapt. coeffs at final time step:  [ 3.25 -2.24  1.02  0.76]
# Episode 43,total_reward: 93.742, mean five: 91.396, total mean 35.075, EPS: 9.70e-03
# Episode 44,  adapt. coeffs at final time step:  [ 3.15 -2.15  0.99  0.76]
# Episode 44,total_reward: 93.874, mean five: 92.260, total mean 36.408, EPS: 8.73e-03
# Episode 45,  adapt. coeffs at final time step:  [ 3.03 -2.02  0.94  0.76]
# Episode 45,total_reward: 93.099, mean five: 92.900, total mean 37.685, EPS: 7.86e-03
# updated!!!! 92.900 ---------------------
# Episode 46,  adapt. coeffs at final time step:  [ 2.97 -1.96  0.92  0.77]
# Episode 46,total_reward: 93.221, mean five: 93.584, total mean 38.890, EPS: 7.07e-03
# updated!!!! 93.584 ---------------------
# Episode 47,  adapt. coeffs at final time step:  [ 2.95 -1.94  0.91  0.77]
# Episode 47,total_reward: 94.064, mean five: 93.600, total mean 40.046, EPS: 6.36e-03
# updated!!!! 93.600 ---------------------
# Episode 48,  adapt. coeffs at final time step:  [ 2.97 -1.96  0.92  0.78]
# Episode 48,total_reward: 89.549, mean five: 92.761, total mean 41.171, EPS: 5.73e-03
# Episode 49,  adapt. coeffs at final time step:  [ 2.99 -1.97  0.93  0.78]
# Episode 49,total_reward: 91.914, mean five: 92.369, total mean 42.158, EPS: 5.15e-03
# Episode 50,  adapt. coeffs at final time step:  [ 2.97 -1.96  0.92  0.78]
# Episode 50,total_reward: 93.162, mean five: 92.382, total mean 43.153, EPS: 4.64e-03
# Episode 51,  adapt. coeffs at final time step:  [ 3.01 -1.99  0.93  0.78]
# Episode 51,total_reward: 92.973, mean five: 92.332, total mean 44.134, EPS: 4.17e-03
# Episode 52,  adapt. coeffs at final time step:  [ 3.05 -2.04  0.95  0.78]
# Episode 52,total_reward: 93.256, mean five: 92.171, total mean 45.073, EPS: 3.76e-03
# Episode 53,  adapt. coeffs at final time step:  [ 3.02 -2.01  0.94  0.78]
# Episode 53,total_reward: 92.881, mean five: 92.837, total mean 45.982, EPS: 3.38e-03
# Episode 54,  adapt. coeffs at final time step:  [ 2.98 -1.96  0.92  0.78]
# Episode 54,total_reward: 90.561, mean five: 92.567, total mean 46.851, EPS: 3.04e-03
# Episode 55,  adapt. coeffs at final time step:  [ 3.04 -2.03  0.95  0.78]
# Episode 55,total_reward: 93.602, mean five: 92.655, total mean 47.645, EPS: 2.74e-03
# Episode 56,  adapt. coeffs at final time step:  [ 3.05 -2.04  0.95  0.79]
# Episode 56,total_reward: 93.840, mean five: 92.828, total mean 48.466, EPS: 2.47e-03
# Episode 57,  adapt. coeffs at final time step:  [ 3.   -2.    0.93  0.8 ]
# Episode 57,total_reward: 93.115, mean five: 92.800, total mean 49.262, EPS: 2.22e-03
# Episode 58,  adapt. coeffs at final time step:  [ 2.97 -1.97  0.92  0.81]
# Episode 58,total_reward: 93.863, mean five: 92.996, total mean 50.018, EPS: 2.00e-03
# Episode 59,  adapt. coeffs at final time step:  [ 3.03 -2.02  0.94  0.81]
# Episode 59,total_reward: 94.205, mean five: 93.725, total mean 50.761, EPS: 1.80e-03
# updated!!!! 93.725 ---------------------
# Episode 60,  adapt. coeffs at final time step:  [ 3.23 -2.22  1.02  0.81]
# Episode 60,total_reward: 94.641, mean five: 93.933, total mean 51.485, EPS: 1.62e-03
# updated!!!! 93.933 ---------------------
# Episode 61,  adapt. coeffs at final time step:  [ 3.14 -2.14  0.99  0.81]
# Episode 61,total_reward: 94.649, mean five: 94.095, total mean 52.193, EPS: 1.46e-03
# updated!!!! 94.095 ---------------------
# Episode 62,  adapt. coeffs at final time step:  [ 3.14 -2.13  0.98  0.82]
# Episode 62,total_reward: 94.624, mean five: 94.397, total mean 52.878, EPS: 1.31e-03
# updated!!!! 94.397 ---------------------
# Episode 63,  adapt. coeffs at final time step:  [ 3.19 -2.18  1.    0.83]
# Episode 63,total_reward: 94.321, mean five: 94.488, total mean 53.540, EPS: 1.18e-03
# updated!!!! 94.488 ---------------------
# Episode 64,  adapt. coeffs at final time step:  [ 3.11 -2.1   0.97  0.84]
# Episode 64,total_reward: 85.089, mean five: 92.665, total mean 54.177, EPS: 1.06e-03
# Episode 65,  adapt. coeffs at final time step:  [ 3.22 -2.21  1.01  0.86]
# Episode 65,total_reward: 94.420, mean five: 92.621, total mean 54.653, EPS: 9.55e-04
# Episode 66,  adapt. coeffs at final time step:  [ 3.2  -2.2   1.01  0.86]
# Episode 66,total_reward: 94.330, mean five: 92.557, total mean 55.256, EPS: 8.60e-04
# Episode 67,  adapt. coeffs at final time step:  [ 3.12 -2.11  0.98  0.86]
# Episode 67,total_reward: 94.797, mean five: 92.591, total mean 55.839, EPS: 7.74e-04
# Episode 68,  adapt. coeffs at final time step:  [ 3.08 -2.07  0.96  0.87]
# Episode 68,total_reward: 94.195, mean five: 92.566, total mean 56.412, EPS: 6.96e-04
# Episode 69,  adapt. coeffs at final time step:  [ 3.1  -2.09  0.97  0.87]
# Episode 69,total_reward: 94.801, mean five: 94.509, total mean 56.959, EPS: 6.27e-04
# updated!!!! 94.509 ---------------------
# Episode 70,  adapt. coeffs at final time step:  [ 3.12 -2.11  0.98  0.89]
# Episode 70,total_reward: 94.036, mean five: 94.432, total mean 57.500, EPS: 5.64e-04
# Episode 71,  adapt. coeffs at final time step:  [ 3.12 -2.11  0.98  0.89]
# Episode 71,total_reward: 94.724, mean five: 94.511, total mean 58.014, EPS: 5.08e-04
# updated!!!! 94.511 ---------------------
# Episode 72,  adapt. coeffs at final time step:  [ 3.15 -2.14  0.99  0.89]
# Episode 72,total_reward: 94.335, mean five: 94.418, total mean 58.524, EPS: 4.57e-04
# Episode 73,  adapt. coeffs at final time step:  [ 3.24 -2.24  1.02  0.89]
# Episode 73,total_reward: 94.534, mean five: 94.486, total mean 59.015, EPS: 4.11e-04
# Episode 74,  adapt. coeffs at final time step:  [ 3.16 -2.15  0.99  0.9 ]
# Episode 74,total_reward: 86.022, mean five: 92.730, total mean 59.495, EPS: 3.70e-04
# Episode 75,  adapt. coeffs at final time step:  [ 3.22 -2.22  1.01  0.9 ]
# Episode 75,total_reward: 93.646, mean five: 92.652, total mean 59.849, EPS: 3.33e-04
# Episode 76,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  0.91]
# Episode 76,total_reward: 94.284, mean five: 92.564, total mean 60.293, EPS: 3.00e-04
# Episode 77,  adapt. coeffs at final time step:  [ 3.16 -2.16  0.99  0.91]
# Episode 77,total_reward: 94.262, mean five: 92.550, total mean 60.735, EPS: 2.70e-04
# Episode 78,  adapt. coeffs at final time step:  [ 3.1  -2.09  0.97  0.91]
# Episode 78,total_reward: 94.951, mean five: 92.633, total mean 61.165, EPS: 2.43e-04
# Episode 79,  adapt. coeffs at final time step:  [ 3.05 -2.04  0.95  0.92]
# Episode 79,total_reward: 93.697, mean five: 94.168, total mean 61.592, EPS: 2.18e-04
# Episode 80,  adapt. coeffs at final time step:  [ 3.03 -2.03  0.95  0.93]
# Episode 80,total_reward: 93.910, mean five: 94.221, total mean 61.994, EPS: 1.97e-04
# Episode 81,  adapt. coeffs at final time step:  [ 3.07 -2.07  0.96  0.93]
# Episode 81,total_reward: 94.170, mean five: 94.198, total mean 62.388, EPS: 1.77e-04
# Episode 82,  adapt. coeffs at final time step:  [ 3.03 -2.03  0.95  0.94]
# Episode 82,total_reward: 93.985, mean five: 94.143, total mean 62.775, EPS: 1.59e-04
# Episode 83,  adapt. coeffs at final time step:  [ 3.01 -2.01  0.94  0.93]
# Episode 83,total_reward: 93.471, mean five: 93.847, total mean 63.151, EPS: 1.43e-04
# Episode 84,  adapt. coeffs at final time step:  [ 3.11 -2.1   0.97  0.95]
# Episode 84,total_reward: 93.188, mean five: 93.745, total mean 63.512, EPS: 1.29e-04
# Episode 85,  adapt. coeffs at final time step:  [ 3.07 -2.07  0.96  0.95]
# Episode 85,total_reward: 89.241, mean five: 92.811, total mean 63.861, EPS: 1.16e-04
# Episode 86,  adapt. coeffs at final time step:  [ 3.02 -2.02  0.94  0.95]
# Episode 86,total_reward: 93.248, mean five: 92.627, total mean 64.156, EPS: 1.04e-04
# Episode 87,  adapt. coeffs at final time step:  [ 2.98 -1.98  0.93  0.95]
# Episode 87,total_reward: 92.290, mean five: 92.288, total mean 64.491, EPS: 9.40e-05
# Episode 88,  adapt. coeffs at final time step:  [ 2.99 -1.99  0.93  0.96]
# Episode 88,total_reward: 91.357, mean five: 91.865, total mean 64.807, EPS: 8.46e-05
# Episode 89,  adapt. coeffs at final time step:  [ 2.96 -1.96  0.92  0.96]
# Episode 89,total_reward: 83.204, mean five: 89.868, total mean 65.105, EPS: 7.62e-05
# Episode 90,  adapt. coeffs at final time step:  [ 3.02 -2.02  0.94  0.97]
# Episode 90,total_reward: 90.059, mean five: 90.032, total mean 65.306, EPS: 6.86e-05
# Episode 91,  adapt. coeffs at final time step:  [ 3.04 -2.04  0.95  0.97]
# Episode 91,total_reward: 93.020, mean five: 89.986, total mean 65.578, EPS: 6.17e-05
# Episode 92,  adapt. coeffs at final time step:  [ 3.02 -2.02  0.94  0.97]
# Episode 92,total_reward: 91.522, mean five: 89.833, total mean 65.876, EPS: 5.55e-05
# Episode 93,  adapt. coeffs at final time step:  [ 2.99 -1.99  0.93  0.97]
# Episode 93,total_reward: 93.020, mean five: 90.165, total mean 66.152, EPS: 5.00e-05
# Episode 94,  adapt. coeffs at final time step:  [ 3.01 -2.01  0.94  0.97]
# Episode 94,total_reward: 92.602, mean five: 92.045, total mean 66.438, EPS: 4.50e-05
# Episode 95,  adapt. coeffs at final time step:  [ 3.   -2.    0.93  0.97]
# Episode 95,total_reward: 93.222, mean five: 92.677, total mean 66.713, EPS: 4.05e-05
# Episode 96,  adapt. coeffs at final time step:  [ 2.97 -1.97  0.92  0.97]
# Episode 96,total_reward: 94.063, mean five: 92.886, total mean 66.990, EPS: 3.64e-05
# Episode 97,  adapt. coeffs at final time step:  [ 3.07 -2.07  0.96  0.98]
# Episode 97,total_reward: 93.825, mean five: 93.346, total mean 67.269, EPS: 3.28e-05
# Episode 98,  adapt. coeffs at final time step:  [ 3.17 -2.16  0.99  0.98]
# Episode 98,total_reward: 93.403, mean five: 93.423, total mean 67.540, EPS: 2.95e-05
# Episode 99,  adapt. coeffs at final time step:  [ 3.13 -2.13  0.98  0.98]
# Episode 99,total_reward: 94.371, mean five: 93.777, total mean 67.801, EPS: 2.66e-05

# %%
aql.actor = torch.load(path+"model.pickle",weights_only=False).to("cuda" if torch.cuda.is_available() else "cpu")

# %%
#Test('model.pickle', rewards, 30, mu0 = k_hat_print).picture()

# %%
#env.MRAC.k_hat = ploting_adapt_coeff[-1]
#env.MRAC.k_temp = ploting_adapt_coeff[-1]

# %%
# Test
#save_observation_temp = []
#save_u1_temp = []
#save_pid_u1_temp = []
#save_ctrl_voltage_temp = []
rewards_test = []
episode_length_test = []
total_episodes_test = 100
best_score = -1000
least_episode_length = 1000

# %%
print('Test')
for i in range(total_episodes_test):
    s = env.reset()
    #state = np.asarray(state[0])
    #s = np.expand_dims(state, axis=0)
    save_observation_temp = [s]
    save_wanted_force_temp = [0.0]
    save_actual_force_temp = [0.0]
    save_model_force_temp = [0.0]
    save_ctrl_voltage_temp = [0.0]
    save_MRAC_adapt_gains_temp= [env.MRAC.k_hat]
    total_reward = 0
    done = False
    t_=0
    while not done:
        k_hat_print = env.MRAC.k_hat.round(2)
        s = torch.tensor(s, dtype = torch.float).unsqueeze(0)
        with torch.no_grad():
            a = aql.actor(s)
        action = a.item()
        next_state, reward, done, _ , wanted_force , actual_force= env.step(action)
        save_observation_temp.append(next_state)
        save_wanted_force_temp.append(wanted_force)
        save_actual_force_temp.append(actual_force)
        save_model_force_temp.append(env.MRAC.y_m)
        save_ctrl_voltage_temp.append(env.MRAC.u)
        save_MRAC_adapt_gains_temp.append(env.MRAC.k_hat)
        state = next_state
        s = np.expand_dims(state, axis=0) ####change
        total_reward += reward
        t_+=1

    episode_length_test.append(t_)
    #save_ctrl_voltage_temp.append(env.DCMotorModel.voltage_input)
    # get best score and update save data
    print(f'Episode {i},'
          f'total_reward: {total_reward:.3f}, Episode Length {t_}')
    print(f"Episode: {i}, ", "adapt. coeffs at final time step: ", k_hat_print)
    if best_score<total_reward and least_episode_length>t_:
        save_observation = list(save_observation_temp)
        save_wanted_force = list(save_wanted_force_temp)
        save_actual_force = list(save_actual_force_temp)
        save_model_force = list(save_model_force_temp)
        save_ctrl_voltage = list(save_ctrl_voltage_temp)
        save_MRAC_adapt_gains = list(save_MRAC_adapt_gains_temp)
        best_score = total_reward
        least_episode_length = t_
        best_episode = i
        print(f"---Best Episode:{best_episode}; Best Score:{best_score}----")
    rewards_test.append(total_reward)
# Out:
# Test
# Episode 0,total_reward: 91.489, Episode Length 141
# Episode: 0,  adapt. coeffs at final time step:  [ 3.12 -2.12  0.98  0.98]
# ---Best Episode:0; Best Score:91.48871950024534----
# Episode 1,total_reward: 94.141, Episode Length 85
# Episode: 1,  adapt. coeffs at final time step:  [ 3.13 -2.13  0.98  0.98]
# ---Best Episode:1; Best Score:94.14054335439032----
# Episode 2,total_reward: 94.636, Episode Length 75
# Episode: 2,  adapt. coeffs at final time step:  [ 3.23 -2.23  1.02  0.98]
# ---Best Episode:2; Best Score:94.6357226692854----
# Episode 3,total_reward: 94.633, Episode Length 75
# Episode: 3,  adapt. coeffs at final time step:  [ 3.28 -2.28  1.04  0.98]
# Episode 4,total_reward: 94.632, Episode Length 75
# Episode: 4,  adapt. coeffs at final time step:  [ 3.31 -2.31  1.05  0.98]
# Episode 5,total_reward: 94.627, Episode Length 75
# Episode: 5,  adapt. coeffs at final time step:  [ 3.33 -2.32  1.05  0.98]
# Episode 6,total_reward: 93.836, Episode Length 90
# Episode: 6,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  0.98]
# Episode 7,total_reward: 94.630, Episode Length 75
# Episode: 7,  adapt. coeffs at final time step:  [ 3.28 -2.28  1.04  0.98]
# Episode 8,total_reward: 94.632, Episode Length 75
# Episode: 8,  adapt. coeffs at final time step:  [ 3.31 -2.31  1.05  0.98]
# Episode 9,total_reward: 94.448, Episode Length 78
# Episode: 9,  adapt. coeffs at final time step:  [ 3.29 -2.28  1.04  0.98]
# Episode 10,total_reward: 94.630, Episode Length 75
# Episode: 10,  adapt. coeffs at final time step:  [ 3.29 -2.29  1.04  0.98]
# Episode 11,total_reward: 91.517, Episode Length 142
# Episode: 11,  adapt. coeffs at final time step:  [ 3.23 -2.23  1.02  0.98]
# Episode 12,total_reward: 94.435, Episode Length 79
# Episode: 12,  adapt. coeffs at final time step:  [ 3.22 -2.22  1.02  0.98]
# Episode 13,total_reward: 94.387, Episode Length 80
# Episode: 13,  adapt. coeffs at final time step:  [ 3.21 -2.21  1.01  0.98]
# Episode 14,total_reward: 94.072, Episode Length 86
# Episode: 14,  adapt. coeffs at final time step:  [ 3.19 -2.19  1.    0.98]
# Episode 15,total_reward: 94.640, Episode Length 75
# Episode: 15,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  0.98]
# Episode 16,total_reward: 92.922, Episode Length 102
# Episode: 16,  adapt. coeffs at final time step:  [ 3.21 -2.21  1.01  0.98]
# Episode 17,total_reward: 94.356, Episode Length 80
# Episode: 17,  adapt. coeffs at final time step:  [ 3.21 -2.21  1.01  0.98]
# Episode 18,total_reward: 91.362, Episode Length 141
# Episode: 18,  adapt. coeffs at final time step:  [ 3.17 -2.17  1.    0.98]
# Episode 19,total_reward: 94.175, Episode Length 84
# Episode: 19,  adapt. coeffs at final time step:  [ 3.16 -2.16  0.99  0.98]
# Episode 20,total_reward: 94.628, Episode Length 75
# Episode: 20,  adapt. coeffs at final time step:  [ 3.22 -2.22  1.01  0.98]
# Episode 21,total_reward: 94.657, Episode Length 75
# Episode: 21,  adapt. coeffs at final time step:  [ 3.28 -2.28  1.04  0.98]
# Episode 22,total_reward: 94.633, Episode Length 75
# Episode: 22,  adapt. coeffs at final time step:  [ 3.31 -2.31  1.05  0.98]
# Episode 23,total_reward: 94.302, Episode Length 82
# Episode: 23,  adapt. coeffs at final time step:  [ 3.27 -2.27  1.03  0.98]
# Episode 24,total_reward: 94.490, Episode Length 77
# Episode: 24,  adapt. coeffs at final time step:  [ 3.27 -2.27  1.03  0.98]
# Episode 25,total_reward: 94.168, Episode Length 84
# Episode: 25,  adapt. coeffs at final time step:  [ 3.23 -2.23  1.02  0.98]
# Episode 26,total_reward: 94.633, Episode Length 75
# Episode: 26,  adapt. coeffs at final time step:  [ 3.28 -2.28  1.04  0.98]
# Episode 27,total_reward: 94.629, Episode Length 75
# Episode: 27,  adapt. coeffs at final time step:  [ 3.29 -2.29  1.04  0.98]
# Episode 28,total_reward: 94.626, Episode Length 75
# Episode: 28,  adapt. coeffs at final time step:  [ 3.31 -2.31  1.05  0.98]
# Episode 29,total_reward: 94.574, Episode Length 76
# Episode: 29,  adapt. coeffs at final time step:  [ 3.3  -2.3   1.04  0.98]
# Episode 30,total_reward: 94.269, Episode Length 82
# Episode: 30,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  0.98]
# Episode 31,total_reward: 94.114, Episode Length 85
# Episode: 31,  adapt. coeffs at final time step:  [ 3.22 -2.22  1.02  0.98]
# Episode 32,total_reward: 94.640, Episode Length 75
# Episode: 32,  adapt. coeffs at final time step:  [ 3.28 -2.28  1.04  0.98]
# Episode 33,total_reward: 87.448, Episode Length 174
# Episode: 33,  adapt. coeffs at final time step:  [ 3.   -1.99  0.93  0.98]
# Episode 34,total_reward: 94.632, Episode Length 75
# Episode: 34,  adapt. coeffs at final time step:  [ 3.15 -2.14  0.99  0.98]
# Episode 35,total_reward: 94.662, Episode Length 75
# Episode: 35,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.02  0.98]
# Episode 36,total_reward: 94.441, Episode Length 79
# Episode: 36,  adapt. coeffs at final time step:  [ 3.23 -2.23  1.02  0.98]
# Episode 37,total_reward: 94.625, Episode Length 75
# Episode: 37,  adapt. coeffs at final time step:  [ 3.27 -2.27  1.03  0.98]
# Episode 38,total_reward: 94.008, Episode Length 87
# Episode: 38,  adapt. coeffs at final time step:  [ 3.23 -2.23  1.02  0.98]
# Episode 39,total_reward: 94.634, Episode Length 75
# Episode: 39,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# Episode 40,total_reward: 94.485, Episode Length 77
# Episode: 40,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# Episode 41,total_reward: 92.129, Episode Length 111
# Episode: 41,  adapt. coeffs at final time step:  [ 3.2  -2.2   1.01  0.98]
# Episode 42,total_reward: 94.626, Episode Length 75
# Episode: 42,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# Episode 43,total_reward: 94.625, Episode Length 75
# Episode: 43,  adapt. coeffs at final time step:  [ 3.28 -2.28  1.04  0.98]
# Episode 44,total_reward: 94.484, Episode Length 77
# Episode: 44,  adapt. coeffs at final time step:  [ 3.27 -2.27  1.03  0.98]
# Episode 45,total_reward: 94.183, Episode Length 84
# Episode: 45,  adapt. coeffs at final time step:  [ 3.24 -2.24  1.02  0.98]
# Episode 46,total_reward: 93.696, Episode Length 92
# Episode: 46,  adapt. coeffs at final time step:  [ 3.2  -2.2   1.01  0.98]
# Episode 47,total_reward: 94.626, Episode Length 75
# Episode: 47,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.02  0.98]
# Episode 48,total_reward: 93.999, Episode Length 87
# Episode: 48,  adapt. coeffs at final time step:  [ 3.21 -2.21  1.01  0.98]
# Episode 49,total_reward: 94.636, Episode Length 75
# Episode: 49,  adapt. coeffs at final time step:  [ 3.24 -2.24  1.02  0.98]
# Episode 50,total_reward: 94.651, Episode Length 75
# Episode: 50,  adapt. coeffs at final time step:  [ 3.29 -2.29  1.04  0.98]
# Episode 51,total_reward: 94.488, Episode Length 78
# Episode: 51,  adapt. coeffs at final time step:  [ 3.27 -2.27  1.03  0.98]
# Episode 52,total_reward: 94.664, Episode Length 75
# Episode: 52,  adapt. coeffs at final time step:  [ 3.32 -2.32  1.05  0.98]
# Episode 53,total_reward: 94.405, Episode Length 79
# Episode: 53,  adapt. coeffs at final time step:  [ 3.29 -2.29  1.04  0.98]
# Episode 54,total_reward: 94.136, Episode Length 85
# Episode: 54,  adapt. coeffs at final time step:  [ 3.24 -2.24  1.02  0.98]
# Episode 55,total_reward: 94.483, Episode Length 78
# Episode: 55,  adapt. coeffs at final time step:  [ 3.24 -2.23  1.02  0.97]
# Episode 56,total_reward: 94.626, Episode Length 75
# Episode: 56,  adapt. coeffs at final time step:  [ 3.28 -2.28  1.04  0.97]
# Episode 57,total_reward: 94.652, Episode Length 75
# Episode: 57,  adapt. coeffs at final time step:  [ 3.32 -2.31  1.05  0.97]
# Episode 58,total_reward: 94.630, Episode Length 75
# Episode: 58,  adapt. coeffs at final time step:  [ 3.31 -2.31  1.05  0.97]
# Episode 59,total_reward: 94.542, Episode Length 76
# Episode: 59,  adapt. coeffs at final time step:  [ 3.31 -2.3   1.05  0.97]
# Episode 60,total_reward: 94.534, Episode Length 77
# Episode: 60,  adapt. coeffs at final time step:  [ 3.29 -2.28  1.04  0.97]
# Episode 61,total_reward: 94.635, Episode Length 75
# Episode: 61,  adapt. coeffs at final time step:  [ 3.31 -2.31  1.05  0.97]
# Episode 62,total_reward: 93.764, Episode Length 91
# Episode: 62,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# Episode 63,total_reward: 94.633, Episode Length 75
# Episode: 63,  adapt. coeffs at final time step:  [ 3.27 -2.27  1.03  0.97]
# Episode 64,total_reward: 91.463, Episode Length 141
# Episode: 64,  adapt. coeffs at final time step:  [ 3.21 -2.21  1.01  0.97]
# Episode 65,total_reward: 91.329, Episode Length 141
# Episode: 65,  adapt. coeffs at final time step:  [ 3.17 -2.17  1.    0.97]
# Episode 66,total_reward: 94.551, Episode Length 76
# Episode: 66,  adapt. coeffs at final time step:  [ 3.21 -2.21  1.01  0.97]
# Episode 67,total_reward: 94.545, Episode Length 76
# Episode: 67,  adapt. coeffs at final time step:  [ 3.24 -2.24  1.02  0.97]
# Episode 68,total_reward: 94.625, Episode Length 75
# Episode: 68,  adapt. coeffs at final time step:  [ 3.27 -2.27  1.03  0.97]
# Episode 69,total_reward: 94.370, Episode Length 80
# Episode: 69,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# Episode 70,total_reward: 94.626, Episode Length 75
# Episode: 70,  adapt. coeffs at final time step:  [ 3.28 -2.28  1.04  0.97]
# Episode 71,total_reward: 94.438, Episode Length 79
# Episode: 71,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# Episode 72,total_reward: 94.230, Episode Length 83
# Episode: 72,  adapt. coeffs at final time step:  [ 3.23 -2.23  1.02  0.97]
# Episode 73,total_reward: 91.486, Episode Length 142
# Episode: 73,  adapt. coeffs at final time step:  [ 3.18 -2.18  1.    0.97]
# Episode 74,total_reward: 94.537, Episode Length 76
# Episode: 74,  adapt. coeffs at final time step:  [ 3.22 -2.22  1.02  0.97]
# Episode 75,total_reward: 94.581, Episode Length 76
# Episode: 75,  adapt. coeffs at final time step:  [ 3.24 -2.24  1.02  0.97]
# Episode 76,total_reward: 94.399, Episode Length 79
# Episode: 76,  adapt. coeffs at final time step:  [ 3.23 -2.23  1.02  0.97]
# Episode 77,total_reward: 94.544, Episode Length 76
# Episode: 77,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.97]
# Episode 78,total_reward: 93.769, Episode Length 91
# Episode: 78,  adapt. coeffs at final time step:  [ 3.21 -2.2   1.01  0.97]
# Episode 79,total_reward: 94.631, Episode Length 75
# Episode: 79,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  0.97]
# Episode 80,total_reward: 94.543, Episode Length 76
# Episode: 80,  adapt. coeffs at final time step:  [ 3.27 -2.27  1.03  0.97]
# Episode 81,total_reward: 93.843, Episode Length 90
# Episode: 81,  adapt. coeffs at final time step:  [ 3.22 -2.22  1.02  0.97]
# Episode 82,total_reward: 91.522, Episode Length 141
# Episode: 82,  adapt. coeffs at final time step:  [ 3.18 -2.18  1.    0.97]
# Episode 83,total_reward: 94.567, Episode Length 76
# Episode: 83,  adapt. coeffs at final time step:  [ 3.21 -2.21  1.01  0.97]
# Episode 84,total_reward: 94.625, Episode Length 75
# Episode: 84,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  0.97]
# Episode 85,total_reward: 91.451, Episode Length 141
# Episode: 85,  adapt. coeffs at final time step:  [ 3.21 -2.2   1.01  0.97]
# Episode 86,total_reward: 93.392, Episode Length 96
# Episode: 86,  adapt. coeffs at final time step:  [ 3.17 -2.17  1.    0.98]
# Episode 87,total_reward: 94.626, Episode Length 75
# Episode: 87,  adapt. coeffs at final time step:  [ 3.23 -2.23  1.02  0.98]
# Episode 88,total_reward: 93.632, Episode Length 93
# Episode: 88,  adapt. coeffs at final time step:  [ 3.19 -2.19  1.    0.98]
# Episode 89,total_reward: 93.972, Episode Length 88
# Episode: 89,  adapt. coeffs at final time step:  [ 3.17 -2.17  1.    0.98]
# Episode 90,total_reward: 94.428, Episode Length 79
# Episode: 90,  adapt. coeffs at final time step:  [ 3.18 -2.18  1.    0.98]
# Episode 91,total_reward: 94.627, Episode Length 75
# Episode: 91,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# Episode 92,total_reward: 94.626, Episode Length 75
# Episode: 92,  adapt. coeffs at final time step:  [ 3.28 -2.28  1.04  0.98]
# Episode 93,total_reward: 94.352, Episode Length 81
# Episode: 93,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]
# Episode 94,total_reward: 94.544, Episode Length 76
# Episode: 94,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  0.98]
# Episode 95,total_reward: 94.626, Episode Length 75
# Episode: 95,  adapt. coeffs at final time step:  [ 3.29 -2.28  1.04  0.98]
# Episode 96,total_reward: 92.126, Episode Length 111
# Episode: 96,  adapt. coeffs at final time step:  [ 3.23 -2.23  1.02  0.98]
# Episode 97,total_reward: 94.318, Episode Length 81
# Episode: 97,  adapt. coeffs at final time step:  [ 3.21 -2.21  1.01  0.98]
# Episode 98,total_reward: 94.626, Episode Length 75
# Episode: 98,  adapt. coeffs at final time step:  [ 3.26 -2.26  1.03  0.98]
# Episode 99,total_reward: 94.533, Episode Length 77
# Episode: 99,  adapt. coeffs at final time step:  [ 3.25 -2.25  1.03  0.98]

# %%
save_observation_temp = None
save_wanted_force_temp = None
save_actual_force_temp = None
save_model_force_temp = None
save_ctrl_voltage_temp = None
save_MRAC_adapt_gains_temp= None

# %%
# Create a dictionary of variables you want to save

variables_to_save = {
    'rewards': rewards,
    'save_observation': save_observation,
    'save_wanted_force': save_wanted_force,
    'save_actual_force': save_actual_force,
    'save_model_force': save_model_force,
    'save_ctrl_voltage': save_ctrl_voltage,
    'aql': aql,
    'rewards_test':rewards_test,
    'save_MRAC_adapt_gains': save_MRAC_adapt_gains,
    'ploting_adapt_coeff': ploting_adapt_coeff,
    'episode_length_test': episode_length_test
}

# %%
path = '/content/drive/MyDrive/Colab Notebooks/codes/MRAC/save_data/Cont_Mount_Car/'

# %%
with open(path+'Cont_Moun_Car.pkl', 'wb') as f:
    pickle.dump(variables_to_save, f)
print(f"All variables saved to {path+'Cont_Moun_Car.pkl'}")
# Out:
# All variables saved to /content/drive/MyDrive/Colab Notebooks/codes/MRAC/save_data/Cont_Mount_Car/Cont_Moun_Car.pkl

# %%
# Open the file in read-binary mode and load the dictionary
with open(path+'Cont_Moun_Car.pkl', 'rb') as f:
    loaded_variables = pickle.load(f)

# Access the loaded variables
rewards = loaded_variables['rewards']
save_observation = loaded_variables['save_observation']
save_wanted_force = loaded_variables['save_wanted_force']
save_actual_force = loaded_variables['save_actual_force']
save_model_force = loaded_variables['save_model_force']
save_ctrl_voltage = loaded_variables['save_ctrl_voltage']
aql = loaded_variables['aql']
rewards_test = loaded_variables['rewards_test']
ploting_adapt_coeff = loaded_variables['ploting_adapt_coeff']
save_MRAC_adapt_gains = loaded_variables['save_MRAC_adapt_gains']
episode_length_test = loaded_variables['episode_length_test']
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
aql.actor = torch.load(path+"model.pickle",weights_only=False).to(device)

# %%
plt.rc('text.latex', preamble=r'\usepackage{amsmath,amssymb,amsfonts}')
#plt.rcParams["text.usetex"]=False
#plt.rcParams["font.family"] = "sans-serif"
#plt.rcParams["font.family"] = "serif"
#plt.rcParams['mathtext.fontset'] = 'cm'
#plt.rcParams['mathtext.fontset'] = 'dejavusans'
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'

# %%
def unnorm_to_norm(x):
  y = (x-low_bound_reward_list)/(up_bound_reward_list-low_bound_reward_list)
  return y

# %%
def norm_to_unnorm(y):
  x=y*(up_bound_reward_list-low_bound_reward_list)+low_bound_reward_list
  return x

# %%
low_bound_reward_list = -100 # -0.1*(1**2 force mag)*(1000*episoded)s
up_bound_reward_list = 100
print("low_bound_reward_list=",low_bound_reward_list)
print("up_bound_reward_list=",up_bound_reward_list)
norm_reward_list = np.array(rewards)
norm_reward_list = unnorm_to_norm(norm_reward_list)
# Out:
# low_bound_reward_list= -100
# up_bound_reward_list= 100

# %%
import matplotlib.pyplot as plt

font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
#plt.plot(plotting_rewards)
plt.plot(rewards, label = "Acc. Episodic Reward",color="C0",linewidth = 1.5)
plt.axhline(y=np.array(rewards)[-20:-1].mean(), linestyle='--',
            label = "Acc. Episodic Reward's last 20 mean= "+f"{np.array(rewards)[-20:-1].mean():.1f}",color="C1",linewidth = 2.5)
plt.xlabel('Training episodes',fontsize=15)
plt.ylabel('Acc. Episodic Reward',fontsize=15)
#plt.rc('axes', labelsize=30)

#plt.grid()
plt.legend()
#plt.title('Discrete_mountain_car',fontsize=20)
plt.show()

# %%
# Episodes versus Norm Acc. Ep. Rewards
#norm_reward_list = np.array(rewards)
#norm_reward_list = (norm_reward_list/abs(norm_reward_list.min())+1)*100
#min_norm_reward_list = -100
#max_norm_reward_list= 100
#norm_reward_list = (norm_reward_list-min_norm_reward_list)/(max_norm_reward_list-min_norm_reward_list)

font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.5)
f.set_figheight(2.2)
plt.plot(norm_reward_list, label = "Normalized Acc. Epi. Reward",color="C0",linewidth = 1.5)
#plt.axhline(y=norm_reward_list[-20:-1].mean(), linestyle='--',
#            label = "Normalized Acc. Episodic Reward's last 20 mean= "+f"{norm_reward_list[-20:-1].mean():.1f}",color="C1",linewidth = 2.5)
plt.xlabel("Training Episode")
plt.ylabel("Normalized Acc. Epi. Reward")
#plt.grid()
#plt.legend()
plt.minorticks_on()
plt.savefig(path+"Cont_Mount_Car_Acc_Reward_vs_Episode.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
print("Normalized Acc. Epsiodic Reward's last 20 mean=")
print(norm_reward_list[-20:-1].mean())
# Out:
# Normalized Acc. Epsiodic Reward's last 20 mean=
# 0.9612635554440059

# %%
font = {'size': 20}
plt.rc('font', **font)
plt.plot(ploting_adapt_coeff)
plt.xlabel("Training episodes")
plt.ylabel("Adaptation control gains\n at last time step")
#plt.rc('axes', labelsize=30)

plt.grid()
plt.legend(labels=[r"$\hat{k_r}$=coeff of $a^{wanted}$",
                   r"$\hat{k}_y$=coeff of $a^{actual}$",
                 r"$\hat{k}_{r-y}$=coeff of $(a^{wanted}-a^{actual})$",
                 r"$\hat{k}_\omega$=coeff of $\dot{\theta}$"], fontsize=10
           , bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %%
N=50
# Compute the moving average of the last 50 numbers
moving_average = []
for i, n in enumerate(ploting_adapt_coeff):
    if i < N:
        # If there are not enough previous elements,
        # append the average of all available elements
        avg = sum(ploting_adapt_coeff[:i+1]) / (i+1)
    else:
        # Otherwise, compute the average of the previous 5 elements
        avg = sum(ploting_adapt_coeff[i-N:i+1]) / N
    moving_average.append(avg)
moving_average = np.array(moving_average).T
# Plot the moving average
font = {'size': 20}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(6)
f.set_figheight(4)

plt.plot(moving_average[0]
         ,label = r"$\hat{k}_r$=coeff of $a^{desired}$"+f"→{moving_average[0,-20:-1].mean():.1e}",color="C0",linewidth = 2)
plt.plot(moving_average[1],'--',
         label = r"$\hat{k}_y$=coeff of $a^{actual}$"+f"→{moving_average[1,-20:-1].mean():.1e}",color="C1",linewidth = 3)
plt.plot(moving_average[2],':',
         label = r"$\hat{k}_{r-y}$=coeff of $(a^{desired}-a^{actual})$"+f"→{moving_average[2,-20:-1].mean():.1e}",color="C2",linewidth = 4)
plt.plot(moving_average[3],'-.',
         label = r"$\hat{k}_\omega$=coeff of $\dot{\theta}$"+f"→{moving_average[3,-20:-1].mean():.1e}",color="C3",linewidth = 2)
#plt.plot(moving_average)
plt.xlabel("Training episodes")
plt.ylabel("Adaptaion control gains\n at last time step")
plt.title('Continuous Mountain Car',fontsize=20)
#plt.ylim(-2.15,3.15)
#plt.yticks(np.arange(-2, 3.1, 1))
plt.grid()
plt.legend(fontsize=11, bbox_to_anchor=(0.5, 0.3), loc='center')
plt.show()

# %%
# Test Histogram
norm_ep_reward_list_test = np.array(rewards_test)
norm_ep_reward_list_test = unnorm_to_norm(norm_ep_reward_list_test)
print(norm_ep_reward_list_test.max())
print(norm_ep_reward_list_test.min())
min_bin = np.floor(norm_ep_reward_list_test.min()*100)/100
print(min_bin)
# Out:
# 0.9733220339869763
# 0.9372384812608371
# 0.93

# %%
font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.5)
f.set_figheight(2.2)
data_rewards = np.array(norm_ep_reward_list_test)
density_True = True
plt.hist(data_rewards, bins=np.arange(0,1.01,0.05),density=density_True ,color='skyblue', edgecolor='black')
plt.xlabel('Normalized Acc. Epi. Reward')
ylabel='Density'if density_True else 'Frequency'
plt.ylabel(ylabel)
#plt.xticks(np.arange(0,1.1,0.2))
plt.xlim((0.80,1.01))
plt.minorticks_on()
plt.savefig(path+"Cont_Mount_Car_Acc_Reward_vs_Episode_Test_Hist.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.2)
f.set_figheight(2.0)
data_rewards = np.array(norm_ep_reward_list_test)
density_True = True
plt.hist(data_rewards, bins = np.arange(0.6,1.0001,0.05), density=density_True,label="Norm Acc. Epi. Reward" ,color='skyblue', edgecolor='black')
data_episode_length_test = np.array(episode_length_test)
plt.hist(data_episode_length_test/100,bins = np.arange(0.6,1.5001,0.05),
         density=density_True,label=r'$10^{-2}\times$Episode Length',
         color='orange', edgecolor='red',
         linewidth=1, linestyle='--')
plt.xlabel('Normalized Acc. Epi. Reward\nand Episode Lengh')
ylabel='Density'if density_True else 'Frequency'
plt.ylabel(ylabel)
#plt.xticks(np.arange(0,1.00001,0.05),minor=True)
plt.minorticks_on()
#plt.xlim((0.6,1.51))
plt.legend(fontsize=7)
plt.savefig(path+"Cont_Mount_Car_Acc_Reward_and_Length_vs_Episode_Test_Hist.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
print("Test Normalized Acc Episodic Reward's Results:")
print(f"Unnormalized: max={norm_to_unnorm(data_rewards).max():.3f} ,mean={norm_to_unnorm(data_rewards).mean():.3f}, std={norm_to_unnorm(data_rewards).std():.3f}")
print(f"Normalized:   max={data_rewards.max():.3e} ,mean={data_rewards.mean():.3e}, std={data_rewards.std():.3e}")
# Out:
# Test Normalized Acc Episodic Reward's Results:
# Unnormalized: max=94.664 ,mean=94.065, std=1.123
# Normalized:   max=9.733e-01 ,mean=9.703e-01, std=5.616e-03

# %%
print("Test Episode Lenght's Results:")
print(f"min={data_episode_length_test.min():.3f} ,mean={data_episode_length_test.mean():.3f}, std={data_episode_length_test.std():.3f}")
# Out:
# Test Episode Lenght's Results:
# min=75.000 ,mean=85.530, std=20.186

# %%
dt=env.tau

# %%
print(dt)
# Out:
# 1.0

# %%
time_ = np.linspace(start = 0, stop = len(save_actual_force)* dt,num=len(save_actual_force) )

font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.5)
f.set_figheight(2.2)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')


plt.step(time_, save_wanted_force ,label = r"$r=a^{desired}$ from RL alg.",color="blue",linewidth = 1.5)
plt.step(time_, save_model_force , '--',label = "$y_m=a^{model}$ from MRAC ref. model",color="green",linewidth = 2)
plt.step(time_, save_actual_force , ':',label = "$y=a^{actual}$ from DC motor plant",color="red",linewidth = 4)
plt.xlabel("Time (s)")
plt.ylabel("Force (N)")
plt.legend(fontsize=7)#,bbox_to_anchor=(1.05, 1.0), loc='upper left')
#plt.xlim(None,max(80,time_[-1]))
plt.xticks(np.arange(0, 80, 10))
#plt.ylim(-2.4,None)
#plt.title('Continuous Mountain Car',fontsize=20)
#plt.grid()
plt.savefig(path+"Cont_Mount_Car_Force_vs_Time.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
e_ry=np.array(save_wanted_force)-np.array(save_actual_force)
e_yy_m=np.array(save_actual_force)-np.array(save_model_force)
print(f"e_ry: (mean, std, mae) = ({e_ry.mean():.2e}, {e_ry.std():.2e}, {np.abs(e_ry).mean():.2e})")
print(f"e_yy_m: (mean, std, mae) = ({e_yy_m.mean():.2e}, {e_yy_m.std():.2e}, {np.abs(e_yy_m).mean():.2e})")
# Out:
# e_ry: (mean, std, mae) = (-5.91e-05, 3.70e-04, 6.35e-05)
# e_yy_m: (mean, std, mae) = (5.91e-05, 3.70e-04, 6.35e-05)

# %%
font = {'size': 20}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(6)
f.set_figheight(4)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

e_ry=np.array(save_wanted_force)-np.array(save_actual_force)
e_yy_m=np.array(save_actual_force)-np.array(save_model_force)


plt.step(time_, e_ry ,label = "$e_{r,y}=a^{desired}-a^{actual}$ ",color="cyan",linewidth = 1.5)
plt.step(time_, e_yy_m , ':',label = "$e_{y,y_m}=a^{actual}-a^{model}$ ",color="brown",linewidth = 4)
plt.axhline(y=e_ry.mean(), color="black",linewidth = 2, linestyle='--', label='mean($e_{r,y}$) =' +f'{e_ry.mean():.1e}')
plt.axhline(y=e_yy_m.mean(), color="magenta",linewidth = 2, linestyle='-.', label='mean($e_{y,y_m}$) =' +f'{e_yy_m.mean():.1e}')


plt.xlabel("time [sec]")
plt.ylabel("Force error [N]")
plt.legend(fontsize=11, bbox_to_anchor=(0.5, 0.2),loc='center',ncols=2)
#plt.xlim(None,max(80,time_[-1]))
plt.xticks(np.arange(0, 80, 10))
#plt.yticks(np.arange(0, 15, 1)
#plt.ylim(-2.4,None)
plt.title('Continuous Mountain Car',fontsize=20)
plt.grid()
plt.show()

# %%
from scipy.integrate import cumulative_trapezoid

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

e_ry=np.array(save_wanted_force)-np.array(save_actual_force)
e_yy_m=np.array(save_actual_force)-np.array(save_model_force)


plt.step(time_, e_ry ,label = r"$e_{r,y}=a^{wanted}-a^{actual}$ ",color="cyan",linewidth = 1.5)
plt.step(time_, e_yy_m , ':',label = "$e_{y,y_m}=a^{actual}-a^{model}$ ",color="brown",linewidth = 4)

plt.xlabel("time [sec]")
plt.ylabel("Force error [N]")
plt.legend(fontsize=12)
plt.grid()
plt.show()

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

e_ry=np.array(save_wanted_force)-np.array(save_actual_force)
e_yy_m=np.array(save_actual_force)-np.array(save_model_force)

cum_trapz_e_ry = cumulative_trapezoid(y=np.r_[0,e_ry],x=None, dx=dt)
cum_trapz_e_yy_m = cumulative_trapezoid(y=np.r_[0,e_yy_m],x=None, dx=dt)


plt.step(time_, e_ry ,label = r"$e_{r,y}=a^{wanted}-a^{actual}$ ",color="cyan",linewidth = 1.5)
plt.step(time_, e_yy_m , ':',label = "$e_{y,y_m}=a^{actual}-a^{model}$ ",color="brown",linewidth = 4)

plt.plot(time_, cum_trapz_e_ry,'--',
         label = r"cumtrapz($e_{r,y}$)",color="black",linewidth = 2)
plt.plot(time_, cum_trapz_e_yy_m,'-.',
         label = r"cumtrapz($e_{y,y_m}$)",color="magenta",linewidth = 2)

plt.xlabel("time [sec]")
plt.ylabel("Force error [N]")
plt.legend(fontsize=12)
plt.grid()
plt.show()

# %%
font = {'size': 20}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(6)
f.set_figheight(4)

plt.plot(time_, save_ctrl_voltage)
plt.xlabel("time [sec]")
plt.ylabel("Control Voltage [volts]")
plt.xticks(np.arange(0, 80, 10))
plt.title('Continuous Mountain Car',fontsize=20)
plt.grid()
plt.show()

# %%
np_array_MRAC_adapt_gains = np.array(save_MRAC_adapt_gains).T

# %%
font = {'size': 20}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(6)
f.set_figheight(4)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

plt.plot(time_, np_array_MRAC_adapt_gains[0]
         ,label = r"$\hat{k}_r$=coeff of $a^{desired}$"+f"→{np_array_MRAC_adapt_gains[0,-20:-1].mean():.1e}",color="C0",linewidth = 2)
plt.plot(time_, np_array_MRAC_adapt_gains[1],'--'
         ,label = r"$\hat{k_y}$=coeff of $a^{actual}$"+f"→{np_array_MRAC_adapt_gains[1,-20:-1].mean():.1e}",color="C1",linewidth = 3)
plt.plot(time_, np_array_MRAC_adapt_gains[2],':',
         label = r"$\hat{k}_{r-y}$=coeff of $(a^{desired}-a^{actual})$"+f"→{np_array_MRAC_adapt_gains[2,-20:-1].mean():.1e}",color="C2",linewidth = 4)
plt.plot(time_, np_array_MRAC_adapt_gains[3],'-.',
         label = r"$\hat{k}_\omega$=coeff of $\dot{\theta}$"+f"→{np_array_MRAC_adapt_gains[3,-20:-1].mean():.1e}",color="C3",linewidth = 2)
plt.xlabel("time [sec]")
plt.ylabel("Adaptation control gains")
plt.xticks(np.arange(0, 80, 10))
plt.title('Continuous Mountain Car',fontsize=20)
#plt.ylim(-2.15,3.15)
#plt.yticks(np.arange(-2, 3.1, 1))
plt.grid()
plt.legend(fontsize=11, bbox_to_anchor=(0.5, 0.3), loc='center')
plt.show()

# %%
import math

position = []   #position of the car along the x-axis
velocity = []   #velocity of the car

for observ in save_observation:
  for index,value in enumerate(observ):
    if index == 0:
      position.append(value)

    if index == 1:
      velocity.append(value)

# %%
print(len(position))
# Out:
# 76

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_x_position = np.linspace(start = 0, stop = len(position)* dt ,num=len(position))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_x_position[-1] , 300)

spl = make_interp_spline(time_x_position, position, k=3)  # type: BSpline
power_smooth = spl(xnew)

font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.5)
f.set_figheight(2.2)

#plt.plot(xnew, power_smooth)
plt.plot(time_x_position, position)
plt.ylabel('Position (m)')
plt.xlabel('Time (s)')
plt.xticks(np.arange(0, 80, 10))
#plt.grid()
plt.savefig(path+"Cont_Mount_Position_vs_Time.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
print("Car reached goal after "+str(time_x_position[-1])+ " seconds")
# Out:
# Car reached goal after 76.0 seconds

# %%
time_velocity = np.linspace(start = 0, stop = len(velocity)* dt ,num=len(velocity))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_velocity[-1] , 300)

spl = make_interp_spline(time_velocity, velocity, k=3)  # type: BSpline
power_smooth = spl(xnew)

plt.plot(xnew, power_smooth)
plt.xlabel("Time [sec]")
plt.ylabel("Velocity [m/sec]")
plt.grid()
plt.show()
