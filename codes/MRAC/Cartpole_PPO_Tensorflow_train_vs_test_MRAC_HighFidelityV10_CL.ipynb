# %% [markdown]
# **References:**
#
# - https://keras.io/examples/rl/ppo_cartpole/
# - [Proximal Policy Optimization Algorithms](https://arxiv.org/abs/1707.06347)
# - [OpenAI Spinning Up docs - PPO](https://spinningup.openai.com/en/latest/algorithms/ppo.html)
# - [OpenAI Spinning Up Github - PPO](https://github.com/openai/spinningup/blob/master/spinup/algos/tf1/ppo/ppo.py)
# - https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py

# %%
import warnings

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'


import tensorflow as tf
#from tf import keras as keras
import keras
from keras import layers

import numpy as np
import gym
import scipy.signal
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle

# %%
np.seterr(all="ignore")
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
import matplotlib, cv2
import matplotlib.pyplot as plt
import base64, io, os, time
import IPython, functools
#from tqdm import tqdm
import tensorflow_probability as tfp
import math
from typing import Optional
from gym import spaces, logger
from gym.utils import seeding
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if (distutils.version.LooseVersion(tf.__version__) <
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
warnings.filterwarnings("ignore", message=".*Conversion of an array with ndim > 0 to a scalar.*")
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
from numpy.linalg import matrix_power
from scipy.linalg import block_diag

# %% [markdown]
# ## Functions and class

# %%
class CartPoleEnvCustomized(gym.Env):
    """
    ### Description
    This environment corresponds to the version of the cart-pole problem
    described by Barto, Sutton, and Anderson in ["Neuronlike Adaptive Elements That Can Solve Difficult Learning Control Problem"](https://ieeexplore.ieee.org/document/6313077).
    A pole is attached by an un-actuated joint to a cart, which moves along a
    frictionless track. The pendulum starts upright, and the goal is to prevent
    it from falling over by increasing and reducing the cart's velocity.
    ### Action Space
    The agent take a 1-element vector for actions.
    The action space is `(action)` in `[0, 1]`, where `action` is used to push
    the cart with a fixed amount of force:
    | Num | Action                 |
    |-----|------------------------|
    | 0   | Push cart to the left  |
    | 1   | Push cart to the right |
    Note: The amount the velocity is reduced or increased is not fixed as it depends on the angle the pole is pointing.
    This is because the center of gravity of the pole increases the amount of energy needed to move the cart underneath it
    ### Observation Space
    The observation is a `ndarray` with shape `(4,)` where the elements correspond to the following:
    | Num | Observation           | Min                  | Max                |
    |-----|-----------------------|----------------------|--------------------|
    | 0   | Cart Position         | -4.8*                 | 4.8*                |
    | 1   | Cart Velocity         | -Inf                 | Inf                |
    | 2   | Pole Angle            | ~ -0.418 rad (-24°)** | ~ 0.418 rad (24°)** |
    | 3   | Pole Angular Velocity | -Inf                 | Inf                |
    **Note:** above denotes the ranges of possible observations for each element, but in two cases this range exceeds the
    range of possible values in an un-terminated episode:
    - `*`: the cart x-position can be observed between `(-4.8, 4.8)`, but an episode terminates if the cart leaves the
    `(-2.4, 2.4)` range.
    - `**`: Similarly, the pole angle can be observed between  `(-.418, .418)` radians or precisely **±24°**, but an episode is
    terminated if the pole angle is outside the `(-.2095, .2095)` range or precisely **±12°**
    ### Rewards
    Reward is 1 for every step taken, including the termination step. The threshold is 475 for v1.
    ### Starting State
    All observations are assigned a uniform random value between (-0.05, 0.05)
    ### Episode Termination
    The episode terminates of one of the following occurs:
    1. Pole Angle is more than ±12°
    2. Cart Position is more than ±2.4 (center of the cart reaches the edge of the display)
    3. Episode length is greater than 500 (200 for v0)
    ### Arguments
    No additional arguments are currently supported.
    """

    metadata = {"render.modes": ["human", "rgb_array"], "video.frames_per_second": 50}

    def __init__(self):
        self.gravity = 9.8
        self.masscart = 1.0
        self.masspole = 0.1
        self.total_mass = self.masspole + self.masscart
        self.length = 0.5  # actually half the pole's length
        self.polemass_length = self.masspole * self.length
        self.force_mag = 10.0
        self.dt = 0.02  # seconds between state updates
        self.kinematics_integrator = None # "euler","semi-implicit euler"


        # Angle at which to fail the episode
        self.theta_threshold_radians = 12 * 2 * math.pi / 360
        self.x_threshold = 2.4

        # Angle limit set to 2 * theta_threshold_radians so failing observation
        # is still within bounds.
        high = np.array(
            [
                self.x_threshold * 2,
                np.finfo(np.float32).max,
                self.theta_threshold_radians * 2,
                np.finfo(np.float32).max,
            ],
            dtype=np.float32,
        )

        self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        self.viewer = None
        self.state = None

        self.steps_beyond_done = None

        ### Customization changes ######
        self.DCMotor_radius = 0.15 #0.2 #### chnge actualy diameter and arm len for rotation
        self.NumIntegrationsSteps = 20 #1
        dt_prime = self.dt/self.NumIntegrationsSteps
        self.tau = dt_prime
        self.MRAC = ModelRefAC()
        self.tau = dt_prime
        self.MRAC.timeSample = self.tau
        self.MRAC.plant.tau1 = self.tau
        self.MRAC.ref_model.tau1 = self.tau
        self.wanted_torque = 0

        self.ideal_env = False
        ####


    def step(self, action):
        err_msg = f"{action!r} ({type(action)}) invalid"
        assert self.action_space.contains(action), err_msg

        x, x_dot, theta, theta_dot = self.state
        force = +self.force_mag if action == 1 else -self.force_mag #+/-10N
        #wanted_torque_ret = self.wanted_torque #return old action
        torque_wanted = force*self.DCMotor_radius
        #self.MPC.y_spf = torque_wanted
        beta_AF = 0.135 #0.135,0.5
        torque_wanted =  (beta_AF)*self.wanted_torque+(1-beta_AF)*torque_wanted
        self.wanted_torque = torque_wanted
        #self.MPC.y[0] = torque_wanted #self.MPC.y_spf #torque_wanted
        wanted_torque_ret = self.wanted_torque

        ### Customization changes #####
        for n in np.arange(start=0, stop=self.NumIntegrationsSteps, step=1):
            if self.ideal_env:
              torque_actual = torque_wanted
            else:
              w = x_dot/self.DCMotor_radius
              self.MRAC.plant.thetadot = w
              torque_actual = self.MRAC.step(r=torque_wanted)
            F = torque_actual/self.DCMotor_radius
            #F = force #ideal env
            ###

            costheta = math.cos(theta)
            sintheta = math.sin(theta)

            # For the interested reader:
            # https://coneural.org/florian/papers/05_cart_pole.pdf
            temp = (
                F + self.polemass_length * theta_dot ** 2 * sintheta
            ) / self.total_mass
            thetaacc = (self.gravity * sintheta - costheta * temp) / (
                self.length * (4.0 / 3.0 - self.masspole * costheta ** 2 / self.total_mass)
            )
            xacc = temp - self.polemass_length * thetaacc * costheta / self.total_mass

            if self.kinematics_integrator == "euler":
                x = x + self.tau * x_dot
                x_dot = x_dot + self.tau * xacc
                theta = theta + self.tau * theta_dot
                theta_dot = theta_dot + self.tau * thetaacc
            elif self.kinematics_integrator == "semi-implicit euler":
                x_dot = x_dot + self.tau * xacc
                x = x + self.tau * x_dot
                theta_dot = theta_dot + self.tau * thetaacc
                theta = theta + self.tau * theta_dot
            else: # trapz on velocities
                new_x_dot = x_dot + self.tau * xacc
                new_theta_dot = theta_dot + self.tau * thetaacc
                x = x + self.tau * (x_dot+new_x_dot)/2
                theta = theta + self.tau * (theta_dot+new_theta_dot)/2
                x_dot = new_x_dot+0
                theta_dot = new_theta_dot+0

        self.state = (x, x_dot, theta, theta_dot)

        done = bool(
            x < -self.x_threshold
            or x > self.x_threshold
            or theta < -self.theta_threshold_radians
            or theta > self.theta_threshold_radians
        )

        if not done: # if we inside the valid range
            reward = 1.0

        elif self.steps_beyond_done is None:
            # Pole just fell!
            self.steps_beyond_done = 0
            reward = 1.0

        else:
            if self.steps_beyond_done == 0:
                logger.warn(
                    "You are calling 'step()' even though this "
                    "environment has already returned done = True. You "
                    "should always call 'reset()' once you receive 'done = "
                    "True' -- any further steps are undefined behavior."
                )
            self.steps_beyond_done += 1
            reward = 0.0

        return np.array(self.state, dtype=np.float32), reward, done, {} ,wanted_torque_ret, torque_actual


    def reset(self, return_info = False, options = None):
        #super().reset(seed=seed)
        self.state = np.random.uniform(low=-0.05, high=0.05, size=(4,))
        self.steps_beyond_done = None

        ### reset MRAC
        self.MRAC.reset()
        self.MRAC.plant.reset()
        self.MRAC.ref_model.reset()
        self.wanted_torque = 0
        #

        if not return_info:
            return np.array(self.state, dtype=np.float32)
        else:
            return np.array(self.state, dtype=np.float32), {}

    def render(self, mode="human"):
        screen_width = 600
        screen_height = 400

        world_width = self.x_threshold * 2
        scale = screen_width / world_width
        carty = 100  # TOP OF CART
        polewidth = 10.0
        polelen = scale * (2 * self.length)
        cartwidth = 50.0
        cartheight = 30.0

        if self.viewer is None:
            #from gym.utils import pyglet_rendering
            from gym.envs.classic_control import rendering as pyglet_rendering

            self.viewer = pyglet_rendering.Viewer(screen_width, screen_height)
            l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
            axleoffset = cartheight / 4.0
            cart = pyglet_rendering.FilledPolygon([(l, b), (l, t), (r, t), (r, b)])
            self.carttrans = pyglet_rendering.Transform()
            cart.add_attr(self.carttrans)
            self.viewer.add_geom(cart)
            l, r, t, b = (
                -polewidth / 2,
                polewidth / 2,
                polelen - polewidth / 2,
                -polewidth / 2,
            )
            pole = pyglet_rendering.FilledPolygon([(l, b), (l, t), (r, t), (r, b)])
            pole.set_color(0.8, 0.6, 0.4)
            self.poletrans = pyglet_rendering.Transform(translation=(0, axleoffset))
            pole.add_attr(self.poletrans)
            pole.add_attr(self.carttrans)
            self.viewer.add_geom(pole)
            self.axle = pyglet_rendering.make_circle(polewidth / 2)
            self.axle.add_attr(self.poletrans)
            self.axle.add_attr(self.carttrans)
            self.axle.set_color(0.5, 0.5, 0.8)
            self.viewer.add_geom(self.axle)
            self.track = pyglet_rendering.Line((0, carty), (screen_width, carty))
            self.track.set_color(0, 0, 0)
            self.viewer.add_geom(self.track)

            self._pole_geom = pole

        if self.state is None:
            return None

        # Edit the pole polygon vertex
        pole = self._pole_geom
        l, r, t, b = (
            -polewidth / 2,
            polewidth / 2,
            polelen - polewidth / 2,
            -polewidth / 2,
        )
        pole.v = [(l, b), (l, t), (r, t), (r, b)]

        x = self.state
        cartx = x[0] * scale + screen_width / 2.0  # MIDDLE OF CART
        self.carttrans.set_translation(cartx, carty)
        self.poletrans.set_rotation(-x[2])

        return self.viewer.render(return_rgb_array=mode == "rgb_array")

    def close(self):
        if self.viewer:
            self.viewer.close()
            self.viewer = None

# %%
# High Fidelity Cartpole ENV by L. Bantel, et al (https://doi.org/10.1109/INTCEC61833.2024.10602859)
# https://github.com/SC-SGS/High-Fidelity-Cartpole
import math
from math import pi, cos, sin, trunc, e
from typing import Optional, Union
import gin

import numpy as np
import pygame
from pygame import gfxdraw

import gym
from gym import spaces, logger
from gym.utils import seeding

#@gin.configurable
class HighFidelityCartPoleEnvCustomized(gym.Env[np.ndarray, Union[int, np.ndarray]]):

    metadata = {"render_modes": ["human", "rgb_array"], "render_fps": 50}

    def __init__(self,
                 force_steps = [0,2,5,7,10,15,20],#[0,5,10,15,20],# [0,100,150,200,250]
                 masscart = 0.94,
                 masspole = 0.1,
                 length = 0.1778,
                 force_mag = 3.0,
                 NumIntegrationsSteps = 200, #20, #internal_tau = 0.02,
                 dt=0.02,#tau = 0.02,
                 x_threshold = 0.3,
                 pole_resistance = 0.99,
                 cart_resistance = 0.99,
                 force_curve = [0,1,0],
                 evaluation = False,#False,
                 swingup = False,#False,
                 discrete_state = False,
                 action_in_state = False): #action_in_state=True

        #set "evaluation" in the code to obtain a second environment for evaluation,
        #for conistent resets

        #physical parameters
        self.force_steps = force_steps
        self.gravity = 9.8
        self.masscart = masscart
        self.masspole = masspole
        self.total_mass = self.masspole + self.masscart
        self.length = length  # actually half the pole's length
        self.polemass_length = self.masspole * self.length
        self.force_mag_mean = force_mag
        self.force_mag = None
        self.dt = dt
        self.NumIntegrationsSteps = NumIntegrationsSteps
        self.internal_tau = dt/NumIntegrationsSteps #internal_tau # seconds for euler step
        #self.tau = tau  # seconds between state updates, multiple of internal tau
        self.mean_pole_resistance = e**(pole_resistance*self.internal_tau)
        self.mean_cart_resistance = cart_resistance
        self.cart_resistance = None
        self.pole_resistance = None
        self.force_curve = force_curve

        #different experimental setups
        self.evaluation = evaluation
        self.swingup = swingup
        self.action_in_state = action_in_state
        self.discrete_state = discrete_state

        self.states = []


        # Angle at which to fail the classical task
        self.theta_threshold_radians = 12 * 2 * math.pi / 360
        self.x_threshold = x_threshold

        # Angle limit set to 2 * theta_threshold_radians so failing observation
        # is still within bounds.
        high = np.array(
            [
                self.x_threshold * 2,
                np.finfo(np.float32).max,
                pi,
                np.finfo(np.float32).max
            ],
            dtype=np.float32,
        )

        self.action_space = spaces.Discrete(len(self.force_steps) * 2 - 1)


        #action within state
        if self.action_in_state:
            action = np.ones(len(force_steps)*2+1)
            self.observation_space = spaces.Box(np.concatenate((-high, action*0)), np.concatenate((high, action)), dtype=np.float32)
            print('action_in_state = True')
        else:
            self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        self.screen = None
        self.clock = None
        self.isopen = True
        self.state = None
        self.num_steps = None

        self.steps_beyond_done = None

        self.last_action = None
        self.last_reward = 0

        ### Customization changes ######
        self.DCMotor_radius = 0.15 #0.2 #### chnge actualy diameter and arm len for rotation
        self.MRAC = ModelRefAC()
        self.MRAC.timeSample = self.internal_tau
        self.MRAC.plant.tau1 = self.internal_tau
        self.MRAC.ref_model.tau1 = self.internal_tau
        self.wanted_torque = 0
        self.kinematics_integrator = None # "euler","semi-implicit euler"

        self.ideal_env = False
        ####



    def update_state(self, state, force, tau):
        #function implements the actual differential equation and integration

        x, x_dot, theta, theta_dot = state

        costheta = math.cos(theta)
        sintheta = math.sin(theta)

        # For the interested reader:
        # https://coneural.org/florian/papers/05_cart_pole.pdf

        #sign function can lead to weird results depending on the time-step-width
        #possible replacement is a scaled and parameterized sigmoid

        temp = (
            force + self.polemass_length * theta_dot ** 2 * sintheta
            - self.cart_resistance*np.tanh(x_dot*tau)#sign(x_dot)
        ) / self.total_mass

        thetaacc = (self.gravity * sintheta - costheta * temp) / (
            self.length * (4.0 / 3.0 - self.masspole * costheta ** 2 / self.total_mass)
        )

        xacc = temp - self.polemass_length * thetaacc * costheta / self.total_mass


        if self.kinematics_integrator == "euler":
          x = x + self.tau * x_dot
          x_dot = x_dot + tau * xacc
          theta = theta + tau * theta_dot
          theta_dot = theta_dot*self.pole_resistance + tau * thetaacc
        elif self.kinematics_integrator == "semi-implicit euler":
          x_dot = x_dot + tau * xacc
          x = x + self.tau * x_dot
          theta_dot = theta_dot*self.pole_resistance + tau * thetaacc
          theta = theta + tau * theta_dot
        else: # trapz on velocities
          new_x_dot = x_dot + tau * xacc
          new_theta_dot = theta_dot*self.pole_resistance + tau * thetaacc
          x = x + tau * (x_dot+new_x_dot)/2
          theta = theta + tau * (theta_dot+new_theta_dot)/2
          x_dot = new_x_dot+0
          theta_dot = new_theta_dot+0

        theta = angle_normalize(theta)


        return (x, x_dot, theta, theta_dot)



    def step(self, action):
        err_msg = f"{action!r} ({type(action)}) invalid"
        assert self.action_space.contains(action), err_msg
        assert self.state is not None, "Call reset before using step method."


        action = action - len(self.force_steps) + 1



        if action > 0:
            dir = 1
        elif action < 0:
            dir = -1
        else:
            dir = 0


        #motor values to use (0-255)
        force = self.force_steps[abs(action)]


        #force curve of the cartpole
        force = self.force_curve[0]*force**2 - self.force_curve[1]*force +  self.force_curve[2]
        force *= dir
        torque_wanted = force*self.DCMotor_radius
        beta_AF = 0.0#0.5,0.135
        torque_wanted = (beta_AF)*self.wanted_torque+(1-beta_AF)*torque_wanted
        #torque_wanted= self.wanted_torque*1
        self.wanted_torque = torque_wanted#_temp*1
        wanted_torque_ret = torque_wanted

        # get current state
        x, x_dot, theta, theta_dot = self.state

        if self.discrete_state:
            old_disc_theta = discretize_angle(theta)

        #internal finer stepping of the simulation
        for i in range(self.NumIntegrationsSteps):
          if self.ideal_env:
            torque_actual = torque_wanted
          else:
            w = x_dot/self.DCMotor_radius
            self.MRAC.plant.thetadot = w
            torque_actual = self.MRAC.step(r=torque_wanted)
          F = torque_actual/self.DCMotor_radius
          self.state = self.update_state(self.state, F, self.internal_tau)
          x, x_dot, theta, theta_dot = self.state



        x, x_dot, theta, theta_dot = self.state

        #calculating the derivatives of the discrete state for the output
        if self.discrete_state:
            new_disc_theta = discretize_angle(theta)

            if new_disc_theta > pi/2 and old_disc_theta < -pi/2:
                old_disc_theta += 2*pi
            elif new_disc_theta < -pi/2 and old_disc_theta > pi/2:
                old_disc_theta -= pi

            disc_theta_dot = (new_disc_theta - old_disc_theta)/self.dt
            out_state = (x, x_dot, new_disc_theta, disc_theta_dot)
        else:
            out_state = self.state


        #variable to check, if pole is upright
        if abs(theta) < self.theta_threshold_radians:
            self.swingup_done = True
        elif abs(theta) > self.theta_threshold_radians:
            self.swingup_done = False


        done = bool(
            x < -self.x_threshold
            or x > self.x_threshold
            or abs(theta_dot) > 5*pi
            or (abs(theta) > self.theta_threshold_radians and not self.swingup)
        )

        if not done:
            if self.evaluation:
                reward = cos(theta / 2) * (1-abs(x)/self.x_threshold)
            else:
                reward = cos(theta / 2) * (1-abs(x)/self.x_threshold)
            #additional addon for training swingup faster

            if self.swingup and abs(theta) < 5/180*pi:
                reward += 5
                if abs(theta_dot) < 6/180*pi:
                    reward += 5


        elif self.steps_beyond_done is None:
            # Pole just fell!
            self.steps_beyond_done = 0
            reward = 0
        else:
            if self.steps_beyond_done == 0:
                logger.warn(
                    "You are calling 'step()' even though this "
                    "environment has already returned done = True. You "
                    "should always call 'reset()' once you receive 'done = "
                    "True' -- any further steps are undefined behavior."
                )
            self.steps_beyond_done += 1
            reward = 0


        self.num_steps += 1
        self.last_action = action
        self.last_reward = reward

        #append action to state if neccessary
        if self.action_in_state:
            action_arr = np.zeros(len(self.force_steps)*2+1)
            action_arr[action+len(self.force_steps)] = 1
            return np.concatenate((np.array(out_state, dtype=np.float32), action_arr)), reward, done, {} ,torque_wanted, torque_actual
        else:
            return np.array(out_state, dtype=np.float32), reward, done, {} ,wanted_torque_ret, torque_actual


    def reset(
        self,
        *,
        seed: Optional[int] = None,
        return_info: bool = False,
        options: Optional[dict] = None,
    ):
        super().reset(seed=seed)

        #reset with slight perturbation
        self.state = self.np_random.uniform(low=-0.1, high=0.1, size=(4,))
        #vertical
        self.state[2] = self.np_random.uniform(low = -2/180*pi, high = 2/180*pi)

        if self.swingup:

            #for evaluation purposes start always hanging
            #for training, start with an arbitary pole angle
            if self.evaluation:
                self.state = self.np_random.uniform(low=-0.01, high=0.01, size=(4,))
                self.state[2] = angle_normalize(pi - self.np_random.uniform(low=-0.01, high=0.01))
            else:
                self.state[2] = self.np_random.uniform(low=-pi, high=pi)


        #perturbate resistance parameters
        self.cart_resistance = self.mean_cart_resistance#np.random.uniform(low = self.mean_cart_resistance*0.95, high = self.mean_cart_resistance*1.05)
        self.pole_resistance = self.mean_pole_resistance#np.random.uniform(low = self.mean_pole_resistance*0.97, high = min(self.mean_pole_resistance*1.03,0.9999))



        #used to train for multiple poles on one agent
        """"
        pend = self.np_random.randint(2)d

        if pend == 0:

            self.masspole = 0.127
            self.total_mass = self.masspole + self.masscart
            self.length = 0.1778  # actually half the pole's length
            self.polemass_length = self.masspole * self.length

        else:

            self.masspole = 0.23
            self.total_mass = self.masspole + self.masscart
            self.length = 0.3302  # actually half the pole's length
            self.polemass_length = self.masspole * self.length
        """


        self.num_steps = 0
        self.steps_beyond_done = None
        self.last_action = 0
        self.swingup_done = False

        ### reset MRAC
        self.MRAC.reset()
        self.MRAC.plant.reset()
        self.MRAC.ref_model.reset()
        self.wanted_torque = 0
        #

        if self.action_in_state:
            action = np.zeros(len(self.force_steps)*2+1)
            out = np.concatenate((np.array(self.state, dtype=np.float32), action))
        else:
            out = np.array(self.state, dtype=np.float32)

        if not return_info:
            return out
        else:
            return out, {}




    def render(self, mode="human"):
        screen_width = 608
        screen_height = 400

        world_width = self.x_threshold * 2
        scale = screen_width / world_width
        polewidth = 10.0
        polelen = scale * self.length
        cartwidth = 50.0
        cartheight = 30.0

        if self.state is None:
            return None

        x = self.state

        if self.screen is None:
            pygame.init()
            self.screen = pygame.display.set_mode((screen_width, screen_height))
        if self.clock is None:
            self.clock = pygame.time.Clock()

        self.surf = pygame.Surface((screen_width, screen_height))
        self.surf.fill((255, 255, 255))

        fontObj = pygame.font.Font(None, 32)
        cart_res = fontObj.render(str(self.cart_resistance), True, (0,0,0), None)

        l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
        axleoffset = cartheight / 4.0
        cartx = x[0] * scale + screen_width / 2.0  # MIDDLE OF CART
        carty = int(screen_height/2 + cartheight/2)  # TOP OF CART
        cart_coords = [(l, b), (l, t), (r, t), (r, b)]
        cart_coords = [(c[0] + cartx, c[1] + carty) for c in cart_coords]
        gfxdraw.aapolygon(self.surf, cart_coords, (0, 0, 0))
        gfxdraw.filled_polygon(self.surf, cart_coords, (0, 0, 0))

        l, r, t, b = (
            -polewidth / 2,
            polewidth / 2,
            polelen - polewidth / 2,
            -polewidth / 2,
        )

        pole_coords = []
        for coord in [(l, b), (l, t), (r, t), (r, b)]:
            coord = pygame.math.Vector2(coord).rotate_rad(-x[2])
            coord = (coord[0] + cartx, coord[1] + carty + axleoffset)
            pole_coords.append(coord)
        gfxdraw.aapolygon(self.surf, pole_coords, (202, 152, 101))
        gfxdraw.filled_polygon(self.surf, pole_coords, (202, 152, 101))

        gfxdraw.aacircle(
            self.surf,
            int(cartx),
            int(carty + axleoffset),
            int(polewidth / 2),
            (129, 132, 203),
        )
        gfxdraw.filled_circle(
            self.surf,
            int(cartx),
            int(carty + axleoffset),
            int(polewidth / 2),
            (129, 132, 203),
        )

        gfxdraw.hline(self.surf, 0, screen_width, carty, (0, 0, 0))

        #draw force steps in render
        for i in range(-len(self.force_steps), len(self.force_steps)+1):
            color = (0,0,0)
            if i == self.last_action:
                color = (255,0,0)
            gfxdraw.filled_circle(
                    self.surf,
                    int(screen_width/2+i*20),
                    int(50),
                    5,
                    color,
            )

        #reward value
        gfxdraw.rectangle(self.surf, (20,20,20,80),(0,0,0))

        gfxdraw.box(self.surf, (20,20,20,self.last_reward*80),(0,0,0))


        self.surf = pygame.transform.flip(self.surf, False, True)
        self.screen.blit(self.surf, (0, 0))
        if mode == "human":
            self.clock.tick(self.metadata["render_fps"])
            pygame.display.flip()

        if mode == "rgb_array":
            return np.transpose(
                np.array(pygame.surfarray.pixels3d(self.screen)), axes=(1, 0, 2)
            )
        else:
            return self.isopen

    def close(self):
        if self.screen is not None:
            pygame.quit()
            self.isopen = False


def angle_normalize(x):
    return ((x + np.pi) % (2 * np.pi)) - np.pi



#not used, possible distribution for perturbating physical parameters
def trunc_normal(mean, sigma, lower = 0, upper = 1):
    i = 0
    x = mean

    while i < 50:
        x =  np.random.normal(mean, sigma)
        if x >= lower and x <= upper:
            break
        i += 1

    if i >= 50:
        x = mean

    return x


def discretize_angle(theta):
    disc = int((theta+pi)/pi*2048)-2048 #range from -2048 to 2048
    return disc/2048*pi #range from -pi to pi


def sign(x):
    if x > 0:
        return 1
    elif x < 0:
        return -1
    else:
        return 0

def sigmoid(x,tau):
    return 2/(1 + np.exp(-x*tau))-1
# Out:
# /usr/local/lib/python3.12/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
class ElectricalDCMotorEnv():

  def __init__(self):
    self.Resistor_R = 1.0
    self.inductor_L = 0.1
    self.torque_const_Kt = 1.0
    self.bemf_const_Ke = 1.0
    self.tau1 = 0.05
        #
    self.current = 0.0
    self.voltage_input = None
    self.thetadot = 0.0

  def step(self, u):
    voltage_BEMF = self.thetadot*self.bemf_const_Ke
    self.voltage_input = np.clip(u, -10, 10)

    f1 = self.torque_const_Kt*self.current
    self.current += self.tau1*(self.voltage_input-voltage_BEMF-self.current*self.Resistor_R)/self.inductor_L
    f2 = self.torque_const_Kt*self.current
    F = f2
    return F # return actual applied torque

  def reset(self):
    self.current = 0.0

# %%
class ReferenceModel():

  def __init__(self):
    self.a_m = 50.0#30.0#50.0
    self.b_m = self.a_m
    self.tau1 = 0.05
    self.x_m = 0.0
    self.y_m = 0.0

  def step(self, r):

    #fwd integration
    #A = -self.a_m*self.tau1
    #Br = self.b_m*self.tau1*r
    #self.y_m = self.x_m+0
    #self.x_m = (1+A)*self.y_m+Br
    #y_m = self.y_m+0

    #bkwd integration
    #A = -self.a_m*self.tau1
    #Br = self.b_m*self.tau1*r
    #if A ==1:
    #  C=1
    #else:
    #  C = 1/(1-A)
    #self.y_m = C*(self.x_m-Br)
    #self.x_m = self.y_m+0

    #trapz integragration
    A = -0.5*self.a_m*self.tau1
    Br= +0.5*self.b_m*self.tau1*r
    if A ==1:
      C=1
    else:
      C = 1/(1-A)
    x_m = self.x_m
    y_m = C*(x_m+Br)
    x_m = (1+A)*y_m + Br
    self.x_m = x_m
    self.y_m = y_m

    return y_m

  def reset(self):
    self.x_m = 0.0
    self.y_m = 0.0

# %%
class ModelRefAC:

  def __init__(self): #  order of signals [r,y,r-y,w]
    self.plant = ElectricalDCMotorEnv()
    self.ref_model = ReferenceModel()
    self.w = 0.0
    self.u = 0.0
    self.r = 0.0
    self.y = 0.0
    self.y_m = 0.0
    self.adaptation_gain=np.array([5,5,1,5]) # positive scalar or np.array shape (4,)
    self.sigma_mod_adapt_gain= np.array([0,0,0,0]) # non-neg scalar or np.array shape (4,)
    self.emod_adapt_gain= np.array([0,0,0,0])
    self.dead_zone_threshold = 0
    self.dead_zone_adapt_gain = 0
    self.timeSample=0.05
    self.mu0 = np.array([1e-3,-1e-3,1e-3,1e-3])
    self.std = 0*1e-6
    self.k_temp = np.array([1e-3,-1e-3,1e-3,1e-3])
    self.k_hat =  np.array([1e-3,-1e-3,1e-3,1e-3])
    self.keep_coeff = True
    self.mask = np.array([True,True,True,True])
    self.distrib = np.random.standard_normal
    self.mrac_mod = True
    self.I_e_ry = 0.0
    self.K_I_e_ry= 0.0


  def step(self, r):
    self.w = self.plant.thetadot
    y = self.y
    y_m = self.y_m
    e=y-y_m
    if self.mrac_mod:
      u = self.adaptationControlLaw(e=e, r=r, y=y, w=self.w)
    else:
      u = r
      self.u = u
    self.r = r
    self.y_m = self.ref_model.step(r)
    self.y = self.plant.step(u)
    return self.y

  def adaptationControlLaw(self, e, r, y, w):
    #a = 1e-3
    #b = np.exp(-a*self.timeSample)
    #e_ry = r-y
    #I_e_ry = b*self.I_e_ry+(1-b)*e_ry/a
    #I = (I_e_ry+self.I_e_ry)/2
    #v = np.array([r,y,I,w]).clip(-20,20)
    #self.I_e_ry = I
    #e_ry = r-y
    #b=0
    #I_e_ry = b*self.I_e_ry+(1-b)*e_ry
    #v = np.array([r,y,self.I_e_ry,w]).clip(-20,20)
    #v = np.array([r,y,I_e_ry,w]).clip(-20,20)
    #self.I_e_ry = I_e_ry
    #v = np.array([r,y,r-y,w]).clip(-20,20)
    e_ry = r-y
    #I_e_ry = self.I_e_ry + e_ry*self.timeSample
    #self.I_e_ry = I_e_ry
    #vI = (self.I_e_ry+I_e_ry)/2
    #e = e
    v = np.array([r,y,e_ry,w]).clip(-20,20)
    e_norm = abs(e)#+abs(e_ry)
    e_ry_norm = abs(e_ry)

    #fwd integration
    #A = -(self.sigma_mod_adapt_gain+self.emod_adapt_gain*e_norm)*self.timeSample
    #Bev = -self.adaptation_gain*self.timeSample*e*v
    #if e_norm<=self.dead_zone_threshold:
    #  A = A*self.dead_zone_adapt_gain
    #  Bev = Bev*self.dead_zone_adapt_gain
    #self.k_hat = self.k_temp*self.mask
    #self.k_temp = ((1+A)*self.k_hat + Bev)*self.mask

    #backwd integration
    #A = -(self.sigma_mod_adapt_gain+self.emod_adapt_gain*e_norm)*self.timeSample
    #Bev = -self.adaptation_gain*self.timeSample*e*v
    #if e_norm<=self.dead_zone_threshold:
    #  A = A*self.dead_zone_adapt_gain
    #  Bev = Bev*self.dead_zone_adapt_gain
    #C = 1-A*(A!=np.ones_like(A))
    #C = 1/C
    #self.k_hat = C*(self.k_temp+Bev)*self.mask
    #self.k_temp = A*self.k_hat*self.mask

    #trapz integration
    A = -0.5*(self.sigma_mod_adapt_gain+self.emod_adapt_gain*e_norm)*self.timeSample
    Bev = -0.5*self.adaptation_gain*self.timeSample*e*v
    if e_norm<=self.dead_zone_threshold:
      A = A*self.dead_zone_adapt_gain
      Bev = Bev*self.dead_zone_adapt_gain
    #if A ==1:
    #  C=1
    #else:
    #  C = 1/(1-A)
    C = 1-A*(A!=np.ones_like(A))
    C = 1/C
    self.k_hat = C*((self.k_temp +Bev)*self.mask)
    self.k_temp = ((1+A)*self.k_hat +Bev)*self.mask
    self.k_hat = np.clip(self.k_hat,-20,20)
    self.k_temp = np.clip(self.k_temp,-20,20)
    u = np.dot(v,self.k_hat)
    #I_e_ry = self.I_e_ry + e_ry*self.timeSample
    #self.I_e_ry = I_e_ry
    #u = u + self.K_I_e_ry*(self.I_e_ry+I_e_ry)/2
    u = np.clip(u,-20,20)
    self.u = u
    return u

  def reset(self):
    self.w = 0.0
    self.r = 0.0
    self.y = 0.0
    self.y_m = 0.0
    mu0 = self.mu0
    sigma0 = self.std
    keep_coeff = self.keep_coeff
    self.k_temp = (sigma0*self.distrib(self.k_temp.shape) + keep_coeff*self.k_temp + (not keep_coeff)*mu0)*self.mask
    self.k_hat = (sigma0*self.distrib(self.k_hat.shape) + keep_coeff*self.k_hat + (not keep_coeff)*mu0)*self.mask

# %%
CartPole = HighFidelityCartPoleEnvCustomized #HighFidelityCartPoleEnvCustomized #CartPoleEnvCustomized
env = CartPole()
observation = env.reset()
#train_mode = True
## for traingng of ideal: action_actual=action_desired_RL
env.ideal_env = False

# %%
print("Sample Time: dt= ", env.dt)
print("Num Integrations Steps: N= ", env.NumIntegrationsSteps)
print("Integration Time: dt/N=", env.dt/env.NumIntegrationsSteps)
# Out:
# Sample Time: dt=  0.02
# Num Integrations Steps: N=  200
# Integration Time: dt/N= 0.0001

# %%
def discounted_cumulative_sums(x, discount):
    # Discounted cumulative sums of vectors for computing rewards-to-go and advantage estimates
    return scipy.signal.lfilter([1], [1, float(-discount)], x[::-1], axis=0)[::-1]


class Buffer:
    # Buffer for storing trajectories
    def __init__(self, observation_dimensions, size, gamma=0.99, lam=0.95):
        # Buffer initialization
        self.observation_buffer = np.zeros(
            (size, observation_dimensions), dtype=np.float32
        )
        self.action_buffer = np.zeros(size, dtype=np.int32)
        self.advantage_buffer = np.zeros(size, dtype=np.float32)
        self.reward_buffer = np.zeros(size, dtype=np.float32)
        self.return_buffer = np.zeros(size, dtype=np.float32)
        self.value_buffer = np.zeros(size, dtype=np.float32)
        self.logprobability_buffer = np.zeros(size, dtype=np.float32)
        self.gamma, self.lam = gamma, lam
        self.pointer, self.trajectory_start_index = 0, 0

    def store(self, observation, action, reward, value, logprobability):
        # Append one step of agent-environment interaction
        self.observation_buffer[self.pointer] = observation
        self.action_buffer[self.pointer] = action
        self.reward_buffer[self.pointer] = reward
        self.value_buffer[self.pointer] = value
        self.logprobability_buffer[self.pointer] = logprobability
        self.pointer += 1

    def finish_trajectory(self, last_value=0):
        # Finish the trajectory by computing advantage estimates and rewards-to-go
        path_slice = slice(self.trajectory_start_index, self.pointer)
        rewards = np.append(self.reward_buffer[path_slice], last_value)
        values = np.append(self.value_buffer[path_slice], last_value)

        deltas = rewards[:-1] + self.gamma * values[1:] - values[:-1]

        self.advantage_buffer[path_slice] = discounted_cumulative_sums(
            deltas, self.gamma * self.lam
        )
        self.return_buffer[path_slice] = discounted_cumulative_sums(
            rewards, self.gamma
        )[:-1]

        self.trajectory_start_index = self.pointer

    def get(self):
        # Get all data of the buffer and normalize the advantages
        self.pointer, self.trajectory_start_index = 0, 0
        advantage_mean, advantage_std = (
            np.mean(self.advantage_buffer),
            np.std(self.advantage_buffer),
        )
        self.advantage_buffer = (self.advantage_buffer - advantage_mean) / advantage_std
        return (
            self.observation_buffer,
            self.action_buffer,
            self.advantage_buffer,
            self.return_buffer,
            self.logprobability_buffer,
        )

#output_activation=None
def mlp(x, sizes, activation=keras.activations.tanh,
        output_activation=None):
    # Build a feedforward neural network
    for size in sizes[:-1]:
        x = layers.Dense(units=size, activation=activation)(x)
    return layers.Dense(units=sizes[-1], activation=output_activation)(x)



def logprobabilities(logits, a):
    # Compute the log-probabilities of taking actions a by using the logits (i.e. the output of the actor)
    logprobabilities_all = keras.ops.log_softmax(logits)
    logprobability = keras.ops.sum(
        keras.ops.one_hot(a, num_actions) * logprobabilities_all, axis=1
    )
    return logprobability


seed_generator = keras.random.SeedGenerator(1337)


# Sample action from actor
@tf.function
def sample_action(observation):
    logits = actor(observation)
    action = keras.ops.squeeze(
        keras.random.categorical(logits, 1, seed=seed_generator), axis=1
    )
    return logits, action


# Train the policy by maxizing the PPO-Clip objective
@tf.function
def train_policy(
    observation_buffer, action_buffer, logprobability_buffer, advantage_buffer
):
    with tf.GradientTape() as tape:  # Record operations for automatic differentiation.
        ratio = keras.ops.exp(
            logprobabilities(actor(observation_buffer), action_buffer)
            - logprobability_buffer
        )
        min_advantage = keras.ops.where(
            advantage_buffer > 0,
            (1 + clip_ratio) * advantage_buffer,
            (1 - clip_ratio) * advantage_buffer,
        )

        policy_loss = -keras.ops.mean(
            keras.ops.minimum(ratio * advantage_buffer, min_advantage)
        )
    policy_grads = tape.gradient(policy_loss, actor.trainable_variables)
    policy_optimizer.apply_gradients(zip(policy_grads, actor.trainable_variables))

    kl = keras.ops.mean(
        logprobability_buffer
        - logprobabilities(actor(observation_buffer), action_buffer)
    )
    kl = keras.ops.sum(kl)
    return kl


# Train the value function by regression on mean-squared error
@tf.function
def train_value_function(observation_buffer, return_buffer):
    with tf.GradientTape() as tape:  # Record operations for automatic differentiation.
        value_loss = keras.ops.mean((return_buffer - critic(observation_buffer)) ** 2)
    value_grads = tape.gradient(value_loss, critic.trainable_variables)
    value_optimizer.apply_gradients(zip(value_grads, critic.trainable_variables))

# %% [markdown]
# ## Hyperparameters

# %%
# Hyperparameters of the PPO algorithm
steps_per_epoch = 4000
epochs = 100 #60 # 40 #30
steps_per_episode_goal = 500
episodes_max = 2500 #3000
gamma = 0.99
clip_ratio = 0.2
policy_learning_rate = 3e-4
value_function_learning_rate = 1e-3
train_policy_iterations = 80
train_value_iterations = 80
lam = 0.97
target_kl = 0.01
hidden_sizes = (64, 64)

# True if you want to render the environment
render = False

# %% [markdown]
# ## Initializations

# %%
# Initialize the environment and get the dimensionality of the
# observation space and the number of possible actions
env = CartPole()
observation_dimensions = env.observation_space.shape[0]
num_actions = env.action_space.n

# Initialize the buffer
buffer = Buffer(observation_dimensions, steps_per_epoch)

# Initialize the actor and the critic as keras models
observation_input = keras.Input(shape=(observation_dimensions,), dtype="float32")
logits = mlp(observation_input, list(hidden_sizes) + [num_actions])
actor = keras.Model(inputs=observation_input, outputs=logits)
value = keras.ops.squeeze(mlp(observation_input, list(hidden_sizes) + [1]), axis=1)
critic = keras.Model(inputs=observation_input, outputs=value)

# Initialize the policy and the value function optimizers
policy_optimizer = keras.optimizers.Adam(learning_rate=policy_learning_rate)
value_optimizer = keras.optimizers.Adam(learning_rate=value_function_learning_rate)

# Initialize the observation, episode return and episode length
#observation, _ = env.reset()
observation = env.reset()
episode_return, episode_length = 0, 0

# %%
#actor.summary()

# %%
#critic.summary()

# %% [markdown]
# ## Train

# %%
env.reset()
# Out:
# array([ 0.0501819 , -0.09334481, -0.02169191,  0.05480082], dtype=float32)

# %%
avg_reward_list = []
acc_ep_reward_list = []

ep_abs_error_action_list = []
ep_abs_error_action_list_eyym = []
avg_ep_abs_error_action_list = []
avg_ep_abs_error_action_list_eyym = []

episode = 0
epoch = 0
# Iterate over the number of epochs/episodes
#while (epoch < epochs) and (episode < episodes_max):
while(episode < episodes_max):
    print(f"Epoch: {epoch}")
    # Initialize the sum of the returns, lengths and number of episodes for each epoch
    episode_return = 0.0
    episodic_abs_error_action = 0.0
    episodic_abs_error_action_eyym = 0.0
    t = 0
    # Iterate over the steps of each epoch
    #while (t < steps_per_epoch):
    while (t < steps_per_epoch) and (episode < episodes_max):
        if render:
            env.render()

        # Get the logits, action, and take one step in the environment
        observation = observation.reshape(1, -1)
        logits, action = sample_action(observation)
        #observation_new, reward, done, _, _ = env.step(action[0].numpy())
        observation_new, reward, done, _ ,torque_wanted, torque_actual= env.step(action[0].numpy().item())
        if CartPole == CartPoleEnvCustomized:
          x_obs = observation_new[0]
          reward_learn= reward*(x_obs>-0.1 and x_obs<0.1)
        else:
          reward_learn = reward
        episode_return += reward

        episodic_abs_error_action += abs(torque_wanted-torque_actual)
        episodic_abs_error_action_eyym +=abs(env.MRAC.y-env.MRAC.y_m)

        # Get the value and log-probability of the action
        value_t = critic(observation)
        logprobability_t = logprobabilities(logits, action)
        # Store obs, act, rew, v_t, logp_pi_t
        buffer.store(observation, action, reward_learn, value_t, logprobability_t)
        # Update the observation
        observation = observation_new

        # Finish trajectory if reached to a terminal state
        terminal = done
        if terminal or (t == steps_per_epoch - 1) or ((t+1)%steps_per_episode_goal==0):
            #print(f"Episode: {episode}; Acc. Reward: {episode_return:.2f}")
            acc_ep_reward_list.append(episode_return)
            avg_return = round(np.mean(acc_ep_reward_list[-40:]))
            avg_reward_list.append(avg_return)
            episode_return = 0.0
            episode += 1
        #observation, _ = env.reset()
        if terminal or (t == steps_per_epoch - 1):# not necessarily (t+1)%steps_per_episode_goal==0
            last_value = 0 if done else critic(observation.reshape(1, -1))
            buffer.finish_trajectory(last_value)
            observation = env.reset()
            print(f"Episode: {episode}; Acc. Reward: {avg_return:.1f}; Pole fell: {terminal}")
            ep_abs_error_action_list.append(episodic_abs_error_action/t)
            ep_abs_error_action_list_eyym.append(episodic_abs_error_action_eyym/t)
            avg_ep_abs_error = np.mean(ep_abs_error_action_list[-40:])
            avg_ep_abs_error_eyym = np.mean(ep_abs_error_action_list_eyym[-40:])
            print("Avg Action Abs Error (e_ry, e_yym) is ({}, {})".format(f"{avg_ep_abs_error:.2e}", f"{avg_ep_abs_error_eyym:.2e}"))
            print("K_MRAC=",env.MRAC.k_hat)

            #acc_ep_reward_list.append(episode_return)
            #print(f"Episode: {episode} ;Acc. Reward: {episode_return:.1f}")
            #episode_return = 0.0
        t+=1
        #if episode >= episodes_max:
        #  break

    # Get values from the buffer
    (
        observation_buffer,
        action_buffer,
        advantage_buffer,
        return_buffer,
        logprobability_buffer,
    ) = buffer.get()

    # Update the policy and implement early stopping using KL divergence
    for _ in range(train_policy_iterations):
        kl = train_policy(
            observation_buffer, action_buffer, logprobability_buffer, advantage_buffer
        )
        if kl > 1.5 * target_kl:
            # Early Stopping
            break

    # Update the value function
    for _ in range(train_value_iterations):
        train_value_function(observation_buffer, return_buffer)
    epoch+=1
# Out:
# Streaming output truncated to the last 5000 lines.
# K_MRAC= [ 16.45709354 -19.97886064   8.42421933   3.31082282]
# Episode: 492; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.49e-01, 2.76e-01)
# K_MRAC= [ 16.35317923 -19.89370711   8.40325022   3.58178214]
# Episode: 493; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.48e-01, 2.76e-01)
# K_MRAC= [ 16.44217024 -19.88999112   8.42030522   4.0525892 ]
# Episode: 494; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.48e-01, 2.77e-01)
# K_MRAC= [ 16.40082398 -19.89312555   8.41266286   4.32228545]
# Episode: 495; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.47e-01, 2.77e-01)
# K_MRAC= [ 16.60245323 -19.91188908   8.45674142   4.46750268]
# Episode: 496; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.47e-01, 2.77e-01)
# K_MRAC= [ 16.63511327 -19.93822076   8.46853976   4.70918141]
# Episode: 497; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.46e-01, 2.77e-01)
# K_MRAC= [ 16.76436139 -19.85524967   8.47779517   4.8474092 ]
# Episode: 498; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.45e-01, 2.77e-01)
# K_MRAC= [ 16.77820948 -19.82795129   8.47510511   5.02199477]
# Episode: 499; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.45e-01, 2.78e-01)
# K_MRAC= [ 16.89417263 -19.78162462   8.48903241   4.95248346]
# Episode: 500; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.44e-01, 2.78e-01)
# K_MRAC= [ 17.44023703 -19.85844201   8.61360876   4.9850673 ]
# Episode: 501; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.44e-01, 2.78e-01)
# K_MRAC= [ 17.35506758 -19.99455425   8.63761515   4.80489762]
# Episode: 502; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.43e-01, 2.78e-01)
# K_MRAC= [ 17.33926421 -19.99846147   8.66564964   4.4675675 ]
# Episode: 503; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.43e-01, 2.78e-01)
# K_MRAC= [ 17.28899888 -19.96552762   8.6611314    4.6889589 ]
# Episode: 504; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.42e-01, 2.78e-01)
# K_MRAC= [ 17.16575782 -20.           8.65885855   4.56241684]
# Episode: 505; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.42e-01, 2.78e-01)
# K_MRAC= [ 17.04935242 -20.           8.65499987   4.77873036]
# Episode: 506; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.41e-01, 2.78e-01)
# K_MRAC= [ 17.10283133 -19.99622308   8.70163697   4.70863397]
# Episode: 507; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.41e-01, 2.78e-01)
# K_MRAC= [ 16.9983713  -20.           8.70083559   4.62806354]
# Episode: 508; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.40e-01, 2.78e-01)
# K_MRAC= [ 16.92982564 -20.           8.73087038   4.1997406 ]
# Episode: 509; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.40e-01, 2.79e-01)
# K_MRAC= [ 16.81728774 -19.98090733   8.73104773   4.20994742]
# Episode: 510; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.39e-01, 2.79e-01)
# K_MRAC= [ 16.67893499 -20.           8.72636089   4.0476481 ]
# Episode: 511; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.39e-01, 2.79e-01)
# K_MRAC= [ 16.70683695 -19.99999671   8.75574149   3.84673777]
# Episode: 512; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.38e-01, 2.79e-01)
# K_MRAC= [ 16.64727394 -19.99439782   8.76513546   4.23466135]
# Episode: 513; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.37e-01, 2.79e-01)
# K_MRAC= [ 16.62341142 -19.95496181   8.75812154   4.40997092]
# Episode: 514; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.37e-01, 2.79e-01)
# K_MRAC= [ 17.30142016 -19.79862813   8.86245655   4.93824805]
# Episode: 515; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.37e-01, 2.79e-01)
# K_MRAC= [ 17.4815934  -19.96936393   8.93263836   4.77249155]
# Episode: 516; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.36e-01, 2.79e-01)
# K_MRAC= [ 17.18859602 -19.98701297   8.940252     4.50846793]
# Episode: 517; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.36e-01, 2.79e-01)
# K_MRAC= [ 17.20062161 -19.99661546   8.94695488   4.44682282]
# Episode: 518; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.36e-01, 2.79e-01)
# K_MRAC= [ 17.41808726 -19.98658063   9.06385952   4.21755342]
# Episode: 519; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.35e-01, 2.79e-01)
# K_MRAC= [ 17.7717513  -19.9984486    9.14308472   4.78417962]
# Episode: 520; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.35e-01, 2.79e-01)
# K_MRAC= [ 17.65209693 -20.           9.14050233   4.69348277]
# Episode: 521; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.35e-01, 2.79e-01)
# K_MRAC= [ 17.7598985  -20.           9.17605046   4.66059201]
# Episode: 522; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.35e-01, 2.79e-01)
# K_MRAC= [ 17.92300472 -20.           9.21337666   4.55113716]
# Episode: 523; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.35e-01, 2.79e-01)
# K_MRAC= [ 17.77120019 -19.97362451   9.20189915   4.81114769]
# Episode: 524; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.34e-01, 2.79e-01)
# K_MRAC= [ 18.06325016 -19.85511684   9.2400358    5.38507881]
# Episode: 525; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.34e-01, 2.79e-01)
# K_MRAC= [ 18.13406904 -20.           9.29036237   5.02925958]
# Episode: 526; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.34e-01, 2.79e-01)
# K_MRAC= [ 18.02468044 -20.           9.30741087   4.73428859]
# Episode: 527; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.34e-01, 2.79e-01)
# K_MRAC= [ 18.22528376 -19.95838464   9.34794008   4.76786104]
# Episode: 528; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.33e-01, 2.79e-01)
# K_MRAC= [ 18.36818184 -20.           9.39494134   4.48335083]
# Episode: 529; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.33e-01, 2.79e-01)
# K_MRAC= [ 18.35191394 -19.96387173   9.40268956   4.66228863]
# Episode: 530; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.33e-01, 2.79e-01)
# K_MRAC= [ 18.06497366 -20.           9.4116626    4.29957722]
# Episode: 531; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.33e-01, 2.79e-01)
# K_MRAC= [ 17.98045081 -20.           9.41435929   3.87082602]
# Episode: 532; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.33e-01, 2.79e-01)
# K_MRAC= [ 17.92427635 -20.           9.46003648   4.39977693]
# Episode: 533; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.33e-01, 2.80e-01)
# K_MRAC= [ 18.05638722 -20.           9.48971858   5.09679444]
# Episode: 534; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.33e-01, 2.80e-01)
# K_MRAC= [ 17.99186746 -20.           9.49096857   5.16600398]
# Episode: 535; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.33e-01, 2.80e-01)
# K_MRAC= [ 17.82462836 -19.96819679   9.47624281   5.40497479]
# Episode: 536; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.32e-01, 2.80e-01)
# K_MRAC= [ 17.64386662 -19.99853806   9.47973672   5.34149604]
# Episode: 537; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.32e-01, 2.80e-01)
# K_MRAC= [ 17.76411134 -19.99855347   9.53961702   4.8979037 ]
# Episode: 538; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.32e-01, 2.80e-01)
# K_MRAC= [ 17.73225683 -19.96907707   9.53969927   4.98010787]
# Episode: 539; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.32e-01, 2.80e-01)
# K_MRAC= [ 17.4531547  -19.99226874   9.52292244   4.9490703 ]
# Episode: 540; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.32e-01, 2.80e-01)
# K_MRAC= [ 17.42558896 -19.96810632   9.5202577    4.93158847]
# Episode: 541; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.31e-01, 2.80e-01)
# K_MRAC= [ 17.3814844  -19.98275575   9.51650574   5.20025015]
# Episode: 543; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.31e-01, 2.80e-01)
# K_MRAC= [ 17.28240349 -20.           9.52161106   5.06898836]
# Episode: 544; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.31e-01, 2.80e-01)
# K_MRAC= [ 17.98391146 -19.87376029   9.66909607   5.53940303]
# Episode: 545; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.30e-01, 2.80e-01)
# K_MRAC= [ 17.72083227 -20.           9.6655951    5.11066026]
# Episode: 546; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.30e-01, 2.80e-01)
# K_MRAC= [ 17.85342654 -19.94467921   9.68430816   5.2248505 ]
# Episode: 547; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.30e-01, 2.80e-01)
# K_MRAC= [ 17.90041415 -19.87571305   9.68953243   5.63911807]
# Episode: 548; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.30e-01, 2.80e-01)
# K_MRAC= [ 17.6876564  -20.           9.70131962   4.98414835]
# Episode: 549; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.30e-01, 2.81e-01)
# K_MRAC= [ 17.6578428  -19.9769791    9.71076099   5.14606151]
# Episode: 550; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.30e-01, 2.81e-01)
# K_MRAC= [ 17.55669637 -19.99608447   9.73862781   4.99961853]
# Episode: 551; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.30e-01, 2.81e-01)
# K_MRAC= [ 17.26272445 -20.           9.73243568   4.67901609]
# Episode: 552; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.30e-01, 2.81e-01)
# K_MRAC= [ 17.34451077 -20.           9.75173731   4.5612621 ]
# Episode: 553; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.30e-01, 2.81e-01)
# K_MRAC= [ 17.44087684 -19.95451701   9.76192901   4.53107116]
# Episode: 554; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.30e-01, 2.81e-01)
# K_MRAC= [ 17.72925213 -19.93187183   9.82933814   4.8682527 ]
# Episode: 555; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.29e-01, 2.81e-01)
# K_MRAC= [ 17.55507134 -19.99974088   9.84196059   5.09547769]
# Episode: 556; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.29e-01, 2.81e-01)
# K_MRAC= [ 17.39557043 -19.99256004   9.83949217   4.91431279]
# Episode: 557; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.29e-01, 2.81e-01)
# K_MRAC= [ 17.28922991 -20.           9.84732426   4.63024437]
# Episode: 558; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.29e-01, 2.81e-01)
# K_MRAC= [ 16.97237538 -20.           9.84642754   4.81564307]
# Episode: 559; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.29e-01, 2.81e-01)
# K_MRAC= [ 16.90726524 -20.           9.86138523   4.42768996]
# Episode: 560; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.29e-01, 2.81e-01)
# K_MRAC= [ 16.7921301  -19.98115062   9.85222832   4.50793119]
# Episode: 561; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.28e-01, 2.81e-01)
# K_MRAC= [ 16.58387962 -20.           9.84341083   4.66373586]
# Episode: 562; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.28e-01, 2.81e-01)
# K_MRAC= [ 16.58255959 -19.98537471   9.86117713   4.7016213 ]
# Episode: 563; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.28e-01, 2.81e-01)
# K_MRAC= [ 16.36078542 -20.           9.85594404   4.83150307]
# Episode: 564; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.27e-01, 2.81e-01)
# K_MRAC= [ 16.38143523 -19.98518848   9.86547237   4.81853254]
# Episode: 565; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.27e-01, 2.81e-01)
# K_MRAC= [ 16.38042834 -19.99379056   9.91237127   4.0188015 ]
# Episode: 566; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.26e-01, 2.82e-01)
# K_MRAC= [ 16.49470538 -19.92223797   9.92696604   4.32505217]
# Episode: 567; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.26e-01, 2.82e-01)
# K_MRAC= [ 17.1623255  -19.95317162  10.06898593   4.11824498]
# Episode: 568; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.26e-01, 2.82e-01)
# K_MRAC= [ 17.37693956 -19.89850448  10.11797424   3.48826852]
# Episode: 569; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.25e-01, 2.82e-01)
# K_MRAC= [ 17.44923956 -19.85357013  10.12344737   3.89727044]
# Episode: 570; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.25e-01, 2.82e-01)
# K_MRAC= [ 17.60483592 -19.81956895  10.14776641   4.16866473]
# Episode: 571; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.25e-01, 2.82e-01)
# K_MRAC= [ 17.50822371 -19.99967998  10.18681847   3.99391115]
# Episode: 572; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.24e-01, 2.82e-01)
# K_MRAC= [ 17.58234507 -19.94481867  10.19358847   4.03703177]
# Episode: 573; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.24e-01, 2.82e-01)
# K_MRAC= [ 17.40561499 -20.          10.18729505   3.84681956]
# Episode: 574; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.23e-01, 2.82e-01)
# K_MRAC= [ 17.40312906 -19.96833027  10.19175999   4.17315536]
# Episode: 575; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.23e-01, 2.82e-01)
# K_MRAC= [ 17.74015724 -19.89644894  10.24623973   4.17813494]
# Episode: 576; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.22e-01, 2.82e-01)
# K_MRAC= [ 18.12348665 -19.91805364  10.34136984   4.4554806 ]
# Episode: 577; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.22e-01, 2.82e-01)
# K_MRAC= [ 17.99751419 -20.          10.36277157   5.29639296]
# Episode: 578; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.22e-01, 2.82e-01)
# K_MRAC= [ 17.98861257 -20.          10.37878199   4.98780162]
# Episode: 579; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.21e-01, 2.82e-01)
# K_MRAC= [ 18.05115217 -19.99512801  10.41613631   4.97877024]
# Episode: 580; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.21e-01, 2.82e-01)
# K_MRAC= [ 18.15569857 -19.97845491  10.43371097   4.77306627]
# Episode: 581; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.21e-01, 2.82e-01)
# K_MRAC= [ 18.26682543 -19.96711581  10.45366853   4.57895944]
# Episode: 582; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.21e-01, 2.82e-01)
# K_MRAC= [ 18.22132824 -19.99854244  10.47846351   4.8121361 ]
# Episode: 583; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.20e-01, 2.82e-01)
# K_MRAC= [ 18.33992723 -19.94194232  10.56190168   5.06624197]
# Episode: 584; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.20e-01, 2.82e-01)
# K_MRAC= [ 18.4764062  -19.99605619  10.6228733    4.58954716]
# Episode: 585; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.20e-01, 2.82e-01)
# K_MRAC= [ 18.54974535 -19.98902413  10.64353346   4.70498776]
# Episode: 586; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.20e-01, 2.82e-01)
# K_MRAC= [ 18.36021082 -20.          10.63112825   4.66869145]
# Episode: 588; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.19e-01, 2.83e-01)
# K_MRAC= [ 17.90830788 -20.          10.59258887   4.90838892]
# Episode: 589; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.19e-01, 2.83e-01)
# K_MRAC= [ 18.1266186  -19.88517807  10.63032805   4.59915429]
# Episode: 590; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.19e-01, 2.83e-01)
# K_MRAC= [ 18.05214629 -20.          10.64107926   4.475454  ]
# Episode: 591; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.19e-01, 2.83e-01)
# K_MRAC= [ 18.52711449 -20.          10.7886884    5.30970191]
# Episode: 592; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.18e-01, 2.83e-01)
# K_MRAC= [ 18.37536732 -20.          10.80106247   5.4124993 ]
# Episode: 593; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.18e-01, 2.83e-01)
# K_MRAC= [ 18.45825187 -19.94485643  10.81702152   5.50572403]
# Episode: 594; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.18e-01, 2.83e-01)
# K_MRAC= [ 18.34837855 -19.99067755  10.82131085   5.53361602]
# Episode: 595; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.17e-01, 2.83e-01)
# K_MRAC= [ 18.39174643 -19.97611841  10.83012807   5.63905137]
# Episode: 596; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.17e-01, 2.83e-01)
# K_MRAC= [ 18.46377164 -19.9676705   10.85452323   5.34667707]
# Episode: 597; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.17e-01, 2.84e-01)
# K_MRAC= [ 18.51018931 -19.90826173  10.85192501   5.67197108]
# Episode: 598; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.17e-01, 2.84e-01)
# K_MRAC= [ 18.27763127 -19.97371404  10.8345598    5.67035791]
# Episode: 599; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.17e-01, 2.84e-01)
# K_MRAC= [ 18.06250408 -19.99606007  10.82748789   5.30199918]
# Episode: 600; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.17e-01, 2.84e-01)
# K_MRAC= [ 18.02974138 -20.          10.83446218   5.14723716]
# Episode: 601; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.17e-01, 2.84e-01)
# K_MRAC= [ 18.16050629 -19.8937792   10.84413693   5.45821938]
# Episode: 602; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.16e-01, 2.84e-01)
# K_MRAC= [ 18.11860456 -19.92422023  10.84184479   5.66250408]
# Episode: 603; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.16e-01, 2.84e-01)
# K_MRAC= [ 18.11034387 -19.98619395  10.86730214   5.30561877]
# Episode: 604; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.16e-01, 2.84e-01)
# K_MRAC= [ 18.0012201  -19.99991314  10.87619449   4.90225367]
# Episode: 605; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.16e-01, 2.85e-01)
# K_MRAC= [ 18.06157161 -20.          10.91433054   4.61875942]
# Episode: 606; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.16e-01, 2.85e-01)
# K_MRAC= [ 18.04880932 -20.          10.92762322   4.17065946]
# Episode: 607; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.16e-01, 2.85e-01)
# K_MRAC= [ 17.96469173 -19.99977169  10.95876022   3.53245445]
# Episode: 608; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.16e-01, 2.85e-01)
# K_MRAC= [ 17.82789676 -20.          10.95682679   3.42307406]
# Episode: 609; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.16e-01, 2.85e-01)
# K_MRAC= [ 17.74875058 -19.96555284  11.00914806   3.65585356]
# Episode: 610; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.16e-01, 2.85e-01)
# K_MRAC= [ 17.46649393 -20.          11.02798249   3.20223951]
# Episode: 611; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.16e-01, 2.85e-01)
# K_MRAC= [ 17.59264055 -19.94581085  11.09954487   3.54709774]
# Episode: 612; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.16e-01, 2.86e-01)
# K_MRAC= [ 17.63478978 -19.99117783  11.14350881   3.90956429]
# Episode: 613; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.16e-01, 2.86e-01)
# K_MRAC= [ 17.71777918 -19.90683067  11.14323726   4.35161925]
# Episode: 614; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.16e-01, 2.86e-01)
# K_MRAC= [ 17.62568177 -20.          11.1448047    3.99180533]
# Episode: 615; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.15e-01, 2.86e-01)
# K_MRAC= [ 17.56757459 -19.99112026  11.15399439   5.10522281]
# Episode: 616; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.15e-01, 2.86e-01)
# K_MRAC= [ 17.41106685 -20.          11.20293807   5.28992701]
# Episode: 617; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.15e-01, 2.87e-01)
# K_MRAC= [ 17.33008865 -20.          11.23559391   4.61345012]
# Episode: 618; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.15e-01, 2.87e-01)
# K_MRAC= [ 17.06067481 -19.97170058  11.23199106   4.52717392]
# Episode: 619; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.15e-01, 2.87e-01)
# K_MRAC= [ 17.41204944 -19.99257106  11.33196842   4.23977163]
# Episode: 620; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.15e-01, 2.87e-01)
# K_MRAC= [ 17.22467154 -19.86297564  11.3134575    5.0715885 ]
# Episode: 621; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.14e-01, 2.87e-01)
# K_MRAC= [ 17.20824971 -19.9820215   11.3339823    4.60863558]
# Episode: 622; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.14e-01, 2.87e-01)
# K_MRAC= [ 17.0359814  -19.96663027  11.3559543    4.85488232]
# Episode: 623; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.14e-01, 2.87e-01)
# K_MRAC= [ 16.91080163 -20.          11.36634871   5.02222025]
# Episode: 624; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.14e-01, 2.88e-01)
# K_MRAC= [ 16.78532179 -19.96252024  11.37050038   4.80945468]
# Episode: 625; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.14e-01, 2.88e-01)
# K_MRAC= [ 16.49763268 -20.          11.35294647   4.92518686]
# Episode: 626; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.13e-01, 2.88e-01)
# K_MRAC= [ 16.35681313 -20.          11.36985012   4.83656618]
# Episode: 627; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.13e-01, 2.88e-01)
# K_MRAC= [ 16.37465474 -19.99910369  11.38007892   4.72796469]
# Episode: 628; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.13e-01, 2.88e-01)
# K_MRAC= [ 16.54459131 -19.97869304  11.43985389   5.02122523]
# Episode: 629; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.13e-01, 2.88e-01)
# K_MRAC= [ 16.76442792 -19.8729406   11.47652514   5.26299526]
# Episode: 630; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.12e-01, 2.88e-01)
# K_MRAC= [ 16.7551     -19.85668323  11.47140808   5.41605078]
# Episode: 631; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.12e-01, 2.88e-01)
# K_MRAC= [ 16.96548753 -19.94189142  11.53052722   5.53896714]
# Episode: 632; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.12e-01, 2.88e-01)
# K_MRAC= [ 16.84683254 -19.98971155  11.52068312   5.53459489]
# Episode: 633; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.12e-01, 2.89e-01)
# K_MRAC= [ 16.60504971 -19.96715745  11.51123736   5.45742248]
# Episode: 634; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.12e-01, 2.89e-01)
# K_MRAC= [ 16.67333397 -19.94446659  11.52035604   5.4305669 ]
# Episode: 635; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.11e-01, 2.89e-01)
# K_MRAC= [ 16.59652061 -20.          11.52814804   4.99425563]
# Episode: 636; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.11e-01, 2.89e-01)
# K_MRAC= [ 16.49440666 -20.          11.54361267   4.7271558 ]
# Episode: 637; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.11e-01, 2.89e-01)
# K_MRAC= [ 16.46198353 -20.          11.54580973   4.62705775]
# Episode: 638; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.11e-01, 2.89e-01)
# K_MRAC= [ 16.51956143 -19.98749398  11.56339632   4.56368455]
# Episode: 639; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.10e-01, 2.89e-01)
# K_MRAC= [ 16.44440712 -20.          11.57656409   4.23218485]
# Episode: 640; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.10e-01, 2.89e-01)
# K_MRAC= [ 16.2968655  -19.96920217  11.55207243   4.53604271]
# Episode: 641; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.10e-01, 2.89e-01)
# K_MRAC= [ 16.3762682  -19.94005841  11.57000684   4.47597713]
# Episode: 642; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.10e-01, 2.89e-01)
# K_MRAC= [ 16.1523848  -19.99009049  11.5596771    4.51807855]
# Episode: 643; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.89e-01)
# K_MRAC= [ 15.94472363 -20.          11.55324563   4.56123984]
# Episode: 644; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.89e-01)
# K_MRAC= [ 16.0143062  -20.          11.58692831   4.20398287]
# Episode: 645; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.89e-01)
# K_MRAC= [ 16.14882539 -19.97333308  11.62250542   4.42605645]
# Episode: 646; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.89e-01)
# K_MRAC= [ 15.98940277 -19.99604361  11.60875812   4.48862784]
# Episode: 647; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.89e-01)
# K_MRAC= [ 16.0123591  -19.91820076  11.62366269   4.5612222 ]
# Episode: 648; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.89e-01)
# K_MRAC= [ 16.25682109 -19.81516854  11.65194864   4.86071099]
# Episode: 649; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.89e-01)
# K_MRAC= [ 16.40000448 -19.9427102   11.70713369   3.93876044]
# Episode: 650; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.89e-01)
# K_MRAC= [ 16.19731232 -20.          11.72850889   4.51166603]
# Episode: 651; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.89e-01)
# K_MRAC= [ 16.02731533 -19.99937555  11.71817011   4.44840649]
# Episode: 652; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.90e-01)
# K_MRAC= [ 16.30501881 -19.88060079  11.77770439   4.8004789 ]
# Episode: 653; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.90e-01)
# K_MRAC= [ 16.23333986 -19.9978774   11.80311912   4.39678769]
# Episode: 654; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.90e-01)
# K_MRAC= [ 16.08018249 -19.98555611  11.79003758   4.44866279]
# Episode: 655; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.90e-01)
# K_MRAC= [ 16.06765105 -20.          11.79500708   4.66598487]
# Episode: 656; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.90e-01)
# K_MRAC= [ 15.88060703 -20.          11.77944149   4.91887427]
# Episode: 657; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.90e-01)
# K_MRAC= [ 15.68299617 -19.98757417  11.76763506   4.85958337]
# Episode: 658; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.90e-01)
# K_MRAC= [ 16.01713123 -19.98489279  11.8417777    4.96808306]
# Episode: 659; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.90e-01)
# K_MRAC= [ 16.06708606 -19.9731856   11.86827908   4.75854455]
# Episode: 660; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.90e-01)
# K_MRAC= [ 16.0041927  -19.97437744  11.89480211   4.79085555]
# Episode: 661; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.90e-01)
# K_MRAC= [ 15.9873299  -19.90954414  11.88570827   4.98594133]
# Episode: 662; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.90e-01)
# K_MRAC= [ 16.14625746 -19.94999314  11.95481809   5.28499557]
# Episode: 663; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.89e-01)
# K_MRAC= [ 15.90771515 -19.97341548  11.95160086   5.27152202]
# Episode: 664; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 15.88874391 -19.91239962  11.96002645   5.4411017 ]
# Episode: 665; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 15.86120964 -20.          11.99123647   5.1342206 ]
# Episode: 666; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 15.84509702 -19.94305908  11.98342645   5.15674425]
# Episode: 667; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 16.05816434 -19.78371558  11.99417121   5.44240266]
# Episode: 668; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 15.88914213 -19.97382675  12.00365967   4.96975773]
# Episode: 669; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 15.9672623  -19.99217958  12.02467892   5.06429062]
# Episode: 670; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 15.99781908 -19.96520907  12.03671552   5.0936148 ]
# Episode: 671; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 16.20807833 -19.91667739  12.08472928   5.33360067]
# Episode: 672; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 16.34408783 -19.99999957  12.14638173   5.34895715]
# Episode: 673; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 16.40118675 -19.96788254  12.15501784   5.28639791]
# Episode: 674; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 16.25981585 -19.96624387  12.14550602   5.28657169]
# Episode: 675; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 16.10873898 -20.          12.15457573   4.80562249]
# Episode: 676; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 16.44008285 -19.96499554  12.22094301   4.87208904]
# Episode: 677; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 16.25408771 -20.          12.2107222    4.85852064]
# Episode: 678; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 16.12856182 -20.          12.22632077   4.23387692]
# Episode: 679; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.89e-01)
# K_MRAC= [ 16.14207793 -19.99861615  12.26809869   4.269633  ]
# Episode: 680; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 15.98414048 -19.98306667  12.25977901   4.22990723]
# Episode: 681; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 16.36893896 -19.88886378  12.31789813   4.62105607]
# Episode: 682; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 16.41845678 -19.99528945  12.35690887   4.94734141]
# Episode: 683; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 16.33504264 -19.92552302  12.35731862   5.1193482 ]
# Episode: 684; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 16.16603264 -19.91394522  12.33837927   5.88473581]
# Episode: 685; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 16.0538049  -20.          12.35047829   5.70470254]
# Episode: 686; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 15.90393298 -20.          12.34261039   5.62295669]
# Episode: 688; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 15.84169703 -19.98558366  12.35085683   5.60320019]
# Episode: 689; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 15.92506187 -19.83967596  12.36526569   6.09482089]
# Episode: 690; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 15.75178583 -19.92895804  12.3484669    6.34819309]
# Episode: 691; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 15.71933686 -19.95918833  12.34802317   6.31523742]
# Episode: 692; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 15.60764854 -20.          12.42992025   6.49434159]
# Episode: 693; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 15.53191458 -19.99825752  12.45287452   6.11603535]
# Episode: 694; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 15.31432273 -19.9990255   12.45676939   5.68459517]
# Episode: 695; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 15.35891481 -20.          12.47881636   5.6930713 ]
# Episode: 696; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 15.13903215 -20.          12.4948692    4.77180753]
# Episode: 697; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 15.20571881 -19.9999954   12.52081728   4.69703642]
# Episode: 698; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.90e-01)
# K_MRAC= [ 15.5074874  -19.93256308  12.57849659   5.71889997]
# Episode: 699; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 15.27912559 -20.          12.57117526   5.50183947]
# Episode: 700; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 15.43149847 -19.8757791   12.5877471    5.99180934]
# Episode: 701; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 15.25366    -20.          12.63945022   4.10374216]
# Episode: 702; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 15.93473812 -19.72301399  12.72940362   5.17201275]
# Episode: 703; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 16.15447373 -19.77895225  12.78453839   5.03092623]
# Episode: 704; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 16.02473141 -19.85038465  12.77287641   5.10393751]
# Episode: 705; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 15.89996023 -19.99300876  12.77644699   4.92061125]
# Episode: 706; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 15.88492306 -20.          12.81404261   4.21837786]
# Episode: 707; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 15.86701908 -19.95396062  12.83151294   3.94432121]
# Episode: 708; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 15.85383678 -19.99694992  12.83952944   4.04923041]
# Episode: 709; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 15.82097593 -19.9956652   12.85594873   3.8087437 ]
# Episode: 710; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 15.8465059  -19.93241257  12.88177081   5.15850613]
# Episode: 711; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 16.09738115 -19.92886809  12.93170995   5.57184326]
# Episode: 712; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 16.18783891 -19.89850336  12.94372855   5.53201457]
# Episode: 713; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 16.20666381 -19.97294581  12.96238202   5.30522287]
# Episode: 714; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.91e-01)
# K_MRAC= [ 16.47241931 -19.9122478   13.00339352   4.99608638]
# Episode: 715; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 16.34913297 -20.          13.00027115   4.88433071]
# Episode: 716; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 16.31011202 -19.9900662   13.01768881   5.04136987]
# Episode: 717; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 16.30972657 -19.9662516   13.01921915   5.21771407]
# Episode: 718; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 16.3364828  -19.95950614  13.0447673    5.75681819]
# Episode: 719; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 16.33651281 -19.99374312  13.07942755   5.71604344]
# Episode: 720; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 16.31499307 -19.94177076  13.07244178   5.81556135]
# Episode: 721; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 16.17296489 -20.          13.08031731   5.54003952]
# Episode: 722; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 16.04111151 -20.          13.07764793   5.22962937]
# Episode: 723; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 16.25787023 -19.85888424  13.09281211   5.85519484]
# Episode: 724; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 16.27906522 -19.8917092   13.1036161    6.24137553]
# Episode: 725; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 16.43608454 -19.93553697  13.14378551   6.24455581]
# Episode: 726; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 16.31096109 -20.          13.14372336   6.21482365]
# Episode: 727; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 16.23663478 -19.96092906  13.13711868   6.32851713]
# Episode: 728; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 16.08165586 -20.          13.14629746   6.09767264]
# Episode: 729; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 15.89045249 -19.99232881  13.13924028   6.02388811]
# Episode: 730; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 15.65877519 -19.97862498  13.16403365   5.95668553]
# Episode: 731; Acc. Reward: 9.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.05e-01, 2.92e-01)
# K_MRAC= [ 16.05136741 -19.94524754  13.24530555   6.01588955]
# Episode: 732; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.92e-01)
# K_MRAC= [ 16.17303369 -19.91947877  13.26448505   6.07837732]
# Episode: 733; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.92e-01)
# K_MRAC= [ 16.50908711 -20.          13.37694666   5.90363357]
# Episode: 734; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.92e-01)
# K_MRAC= [ 16.35737095 -20.          13.36682543   5.79815108]
# Episode: 735; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.92e-01)
# K_MRAC= [ 16.25616338 -19.99536176  13.37112438   5.61130739]
# Episode: 737; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.92e-01)
# K_MRAC= [ 16.24367701 -20.          13.37978835   5.14579793]
# Episode: 738; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.92e-01)
# K_MRAC= [ 16.14222774 -19.96471455  13.38001727   5.01202209]
# Episode: 739; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.92e-01)
# K_MRAC= [ 16.29832219 -20.          13.43362644   4.71291131]
# Episode: 740; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.92e-01)
# K_MRAC= [ 16.40741926 -20.          13.4757924    4.77664096]
# Episode: 741; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.92e-01)
# K_MRAC= [ 16.79475684 -19.92620278  13.54670052   5.39858899]
# Episode: 742; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.92e-01)
# K_MRAC= [ 16.60259176 -19.98061569  13.54275736   4.99623954]
# Episode: 743; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.92e-01)
# K_MRAC= [ 16.65701875 -19.99911611  13.59951815   4.66538207]
# Episode: 744; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.92e-01)
# K_MRAC= [ 17.1370602  -20.          13.72578881   4.35841558]
# Episode: 745; Acc. Reward: 7.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.92e-01)
# K_MRAC= [ 17.50480664 -19.80505661  13.76038899   4.95138093]
# Episode: 746; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.92e-01)
# K_MRAC= [ 17.72676938 -19.8510705   13.81398431   5.23256257]
# Episode: 747; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.92e-01)
# K_MRAC= [ 17.64329922 -20.          13.87160477   4.30772617]
# Episode: 748; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.92e-01)
# K_MRAC= [ 17.31226876 -20.          13.83998657   4.76415256]
# Episode: 749; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.92e-01)
# K_MRAC= [ 17.28236818 -19.95404055  13.84822504   4.88753814]
# Episode: 750; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.92e-01)
# K_MRAC= [ 17.48053352 -19.9987149   13.91902399   5.4615527 ]
# Episode: 751; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.92e-01)
# K_MRAC= [ 17.29399547 -19.99561494  13.89988048   5.58726314]
# Episode: 752; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.92e-01)
# K_MRAC= [ 17.65886245 -19.89924876  13.9647516    6.01754511]
# Episode: 753; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.92e-01)
# K_MRAC= [ 17.47672859 -20.          13.95601593   6.30274815]
# Episode: 754; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.07e-01, 2.92e-01)
# K_MRAC= [ 17.61010991 -19.98492797  14.01663222   6.03395841]
# Episode: 755; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.92e-01)
# K_MRAC= [ 17.43991736 -20.          14.00711258   6.13814012]
# Episode: 756; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.92e-01)
# K_MRAC= [ 17.32091428 -19.99981337  14.02762206   5.69761684]
# Episode: 757; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.92e-01)
# K_MRAC= [ 17.20985588 -20.          14.02542799   5.51270336]
# Episode: 758; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.92e-01)
# K_MRAC= [ 16.88878281 -19.98710886  14.0169272    5.01620737]
# Episode: 759; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.92e-01)
# K_MRAC= [ 16.95894198 -19.94908605  14.06861258   5.17269767]
# Episode: 760; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.92e-01)
# K_MRAC= [ 16.93702165 -20.          14.08430727   4.59561638]
# Episode: 761; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.92e-01)
# K_MRAC= [ 17.03278985 -19.98206809  14.10653384   4.64395884]
# Episode: 762; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.92e-01)
# K_MRAC= [ 17.08891328 -20.          14.15675197   4.06325226]
# Episode: 763; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.92e-01)
# K_MRAC= [ 16.88420371 -20.          14.14501227   4.04258996]
# Episode: 764; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.92e-01)
# K_MRAC= [ 16.96918703 -19.94248796  14.17576016   4.73815402]
# Episode: 765; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.92e-01)
# K_MRAC= [ 16.71563745 -19.96464003  14.16617932   4.64712589]
# Episode: 766; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.92e-01)
# K_MRAC= [ 16.42818943 -20.          14.17823084   4.12670227]
# Episode: 767; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.92e-01)
# K_MRAC= [ 16.74359643 -19.85608785  14.22900381   4.6034363 ]
# Episode: 768; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.92e-01)
# K_MRAC= [ 16.4921806  -19.97060277  14.21229127   4.84239252]
# Episode: 769; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.92e-01)
# K_MRAC= [ 16.77791496 -19.92068893  14.2621455    5.6532749 ]
# Episode: 770; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.92e-01)
# K_MRAC= [ 16.47852046 -19.99812819  14.24890967   5.63719851]
# Episode: 771; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.92e-01)
# K_MRAC= [ 16.47440085 -19.94775281  14.24871989   5.70606405]
# Episode: 772; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.92e-01)
# K_MRAC= [ 16.2293451  -20.          14.24678959   5.70466372]
# Episode: 773; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.92e-01)
# K_MRAC= [ 16.54507208 -19.90846637  14.29427722   5.64638987]
# Episode: 774; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.92e-01)
# K_MRAC= [ 16.59278637 -19.99628322  14.32138345   5.45465759]
# Episode: 775; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.92e-01)
# K_MRAC= [ 16.6135007  -20.          14.35712826   5.34887971]
# Episode: 776; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.92e-01)
# K_MRAC= [ 16.53218553 -19.98255934  14.35970126   5.09908463]
# Episode: 777; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.92e-01)
# K_MRAC= [ 16.65771395 -19.95968721  14.39812184   5.26058526]
# Episode: 778; Acc. Reward: 8.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.92e-01)
# K_MRAC= [ 16.91890139 -19.99184668  14.48707636   4.98416368]
# Episode: 779; Acc. Reward: 8.0; Pole fell: True
# ...
# K_MRAC= [ 12.4913288  -19.907201    19.96336866   3.97583442]
# Episode: 2123; Acc. Reward: 84.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.94e-01)
# K_MRAC= [ 12.93344004 -19.85908791  19.97749335   4.75196992]
# Epoch: 12
# Episode: 2124; Acc. Reward: 85.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.94e-01)
# K_MRAC= [ 12.11930771 -19.98280942  19.94012223   4.20517335]
# Episode: 2125; Acc. Reward: 85.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.94e-01)
# K_MRAC= [ 12.06610056 -19.85194625  19.99848727   4.76660687]
# Episode: 2126; Acc. Reward: 83.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.09e-01, 2.94e-01)
# K_MRAC= [ 12.01465031 -19.95941944  19.98778607   3.2398179 ]
# Episode: 2127; Acc. Reward: 84.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.10e-01, 2.94e-01)
# K_MRAC= [ 12.87671281 -20.          19.99253227   4.67227097]
# Episode: 2128; Acc. Reward: 84.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.11e-01, 2.95e-01)
# K_MRAC= [ 12.92426814 -19.99449077  19.98313585   4.41946537]
# Episode: 2129; Acc. Reward: 80.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.12e-01, 2.95e-01)
# K_MRAC= [ 13.14075786 -19.84974471  19.99919518   4.58912728]
# Episode: 2131; Acc. Reward: 84.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.13e-01, 2.95e-01)
# K_MRAC= [ 14.47472859 -19.83267704  19.9972889    5.46827307]
# Episode: 2133; Acc. Reward: 87.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.14e-01, 2.95e-01)
# K_MRAC= [ 13.97080801 -19.91168373  19.99054826   4.51295562]
# Episode: 2134; Acc. Reward: 86.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.15e-01, 2.95e-01)
# K_MRAC= [ 13.44917588 -19.90103902  19.9966891    5.76380272]
# Episode: 2135; Acc. Reward: 84.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.15e-01, 2.95e-01)
# K_MRAC= [ 13.93340521 -19.47181689  20.           5.01121194]
# Episode: 2137; Acc. Reward: 82.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.16e-01, 2.95e-01)
# K_MRAC= [ 15.16719921 -19.67452359  20.           5.03487985]
# Episode: 2138; Acc. Reward: 82.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.17e-01, 2.95e-01)
# K_MRAC= [ 15.08040471 -19.87349123  19.97655394   4.8957777 ]
# Episode: 2139; Acc. Reward: 84.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.17e-01, 2.95e-01)
# K_MRAC= [ 15.85898756 -19.7782045   20.           7.43788832]
# Episode: 2140; Acc. Reward: 85.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.18e-01, 2.96e-01)
# K_MRAC= [ 16.39382896 -19.9282087   20.           5.8338477 ]
# Episode: 2142; Acc. Reward: 85.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.19e-01, 2.96e-01)
# K_MRAC= [ 14.70132578 -19.97695167  19.97628147   4.4760226 ]
# Episode: 2143; Acc. Reward: 85.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.18e-01, 2.94e-01)
# K_MRAC= [ 15.10675927 -19.76487481  19.99748071   4.1464822 ]
# Episode: 2145; Acc. Reward: 83.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.18e-01, 2.94e-01)
# K_MRAC= [ 14.87194797 -19.99860927  19.97954072   3.46040851]
# Episode: 2146; Acc. Reward: 84.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.19e-01, 2.93e-01)
# K_MRAC= [ 14.39577541 -19.97168744  19.99321086   4.97998936]
# Episode: 2148; Acc. Reward: 86.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.20e-01, 2.93e-01)
# K_MRAC= [ 13.68527751 -20.          19.9372362    5.04633696]
# Episode: 2149; Acc. Reward: 90.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.21e-01, 2.92e-01)
# K_MRAC= [ 13.39631849 -19.99705515  19.99950548   6.49690768]
# Episode: 2150; Acc. Reward: 84.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.22e-01, 2.92e-01)
# K_MRAC= [ 13.46055951 -19.93409563  20.           4.87908709]
# Episode: 2151; Acc. Reward: 83.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.23e-01, 2.92e-01)
# K_MRAC= [ 14.03261674 -19.75678423  19.97558048   5.52650755]
# Episode: 2153; Acc. Reward: 79.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.24e-01, 2.92e-01)
# K_MRAC= [ 14.03676074 -19.77627999  20.           5.19093827]
# Episode: 2154; Acc. Reward: 87.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.25e-01, 2.92e-01)
# K_MRAC= [ 12.27529595 -19.97163022  19.99711413   4.29667288]
# Epoch: 13
# Episode: 2156; Acc. Reward: 91.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.26e-01, 2.91e-01)
# K_MRAC= [ 13.03094717 -19.96129033  19.99200902   4.49850955]
# Episode: 2157; Acc. Reward: 97.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.26e-01, 2.91e-01)
# K_MRAC= [ 12.97219694 -19.90814169  19.96956265   4.21128852]
# Episode: 2159; Acc. Reward: 97.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.26e-01, 2.91e-01)
# K_MRAC= [ 13.17742386 -19.83987696  19.97762924   4.68121206]
# Episode: 2161; Acc. Reward: 103.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.26e-01, 2.90e-01)
# K_MRAC= [ 13.79482599 -19.38323417  20.           5.66202813]
# Episode: 2163; Acc. Reward: 109.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.27e-01, 2.90e-01)
# K_MRAC= [ 15.37768581 -19.75855512  19.99762876   5.56041011]
# Episode: 2164; Acc. Reward: 110.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.27e-01, 2.90e-01)
# K_MRAC= [ 15.20815786 -19.94232293  19.97877096   6.09400188]
# Episode: 2166; Acc. Reward: 118.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.27e-01, 2.90e-01)
# K_MRAC= [ 13.04649904 -19.99863737  19.96674564   4.1991287 ]
# Episode: 2169; Acc. Reward: 128.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.27e-01, 2.90e-01)
# K_MRAC= [ 12.58670098 -19.58172145  20.           4.10023658]
# Episode: 2170; Acc. Reward: 131.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.27e-01, 2.90e-01)
# K_MRAC= [ 11.21766865 -20.          19.91483482   5.23846995]
# Epoch: 14
# Episode: 2172; Acc. Reward: 132.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.28e-01, 2.90e-01)
# K_MRAC= [ 13.05067953 -19.75999737  20.           3.95058409]
# Episode: 2174; Acc. Reward: 140.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.28e-01, 2.90e-01)
# K_MRAC= [ 10.66974279 -20.          19.92966102   5.16476632]
# Episode: 2176; Acc. Reward: 147.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.28e-01, 2.90e-01)
# K_MRAC= [ 11.24151323 -19.62039282  20.           4.14240704]
# Episode: 2178; Acc. Reward: 150.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.29e-01, 2.90e-01)
# K_MRAC= [  9.97595149 -19.63270161  19.90594106   4.90159685]
# Episode: 2180; Acc. Reward: 154.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.29e-01, 2.90e-01)
# K_MRAC= [ 10.25329848 -19.72137563  19.85337847   4.42666587]
# Episode: 2181; Acc. Reward: 160.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.29e-01, 2.90e-01)
# K_MRAC= [ 11.21370259 -19.89297491  19.98007803   4.57987091]
# Episode: 2183; Acc. Reward: 157.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.29e-01, 2.89e-01)
# K_MRAC= [ 11.28312767 -19.84511407  19.9709783    4.75770917]
# Episode: 2184; Acc. Reward: 157.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.30e-01, 2.89e-01)
# K_MRAC= [ 12.70780932 -19.35897333  20.           5.47613879]
# Episode: 2186; Acc. Reward: 157.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.31e-01, 2.89e-01)
# K_MRAC= [ 12.3171864  -19.95399226  19.98740711   5.9412785 ]
# Episode: 2187; Acc. Reward: 161.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.31e-01, 2.88e-01)
# K_MRAC= [ 11.65570695 -19.63753129  19.98883381   5.04016196]
# Episode: 2188; Acc. Reward: 162.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.31e-01, 2.88e-01)
# K_MRAC= [ 12.27370249 -19.80271323  19.99233087   3.86813191]
# Epoch: 15
# Episode: 2190; Acc. Reward: 167.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.29e-01, 2.88e-01)
# K_MRAC= [ 11.19130225 -19.8604247   20.           4.96645391]
# Episode: 2196; Acc. Reward: 196.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.29e-01, 2.87e-01)
# K_MRAC= [ 10.812709   -18.87549932  19.97591132   3.66584015]
# Episode: 2198; Acc. Reward: 203.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.28e-01, 2.87e-01)
# K_MRAC= [  9.69092982 -19.88894026  19.98170393   4.5379241 ]
# Epoch: 16
# Episode: 2204; Acc. Reward: 236.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.29e-01, 2.86e-01)
# K_MRAC= [ 10.37871827 -19.91591305  20.           4.79800548]
# Episode: 2207; Acc. Reward: 248.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.29e-01, 2.86e-01)
# K_MRAC= [  9.97422074 -19.83104446  19.88974867   5.88374081]
# Epoch: 17
# Episode: 2215; Acc. Reward: 287.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.29e-01, 2.85e-01)
# K_MRAC= [  7.86910801 -18.57054571  19.2133377    6.46169179]
# Epoch: 18
# Episode: 2221; Acc. Reward: 313.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.28e-01, 2.84e-01)
# K_MRAC= [ 10.3947042  -19.11030048  19.98669037   4.53412555]
# Episode: 2224; Acc. Reward: 338.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.28e-01, 2.84e-01)
# K_MRAC= [  8.66972384 -18.9640504   19.66717748   5.11188899]
# Epoch: 19
# Episode: 2232; Acc. Reward: 378.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.27e-01, 2.83e-01)
# K_MRAC= [  7.51330955 -19.66489871  19.48560723   6.22559037]
# Epoch: 20
# Episode: 2240; Acc. Reward: 371.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.27e-01, 2.82e-01)
# K_MRAC= [ 10.55625635 -19.91880648  19.92164705   5.56377587]
# Epoch: 21
# Episode: 2248; Acc. Reward: 386.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.27e-01, 2.81e-01)
# K_MRAC= [ 11.09526355 -19.55482225  19.96928873   5.9345846 ]
# Epoch: 22
# Episode: 2256; Acc. Reward: 392.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.26e-01, 2.80e-01)
# K_MRAC= [  9.49778903 -19.35539705  19.83461052   6.00637113]
# Epoch: 23
# Episode: 2264; Acc. Reward: 407.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.26e-01, 2.80e-01)
# K_MRAC= [ 10.84945129 -19.87720138  19.91787759   5.80776623]
# Epoch: 24
# Episode: 2272; Acc. Reward: 415.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.25e-01, 2.79e-01)
# K_MRAC= [ 10.39625319 -19.62067102  19.95387526   6.38347467]
# Epoch: 25
# Episode: 2276; Acc. Reward: 422.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.25e-01, 2.78e-01)
# K_MRAC= [ 10.8568678  -19.36823722  19.86360706   6.26738854]
# Episode: 2281; Acc. Reward: 433.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.25e-01, 2.77e-01)
# K_MRAC= [ 10.32220423 -19.34404569  19.87287705   6.62683428]
# Epoch: 26
# Episode: 2289; Acc. Reward: 435.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.25e-01, 2.77e-01)
# K_MRAC= [ 13.93263823 -19.95265058  19.99160835   6.1212623 ]
# Epoch: 27
# Episode: 2297; Acc. Reward: 436.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.25e-01, 2.76e-01)
# K_MRAC= [ 11.04645543 -19.92701809  19.93982908   7.03323102]
# Epoch: 28
# Episode: 2305; Acc. Reward: 440.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.25e-01, 2.75e-01)
# K_MRAC= [ 13.69440992 -19.99908693  19.99152661   6.31299719]
# Epoch: 29
# Episode: 2313; Acc. Reward: 444.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.24e-01, 2.75e-01)
# K_MRAC= [ 11.47325134 -19.98391499  19.9028283    7.2099415 ]
# Epoch: 30
# Episode: 2321; Acc. Reward: 459.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.25e-01, 2.74e-01)
# K_MRAC= [ 13.48547962 -19.99507294  20.           6.14440165]
# Epoch: 31
# Episode: 2329; Acc. Reward: 465.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.25e-01, 2.73e-01)
# K_MRAC= [ 13.06467805 -19.98154696  19.99155664   7.53732706]
# Epoch: 32
# Episode: 2337; Acc. Reward: 469.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.25e-01, 2.73e-01)
# K_MRAC= [ 10.91634153 -19.67514096  19.91394969   8.44249861]
# Epoch: 33
# Episode: 2345; Acc. Reward: 471.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.25e-01, 2.72e-01)
# K_MRAC= [ 13.49909358 -19.47373967  19.97521681   7.42804473]
# Epoch: 34
# Episode: 2351; Acc. Reward: 470.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.25e-01, 2.72e-01)
# K_MRAC= [ 12.61344378 -19.61904311  20.           7.14457352]
# Episode: 2354; Acc. Reward: 462.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.24e-01, 2.71e-01)
# K_MRAC= [ 12.98426023 -20.          19.96436892   7.66158571]
# Epoch: 35
# Episode: 2362; Acc. Reward: 463.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.24e-01, 2.70e-01)
# K_MRAC= [ 12.52792563 -19.92568161  19.8745586    8.36814376]
# Epoch: 36
# Episode: 2370; Acc. Reward: 464.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.23e-01, 2.69e-01)
# K_MRAC= [ 10.07363433 -19.92896743  19.89205657   9.34442665]
# Epoch: 37
# Episode: 2378; Acc. Reward: 465.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.22e-01, 2.69e-01)
# K_MRAC= [ 12.71015037 -19.3917048   19.99270299   8.9723986 ]
# Epoch: 38
# Episode: 2386; Acc. Reward: 466.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.21e-01, 2.68e-01)
# K_MRAC= [ 12.39895214 -20.          19.96697509   6.92270472]
# Epoch: 39
# Episode: 2394; Acc. Reward: 479.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.20e-01, 2.67e-01)
# K_MRAC= [ 11.10977135 -19.49219795  19.95984622   9.56609578]
# Epoch: 40
# Episode: 2401; Acc. Reward: 472.0; Pole fell: True
# Avg Action Abs Error (e_ry, e_yym) is (5.18e-01, 2.66e-01)
# K_MRAC= [ 12.16765103 -19.40614219  20.           8.24380994]
# Episode: 2403; Acc. Reward: 468.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.17e-01, 2.65e-01)
# K_MRAC= [  9.12303619 -19.77504999  19.6863112   10.64109014]
# Epoch: 41
# Episode: 2411; Acc. Reward: 468.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.16e-01, 2.64e-01)
# K_MRAC= [ 10.76045657 -19.4437107   19.82976067  10.01324089]
# Epoch: 42
# Episode: 2419; Acc. Reward: 468.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.14e-01, 2.63e-01)
# K_MRAC= [  9.47600017 -19.86686422  19.77740806   8.45965522]
# Epoch: 43
# Episode: 2427; Acc. Reward: 468.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.12e-01, 2.62e-01)
# K_MRAC= [  8.50042671 -18.23045274  19.27913914  10.54368931]
# Epoch: 44
# Episode: 2435; Acc. Reward: 468.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.10e-01, 2.61e-01)
# K_MRAC= [  9.69240108 -17.05328234  19.28209993   8.65117129]
# Epoch: 45
# Episode: 2443; Acc. Reward: 481.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.08e-01, 2.59e-01)
# K_MRAC= [  9.0880871  -17.39631284  19.22984323  10.23519917]
# Epoch: 46
# Episode: 2451; Acc. Reward: 482.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.06e-01, 2.58e-01)
# K_MRAC= [ 10.22941793 -18.65766103  19.71037904  10.72618174]
# Epoch: 47
# Episode: 2459; Acc. Reward: 484.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.04e-01, 2.57e-01)
# K_MRAC= [  9.42706539 -19.72101015  19.73113646  10.80225909]
# Epoch: 48
# Episode: 2467; Acc. Reward: 485.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.03e-01, 2.56e-01)
# K_MRAC= [  9.25064284 -18.12549509  19.37674894  12.12810447]
# Epoch: 49
# Episode: 2475; Acc. Reward: 485.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (5.01e-01, 2.55e-01)
# K_MRAC= [ 11.14977605 -18.30047875  19.79157231  10.92895307]
# Epoch: 50
# Episode: 2483; Acc. Reward: 486.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (4.99e-01, 2.54e-01)
# K_MRAC= [  9.13615169 -17.75726784  19.28020526  12.32796339]
# Epoch: 51
# Episode: 2491; Acc. Reward: 485.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (4.97e-01, 2.52e-01)
# K_MRAC= [  8.86866957 -17.96932106  19.26911948  12.35057264]
# Epoch: 52
# Episode: 2499; Acc. Reward: 485.0; Pole fell: False
# Avg Action Abs Error (e_ry, e_yym) is (4.94e-01, 2.51e-01)
# K_MRAC= [  8.78079775 -17.71219411  19.20011972  12.3387211 ]
# Epoch: 53

# %%
path = '/content/drive/MyDrive/Colab Notebooks/codes/MRAC/train_vs_test/save_data/Cartpole_PPO/'

# %%
actor.save(path+"cartple_actor.keras")
critic.save(path+"cartple_critic.keras")

# %%
# Save acc reward data
variables_to_save = {
    'avg_reward_list': avg_reward_list,
    'acc_ep_reward_list': acc_ep_reward_list
    }

# %%
with open(path+'Cartpole_acc_reward_data.pkl', 'wb') as f:
    pickle.dump(variables_to_save, f)
print(f"All variables saved to {path+'Cartpole_acc_reward_data.pkl'}")
# Out:
# All variables saved to /content/drive/MyDrive/Colab Notebooks/codes/MRAC/train_vs_test/save_data/Cartpole_PPO/Cartpole_acc_reward_data.pkl

# %%
# load policies models
actor = keras.models.load_model(path+"cartple_actor.keras")
critic = keras.models.load_model(path+"cartple_critic.keras")

# %%
# Load acc reward data
with open(path+'Cartpole_acc_reward_data.pkl', 'rb') as f:
    loaded_variables = pickle.load(f)
avg_reward_list = loaded_variables['avg_reward_list']
acc_ep_reward_list = loaded_variables['acc_ep_reward_list']

# %%
low_bound_reward_list = 0
up_bound_reward_list= 500
print("low_bound_reward_list=",low_bound_reward_list)
print("up_bound_reward_list=",up_bound_reward_list)
# Out:
# low_bound_reward_list= 0
# up_bound_reward_list= 500

# %%
def unnorm_to_norm(x):
  y = (x-low_bound_reward_list)/(up_bound_reward_list-low_bound_reward_list)
  return y

# %%
def norm_to_unnorm(y):
  x=y*(up_bound_reward_list-low_bound_reward_list)+low_bound_reward_list
  return x

# %%
norm_reward_list = np.array(avg_reward_list)
#norm_reward_list = (norm_reward_list-min_norm_reward_list)/(max_norm_reward_list-min_norm_reward_list)
norm_reward_list = unnorm_to_norm(norm_reward_list)

# %%
# Plotting graph
# Episodes versus Acc. Rewards
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(avg_reward_list, label = "Acc. Episodic Reward",color="C0",linewidth = 1.5)
plt.axhline(y=np.array(avg_reward_list)[-20:-1].mean(), linestyle='--',
            label = "Acc. Epsiodic Reward's\nlast 20 mean= "+f"{np.array(avg_reward_list)[-20:-1].mean():.1f}",color="C1",linewidth = 2.5)
plt.minorticks_on()
plt.xlabel("Training episodes")
plt.ylabel("Acc. Episodic Reward")
#plt.grid()
plt.legend(fontsize=14)
plt.show()

# %%
# Episodes versus Avg. Rewards

font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.5)
f.set_figheight(2.2)
plt.plot(norm_reward_list, label = "Normalized Acc. Epi. Reward",color="C0",linewidth = 1.5)
#plt.axhline(y=norm_reward_list[-20:-1].mean(), linestyle='--',
#            label = "Normalized Acc. Episodic Reward's last 20 mean= "+f"{norm_reward_list[-20:-1].mean():.1f}",color="C1",linewidth = 2.5)
plt.xlabel("Training Episode")
plt.ylabel("Normalized Acc. Epi. Reward")
#plt.grid()
#plt.legend()
#plt.xticks(np.arange(0, 2501, 500))
#plt.yticks(np.arange(0.0, 1.1, 0.1))
plt.minorticks_on()
#plt.savefig(path+"Cartpole_Acc_Reward_vs_Episode.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
state = 0
action = 0
next_state = 0
next_action = 0

# %%
print("Avg. Epsiodic Reward's last 5 epoch mean=")
print(np.array(avg_reward_list)[-5:].mean())
# Out:
# Avg. Epsiodic Reward's last 5 epoch mean=
# 485.2

# %% [markdown]
# **Test Ideal Env**

# %%
observation = env.reset()
total_episodes_test = 100
best_score = -1000
#train_mode = False
## for traingng of ideal: action_actual=action_desired_RL
env.ideal_env = True

## for training of feed fwd: u_ctrl=k*action_desired_RL
#env.ideal_env = False
#env.DCMotorModel.Kp = 0.0
#env.DCMotorModel.Ki = 0.0
#env.DCMotorModel.Kd = 0.0
#env.DCMotorModel.Kr = 1.0
#env.DCMotorModel.Kw = 0.0

## for training with desined PID ctrl:
#env.ideal_env = False
#env.DCMotorModel.Kp = 4.3
#env.DCMotorModel.Ki = 1.0
#env.DCMotorModel.Kd = 10**(-6)
#env.DCMotorModel.Kr = 0.7
#env.DCMotorModel.Kw = 1.0

# %%
# To store reward history of each episode
ep_reward_list_test = []
# To store average reward history of last few episodes
avg_reward_list_test = []

ep_abs_error_action_list_test = []
avg_ep_abs_error_action_list_test = []

save_observation = []
save_wanted_torque = []
save_actual_torque = []

num_success = 0
print('Test')
for ep in range(total_episodes_test):
    observation = env.reset()
    save_observation_temp = [observation]
    save_wanted_torque_temp = [0.0]
    save_actual_torque_temp = [0.0]
    save_model_torque_temp = [0.0]
    save_MRAC_adapt_gains_temp= [env.MRAC.k_hat]
    save_ctrl_voltage_temp = [0.0]
    done=False
    t=0
    episodic_reward = 0
    while not done and t<steps_per_episode_goal:
        # using our observation, choose an action and take it in the environment
        # Get the logits, action, and take one step in the environment
        k_hat_print = env.MRAC.k_hat.round(2)
        observation = observation.reshape(1, -1)
        logits, action = sample_action(observation)
        #observation_new, reward, done, _, _ = env.step(action[0].numpy())
        observation_new, reward, done, _ ,torque_wanted, torque_actual= env.step(action[0].numpy().item())
        episodic_reward += reward
        observation = observation_new
        save_observation_temp.append(observation)
        save_wanted_torque_temp.append(torque_wanted)
        save_actual_torque_temp.append(torque_actual)
        save_model_torque_temp.append(env.MRAC.y_m)
        save_MRAC_adapt_gains_temp.append(env.MRAC.k_hat)
        save_ctrl_voltage_temp.append(env.MRAC.u)
        t+=1

    # get best score and update save data
    #save_ctrl_voltage_temp.append(env.DCMotorModel.voltage_input)
    print(f"Episode: {ep}; Acc. Reward: {episodic_reward:.1f}; Pole fell: {done}")
    print(f"Episode: {ep}; "," adapt. coeffs at final time step: ", k_hat_print)
    if best_score<episodic_reward:
        save_observation = list(save_observation_temp)
        save_wanted_torque = list(save_wanted_torque_temp)
        save_actual_torque = list(save_actual_torque_temp)
        save_model_torque = list(save_model_torque_temp)
        save_ctrl_voltage = list(save_ctrl_voltage_temp)
        save_MRAC_adapt_gains = list(save_MRAC_adapt_gains_temp)
        best_score = episodic_reward
    ep_reward_list_test.append(episodic_reward)
    num_success+= 0 + (not done)
# Out:
# Test
# Episode: 0; Acc. Reward: 484.1; Pole fell: False
# Episode: 0;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 1; Acc. Reward: 479.9; Pole fell: False
# Episode: 1;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 2; Acc. Reward: 481.4; Pole fell: False
# Episode: 2;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 3; Acc. Reward: 482.1; Pole fell: False
# Episode: 3;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 4; Acc. Reward: 478.9; Pole fell: False
# Episode: 4;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 5; Acc. Reward: 486.6; Pole fell: False
# Episode: 5;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 6; Acc. Reward: 484.0; Pole fell: False
# Episode: 6;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 7; Acc. Reward: 482.0; Pole fell: False
# Episode: 7;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 8; Acc. Reward: 482.1; Pole fell: False
# Episode: 8;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 9; Acc. Reward: 483.2; Pole fell: False
# Episode: 9;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 10; Acc. Reward: 488.1; Pole fell: False
# Episode: 10;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 11; Acc. Reward: 487.2; Pole fell: False
# Episode: 11;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 12; Acc. Reward: 483.7; Pole fell: False
# Episode: 12;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 13; Acc. Reward: 485.3; Pole fell: False
# Episode: 13;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 14; Acc. Reward: 480.0; Pole fell: False
# Episode: 14;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 15; Acc. Reward: 482.6; Pole fell: False
# Episode: 15;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 16; Acc. Reward: 480.7; Pole fell: False
# Episode: 16;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 17; Acc. Reward: 477.4; Pole fell: False
# Episode: 17;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 18; Acc. Reward: 482.8; Pole fell: False
# Episode: 18;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 19; Acc. Reward: 481.6; Pole fell: False
# Episode: 19;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 20; Acc. Reward: 482.7; Pole fell: False
# Episode: 20;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 21; Acc. Reward: 486.7; Pole fell: False
# Episode: 21;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 22; Acc. Reward: 487.4; Pole fell: False
# Episode: 22;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 23; Acc. Reward: 474.6; Pole fell: False
# Episode: 23;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 24; Acc. Reward: 484.5; Pole fell: False
# Episode: 24;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 25; Acc. Reward: 474.8; Pole fell: False
# Episode: 25;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 26; Acc. Reward: 486.4; Pole fell: False
# Episode: 26;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 27; Acc. Reward: 486.8; Pole fell: False
# Episode: 27;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 28; Acc. Reward: 479.7; Pole fell: False
# Episode: 28;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 29; Acc. Reward: 475.2; Pole fell: False
# Episode: 29;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 30; Acc. Reward: 482.4; Pole fell: False
# Episode: 30;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 31; Acc. Reward: 477.9; Pole fell: False
# Episode: 31;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 32; Acc. Reward: 482.4; Pole fell: False
# Episode: 32;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 33; Acc. Reward: 487.1; Pole fell: False
# Episode: 33;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 34; Acc. Reward: 488.6; Pole fell: False
# Episode: 34;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 35; Acc. Reward: 482.5; Pole fell: False
# Episode: 35;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 36; Acc. Reward: 481.9; Pole fell: False
# Episode: 36;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 37; Acc. Reward: 478.9; Pole fell: False
# Episode: 37;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 38; Acc. Reward: 483.0; Pole fell: False
# Episode: 38;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 39; Acc. Reward: 481.0; Pole fell: False
# Episode: 39;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 40; Acc. Reward: 483.1; Pole fell: False
# Episode: 40;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 41; Acc. Reward: 484.0; Pole fell: False
# Episode: 41;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 42; Acc. Reward: 487.9; Pole fell: False
# Episode: 42;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 43; Acc. Reward: 479.2; Pole fell: False
# Episode: 43;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 44; Acc. Reward: 473.1; Pole fell: False
# Episode: 44;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 45; Acc. Reward: 484.0; Pole fell: False
# Episode: 45;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 46; Acc. Reward: 479.9; Pole fell: False
# Episode: 46;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 47; Acc. Reward: 486.4; Pole fell: False
# Episode: 47;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 48; Acc. Reward: 481.5; Pole fell: False
# Episode: 48;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 49; Acc. Reward: 478.2; Pole fell: False
# Episode: 49;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 50; Acc. Reward: 482.5; Pole fell: False
# Episode: 50;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 51; Acc. Reward: 484.9; Pole fell: False
# Episode: 51;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 52; Acc. Reward: 474.3; Pole fell: False
# Episode: 52;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 53; Acc. Reward: 478.6; Pole fell: False
# Episode: 53;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 54; Acc. Reward: 477.7; Pole fell: False
# Episode: 54;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 55; Acc. Reward: 486.0; Pole fell: False
# Episode: 55;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 56; Acc. Reward: 480.8; Pole fell: False
# Episode: 56;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 57; Acc. Reward: 479.4; Pole fell: False
# Episode: 57;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 58; Acc. Reward: 486.9; Pole fell: False
# Episode: 58;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 59; Acc. Reward: 489.9; Pole fell: False
# Episode: 59;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 60; Acc. Reward: 477.7; Pole fell: False
# Episode: 60;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 61; Acc. Reward: 491.7; Pole fell: False
# Episode: 61;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 62; Acc. Reward: 478.6; Pole fell: False
# Episode: 62;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 63; Acc. Reward: 482.5; Pole fell: False
# Episode: 63;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 64; Acc. Reward: 482.7; Pole fell: False
# Episode: 64;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 65; Acc. Reward: 486.7; Pole fell: False
# Episode: 65;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 66; Acc. Reward: 485.2; Pole fell: False
# Episode: 66;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 67; Acc. Reward: 476.2; Pole fell: False
# Episode: 67;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 68; Acc. Reward: 489.8; Pole fell: False
# Episode: 68;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 69; Acc. Reward: 476.0; Pole fell: False
# Episode: 69;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 70; Acc. Reward: 480.2; Pole fell: False
# Episode: 70;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 71; Acc. Reward: 486.0; Pole fell: False
# Episode: 71;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 72; Acc. Reward: 486.0; Pole fell: False
# Episode: 72;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 73; Acc. Reward: 490.4; Pole fell: False
# Episode: 73;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 74; Acc. Reward: 471.5; Pole fell: False
# Episode: 74;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 75; Acc. Reward: 482.8; Pole fell: False
# Episode: 75;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 76; Acc. Reward: 486.5; Pole fell: False
# Episode: 76;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 77; Acc. Reward: 476.0; Pole fell: False
# Episode: 77;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 78; Acc. Reward: 478.4; Pole fell: False
# Episode: 78;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 79; Acc. Reward: 483.2; Pole fell: False
# Episode: 79;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 80; Acc. Reward: 490.0; Pole fell: False
# Episode: 80;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 81; Acc. Reward: 479.2; Pole fell: False
# Episode: 81;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 82; Acc. Reward: 486.8; Pole fell: False
# Episode: 82;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 83; Acc. Reward: 485.6; Pole fell: False
# Episode: 83;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 84; Acc. Reward: 487.2; Pole fell: False
# Episode: 84;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 85; Acc. Reward: 480.6; Pole fell: False
# Episode: 85;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 86; Acc. Reward: 478.8; Pole fell: False
# Episode: 86;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 87; Acc. Reward: 480.3; Pole fell: False
# Episode: 87;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 88; Acc. Reward: 481.6; Pole fell: False
# Episode: 88;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 89; Acc. Reward: 477.5; Pole fell: False
# Episode: 89;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 90; Acc. Reward: 474.9; Pole fell: False
# Episode: 90;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 91; Acc. Reward: 480.5; Pole fell: False
# Episode: 91;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 92; Acc. Reward: 479.1; Pole fell: False
# Episode: 92;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 93; Acc. Reward: 486.4; Pole fell: False
# Episode: 93;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 94; Acc. Reward: 487.5; Pole fell: False
# Episode: 94;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 95; Acc. Reward: 481.4; Pole fell: False
# Episode: 95;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 96; Acc. Reward: 483.3; Pole fell: False
# Episode: 96;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 97; Acc. Reward: 477.4; Pole fell: False
# Episode: 97;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 98; Acc. Reward: 485.0; Pole fell: False
# Episode: 98;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]
# Episode: 99; Acc. Reward: 473.3; Pole fell: False
# Episode: 99;   adapt. coeffs at final time step:  [ 10.   -17.29  19.36  11.72]

# %%
score = num_success/total_episodes_test*100
print(f"score=({num_success} successes)/({total_episodes_test} episodes)*100={score:.1f}")
# Out:
# score=(100 successes)/(100 episodes)*100=100.0

# %%
print("Acc. Episodic Reward's mean=")
print(np.array(ep_reward_list_test).mean())
print(f"Normalized mean= {unnorm_to_norm(np.array(ep_reward_list_test).mean()):.3e}")
print(f"Normalized std = {unnorm_to_norm(np.array(ep_reward_list_test).std()):.3e}")
# Out:
# Acc. Episodic Reward's mean=
# 482.20630189039167
# Normalized mean= 9.644e-01
# Normalized std = 8.595e-03

# %%
# Plotting graph
# Episodes versus Avg. Rewards
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(ep_reward_list_test, label = "Acc. Epsiodic Reward",color="C0",linewidth = 1.5)
plt.axhline(y=np.array(ep_reward_list_test).mean(), linestyle='--',
            label = "Acc. Epsiodic Reward's mean= "+f"{np.array(ep_reward_list_test).mean():.1f}",color="C1",linewidth = 2.5)
plt.xlabel("Episode")
plt.ylabel("Acc. Epsiodic Reward")
plt.grid()
plt.legend()
plt.show()

# %%
dt=env.dt
time_= np.linspace(start = 0, stop = len(save_wanted_torque)* dt,
                   num=len(save_wanted_torque) )

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)

plt.step(time_, save_wanted_torque ,label = "desired_torque",color="blue",linewidth = 1.5)
plt.xlabel("time [sec]")
plt.ylabel("Torque [Nm]")
if not env.ideal_env:
  plt.step(time_, save_actual_torque , ':',label = "actual_torque",color="red",linewidth = 4)
  mae_torque_error = np.array(save_wanted_torque)-np.array(save_actual_torque)
  mae_torque_error = np.abs(mae_torque_error).mean()
  plt.axhline(y=mae_torque_error, linestyle='--',
            label = "MAE_torque_error= "+f"{mae_torque_error:.2e}",color="C1",linewidth = 2.5)
  plt.legend()
plt.grid()
plt.show()

# %%
if not env.ideal_env:
  e_ry=np.array(save_wanted_torque)-np.array(save_actual_torque)
  e_yy_m=np.array(save_actual_torque)-np.array(save_model_torque)
  print(f"e_ry: (mean, std, mae) = ({e_ry.mean():.2e}, {e_ry.std():.2e}, {np.abs(e_ry).mean():.2e})")
  print(f"e_yy_m: (mean, std, mae) = ({e_yy_m.mean():.2e}, {e_yy_m.std():.2e}, {np.abs(e_yy_m).mean():.2e})")

# %%
# distribution to 4 observation parameters

position = []
velocity = []
angle = []
angular_velocity = []
for observ in save_observation:
  for index,value in enumerate(observ):
    if index == 0:
      position.append(value)
    if index == 1:
      velocity.append(value)
    if index == 2:
      angle.append(value)
    if index == 3:
      angular_velocity.append(value)

# %%
print(len(position))
# Out:
# 501

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_position = np.linspace(start = 0, stop = len(position)* dt,num=len(position))##############################################
#time_position , position
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_position[-1] , 300)

spl = make_interp_spline(time_position, position, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Position [m]')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_velocity = np.linspace(start = 0, stop = len(velocity)* dt,num=len(velocity))
#time_velocity , velocity
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_velocity[-1] , 300)

spl = make_interp_spline(time_velocity, velocity, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Velocity [m]')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_angle = np.linspace(start = 0, stop = len(angle)* dt,num=len(angle))
#time_angle , angle
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_angle[-1] , 300)

spl = make_interp_spline(time_angle,angle, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Angle [rad]')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_angular_velocity = np.linspace(start = 0, stop = len(angular_velocity)* dt,num=len(angular_velocity))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_angular_velocity[-1] , 300)

spl = make_interp_spline(time_angular_velocity, angular_velocity, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Angular Velocity [rad/sec]')
plt.show()

# %% [markdown]
# **Test Actual Env Ctrl**

# %%
env = CartPole()
observation = env.reset()
total_episodes_test = 100
best_score = -1000
#train_mode = False
## for traingng of ideal: action_actual=action_desired_RL
#env.ideal_env = True


## for training with desined MPC ctrl:
env.ideal_env = False

# %%
# To store reward history of each episode
ep_reward_list_test = []
# To store average reward history of last few episodes
avg_reward_list_test = []

ep_abs_error_action_list_test = []
avg_ep_abs_error_action_list_test = []

save_observation = []
save_wanted_torque = []
save_actual_torque = []

num_success = 0
print('Test')
for ep in range(total_episodes_test):
    observation = env.reset()
    save_observation_temp = [observation]
    save_wanted_torque_temp = [0.0]
    save_actual_torque_temp = [0.0]
    save_model_torque_temp = [0.0]
    save_MRAC_adapt_gains_temp= [env.MRAC.k_hat]
    save_ctrl_voltage_temp = [0.0]
    done=False
    t=0
    episodic_reward = 0
    while not done and t<steps_per_episode_goal:
        # using our observation, choose an action and take it in the environment
        # Get the logits, action, and take one step in the environment
        k_hat_print = env.MRAC.k_hat.round(2)
        observation = observation.reshape(1, -1)
        logits, action = sample_action(observation)
        #observation_new, reward, done, _, _ = env.step(action[0].numpy())
        observation_new, reward, done, _ ,torque_wanted, torque_actual= env.step(action[0].numpy().item())
        episodic_reward += reward
        observation = observation_new
        save_observation_temp.append(observation)
        save_wanted_torque_temp.append(torque_wanted)
        save_actual_torque_temp.append(torque_actual)
        save_model_torque_temp.append(env.MRAC.y_m)
        save_MRAC_adapt_gains_temp.append(env.MRAC.k_hat)
        save_ctrl_voltage_temp.append(env.MRAC.u)
        t+=1

    # get best score and update save data
    #save_ctrl_voltage_temp.append(env.DCMotorModel.voltage_input)
    print(f"Episode: {ep}; Acc. Reward: {episodic_reward:.1f}; Pole fell: {done}")
    print(f"Episode: {ep}; "," adapt. coeffs at final time step: ", k_hat_print)
    if best_score<episodic_reward:
        save_observation = list(save_observation_temp)
        save_wanted_torque = list(save_wanted_torque_temp)
        save_actual_torque = list(save_actual_torque_temp)
        save_model_torque = list(save_model_torque_temp)
        save_ctrl_voltage = list(save_ctrl_voltage_temp)
        save_MRAC_adapt_gains = list(save_MRAC_adapt_gains_temp)
        best_score = episodic_reward
    ep_reward_list_test.append(episodic_reward)
    num_success+= 0 + (not done)
# Out:
# Test
# Episode: 0; Acc. Reward: 478.3; Pole fell: False
# Episode: 0;   adapt. coeffs at final time step:  [ 3.71 -2.77  1.3   0.72]
# Episode: 1; Acc. Reward: 482.2; Pole fell: False
# Episode: 1;   adapt. coeffs at final time step:  [ 3.81 -3.07  1.38  1.04]
# Episode: 2; Acc. Reward: 482.2; Pole fell: False
# Episode: 2;   adapt. coeffs at final time step:  [ 3.95 -3.11  1.41  1.07]
# Episode: 3; Acc. Reward: 477.2; Pole fell: False
# Episode: 3;   adapt. coeffs at final time step:  [ 4.16 -3.56  1.55  1.17]
# Episode: 4; Acc. Reward: 480.6; Pole fell: False
# Episode: 4;   adapt. coeffs at final time step:  [ 4.28 -3.36  1.53  1.34]
# Episode: 5; Acc. Reward: 485.3; Pole fell: False
# Episode: 5;   adapt. coeffs at final time step:  [ 4.23 -3.42  1.53  1.46]
# Episode: 6; Acc. Reward: 482.9; Pole fell: False
# Episode: 6;   adapt. coeffs at final time step:  [ 4.11 -3.68  1.56  1.32]
# Episode: 7; Acc. Reward: 474.8; Pole fell: False
# Episode: 7;   adapt. coeffs at final time step:  [ 4.77 -3.94  1.74  0.87]
# Episode: 8; Acc. Reward: 479.1; Pole fell: False
# Episode: 8;   adapt. coeffs at final time step:  [ 4.48 -3.9   1.68  1.52]
# Episode: 9; Acc. Reward: 480.0; Pole fell: False
# Episode: 9;   adapt. coeffs at final time step:  [ 4.5  -3.92  1.68  1.73]
# Episode: 10; Acc. Reward: 476.8; Pole fell: False
# Episode: 10;   adapt. coeffs at final time step:  [ 4.37 -3.77  1.63  1.88]
# Episode: 11; Acc. Reward: 474.7; Pole fell: False
# Episode: 11;   adapt. coeffs at final time step:  [ 4.28 -4.2   1.7   1.75]
# Episode: 12; Acc. Reward: 481.7; Pole fell: False
# Episode: 12;   adapt. coeffs at final time step:  [ 4.48 -3.87  1.67  1.73]
# Episode: 13; Acc. Reward: 481.6; Pole fell: False
# Episode: 13;   adapt. coeffs at final time step:  [ 4.33 -3.98  1.66  1.49]
# Episode: 14; Acc. Reward: 478.4; Pole fell: False
# Episode: 14;   adapt. coeffs at final time step:  [ 4.32 -3.94  1.65  1.46]
# Episode: 15; Acc. Reward: 482.0; Pole fell: False
# Episode: 15;   adapt. coeffs at final time step:  [ 4.37 -3.98  1.67  1.46]
# Episode: 16; Acc. Reward: 483.8; Pole fell: False
# Episode: 16;   adapt. coeffs at final time step:  [ 4.45 -3.67  1.63  1.49]
# Episode: 17; Acc. Reward: 475.8; Pole fell: False
# Episode: 17;   adapt. coeffs at final time step:  [ 4.35 -3.59  1.59  1.44]
# Episode: 18; Acc. Reward: 479.8; Pole fell: False
# Episode: 18;   adapt. coeffs at final time step:  [ 4.39 -3.59  1.6   1.55]
# Episode: 19; Acc. Reward: 484.9; Pole fell: False
# Episode: 19;   adapt. coeffs at final time step:  [ 4.38 -3.67  1.61  1.55]
# Episode: 20; Acc. Reward: 473.5; Pole fell: False
# Episode: 20;   adapt. coeffs at final time step:  [ 4.27 -3.59  1.57  1.59]
# Episode: 21; Acc. Reward: 475.5; Pole fell: False
# Episode: 21;   adapt. coeffs at final time step:  [ 4.41 -3.52  1.59  1.54]
# Episode: 22; Acc. Reward: 486.2; Pole fell: False
# Episode: 22;   adapt. coeffs at final time step:  [ 4.34 -3.77  1.62  1.62]
# Episode: 23; Acc. Reward: 473.9; Pole fell: False
# Episode: 23;   adapt. coeffs at final time step:  [ 4.4  -3.7   1.62  1.56]
# Episode: 24; Acc. Reward: 482.1; Pole fell: False
# Episode: 24;   adapt. coeffs at final time step:  [ 4.41 -3.66  1.61  1.47]
# Episode: 25; Acc. Reward: 481.5; Pole fell: False
# Episode: 25;   adapt. coeffs at final time step:  [ 4.4  -3.63  1.6   1.62]
# Episode: 26; Acc. Reward: 473.9; Pole fell: False
# Episode: 26;   adapt. coeffs at final time step:  [ 4.37 -3.75  1.63  1.61]
# Episode: 27; Acc. Reward: 478.4; Pole fell: False
# Episode: 27;   adapt. coeffs at final time step:  [ 4.43 -3.7   1.63  1.44]
# Episode: 28; Acc. Reward: 482.7; Pole fell: False
# Episode: 28;   adapt. coeffs at final time step:  [ 4.51 -3.56  1.61  1.48]
# Episode: 29; Acc. Reward: 478.3; Pole fell: False
# Episode: 29;   adapt. coeffs at final time step:  [ 4.26 -3.75  1.6   1.39]
# Episode: 30; Acc. Reward: 481.3; Pole fell: False
# Episode: 30;   adapt. coeffs at final time step:  [ 4.28 -3.53  1.56  1.51]
# Episode: 31; Acc. Reward: 482.9; Pole fell: False
# Episode: 31;   adapt. coeffs at final time step:  [ 4.32 -3.55  1.57  1.46]
# Episode: 32; Acc. Reward: 485.3; Pole fell: False
# Episode: 32;   adapt. coeffs at final time step:  [ 4.2  -3.54  1.55  1.54]
# Episode: 33; Acc. Reward: 485.4; Pole fell: False
# Episode: 33;   adapt. coeffs at final time step:  [ 4.23 -3.52  1.55  1.55]
# Episode: 34; Acc. Reward: 485.6; Pole fell: False
# Episode: 34;   adapt. coeffs at final time step:  [ 4.38 -3.81  1.64  1.5 ]
# Episode: 35; Acc. Reward: 478.9; Pole fell: False
# Episode: 35;   adapt. coeffs at final time step:  [ 4.42 -4.02  1.69  1.47]
# Episode: 36; Acc. Reward: 485.9; Pole fell: False
# Episode: 36;   adapt. coeffs at final time step:  [ 4.49 -3.95  1.69  1.61]
# Episode: 37; Acc. Reward: 482.2; Pole fell: False
# Episode: 37;   adapt. coeffs at final time step:  [ 4.55 -3.96  1.7   1.5 ]
# Episode: 38; Acc. Reward: 484.1; Pole fell: False
# Episode: 38;   adapt. coeffs at final time step:  [ 4.41 -3.82  1.65  1.85]
# Episode: 39; Acc. Reward: 487.1; Pole fell: False
# Episode: 39;   adapt. coeffs at final time step:  [ 4.57 -3.92  1.7   1.66]
# Episode: 40; Acc. Reward: 481.1; Pole fell: False
# Episode: 40;   adapt. coeffs at final time step:  [ 4.67 -4.17  1.77  1.77]
# Episode: 41; Acc. Reward: 482.0; Pole fell: False
# Episode: 41;   adapt. coeffs at final time step:  [ 4.6  -3.9   1.7   1.76]
# Episode: 42; Acc. Reward: 478.2; Pole fell: False
# Episode: 42;   adapt. coeffs at final time step:  [ 4.73 -3.92  1.73  1.59]
# Episode: 43; Acc. Reward: 470.0; Pole fell: False
# Episode: 43;   adapt. coeffs at final time step:  [ 4.39 -3.97  1.67  1.81]
# Episode: 44; Acc. Reward: 477.3; Pole fell: False
# Episode: 44;   adapt. coeffs at final time step:  [ 4.57 -3.67  1.65  1.75]
# Episode: 45; Acc. Reward: 483.9; Pole fell: False
# Episode: 45;   adapt. coeffs at final time step:  [ 4.39 -3.87  1.65  1.68]
# Episode: 46; Acc. Reward: 487.7; Pole fell: False
# Episode: 46;   adapt. coeffs at final time step:  [ 4.35 -4.04  1.68  1.7 ]
# Episode: 47; Acc. Reward: 477.3; Pole fell: False
# Episode: 47;   adapt. coeffs at final time step:  [ 4.49 -3.73  1.65  1.62]
# Episode: 48; Acc. Reward: 479.7; Pole fell: False
# Episode: 48;   adapt. coeffs at final time step:  [ 4.52 -3.71  1.65  1.64]
# Episode: 49; Acc. Reward: 487.5; Pole fell: False
# Episode: 49;   adapt. coeffs at final time step:  [ 4.97 -3.84  1.76  1.3 ]
# Episode: 50; Acc. Reward: 480.0; Pole fell: False
# Episode: 50;   adapt. coeffs at final time step:  [ 4.65 -3.97  1.72  1.82]
# Episode: 51; Acc. Reward: 474.6; Pole fell: False
# Episode: 51;   adapt. coeffs at final time step:  [ 4.45 -3.81  1.65  1.78]
# Episode: 52; Acc. Reward: 481.2; Pole fell: False
# Episode: 52;   adapt. coeffs at final time step:  [ 4.51 -3.97  1.7   1.62]
# Episode: 53; Acc. Reward: 481.5; Pole fell: False
# Episode: 53;   adapt. coeffs at final time step:  [ 4.36 -3.76  1.63  1.7 ]
# Episode: 54; Acc. Reward: 487.5; Pole fell: False
# Episode: 54;   adapt. coeffs at final time step:  [ 4.27 -3.72  1.6   1.78]
# Episode: 55; Acc. Reward: 483.6; Pole fell: False
# Episode: 55;   adapt. coeffs at final time step:  [ 4.42 -3.89  1.66  1.46]
# Episode: 56; Acc. Reward: 475.7; Pole fell: False
# Episode: 56;   adapt. coeffs at final time step:  [ 4.61 -3.67  1.66  1.45]
# Episode: 57; Acc. Reward: 490.2; Pole fell: False
# Episode: 57;   adapt. coeffs at final time step:  [ 4.62 -4.06  1.74  1.31]
# Episode: 58; Acc. Reward: 483.4; Pole fell: False
# Episode: 58;   adapt. coeffs at final time step:  [ 4.67 -3.87  1.71  1.45]
# Episode: 59; Acc. Reward: 486.7; Pole fell: False
# Episode: 59;   adapt. coeffs at final time step:  [ 4.46 -3.8   1.65  1.72]
# Episode: 60; Acc. Reward: 480.6; Pole fell: False
# Episode: 60;   adapt. coeffs at final time step:  [ 4.36 -4.03  1.68  1.67]
# Episode: 61; Acc. Reward: 483.1; Pole fell: False
# Episode: 61;   adapt. coeffs at final time step:  [ 4.42 -3.81  1.65  1.59]
# Episode: 62; Acc. Reward: 479.8; Pole fell: False
# Episode: 62;   adapt. coeffs at final time step:  [ 4.21 -3.94  1.63  1.66]
# Episode: 63; Acc. Reward: 482.6; Pole fell: False
# Episode: 63;   adapt. coeffs at final time step:  [ 4.47 -4.11  1.72  1.34]
# Episode: 64; Acc. Reward: 486.2; Pole fell: False
# Episode: 64;   adapt. coeffs at final time step:  [ 4.48 -3.94  1.68  1.72]
# Episode: 65; Acc. Reward: 481.3; Pole fell: False
# Episode: 65;   adapt. coeffs at final time step:  [ 4.61 -3.87  1.7   1.52]
# Episode: 66; Acc. Reward: 483.5; Pole fell: False
# Episode: 66;   adapt. coeffs at final time step:  [ 4.42 -3.86  1.66  1.83]
# Episode: 67; Acc. Reward: 475.7; Pole fell: False
# Episode: 67;   adapt. coeffs at final time step:  [ 4.57 -4.08  1.73  1.35]
# Episode: 68; Acc. Reward: 483.3; Pole fell: False
# Episode: 68;   adapt. coeffs at final time step:  [ 4.4  -3.78  1.64  1.86]
# Episode: 69; Acc. Reward: 482.9; Pole fell: False
# Episode: 69;   adapt. coeffs at final time step:  [ 4.63 -4.1   1.75  1.55]
# Episode: 70; Acc. Reward: 485.9; Pole fell: False
# Episode: 70;   adapt. coeffs at final time step:  [ 4.84 -4.13  1.79  1.54]
# Episode: 71; Acc. Reward: 484.5; Pole fell: False
# Episode: 71;   adapt. coeffs at final time step:  [ 4.38 -4.05  1.69  1.77]
# Episode: 72; Acc. Reward: 480.6; Pole fell: False
# Episode: 72;   adapt. coeffs at final time step:  [ 4.37 -3.9   1.65  1.83]
# Episode: 73; Acc. Reward: 486.8; Pole fell: False
# Episode: 73;   adapt. coeffs at final time step:  [ 4.6  -3.72  1.67  1.73]
# Episode: 74; Acc. Reward: 487.5; Pole fell: False
# Episode: 74;   adapt. coeffs at final time step:  [ 4.55 -4.13  1.74  1.43]
# Episode: 75; Acc. Reward: 477.8; Pole fell: False
# Episode: 75;   adapt. coeffs at final time step:  [ 4.6  -3.64  1.65  1.47]
# Episode: 76; Acc. Reward: 466.9; Pole fell: False
# Episode: 76;   adapt. coeffs at final time step:  [ 4.41 -3.65  1.61  1.63]
# Episode: 77; Acc. Reward: 472.2; Pole fell: False
# Episode: 77;   adapt. coeffs at final time step:  [ 4.47 -4.12  1.72  1.73]
# Episode: 78; Acc. Reward: 480.0; Pole fell: False
# Episode: 78;   adapt. coeffs at final time step:  [ 4.94 -3.82  1.75  1.54]
# Episode: 79; Acc. Reward: 481.8; Pole fell: False
# Episode: 79;   adapt. coeffs at final time step:  [ 4.43 -3.95  1.68  1.72]
# Episode: 80; Acc. Reward: 487.3; Pole fell: False
# Episode: 80;   adapt. coeffs at final time step:  [ 4.43 -3.96  1.68  1.82]
# Episode: 81; Acc. Reward: 486.2; Pole fell: False
# Episode: 81;   adapt. coeffs at final time step:  [ 4.26 -3.79  1.61  1.81]
# Episode: 82; Acc. Reward: 484.2; Pole fell: False
# Episode: 82;   adapt. coeffs at final time step:  [ 4.29 -3.73  1.6   1.63]
# Episode: 83; Acc. Reward: 481.8; Pole fell: False
# Episode: 83;   adapt. coeffs at final time step:  [ 4.38 -3.76  1.63  1.53]
# Episode: 84; Acc. Reward: 485.6; Pole fell: False
# Episode: 84;   adapt. coeffs at final time step:  [ 4.36 -3.68  1.61  1.55]
# Episode: 85; Acc. Reward: 483.4; Pole fell: False
# Episode: 85;   adapt. coeffs at final time step:  [ 4.49 -3.59  1.62  1.43]
# Episode: 86; Acc. Reward: 486.7; Pole fell: False
# Episode: 86;   adapt. coeffs at final time step:  [ 4.83 -3.87  1.74  1.57]
# Episode: 87; Acc. Reward: 482.7; Pole fell: False
# Episode: 87;   adapt. coeffs at final time step:  [ 4.54 -4.38  1.78  1.63]
# Episode: 88; Acc. Reward: 474.9; Pole fell: False
# Episode: 88;   adapt. coeffs at final time step:  [ 4.85 -4.36  1.84  1.7 ]
# Episode: 89; Acc. Reward: 488.2; Pole fell: False
# Episode: 89;   adapt. coeffs at final time step:  [ 4.66 -4.05  1.74  1.83]
# Episode: 90; Acc. Reward: 475.5; Pole fell: False
# Episode: 90;   adapt. coeffs at final time step:  [ 4.74 -4.06  1.76  1.92]
# Episode: 91; Acc. Reward: 484.9; Pole fell: False
# Episode: 91;   adapt. coeffs at final time step:  [ 4.56 -4.34  1.78  1.71]
# Episode: 92; Acc. Reward: 485.2; Pole fell: False
# Episode: 92;   adapt. coeffs at final time step:  [ 4.48 -4.07  1.71  1.88]
# Episode: 93; Acc. Reward: 480.7; Pole fell: False
# Episode: 93;   adapt. coeffs at final time step:  [ 4.52 -4.17  1.74  1.7 ]
# Episode: 94; Acc. Reward: 486.9; Pole fell: False
# Episode: 94;   adapt. coeffs at final time step:  [ 4.42 -3.91  1.67  1.82]
# Episode: 95; Acc. Reward: 485.0; Pole fell: False
# Episode: 95;   adapt. coeffs at final time step:  [ 4.62 -3.9   1.71  1.71]
# Episode: 96; Acc. Reward: 476.4; Pole fell: False
# Episode: 96;   adapt. coeffs at final time step:  [ 4.42 -3.81  1.65  1.6 ]
# Episode: 97; Acc. Reward: 483.8; Pole fell: False
# Episode: 97;   adapt. coeffs at final time step:  [ 4.78 -3.74  1.7   1.57]
# Episode: 98; Acc. Reward: 486.0; Pole fell: False
# Episode: 98;   adapt. coeffs at final time step:  [ 4.29 -3.97  1.65  1.92]
# Episode: 99; Acc. Reward: 472.7; Pole fell: False
# Episode: 99;   adapt. coeffs at final time step:  [ 4.3  -3.77  1.61  1.62]

# %%
score = num_success/total_episodes_test*100
print(f"score=({num_success} successes)/({total_episodes_test} episodes)*100={score:.1f}")
# Out:
# score=(100 successes)/(100 episodes)*100=100.0

# %%
print("Acc. Episodic Reward's mean=")
print(np.array(ep_reward_list_test).mean())
print(f"Normalized mean= {unnorm_to_norm(np.array(ep_reward_list_test).mean()):.3e}")
print(f"Normalized std = {unnorm_to_norm(np.array(ep_reward_list_test).std()):.3e}")
# Out:
# Acc. Episodic Reward's mean=
# 481.3727653430488
# Normalized mean= 9.627e-01
# Normalized std = 8.965e-03

# %%
# Plotting graph
# Episodes versus Avg. Rewards
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(ep_reward_list_test, label = "Acc. Epsiodic Reward",color="C0",linewidth = 1.5)
plt.axhline(y=np.array(ep_reward_list_test).mean(), linestyle='--',
            label = "Acc. Epsiodic Reward's mean= "+f"{np.array(ep_reward_list_test).mean():.1f}",color="C1",linewidth = 2.5)
plt.xlabel("Episode")
plt.ylabel("Acc. Epsiodic Reward")
plt.grid()
plt.legend()
plt.show()

# %%
dt=env.dt
time_= np.linspace(start = 0, stop = len(save_wanted_torque)* dt,
                   num=len(save_wanted_torque) )

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)

plt.step(time_, save_wanted_torque ,label = "desired_torque",color="blue",linewidth = 1.5)
plt.xlabel("time [sec]")
plt.ylabel("Torque [Nm]")
if not env.ideal_env:
  plt.step(time_, save_actual_torque , ':',label = "actual_torque",color="red",linewidth = 4)
  mae_torque_error = np.array(save_wanted_torque)-np.array(save_actual_torque)
  mae_torque_error = np.abs(mae_torque_error).mean()
  plt.axhline(y=mae_torque_error, linestyle='--',
            label = "MAE_torque_error= "+f"{mae_torque_error:.2e}",color="C1",linewidth = 2.5)
  plt.legend()
plt.grid()
plt.show()

# %%
if not env.ideal_env:
  e_ry=np.array(save_wanted_torque)-np.array(save_actual_torque)
  e_yy_m=np.array(save_actual_torque)-np.array(save_model_torque)
  print(f"e_ry: (mean, std, mae) = ({e_ry.mean():.2e}, {e_ry.std():.2e}, {np.abs(e_ry).mean():.2e})")
  print(f"e_yy_m: (mean, std, mae) = ({e_yy_m.mean():.2e}, {e_yy_m.std():.2e}, {np.abs(e_yy_m).mean():.2e})")
# Out:
# e_ry: (mean, std, mae) = (1.38e-03, 6.62e-01, 5.20e-01)
# e_yy_m: (mean, std, mae) = (-7.36e-04, 9.90e-02, 7.27e-02)

# %%
# distribution to 4 observation parameters

position = []
velocity = []
angle = []
angular_velocity = []
for observ in save_observation:
  for index,value in enumerate(observ):
    if index == 0:
      position.append(value)
    if index == 1:
      velocity.append(value)
    if index == 2:
      angle.append(value)
    if index == 3:
      angular_velocity.append(value)

# %%
print(len(position))
# Out:
# 501

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_position = np.linspace(start = 0, stop = len(position)* dt,num=len(position))##############################################
#time_position , position
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_position[-1] , 300)

spl = make_interp_spline(time_position, position, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Position [m]')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_velocity = np.linspace(start = 0, stop = len(velocity)* dt,num=len(velocity))
#time_velocity , velocity
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_velocity[-1] , 300)

spl = make_interp_spline(time_velocity, velocity, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Velocity [m]')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_angle = np.linspace(start = 0, stop = len(angle)* dt,num=len(angle))
#time_angle , angle
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_angle[-1] , 300)

spl = make_interp_spline(time_angle,angle, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Angle [rad]')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_angular_velocity = np.linspace(start = 0, stop = len(angular_velocity)* dt,num=len(angular_velocity))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_angular_velocity[-1] , 300)

spl = make_interp_spline(time_angular_velocity, angular_velocity, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Angular Velocity [rad/sec]')
plt.show()

# %% [markdown]
# **Test Actual Env FF**

# %%
observation = env.reset()
total_episodes_test = 100
best_score = -1000
#train_mode = False
## for traingng of ideal: action_actual=action_desired_RL
#env.ideal_env = True

## for training of feed fwd: u_ctrl=k*action_desired_RL
env.ideal_env = False
env.MRAC.mrac_mod = False

# %%
# To store reward history of each episode
ep_reward_list_test = []
# To store average reward history of last few episodes
avg_reward_list_test = []

ep_abs_error_action_list_test = []
avg_ep_abs_error_action_list_test = []

save_observation = []
save_wanted_torque = []
save_actual_torque = []

num_success = 0
print('Test')
for ep in range(total_episodes_test):
    observation = env.reset()
    save_observation_temp = [observation]
    save_wanted_torque_temp = [0.0]
    save_actual_torque_temp = [0.0]
    save_model_torque_temp = [0.0]
    save_MRAC_adapt_gains_temp= [env.MRAC.k_hat]
    save_ctrl_voltage_temp = [0.0]
    done=False
    t=0
    episodic_reward = 0
    while not done and t<steps_per_episode_goal:
        # using our observation, choose an action and take it in the environment
        # Get the logits, action, and take one step in the environment
        k_hat_print = env.MRAC.k_hat.round(2)
        observation = observation.reshape(1, -1)
        logits, action = sample_action(observation)
        #observation_new, reward, done, _, _ = env.step(action[0].numpy())
        observation_new, reward, done, _ ,torque_wanted, torque_actual= env.step(action[0].numpy().item())
        episodic_reward += reward
        observation = observation_new
        save_observation_temp.append(observation)
        save_wanted_torque_temp.append(torque_wanted)
        save_actual_torque_temp.append(torque_actual)
        save_model_torque_temp.append(env.MRAC.y_m)
        save_MRAC_adapt_gains_temp.append(env.MRAC.k_hat)
        save_ctrl_voltage_temp.append(env.MRAC.u)
        t+=1

    # get best score and update save data
    #save_ctrl_voltage_temp.append(env.DCMotorModel.voltage_input)
    print(f"Episode: {ep}; Acc. Reward: {episodic_reward:.1f}; Pole fell: {done}")
    print(f"Episode: {ep}; "," adapt. coeffs at final time step: ", k_hat_print)
    if best_score<episodic_reward:
        save_observation = list(save_observation_temp)
        save_wanted_torque = list(save_wanted_torque_temp)
        save_actual_torque = list(save_actual_torque_temp)
        save_model_torque = list(save_model_torque_temp)
        save_ctrl_voltage = list(save_ctrl_voltage_temp)
        save_MRAC_adapt_gains = list(save_MRAC_adapt_gains_temp)
        best_score = episodic_reward
    ep_reward_list_test.append(episodic_reward)
    num_success+= 0 + (not done)
# Out:
# Test
# Episode: 0; Acc. Reward: 83.9; Pole fell: True
# Episode: 0;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 1; Acc. Reward: 132.2; Pole fell: True
# Episode: 1;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 2; Acc. Reward: 134.9; Pole fell: True
# Episode: 2;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 3; Acc. Reward: 167.0; Pole fell: True
# Episode: 3;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 4; Acc. Reward: 158.8; Pole fell: True
# Episode: 4;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 5; Acc. Reward: 212.8; Pole fell: True
# Episode: 5;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 6; Acc. Reward: 120.7; Pole fell: True
# Episode: 6;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 7; Acc. Reward: 118.6; Pole fell: True
# Episode: 7;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 8; Acc. Reward: 44.8; Pole fell: True
# Episode: 8;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 9; Acc. Reward: 89.8; Pole fell: True
# Episode: 9;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 10; Acc. Reward: 67.6; Pole fell: True
# Episode: 10;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 11; Acc. Reward: 133.2; Pole fell: True
# Episode: 11;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 12; Acc. Reward: 159.9; Pole fell: True
# Episode: 12;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 13; Acc. Reward: 152.8; Pole fell: True
# Episode: 13;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 14; Acc. Reward: 247.5; Pole fell: True
# Episode: 14;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 15; Acc. Reward: 103.0; Pole fell: True
# Episode: 15;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 16; Acc. Reward: 334.2; Pole fell: True
# Episode: 16;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 17; Acc. Reward: 95.2; Pole fell: True
# Episode: 17;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 18; Acc. Reward: 267.6; Pole fell: True
# Episode: 18;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 19; Acc. Reward: 90.7; Pole fell: True
# Episode: 19;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 20; Acc. Reward: 128.2; Pole fell: True
# Episode: 20;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 21; Acc. Reward: 262.4; Pole fell: True
# Episode: 21;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 22; Acc. Reward: 223.6; Pole fell: True
# Episode: 22;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 23; Acc. Reward: 86.8; Pole fell: True
# Episode: 23;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 24; Acc. Reward: 98.9; Pole fell: True
# Episode: 24;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 25; Acc. Reward: 208.9; Pole fell: True
# Episode: 25;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 26; Acc. Reward: 139.4; Pole fell: True
# Episode: 26;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 27; Acc. Reward: 299.2; Pole fell: True
# Episode: 27;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 28; Acc. Reward: 151.2; Pole fell: True
# Episode: 28;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 29; Acc. Reward: 102.5; Pole fell: True
# Episode: 29;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 30; Acc. Reward: 251.7; Pole fell: True
# Episode: 30;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 31; Acc. Reward: 203.3; Pole fell: True
# Episode: 31;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 32; Acc. Reward: 127.2; Pole fell: True
# Episode: 32;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 33; Acc. Reward: 245.9; Pole fell: True
# Episode: 33;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 34; Acc. Reward: 247.1; Pole fell: True
# Episode: 34;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 35; Acc. Reward: 230.1; Pole fell: True
# Episode: 35;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 36; Acc. Reward: 206.2; Pole fell: True
# Episode: 36;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 37; Acc. Reward: 190.9; Pole fell: True
# Episode: 37;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 38; Acc. Reward: 75.7; Pole fell: True
# Episode: 38;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 39; Acc. Reward: 151.1; Pole fell: True
# Episode: 39;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 40; Acc. Reward: 104.4; Pole fell: True
# Episode: 40;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 41; Acc. Reward: 81.7; Pole fell: True
# Episode: 41;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 42; Acc. Reward: 98.9; Pole fell: True
# Episode: 42;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 43; Acc. Reward: 162.0; Pole fell: True
# Episode: 43;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 44; Acc. Reward: 241.0; Pole fell: True
# Episode: 44;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 45; Acc. Reward: 144.9; Pole fell: True
# Episode: 45;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 46; Acc. Reward: 273.9; Pole fell: True
# Episode: 46;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 47; Acc. Reward: 179.7; Pole fell: True
# Episode: 47;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 48; Acc. Reward: 132.5; Pole fell: True
# Episode: 48;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 49; Acc. Reward: 171.5; Pole fell: True
# Episode: 49;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 50; Acc. Reward: 149.9; Pole fell: True
# Episode: 50;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 51; Acc. Reward: 297.8; Pole fell: True
# Episode: 51;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 52; Acc. Reward: 198.6; Pole fell: True
# Episode: 52;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 53; Acc. Reward: 125.2; Pole fell: True
# Episode: 53;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 54; Acc. Reward: 142.4; Pole fell: True
# Episode: 54;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 55; Acc. Reward: 203.3; Pole fell: True
# Episode: 55;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 56; Acc. Reward: 234.0; Pole fell: True
# Episode: 56;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 57; Acc. Reward: 112.7; Pole fell: True
# Episode: 57;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 58; Acc. Reward: 201.8; Pole fell: True
# Episode: 58;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 59; Acc. Reward: 161.3; Pole fell: True
# Episode: 59;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 60; Acc. Reward: 114.8; Pole fell: True
# Episode: 60;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 61; Acc. Reward: 259.8; Pole fell: True
# Episode: 61;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 62; Acc. Reward: 209.5; Pole fell: True
# Episode: 62;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 63; Acc. Reward: 41.0; Pole fell: True
# Episode: 63;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 64; Acc. Reward: 124.2; Pole fell: True
# Episode: 64;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 65; Acc. Reward: 113.0; Pole fell: True
# Episode: 65;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 66; Acc. Reward: 117.3; Pole fell: True
# Episode: 66;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 67; Acc. Reward: 145.3; Pole fell: True
# Episode: 67;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 68; Acc. Reward: 265.1; Pole fell: True
# Episode: 68;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 69; Acc. Reward: 215.2; Pole fell: True
# Episode: 69;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 70; Acc. Reward: 182.4; Pole fell: True
# Episode: 70;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 71; Acc. Reward: 181.0; Pole fell: True
# Episode: 71;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 72; Acc. Reward: 193.0; Pole fell: True
# Episode: 72;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 73; Acc. Reward: 126.8; Pole fell: True
# Episode: 73;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 74; Acc. Reward: 355.9; Pole fell: True
# Episode: 74;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 75; Acc. Reward: 90.5; Pole fell: True
# Episode: 75;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 76; Acc. Reward: 284.5; Pole fell: True
# Episode: 76;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 77; Acc. Reward: 118.6; Pole fell: True
# Episode: 77;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 78; Acc. Reward: 90.0; Pole fell: True
# Episode: 78;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 79; Acc. Reward: 279.4; Pole fell: True
# Episode: 79;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 80; Acc. Reward: 206.8; Pole fell: True
# Episode: 80;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 81; Acc. Reward: 106.0; Pole fell: True
# Episode: 81;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 82; Acc. Reward: 173.1; Pole fell: True
# Episode: 82;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 83; Acc. Reward: 355.0; Pole fell: True
# Episode: 83;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 84; Acc. Reward: 110.6; Pole fell: True
# Episode: 84;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 85; Acc. Reward: 142.8; Pole fell: True
# Episode: 85;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 86; Acc. Reward: 214.4; Pole fell: True
# Episode: 86;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 87; Acc. Reward: 160.7; Pole fell: True
# Episode: 87;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 88; Acc. Reward: 214.0; Pole fell: True
# Episode: 88;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 89; Acc. Reward: 144.6; Pole fell: True
# Episode: 89;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 90; Acc. Reward: 231.8; Pole fell: True
# Episode: 90;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 91; Acc. Reward: 130.0; Pole fell: True
# Episode: 91;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 92; Acc. Reward: 237.0; Pole fell: True
# Episode: 92;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 93; Acc. Reward: 140.3; Pole fell: True
# Episode: 93;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 94; Acc. Reward: 102.2; Pole fell: True
# Episode: 94;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 95; Acc. Reward: 261.6; Pole fell: True
# Episode: 95;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 96; Acc. Reward: 133.9; Pole fell: True
# Episode: 96;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 97; Acc. Reward: 141.9; Pole fell: True
# Episode: 97;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 98; Acc. Reward: 128.2; Pole fell: True
# Episode: 98;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]
# Episode: 99; Acc. Reward: 75.8; Pole fell: True
# Episode: 99;   adapt. coeffs at final time step:  [ 4.3  -3.76  1.61  1.62]

# %%
env.MRAC.mrac_mod = True

# %%
score = num_success/total_episodes_test*100
print(f"score=({num_success} successes)/({total_episodes_test} episodes)*100={score:.1f}")
# Out:
# score=(0 successes)/(100 episodes)*100=0.0

# %%
print("Acc. Episodic Reward's mean=")
print(np.array(ep_reward_list_test).mean())
print(f"Normalized mean= {unnorm_to_norm(np.array(ep_reward_list_test).mean()):.3e}")
print(f"Normalized std = {unnorm_to_norm(np.array(ep_reward_list_test).std()):.3e}")
# Out:
# Acc. Episodic Reward's mean=
# 168.8115744767555
# Normalized mean= 3.376e-01
# Normalized std = 1.375e-01

# %%
# Plotting graph
# Episodes versus Avg. Rewards
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(ep_reward_list_test, label = "Acc. Epsiodic Reward",color="C0",linewidth = 1.5)
plt.axhline(y=np.array(ep_reward_list_test).mean(), linestyle='--',
            label = "Acc. Epsiodic Reward's mean= "+f"{np.array(ep_reward_list_test).mean():.1f}",color="C1",linewidth = 2.5)
plt.xlabel("Episode")
plt.ylabel("Acc. Epsiodic Reward")
plt.grid()
plt.legend()
plt.show()

# %%
print("Acc. Epsiodic Reward's mean=")
print(np.array(ep_reward_list_test).mean())
# Out:
# Acc. Epsiodic Reward's mean=
# 168.8115744767555

# %%
dt=env.dt
time_= np.linspace(start = 0, stop = len(save_wanted_torque)* dt,
                   num=len(save_wanted_torque) )

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)

plt.step(time_, save_wanted_torque ,label = "desired_torque",color="blue",linewidth = 1.5)
plt.xlabel("time [sec]")
plt.ylabel("Torque [Nm]")
if not env.ideal_env:
  plt.step(time_, save_actual_torque , ':',label = "actual_torque",color="red",linewidth = 4)
  mae_torque_error = np.array(save_wanted_torque)-np.array(save_actual_torque)
  mae_torque_error = np.abs(mae_torque_error).mean()
  plt.axhline(y=mae_torque_error, linestyle='--',
            label = "MAE_torque_error= "+f"{mae_torque_error:.2e}",color="C1",linewidth = 2.5)
  plt.legend()
plt.grid()
plt.show()

# %%
if not env.ideal_env:
  e_ry=np.array(save_wanted_torque)-np.array(save_actual_torque)
  e_yy_m=np.array(save_actual_torque)-np.array(save_model_torque)
  print(f"e_ry: (mean, std, mae) = ({e_ry.mean():.2e}, {e_ry.std():.2e}, {np.abs(e_ry).mean():.2e})")
  print(f"e_yy_m: (mean, std, mae) = ({e_yy_m.mean():.2e}, {e_yy_m.std():.2e}, {np.abs(e_yy_m).mean():.2e})")
# Out:
# e_ry: (mean, std, mae) = (8.65e-02, 1.46e+00, 1.23e+00)
# e_yy_m: (mean, std, mae) = (-8.96e-02, 1.19e+00, 9.93e-01)

# %%
# distribution to 4 observation parameters

position = []
velocity = []
angle = []
angular_velocity = []
for observ in save_observation:
  for index,value in enumerate(observ):
    if index == 0:
      position.append(value)
    if index == 1:
      velocity.append(value)
    if index == 2:
      angle.append(value)
    if index == 3:
      angular_velocity.append(value)

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_position = np.linspace(start = 0, stop = len(position)* dt,num=len(position))##############################################
#time_position , position
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_position[-1] , 300)

spl = make_interp_spline(time_position, position, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Position [m]')
plt.show()

# %%
print(len(position))
# Out:
# 431

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_velocity = np.linspace(start = 0, stop = len(velocity)* dt,num=len(velocity))
#time_velocity , velocity
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_velocity[-1] , 300)

spl = make_interp_spline(time_velocity, velocity, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Velocity [m]')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_angle = np.linspace(start = 0, stop = len(angle)* dt,num=len(angle))
#time_angle , angle
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_angle[-1] , 300)

spl = make_interp_spline(time_angle,angle, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Angle [rad]')
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_angular_velocity = np.linspace(start = 0, stop = len(angular_velocity)* dt,num=len(angular_velocity))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_angular_velocity[-1] , 300)

spl = make_interp_spline(time_angular_velocity, angular_velocity, k=3)  # type: BSpline
power_smooth = spl(xnew)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(xnew, power_smooth)
plt.grid()
plt.xlabel('Time [sec]')
plt.ylabel('Angular Velocity [rad/sec]')
plt.show()
