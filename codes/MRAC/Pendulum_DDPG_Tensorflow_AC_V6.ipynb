# %%
 # https://keras.io/examples/rl/ddpg_pendulum/

# %%
import gym
import tensorflow as tf
import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle

# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from os import path

class custom_PendulumEnv(gym.Env):
    metadata = {
        'render.modes' : ['human', 'rgb_array'],
        'video.frames_per_second' : 30
    }

    def __init__(self):
        self.max_speed=8
        self.max_torque=2.
        self.dt=.05
        self.NumIntegrationsSteps = 20#5
        self.viewer = None
        self.max_step = 200
        self.current_step = 0

        high = np.array([1., 1., self.max_speed])
        self.action_space = spaces.Box(low=-self.max_torque, high=self.max_torque, shape=(1,))
        self.observation_space = spaces.Box(low=-high, high=high)

        self.seed()

        ### Customization changes ############################
        self.MRAC = ModelRefAC()
        self.MRAC.timeSample = self.dt/self.NumIntegrationsSteps
        self.MRAC.plant.tau1 = self.dt/self.NumIntegrationsSteps
        self.MRAC.ref_model.tau1 = self.dt/self.NumIntegrationsSteps
        self.wanted_torque = 0
        ####


    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def step(self,action):
        th, thdot = self.state # th := theta
        newth, newthdot = self.state # th := theta

        g = 10.
        m = 1.
        l = 1.
        dt = self.dt/self.NumIntegrationsSteps

        wanted_torque = np.clip(action, -self.max_torque, self.max_torque)[0] #numpy.clip() function is used to Clip (limit) the values in an array
        #wanted_torque = 0.135*self.wanted_torque+0.865*wanted_torque
        self.wanted_torque = wanted_torque
        self.MRAC.r = wanted_torque
        for n in np.arange(start=0, stop=self.NumIntegrationsSteps, step=1):
          self.MRAC.plant.thetadot = newthdot
          actual_torque = self.MRAC.step(r=wanted_torque)
          newthdot = newthdot + (-3*g/(2*l) * np.sin(newth + np.pi) + 3./(m*l**2)*actual_torque) * dt
          newth = newth + newthdot*dt
          newthdot = np.clip(newthdot, -self.max_speed, self.max_speed) #pylint: disable=E1111 #numpy.clip() function is used to Clip (limit) the values in an array

        self.last_u = actual_torque
        costs = angle_normalize(th)**2 + .1*thdot**2 + .001*(actual_torque**2)
        self.state = np.array([newth, newthdot])

        self.current_step += 1
        done = bool(self.current_step % self.max_step == 0)

        #return self._get_obs(), -costs, done, {} , u , u_after_pid
        return self._get_obs(), -costs, done, {} , wanted_torque , actual_torque


    def reset(self):
        high = np.array([np.pi, 1])
        self.state = self.np_random.uniform(low=-high, high=high)
        self.last_u = None

        self.MRAC.reset()
        self.MRAC.plant.reset()
        self.MRAC.ref_model.reset()
        self.wanted_torque = 0

        return self._get_obs()

    def _get_obs(self):
        theta, thetadot = self.state
        return np.array([np.cos(theta), np.sin(theta), thetadot])

    def render(self, mode='human'):

        if self.viewer is None:
            from gym.envs.classic_control import rendering
            self.viewer = rendering.Viewer(500,500)
            self.viewer.set_bounds(-2.2,2.2,-2.2,2.2)
            rod = rendering.make_capsule(1, .2)
            rod.set_color(.8, .3, .3)
            self.pole_transform = rendering.Transform()
            rod.add_attr(self.pole_transform)
            self.viewer.add_geom(rod)
            axle = rendering.make_circle(.05)
            axle.set_color(0,0,0)
            self.viewer.add_geom(axle)
            fname = path.join(path.dirname(__file__), "assets/clockwise.png")
            self.img = rendering.Image(fname, 1., 1.)
            self.imgtrans = rendering.Transform()
            self.img.add_attr(self.imgtrans)

        self.viewer.add_onetime(self.img)
        self.pole_transform.set_rotation(self.state[0] + np.pi/2)
        if self.last_u:
            self.imgtrans.scale = (-self.last_u/2, np.abs(self.last_u)/2)

        return self.viewer.render(return_rgb_array = mode=='rgb_array')

    def close(self):
        if self.viewer: self.viewer.close()

def angle_normalize(x):
    return (((x+np.pi) % (2*np.pi)) - np.pi)

# %%
class ElectricalDCMotorEnv():

  def __init__(self):
    self.Resistor_R = 1.0
    self.inductor_L = 0.1
    self.torque_const_Kt = 1.0
    self.bemf_const_Ke = 1.0
    self.tau1 = 0.05
        #
    self.current = 0.0
    self.voltage_input = None
    self.thetadot = 0.0

  def step(self, u):
    voltage_BEMF = self.thetadot*self.bemf_const_Ke
    self.voltage_input = np.clip(u, -10, 10)

    f1 = self.torque_const_Kt*self.current
    self.current += self.tau1*(self.voltage_input-voltage_BEMF-self.current*self.Resistor_R)/self.inductor_L
    f2 = self.torque_const_Kt*self.current
    F = f2
    return F # return actual applied torque

  def reset(self):
    self.current = 0.0

# %%
class ReferenceModel():

  def __init__(self):
    self.a_m = 50.0#30.0
    self.b_m = self.a_m
    self.tau1 = 0.05
    self.x_m = 0.0
    self.y_m = 0.0

  def step(self, r):

    #fwd integration
    #A = -self.a_m*self.tau1
    #Br = self.b_m*self.tau1*r
    #self.y_m = self.x_m+0
    #self.x_m = (1+A)*self.y_m+Br
    #y_m = self.y_m+0

    #bkwd integration
    #A = -self.a_m*self.tau1
    #Br = self.b_m*self.tau1*r
    #if A ==1:
    #  C=1
    #else:
    #  C = 1/(1-A)
    #self.y_m = C*(self.x_m-Br)
    #self.x_m = self.y_m+0
    #y_m = self.y_m+0

    #trapz integragration
    A = -0.5*self.a_m*self.tau1
    Br= +0.5*self.b_m*self.tau1*r
    if A ==1:
      C=1
    else:
      C = 1/(1-A)
    x_m = self.x_m
    y_m = C*(x_m+Br)
    x_m = (1+A)*y_m + Br
    self.x_m = x_m
    self.y_m = y_m

    return y_m

  def reset(self):
    self.x_m = 0.0
    self.y_m = 0.0

# %%
class ModelRefAC:

  def __init__(self): #  order of signals [r,y,r-y,w]
    self.plant = ElectricalDCMotorEnv()
    self.ref_model = ReferenceModel()
    self.w = 0.0
    self.u = 0.0
    self.r = 0.0
    self.y = 0.0
    self.y_m = 0.0

    #self.adaptation_gain=np.array([5,5,5,5]) # positive scalar or np.array shape (4,)
    self.adaptation_gain=np.array([5,5,1,5])
    self.sigma_mod_adapt_gain=0 # non-neg scalar or np.array shape (4,)
    self.emod_adapt_gain=0
    self.dead_zone_threshold = 0*1e-10
    self.dead_zone_adapt_gain = 1e-6
    self.timeSample=0.05
    self.mu0 = np.array([1e-3,-1e-3,1e-3,1e-3])
    self.std = 0*1e-6
    self.k_temp = self.mu0
    self.k_hat =  self.mu0
    self.keep_coeff = True
    self.mask = np.array([True,True,True,True])
    self.distrib = np.random.standard_normal


  def step(self, r):
    self.r = r
    self.w = self.plant.thetadot
    y = self.y
    y_m = self.y_m
    e=y-y_m
    u = self.adaptationControlLaw(e=e, r=r, y=y, w=self.w)
    self.y_m = self.ref_model.step(r)
    self.y = self.plant.step(u)
    return self.y

  def adaptationControlLaw(self, e, r, y, w):
    v = np.array([r,y,r-y,w])#.clip(-20,20)
    e_norm = abs(e)

    #fwd integration
    #A = -(self.sigma_mod_adapt_gain+self.emod_adapt_gain*e_norm)*self.timeSample
    #Bev = -self.adaptation_gain*self.timeSample*e*v
    #if e_norm<=self.dead_zone_threshold:
    #  A = A*self.dead_zone_adapt_gain
    #  Bev = Bev*self.dead_zone_adapt_gain
    #self.k_hat = self.k_temp*self.mask
    #self.k_temp = ((1+A)*self.k_hat + Bev)*self.mask

    #backwd integration
    #A = -(self.sigma_mod_adapt_gain+self.emod_adapt_gain*e_norm)*self.timeSample
    #Bev = -self.adaptation_gain*self.timeSample*e*v
    #if e_norm<=self.dead_zone_threshold:
    #  A = A*self.dead_zone_adapt_gain
    #  Bev = Bev*self.dead_zone_adapt_gain
    #C = 1-A*(A!=np.ones_like(A))
    #C = 1/C
    #self.k_hat = C*(self.k_temp+Bev)*self.mask
    #self.k_temp = A*self.k_hat*self.mask

    #trapz integration
    A = -0.5*(self.sigma_mod_adapt_gain+self.emod_adapt_gain*e_norm)*self.timeSample
    Bev = -0.5*self.adaptation_gain*self.timeSample*e*v
    if e_norm<=self.dead_zone_threshold:
      A = A*self.dead_zone_adapt_gain
      Bev = Bev*self.dead_zone_adapt_gain
    if A ==1:
      C=1
    else:
      C = 1/(1-A)
    self.k_hat = C*((self.k_temp +Bev)*self.mask)
    self.k_temp = ((1+A)*self.k_hat +Bev)*self.mask
    u = np.dot(v,self.k_hat)
    u=np.clip(u,-10,10)
    self.u = u
    return u

  def reset(self):
    self.w = 0.0
    self.r = 0.0
    self.y = 0.0
    self.y_m = 0.0
    mu0 = self.mu0
    sigma0 = self.std
    keep_coeff = self.keep_coeff
    self.k_temp = (sigma0*self.distrib(self.k_temp.shape) + keep_coeff*self.k_temp + (not keep_coeff)*mu0)*self.mask
    self.k_hat = (sigma0*self.distrib(self.k_hat.shape) + keep_coeff*self.k_hat + (not keep_coeff)*mu0)*self.mask

# %%
env = custom_PendulumEnv()
# Out:
# /usr/local/lib/python3.12/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
print("dt= ", env.dt)
print("N= ", env.NumIntegrationsSteps)
print("dt/N=", env.dt/env.NumIntegrationsSteps)
print("gamma*dt/N=", env.MRAC.adaptation_gain*env.dt/env.NumIntegrationsSteps)
# Out:
# dt=  0.05
# N=  20
# dt/N= 0.0025
# gamma*dt/N= [0.0125 0.0125 0.0025 0.0125]

# %%
'''
problem = "Pendulum-v1"
env = gym.make(problem)
'''


num_states = env.observation_space.shape[0]
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.shape[0]
print("Size of Action Space ->  {}".format(num_actions))

upper_bound = env.action_space.high[0]
lower_bound = env.action_space.low[0]

print("Max Value of Action ->  {}".format(upper_bound))
print("Min Value of Action ->  {}".format(lower_bound))
# Out:
# Size of State Space ->  3
# Size of Action Space ->  1
# Max Value of Action ->  2.0
# Min Value of Action ->  -2.0

# %%
class OUActionNoise:
    def __init__(self, mean, std_deviation, theta=0.15, dt=1e-2, x_initial=None):
        self.theta = theta
        self.mean = mean
        self.std_dev = std_deviation
        self.dt = dt
        self.x_initial = x_initial
        self.reset()

    def __call__(self):
        # Formula taken from https://www.wikipedia.org/wiki/Ornstein-Uhlenbeck_process.
        x = (
            self.x_prev
            + self.theta * (self.mean - self.x_prev) * self.dt
            + self.std_dev * np.sqrt(self.dt) * np.random.normal(size=self.mean.shape)
        )
        # Store x into x_prev
        # Makes next noise dependent on current one
        self.x_prev = x
        return x

    def reset(self):
        if self.x_initial is not None:
            self.x_prev = self.x_initial
        else:
            self.x_prev = np.zeros_like(self.mean)

# %%
class Buffer:
    def __init__(self, buffer_capacity=100000, batch_size=64):
        # Number of "experiences" to store at max
        self.buffer_capacity = buffer_capacity
        # Num of tuples to train on.
        self.batch_size = batch_size

        # Its tells us num of times record() was called.
        self.buffer_counter = 0

        # Instead of list of tuples as the exp.replay concept go
        # We use different np.arrays for each tuple element
        self.state_buffer = np.zeros((self.buffer_capacity, num_states))
        self.action_buffer = np.zeros((self.buffer_capacity, num_actions))
        self.reward_buffer = np.zeros((self.buffer_capacity, 1))
        self.next_state_buffer = np.zeros((self.buffer_capacity, num_states))

    # Takes (s,a,r,s') observation tuple as input
    def record(self, obs_tuple):
        # Set index to zero if buffer_capacity is exceeded,
        # replacing old records
        index = self.buffer_counter % self.buffer_capacity

        self.state_buffer[index] = obs_tuple[0]
        self.action_buffer[index] = obs_tuple[1]
        self.reward_buffer[index] = obs_tuple[2]
        self.next_state_buffer[index] = obs_tuple[3]

        self.buffer_counter += 1

    # Eager execution is turned on by default in TensorFlow 2. Decorating with tf.function allows
    # TensorFlow to build a static graph out of the logic and computations in our function.
    # This provides a large speed up for blocks of code that contain many small TensorFlow operations such as this one.
    @tf.function
    def update(
        self,
        state_batch,
        action_batch,
        reward_batch,
        next_state_batch,
    ):
        # Training and updating Actor & Critic networks.
        # See Pseudo Code.
        with tf.GradientTape() as tape:
            target_actions = target_actor(next_state_batch, training=True)
            y = reward_batch + gamma * target_critic(
                [next_state_batch, target_actions], training=True
            )
            critic_value = critic_model([state_batch, action_batch], training=True)
            critic_loss = keras.ops.mean(keras.ops.square(y - critic_value))

        critic_grad = tape.gradient(critic_loss, critic_model.trainable_variables)
        critic_optimizer.apply_gradients(
            zip(critic_grad, critic_model.trainable_variables)
        )

        with tf.GradientTape() as tape:
            actions = actor_model(state_batch, training=True)
            critic_value = critic_model([state_batch, actions], training=True)
            # Used `-value` as we want to maximize the value given
            # by the critic for our actions
            actor_loss = -keras.ops.mean(critic_value)

        actor_grad = tape.gradient(actor_loss, actor_model.trainable_variables)
        actor_optimizer.apply_gradients(
            zip(actor_grad, actor_model.trainable_variables)
        )

    # We compute the loss and update parameters
    def learn(self):
        # Get sampling range
        record_range = min(self.buffer_counter, self.buffer_capacity)
        # Randomly sample indices
        batch_indices = np.random.choice(record_range, self.batch_size)

        # Convert to tensors
        state_batch = keras.ops.convert_to_tensor(self.state_buffer[batch_indices])
        action_batch = keras.ops.convert_to_tensor(self.action_buffer[batch_indices])
        reward_batch = keras.ops.convert_to_tensor(self.reward_buffer[batch_indices])
        reward_batch = keras.ops.cast(reward_batch, dtype="float32")
        next_state_batch = keras.ops.convert_to_tensor(
            self.next_state_buffer[batch_indices]
        )

        self.update(state_batch, action_batch, reward_batch, next_state_batch)


# This update target parameters slowly
# Based on rate `tau`, which is much less than one.
def update_target(target, original, tau):
    target_weights = target.get_weights()
    original_weights = original.get_weights()

    for i in range(len(target_weights)):
        target_weights[i] = original_weights[i] * tau + target_weights[i] * (1 - tau)

    target.set_weights(target_weights)

# %%
def get_actor():
    # Initialize weights between -3e-3 and 3-e3
    last_init = tf.random_uniform_initializer(minval=-0.003, maxval=0.003)

    inputs = layers.Input(shape=(num_states,))
    out = layers.Dense(256, activation="relu")(inputs)
    out = layers.Dense(256, activation="relu")(out)
    outputs = layers.Dense(1, activation="tanh", kernel_initializer=last_init)(out)

    # Our upper bound is 2.0 for Pendulum.
    outputs = outputs * upper_bound
    model = tf.keras.Model(inputs, outputs)
    return model


def get_critic():
    # State as input
    state_input = layers.Input(shape=(num_states,))
    state_out = layers.Dense(16, activation="relu")(state_input)
    state_out = layers.Dense(32, activation="relu")(state_out)

    # Action as input
    action_input = layers.Input(shape=(num_actions,))
    action_out = layers.Dense(32, activation="relu")(action_input)

    # Both are passed through seperate layer before concatenating
    concat = layers.Concatenate()([state_out, action_out])

    out = layers.Dense(256, activation="relu")(concat)
    out = layers.Dense(256, activation="relu")(out)
    outputs = layers.Dense(1)(out)

    # Outputs single value for give state-action
    model = tf.keras.Model([state_input, action_input], outputs)

    return model

# %%
def policy(state, noise_object):
    sampled_actions = tf.squeeze(actor_model(state))
    noise = noise_object()
    # Adding noise to action
    sampled_actions = sampled_actions.numpy() + noise

    # We make sure action is within bounds
    legal_action = np.clip(sampled_actions, lower_bound, upper_bound) #numpy.clip() function is used to Clip (limit) the values in an array

    return [np.squeeze(legal_action)]

# %%
std_dev = 0.2
ou_noise = OUActionNoise(mean=np.zeros(1), std_deviation=float(std_dev) * np.ones(1))

actor_model = get_actor()
critic_model = get_critic()

target_actor = get_actor()
target_critic = get_critic()

# Making the weights equal initially
target_actor.set_weights(actor_model.get_weights())
target_critic.set_weights(critic_model.get_weights())

# Learning rate for actor-critic models
critic_lr = 0.002
actor_lr = 0.001

critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

# Discount factor for future rewards
gamma = 0.99
# Used to update target networks
tau = 0.005

buffer = Buffer(50000, 64)

# %%
#######################################################tests
prev_state = env.reset()
print(prev_state)
print(type(prev_state))
# Out:
# [ 0.99289329 -0.11900805  0.21318471]
# <class 'numpy.ndarray'>

# %%
total_episodes=200
print_episode_each=1

# %%
# To store reward history of each episode
ep_reward_list = []
# To store average reward history of last few episodes
avg_reward_list = []
best_score = -1600

# %%
path_ = '/content/drive/MyDrive/Colab Notebooks/codes/MRAC/save_data/Pendulum/'

# %%
save_observation = []
save_wanted_torque = [0]
save_actual_torque = [0]
save_model_torque = [0]
save_ctrl_voltage = []
save_MRAC_adapt_gains = []

ploting_adapt_coeff=[]
k_hat_print = env.MRAC.mu0
print('Initial adapt. coeffs: ', k_hat_print)

initial_not_saved = True
# Takes about 4 min to train
for ep in range(total_episodes):

    prev_state = env.reset()
    episodic_reward = 0

    while True:
        # Uncomment this to see the Actor in action
        # But not in a python notebook.
        # env.render()
        k_hat_print = env.MRAC.k_hat.round(2)
        if ep == total_episodes - 1 and initial_not_saved:
          save_MRAC_adapt_gains.append(env.MRAC.k_hat)
          save_observation.append(prev_state)
          u0=env.MRAC.adaptationControlLaw(e=env.MRAC.y-env.MRAC.y_m,
                                              r=env.MRAC.r,y=env.MRAC.y,
                                              w=env.MRAC.w)
          save_ctrl_voltage.append(u0)
          initial_not_saved = False
       #end if

        tf_prev_state = tf.expand_dims(tf.convert_to_tensor(prev_state), 0)

        action = policy(tf_prev_state, ou_noise)

        # Recieve state and reward from environment.
        state, reward, done, info , wanted_torque , actual_torque = env.step(action)
        voltage = env.MRAC.plant.voltage_input


        if ep == total_episodes - 1 :
          save_observation.append(state)
          save_wanted_torque.append(wanted_torque)
          save_actual_torque.append(actual_torque)
          save_model_torque.append(env.MRAC.y_m)
          save_ctrl_voltage.append(env.MRAC.u)
          save_MRAC_adapt_gains.append(env.MRAC.k_hat)
        #end if


        buffer.record((prev_state, action, reward, state))
        episodic_reward += reward

        buffer.learn()
        update_target(target_actor, actor_model, tau)
        update_target(target_critic, critic_model, tau)

        # End this episode when `done` is True
        if done:
            break

        prev_state = state

    ep_reward_list.append(episodic_reward)
    ploting_adapt_coeff.append(k_hat_print)
    # Mean of last 40 episodes
    avg_reward = np.mean(ep_reward_list[-40:])
    if ep%print_episode_each == 0 or ep == total_episodes - 1:
      print(f"Episode * {ep} * "," adapt. coeffs at final time step: ", k_hat_print)
      if ep%10==0 and ep>0:
        k_hat_median = np.median(np.array(ploting_adapt_coeff), axis=0)
        print("median: ", k_hat_median)
      print("Episode * {} * Avg Reward is ==> {:.3f}".format(ep, avg_reward))
    if best_score <= np.mean(ep_reward_list[-5:]):
      best_score = np.mean(ep_reward_list[-5:])
      actor_model.save_weights(path_+"pendulum_temp_actor.weights.h5")
    if ep== int(total_episodes/2):
      actor_model.load_weights(path_+"pendulum_temp_actor.weights.h5")
      target_actor.load_weights(path_+"pendulum_temp_actor.weights.h5")
    avg_reward_list.append(avg_reward)

actor_model.load_weights(path_+"pendulum_temp_actor.weights.h5")
# Out:
# Initial adapt. coeffs:  [ 0.001 -0.001  0.001  0.001]
# Episode * 0 *   adapt. coeffs at final time step:  [ 0.11 -0.41  0.1   1.39]
# Episode * 0 * Avg Reward is ==> -1534.767
# Episode * 1 *   adapt. coeffs at final time step:  [ 1.24 -0.83  0.41  0.44]
# Episode * 1 * Avg Reward is ==> -1527.632
# Episode * 2 *   adapt. coeffs at final time step:  [ 1.83 -0.84  0.53  0.94]
# Episode * 2 * Avg Reward is ==> -1473.319
# Episode * 3 *   adapt. coeffs at final time step:  [ 2.06 -1.06  0.62  1.08]
# Episode * 3 * Avg Reward is ==> -1502.981
# Episode * 4 *   adapt. coeffs at final time step:  [ 2.19 -1.18  0.68  1.03]
# Episode * 4 * Avg Reward is ==> -1489.516
# Episode * 5 *   adapt. coeffs at final time step:  [ 2.27 -1.33  0.72  1.15]
# Episode * 5 * Avg Reward is ==> -1485.879
# Episode * 6 *   adapt. coeffs at final time step:  [ 5.54 -4.73  2.05  0.78]
# Episode * 6 * Avg Reward is ==> -1467.520
# Episode * 7 *   adapt. coeffs at final time step:  [ 5.58 -4.55  2.03  0.88]
# Episode * 7 * Avg Reward is ==> -1481.082
# Episode * 8 *   adapt. coeffs at final time step:  [ 5.43 -4.5   1.99  0.9 ]
# Episode * 8 * Avg Reward is ==> -1469.448
# Episode * 9 *   adapt. coeffs at final time step:  [ 5.43 -4.41  1.97  1.02]
# Episode * 9 * Avg Reward is ==> -1449.056
# Episode * 10 *   adapt. coeffs at final time step:  [ 5.36 -4.33  1.94  0.98]
# median:  [ 2.27 -1.33  0.72  0.98]
# Episode * 10 * Avg Reward is ==> -1419.331
# Episode * 11 *   adapt. coeffs at final time step:  [ 5.35 -4.24  1.92  1.09]
# Episode * 11 * Avg Reward is ==> -1396.997
# Episode * 12 *   adapt. coeffs at final time step:  [ 5.22 -4.15  1.87  1.02]
# Episode * 12 * Avg Reward is ==> -1348.972
# Episode * 13 *   adapt. coeffs at final time step:  [ 5.7  -4.63  2.07  1.04]
# Episode * 13 * Avg Reward is ==> -1298.588
# Episode * 14 *   adapt. coeffs at final time step:  [ 5.81 -4.59  2.08  0.97]
# Episode * 14 * Avg Reward is ==> -1270.560
# Episode * 15 *   adapt. coeffs at final time step:  [ 5.8  -4.79  2.12  0.85]
# Episode * 15 * Avg Reward is ==> -1232.732
# Episode * 16 *   adapt. coeffs at final time step:  [ 5.78 -4.79  2.11  0.96]
# Episode * 16 * Avg Reward is ==> -1198.650
# Episode * 17 *   adapt. coeffs at final time step:  [ 5.77 -4.73  2.1   1.  ]
# Episode * 17 * Avg Reward is ==> -1153.306
# Episode * 18 *   adapt. coeffs at final time step:  [ 5.6  -4.61  2.04  0.96]
# Episode * 18 * Avg Reward is ==> -1119.051
# Episode * 19 *   adapt. coeffs at final time step:  [ 5.56 -4.56  2.02  1.02]
# Episode * 19 * Avg Reward is ==> -1075.623
# Episode * 20 *   adapt. coeffs at final time step:  [ 5.53 -4.51  2.01  0.99]
# median:  [ 5.43 -4.5   1.99  0.99]
# Episode * 20 * Avg Reward is ==> -1030.444
# Episode * 21 *   adapt. coeffs at final time step:  [ 5.41 -4.46  1.98  1.12]
# Episode * 21 * Avg Reward is ==> -989.329
# Episode * 22 *   adapt. coeffs at final time step:  [ 5.34 -4.36  1.94  1.02]
# Episode * 22 * Avg Reward is ==> -956.980
# Episode * 23 *   adapt. coeffs at final time step:  [ 5.17 -4.3   1.9   1.2 ]
# Episode * 23 * Avg Reward is ==> -922.199
# Episode * 24 *   adapt. coeffs at final time step:  [ 5.12 -4.2   1.86  1.03]
# Episode * 24 * Avg Reward is ==> -890.352
# Episode * 25 *   adapt. coeffs at final time step:  [ 4.8  -4.29  1.82  1.18]
# Episode * 25 * Avg Reward is ==> -860.831
# Episode * 26 *   adapt. coeffs at final time step:  [ 4.87 -4.05  1.79  1.08]
# Episode * 26 * Avg Reward is ==> -833.447
# Episode * 27 *   adapt. coeffs at final time step:  [ 4.25 -4.03  1.66  1.09]
# Episode * 27 * Avg Reward is ==> -812.572
# Episode * 28 *   adapt. coeffs at final time step:  [ 3.31 -2.33  1.13  1.11]
# Episode * 28 * Avg Reward is ==> -788.898
# Episode * 29 *   adapt. coeffs at final time step:  [ 3.44 -2.22  1.13  1.07]
# Episode * 29 * Avg Reward is ==> -770.567
# Episode * 30 *   adapt. coeffs at final time step:  [ 3.28 -2.09  1.07  0.98]
# median:  [ 5.34 -4.3   1.92  1.02]
# Episode * 30 * Avg Reward is ==> -753.661
# Episode * 31 *   adapt. coeffs at final time step:  [ 3.23 -2.23  1.09  1.01]
# Episode * 31 * Avg Reward is ==> -733.851
# Episode * 32 *   adapt. coeffs at final time step:  [ 3.23 -2.23  1.09  0.98]
# Episode * 32 * Avg Reward is ==> -719.058
# Episode * 33 *   adapt. coeffs at final time step:  [ 3.26 -2.26  1.1   1.01]
# Episode * 33 * Avg Reward is ==> -701.786
# Episode * 34 *   adapt. coeffs at final time step:  [ 3.26 -2.26  1.1   1.  ]
# Episode * 34 * Avg Reward is ==> -685.081
# Episode * 35 *   adapt. coeffs at final time step:  [ 3.27 -2.27  1.11  1.01]
# Episode * 35 * Avg Reward is ==> -675.133
# Episode * 36 *   adapt. coeffs at final time step:  [ 3.28 -2.28  1.11  1.04]
# Episode * 36 * Avg Reward is ==> -660.145
# Episode * 37 *   adapt. coeffs at final time step:  [ 3.45 -2.47  1.18  1.27]
# Episode * 37 * Avg Reward is ==> -646.008
# Episode * 38 *   adapt. coeffs at final time step:  [ 3.46 -2.47  1.19  1.08]
# Episode * 38 * Avg Reward is ==> -632.615
# Episode * 39 *   adapt. coeffs at final time step:  [ 3.58 -2.61  1.24  1.13]
# Episode * 39 * Avg Reward is ==> -623.178
# Episode * 40 *   adapt. coeffs at final time step:  [ 3.55 -2.56  1.22  1.  ]
# median:  [ 4.8  -4.05  1.79  1.02]
# Episode * 40 * Avg Reward is ==> -591.005
# Episode * 41 *   adapt. coeffs at final time step:  [ 3.53 -2.53  1.21  1.01]
# Episode * 41 * Avg Reward is ==> -553.026
# Episode * 42 *   adapt. coeffs at final time step:  [ 3.51 -2.5   1.2   0.99]
# Episode * 42 * Avg Reward is ==> -528.201
# Episode * 43 *   adapt. coeffs at final time step:  [ 3.48 -2.48  1.19  1.01]
# Episode * 43 * Avg Reward is ==> -491.521
# Episode * 44 *   adapt. coeffs at final time step:  [ 3.46 -2.46  1.18  1.  ]
# Episode * 44 * Avg Reward is ==> -461.825
# Episode * 45 *   adapt. coeffs at final time step:  [ 3.57 -2.55  1.23  1.  ]
# Episode * 45 * Avg Reward is ==> -434.582
# Episode * 46 *   adapt. coeffs at final time step:  [ 3.67 -2.67  1.27  1.25]
# Episode * 46 * Avg Reward is ==> -406.974
# Episode * 47 *   adapt. coeffs at final time step:  [ 3.66 -2.66  1.27  1.13]
# Episode * 47 * Avg Reward is ==> -370.567
# Episode * 48 *   adapt. coeffs at final time step:  [ 3.63 -2.63  1.25  0.98]
# Episode * 48 * Avg Reward is ==> -342.385
# Episode * 49 *   adapt. coeffs at final time step:  [ 3.62 -2.62  1.25  1.  ]
# Episode * 49 * Avg Reward is ==> -313.977
# Episode * 50 *   adapt. coeffs at final time step:  [ 3.61 -2.61  1.24  1.02]
# median:  [ 3.62 -2.62  1.25  1.01]
# Episode * 50 * Avg Reward is ==> -289.146
# Episode * 51 *   adapt. coeffs at final time step:  [ 3.61 -2.68  1.26  1.07]
# Episode * 51 * Avg Reward is ==> -263.462
# Episode * 52 *   adapt. coeffs at final time step:  [ 3.31 -2.45  1.15  1.04]
# Episode * 52 * Avg Reward is ==> -250.435
# Episode * 53 *   adapt. coeffs at final time step:  [ 3.26 -2.25  1.1   1.  ]
# Episode * 53 * Avg Reward is ==> -240.524
# Episode * 54 *   adapt. coeffs at final time step:  [ 3.27 -2.24  1.1   0.99]
# Episode * 54 * Avg Reward is ==> -224.583
# Episode * 55 *   adapt. coeffs at final time step:  [ 3.43 -2.32  1.15  0.92]
# Episode * 55 * Avg Reward is ==> -207.982
# Episode * 56 *   adapt. coeffs at final time step:  [ 3.42 -2.32  1.15  0.87]
# Episode * 56 * Avg Reward is ==> -191.733
# Episode * 57 *   adapt. coeffs at final time step:  [ 3.6  -2.75  1.27  0.88]
# Episode * 57 * Avg Reward is ==> -185.235
# Episode * 58 *   adapt. coeffs at final time step:  [ 3.5  -2.53  1.21  1.03]
# Episode * 58 * Avg Reward is ==> -175.969
# Episode * 59 *   adapt. coeffs at final time step:  [ 7.14 -5.42  2.51  2.63]
# Episode * 59 * Avg Reward is ==> -193.226
# Episode * 60 *   adapt. coeffs at final time step:  [ 3.28 -4.62  1.58  2.08]
# median:  [ 3.58 -2.61  1.24  1.01]
# Episode * 60 * Avg Reward is ==> -193.204
# Episode * 61 *   adapt. coeffs at final time step:  [ 3.9  -2.99  1.38  1.24]
# Episode * 61 * Avg Reward is ==> -193.289
# Episode * 62 *   adapt. coeffs at final time step:  [ 3.92 -3.09  1.4   1.06]
# Episode * 62 * Avg Reward is ==> -190.385
# Episode * 63 *   adapt. coeffs at final time step:  [ 3.79 -2.98  1.36  0.95]
# Episode * 63 * Avg Reward is ==> -193.141
# Episode * 64 *   adapt. coeffs at final time step:  [ 3.89 -3.23  1.42  1.3 ]
# Episode * 64 * Avg Reward is ==> -193.209
# Episode * 65 *   adapt. coeffs at final time step:  [ 3.67 -2.63  1.26  1.35]
# Episode * 65 * Avg Reward is ==> -190.188
# Episode * 66 *   adapt. coeffs at final time step:  [ 3.68 -2.97  1.33  1.07]
# Episode * 66 * Avg Reward is ==> -190.128
# Episode * 67 *   adapt. coeffs at final time step:  [ 3.89 -2.85  1.35  1.05]
# Episode * 67 * Avg Reward is ==> -183.975
# Episode * 68 *   adapt. coeffs at final time step:  [ 3.58 -2.7   1.26  1.21]
# Episode * 68 * Avg Reward is ==> -184.107
# Episode * 69 *   adapt. coeffs at final time step:  [ 3.39 -2.3   1.14  1.  ]
# Episode * 69 * Avg Reward is ==> -187.362
# Episode * 70 *   adapt. coeffs at final time step:  [ 3.35 -2.32  1.14  1.  ]
# median:  [ 3.61 -2.63  1.26  1.02]
# Episode * 70 * Avg Reward is ==> -184.327
# Episode * 71 *   adapt. coeffs at final time step:  [ 3.35 -2.35  1.14  1.01]
# Episode * 71 * Avg Reward is ==> -184.499
# Episode * 72 *   adapt. coeffs at final time step:  [ 3.33 -2.33  1.13  1.  ]
# Episode * 72 * Avg Reward is ==> -186.773
# Episode * 73 *   adapt. coeffs at final time step:  [ 3.45 -2.61  1.21  1.19]
# Episode * 73 * Avg Reward is ==> -186.675
# Episode * 74 *   adapt. coeffs at final time step:  [ 3.52 -2.52  1.21  1.1 ]
# Episode * 74 * Avg Reward is ==> -186.772
# Episode * 75 *   adapt. coeffs at final time step:  [ 3.37 -2.47  1.17  1.12]
# Episode * 75 * Avg Reward is ==> -178.612
# Episode * 76 *   adapt. coeffs at final time step:  [ 3.29 -2.17  1.09  1.09]
# Episode * 76 * Avg Reward is ==> -178.621
# Episode * 77 *   adapt. coeffs at final time step:  [ 3.56 -2.56  1.22  0.9 ]
# Episode * 77 * Avg Reward is ==> -178.591
# Episode * 78 *   adapt. coeffs at final time step:  [ 3.47 -2.41  1.18  1.  ]
# Episode * 78 * Avg Reward is ==> -181.663
# Episode * 79 *   adapt. coeffs at final time step:  [ 3.45 -2.39  1.17  0.98]
# Episode * 79 * Avg Reward is ==> -178.579
# Episode * 80 *   adapt. coeffs at final time step:  [ 3.41 -2.32  1.15  1.01]
# median:  [ 3.56 -2.61  1.23  1.02]
# Episode * 80 * Avg Reward is ==> -181.648
# Episode * 81 *   adapt. coeffs at final time step:  [ 3.38 -2.26  1.13  1.02]
# Episode * 81 * Avg Reward is ==> -187.901
# Episode * 82 *   adapt. coeffs at final time step:  [ 3.46 -2.41  1.18  1.01]
# Episode * 82 * Avg Reward is ==> -184.978
# Episode * 83 *   adapt. coeffs at final time step:  [ 3.58 -2.6   1.24  1.06]
# Episode * 83 * Avg Reward is ==> -184.975
# Episode * 84 *   adapt. coeffs at final time step:  [ 3.65 -2.72  1.27  0.96]
# Episode * 84 * Avg Reward is ==> -181.979
# Episode * 85 *   adapt. coeffs at final time step:  [ 3.98 -3.01  1.4   1.35]
# Episode * 85 * Avg Reward is ==> -178.555
# Episode * 86 *   adapt. coeffs at final time step:  [ 4.01 -3.34  1.47  1.3 ]
# Episode * 86 * Avg Reward is ==> -180.885
# Episode * 87 *   adapt. coeffs at final time step:  [ 3.55 -2.82  1.27  1.06]
# Episode * 87 * Avg Reward is ==> -183.800
# Episode * 88 *   adapt. coeffs at final time step:  [ 3.55 -2.54  1.22  1.07]
# Episode * 88 * Avg Reward is ==> -180.515
# Episode * 89 *   adapt. coeffs at final time step:  [ 3.79 -2.83  1.33  0.92]
# Episode * 89 * Avg Reward is ==> -183.426
# Episode * 90 *   adapt. coeffs at final time step:  [ 3.77 -2.7   1.3   1.05]
# median:  [ 3.57 -2.61  1.24  1.02]
# Episode * 90 * Avg Reward is ==> -183.366
# Episode * 91 *   adapt. coeffs at final time step:  [ 3.58 -2.56  1.23  0.98]
# Episode * 91 * Avg Reward is ==> -183.474
# Episode * 92 *   adapt. coeffs at final time step:  [ 3.44 -2.36  1.16  1.  ]
# Episode * 92 * Avg Reward is ==> -183.552
# Episode * 93 *   adapt. coeffs at final time step:  [ 3.4  -2.29  1.14  0.94]
# Episode * 93 * Avg Reward is ==> -177.396
# Episode * 94 *   adapt. coeffs at final time step:  [ 3.47 -2.43  1.18  0.91]
# Episode * 94 * Avg Reward is ==> -177.161
# Episode * 95 *   adapt. coeffs at final time step:  [ 3.59 -2.59  1.24  0.94]
# Episode * 95 * Avg Reward is ==> -180.291
# Episode * 96 *   adapt. coeffs at final time step:  [ 3.77 -2.77  1.31  1.04]
# Episode * 96 * Avg Reward is ==> -186.391
# Episode * 97 *   adapt. coeffs at final time step:  [ 3.69 -2.76  1.29  1.05]
# Episode * 97 * Avg Reward is ==> -183.378
# Episode * 98 *   adapt. coeffs at final time step:  [ 4.06 -3.59  1.53  0.97]
# Episode * 98 * Avg Reward is ==> -180.115
# Episode * 99 *   adapt. coeffs at final time step:  [ 4.19 -3.31  1.5   1.  ]
# Episode * 99 * Avg Reward is ==> -162.846
# Episode * 100 *   adapt. coeffs at final time step:  [ 3.78 -3.    1.36  1.22]
# median:  [ 3.58 -2.61  1.24  1.02]
# Episode * 100 * Avg Reward is ==> -165.826
# Episode * 101 *   adapt. coeffs at final time step:  [ 3.92 -2.97  1.38  1.19]
# Episode * 101 * Avg Reward is ==> -165.784
# Episode * 102 *   adapt. coeffs at final time step:  [ 3.78 -2.9   1.34  1.16]
# Episode * 102 * Avg Reward is ==> -168.347
# Episode * 103 *   adapt. coeffs at final time step:  [ 3.62 -2.79  1.28  1.06]
# Episode * 103 * Avg Reward is ==> -165.626
# Episode * 104 *   adapt. coeffs at final time step:  [ 3.93 -3.17  1.42  0.89]
# Episode * 104 * Avg Reward is ==> -165.575
# Episode * 105 *   adapt. coeffs at final time step:  [ 3.73 -2.7   1.29  1.15]
# Episode * 105 * Avg Reward is ==> -168.533
# Episode * 106 *   adapt. coeffs at final time step:  [ 3.63 -2.72  1.27  0.98]
# Episode * 106 * Avg Reward is ==> -174.487
# Episode * 107 *   adapt. coeffs at final time step:  [ 3.59 -2.58  1.24  0.96]
# Episode * 107 * Avg Reward is ==> -177.475
# Episode * 108 *   adapt. coeffs at final time step:  [ 3.71 -2.76  1.3   1.  ]
# Episode * 108 * Avg Reward is ==> -180.000
# Episode * 109 *   adapt. coeffs at final time step:  [ 3.6  -2.77  1.27  1.05]
# Episode * 109 * Avg Reward is ==> -174.170
# Episode * 110 *   adapt. coeffs at final time step:  [ 3.74 -2.78  1.31  0.93]
# median:  [ 3.6  -2.63  1.26  1.02]
# Episode * 110 * Avg Reward is ==> -174.169
# Episode * 111 *   adapt. coeffs at final time step:  [ 3.84 -2.95  1.36  1.31]
# Episode * 111 * Avg Reward is ==> -176.956
# Episode * 112 *   adapt. coeffs at final time step:  [ 3.69 -2.78  1.3   1.04]
# Episode * 112 * Avg Reward is ==> -171.550
# Episode * 113 *   adapt. coeffs at final time step:  [ 3.57 -2.63  1.24  1.07]
# Episode * 113 * Avg Reward is ==> -171.468
# Episode * 114 *   adapt. coeffs at final time step:  [ 3.83 -2.76  1.32  1.34]
# Episode * 114 * Avg Reward is ==> -171.642
# Episode * 115 *   adapt. coeffs at final time step:  [ 3.52 -2.47  1.2   1.07]
# Episode * 115 * Avg Reward is ==> -177.698
# Episode * 116 *   adapt. coeffs at final time step:  [ 3.55 -2.56  1.22  1.12]
# Episode * 116 * Avg Reward is ==> -177.677
# Episode * 117 *   adapt. coeffs at final time step:  [ 3.57 -2.49  1.21  1.11]
# Episode * 117 * Avg Reward is ==> -183.915
# Episode * 118 *   adapt. coeffs at final time step:  [ 3.72 -2.78  1.3   0.97]
# Episode * 118 * Avg Reward is ==> -186.323
# Episode * 119 *   adapt. coeffs at final time step:  [ 3.79 -2.89  1.34  1.39]
# Episode * 119 * Avg Reward is ==> -186.292
# Episode * 120 *   adapt. coeffs at final time step:  [ 3.43 -2.46  1.18  1.12]
# median:  [ 3.6  -2.63  1.26  1.02]
# Episode * 120 * Avg Reward is ==> -180.094
# Episode * 121 *   adapt. coeffs at final time step:  [ 3.51 -2.38  1.18  0.94]
# Episode * 121 * Avg Reward is ==> -179.894
# Episode * 122 *   adapt. coeffs at final time step:  [ 3.33 -2.25  1.12  1.01]
# Episode * 122 * Avg Reward is ==> -176.555
# Episode * 123 *   adapt. coeffs at final time step:  [ 3.34 -2.24  1.12  0.95]
# Episode * 123 * Avg Reward is ==> -176.618
# Episode * 124 *   adapt. coeffs at final time step:  [ 3.36 -2.29  1.13  1.1 ]
# Episode * 124 * Avg Reward is ==> -176.757
# Episode * 125 *   adapt. coeffs at final time step:  [ 3.43 -2.36  1.16  0.92]
# Episode * 125 * Avg Reward is ==> -174.032
# Episode * 126 *   adapt. coeffs at final time step:  [ 3.58 -2.56  1.23  1.18]
# Episode * 126 * Avg Reward is ==> -168.666
# Episode * 127 *   adapt. coeffs at final time step:  [ 3.88 -3.02  1.38  1.02]
# Episode * 127 * Avg Reward is ==> -169.130
# Episode * 128 *   adapt. coeffs at final time step:  [ 4.36 -3.63  1.6   1.51]
# Episode * 128 * Avg Reward is ==> -169.568
# Episode * 129 *   adapt. coeffs at final time step:  [ 4.09 -3.53  1.53  1.21]
# Episode * 129 * Avg Reward is ==> -166.496
# Episode * 130 *   adapt. coeffs at final time step:  [ 3.6  -2.66  1.25  1.47]
# median:  [ 3.59 -2.63  1.25  1.02]
# Episode * 130 * Avg Reward is ==> -166.581
# Episode * 131 *   adapt. coeffs at final time step:  [ 3.43 -2.32  1.15  0.98]
# Episode * 131 * Avg Reward is ==> -169.646
# Episode * 132 *   adapt. coeffs at final time step:  [ 3.46 -2.41  1.17  1.02]
# Episode * 132 * Avg Reward is ==> -166.569
# Episode * 133 *   adapt. coeffs at final time step:  [ 3.68 -2.77  1.29  0.95]
# Episode * 133 * Avg Reward is ==> -166.660
# Episode * 134 *   adapt. coeffs at final time step:  [ 3.76 -2.77  1.31  1.01]
# Episode * 134 * Avg Reward is ==> -164.048
# Episode * 135 *   adapt. coeffs at final time step:  [ 3.96 -3.02  1.4   1.02]
# Episode * 135 * Avg Reward is ==> -164.077
# Episode * 136 *   adapt. coeffs at final time step:  [ 3.99 -3.05  1.41  1.08]
# Episode * 136 * Avg Reward is ==> -157.976
# Episode * 137 *   adapt. coeffs at final time step:  [ 3.94 -3.14  1.42  1.03]
# Episode * 137 * Avg Reward is ==> -161.060
# Episode * 138 *   adapt. coeffs at final time step:  [ 3.77 -2.94  1.34  1.37]
# Episode * 138 * Avg Reward is ==> -164.390
# Episode * 139 *   adapt. coeffs at final time step:  [ 4.07 -3.16  1.45  1.29]
# Episode * 139 * Avg Reward is ==> -164.498
# Episode * 140 *   adapt. coeffs at final time step:  [ 4.32 -3.61  1.59  1.14]
# median:  [ 3.6  -2.66  1.26  1.02]
# Episode * 140 * Avg Reward is ==> -161.453
# Episode * 141 *   adapt. coeffs at final time step:  [ 4.4  -3.59  1.6   1.29]
# Episode * 141 * Avg Reward is ==> -158.320
# Episode * 142 *   adapt. coeffs at final time step:  [ 3.93 -3.55  1.5   1.3 ]
# Episode * 142 * Avg Reward is ==> -158.438
# Episode * 143 *   adapt. coeffs at final time step:  [ 4.02 -3.16  1.44  1.12]
# Episode * 143 * Avg Reward is ==> -158.674
# Episode * 144 *   adapt. coeffs at final time step:  [ 3.93 -3.13  1.41  1.22]
# Episode * 144 * Avg Reward is ==> -161.994
# Episode * 145 *   adapt. coeffs at final time step:  [ 4.17 -3.37  1.51  1.05]
# Episode * 145 * Avg Reward is ==> -162.149
# Episode * 146 *   adapt. coeffs at final time step:  [ 4.5  -3.66  1.63  1.13]
# Episode * 146 * Avg Reward is ==> -159.485
# Episode * 147 *   adapt. coeffs at final time step:  [ 4.63 -3.78  1.68  1.16]
# Episode * 147 * Avg Reward is ==> -159.648
# Episode * 148 *   adapt. coeffs at final time step:  [ 5.09 -4.38  1.9   1.16]
# Episode * 148 * Avg Reward is ==> -157.127
# Episode * 149 *   adapt. coeffs at final time step:  [ 4.51 -4.06  1.72  1.39]
# Episode * 149 * Avg Reward is ==> -156.717
# Episode * 150 *   adapt. coeffs at final time step:  [ 4.86 -4.24  1.82  0.99]
# median:  [ 3.63 -2.7   1.27  1.03]
# Episode * 150 * Avg Reward is ==> -162.116
# Episode * 151 *   adapt. coeffs at final time step:  [ 4.73 -3.98  1.74  1.31]
# Episode * 151 * Avg Reward is ==> -159.274
# Episode * 152 *   adapt. coeffs at final time step:  [ 4.29 -3.56  1.57  1.23]
# Episode * 152 * Avg Reward is ==> -159.548
# Episode * 153 *   adapt. coeffs at final time step:  [ 4.4  -3.78  1.64  1.1 ]
# Episode * 153 * Avg Reward is ==> -159.682
# Episode * 154 *   adapt. coeffs at final time step:  [ 4.66 -4.04  1.74  1.16]
# Episode * 154 * Avg Reward is ==> -162.451
# Episode * 155 *   adapt. coeffs at final time step:  [ 4.21 -3.41  1.52  1.6 ]
# Episode * 155 * Avg Reward is ==> -159.342
# Episode * 156 *   adapt. coeffs at final time step:  [ 3.5  -2.51  1.2   1.17]
# Episode * 156 * Avg Reward is ==> -162.223
# Episode * 157 *   adapt. coeffs at final time step:  [ 3.52 -2.41  1.19  0.93]
# Episode * 157 * Avg Reward is ==> -156.174
# Episode * 158 *   adapt. coeffs at final time step:  [ 3.74 -2.79  1.31  0.83]
# Episode * 158 * Avg Reward is ==> -150.693
# Episode * 159 *   adapt. coeffs at final time step:  [ 3.76 -2.87  1.33  0.97]
# Episode * 159 * Avg Reward is ==> -150.565
# Episode * 160 *   adapt. coeffs at final time step:  [ 3.45 -2.54  1.2   1.11]
# median:  [ 3.65 -2.72  1.27  1.04]
# Episode * 160 * Avg Reward is ==> -153.824
# Episode * 161 *   adapt. coeffs at final time step:  [ 3.86 -2.84  1.34  1.07]
# Episode * 161 * Avg Reward is ==> -150.816
# Episode * 162 *   adapt. coeffs at final time step:  [ 3.78 -2.91  1.34  0.97]
# Episode * 162 * Avg Reward is ==> -151.068
# Episode * 163 *   adapt. coeffs at final time step:  [ 3.5  -2.51  1.2   1.01]
# Episode * 163 * Avg Reward is ==> -147.918
# Episode * 164 *   adapt. coeffs at final time step:  [ 3.56 -2.54  1.22  0.96]
# Episode * 164 * Avg Reward is ==> -147.733
# Episode * 165 *   adapt. coeffs at final time step:  [ 3.38 -2.28  1.13  0.96]
# Episode * 165 * Avg Reward is ==> -144.500
# Episode * 166 *   adapt. coeffs at final time step:  [ 3.4  -2.31  1.14  0.88]
# Episode * 166 * Avg Reward is ==> -141.228
# Episode * 167 *   adapt. coeffs at final time step:  [ 3.36 -2.2   1.11  0.88]
# Episode * 167 * Avg Reward is ==> -138.025
# Episode * 168 *   adapt. coeffs at final time step:  [ 3.43 -2.2   1.13  0.96]
# Episode * 168 * Avg Reward is ==> -137.827
# Episode * 169 *   adapt. coeffs at final time step:  [ 3.27 -2.22  1.1   0.96]
# Episode * 169 * Avg Reward is ==> -140.988
# Episode * 170 *   adapt. coeffs at final time step:  [ 3.27 -2.14  1.08  0.99]
# median:  [ 3.62 -2.7   1.27  1.03]
# Episode * 170 * Avg Reward is ==> -140.823
# Episode * 171 *   adapt. coeffs at final time step:  [ 3.27 -2.16  1.09  0.99]
# Episode * 171 * Avg Reward is ==> -137.712
# Episode * 172 *   adapt. coeffs at final time step:  [ 3.26 -2.08  1.07  0.95]
# Episode * 172 * Avg Reward is ==> -137.513
# Episode * 173 *   adapt. coeffs at final time step:  [ 3.27 -2.03  1.06  0.91]
# Episode * 173 * Avg Reward is ==> -137.433
# Episode * 174 *   adapt. coeffs at final time step:  [ 3.24 -2.05  1.06  0.87]
# Episode * 174 * Avg Reward is ==> -134.286
# Episode * 175 *   adapt. coeffs at final time step:  [ 3.72 -2.71  1.29  0.91]
# Episode * 175 * Avg Reward is ==> -134.194
# Episode * 176 *   adapt. coeffs at final time step:  [ 3.32 -2.51  1.17  1.13]
# Episode * 176 * Avg Reward is ==> -137.257
# Episode * 177 *   adapt. coeffs at final time step:  [ 3.34 -2.39  1.15  1.13]
# Episode * 177 * Avg Reward is ==> -140.006
# Episode * 178 *   adapt. coeffs at final time step:  [ 3.31 -2.31  1.12  0.99]
# Episode * 178 * Avg Reward is ==> -142.803
# Episode * 179 *   adapt. coeffs at final time step:  [ 3.26 -2.21  1.09  1.  ]
# Episode * 179 * Avg Reward is ==> -139.615
# Episode * 180 *   adapt. coeffs at final time step:  [ 3.22 -2.21  1.09  1.01]
# median:  [ 3.6  -2.66  1.26  1.02]
# Episode * 180 * Avg Reward is ==> -136.550
# Episode * 181 *   adapt. coeffs at final time step:  [ 3.21 -2.2   1.08  0.98]
# Episode * 181 * Avg Reward is ==> -143.341
# Episode * 182 *   adapt. coeffs at final time step:  [ 3.25 -2.14  1.08  1.02]
# Episode * 182 * Avg Reward is ==> -143.692
# Episode * 183 *   adapt. coeffs at final time step:  [ 3.24 -2.11  1.07  1.  ]
# Episode * 183 * Avg Reward is ==> -146.196
# Episode * 184 *   adapt. coeffs at final time step:  [ 3.22 -2.12  1.07  0.97]
# Episode * 184 * Avg Reward is ==> -145.454
# Episode * 185 *   adapt. coeffs at final time step:  [ 3.21 -2.15  1.07  0.99]
# Episode * 185 * Avg Reward is ==> -145.202
# Episode * 186 *   adapt. coeffs at final time step:  [ 3.26 -2.31  1.11  1.08]
# Episode * 186 * Avg Reward is ==> -142.042
# Episode * 187 *   adapt. coeffs at final time step:  [ 3.3  -2.31  1.12  0.96]
# Episode * 187 * Avg Reward is ==> -141.893
# Episode * 188 *   adapt. coeffs at final time step:  [ 3.25 -2.21  1.09  1.  ]
# Episode * 188 * Avg Reward is ==> -144.806
# Episode * 189 *   adapt. coeffs at final time step:  [ 3.22 -2.2   1.09  1.07]
# Episode * 189 * Avg Reward is ==> -148.150
# Episode * 190 *   adapt. coeffs at final time step:  [ 3.17 -2.16  1.07  1.  ]
# median:  [ 3.58 -2.62  1.24  1.02]
# Episode * 190 * Avg Reward is ==> -142.717
# Episode * 191 *   adapt. coeffs at final time step:  [ 3.18 -2.12  1.06  0.98]
# Episode * 191 * Avg Reward is ==> -142.608
# Episode * 192 *   adapt. coeffs at final time step:  [ 3.31 -2.32  1.13  0.92]
# Episode * 192 * Avg Reward is ==> -145.515
# Episode * 193 *   adapt. coeffs at final time step:  [ 3.23 -2.2   1.09  0.99]
# Episode * 193 * Avg Reward is ==> -148.284
# Episode * 194 *   adapt. coeffs at final time step:  [ 3.26 -2.22  1.1   1.02]
# Episode * 194 * Avg Reward is ==> -145.486
# Episode * 195 *   adapt. coeffs at final time step:  [ 3.2  -2.15  1.07  0.99]
# Episode * 195 * Avg Reward is ==> -148.634
# Episode * 196 *   adapt. coeffs at final time step:  [ 3.14 -2.14  1.06  0.98]
# Episode * 196 * Avg Reward is ==> -142.873
# Episode * 197 *   adapt. coeffs at final time step:  [ 3.36 -2.35  1.14  0.99]
# Episode * 197 * Avg Reward is ==> -146.045
# Episode * 198 *   adapt. coeffs at final time step:  [ 3.3  -2.31  1.12  0.92]
# Episode * 198 * Avg Reward is ==> -148.787
# Episode * 199 *   adapt. coeffs at final time step:  [ 3.26 -2.15  1.08  1.  ]
# Episode * 199 * Avg Reward is ==> -151.388

# %%
print((np.array(ploting_adapt_coeff)).mean(axis=0).round(2))
print(np.median(np.array(ploting_adapt_coeff), axis=0))
# Out:
# [ 3.76 -2.82  1.32  1.06]
# [ 3.575 -2.595  1.24   1.02 ]

# %%
total_episodes_test = 100
ep_reward_list_test = []
#avg_reward_list_test = []
best_score = -1600

# %%
# Takes about 4 min to train
print('Test')
for ep in range(total_episodes_test):
    prev_state = env.reset()
    if ep == total_episodes_test - 1:
      env.state = np.array([3.14,0])
      prev_state=env._get_obs()
    save_observation_temp = [prev_state]
    save_wanted_torque_temp = [0.0]
    save_actual_torque_temp = [0.0]
    save_model_torque_temp = [0.0]
    save_ctrl_voltage_temp = [0.0]
    save_MRAC_adapt_gains_temp= [env.MRAC.k_hat]
    episodic_reward = 0

    while True:
        # Uncomment this to see the Actor in action
        # But not in a python notebook.
        # env.render()
        k_hat_print = env.MRAC.k_hat.round(2)
        tf_prev_state = tf.expand_dims(tf.convert_to_tensor(prev_state), 0)

        action = policy(tf_prev_state, ou_noise)

        # Recieve state and reward from environment.
        state, reward, done, info , wanted_torque , actual_torque = env.step(action)
        save_observation_temp.append(state)
        save_wanted_torque_temp.append(wanted_torque)
        save_actual_torque_temp.append(actual_torque)
        save_model_torque_temp.append(env.MRAC.y_m)
        save_ctrl_voltage_temp.append(env.MRAC.u)
        save_MRAC_adapt_gains_temp.append(env.MRAC.k_hat)

        episodic_reward += reward

        # End this episode when `done` is True
        if done:
            break

        prev_state = state
    ep_reward_list_test.append(episodic_reward)

    # Mean of last 10 episodes
    avg_reward = np.mean(ep_reward_list_test[-10:])
    print("Episode * {} * Acc Reward is ==> {} (last 10 ep AVG: {})".format(ep, f"{episodic_reward:.3f}" ,f"{avg_reward:.3f}"))
    print(f"Episode * {ep} * "," adapt. coeffs at final time step: ", k_hat_print)
    if best_score<episodic_reward:
    #if ep == total_episodes_test - 1:
      save_observation = list(save_observation_temp)
      save_wanted_torque = list(save_wanted_torque_temp)
      save_actual_torque = list(save_actual_torque_temp)
      save_model_torque = list(save_model_torque_temp)
      save_ctrl_voltage = list(save_ctrl_voltage_temp)
      save_MRAC_adapt_gains = list(save_MRAC_adapt_gains_temp)
      best_score = episodic_reward
    #avg_reward_list_test.append(avg_reward)
# Out:
# Test
# Episode * 0 * Acc Reward is ==> -263.147 (last 10 ep AVG: -263.147)
# Episode * 0 *   adapt. coeffs at final time step:  [ 3.67 -2.66  1.27  1.09]
# Episode * 1 * Acc Reward is ==> -125.498 (last 10 ep AVG: -194.323)
# Episode * 1 *   adapt. coeffs at final time step:  [ 3.48 -2.68  1.23  0.94]
# Episode * 2 * Acc Reward is ==> -130.294 (last 10 ep AVG: -172.980)
# Episode * 2 *   adapt. coeffs at final time step:  [ 3.74 -2.83  1.31  0.94]
# Episode * 3 * Acc Reward is ==> -1.072 (last 10 ep AVG: -130.003)
# Episode * 3 *   adapt. coeffs at final time step:  [ 3.79 -2.78  1.32  0.97]
# Episode * 4 * Acc Reward is ==> -2.124 (last 10 ep AVG: -104.427)
# Episode * 4 *   adapt. coeffs at final time step:  [ 3.67 -2.79  1.29  0.97]
# Episode * 5 * Acc Reward is ==> -126.857 (last 10 ep AVG: -108.165)
# Episode * 5 *   adapt. coeffs at final time step:  [ 4.1  -3.21  1.46  1.03]
# Episode * 6 * Acc Reward is ==> -128.411 (last 10 ep AVG: -111.058)
# Episode * 6 *   adapt. coeffs at final time step:  [ 3.78 -2.82  1.32  0.95]
# Episode * 7 * Acc Reward is ==> -128.286 (last 10 ep AVG: -113.211)
# Episode * 7 *   adapt. coeffs at final time step:  [ 3.81 -2.9   1.34  0.99]
# Episode * 8 * Acc Reward is ==> -125.290 (last 10 ep AVG: -114.553)
# Episode * 8 *   adapt. coeffs at final time step:  [ 3.85 -2.89  1.35  1.08]
# Episode * 9 * Acc Reward is ==> -122.724 (last 10 ep AVG: -115.370)
# Episode * 9 *   adapt. coeffs at final time step:  [ 3.84 -2.9   1.35  0.97]
# Episode * 10 * Acc Reward is ==> -117.951 (last 10 ep AVG: -100.851)
# Episode * 10 *   adapt. coeffs at final time step:  [ 3.75 -2.76  1.3   1.12]
# Episode * 11 * Acc Reward is ==> -116.730 (last 10 ep AVG: -99.974)
# Episode * 11 *   adapt. coeffs at final time step:  [ 3.45 -2.37  1.16  1.09]
# Episode * 12 * Acc Reward is ==> -388.062 (last 10 ep AVG: -125.751)
# Episode * 12 *   adapt. coeffs at final time step:  [ 3.33 -2.18  1.1   0.97]
# Episode * 13 * Acc Reward is ==> -256.197 (last 10 ep AVG: -151.263)
# Episode * 13 *   adapt. coeffs at final time step:  [ 3.38 -2.22  1.12  1.02]
# Episode * 14 * Acc Reward is ==> -251.910 (last 10 ep AVG: -176.242)
# Episode * 14 *   adapt. coeffs at final time step:  [ 3.59 -2.56  1.23  0.95]
# Episode * 15 * Acc Reward is ==> -226.408 (last 10 ep AVG: -186.197)
# Episode * 15 *   adapt. coeffs at final time step:  [ 3.81 -2.79  1.32  0.94]
# Episode * 16 * Acc Reward is ==> -356.103 (last 10 ep AVG: -208.966)
# Episode * 16 *   adapt. coeffs at final time step:  [ 3.64 -3.    1.33  1.06]
# Episode * 17 * Acc Reward is ==> -258.571 (last 10 ep AVG: -221.995)
# Episode * 17 *   adapt. coeffs at final time step:  [ 3.77 -2.81  1.32  1.  ]
# Episode * 18 * Acc Reward is ==> -1.335 (last 10 ep AVG: -209.599)
# Episode * 18 *   adapt. coeffs at final time step:  [ 3.68 -2.67  1.27  1.04]
# Episode * 19 * Acc Reward is ==> -1.405 (last 10 ep AVG: -197.467)
# Episode * 19 *   adapt. coeffs at final time step:  [ 3.82 -2.84  1.33  0.98]
# Episode * 20 * Acc Reward is ==> -2.784 (last 10 ep AVG: -185.950)
# Episode * 20 *   adapt. coeffs at final time step:  [ 3.87 -2.88  1.35  0.96]
# Episode * 21 * Acc Reward is ==> -248.784 (last 10 ep AVG: -199.156)
# Episode * 21 *   adapt. coeffs at final time step:  [ 3.72 -2.81  1.31  0.98]
# Episode * 22 * Acc Reward is ==> -130.192 (last 10 ep AVG: -173.369)
# Episode * 22 *   adapt. coeffs at final time step:  [ 3.48 -2.47  1.19  1.01]
# Episode * 23 * Acc Reward is ==> -252.268 (last 10 ep AVG: -172.976)
# Episode * 23 *   adapt. coeffs at final time step:  [ 3.55 -2.43  1.2   0.93]
# Episode * 24 * Acc Reward is ==> -118.500 (last 10 ep AVG: -159.635)
# Episode * 24 *   adapt. coeffs at final time step:  [ 3.57 -2.64  1.24  1.05]
# Episode * 25 * Acc Reward is ==> -127.637 (last 10 ep AVG: -149.758)
# Episode * 25 *   adapt. coeffs at final time step:  [ 3.68 -2.66  1.27  1.03]
# Episode * 26 * Acc Reward is ==> -1.486 (last 10 ep AVG: -114.296)
# Episode * 26 *   adapt. coeffs at final time step:  [ 3.82 -2.83  1.33  0.97]
# Episode * 27 * Acc Reward is ==> -127.532 (last 10 ep AVG: -101.192)
# Episode * 27 *   adapt. coeffs at final time step:  [ 3.85 -3.12  1.39  1.04]
# Episode * 28 * Acc Reward is ==> -122.569 (last 10 ep AVG: -113.316)
# Episode * 28 *   adapt. coeffs at final time step:  [ 3.77 -2.8   1.31  1.04]
# Episode * 29 * Acc Reward is ==> -232.166 (last 10 ep AVG: -136.392)
# Episode * 29 *   adapt. coeffs at final time step:  [ 3.81 -2.96  1.36  1.16]
# Episode * 30 * Acc Reward is ==> -127.050 (last 10 ep AVG: -148.818)
# Episode * 30 *   adapt. coeffs at final time step:  [ 3.79 -2.97  1.35  1.11]
# Episode * 31 * Acc Reward is ==> -121.642 (last 10 ep AVG: -136.104)
# Episode * 31 *   adapt. coeffs at final time step:  [ 3.69 -2.76  1.29  1.23]
# Episode * 32 * Acc Reward is ==> -258.832 (last 10 ep AVG: -148.968)
# Episode * 32 *   adapt. coeffs at final time step:  [ 4.   -3.23  1.45  0.96]
# Episode * 33 * Acc Reward is ==> -116.973 (last 10 ep AVG: -135.439)
# Episode * 33 *   adapt. coeffs at final time step:  [ 3.86 -3.41  1.45  1.28]
# Episode * 34 * Acc Reward is ==> -241.362 (last 10 ep AVG: -147.725)
# Episode * 34 *   adapt. coeffs at final time step:  [ 3.91 -3.02  1.39  1.26]
# Episode * 35 * Acc Reward is ==> -128.174 (last 10 ep AVG: -147.779)
# Episode * 35 *   adapt. coeffs at final time step:  [ 3.66 -2.96  1.33  1.2 ]
# Episode * 36 * Acc Reward is ==> -126.278 (last 10 ep AVG: -160.258)
# Episode * 36 *   adapt. coeffs at final time step:  [ 3.5  -2.47  1.2   0.98]
# Episode * 37 * Acc Reward is ==> -243.792 (last 10 ep AVG: -171.884)
# Episode * 37 *   adapt. coeffs at final time step:  [ 3.53 -2.54  1.21  0.98]
# Episode * 38 * Acc Reward is ==> -1.481 (last 10 ep AVG: -159.775)
# Episode * 38 *   adapt. coeffs at final time step:  [ 3.66 -2.64  1.26  0.93]
# Episode * 39 * Acc Reward is ==> -121.528 (last 10 ep AVG: -148.711)
# Episode * 39 *   adapt. coeffs at final time step:  [ 3.82 -2.8   1.33  0.98]
# Episode * 40 * Acc Reward is ==> -2.310 (last 10 ep AVG: -136.237)
# Episode * 40 *   adapt. coeffs at final time step:  [ 3.9  -3.04  1.39  0.99]
# Episode * 41 * Acc Reward is ==> -128.421 (last 10 ep AVG: -136.915)
# Episode * 41 *   adapt. coeffs at final time step:  [ 3.56 -2.52  1.22  0.97]
# Episode * 42 * Acc Reward is ==> -120.496 (last 10 ep AVG: -123.082)
# Episode * 42 *   adapt. coeffs at final time step:  [ 3.52 -2.49  1.2   0.96]
# Episode * 43 * Acc Reward is ==> -367.812 (last 10 ep AVG: -148.165)
# Episode * 43 *   adapt. coeffs at final time step:  [ 3.46 -2.4   1.17  0.99]
# Episode * 44 * Acc Reward is ==> -0.761 (last 10 ep AVG: -124.105)
# Episode * 44 *   adapt. coeffs at final time step:  [ 3.46 -2.4   1.17  0.93]
# Episode * 45 * Acc Reward is ==> -122.370 (last 10 ep AVG: -123.525)
# Episode * 45 *   adapt. coeffs at final time step:  [ 3.65 -2.7   1.27  0.92]
# Episode * 46 * Acc Reward is ==> -125.679 (last 10 ep AVG: -123.465)
# Episode * 46 *   adapt. coeffs at final time step:  [ 4.02 -3.23  1.45  0.91]
# Episode * 47 * Acc Reward is ==> -240.669 (last 10 ep AVG: -123.153)
# Episode * 47 *   adapt. coeffs at final time step:  [ 3.82 -2.98  1.36  1.03]
# Episode * 48 * Acc Reward is ==> -126.295 (last 10 ep AVG: -135.634)
# Episode * 48 *   adapt. coeffs at final time step:  [ 3.7  -2.7   1.28  0.95]
# Episode * 49 * Acc Reward is ==> -1.382 (last 10 ep AVG: -123.620)
# Episode * 49 *   adapt. coeffs at final time step:  [ 3.7  -2.69  1.28  0.93]
# Episode * 50 * Acc Reward is ==> -126.393 (last 10 ep AVG: -136.028)
# Episode * 50 *   adapt. coeffs at final time step:  [ 3.43 -2.35  1.16  1.02]
# Episode * 51 * Acc Reward is ==> -299.207 (last 10 ep AVG: -153.106)
# Episode * 51 *   adapt. coeffs at final time step:  [ 3.39 -2.31  1.14  0.95]
# Episode * 52 * Acc Reward is ==> -129.575 (last 10 ep AVG: -154.014)
# Episode * 52 *   adapt. coeffs at final time step:  [ 3.4  -2.35  1.15  0.98]
# Episode * 53 * Acc Reward is ==> -366.012 (last 10 ep AVG: -153.834)
# Episode * 53 *   adapt. coeffs at final time step:  [ 3.44 -2.38  1.16  0.97]
# Episode * 54 * Acc Reward is ==> -131.829 (last 10 ep AVG: -166.941)
# Episode * 54 *   adapt. coeffs at final time step:  [ 3.45 -2.48  1.19  1.02]
# Episode * 55 * Acc Reward is ==> -350.360 (last 10 ep AVG: -189.740)
# Episode * 55 *   adapt. coeffs at final time step:  [ 3.35 -2.24  1.12  0.98]
# Episode * 56 * Acc Reward is ==> -122.332 (last 10 ep AVG: -189.405)
# Episode * 56 *   adapt. coeffs at final time step:  [ 3.87 -2.94  1.36  0.83]
# Episode * 57 * Acc Reward is ==> -118.018 (last 10 ep AVG: -177.140)
# Episode * 57 *   adapt. coeffs at final time step:  [ 3.97 -3.18  1.43  0.98]
# Episode * 58 * Acc Reward is ==> -260.332 (last 10 ep AVG: -190.544)
# Episode * 58 *   adapt. coeffs at final time step:  [ 3.9  -2.94  1.37  1.05]
# Episode * 59 * Acc Reward is ==> -1.301 (last 10 ep AVG: -190.536)
# Episode * 59 *   adapt. coeffs at final time step:  [ 3.97 -3.03  1.4   1.04]
# Episode * 60 * Acc Reward is ==> -255.134 (last 10 ep AVG: -203.410)
# Episode * 60 *   adapt. coeffs at final time step:  [ 3.91 -3.09  1.4   0.97]
# Episode * 61 * Acc Reward is ==> -1.071 (last 10 ep AVG: -173.596)
# Episode * 61 *   adapt. coeffs at final time step:  [ 3.67 -2.76  1.29  1.02]
# Episode * 62 * Acc Reward is ==> -125.503 (last 10 ep AVG: -173.189)
# Episode * 62 *   adapt. coeffs at final time step:  [ 3.6  -2.53  1.23  1.03]
# Episode * 63 * Acc Reward is ==> -244.460 (last 10 ep AVG: -161.034)
# Episode * 63 *   adapt. coeffs at final time step:  [ 3.46 -2.38  1.17  0.98]
# Episode * 64 * Acc Reward is ==> -237.007 (last 10 ep AVG: -171.552)
# Episode * 64 *   adapt. coeffs at final time step:  [ 3.46 -2.35  1.16  0.96]
# Episode * 65 * Acc Reward is ==> -126.537 (last 10 ep AVG: -149.170)
# Episode * 65 *   adapt. coeffs at final time step:  [ 3.37 -2.23  1.12  0.98]
# Episode * 66 * Acc Reward is ==> -0.818 (last 10 ep AVG: -137.018)
# Episode * 66 *   adapt. coeffs at final time step:  [ 3.42 -2.32  1.15  0.89]
# Episode * 67 * Acc Reward is ==> -126.298 (last 10 ep AVG: -137.846)
# Episode * 67 *   adapt. coeffs at final time step:  [ 3.58 -2.87  1.29  0.97]
# Episode * 68 * Acc Reward is ==> -1.254 (last 10 ep AVG: -111.938)
# Episode * 68 *   adapt. coeffs at final time step:  [ 3.84 -2.87  1.34  0.94]
# Episode * 69 * Acc Reward is ==> -246.847 (last 10 ep AVG: -136.493)
# Episode * 69 *   adapt. coeffs at final time step:  [ 3.89 -2.95  1.37  1.12]
# Episode * 70 * Acc Reward is ==> -353.184 (last 10 ep AVG: -146.298)
# Episode * 70 *   adapt. coeffs at final time step:  [ 3.71 -2.93  1.33  0.97]
# Episode * 71 * Acc Reward is ==> -122.375 (last 10 ep AVG: -158.428)
# Episode * 71 *   adapt. coeffs at final time step:  [ 3.78 -2.87  1.33  1.11]
# Episode * 72 * Acc Reward is ==> -124.836 (last 10 ep AVG: -158.362)
# Episode * 72 *   adapt. coeffs at final time step:  [ 3.93 -3.    1.39  0.92]
# Episode * 73 * Acc Reward is ==> -1.526 (last 10 ep AVG: -134.068)
# Episode * 73 *   adapt. coeffs at final time step:  [ 3.92 -2.96  1.38  0.95]
# Episode * 74 * Acc Reward is ==> -1.196 (last 10 ep AVG: -110.487)
# Episode * 74 *   adapt. coeffs at final time step:  [ 3.95 -3.07  1.4   1.  ]
# Episode * 75 * Acc Reward is ==> -252.745 (last 10 ep AVG: -123.108)
# Episode * 75 *   adapt. coeffs at final time step:  [ 3.93 -3.13  1.41  0.97]
# Episode * 76 * Acc Reward is ==> -126.969 (last 10 ep AVG: -135.723)
# Episode * 76 *   adapt. coeffs at final time step:  [ 4.03 -3.22  1.45  1.04]
# Episode * 77 * Acc Reward is ==> -119.524 (last 10 ep AVG: -135.046)
# Episode * 77 *   adapt. coeffs at final time step:  [ 3.67 -2.63  1.26  1.13]
# Episode * 78 * Acc Reward is ==> -2.672 (last 10 ep AVG: -135.188)
# Episode * 78 *   adapt. coeffs at final time step:  [ 3.82 -2.84  1.33  1.07]
# Episode * 79 * Acc Reward is ==> -124.687 (last 10 ep AVG: -122.972)
# Episode * 79 *   adapt. coeffs at final time step:  [ 3.74 -3.01  1.35  1.05]
# Episode * 80 * Acc Reward is ==> -250.615 (last 10 ep AVG: -112.715)
# Episode * 80 *   adapt. coeffs at final time step:  [ 3.67 -2.76  1.28  1.03]
# Episode * 81 * Acc Reward is ==> -0.941 (last 10 ep AVG: -100.571)
# Episode * 81 *   adapt. coeffs at final time step:  [ 3.57 -2.63  1.24  1.03]
# Episode * 82 * Acc Reward is ==> -0.983 (last 10 ep AVG: -88.186)
# Episode * 82 *   adapt. coeffs at final time step:  [ 3.51 -2.71  1.24  1.  ]
# Episode * 83 * Acc Reward is ==> -122.265 (last 10 ep AVG: -100.260)
# Episode * 83 *   adapt. coeffs at final time step:  [ 3.55 -2.78  1.27  1.02]
# Episode * 84 * Acc Reward is ==> -0.960 (last 10 ep AVG: -100.236)
# Episode * 84 *   adapt. coeffs at final time step:  [ 3.66 -2.71  1.27  1.01]
# Episode * 85 * Acc Reward is ==> -248.316 (last 10 ep AVG: -99.793)
# Episode * 85 *   adapt. coeffs at final time step:  [ 3.76 -2.72  1.3   1.03]
# Episode * 86 * Acc Reward is ==> -1.183 (last 10 ep AVG: -87.215)
# Episode * 86 *   adapt. coeffs at final time step:  [ 4.09 -3.38  1.5   0.98]
# Episode * 87 * Acc Reward is ==> -3.616 (last 10 ep AVG: -75.624)
# Episode * 87 *   adapt. coeffs at final time step:  [ 4.03 -3.13  1.43  1.02]
# Episode * 88 * Acc Reward is ==> -1.690 (last 10 ep AVG: -75.526)
# Episode * 88 *   adapt. coeffs at final time step:  [ 3.92 -3.22  1.43  1.05]
# Episode * 89 * Acc Reward is ==> -0.779 (last 10 ep AVG: -63.135)
# Episode * 89 *   adapt. coeffs at final time step:  [ 3.47 -2.42  1.18  1.18]
# Episode * 90 * Acc Reward is ==> -124.518 (last 10 ep AVG: -50.525)
# Episode * 90 *   adapt. coeffs at final time step:  [ 3.41 -2.33  1.15  1.01]
# Episode * 91 * Acc Reward is ==> -250.964 (last 10 ep AVG: -75.527)
# Episode * 91 *   adapt. coeffs at final time step:  [ 3.77 -2.79  1.31  0.88]
# Episode * 92 * Acc Reward is ==> -126.789 (last 10 ep AVG: -88.108)
# Episode * 92 *   adapt. coeffs at final time step:  [ 3.52 -2.48  1.2   1.03]
# Episode * 93 * Acc Reward is ==> -119.787 (last 10 ep AVG: -87.860)
# Episode * 93 *   adapt. coeffs at final time step:  [ 3.51 -2.43  1.19  0.95]
# Episode * 94 * Acc Reward is ==> -119.714 (last 10 ep AVG: -99.736)
# Episode * 94 *   adapt. coeffs at final time step:  [ 3.93 -2.96  1.38  1.02]
# Episode * 95 * Acc Reward is ==> -123.476 (last 10 ep AVG: -87.252)
# Episode * 95 *   adapt. coeffs at final time step:  [ 3.56 -2.67  1.25  1.06]
# Episode * 96 * Acc Reward is ==> -128.160 (last 10 ep AVG: -99.949)
# Episode * 96 *   adapt. coeffs at final time step:  [ 3.56 -2.48  1.21  0.99]
# Episode * 97 * Acc Reward is ==> -128.140 (last 10 ep AVG: -112.402)
# Episode * 97 *   adapt. coeffs at final time step:  [ 3.65 -2.59  1.25  0.95]
# Episode * 98 * Acc Reward is ==> -127.604 (last 10 ep AVG: -124.993)
# Episode * 98 *   adapt. coeffs at final time step:  [ 3.98 -3.06  1.41  0.89]
# Episode * 99 * Acc Reward is ==> -248.662 (last 10 ep AVG: -149.781)
# Episode * 99 *   adapt. coeffs at final time step:  [ 3.71 -2.78  1.3   1.09]

# %%
save_observation_temp = None
save_wanted_torque_temp = None
save_actual_torque_temp = None
save_model_torque_temp = None
save_ctrl_voltage_temp = None
save_MRAC_adapt_gains_temp= None

# %%
# Create a dictionary of variables you want to save

variables_to_save = {
    'ep_reward_list': ep_reward_list,
    'avg_reward_list': avg_reward_list,
    'save_observation': save_observation,
    'save_wanted_torque': save_wanted_torque,
    'save_actual_torque': save_actual_torque,
    'save_model_torque': save_model_torque,
    'save_ctrl_voltage': save_ctrl_voltage,
    'ep_reward_list_test':ep_reward_list_test,
    'save_MRAC_adapt_gains': save_MRAC_adapt_gains,
    'ploting_adapt_coeff': ploting_adapt_coeff
}

# %%
path_ = '/content/drive/MyDrive/Colab Notebooks/codes/MRAC/save_data/Pendulum/'

# %%
# Save the weights
actor_model.save_weights(path_+"pendulum_actor.weights.h5")
critic_model.save_weights(path_+"pendulum_critic.weights.h5")

target_actor.save_weights(path_+"pendulum_target_actor.weights.h5")
target_critic.save_weights(path_+"pendulum_target_critic.weights.h5")

# %%
with open(path_+'Pendulum.pkl', 'wb') as f:
    pickle.dump(variables_to_save, f)
print(f"All variables saved to {path_+'Pendulum.pkl'}")
# Out:
# All variables saved to /content/drive/MyDrive/Colab Notebooks/codes/MRAC/save_data/Pendulum/Pendulum.pkl

# %%
# Define the file path
path_ = '/content/drive/MyDrive/Colab Notebooks/codes/MRAC/save_data/Pendulum/'

# %%
actor_model = get_actor()
critic_model = get_critic()
target_actor = get_actor()
target_critic = get_critic()

# %%
actor_model.load_weights(path_+"pendulum_actor.weights.h5")
critic_model.load_weights(path_+"pendulum_critic.weights.h5")
target_actor.load_weights(path_+"pendulum_target_actor.weights.h5")
target_critic.load_weights(path_+"pendulum_target_critic.weights.h5")

# %%
# Open the file in read-binary mode and load the dictionary
with open(path_+'Pendulum.pkl', 'rb') as f:
    loaded_variables = pickle.load(f)

# Access the loaded variables
ep_reward_list = loaded_variables['ep_reward_list']
avg_reward_list = loaded_variables['avg_reward_list']
save_observation = loaded_variables['save_observation']
save_wanted_torque = loaded_variables['save_wanted_torque']
save_actual_torque = loaded_variables['save_actual_torque']
save_model_torque = loaded_variables['save_model_torque']
save_ctrl_voltage = loaded_variables['save_ctrl_voltage']
ep_reward_list_test=loaded_variables['ep_reward_list_test']
save_MRAC_adapt_gains = loaded_variables['save_MRAC_adapt_gains']
ploting_adapt_coeff = loaded_variables['ploting_adapt_coeff']

# %%
plt.rc('text.latex', preamble=r'\usepackage{amsmath,amssymb,amsfonts}')
#plt.rcParams["text.usetex"]=False
#plt.rcParams["font.family"] = "sans-serif"
#plt.rcParams["font.family"] = "serif"
#plt.rcParams['mathtext.fontset'] = 'cm'
#plt.rcParams['mathtext.fontset'] = 'dejavusans'
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'

# %%
def unnorm_to_norm(x):
  y = (x-low_bound_reward_list)/(up_bound_reward_list-low_bound_reward_list)
  return y

# %%
def norm_to_unnorm(y):
  x=y*(up_bound_reward_list-low_bound_reward_list)+low_bound_reward_list
  return x

# %%
norm_reward_list = np.array(avg_reward_list)
low_bound_reward_list = -3254.72 #=-(pi**2 + 0.1 * 8**2 + 0.001 * 2**2)*(200 time step) #norm_reward_list.min()
up_bound_reward_list=0
print("low_bound_reward_list=",low_bound_reward_list)
print("up_bound_reward_list=",up_bound_reward_list)
#norm_reward_list = (norm_reward_list-min_norm_reward_list)/(max_norm_reward_list-min_norm_reward_list)
norm_reward_list = unnorm_to_norm(norm_reward_list)
# Out:
# low_bound_reward_list= -3254.72
# up_bound_reward_list= 0

# %%
# Plotting graph
# Episodes versus Avg. Rewards
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(6)
f.set_figheight(4)
plt.plot(avg_reward_list, label = "Avg. Epsiodic Reward",color="C0",linewidth = 1.5)
plt.axhline(y=np.array(avg_reward_list)[-20:-1].mean(), linestyle='--',
            label = "Avg. Epsiodic Reward's last 20 mean= "+f"{np.array(avg_reward_list)[-20:-1].mean():.1f}",color="C1",linewidth = 2.5)
plt.xlabel("Episode")
plt.ylabel("Avg. Epsiodic Reward")
plt.title('Pendulum',fontsize=20)
plt.grid()
plt.legend(fontsize=11)
plt.show()

# %%
# Episodes versus Norm Acc. Ep. Rewards

font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2.0)
f.set_figheight(1.2)
plt.plot(norm_reward_list, label = "Normalized Acc.\n Epi. Reward",color="C0",linewidth = 1.5)
#plt.axhline(y=norm_reward_list[-20:-1].mean(), linestyle='--',
#            label = "Normalized Acc. Episodic Reward's last 20 mean= "+f"{norm_reward_list[-20:-1].mean():.1f}",color="C1",linewidth = 2.5)
plt.xlabel("Training Episode")
plt.ylabel("Normalized Acc.\nEpi. Reward")
#plt.grid()
#plt.legend()
plt.minorticks_on()
plt.xticks(np.arange(0, len(norm_reward_list)+1, 50))
#plt.yticks(np.arange(0.0, 1.0, 0.1))
plt.savefig(path_+"Pendulum_Acc_Reward_vs_Episode.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print("Normalized Acc. Epsiodic Reward's last 20 mean=")
print(norm_reward_list[-20:-1].mean())
# Out:
# Normalized Acc. Epsiodic Reward's last 20 mean=
# 0.9555580745090536

# %%
font = {'size': 20}
plt.rc('font', **font)
plt.plot(ploting_adapt_coeff)
plt.xlabel("Training episodes")
plt.ylabel("Adaptaion control gains\n at last time step")
#plt.rc('axes', labelsize=30)

plt.title('Pendulum',fontsize=20)
plt.grid()
plt.legend(labels=[r"$\hat{k_r}$=coeff of $a^{wanted}$",
                   r"$\hat{k}_y$=coeff of $a^{actual}$",
                 r"$\hat{k}_{r-y}$=coeff of $(a^{wanted}-a^{actual})$",
                 r"$\hat{k}_\omega$=coeff of $\dot{\theta}$"], fontsize=10
           , bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2010: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   p.space          = oneOf(self._space_widths)("space")
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2020: PyparsingDeprecationWarning: 'leaveWhitespace' deprecated - use 'leave_whitespace'
#   )("sym").leaveWhitespace()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:1984: PyparsingDeprecationWarning: 'setName' deprecated - use 'set_name'
#   val.setName(key)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:1987: PyparsingDeprecationWarning: 'setParseAction' deprecated - use 'set_parse_action'
#   val.setParseAction(getattr(self, key))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2088: PyparsingDeprecationWarning: 'endQuoteChar' argument is deprecated, use 'end_quote_char'
#   p.text = cmd(r"\text", QuotedString('{', '\\', endQuoteChar="}"))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2146: PyparsingDeprecationWarning: 'unquoteResults' argument is deprecated, use 'unquote_results'
#   p.math_string   = QuotedString('$', '\\', unquoteResults=False)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()

# %%
N=10
# Compute the moving average of the last 50 numbers
moving_average = []
for i, n in enumerate(ploting_adapt_coeff):
    if i < N:
        # If there are not enough previous elements,
        # append the average of all available elements
        avg = sum(ploting_adapt_coeff[:i+1]) / (i+1)
    else:
        # Otherwise, compute the average of the previous 5 elements
        avg = sum(ploting_adapt_coeff[i-N:i+1]) / N
    moving_average.append(avg)
moving_average = np.array(moving_average).T
# Plot the moving average
#f"→{moving_average[0,-20:-1].mean()"
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(6)
f.set_figheight(4)
plt.plot(moving_average[0]
         ,label = r"$\hat{k_r}$=coeff of $a^{desired}$"+f"→{moving_average[0,-5:-1].mean():.1e}",color="C0",linewidth = 2)
plt.plot(moving_average[1],'--',
         label = r"$\hat{k}_y$=coeff of $a^{actual}$ "+f"→{moving_average[1,-5:-1].mean():.1e}",color="C1",linewidth = 3)
plt.plot(moving_average[2],':',
         label = r"$\hat{k}_{r-y}$=coeff of $(a^{desired}-a^{actual})$"+f"→{moving_average[2,-5:-1].mean():.1e}",
         color="C2",linewidth = 4)
plt.plot(moving_average[3],'-.',
         label = r"$\hat{k}_\omega$=coeff of $\dot{\theta}$"+f"→{moving_average[3,-5:-1].mean():.1e}"
         ,color="C3",linewidth = 2)
#plt.plot(moving_average)
plt.xlabel("Training episodes")
plt.ylabel("Adaptation control gains\n at last time step")
plt.title('Pendulum',fontsize=20)
#plt.ylim(-24,8)
plt.grid()
plt.legend(fontsize=13, bbox_to_anchor=(0.5, 0.3), loc='center')
#plt.legend(fontsize=12, bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %%
# Test Histogram
norm_ep_reward_list_test = np.array(ep_reward_list_test)
norm_ep_reward_list_test = unnorm_to_norm(norm_ep_reward_list_test)

# %%
font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(1.1)
f.set_figheight(1.1)
data_rewards = np.array(norm_ep_reward_list_test)
density_True = True
#bins_norm = unnorm_to_norm(np.arange(-680,0,85))
plt.hist(data_rewards, bins=np.arange(0,1.01,0.02), density=density_True ,color='skyblue', edgecolor='black')
plt.xlabel('Normalized Acc.\nEpi. Reward')
ylabel='Density'if density_True else 'Frequency'
plt.ylabel(ylabel)
plt.xticks(np.arange(0.8,1.01,0.1))
plt.minorticks_on()
plt.xlim((0.80,1.01))
plt.savefig(path_+"Pendulum_Acc_Reward_vs_Episode_Test_Hist.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print("Test Normalized Acc Episodic Reward's Results:")
print(f"Unnormalized: max={norm_to_unnorm(data_rewards).max():.3f} ,mean={norm_to_unnorm(data_rewards).mean():.3f}, std={norm_to_unnorm(data_rewards).std():.3f}")
print(f"Normalized:   max={data_rewards.max():.3e} ,mean={data_rewards.mean():.3e}, std={data_rewards.std():.3e}")
# Out:
# Test Normalized Acc Episodic Reward's Results:
# Unnormalized: max=-0.761 ,mean=-138.448, std=102.924
# Normalized:   max=9.998e-01 ,mean=9.575e-01, std=3.162e-02

# %%
#!pip install latex

# %%
dt=env.dt

# %%
time_ = np.linspace(start = 0, stop = len(save_actual_torque)* dt,num=len(save_actual_torque) )

font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(4.5)
f.set_figheight(1.5)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')


plt.step(time_, save_wanted_torque ,label = r"$r=a^{desired}$ from RL alg.",color="blue",linewidth = 1.5)
plt.step(time_, save_model_torque , '--',label = "$y_m=a^{model}$ from MRAC ref. model",color="green",linewidth = 2)
plt.step(time_, save_actual_torque , ':',label = "$y=a^{actual}$ from DC motor plant",color="red",linewidth = 4)
plt.minorticks_on()
plt.xlabel("Time (s)")
plt.ylabel("Torque (N⋅m)")
plt.legend(fontsize=7)#,bbox_to_anchor=(1, 1), loc='upper left')
#plt.grid()
plt.xlim(-0.1,10.1)
plt.savefig(path_+"Pendulum_Torque_vs_Time.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
e_ry=np.array(save_wanted_torque)-np.array(save_actual_torque)
e_yy_m=np.array(save_actual_torque)-np.array(save_model_torque)
print(f"e_ry: (mean, std, mae) = ({e_ry.mean():.2e}, {e_ry.std():.2e}, {np.abs(e_ry).mean():.2e})")
print(f"e_yy_m: (mean, std, mae) = ({e_yy_m.mean():.2e}, {e_yy_m.std():.2e}, {np.abs(e_yy_m).mean():.2e})")
# Out:
# e_ry: (mean, std, mae) = (-1.70e-03, 1.93e-01, 1.47e-01)
# e_yy_m: (mean, std, mae) = (8.65e-04, 1.23e-02, 9.87e-03)

# %%
font = {'size': 20}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(6)
f.set_figheight(4)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

e_ry=np.array(save_wanted_torque)-np.array(save_actual_torque)
e_yy_m=np.array(save_actual_torque)-np.array(save_model_torque)


plt.step(time_, e_ry ,label = "$e_{r,y}=a^{desired}-a^{actual}$ ",color="cyan",linewidth = 1.5)
plt.step(time_, e_yy_m , ':',label = "$e_{y,y_m}=a^{actual}-a^{model}$ ",color="brown",linewidth = 4)
plt.axhline(y=e_ry.mean(), color="black",linewidth = 2, linestyle='--', label='mean($e_{r,y}$) =' +f'{e_ry.mean():.1e}')
plt.axhline(y=e_yy_m.mean(), color="magenta",linewidth = 2, linestyle='-.', label='mean($e_{y,y_m}$) =' +f'{e_yy_m.mean():.1e}')


plt.xlabel("time [sec]")
plt.ylabel("Torque error [Nm]")
plt.ylim(-0.6,1.05)
plt.legend(fontsize=11, bbox_to_anchor=(0.5, 0.85),loc='center',ncols=2)
plt.title('Pendulum',fontsize=20)
#plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.grid()
plt.show()

# %%
from scipy.integrate import cumulative_trapezoid

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

e_ry=np.array(save_wanted_torque)-np.array(save_actual_torque)
e_yy_m=np.array(save_actual_torque)-np.array(save_model_torque)


plt.step(time_, e_ry ,label = r"$e_{r,y}=a^{wanted}-a^{actual}$ ",color="cyan",linewidth = 1.5)
plt.step(time_, e_yy_m , ':',label = "$e_{y,y_m}=a^{actual}-a^{model}$ ",color="brown",linewidth = 4)

plt.xlabel("time [sec]")
plt.ylabel("Torque error [Nm]")
plt.legend(fontsize=12)
#plt.legend(fontsize=10,bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.grid()
plt.show()

# %%
font = {'size': 15}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

e_ry=np.array(save_wanted_torque)-np.array(save_actual_torque)
e_yy_m=np.array(save_actual_torque)-np.array(save_model_torque)

cum_trapz_e_ry = cumulative_trapezoid(y=np.r_[0,e_ry],x=None, dx=dt)
cum_trapz_e_yy_m = cumulative_trapezoid(y=np.r_[0,e_yy_m],x=None, dx=dt)


plt.step(time_, e_ry ,label = r"$e_{r,y}=a^{wanted}-a^{actual}$ ",color="cyan",linewidth = 1.5)
plt.step(time_, e_yy_m , ':',label = "$e_{y,y_m}=a^{actual}-a^{model}$ ",color="brown",linewidth = 4)

plt.plot(time_, cum_trapz_e_ry,'--',
         label = r"cumtrapz($e_{r,y}$)",color="black",linewidth = 2)
plt.plot(time_, cum_trapz_e_yy_m,'-.',
         label = r"cumtrapz($e_{y,y_m}$)",color="magenta",linewidth = 2)

plt.xlabel("time [sec]")
plt.ylabel("Torque error [Nm]")
plt.legend(fontsize=10,bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.grid()
plt.show()

# %%
font = {'size': 20}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(6)
f.set_figheight(4)

plt.plot(time_, save_ctrl_voltage)
plt.xlabel("time [sec]")
plt.ylabel("Control Voltage[volts]")
plt.title('Pendulum',fontsize=20)
plt.grid()
plt.show()

# %%
np_array_MRAC_adapt_gains = np.array(save_MRAC_adapt_gains).T

# %%
font = {'size': 20}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(6)
f.set_figheight(4)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

plt.plot(time_, np_array_MRAC_adapt_gains[0]
         ,label = r"$\hat{k_r}$=coeff of $a^{desired}$"+f"→{np_array_MRAC_adapt_gains[0,-20:-1].mean():.1e}",color="C0",linewidth = 2)
plt.plot(time_, np_array_MRAC_adapt_gains[1],'--'
         ,label = r"$\hat{k_y}$=coeff of $a^{actual}$"+f"→{np_array_MRAC_adapt_gains[1,-20:-1].mean():.1e}",color="C1",linewidth = 3)
plt.plot(time_, np_array_MRAC_adapt_gains[2],':',
         label = r"$\hat{k}_{r-y}$=coeff of $(a^{wanted}-a^{actual})$"+f"→{np_array_MRAC_adapt_gains[2,-20:-1].mean():.1e}",color="C2",linewidth = 4)
plt.plot(time_, np_array_MRAC_adapt_gains[3],'-.',
         label = r"$\hat{k}_\omega$=coeff of $\dot{\theta}$"+f"→{np_array_MRAC_adapt_gains[3,-20:-1].mean():.1e}",color="C3",linewidth = 2)
plt.xlabel("time [sec]")
plt.ylabel("Adaptation control gains",fontsize=17)
plt.grid()
plt.title('Pendulum',fontsize=20)
#plt.legend(fontsize=10)
plt.legend(fontsize=10, bbox_to_anchor=(0.5, 0.3), loc='center')
#plt.legend(fontsize=10, bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %%
import math

x_print = []
y_print = []
thetadot_print = []

for observ in save_observation:
  for index,value in enumerate(observ):
    if index == 0:
      x_print.append(value)
      #theta_print.append(math.acos(value))
    if index == 1:
      y_print.append(value)
    if index == 2:
      thetadot_print.append(value)

theta_print = list(np.arctan2(np.array(y_print), np.array(x_print)))

# %%
#dt=0.05
print(len(x_print))
# Out:
# 201

# %%
#dt=0.05
print(len(x_print))
# Out:
# 201

# %%
font = {'size': 10}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(3)
f.set_figheight(2)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')


plt.plot(time_, x_print,
         label = r"x=cos($\theta$): Vertical pos.[m]",color="blue",linewidth = 1.5)
plt.plot(time_, y_print,':',
         label = r"y=sin($\theta$): Horizontal pos.[m]",color="red",linewidth = 4)
plt.xlabel("time [sec]")
plt.ylabel("Pendulum's position")
plt.grid()
plt.title('Pendulum')
plt.legend(fontsize=7)
plt.show()

# %%
font = {'size': 10}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(3)
f.set_figheight(2)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}')


plt.plot(time_, theta_print,
         label = r"$\theta$: Angle [rad]",color="blue",linewidth = 1.5)
plt.plot(time_, thetadot_print,':',
         label = r"$\dot{\theta}$: Angular Velocity [rad/sec]",color="red",
         linewidth = 4)
plt.xlabel("time [sec]")
plt.ylabel("Pendulum's angle\nand angular velocity")
plt.title('Pendulum')
plt.grid()
plt.legend(fontsize=7)
plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline

time_theta_print = np.linspace(start = 0, stop = len(theta_print)* dt,num=len(theta_print))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_theta_print[-1] , 300)
spl = make_interp_spline(time_theta_print, theta_print, k=3)  # type: BSpline
power_smooth_theta = spl(xnew)

time_thetadot_print = np.linspace(start = 0, stop = len(thetadot_print)* dt,num=len(thetadot_print))
# 300 represents number of points to make between T.min and T.max
xnew = np.linspace(0, time_thetadot_print[-1] , 300)
spl = make_interp_spline(time_thetadot_print, thetadot_print, k=3)  # type: BSpline
power_smooth_theta_dot = spl(xnew)

# %%
font = {'size': 9}
plt.rc('font', **font)
f = plt.figure()
f.set_figwidth(2)
f.set_figheight(1.5)

plt.plot(xnew, 180*power_smooth_theta/np.pi,label=r'$\theta(\degree)$',linewidth = 2)
plt.plot(xnew, 10*power_smooth_theta_dot,'--',color='red',label=r'10$\times$[$\dot{\theta}$(rad/s)]',linewidth = 0.75)
plt.minorticks_on()
plt.xlabel("Time (s)")
#plt.rc('text.latex', preamble=r'\usepackage{amsmath}')
#plt.ylabel(r'Angle $\theta$ (rad) and'+'\n'+r'Angular velocity $\dot{\theta}$ (rad/s)')
plt.ylabel(r'Angle $\theta$ and'+'\n' +r'Velocity $\dot{\theta}$')
#plt.grid()
plt.legend(fontsize=7)
plt.savefig(path_+"Pendulum_Angle_and_Velocity_vs_Time.pdf", format='pdf', bbox_inches='tight')
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
force_square_mean = (np.array(save_actual_torque)**2).mean()
power_smooth_theta_mean = np.array(power_smooth_theta).mean()
power_smooth_square_theta_mean = np.array(power_smooth_theta**2).mean()
power_smooth_theta_dot_mean = np.array(power_smooth_theta_dot).mean()
power_smooth_square_theta_dot_mean = np.array(power_smooth_theta_dot**2).mean()

# %%
reward_mean = -(power_smooth_square_theta_mean+0.1*power_smooth_square_theta_dot_mean+0.001*force_square_mean)

# %%
print(f'reward_mean (in time) = {reward_mean:.2e}')
print(f'acc. episodic of mean reward={200*reward_mean:.3f}')
# Out:
# reward_mean (in time) = -3.75e-03
# acc. episodic of mean reward=-0.749

# %%
print(f'theta mean={power_smooth_theta_mean:.2e} ({180*power_smooth_theta_mean/np.pi:.2e} degrees)')
# Out:
# theta mean=5.33e-03 (3.05e-01 degrees)

# %%
print(f'theta_dot mean={power_smooth_theta_dot_mean:.2e}')
# Out:
# theta_dot mean=2.92e-03
